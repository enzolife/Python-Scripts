# %%
from pandas import Series, DataFrame
import pandas as pd
import glob
import os

# %%
path ='D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.4.23 Data Visualization\\Order\\SG' # use your path
allFiles = glob.glob(path + "\\*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    os.chdir(os.path.dirname(file_))
    df = pd.read_csv(os.path.basename(file_),index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
frame['Purchased on']= pd.to_datetime(frame['Purchased on'])
grouped = frame['Order ID'].groupby([frame['Purchased on'],frame['Country']])
order_by_date_by_country = grouped.count()
order_by_date_by_country
# Out:
# Purchased on  Country
# 2016-03-10    SG            4
# 2016-03-11    SG            3
# 2016-03-13    SG            1
# 2016-03-15    SG            3
# 2016-03-17    SG            1
# 2016-03-18    SG            2
# 2016-03-20    SG            2
# 2016-03-21    SG           15
# 2016-03-22    SG            8
# 2016-03-23    SG            4
# 2016-03-24    SG            9
# 2016-03-25    SG            6
# 2016-03-26    SG           10
# 2016-03-27    SG           27
# 2016-03-28    SG           37
# 2016-03-29    SG           63
# 2016-03-30    SG           39
# 2016-03-31    SG           84
# 2016-04-01    SG          158
# 2016-04-02    SG          126
# 2016-04-03    SG           86
# 2016-04-04    SG           63
# 2016-04-05    SG           50
# 2016-04-06    SG           52
# 2016-04-07    SG           75
# 2016-04-08    SG           90
# 2016-04-09    SG          113
# 2016-04-10    SG           80
# 2016-04-11    SG          102
# 2016-04-12    SG           74
#                          ...
# 2017-06-21    SG         1020
# 2017-06-22    SG          954
# 2017-06-23    SG         1437
# 2017-06-24    SG         1092
# 2017-06-25    SG         1092
# 2017-06-26    SG         1280
# 2017-06-27    SG         1029
# 2017-06-28    SG         1305
# 2017-06-29    SG         1329
# 2017-06-30    SG         1366
# 2017-07-01    SG         1553
# 2017-07-02    SG         1651
# 2017-07-03    SG         1398
# 2017-07-04    SG         1352
# 2017-07-05    SG         1584
# 2017-07-06    SG         1416
# 2017-07-07    SG         1687
# 2017-07-08    SG         1730
# 2017-07-09    SG         1891
# 2017-07-10    SG         1671
# 2017-07-11    SG         1982
# 2017-07-12    SG         1687
# 2017-07-13    SG         1691
# 2017-07-14    SG         1430
# 2017-07-15    SG         1496
# 2017-07-16    SG         1661
# 2017-07-17    SG         1721
# 2017-07-18    SG         1677
# 2017-07-19    SG         1562
# 2017-07-20    SG         1628
# Name: Order ID, dtype: int64

# %%
order_by_date_by_country_pivot = frame.pivot_table('Order ID',aggfunc='count',index=['Purchased on'],columns='Country')
order_by_date_by_country_pivot
# Out:
# Country         SG
# Purchased on
# 2016-03-10       4
# 2016-03-11       3
# 2016-03-13       1
# 2016-03-15       3
# 2016-03-17       1
# 2016-03-18       2
# 2016-03-20       2
# 2016-03-21      15
# 2016-03-22       8
# 2016-03-23       4
# 2016-03-24       9
# 2016-03-25       6
# 2016-03-26      10
# 2016-03-27      27
# 2016-03-28      37
# 2016-03-29      63
# 2016-03-30      39
# 2016-03-31      84
# 2016-04-01     158
# 2016-04-02     126
# 2016-04-03      86
# 2016-04-04      63
# 2016-04-05      50
# 2016-04-06      52
# 2016-04-07      75
# 2016-04-08      90
# 2016-04-09     113
# 2016-04-10      80
# 2016-04-11     102
# 2016-04-12      74
# ...            ...
# 2017-06-21    1020
# 2017-06-22     954
# 2017-06-23    1437
# 2017-06-24    1092
# 2017-06-25    1092
# 2017-06-26    1280
# 2017-06-27    1029
# 2017-06-28    1305
# 2017-06-29    1329
# 2017-06-30    1366
# 2017-07-01    1553
# 2017-07-02    1651
# 2017-07-03    1398
# 2017-07-04    1352
# 2017-07-05    1584
# 2017-07-06    1416
# 2017-07-07    1687
# 2017-07-08    1730
# 2017-07-09    1891
# 2017-07-10    1671
# 2017-07-11    1982
# 2017-07-12    1687
# 2017-07-13    1691
# 2017-07-14    1430
# 2017-07-15    1496
# 2017-07-16    1661
# 2017-07-17    1721
# 2017-07-18    1677
# 2017-07-19    1562
# 2017-07-20    1628
#
# [494 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
order_by_date_by_country_pivot.plot(kind='line')
plt.show()

# %%
frame['year'] = frame['Purchased on'].dt.year
frame['month'] = frame['Purchased on'].dt.month
grouped = frame['Order ID'].groupby([frame['year'],frame['month'],frame['Country']])
order_by_month_year_by_country = grouped.count()
order_by_month_year_by_country
# Out:
# year  month  Country
# 2016  3      SG           318
#       4      SG          3068
#       5      SG          8366
#       6      SG         11878
#       7      SG          8981
#       8      SG         10678
#       9      SG         12856
#       10     SG         14173
#       11     SG         17839
#       12     SG         18829
# 2017  1      SG         19391
#       2      SG         19597
#       3      SG         27118
#       4      SG         32231
#       5      SG         36180
#       6      SG         35476
#       7      SG         32468
# Name: Order ID, dtype: int64

# %%
frame['year/month'] = frame['Purchased on'].dt.strftime('%Y-%m')
grouped = frame['Order ID'].groupby([frame['year/month'],frame['Country']])
order_by_month_year_by_country_new = grouped.count()
order_by_month_year_by_country_new
# Out:
# year/month  Country
# 2016-03     SG           318
# 2016-04     SG          3068
# 2016-05     SG          8366
# 2016-06     SG         11878
# 2016-07     SG          8981
# 2016-08     SG         10678
# 2016-09     SG         12856
# 2016-10     SG         14173
# 2016-11     SG         17839
# 2016-12     SG         18829
# 2017-01     SG         19391
# 2017-02     SG         19597
# 2017-03     SG         27118
# 2017-04     SG         32231
# 2017-05     SG         36180
# 2017-06     SG         35476
# 2017-07     SG         32468
# Name: Order ID, dtype: int64

# %%
order_by_month_year_by_country_pivot = frame.pivot_table('Order ID',aggfunc='count',index=['year/month'],columns='Country')
order_by_month_year_by_country_pivot
# Out:
# Country        SG
# year/month
# 2016-03       318
# 2016-04      3068
# 2016-05      8366
# 2016-06     11878
# 2016-07      8981
# 2016-08     10678
# 2016-09     12856
# 2016-10     14173
# 2016-11     17839
# 2016-12     18829
# 2017-01     19391
# 2017-02     19597
# 2017-03     27118
# 2017-04     32231
# 2017-05     36180
# 2017-06     35476
# 2017-07     32468

# %%
order_by_month_year_by_country_pivot.plot(kind='bar',stacked=True)
plt.show()

# %%
percentage_changed = order_by_month_year_by_country_pivot.pct_change()
percentage_changed
# Out:
# Country           SG
# year/month
# 2016-03          NaN
# 2016-04     8.647799
# 2016-05     1.726858
# 2016-06     0.419794
# 2016-07    -0.243896
# 2016-08     0.188954
# 2016-09     0.203971
# 2016-10     0.102442
# 2016-11     0.258661
# 2016-12     0.055496
# 2017-01     0.029848
# 2017-02     0.010623
# 2017-03     0.383783
# 2017-04     0.188546
# 2017-05     0.122522
# 2017-06    -0.019458
# 2017-07    -0.084790

# %%
percentage_changed.plot(kind='line')
plt.show()

# %%
order_by_month_year_by_country_pivot.to_csv('test_file.csv', sep=',', encoding='utf-8')
