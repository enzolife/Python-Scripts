# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = [
    'https://spreadsheets.google.com/feeds',
    'https://www.googleapis.com/auth/drive'
]

credentials = ServiceAccountCredentials.from_json_keyfile_name("C:\\Users\\kuang\\Documents\\Python Scripts\\Enzo's Test Project-ea5529b41c25.json", scope)

gc = gspread.authorize(credentials)

# sh = gc.create('2017.5.26 Test Google Sheet')

# sh.share('enzo.kuang@shopeemobile.com', perm_type='user', role='writer')

# %%
sht1 = gc.open_by_key('166AFf3_GdxtMlLJ2hJQiTFfb3ojlL-dorNWRGwoAu0s')

# %%
worksheet = sht1.sheet1

# %%
val = worksheet.acell('B1').value
val
# Out:
# 'O_o'

# %%
# Get all values from the first row
values_list_row = worksheet.row_values(1)

# Get all values from the first column
values_list_column = worksheet.col_values(1)

# %%
values_list_row
# Out:
# ['O_o',
#  'O_o',
#  'O_o',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
values_list_column
# Out:
# ['O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
worksheet.update_acell('B1', 'Bingo!')

# %%
# Select a range
cell_list = worksheet.range('A1:C7')

for cell in cell_list:
    cell.value = 'O_o'

# Update in batch
worksheet.update_cells(cell_list)

# %%
# Get all values from the first row
values_list_row = worksheet.row_values(1)

# Get all values from the first column
values_list_column = worksheet.col_values(1)

# %%
values_list_row
# Out:
# ['O_o',
#  'O_o',
#  'O_o',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
values_list_column
# Out:
# ['O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  'O_o',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
list_of_lists = worksheet.get_all_values()
list_of_lists
# Out:
# [['O_o', 'O_o', 'O_o'],
#  ['O_o', 'O_o', 'O_o'],
#  ['O_o', 'O_o', 'O_o'],
#  ['O_o', 'O_o', 'O_o'],
#  ['O_o', 'O_o', 'O_o'],
#  ['O_o', 'O_o', 'O_o'],
#  ['O_o', 'O_o', 'O_o']]

# %%
sht2 = gc.open_by_key('1q_DFS_9EDM5TEdfi5rK9AgYlHEE2nU-9COTM_EzqNXA')

# 要先将google sheet share给我的那个开发账户，才可以这样读取，否则就会not found
