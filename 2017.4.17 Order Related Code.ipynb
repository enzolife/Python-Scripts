# %%
from pandas import Series, DataFrame
import pandas as pd
import glob

# %%
path ='D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.4.23 Data Visualization\\Order' # use your path
allFiles = glob.glob(path + "\\*\\*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
frame['Purchased on']= pd.to_datetime(frame['Purchased on'])
grouped = frame['﻿Order ID'].groupby([frame['Purchased on'],frame['Country']])
order_by_date_by_country = grouped.count()
order_by_date_by_country
# Out:
# Purchased on  Country
# 2016-03-10    SG             4
# 2016-03-11    SG             3
# 2016-03-13    SG             1
# 2016-03-15    SG             3
# 2016-03-17    MY             1
#               SG             1
# 2016-03-18    MY             2
#               SG             2
# 2016-03-20    SG             2
# 2016-03-21    SG            15
# 2016-03-22    SG             8
# 2016-03-23    MY             5
#               SG             4
# 2016-03-24    MY             7
#               SG             9
# 2016-03-25    MY            16
#               SG             6
# 2016-03-26    MY            16
#               SG            10
# 2016-03-27    MY             7
#               SG            27
# 2016-03-28    MY            10
#               SG            37
# 2016-03-29    MY            20
#               SG            63
# 2016-03-30    MY            25
#               SG            39
# 2016-03-31    MY            25
#               SG            84
# 2016-04-01    MY            24
#                          ...
# 2017-04-18    ID          2645
#               MY          5401
#               SG           877
#               TH           946
#               TW          7634
# 2017-04-19    ID          2546
#               MY          5078
#               SG           931
#               TH           894
#               TW          8380
# 2017-04-20    ID          2753
#               MY          5253
#               SG           903
#               TH           983
#               TW          8220
# 2017-04-21    ID          2701
#               MY          4721
#               SG           864
#               TH           847
#               TW         13589
# 2017-04-22    ID          3051
#               MY          4326
#               SG           958
#               TH           868
#               TW         15493
# 2017-04-23    ID          3197
#               MY          4074
#               SG          1077
#               TH           889
#               TW         14550
# Name: ﻿Order ID, dtype: int64

# %%
order_by_date_by_country_pivot = frame.pivot_table('﻿Order ID',aggfunc='count',index=['Purchased on'],columns='Country')
order_by_date_by_country_pivot
# Out:
# Country           ID      MY      SG      TH       TW
# Purchased on
# 2016-03-10       NaN     NaN     4.0     NaN      NaN
# 2016-03-11       NaN     NaN     3.0     NaN      NaN
# 2016-03-13       NaN     NaN     1.0     NaN      NaN
# 2016-03-15       NaN     NaN     3.0     NaN      NaN
# 2016-03-17       NaN     1.0     1.0     NaN      NaN
# 2016-03-18       NaN     2.0     2.0     NaN      NaN
# 2016-03-20       NaN     NaN     2.0     NaN      NaN
# 2016-03-21       NaN     NaN    15.0     NaN      NaN
# 2016-03-22       NaN     NaN     8.0     NaN      NaN
# 2016-03-23       NaN     5.0     4.0     NaN      NaN
# 2017-04-18    2645.0  5401.0   877.0   946.0   7634.0
# 2017-04-19    2546.0  5078.0   931.0   894.0   8380.0
# 2017-04-20    2753.0  5253.0   903.0   983.0   8220.0
# 2017-04-21    2701.0  4721.0   864.0   847.0  13589.0
# 2017-04-22    3051.0  4326.0   958.0   868.0  15493.0
# 2017-04-23    3197.0  4074.0  1077.0   889.0  14550.0
#
# [406 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
order_by_date_by_country_pivot.plot(kind='line')
plt.show()

# %%
frame['year'] = frame['Purchased on'].dt.year
frame['month'] = frame['Purchased on'].dt.month
grouped = frame['﻿Order ID'].groupby([frame['year'],frame['month'],frame['Country']])
order_by_month_year_by_country = grouped.count()
order_by_month_year_by_country
# Out:
# year  month  Country
# 2016  3      MY            134
#              SG            318
#       4      MY           4935
#              SG           3068
#              TW             28
#       5      MY          14797
#              SG           8366
#              TW           3600
#       6      ID           6786
#              MY          36906
#              SG          11878
#              TW           2917
#       7      ID          11670
#              MY          42725
#              SG           8981
#              TW           3178
#       8      ID          21768
#              MY          48430
#              SG          10678
#              TH            409
#              TW           6440
#       9      ID          56131
#              MY          54852
#              SG          12856
#              TH           4631
#              TW          16058
#       10     ID          61311
#              MY          68014
#              SG          14173
#              TH          10756
#                          ...
#       11     ID          76005
#              MY          70533
#              SG          17839
#              TH          14609
#              TW          45727
#       12     ID          72323
#              MY          86268
#              SG          18829
#              TH          23433
#              TW          70550
# 2017  1      ID          70182
#              MY          82392
#              SG          19391
#              TH          28489
#              TW          82524
#       2      ID          50113
#              MY          94688
#              SG          19597
#              TH          23205
#              TW         108364
#       3      ID          76996
#              MY         145970
#              SG          27118
#              TH          26895
#              TW         181714
#       4      ID          63954
#              MY         122343
#              SG          23717
#              TH          18448
#              TW         202180
# Name: ﻿Order ID, dtype: int64

# %%
frame['year/month'] = frame['Purchased on'].dt.strftime('%Y-%m')
grouped = frame['﻿Order ID'].groupby([frame['year/month'],frame['Country']])
order_by_month_year_by_country_new = grouped.count()
order_by_month_year_by_country_new
# Out:
# year/month  Country
# 2016-03     MY            134
#             SG            318
# 2016-04     MY           4935
#             SG           3068
#             TW             28
# 2016-05     MY          14797
#             SG           8366
#             TW           3600
# 2016-06     ID           6786
#             MY          36906
#             SG          11878
#             TW           2917
# 2016-07     ID          11670
#             MY          42725
#             SG           8981
#             TW           3178
# 2016-08     ID          21768
#             MY          48430
#             SG          10678
#             TH            409
#             TW           6440
# 2016-09     ID          56131
#             MY          54852
#             SG          12856
#             TH           4631
#             TW          16058
# 2016-10     ID          61311
#             MY          68014
#             SG          14173
#             TH          10756
#                         ...
# 2016-11     ID          76005
#             MY          70533
#             SG          17839
#             TH          14609
#             TW          45727
# 2016-12     ID          72323
#             MY          86268
#             SG          18829
#             TH          23433
#             TW          70550
# 2017-01     ID          70182
#             MY          82392
#             SG          19391
#             TH          28489
#             TW          82524
# 2017-02     ID          50113
#             MY          94688
#             SG          19597
#             TH          23205
#             TW         108364
# 2017-03     ID          76996
#             MY         145970
#             SG          27118
#             TH          26895
#             TW         181714
# 2017-04     ID          63954
#             MY         122343
#             SG          23717
#             TH          18448
#             TW         202180
# Name: ﻿Order ID, dtype: int64

# %%
order_by_month_year_by_country_pivot = frame.pivot_table('﻿Order ID',aggfunc='count',index=['year/month'],columns='Country')
order_by_month_year_by_country_pivot
# Out:
# Country          ID        MY       SG       TH        TW
# year/month
# 2016-03         NaN     134.0    318.0      NaN       NaN
# 2016-04         NaN    4935.0   3068.0      NaN      28.0
# 2016-05         NaN   14797.0   8366.0      NaN    3600.0
# 2016-06      6786.0   36906.0  11878.0      NaN    2917.0
# 2016-07     11670.0   42725.0   8981.0      NaN    3178.0
# 2016-08     21768.0   48430.0  10678.0    409.0    6440.0
# 2016-09     56131.0   54852.0  12856.0   4631.0   16058.0
# 2016-10     61311.0   68014.0  14173.0  10756.0   23277.0
# 2016-11     76005.0   70533.0  17839.0  14609.0   45727.0
# 2016-12     72323.0   86268.0  18829.0  23433.0   70550.0
# 2017-01     70182.0   82392.0  19391.0  28489.0   82524.0
# 2017-02     50113.0   94688.0  19597.0  23205.0  108364.0
# 2017-03     76996.0  145970.0  27118.0  26895.0  181714.0
# 2017-04     63954.0  122343.0  23717.0  18448.0  202180.0

# %%
order_by_month_year_by_country_pivot.plot(kind='bar',stacked=True)
plt.show()

# %%
percentage_changed = order_by_month_year_by_country_pivot.pct_change()
percentage_changed
# Out:
# Country           ID         MY        SG         TH          TW
# year/month
# 2016-03          NaN        NaN       NaN        NaN         NaN
# 2016-04          NaN  35.828358  8.647799        NaN         NaN
# 2016-05          NaN   1.998379  1.726858        NaN  127.571429
# 2016-06          NaN   1.494154  0.419794        NaN   -0.189722
# 2016-07     0.719717   0.157671 -0.243896        NaN    0.089475
# 2016-08     0.865296   0.133528  0.188954        NaN    1.026432
# 2016-09     1.578602   0.132604  0.203971  10.322738    1.493478
# 2016-10     0.092284   0.239955  0.102442   1.322609    0.449558
# 2016-11     0.239663   0.037036  0.258661   0.358219    0.964471
# 2016-12    -0.048444   0.223087  0.055496   0.604011    0.542852
# 2017-01    -0.029603  -0.044930  0.029848   0.215764    0.169724
# 2017-02    -0.285957   0.149238  0.010623  -0.185475    0.313121
# 2017-03     0.536448   0.541589  0.383783   0.159017    0.676885
# 2017-04    -0.169385  -0.161862 -0.125415  -0.314073    0.112628

# %%
percentage_changed.plot(kind='line')
plt.show()

# %%
order_by_month_year_by_country_pivot.to_csv('test_file.csv', sep=',', encoding='utf-8')
