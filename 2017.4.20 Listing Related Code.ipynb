# %%
from pandas import Series, DataFrame
import pandas as pd
import glob

# %%
path ='D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.4.23 Data Visualization\\Listing' # use your path
allFiles = glob.glob(path + "\\*\\*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (27,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
frame['Date Created']= pd.to_datetime(frame['Date Created'])
frame['year/month'] = frame['Date Created'].dt.strftime('%Y-%m')
listing_by_month_year_by_country_pivot = frame.pivot_table('﻿Product ID',aggfunc='count',index=['year/month'],columns='Country')
listing_by_month_year_by_country_pivot
# Out:
# Country           ID        MY        SG        TH         TW
# year/month
# 2016-03          NaN     897.0    1270.0       NaN        NaN
# 2016-04          NaN    4865.0    4822.0       NaN     1420.0
# 2016-05          NaN    9477.0    9449.0       NaN     5456.0
# 2016-06       2091.0   21842.0   21460.0       NaN     4758.0
# 2016-07       4781.0   54595.0   42958.0       NaN    12916.0
# 2016-08      27946.0   84768.0   79588.0    3744.0    22813.0
# 2016-09     122175.0  150003.0  137638.0   28215.0    61711.0
# 2016-10     134569.0  155831.0  129401.0   30094.0   113017.0
# 2016-11     171533.0  237514.0  202325.0  107490.0   163933.0
# 2016-12     233959.0  235631.0  160256.0  166353.0   250128.0
# 2017-01     164219.0  119267.0   84176.0   88038.0   137610.0
# 2017-02     143603.0  160073.0  100005.0  127448.0   497418.0
# 2017-03     182563.0  313295.0  240313.0  208936.0  1422915.0
# 2017-04     217179.0  304092.0  252819.0  202571.0  1237904.0

# %%
import matplotlib.pyplot as plt
listing_by_month_year_by_country_pivot.plot(kind='bar',stacked=True)
plt.show()

# %%
listing_by_category_by_country_pivot = frame.pivot_table('﻿Product ID',aggfunc='count',index=['Category'],columns='Country')
listing_by_category_by_country_pivot
# Out:
# Country                          ID        MY        SG        TH         TW
# Category
# Arts                            NaN   22441.0   24730.0       NaN        NaN
# Automotive                  22748.0       NaN       NaN       NaN        NaN
# Baby & Kids                 62834.0       NaN       NaN       NaN        NaN
# Baby & Toys                     NaN  124553.0   90326.0   60651.0        NaN
# Bags                            NaN       NaN   68092.0   43729.0        NaN
# Computer & Accessories      29484.0   25618.0   25075.0   16355.0        NaN
# Cosmetics                   94141.0       NaN       NaN       NaN        NaN
# DIY                             NaN       NaN       NaN   17695.0        NaN
# Electronics                 39347.0       NaN       NaN       NaN        NaN
# Everything Else                 NaN       NaN       NaN       NaN    90546.0
# Fashion Accessories        224406.0  272563.0  226810.0  137741.0        NaN
# Food & Beverages              919.0     684.0    1088.0    1407.0     6354.0
# Game Kingdom                    NaN       NaN       NaN       NaN    22637.0
# Games                           NaN   33053.0   16131.0   14514.0        NaN
# Hardware & 3C                   NaN       NaN       NaN       NaN    90078.0
# Health & Beauty             49926.0  184061.0  145467.0   89653.0   117213.0
# Helpbuy                         NaN       NaN       NaN       NaN    12165.0
# Hobby & Toys                68364.0       NaN       NaN       NaN        NaN
# Home & Living              152250.0  225666.0  169486.0  113225.0   225290.0
# Home Appliances                 NaN   17223.0   22291.0       NaN        NaN
# Home Electronic                 NaN       NaN       NaN       NaN    20194.0
# Life & Entertainment            NaN       NaN       NaN       NaN    88760.0
# Men Bags                     8284.0       NaN       NaN       NaN        NaN
# Men Clothes                 42333.0   68411.0   40083.0   32150.0        NaN
# Men Shoes                    9988.0   28626.0   12266.0   10490.0   253802.0
# Men's Apparel                   NaN       NaN       NaN       NaN   476332.0
# Men's Bags & Wallets            NaN   10277.0       NaN       NaN        NaN
# Men's Bags& Accessories         NaN       NaN       NaN       NaN   123060.0
# Mobile & Accessories       149955.0  243614.0  199152.0       NaN        NaN
# Mobile & Gadgets                NaN       NaN       NaN  125740.0   248389.0
# Mother & Baby                   NaN       NaN       NaN       NaN   253437.0
# Motors                          NaN       NaN       NaN       NaN    27589.0
# Muslim Fashion               3470.0    5079.0       NaN       NaN        NaN
# Others                      20051.0   63460.0   44200.0   37205.0        NaN
# Pets                            NaN       NaN   12492.0    7599.0    12153.0
# Photography & Videography   13584.0       NaN       NaN   22759.0        NaN
# Shoes                           NaN       NaN       NaN      12.0        NaN
# Souvenir                     4798.0       NaN       NaN       NaN        NaN
# Sports                      67985.0       NaN       NaN       NaN        NaN
# Sports & Outdoor                NaN   70881.0       NaN       NaN        NaN
# Sports & Outdoors               NaN       NaN   81445.0   26982.0    55393.0
# Stationery & Books              NaN       NaN     227.0    4557.0        NaN
# Tickets & Services              NaN       NaN       NaN       NaN      115.0
# Tickets & Vouchers              NaN      62.0      35.0      28.0        NaN
# Travel & Lifestyle              NaN       NaN       NaN    5347.0        NaN
# Vouchers                       85.0       NaN       NaN       NaN        NaN
# Watches                     71135.0   77805.0   54917.0       NaN        NaN
# Watches & Glasses               NaN       NaN       NaN   39877.0        NaN
# Women Accessories               NaN       NaN       NaN       NaN   276287.0
# Women Bags                  62320.0       NaN       NaN       NaN   135977.0
# Women Clothes              185251.0  266470.0  207821.0  137623.0        NaN
# Women Shoes                 20960.0   31949.0   24346.0   17550.0   265088.0
# Women's Apparel                 NaN       NaN       NaN       NaN  1131140.0
# Women's Bags                    NaN   79654.0       NaN       NaN        NaN

# %%
listing_by_category_by_country_pivot.to_csv('test_file.csv', sep=',', encoding='utf-8')
