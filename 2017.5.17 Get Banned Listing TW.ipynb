# %%
from pandas import Series, DataFrame
import pandas as pd
import glob

# %%
path ='D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.4.23 Data Visualization\\Listing\\TW' # use your path
allFiles = glob.glob(path + "\\*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (28,29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# 输出的目录
output_file_path = "D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.8.25 Temp Report Folder\\"

# %%
# 计算Yesterday New Live SKUs
frame4 = frame[(frame['Product name'].str.contains("行動電源|移動電源|充電寶|行動充電寶|麥克風|藍牙音箱|藍牙音響|平衡車")==True)]
frame4[0:10]
# Out:
#       ﻿Product ID Username Shopname         Category  \
# 1357    263355078    ya.tw    ya.tw  Home Electronic
# 1360    263355052    ya.tw    ya.tw  Home Electronic
# 1401    263354501    ya.tw    ya.tw  Home Electronic
# 1406    263354463    ya.tw    ya.tw  Home Electronic
# 1419    263354163    ya.tw    ya.tw  Home Electronic
# 1424    263354078    ya.tw    ya.tw  Home Electronic
# 1454    263353844    ya.tw    ya.tw  Home Electronic
# 1459    263353689    ya.tw    ya.tw  Home Electronic
# 1468    263353381    ya.tw    ya.tw  Home Electronic
# 1472    263353362    ya.tw    ya.tw  Home Electronic
#
#                                     Product name Brand   Price  \
# 1357     【批發價現貨】索愛 S-75戶外無線藍牙音箱迷你便攜式七彩燈音響插卡炫彩低音炮  None  1253.0
# 1360  【批發價現貨】索愛 S-51藍牙音箱戶外4.0無線防水便攜插卡低音炮LED炫彩小音響  None  1032.0
# 1401    【批發價現貨】索愛 X6無線藍牙音箱便攜戶外雙喇叭迷你4.0手機免提低音炮小音響  None   922.0
# 1406     【批發價現貨】索愛 S-52無線藍牙音箱迷你低音炮創意便攜音響插卡戶外手機音響  None  1327.0
# ...

# %%
frame4.to_csv(output_file_path + 'Get Banned Listing TW.csv', sep=',')
