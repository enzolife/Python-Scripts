# %%
import csv
import gspread
import urllib
import codecs

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = [
    'https://spreadsheets.google.com/feeds',
    'https://www.googleapis.com/auth/drive'
]

credentials = ServiceAccountCredentials.from_json_keyfile_name("Enzo Test Project-ea5529b41c25.json", scope)

gc = gspread.authorize(credentials)

# sh = gc.create('2017.5.26 Test Google Sheet')

# sh.share('enzo.kuang@shopeemobile.com', perm_type='user', role='writer')

# %%
# 打开Seller Index by Key
seller_index = gc.open_by_key('1VLYS6XmEjiI9UBEx4cG8YaBbAXDkTvoPc9NJb-m6ECQ')

# %%
worksheet = seller_index.sheet1

# %%
list_of_lists = worksheet.get_all_values()
list_of_lists
# Out:
# [['Site',
#   'Seller name',
#   'Shop id',
#   'Shop url',
#   'PIC',
#   'Update date',
#   'Holiday Mode?'],
#  ['SG',
#   'imecentury.sg',
#   '15566342',
#   'http://shopee.sg/imecentury.sg',
#   'Vicky',
#   '2/7/2017',
#   ''],
#  ['SG',
#   'mooncase01.sg',
#   '16246585',
#   'http://shopee.sg/mooncase01.sg',
#   'Ruby',
#   '2/7/2017',
#   ''],
#  ['SG',
#   'lovelybaby.sg',
#   '15056251',
#   'http://shopee.sg/lovelybaby.sg',
#   'Jun',
#   '2/8/2017',
#   ''],
#  ['SG',
#   'miuco.sg',
#   '15386575',
#   'http://shopee.sg/miuco.sg',
#   'Yoyo',
#   '2/8/2017',
#   ''],
#  ['SG',
#   'wishlove.sg',
#   '15055507',
#   'http://shopee.sg/wishlove.sg',
#   'Jun',
#   '2/9/2017',
#   ''],
#  ['SG',
#   'beautyinus.sg',
#   '16023074',
#   'http://shopee.sg/beautyinus.sg',
#   '',
#   '2/9/2017',
#   ''],
#  ['SG',
#   'successfulman.sg',
#   '14333041',
#   'http://shopee.sg/successfulman.sg',
#   'Ruby',
#   '2/10/2017',
#   ''],
#  ['SG',
#   'chishengda.sg',
#   '14947513',
#   'http://shopee.sg/chishengda.sg',
#   'Ki',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'successdc.sg',
#   '15055397',
#   'http://shopee.sg/successdc.sg',
#   'Jun',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'hotsale.sg',
#   '15055522',
#   'http://shopee.sg/hotsale.sg',
#   'Jun',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'steadyup.sg',
#   '15055548',
#   'http://shopee.sg/steadyup.sg',
#   'Jun',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'dcstore.sg',
#   '15055572',
#   'http://shopee.sg/dcstore.sg',
#   'Jun',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'beautylife.sg',
#   '16297393',
#   'http://shopee.sg/beautylife.sg',
#   'Jun',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'healthsports.sg',
#   '16297808',
#   'http://shopee.sg/healthsports.sg',
#   'Jun',
#   '2/11/2017',
#   ''],
#  ['SG',
#   'greenworld.sg',
#   '14953674',
#   'http://shopee.sg/greenworld.sg',
#   'Ruby',
#   '2/14/2017',
#   ''],
#  ['SG',
#   'cinderella.sg',
#   '15037005',
#   'http://shopee.sg/cinderella.sg',
#   'Ki',
#   '2/14/2017',
#   ''],
#  ['SG',
#   'variqueen.sg',
#   '9886045',
#   'http://shopee.sg/variqueen.sg',
#   'Ivan',
#   '2/15/2017',
#   ''],
#  ['SG',
#   'precious2all.sg',
#   '14939090',
#   'http://shopee.sg/precious2all.sg',
#   'Eason',
#   '2/15/2017',
#   ''],
#  ['SG',
#   'hotwind.sg',
#   '16174997',
#   'http://shopee.sg/hotwind.sg',
#   'Ivan',
#   '2/15/2017',
#   ''],
#  ['SG',
#   'dailyforu.sg',
#   '16586175',
#   'http://shopee.sg/dailyforu.sg',
#   'Vicky',
#   '2/15/2017',
#   ''],
#  ['SG',
#   'healthylife.sg',
#   '9886018',
#   'http://shopee.sg/healthylife.sg',
#   'Ivan',
#   '2/16/2017',
#   ''],
#  ['SG',
#   'vigorous.sg',
#   '15520032',
#   'http://shopee.sg/vigorous.sg',
#   'Chloe',
#   '2/16/2017',
#   ''],
#  ['SG',
#   'bestlink.sg',
#   '16175676',
#   'http://shopee.sg/bestlink.sg',
#   'Ivan',
#   '2/16/2017',
#   ''],
#  ['SG',
#   'shiyi.sg',
#   '14942049',
#   'http://shopee.sg/shiyi.sg',
#   'Ki',
#   '2/18/2017',
#   ''],
#  ['SG',
#   'choetech.sg',
#   '16393415',
#   'http://shopee.sg/choetech.sg',
#   'Mango',
#   '2/18/2017',
#   ''],
#  ['SG',
#   'bigbear.sg',
#   '14420689',
#   'http://shopee.sg/bigbear.sg',
#   'Joanne',
#   '2/17/2017',
#   ''],
#  ['SG',
#   'fibeauty.sg',
#   '15611828',
#   'http://shopee.sg/fibeauty.sg',
#   'Nikki',
#   '2/17/2017',
#   ''],
#  ['SG',
#   'fashionicon.sg',
#   '16572352',
#   'http://shopee.sg/fashionicon.sg',
#   'Vicky',
#   '2/17/2017',
#   ''],
#  ['SG',
#   'sugarlemon.sg',
#   '16628952',
#   'http://shopee.sg/sugarlemon.sg',
#   'Erica',
#   '2/17/2017',
#   ''],
#  ['SG',
#   'haya2.sg',
#   '12466751',
#   'http://shopee.sg/haya2.sg',
#   'Ki',
#   '2/20/2017',
#   ''],
#  ['SG',
#   'mogge.sg',
#   '16678507',
#   'http://shopee.sg/mogge.sg',
#   'Ivan',
#   '2/20/2017',
#   ''],
#  ['SG',
#   'autumnam.sg',
#   '16732896',
#   'http://shopee.sg/autumnam.sg',
#   'Erica',
#   '2/20/2017',
#   ''],
#  ['SG',
#   'beautydream.sg',
#   '16192357',
#   'http://shopee.sg/beautydream.sg',
#   'Ivan',
#   '2/21/2017',
#   ''],
#  ['SG',
#   'fashionhub.sg',
#   '16666500',
#   'http://shopee.sg/fashionhub.sg',
#   'Ivan',
#   '2/21/2017',
#   ''],
#  ['SG',
#   'ristory.sg',
#   '16678397',
#   'http://shopee.sg/ristory.sg',
#   'Ivan',
#   '2/21/2017',
#   ''],
#  ['SG',
#   'noziroh.sg',
#   '16717625',
#   'http://shopee.sg/noziroh.sg',
#   'Ivan',
#   '2/21/2017',
#   ''],
#  ['SG',
#   'xindi.sg',
#   '16727174',
#   'http://shopee.sg/xindi.sg',
#   'Yoyo',
#   '2/21/2017',
#   ''],
#  ['SG',
#   'bigdealmarket.sg',
#   '16855601',
#   'http://shopee.sg/bigdealmarket.sg',
#   '0',
#   '2/21/2017',
#   ''],
#  ['SG',
#   'simplelife1.sg',
#   '14943685',
#   'http://shopee.sg/simplelife1.sg',
#   'Ki',
#   '2/22/2017',
#   ''],
#  ['SG',
#   'betterlif.sg',
#   '16666548',
#   'http://shopee.sg/betterlif.sg',
#   'Ivan',
#   '2/22/2017',
#   ''],
#  ['SG',
#   'dormoo.sg',
#   '15040407',
#   'http://shopee.sg/dormoo.sg',
#   'Ki',
#   '2/23/2017',
#   ''],
#  ['SG',
#   'livestar.sg',
#   '16678431',
#   'http://shopee.sg/livestar.sg',
#   'Ivan',
#   '2/23/2017',
#   ''],
#  ['SG',
#   'attracter.sg',
#   '16678453',
#   'http://shopee.sg/attracter.sg',
#   'Ivan',
#   '2/23/2017',
#   ''],
#  ['SG',
#   'liweiki.sg',
#   '16678492',
#   'http://shopee.sg/liweiki.sg',
#   'Ivan',
#   '2/23/2017',
#   ''],
#  ['SG',
#   'bigbigbox.sg',
#   '16727400',
#   'http://shopee.sg/bigbigbox.sg',
#   'Ivan',
#   '2/23/2017',
#   ''],
#  ['SG',
#   'a4zfashion.sg',
#   '17030357',
#   'http://shopee.sg/a4zfashion.sg',
#   'Jun',
#   '2/23/2017',
#   ''],
#  ['SG',
#   'newdress.sg',
#   '16521576',
#   'http://shopee.sg/newdress.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'beautymore.sg',
#   '16521631',
#   'http://shopee.sg/beautymore.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'hotwing.sg',
#   '16521644',
#   'http://shopee.sg/hotwing.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'onelife.sg',
#   '16521699',
#   'http://shopee.sg/onelife.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'liveeasy.sg',
#   '16521720',
#   'http://shopee.sg/liveeasy.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'relaxcity.sg',
#   '16521730',
#   'http://shopee.sg/relaxcity.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'jasmine.sg',
#   '16521738',
#   'http://shopee.sg/jasmine.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'fashionlist.sg',
#   '16523428',
#   'http://shopee.sg/fashionlist.sg',
#   'Cindy',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'fastrading.sg',
#   '16733588',
#   'http://shopee.sg/fastrading.sg',
#   'Jun',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'minitony.sg',
#   '16921053',
#   'http://shopee.sg/minitony.sg',
#   'Ki',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'lemonfashion.sg',
#   '16929300',
#   'http://shopee.sg/lemonfashion.sg',
#   'Vicky',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'missmiss.sg',
#   '17010931',
#   'http://shopee.sg/missmiss.sg',
#   'Echo',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'candyhouse.sg',
#   '17077805',
#   'http://shopee.sg/candyhouse.sg',
#   'Vicky',
#   '2/26/2017',
#   ''],
#  ['SG',
#   'bolonic.sg',
#   '12788257',
#   'http://shopee.sg/bolonic.sg',
#   'Jun',
#   '2/27/2017',
#   ''],
#  ['SG',
#   'primer.sg',
#   '14743565',
#   'http://shopee.sg/primer.sg',
#   'Eason',
#   '2/27/2017',
#   ''],
#  ['SG',
#   'griefgrocery.sg',
#   '16664632',
#   'http://shopee.sg/griefgrocery.sg',
#   'Vicky',
#   '2/27/2017',
#   ''],
#  ['SG',
#   'cofoemedical.sg',
#   '16587763',
#   'http://shopee.sg/cofoemedical.sg',
#   'Nikki',
#   '2/28/2017',
#   ''],
#  ['SG',
#   'seeven.sg',
#   '16969063',
#   'http://shopee.sg/seeven.sg',
#   'Ivan',
#   '2/28/2017',
#   ''],
#  ['SG',
#   'qyqz.sg',
#   '17032156',
#   'http://shopee.sg/qyqz.sg',
#   'Yoyo',
#   '2/28/2017',
#   ''],
#  ['SG',
#   'heyg.sg',
#   '17082132',
#   'http://shopee.sg/heyg.sg',
#   'Ivan',
#   '2/28/2017',
#   ''],
#  ['SG',
#   'delaman.sg',
#   '13495361',
#   'http://shopee.sg/delaman.sg',
#   'Jun',
#   '6/21/2017',
#   ''],
#  ['SG',
#   'tongtongstore.sg',
#   '14146522',
#   'http://shopee.sg/tongtongstore.sg',
#   'Ki',
#   '6/21/2017',
#   ''],
#  ['SG',
#   'topshop.sg',
#   '16909707',
#   'http://shopee.sg/topshop.sg',
#   'Vicky',
#   '6/21/2017',
#   ''],
#  ['SG',
#   'beverlymemory.sg',
#   '17230446',
#   'http://shopee.sg/beverlymemory.sg',
#   'Jolene',
#   '6/21/2017',
#   ''],
#  ['SG',
#   'leadingsea.sg',
#   '17281849',
#   'http://shopee.sg/leadingsea.sg',
#   'Joanne',
#   '6/21/2017',
#   ''],
#  ['SG',
#   'musiccenter.sg',
#   '17327769',
#   'http://shopee.sg/musiccenter.sg',
#   'Jun',
#   '6/21/2017',
#   ''],
#  ['SG',
#   'realfashion.sg',
#   '15047604',
#   'http://shopee.sg/realfashion.sg',
#   'Ki',
#   '3/2/2017',
#   ''],
#  ['SG',
#   'aoguhome.sg',
#   '17030485',
#   'http://shopee.sg/aoguhome.sg',
#   'Jun',
#   '3/2/2017',
#   ''],
#  ['SG',
#   'fashionyou.sg',
#   '17222609',
#   'http://shopee.sg/fashionyou.sg',
#   'Ivan',
#   '3/2/2017',
#   ''],
#  ['SG',
#   'ntwholesaleshop1.sg',
#   '17230954',
#   'http://shopee.sg/ntwholesaleshop1.sg',
#   'Yoyo',
#   '3/2/2017',
#   ''],
#  ['SG',
#   'ntwholesaleshop3.sg',
#   '17231091',
#   'http://shopee.sg/ntwholesaleshop3.sg',
#   'Yoyo',
#   '3/2/2017',
#   ''],
#  ['SG',
#   'ntwholesaleshop2.sg',
#   '17258765',
#   'http://shopee.sg/ntwholesaleshop2.sg',
#   'Yoyo',
#   '3/2/2017',
#   ''],
#  ['SG',
#   'onlymall.sg',
#   '17327696',
#   'http://shopee.sg/onlymall.sg',
#   'Jun',
#   '3/2/2017',
#   ''],
#  ['SG', 'al.sg', '17381012', 'http://shopee.sg/al.sg', 'Yoyo', '3/2/2017', ''],
#  ['SG',
#   'kitty.sg',
#   '15057736',
#   'http://shopee.sg/kitty.sg',
#   'Jun',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'starbox.sg',
#   '16521769',
#   'http://shopee.sg/starbox.sg',
#   'Cindy',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'kisswind.sg',
#   '16521783',
#   'http://shopee.sg/kisswind.sg',
#   'Cindy',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'styleroom.sg',
#   '16521793',
#   'http://shopee.sg/styleroom.sg',
#   'Cindy',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'fashionpeloman.sg',
#   '17327726',
#   'http://shopee.sg/fashionpeloman.sg',
#   'Jun',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'weshow.sg',
#   '17327874',
#   'http://shopee.sg/weshow.sg',
#   'Jun',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'street11.sg',
#   '17327907',
#   'http://shopee.sg/street11.sg',
#   'Jun',
#   '3/5/2017',
#   ''],
#  ['SG',
#   'smilebuy.sg',
#   '16296879',
#   'http://shopee.sg/smilebuy.sg',
#   'Jun',
#   '3/6/2017',
#   ''],
#  ['SG',
#   'givemefive.sg',
#   '17327845',
#   'http://shopee.sg/givemefive.sg',
#   'Jun',
#   '3/6/2017',
#   ''],
#  ['SG',
#   'nicewear.sg',
#   '14695339',
#   'http://shopee.sg/nicewear.sg',
#   'Jun',
#   '3/7/2017',
#   ''],
#  ['SG',
#   'surfing.sg',
#   '14695382',
#   'http://shopee.sg/surfing.sg',
#   'Jun',
#   '3/7/2017',
#   ''],
#  ['SG',
#   'xyabia.sg',
#   '17222358',
#   'http://shopee.sg/xyabia.sg',
#   'Bella',
#   '3/7/2017',
#   ''],
#  ['SG',
#   'musiccenter.sg',
#   '17327769',
#   'http://shopee.sg/musiccenter.sg',
#   'Jun',
#   '3/7/2017',
#   ''],
#  ['SG',
#   'tengling.sg',
#   '17382591',
#   'http://shopee.sg/tengling.sg',
#   'Yoyo',
#   '3/7/2017',
#   ''],
#  ['SG',
#   'ethinker.sg',
#   '17674339',
#   'http://shopee.sg/ethinker.sg',
#   'Cindy',
#   '3/9/2017',
#   ''],
#  ['SG',
#   'rosmarinus.sg',
#   '17705184',
#   'http://shopee.sg/rosmarinus.sg',
#   'Cindy',
#   '3/9/2017',
#   ''],
#  ['SG',
#   'aiwoko.sg',
#   '17819609',
#   'http://shopee.sg/aiwoko.sg',
#   'Erica',
#   '3/9/2017',
#   ''],
#  ['SG',
#   'redsun.sg',
#   '9501121',
#   'http://shopee.sg/redsun.sg',
#   'Echo',
#   '3/12/2017',
#   ''],
#  ['SG',
#   'ftd.co.sg',
#   '16735498',
#   'http://shopee.sg/ftd.co.sg',
#   'Andrea',
#   '3/12/2017',
#   ''],
#  ['SG',
#   'letsbay.sg',
#   '17713686',
#   'http://shopee.sg/letsbay.sg',
#   'Eason',
#   '3/12/2017',
#   ''],
#  ['SG',
#   'blingstreet.sg',
#   '16727847',
#   'http://shopee.sg/blingstreet.sg',
#   'Ivan',
#   '3/13/2017',
#   ''],
#  ['SG',
#   'sjjh.sg',
#   '17855518',
#   'http://shopee.sg/sjjh.sg',
#   'Joanne',
#   '3/13/2017',
#   ''],
#  ['SG',
#   'antshouse.sg',
#   '17908751',
#   'http://shopee.sg/antshouse.sg',
#   'Nikki',
#   '3/13/2017',
#   ''],
#  ['SG',
#   'raitron.sg',
#   '13682255',
#   'http://shopee.sg/raitron.sg',
#   'Jun',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'loveshop.sg',
#   '14063759',
#   'http://shopee.sg/loveshop.sg',
#   'Cindy',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'minilocoker.sg',
#   '14592310',
#   'http://shopee.sg/minilocoker.sg',
#   'Vicky',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'maotai.sg',
#   '17013133',
#   'http://shopee.sg/maotai.sg',
#   'Ki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'sports.sg',
#   '17013164',
#   'http://shopee.sg/sports.sg',
#   'Ki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'weidaodao.sg',
#   '17013217',
#   'http://shopee.sg/weidaodao.sg',
#   'Ki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'lululemon.sg',
#   '17013234',
#   'http://shopee.sg/lululemon.sg',
#   'Ki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'uatribe.sg',
#   '17013266',
#   'http://shopee.sg/uatribe.sg',
#   'Ki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'jack8.sg',
#   '17013307',
#   'http://shopee.sg/jack8.sg',
#   'Ki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'suncity.sg',
#   '17370632',
#   'http://shopee.sg/suncity.sg',
#   'Jolene',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'chaodama.sg',
#   '18102456',
#   'http://shopee.sg/chaodama.sg',
#   'Yoyo',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'seeio.sg',
#   '18103131',
#   'http://shopee.sg/seeio.sg',
#   'Ivan',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'bangbuy.sg',
#   '18108976',
#   'http://shopee.sg/bangbuy.sg',
#   'Nikki',
#   '3/14/2017',
#   ''],
#  ['SG',
#   'muitobom.sg',
#   '16687218',
#   'http://shopee.sg/muitobom.sg',
#   'Jun',
#   '3/15/2017',
#   ''],
#  ['SG',
#   'lakala.sg',
#   '17013332',
#   'http://shopee.sg/lakala.sg',
#   'Ki',
#   '3/15/2017',
#   ''],
#  ['SG',
#   'wanshida.sg',
#   '17013347',
#   'http://shopee.sg/wanshida.sg',
#   'Ki',
#   '3/15/2017',
#   ''],
#  ['SG',
#   'fish.sg',
#   '17393382',
#   'http://shopee.sg/fish.sg',
#   'Cody',
#   '3/15/2017',
#   ''],
#  ['SG',
#   'lego.sg',
#   '16538685',
#   'http://shopee.sg/lego.sg',
#   'Cindy',
#   '3/16/2017',
#   ''],
#  ['SG',
#   'lancaihe01.sg',
#   '16614405',
#   'http://shopee.sg/lancaihe01.sg',
#   'Ki',
#   '3/16/2017',
#   ''],
#  ['SG',
#   'hawana.sg',
#   '17013385',
#   'http://shopee.sg/hawana.sg',
#   'Ki',
#   '3/16/2017',
#   ''],
#  ['SG',
#   'yijiele.sg',
#   '17013407',
#   'http://shopee.sg/yijiele.sg',
#   'Ki',
#   '3/16/2017',
#   ''],
#  ['SG',
#   'fashiongoing.sg',
#   '17640988',
#   'http://shopee.sg/fashiongoing.sg',
#   'Cindy',
#   '3/16/2017',
#   ''],
#  ['SG',
#   'autohome.sg',
#   '15611816',
#   'http://shopee.sg/autohome.sg',
#   'Nikki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'beautystarting.sg',
#   '16174733',
#   'http://shopee.sg/beautystarting.sg',
#   'Ivan',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'showmestyle.sg',
#   '16175315',
#   'http://shopee.sg/showmestyle.sg',
#   'Ivan',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'forevergo.sg',
#   '16175883',
#   'http://shopee.sg/forevergo.sg',
#   'Ivan',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'lancaihe02.sg',
#   '16614684',
#   'http://shopee.sg/lancaihe02.sg',
#   'Ki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'lancaihe03.sg',
#   '16614827',
#   'http://shopee.sg/lancaihe03.sg',
#   'Ki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'lancaihe04.sg',
#   '16614914',
#   'http://shopee.sg/lancaihe04.sg',
#   'Ki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'lancaihe05.sg',
#   '16615401',
#   'http://shopee.sg/lancaihe05.sg',
#   'Ki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'burgesss.sg',
#   '17447906',
#   'http://shopee.sg/burgesss.sg',
#   'Nikki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'allwish.sg',
#   '17918802',
#   'http://shopee.sg/allwish.sg',
#   'Ki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'monking.sg',
#   '17922709',
#   'http://shopee.sg/monking.sg',
#   'Nikki',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'fjrsl.sg',
#   '17924554',
#   'http://shopee.sg/fjrsl.sg',
#   'Ivan',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'redhithot.sg',
#   '18256447',
#   'http://shopee.sg/redhithot.sg',
#   'Vicky',
#   '3/19/2017',
#   ''],
#  ['SG',
#   'lego.sg',
#   '16538685',
#   'http://shopee.sg/lego.sg',
#   'Cindy',
#   '3/20/2017',
#   ''],
#  ['SG',
#   'colorfulgorgeous.sg',
#   '16634872',
#   'http://shopee.sg/colorfulgorgeous.sg',
#   'Erica',
#   '3/20/2017',
#   ''],
#  ['SG',
#   'yuansheng.sg',
#   '18183668',
#   'http://shopee.sg/yuansheng.sg',
#   'Chloe',
#   '3/20/2017',
#   ''],
#  ['SG',
#   'ourui.sg',
#   '18291454',
#   'http://shopee.sg/ourui.sg',
#   'Boey',
#   '3/20/2017',
#   ''],
#  ['SG',
#   'haku.sg',
#   '17613795',
#   'http://shopee.sg/haku.sg',
#   'Yoyo',
#   '3/21/2017',
#   ''],
#  ['SG',
#   'orchiddirect.sg',
#   '18255338',
#   'http://shopee.sg/orchiddirect.sg',
#   'Ruby',
#   '3/21/2017',
#   ''],
#  ['SG',
#   'swrose.sg',
#   '18316510',
#   'http://shopee.sg/swrose.sg',
#   'Jun',
#   '3/21/2017',
#   ''],
#  ['SG',
#   'outletstore.sg',
#   '18556965',
#   'http://shopee.sg/outletstore.sg',
#   'Ivan',
#   '3/21/2017',
#   ''],
#  ['SG',
#   'happyshopee.sg',
#   '18584105',
#   'http://shopee.sg/happyshopee.sg',
#   'Andrea',
#   '3/21/2017',
#   ''],
#  ['SG',
#   'cayxin.sg',
#   '18172411',
#   'http://shopee.sg/cayxin.sg',
#   'Ivan',
#   '3/22/2017',
#   ''],
#  ['SG',
#   'mornflystore.sg',
#   '18231101',
#   'http://shopee.sg/mornflystore.sg',
#   'Andrea',
#   '3/22/2017',
#   ''],
#  ['SG',
#   'jichuan.sg',
#   '18627164',
#   'http://shopee.sg/jichuan.sg',
#   'Yoyo',
#   '3/22/2017',
#   ''],
#  ['SG',
#   'aibel.sg',
#   '16538395',
#   'http://shopee.sg/aibel.sg',
#   'Cindy',
#   '3/23/2017',
#   ''],
#  ['SG',
#   'hkda.sg',
#   '18172479',
#   'http://shopee.sg/hkda.sg',
#   'Ivan',
#   '3/23/2017',
#   ''],
#  ['SG',
#   'epathchinastore.sg',
#   '18312507',
#   'http://shopee.sg/epathchinastore.sg',
#   'Andrea',
#   '3/23/2017',
#   ''],
#  ['SG',
#   'yohoostore.sg',
#   '18654294',
#   'http://shopee.sg/yohoostore.sg',
#   'Joanne',
#   '3/23/2017',
#   ''],
#  ['SG',
#   'shopay.sg',
#   '16538256',
#   'http://shopee.sg/shopay.sg',
#   'Cindy',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'ustyle.sg',
#   '16538370',
#   'http://shopee.sg/ustyle.sg',
#   'Cindy',
#   '3/26/2017',
#   ''],
#  ['OU',
#   'fashionyou',
#   '17089992',
#   'http://shopee.sg/fashionyou',
#   'Ivan',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'bestyi.sg',
#   '18172562',
#   'http://shopee.sg/bestyi.sg',
#   'Ivan',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'huanchi888.sg',
#   '18775602',
#   'http://shopee.sg/huanchi888.sg',
#   'Chloe',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'newwings.sg',
#   '18799352',
#   'http://shopee.sg/newwings.sg',
#   'Jolene',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'kaixi.sg',
#   '18172522',
#   'http://shopee.sg/kaixi.sg',
#   'Ivan',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'cortana.sg',
#   '18864879',
#   'http://shopee.sg/cortana.sg',
#   'Ruby',
#   '3/26/2017',
#   ''],
#  ['SG',
#   'matwin.sg',
#   '18172607',
#   'http://shopee.sg/matwin.sg',
#   'Ivan',
#   '3/27/2017',
#   ''],
#  ['SG',
#   'chancecatch.sg',
#   '18584244',
#   'http://shopee.sg/chancecatch.sg',
#   'Vicky',
#   '3/27/2017',
#   ''],
#  ['SG',
#   'crystal.sg',
#   '18784557',
#   'http://shopee.sg/crystal.sg',
#   'Ki',
#   '3/27/2017',
#   ''],
#  ['SG',
#   'thebest.sg',
#   '18784651',
#   'http://shopee.sg/thebest.sg',
#   'Ki',
#   '3/27/2017',
#   ''],
#  ['SG',
#   'fourseason.sg',
#   '18784700',
#   'http://shopee.sg/fourseason.sg',
#   'Ki',
#   '3/27/2017',
#   ''],
#  ['SG',
#   'ledmall.sg',
#   '13496573',
#   'http://shopee.sg/ledmall.sg',
#   'Jun',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'lovewonder.sg',
#   '17906400',
#   'http://shopee.sg/lovewonder.sg',
#   'cindy',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'shop4fun1.sg',
#   '17914656',
#   'http://shopee.sg/shop4fun1.sg',
#   'Yoyo',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'sunway.sg',
#   '18568884',
#   'http://shopee.sg/sunway.sg',
#   'Boey',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'beginning.sg',
#   '18784747',
#   'http://shopee.sg/beginning.sg',
#   'Ki',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'writea.sg',
#   '18784836',
#   'http://shopee.sg/writea.sg',
#   'Ki',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'fivehappy.sg',
#   '18785062',
#   'http://shopee.sg/fivehappy.sg',
#   'Ki',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'cheerful.sg',
#   '18785091',
#   'http://shopee.sg/cheerful.sg',
#   'Ki',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'qiqimall.sg',
#   '19041109',
#   'http://shopee.sg/qiqimall.sg',
#   'Nikki',
#   '3/28/2017',
#   ''],
#  ['SG',
#   'ilovs.sg',
#   '10169225',
#   'http://shopee.sg/ilovs.sg',
#   'Vicky',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'superseller.sg',
#   '12662873',
#   'http://shopee.sg/superseller.sg',
#   'Cindy',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'sicilypee.sg',
#   '18171678',
#   'http://shopee.sg/sicilypee.sg',
#   'Ruby',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'jcube.sg',
#   '18322925',
#   'http://shopee.sg/jcube.sg',
#   'Jun',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'kaforever.sg',
#   '18560901',
#   'http://shopee.sg/kaforever.sg',
#   'Ivan',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'forthefu.sg',
#   '18784874',
#   'http://shopee.sg/forthefu.sg',
#   'Ki',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'trustyou.sg',
#   '18784939',
#   'http://shopee.sg/trustyou.sg',
#   'Ki',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'companion.sg',
#   '18784986',
#   'http://shopee.sg/companion.sg',
#   'Ki',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'topmen.sg',
#   '18789051',
#   'http://shopee.sg/topmen.sg',
#   'Andrea',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'yyjack.sg',
#   '19068187',
#   'http://shopee.sg/yyjack.sg',
#   'Vicky',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'kklucy.sg',
#   '19130517',
#   'http://shopee.sg/kklucy.sg',
#   'Vicky',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'kakalucky.sg',
#   '19130939',
#   'http://shopee.sg/kakalucky.sg',
#   'Vicky',
#   '3/29/2017',
#   ''],
#  ['SG',
#   'eworld.sg',
#   '9885980',
#   'http://shopee.sg/eworld.sg',
#   'Ivan',
#   '3/30/2017',
#   ''],
#  ['SG',
#   'zztim.sg',
#   '18162078',
#   'http://shopee.sg/zztim.sg',
#   'Vicky',
#   '3/30/2017',
#   ''],
#  ['SG',
#   'tiangang.sg',
#   '18185692',
#   'http://shopee.sg/tiangang.sg',
#   'Chloe',
#   '3/30/2017',
#   ''],
#  ['SG',
#   'wonderfulstarmerx.sg',
#   '19063555',
#   'http://shopee.sg/wonderfulstarmerx.sg',
#   'Nikki',
#   '3/30/2017',
#   ''],
#  ['SG',
#   'pretty.sg',
#   '19188903',
#   'http://shopee.sg/pretty.sg',
#   'Ivan',
#   '3/30/2017',
#   ''],
#  ['SG',
#   'tangxia.sg',
#   '19279992',
#   'http://shopee.sg/tangxia.sg',
#   'Jolene',
#   '3/30/2017',
#   ''],
#  ['SG',
#   'ok360.sg',
#   '18634583',
#   'http://shopee.sg/ok360.sg',
#   'Andrea',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'focus.sg',
#   '18798274',
#   'http://shopee.sg/focus.sg',
#   'Bella',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'hahatop.sg',
#   '19129545',
#   'http://shopee.sg/hahatop.sg',
#   'Andrea',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'dadatop.sg',
#   '19131303',
#   'http://shopee.sg/dadatop.sg',
#   'Vicky',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'cardcool.sg',
#   '19184094',
#   'http://shopee.sg/cardcool.sg',
#   'Jolene',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'jiayi.sg',
#   '19210127',
#   'http://shopee.sg/jiayi.sg',
#   'Boey',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'blairshop.sg',
#   '19353970',
#   'http://shopee.sg/blairshop.sg',
#   'Vicky',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'happinessstore.sg',
#   '19378239',
#   'http://shopee.sg/happinessstore.sg',
#   'Ruby',
#   '4/2/2017',
#   ''],
#  ['SG',
#   'yh1.sg',
#   '19208497',
#   'http://shopee.sg/yh1.sg',
#   'Yoyo',
#   '4/3/2017',
#   ''],
#  ['SG',
#   'demee.sg',
#   '15040902',
#   'http://shopee.sg/demee.sg',
#   'Ki',
#   '4/4/2017',
#   ''],
#  ['SG',
#   'pinkase.sg',
#   '15041532',
#   'http://shopee.sg/pinkase.sg',
#   'Ki',
#   '4/4/2017',
#   ''],
#  ['SG',
#   'huimeng.sg',
#   '19136149',
#   'http://shopee.sg/huimeng.sg',
#   'Ki',
#   '4/4/2017',
#   ''],
#  ['SG',
#   'clolorlife.sg',
#   '16521753',
#   'http://shopee.sg/clolorlife.sg',
#   'Cindy',
#   '4/5/2017',
#   ''],
#  ['SG',
#   'fashionlife.sg',
#   '18582351',
#   'http://shopee.sg/fashionlife.sg',
#   'Nikki',
#   '4/5/2017',
#   ''],
#  ['SG',
#   'yihang.sg',
#   '19147626',
#   'http://shopee.sg/yihang.sg',
#   'Eason',
#   '4/5/2017',
#   ''],
#  ['SG',
#   'folklore.sg',
#   '18794433',
#   'http://shopee.sg/folklore.sg',
#   'Ki',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'walkinhorizon.sg',
#   '18794513',
#   'http://shopee.sg/walkinhorizon.sg',
#   'Ki',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'fashionbeauty.sg',
#   '18796269',
#   'http://shopee.sg/fashionbeauty.sg',
#   'Ki',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'followsunflower.sg',
#   '18796328',
#   'http://shopee.sg/followsunflower.sg',
#   'Ki',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'somple.sg',
#   '19288272',
#   'http://shopee.sg/somple.sg',
#   'Boey',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'queenstyle.sg',
#   '19684837',
#   'http://shopee.sg/queenstyle.sg',
#   'Vicky',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'helin.sg',
#   '19750132',
#   'http://shopee.sg/helin.sg',
#   'Yoyo',
#   '4/6/2017',
#   ''],
#  ['SG',
#   'zhuiyi.sg',
#   '15236011',
#   'http://shopee.sg/zhuiyi.sg',
#   'Ki',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'happydays.sg',
#   '18794361',
#   'http://shopee.sg/happydays.sg',
#   'Ki',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'cicitop.sg',
#   '19131558',
#   'http://shopee.sg/cicitop.sg',
#   'Vicky',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'bibitop.sg',
#   '19401352',
#   'http://shopee.sg/bibitop.sg',
#   'Vicky',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'gcgctop.sg',
#   '19401619',
#   'http://shopee.sg/gcgctop.sg',
#   'Vicky',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'highways.sg',
#   '19779086',
#   'http://shopee.sg/highways.sg',
#   'Ki',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'gnzoe.sg',
#   '19839136',
#   'http://shopee.sg/gnzoe.sg',
#   'Bella',
#   '4/9/2017',
#   ''],
#  ['SG',
#   'haya4.sg',
#   '12466792',
#   'http://shopee.sg/haya4.sg',
#   'Ki',
#   '4/10/2017',
#   ''],
#  ['SG',
#   'ppmarket.sg',
#   '16304101',
#   'http://shopee.sg/ppmarket.sg',
#   'Joanne',
#   '4/10/2017',
#   ''],
#  ['SG',
#   'xuanbin.sg',
#   '18714867',
#   'http://shopee.sg/xuanbin.sg',
#   'Yoyo',
#   '4/10/2017',
#   ''],
#  ['SG',
#   'niceoldotcom.sg',
#   '18794475',
#   'http://shopee.sg/niceoldotcom.sg',
#   'Ki',
#   '4/10/2017',
#   ''],
#  ['SG',
#   'youmai.sg',
#   '19136525',
#   'http://shopee.sg/youmai.sg',
#   'Ki',
#   '4/10/2017',
#   ''],
#  ['SG',
#   'amelie.sg',
#   '20027861',
#   'http://shopee.sg/amelie.sg',
#   'Jolene',
#   '4/10/2017',
#   ''],
#  ['SG',
#   'gateway.sg',
#   '18798090',
#   'http://shopee.sg/gateway.sg',
#   'Eason',
#   '4/11/2017',
#   ''],
#  ['SG',
#   'ruifan.sg',
#   '18178845',
#   'http://shopee.sg/ruifan.sg',
#   'Ki',
#   '4/12/2017',
#   ''],
#  ['SG',
#   'joytownonline.sg',
#   '18796143',
#   'http://shopee.sg/joytownonline.sg',
#   'Ki',
#   '4/12/2017',
#   ''],
#  ['SG',
#   'fashiongirlstore.sg',
#   '19831684',
#   'http://shopee.sg/fashiongirlstore.sg',
#   'Nikki',
#   '4/12/2017',
#   ''],
#  ['SG',
#   'rongfu.sg',
#   '20045070',
#   'http://shopee.sg/rongfu.sg',
#   'Yoyo',
#   '4/12/2017',
#   ''],
#  ['SG',
#   'xiaoxiaoxing.sg',
#   '8604773',
#   'http://shopee.sg/xiaoxiaoxing.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'fanshang6.sg',
#   '12436011',
#   'http://shopee.sg/fanshang6.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'fanshang7.sg',
#   '12436257',
#   'http://shopee.sg/fanshang7.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'haya2.sg',
#   '12466751',
#   'http://shopee.sg/haya2.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'ourlover.sg',
#   '12787566',
#   'http://shopee.sg/ourlover.sg',
#   'Jun',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'bailingniao.sg',
#   '14061288',
#   'http://shopee.sg/bailingniao.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'luyou.sg',
#   '18648858',
#   'http://shopee.sg/luyou.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'rosycheek.sg',
#   '18794384',
#   'http://shopee.sg/rosycheek.sg',
#   'Ki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'kingplayers.sg',
#   '18852156',
#   'http://shopee.sg/kingplayers.sg',
#   'Jun',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'yinggg.sg',
#   '19135008',
#   'http://shopee.sg/yinggg.sg',
#   'Joanne',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'yh3.sg',
#   '19208617',
#   'http://shopee.sg/yh3.sg',
#   'Yoyo',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'cilicap.sg',
#   '19701788',
#   'http://shopee.sg/cilicap.sg',
#   'Vicky',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'ulove.sg',
#   '19768590',
#   'http://shopee.sg/ulove.sg',
#   'Shelly',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'newhopetree.sg',
#   '19849039',
#   'http://shopee.sg/newhopetree.sg',
#   'Boey',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'aiaitop.sg',
#   '20024976',
#   'http://shopee.sg/aiaitop.sg',
#   'Andrea',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'zrfashion.sg',
#   '20101639',
#   'http://shopee.sg/zrfashion.sg',
#   'Nikki',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'heydel.sg',
#   '20236367',
#   'http://shopee.sg/heydel.sg',
#   'Jolene',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'atmeet.sg',
#   '20242490',
#   'http://shopee.sg/atmeet.sg',
#   'Ivan',
#   '4/16/2017',
#   ''],
#  ['SG',
#   'easytake.sg',
#   '16521676',
#   'http://shopee.sg/easytake.sg',
#   'Cindy',
#   '4/17/2017',
#   ''],
#  ['SG',
#   'dumakids.sg',
#   '19058667',
#   'http://shopee.sg/dumakids.sg',
#   'Joanne',
#   '4/18/2017',
#   ''],
#  ['SG',
#   'yh2.sg',
#   '19208562',
#   'http://shopee.sg/yh2.sg',
#   'Yoyo',
#   '4/19/2017',
#   ''],
#  ['SG',
#   'ailigap.sg',
#   '19700312',
#   'http://shopee.sg/ailigap.sg',
#   'Vicky',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'bilibap.sg',
#   '19701563',
#   'http://shopee.sg/bilibap.sg',
#   'Vicky',
#   '4/21/2017',
#   ''],
#  ['SG',
#   'hodroad.sg',
#   '20041367',
#   'http://shopee.sg/hodroad.sg',
#   'Ki',
#   '4/22/2017',
#   ''],
#  ['SG',
#   'fancyocean.sg',
#   '20150784',
#   'http://shopee.sg/fancyocean.sg',
#   'Ruby',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'dlbbaby.sg',
#   '20179882',
#   'http://shopee.sg/dlbbaby.sg',
#   'Joanne',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'prettygal.sg',
#   '18845917',
#   'http://shopee.sg/prettygal.sg',
#   'Jun',
#   '4/18/2017',
#   ''],
#  ['SG',
#   'sunyoo.sg',
#   '19811528',
#   'http://shopee.sg/sunyoo.sg',
#   'Jun',
#   '4/18/2017',
#   ''],
#  ['SG',
#   'hyper3c.sg',
#   '20046450',
#   'http://shopee.sg/hyper3c.sg',
#   'Ivan',
#   '4/18/2017',
#   ''],
#  ['SG',
#   'beautyartisan.sg',
#   '17429452',
#   'http://shopee.sg/beautyartisan.sg',
#   'Jun',
#   '4/19/2017',
#   ''],
#  ['SG',
#   'dreamworld.sg',
#   '18584284',
#   'http://shopee.sg/dreamworld.sg',
#   'Vicky',
#   '4/19/2017',
#   ''],
#  ['SG',
#   'jiaenbeauty.sg',
#   '19686714',
#   'http://shopee.sg/jiaenbeauty.sg',
#   'Jun',
#   '4/19/2017',
#   ''],
#  ['SG',
#   'weka.sg',
#   '19811306',
#   'http://shopee.sg/weka.sg',
#   'Jun',
#   '4/19/2017',
#   ''],
#  ['SG',
#   'topop.sg',
#   '13732930',
#   'http://shopee.sg/topop.sg',
#   'Erica',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'proudness.sg',
#   '16584620',
#   'http://shopee.sg/proudness.sg',
#   'Eason',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'fashionhub.sg',
#   '16666500',
#   'http://shopee.sg/fashionhub.sg',
#   'Ivan',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'eastwind.sg',
#   '18584335',
#   'http://shopee.sg/eastwind.sg',
#   'Vicky',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'topsdeals.sg',
#   '18797975',
#   'http://shopee.sg/topsdeals.sg',
#   'Boey',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'countless.sg',
#   '19051557',
#   'http://shopee.sg/countless.sg',
#   'Ki',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'fashionpark.sg',
#   '19051846',
#   'http://shopee.sg/fashionpark.sg',
#   'Ki',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'dreamtimes.sg',
#   '19068073',
#   'http://shopee.sg/dreamtimes.sg',
#   'Ki',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'oceanmaps.sg',
#   '19068115',
#   'http://shopee.sg/oceanmaps.sg',
#   'Ki',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'starshine.sg',
#   '19278045',
#   'http://shopee.sg/starshine.sg',
#   'Boey',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'beautyone.sg',
#   '20025878',
#   'http://shopee.sg/beautyone.sg',
#   'Cindy',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'kinostar.sg',
#   '20101539',
#   'http://shopee.sg/kinostar.sg',
#   'Nikki',
#   '4/20/2017',
#   ''],
#  ['SG',
#   'pawchinaworkshop.sg',
#   '18560788',
#   'http://shopee.sg/pawchinaworkshop.sg',
#   'Boey',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'buyou.sg',
#   '18653683',
#   'http://shopee.sg/buyou.sg',
#   'Ki',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'happydeals.sg',
#   '19067238',
#   'http://shopee.sg/happydeals.sg',
#   'Ki',
#   '4/23/2017',
#   ''],
#  ['SG',
#   '3chilce.sg',
#   '19709275',
#   'http://shopee.sg/3chilce.sg',
#   'Vicky',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'geeka.sg',
#   '19811109',
#   'http://shopee.sg/geeka.sg',
#   'Jun',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'homee.sg',
#   '19811463',
#   'http://shopee.sg/homee.sg',
#   'Jun',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'lagom.sg',
#   '20038486',
#   'http://shopee.sg/lagom.sg',
#   'Joanne',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'dkases.sg',
#   '20290405',
#   'http://shopee.sg/dkases.sg',
#   'Ki',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'gocases.sg',
#   '20290514',
#   'http://shopee.sg/gocases.sg',
#   'Ki',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'xindi1.sg',
#   '20587401',
#   'http://shopee.sg/xindi1.sg',
#   'Yoyo',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'outerinner.sg',
#   '20746917',
#   'http://shopee.sg/outerinner.sg',
#   'Yoyo',
#   '4/23/2017',
#   ''],
#  ['SG',
#   'shinyheaven.sg',
#   '18796234',
#   'http://shopee.sg/shinyheaven.sg',
#   'Ki',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'anything4.sg',
#   '19051942',
#   'http://shopee.sg/anything4.sg',
#   'Ki',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'rebunestore.sg',
#   '19054826',
#   'http://shopee.sg/rebunestore.sg',
#   'Joanne',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'merryeveryday.sg',
#   '19067307',
#   'http://shopee.sg/merryeveryday.sg',
#   'Ki',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'laigou.sg',
#   '19128526',
#   'http://shopee.sg/laigou.sg',
#   'Ivan',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'yh4.sg',
#   '19208700',
#   'http://shopee.sg/yh4.sg',
#   'Yoyo',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'hellobaby.sg',
#   '20179540',
#   'http://shopee.sg/hellobaby.sg',
#   'Joanne',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'rosyshop.sg',
#   '20290465',
#   'http://shopee.sg/rosyshop.sg',
#   'Ki',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'milkyway.sg',
#   '20290488',
#   'http://shopee.sg/milkyway.sg',
#   'Ki',
#   '4/24/2017',
#   ''],
#  ['SG',
#   'usabrandshop',
#   '5917974',
#   'http://shopee.sg/usabrandshop',
#   'Jolene',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'fantasyisland.sg',
#   '18584363',
#   'http://shopee.sg/fantasyisland.sg',
#   'Vicky',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'izzyouth.sg',
#   '19068020',
#   'http://shopee.sg/izzyouth.sg',
#   'Ki',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'coobuy.sg',
#   '19216692',
#   'http://shopee.sg/coobuy.sg',
#   'Ivan',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'chasingtrendshop.sg',
#   '20242999',
#   'http://shopee.sg/chasingtrendshop.sg',
#   'Nikki',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'fashionista.sg',
#   '20291687',
#   'http://shopee.sg/fashionista.sg',
#   'Ki',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'enjelwang.sg',
#   '20947096',
#   'http://shopee.sg/enjelwang.sg',
#   'Bella',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'tipoo.sg',
#   '20950600',
#   'http://shopee.sg/tipoo.sg',
#   'Chloe',
#   '4/25/2017',
#   ''],
#  ['SG',
#   'shoppnew.sg',
#   '19051363',
#   'http://shopee.sg/shoppnew.sg',
#   'Ki',
#   '4/26/2017',
#   ''],
#  ['SG',
#   'elife.sg',
#   '19771171',
#   'http://shopee.sg/elife.sg',
#   'Shelly',
#   '4/26/2017',
#   ''],
#  ['SG',
#   'limitstyle.sg',
#   '18755248',
#   'http://shopee.sg/limitstyle.sg',
#   '0',
#   '4/27/2017',
#   ''],
#  ['SG',
#   'superecho.sg',
#   '19051757',
#   'http://shopee.sg/superecho.sg',
#   'Ki',
#   '4/27/2017',
#   ''],
#  ['SG',
#   'semile.sg',
#   '19061672',
#   'http://shopee.sg/semile.sg',
#   'Jun',
#   '4/27/2017',
#   ''],
#  ['SG',
#   'cardcool.sg',
#   '19184094',
#   'http://shopee.sg/cardcool.sg',
#   'Jolene',
#   '4/27/2017',
#   ''],
#  ['SG',
#   'newbuy.sg',
#   '19773171',
#   'http://shopee.sg/newbuy.sg',
#   'Shelly',
#   '4/27/2017',
#   ''],
#  ['SG',
#   'zada.sg',
#   '18378421',
#   'http://shopee.sg/zada.sg',
#   'Vicky',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'happybuynow.sg',
#   '20476788',
#   'http://shopee.sg/happybuynow.sg',
#   'Jun',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'mamibaby.sg',
#   '20938552',
#   'http://shopee.sg/mamibaby.sg',
#   'Eason',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'longluoyun.sg',
#   '21025183',
#   'http://shopee.sg/longluoyun.sg',
#   'Ki',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'zhenxiang.sg',
#   '21077983',
#   'http://shopee.sg/zhenxiang.sg',
#   'Yoyo',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'zhenxiang1.sg',
#   '21078098',
#   'http://shopee.sg/zhenxiang1.sg',
#   'Yoyo',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'zhenxiang2.sg',
#   '21078229',
#   'http://shopee.sg/zhenxiang2.sg',
#   'Yoyo',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'leefens.sg',
#   '21088866',
#   'http://shopee.sg/leefens.sg',
#   'Joanne',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'craftseries.sg',
#   '21222675',
#   'http://shopee.sg/craftseries.sg',
#   'Ivan',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'magicalstarmerx.sg',
#   '21253984',
#   'http://shopee.sg/magicalstarmerx.sg',
#   'Nikki',
#   '5/1/2017',
#   ''],
#  ['SG',
#   'topone3.sg',
#   '19053615',
#   'http://shopee.sg/topone3.sg',
#   'Yoyo',
#   '5/2/2017',
#   ''],
#  ['SG',
#   'dreamforest.sg',
#   '21222538',
#   'http://shopee.sg/dreamforest.sg',
#   'Ivan',
#   '5/3/2017',
#   ''],
#  ['SG',
#   'kaizenauto.sg',
#   '21596718',
#   'http://shopee.sg/kaizenauto.sg',
#   'Ivan',
#   '5/3/2017',
#   ''],
#  ['SG',
#   'ciaoxshop.sg',
#   '21090868',
#   'http://shopee.sg/ciaoxshop.sg',
#   'Joanne',
#   '5/4/2017',
#   '55'],
#  ['SG',
#   'fairytales.sg',
#   '21222794',
#   'http://shopee.sg/fairytales.sg',
#   'Ivan',
#   '5/4/2017',
#   '91'],
#  ['SG',
#   'smilemall.sg',
#   '19847054',
#   'http://shopee.sg/smilemall.sg',
#   'Jun',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'fairmart.sg',
#   '20725721',
#   'http://shopee.sg/fairmart.sg',
#   'Cindy',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'hongkongmall.sg',
#   '21004222',
#   'http://shopee.sg/hongkongmall.sg',
#   'Vicky',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'chicsummer.sg',
#   '21222256',
#   'http://shopee.sg/chicsummer.sg',
#   'Ivan',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'yitong.sg',
#   '21222906',
#   'http://shopee.sg/yitong.sg',
#   'Bella',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'smartsimple.sg',
#   '21223127',
#   'http://shopee.sg/smartsimple.sg',
#   'Ivan',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'gameme.sg',
#   '21606058',
#   'http://shopee.sg/gameme.sg',
#   'Cindy',
#   '5/7/2017',
#   ''],
#  ['SG',
#   'coolfashion.sg',
#   '21980091',
#   'http://shopee.sg/coolfashion.sg',
#   'Ivan',
#   '5/8/2017',
#   ''],
#  ['SG',
#   'onsalezone.sg',
#   '21252442',
#   'http://shopee.sg/onsalezone.sg',
#   'Erica',
#   '5/10/2017',
#   ''],
#  ['SG',
#   'dimai.sg',
#   '21990852',
#   'http://shopee.sg/dimai.sg',
#   'Yoyo',
#   '5/10/2017',
#   ''],
#  ['SG',
#   'yd.sg',
#   '21991182',
#   'http://shopee.sg/yd.sg',
#   'Ivan',
#   '5/10/2017',
#   ''],
#  ['SG',
#   'fangda.sg',
#   '21533756',
#   'http://shopee.sg/fangda.sg',
#   'Yoyo',
#   '5/11/2017',
#   ''],
#  ['SG',
#   'louiwill.sg',
#   '20728438',
#   'http://shopee.sg/louiwill.sg',
#   'Nikki',
#   '5/14/2017',
#   ''],
#  ['SG',
#   'yinmenfashion.sg',
#   '20728477',
#   'http://shopee.sg/yinmenfashion.sg',
#   'Nikki',
#   '5/14/2017',
#   ''],
#  ['SG',
#   'starto.sg',
#   '21508218',
#   'http://shopee.sg/starto.sg',
#   'Chloe',
#   '5/15/2017',
#   ''],
#  ['SG',
#   'yishi.sg',
#   '21753193',
#   'http://shopee.sg/yishi.sg',
#   'Ki',
#   '5/15/2017',
#   ''],
#  ['SG',
#   'sbuycollection.sg',
#   '22069323',
#   'http://shopee.sg/sbuycollection.sg',
#   'Vicky',
#   '5/15/2017',
#   ''],
#  ['SG',
#   'qiners.sg',
#   '21964538',
#   'http://shopee.sg/qiners.sg',
#   'Evan',
#   '5/16/2017',
#   ''],
#  ['SG',
#   'txm.sg',
#   '21757274',
#   'http://shopee.sg/txm.sg',
#   'Nikki',
#   '5/17/2017',
#   ''],
#  ['SG',
#   'newbuy.sg',
#   '19773171',
#   'http://shopee.sg/newbuy.sg',
#   'Shelly',
#   '5/18/2017',
#   ''],
#  ['SG',
#   'adaloveshop.sg',
#   '20479777',
#   'http://shopee.sg/adaloveshop.sg',
#   'Joanne',
#   '5/18/2017',
#   ''],
#  ['SG',
#   'ifashion.sg',
#   '21757305',
#   'http://shopee.sg/ifashion.sg',
#   'Nikki',
#   '5/18/2017',
#   ''],
#  ['SG',
#   'qiners.sg',
#   '21964538',
#   'http://shopee.sg/qiners.sg',
#   'Evan',
#   '5/18/2017',
#   ''],
#  ['SG',
#   'babyanne.sg',
#   '22132975',
#   'http://shopee.sg/babyanne.sg',
#   'Ruby',
#   '5/18/2017',
#   ''],
#  ['SG',
#   'ceshi.sg',
#   '22559783',
#   'http://shopee.sg/ceshi.sg',
#   'Boey',
#   '5/18/2017',
#   ''],
#  ['SG',
#   'tianxia.sg',
#   '22587672',
#   'http://shopee.sg/tianxia.sg',
#   'Chloe',
#   '5/21/2017',
#   ''],
#  ['SG',
#   'ywny20150320.sg',
#   '22740857',
#   'http://shopee.sg/ywny20150320.sg',
#   'Bella',
#   '5/21/2017',
#   ''],
#  ['SG',
#   'easylife.sg',
#   '13744999',
#   'http://shopee.sg/easylife.sg',
#   'Jolene',
#   '5/22/2017',
#   ''],
#  ['SG',
#   'dilidap.sg',
#   '19702041',
#   'http://shopee.sg/dilidap.sg',
#   'Vicky',
#   '5/22/2017',
#   ''],
#  ['SG',
#   'yingshan.sg',
#   '20608618',
#   'http://shopee.sg/yingshan.sg',
#   'Ki',
#   '5/22/2017',
#   ''],
#  ['SG',
#   'oushinuo.sg',
#   '21755473',
#   'http://shopee.sg/oushinuo.sg',
#   'Evan',
#   '5/22/2017',
#   ''],
#  ['SG',
#   'maryxiao.sg',
#   '21992220',
#   'http://shopee.sg/maryxiao.sg',
#   'Joanne',
#   '5/22/2017',
#   ''],
#  ['SG',
#   'hy.sg',
#   '22499647',
#   'http://shopee.sg/hy.sg',
#   'Yoyo',
#   '5/22/2017',
#   ''],
#  ['SG',
#   'domybest.sg',
#   '19051912',
#   'http://shopee.sg/domybest.sg',
#   'Ki',
#   '5/23/2017',
#   ''],
#  ['SG',
#   'asleepsheep.sg',
#   '20675715',
#   'http://shopee.sg/asleepsheep.sg',
#   'Remy',
#   '5/23/2017',
#   ''],
#  ['SG',
#   'niel.sg',
#   '22293509',
#   'http://shopee.sg/niel.sg',
#   'Anita',
#   '5/23/2017',
#   ''],
#  ['SG',
#   'huanqiu.sg',
#   '22745304',
#   'http://shopee.sg/huanqiu.sg',
#   'Chloe',
#   '5/23/2017',
#   ''],
#  ['SG',
#   'topone.sg',
#   '11594731',
#   'http://shopee.sg/topone.sg',
#   'Cindy',
#   '5/24/2017',
#   ''],
#  ['SG',
#   'boutique520.sg',
#   '19051639',
#   'http://shopee.sg/boutique520.sg',
#   'Ki',
#   '5/24/2017',
#   ''],
#  ['SG',
#   'luckylolita.sg',
#   '19067193',
#   'http://shopee.sg/luckylolita.sg',
#   'Ki',
#   '5/24/2017',
#   ''],
#  ['SG',
#   'hiphoppie.sg',
#   '22220410',
#   'http://shopee.sg/hiphoppie.sg',
#   'Nikki',
#   '5/24/2017',
#   ''],
#  ['SG',
#   'hy1.sg',
#   '22499676',
#   'http://shopee.sg/hy1.sg',
#   'Yoyo',
#   '5/24/2017',
#   ''],
#  ['SG',
#   'zebraremember.sg',
#   '23042929',
#   'http://shopee.sg/zebraremember.sg',
#   'Shelly',
#   '5/24/2017',
#   ''],
#  ['SG',
#   'shankming.sg',
#   '9947223',
#   'http://shopee.sg/shankming.sg',
#   'Vicky',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'seashell02.sg',
#   '19067356',
#   'http://shopee.sg/seashell02.sg',
#   'Ki',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'magicmall01.sg',
#   '19067433',
#   'http://shopee.sg/magicmall01.sg',
#   'Ki',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'charlotty.sg',
#   '19067531',
#   'http://shopee.sg/charlotty.sg',
#   'Ki',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'kaymark.sg',
#   '21098053',
#   'http://shopee.sg/kaymark.sg',
#   'Anita',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'wonderfulmyth.sg',
#   '22662981',
#   'http://shopee.sg/wonderfulmyth.sg',
#   'Joanne',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'forbeautiful1.sg',
#   '23326134',
#   'http://shopee.sg/forbeautiful1.sg',
#   'Yoyo',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'shankming.sg',
#   '9947223',
#   'http://shopee.sg/shankming.sg',
#   'Vicky',
#   '5/25/2017',
#   ''],
#  ['SG',
#   'supermall.sg',
#   '11594262',
#   'http://shopee.sg/supermall.sg',
#   'Cindy',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'simplelife_2.sg',
#   '17695899',
#   'http://shopee.sg/simplelife_2.sg',
#   'Ki',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'simplelife_3.sg',
#   '17695927',
#   'http://shopee.sg/simplelife_3.sg',
#   'Ki',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'orfila.sg',
#   '19052512',
#   'http://shopee.sg/orfila.sg',
#   'Ki',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'st76088.sg',
#   '22575506',
#   'http://shopee.sg/st76088.sg',
#   'Chloe',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'ms.sg',
#   '22576164',
#   'http://shopee.sg/ms.sg',
#   'Ivan',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'luoyun.sg',
#   '23161006',
#   'http://shopee.sg/luoyun.sg',
#   'Ki',
#   '5/28/2017',
#   ''],
#  ['SG',
#   'nfy.sg',
#   '23255452',
#   'http://shopee.sg/nfy.sg',
#   'Chloe',
#   '5/29/2017',
#   ''],
#  ['SG',
#   'ylifestore.sg',
#   '19063519',
#   'http://shopee.sg/ylifestore.sg',
#   'Nikki',
#   '5/30/2017',
#   ''],
#  ['SG',
#   'bellare.sg',
#   '19067988',
#   'http://shopee.sg/bellare.sg',
#   'Ki',
#   '5/31/2017',
#   ''],
#  ['SG',
#   '1to9shopee.sg',
#   '21988721',
#   'http://shopee.sg/1to9shopee.sg',
#   'Boey',
#   '5/31/2017',
#   ''],
#  ['SG',
#   'youcai.sg',
#   '22756208',
#   'http://shopee.sg/youcai.sg',
#   'Evan',
#   '5/31/2017',
#   ''],
#  ['SG',
#   'goshopping.sg',
#   '23388216',
#   'http://shopee.sg/goshopping.sg',
#   'Vicky',
#   '5/31/2017',
#   ''],
#  ['SG',
#   'mokeybuy.sg',
#   '22065382',
#   'http://shopee.sg/mokeybuy.sg',
#   'Jun',
#   '6/1/2017',
#   ''],
#  ['SG',
#   'hy2.sg',
#   '22499714',
#   'http://shopee.sg/hy2.sg',
#   'Yoyo',
#   '6/1/2017',
#   ''],
#  ['SG',
#   'lalang.sg',
#   '23076960',
#   'http://shopee.sg/lalang.sg',
#   'Yoyo',
#   '6/1/2017',
#   ''],
#  ['SG',
#   'lalang1.sg',
#   '23077028',
#   'http://shopee.sg/lalang1.sg',
#   'Yoyo',
#   '6/1/2017',
#   ''],
#  ['SG',
#   'typhoon.sg',
#   '19051805',
#   'http://shopee.sg/typhoon.sg',
#   'Ki',
#   '6/4/2017',
#   ''],
#  ['SG',
#   'falifap.sg',
#   '19702263',
#   'http://shopee.sg/falifap.sg',
#   'Vicky',
#   '6/4/2017',
#   ''],
#  ['SG',
#   'luckyditto.sg',
#   '22061680',
#   'http://shopee.sg/luckyditto.sg',
#   'Jolene',
#   '6/4/2017',
#   ''],
#  ['SG', 'yt.sg', '22489728', 'http://shopee.sg/yt.sg', 'Ivan', '6/4/2017', ''],
#  ['SG',
#   'qwaa7766.sg',
#   '23233976',
#   'http://shopee.sg/qwaa7766.sg',
#   'Ki',
#   '6/4/2017',
#   ''],
#  ['SG',
#   'factoryoutlet.sg',
#   '23304655',
#   'http://shopee.sg/factoryoutlet.sg',
#   'Boey',
#   '6/4/2017',
#   ''],
#  ['SG',
#   'globallshop.sg',
#   '23918308',
#   'http://shopee.sg/globallshop.sg',
#   'Ivan',
#   '6/4/2017',
#   ''],
#  ['SG',
#   'feilixiangstore.sg',
#   '23934541',
#   'http://shopee.sg/feilixiangstore.sg',
#   'Ivan',
#   '6/4/2017',
#   ''],
#  ['SG',
#   'lovemyhome.sg',
#   '22072368',
#   'http://shopee.sg/lovemyhome.sg',
#   'Jun',
#   '6/5/2017',
#   ''],
#  ['SG',
#   'haiyue.sg',
#   '10245494',
#   'http://shopee.sg/haiyue.sg',
#   'Ki ',
#   '6/7/2017',
#   ''],
#  ['SG',
#   'angelcity123.sg',
#   '19051703',
#   'http://shopee.sg/angelcity123.sg',
#   'Ki ',
#   '6/7/2017',
#   ''],
#  ['SG',
#   'luckylolita.sg',
#   '19067193',
#   'http://shopee.sg/luckylolita.sg',
#   'Ki ',
#   '6/7/2017',
#   ''],
#  ['SG',
#   'molystyle.sg',
#   '21969619',
#   'http://shopee.sg/molystyle.sg',
#   'Evan ',
#   '6/7/2017',
#   ''],
#  ['SG',
#   'ly.sg',
#   '21976491',
#   'http://shopee.sg/ly.sg',
#   'Bella',
#   '6/8/2017',
#   ''],
#  ['SG',
#   'st76088.sg',
#   '22575506',
#   'http://shopee.sg/st76088.sg',
#   'Chloe',
#   '6/8/2017',
#   ''],
#  ['SG',
#   'emk668.sg',
#   '23079687',
#   'http://shopee.sg/emk668.sg',
#   'Richard',
#   '6/8/2017',
#   ''],
#  ['SG',
#   'jdalife.sg',
#   '24011481',
#   'http://shopee.sg/jdalife.sg',
#   'Joanne',
#   '6/8/2017',
#   ''],
#  ['SG',
#   'abuyt.sg',
#   '24676485',
#   'http://shopee.sg/abuyt.sg',
#   'Natalie',
#   '6/8/2017',
#   ''],
#  ['SG',
#   'trust13.sg',
#   '12488111',
#   'http://shopee.sg/trust13.sg',
#   'Echo ',
#   '6/11/2017',
#   ''],
#  ['SG',
#   'electronichome.sg',
#   '22069582',
#   'http://shopee.sg/electronichome.sg',
#   'Richard ',
#   '6/11/2017',
#   ''],
#  ['SG',
#   'pandamall.sg',
#   '22116292',
#   'http://shopee.sg/pandamall.sg',
#   'Richard ',
#   '6/11/2017',
#   ''],
#  ['SG',
#   'huixin123.sg',
#   '23255503',
#   'http://shopee.sg/huixin123.sg',
#   'Chloe ',
#   '6/11/2017',
#   ''],
#  ['SG',
#   'fashiondress.sg',
#   '23310614',
#   'http://shopee.sg/fashiondress.sg',
#   'Boey ',
#   '6/11/2017',
#   ''],
#  ['SG',
#   'besthylidge.sg',
#   '24013303',
#   'http://shopee.sg/besthylidge.sg',
#   'Joanne ',
#   '6/11/2017',
#   ''],
#  ['SG',
#   'gsld.sg',
#   '22111725',
#   'http://shopee.sg/gsld.sg',
#   'Yoyo ',
#   '6/12/2017',
#   ''],
#  ['SG',
#   'rinhoo.sg',
#   '22137378',
#   'http://shopee.sg/rinhoo.sg',
#   'Jun ',
#   '6/12/2017',
#   ''],
#  ['SG',
#   'kaith.sg',
#   '24759976',
#   'http://shopee.sg/kaith.sg',
#   'Joanne ',
#   '6/12/2017',
#   ''],
#  ['SG',
#   'xy.sg',
#   '21992902',
#   'http://shopee.sg/xy.sg',
#   'Ivan ',
#   '6/13/2017',
#   ''],
#  ['SG',
#   'goodnurse.sg',
#   '22658223',
#   'http://shopee.sg/goodnurse.sg',
#   'Natalie ',
#   '6/14/2017',
#   ''],
#  ['SG',
#   'glamshop.sg',
#   '25239958',
#   'http://shopee.sg/glamshop.sg',
#   'Jolene ',
#   '6/14/2017',
#   ''],
#  ['SG',
#   'marvogo.sg',
#   '20610909',
#   'http://shopee.sg/marvogo.sg',
#   'Phoebe ',
#   '6/15/2017',
#   ''],
#  ['SG',
#   'rzants21.sg',
#   '22808553',
#   'http://shopee.sg/rzants21.sg',
#   'Vicky ',
#   '6/15/2017',
#   ''],
#  ['SG',
#   'helin1.sg',
#   '23241564',
#   'http://shopee.sg/helin1.sg',
#   'Yoyo ',
#   '6/15/2017',
#   ''],
#  ['SG',
#   'bleamfly.sg',
#   '24923793',
#   'http://shopee.sg/bleamfly.sg',
#   'Anita ',
#   '6/15/2017',
#   ''],
#  ['SG',
#   'exceltarget.sg',
#   '5560589',
#   'http://shopee.sg/exceltarget.sg',
#   'Ki ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'bailingniao.sg',
#   '14061288',
#   'http://shopee.sg/bailingniao.sg',
#   'Ki ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'jt.sg',
#   '21992921',
#   'http://shopee.sg/jt.sg',
#   'Ivan ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'jm.sg',
#   '21992958',
#   'http://shopee.sg/jm.sg',
#   'Ivan ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'ky.sg',
#   '21992981',
#   'http://shopee.sg/ky.sg',
#   'Ivan ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'oc.sg',
#   '21993003',
#   'http://shopee.sg/oc.sg',
#   'Ivan ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'vstone.sg',
#   '24680502',
#   'http://shopee.sg/vstone.sg',
#   'Bella ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'toymall.sg',
#   '25465672',
#   'http://shopee.sg/toymall.sg',
#   'Shelly ',
#   '6/18/2017',
#   ''],
#  ['SG',
#   'fengcai.sg',
#   '23135652',
#   'http://shopee.sg/fengcai.sg',
#   'Boey ',
#   '6/19/2017',
#   ''],
#  ['SG',
#   'snzvok.sg',
#   '24037698',
#   'http://shopee.sg/snzvok.sg',
#   'Boey ',
#   '6/19/2017',
#   ''],
#  ['SG',
#   'alibato.sg',
#   '24912311',
#   'http://shopee.sg/alibato.sg',
#   'Shelly ',
#   '6/19/2017',
#   ''],
#  ['SG',
#   'aligoto.sg',
#   '25356139',
#   'http://shopee.sg/aligoto.sg',
#   'Shelly ',
#   '6/19/2017',
#   ''],
#  ['SG',
#   'alicimore.sg',
#   '25360311',
#   'http://shopee.sg/alicimore.sg',
#   'Shelly ',
#   '6/19/2017',
#   '']]

# %%
worksheet_list = seller_index.worksheets()
worksheet_list
# Out:
# [<Worksheet 'SG' id:od6>,
#  <Worksheet 'MY' id:owgbwec>,
#  <Worksheet 'SG_matching' id:o9y341b>,
#  <Worksheet 'TH_matching' id:oahqdmj>,
#  <Worksheet 'ID_matching' id:odxf3d7>,
#  <Worksheet 'TW' id:onscglr>,
#  <Worksheet 'ID' id:oyxgkns>,
#  <Worksheet 'TH' id:oe3lwr0>,
#  <Worksheet 'testing' id:ow64koh>,
#  <Worksheet 'Working Sheet' id:on9jnwc>,
#  <Worksheet 'Reporting Format' id:ofcou8v>,
#  <Worksheet 'Seller_index' id:ol96uxo>,
#  <Worksheet 'Not on Seller Index' id:oxcvpxw>,
#  <Worksheet 'Sellerindex_TW' id:o34ns6s>,
#  <Worksheet 'Sellerindex_MY' id:ow102t9>]

# %%
docs = [
    {"doc":"New Shop Tracker"}
    ]
path = 'D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\' \
       'Shopee 2016.4.12\\2016.8.28 Seller Index Data\\'

# %%
#process doc list
for doc in docs:
    spreadsheet = gc.open(doc["doc"])
    for i, worksheet in enumerate(spreadsheet.worksheets()):
        if worksheet.title == 'SG':
            filename = path + doc["doc"] + '-worksheet' + str(i) + '.csv'
            # newline = ''这部分，请参考evernote: 
            # For use with the csv module, the Python 3 open should also have newline='' as a parameter [ref]
            with open(filename, 'w', newline='') as f:
                writer = csv.writer(f)
                content = worksheet.get_all_values()
                for row in content:
                    new_row=[]
                    for record in row:
                        new_row.append(record)
                    try:
                        writer.writerow(new_row)
                    except (UnicodeEncodeError, UnicodeDecodeError):
                        print ("Caught unicode error")
            print ('== Finished Writing: ' + filename + ' ==')
print ('====== FINISHED ======')
# Out:
# == Finished Writing: D:\Program Files (x86)\百度云同步盘\Dropbox\Shopee 2016.4.12\2016.8.28 Seller Index Data\New Shop Tracker-worksheet0.csv ==
# ====== FINISHED ======
