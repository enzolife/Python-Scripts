# %%
import pip
from subprocess import call
 
for dist in pip.get_installed_distributions():
    call("pip install --upgrade " + dist.project_name, shell=True)
    print('%s is updated' % dist.project_name)
# Out:
# xlwt is updated
# xlwings is updated
# XlsxWriter is updated
# xlrd is updated
# wrapt is updated
# win-unicode-console is updated
# widgetsnbextension is updated
# wheel is updated
# Werkzeug is updated
# wcwidth is updated
# uritemplate is updated
# unicodecsv is updated
# traitlets is updated
# tornado is updated
# toolz is updated
# tables is updated
# sympy is updated
# statsmodels is updated
# SQLAlchemy is updated
# spyder is updated
# sockjs-tornado is updated
# snowballstemmer is updated
# six is updated
# singledispatch is updated
# simplegeneric is updated
# seaborn is updated
# scipy is updated
# scikit-learn is updated
# scikit-image is updated
# schedule is updated
# rsa is updated
# rope-py3k is updated
# requests is updated
# QtPy is updated
# qtconsole is updated
# QtAwesome is updated
# pyzmq is updated
# PyYAML is updated
# pywin32 is updated
# pytz is updated
# python-dateutil is updated
# pytest is updated
# pyparsing is updated
# pyOpenSSL is updated
# pylint is updated
# Pygments is updated
# pyflakes is updated
# pycurl is updated
# pycrypto is updated
# pycparser is updated
# pycosat is updated
# pyasn1 is updated
# pyasn1-modules is updated
# py is updated
# psutil is updated
# prompt-toolkit is updated
# ply is updated
# pip is updated
# Pillow is updated
# pickleshare is updated
# pep8 is updated
# patsy is updated
# pathlib2 is updated
# path.py is updated
# partd is updated
# pandas is updated
# openpyxl is updated
# odo is updated
# oauth2client is updated
# numpydoc is updated
# numpy is updated
# numexpr is updated
# numba is updated
# notebook is updated
# nose is updated
# nltk is updated
# networkx is updated
# nbformat is updated
# nbconvert is updated
# multipledispatch is updated
# mpmath is updated
# mistune is updated
# menuinst is updated
# matplotlib is updated
# MarkupSafe is updated
# lxml is updated
# locket is updated
# llvmlite is updated
# lazy-object-proxy is updated
# jupyter is updated
# jupyter-core is updated
# jupyter-console is updated
# jupyter-client is updated
# jsonschema is updated
# Jinja2 is updated
# jedi is updated
# jdcal is updated
# itsdangerous is updated
# isort is updated
# ipywidgets is updated
# ipython is updated
# ipython-genutils is updated
# ipykernel is updated
# imagesize is updated
# idna is updated
# httplib2 is updated
# HeapDict is updated
# h5py is updated
# gspread is updated
# greenlet is updated
# google-api-python-client is updated
# gevent is updated
# Flask is updated
# Flask-Cors is updated
# fastcache is updated
# et-xmlfile is updated
# docutils is updated
# dill is updated
# df2gspread is updated
# decorator is updated
# datashape is updated
# dask is updated
# cytoolz is updated
# Cython is updated
# cycler is updated
# cryptography is updated
# contextlib2 is updated
# configobj is updated
# conda is updated
# comtypes is updated
# colorama is updated
# clyent is updated
# cloudpickle is updated
# click is updated
# chest is updated
# chardet is updated
# cffi is updated
# Bottleneck is updated
# boto is updated
# bokeh is updated
# blaze is updated
# bitarray is updated
# beautifulsoup4 is updated
# backports.shutil-get-terminal-size is updated
# Babel is updated
# astropy is updated
# astroid is updated
# anaconda-project is updated
# anaconda-navigator is updated
# anaconda-client is updated
# alabaster is updated
# sphinx is updated
# setuptools is updated
