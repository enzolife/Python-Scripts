# %%
import requests
import time
import datetime as dt
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy
import logging

# %%
logging.basicConfig(level=logging.INFO, 
                    format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
# Date
today_date = dt.date.today() + dt.timedelta(days=0)
yesterday_date = dt.date.today() + dt.timedelta(days=-1)
seven_days_before_date = dt.date.today() + dt.timedelta(days=-7)

# %%
# get_auth_signature
def get_auth_signature(url, payload, shop_key):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
def post_message_to_shopee_api(url, payload, shop_key):
    # Auth Signature
    auth_signature = get_auth_signature(url, payload, shop_key) 
    # HTML Header
    headers = {"Host": "partner.shopeemobile.com",
                "Content-Type": "application/json",
                "Content-Length": "89",
                "Authorization": auth_signature}
    # HTML Body
    payload = json.dumps(payload)
    # Post Request
    r = requests.post(url, data=payload, headers=headers)
    # 打印原始Json
    parsed = json.loads(r.text)
    return parsed

# %%
# get_item_list
def get_item_list(partner_id, shopid, shop_key):
    # parameters
    max_page = 200
    pagination_entries_per_page = 100
    i = 0
    # Current time stamp
    timestamp = int(time.time())
    # URL
    url = 'https://partner.shopeemobile.com/api/v1/items/get'
    
    try:
        while i <= max_page:
            # start entry
            start_entry = i * pagination_entries_per_page
            # Parameter
            pagination_offset = start_entry
            # payload
            payload = {"partner_id":partner_id,
                       "shopid":shopid,
                       "timestamp":timestamp,
                       "pagination_offset":pagination_offset,
                       "pagination_entries_per_page":pagination_entries_per_page}
            # post_message_to_shopee_api
            parsed = post_message_to_shopee_api(url, payload, shop_key)
            # 漂亮打印Json
            item_list = json_normalize(parsed['items'])
            # 排除update_time
            selected_column = ['item_id', 'shopid', 'status']
            item_list = item_list[selected_column]

            # 合并
            if i == 0:
                all_item_list = item_list
            else:
                all_item_list = all_item_list.append(item_list)

            i += 1
            logging.info('Retrieving item from page ' + str(i))
    except:
        pass

    # 去重
    logging.info('Remove duplicate records.')
    all_item_list = all_item_list.drop_duplicates('item_id').reset_index()
    logging.info('Retrieved item list.')
    return all_item_list

# %%
# get_item_detail
def get_item_detail(partner_id, shopid, shop_key, all_item_list):
    # empty item_detail_list
    item_detail_list = pd.DataFrame()
    # Current time stamp
    timestamp = int(time.time())
    # get item detail
    url = 'https://partner.shopeemobile.com/api/v1/item/get'
    
    for key, item in all_item_list.iterrows():
        try:
            item_id = item['item_id']
            logging.info('Now retrieving ' + str(item_id) + ' detail.')
            # payload
            payload = {"partner_id":partner_id,
                       "shopid":shopid,
                       "timestamp":timestamp,
                       "item_id": item_id}
            # post_message_to_shopee_api
            parsed = post_message_to_shopee_api(url, payload, shop_key)
            # 漂亮打印Json
            item_detail = json_normalize(parsed['item'])
            item_detail_list = item_detail_list.append(item_detail)
            logging.info('Retrieved ' + str(item_id) + ' detail.')
        except:
            pass

    # convert timestamp to date
    item_detail_list['create_time'] = pd.to_datetime(item_detail_list['create_time'], unit='s').dt.date
    item_detail_list['update_time'] = pd.to_datetime(item_detail_list['update_time'], unit='s').dt.date
    item_detail_list['days_since_live'] = (today_date - item_detail_list['create_time']).dt.days

    return item_detail_list

# %%
# retrieve_dict_and_convert_to_df_column
def retrieve_dict_and_convert_to_df_column(dataframe, column_name, selected_key_list, converted_column_name):

    edited_column_list = []

    for index, record in dataframe.iterrows():
        to_edit_column = pd.DataFrame(record[column_name])
        try:
            to_edit_column = to_edit_column[selected_key_list]
            to_edit_column_dict = to_edit_column.to_dict('records')
        except:
            to_edit_column_dict = '[]'
        edited_column_list.append(to_edit_column_dict)
    
    dataframe[converted_column_name] = edited_column_list
    return dataframe

# %%
# retrieve_image_and_convert_to_dict
def retrieve_image_and_convert_to_dict(dataframe, column_name, converted_column_name):
    edited_column_list = []
    for index, record in dataframe.iterrows():
        img_url_dict_list = []
        to_edit_column = pd.DataFrame(record[column_name])
        for index, img_url in to_edit_column.iterrows():
            img_url_dict = {'url': img_url[0]}
            img_url_dict_list.append(img_url_dict)
        edited_column_list.append(img_url_dict_list)
    dataframe[converted_column_name] = edited_column_list
    return dataframe

# %%
# 根据每个分类，找到必填的attributes，然后填上
def get_category_attributes(partner_id, shopid, shop_key, category_id):
    # Current time stamp
    timestamp = int(time.time())
    
    payload = {"partner_id":partner_id,
               "shopid": shopid,
               "timestamp": timestamp,
               "category_id": category_id}

    url = 'https://partner.shopeemobile.com/api/v1/item/attributes/get'

    # post_message_to_shopee_api
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    # 漂亮打印Json
    attribute_list = json_normalize(parsed['attributes'])
    attribute_list['category_id'] = category_id
    
    # 查找是否有error
    
    return attribute_list

# %%
# 找店铺分类
def get_category_info(partner_id, shopid, shop_key):
    
    # Current time stamp
    timestamp = int(time.time())
    
    payload = {"partner_id":partner_id,
               "shopid": shopid,
               "timestamp": timestamp}

    url = 'https://partner.shopeemobile.com/api/v1/item/categories/get'

    # post_message_to_shopee_api
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    # 漂亮打印Json
    category_list = json_normalize(parsed['categories'])
    
    # 查找是否有error
    
    return category_list

# %%
# 删除产品
def delete_product(partner_id, shopid, shop_key, delete_product_id):
    # Current time stamp
    timestamp = int(time.time())
    
    # payload
    payload = {
               "item_id": delete_product_id,
               "partner_id": partner_id,
               "shopid": shopid,
               "timestamp": timestamp
               }

    # print(payload)
    
    url = 'https://partner.shopeemobile.com/api/v1/item/delete'

    # post_message_to_shopee_api
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    logging.info('Product ID: ' + str(delete_product_id) + ' is deleted.')
    
    # 查找是否有error

# %%
# 添加商品图片
def add_product_image(partner_id, shopid, shop_key, item_id, images):
    # 上传中可能失败；尝试到找不到fail_image为止
    while len(images) != 0:
        # Current time stamp
        timestamp = int(time.time())

        # payload
        payload = {
                    "item_id": item_id,
                    "images": images,
                    "partner_id": partner_id,
                    "shopid": shopid,
                    "timestamp": timestamp
                   }

        url = 'https://partner.shopeemobile.com/api/v1/item/img/add'

        # post_message_to_shopee_api
        parsed = post_message_to_shopee_api(url, payload, shop_key)
        # print(parsed)
        logging.info('add_product_image - Images for Product ID: ' + str(item_id) + ' are added.')
        # 清空images
        images = []
        
        # 查找是否有error

        # 查找是否有上传失败的图片
        if 'fail_image' in parsed.keys():
            logging.info('add_product_image - Start to upload failed images.')
            images = parsed['fail_image']

# %%
# 添加商品图片到某个指定位置
def add_product_image_to_certain_location(partner_id, shopid, shop_key, item_id, image_url, image_position):
    # 上传中可能失败；尝试到找不到fail_image为止
    while len(image_url) != 0:
        # Current time stamp
        timestamp = int(time.time())

        # payload
        payload = {
                    "item_id": item_id,
                    "image_url": image_url,
                    "image_position": image_position,
                    "partner_id": partner_id,
                    "shopid": shopid,
                    "timestamp": timestamp
                   }

        url = 'https://partner.shopeemobile.com/api/v1/item/img/insert'

        # post_message_to_shopee_api
        parsed = post_message_to_shopee_api(url, payload, shop_key)
        logging.info(parsed)
        # 查找是否有上传失败的图片
        if 'error' in parsed.keys():
            logging.warning('add_product_image - Error occurred. Upload agaign')
        else:
            logging.info('add_product_image_to_certain_location - Images for Product ID: ' + str(item_id) + ' are added.')
            # 清空images
            image_url = ''

# %%
# 新增产品
def add_product(partner_id, shopid, shop_key,
                category_id,
                name,
                description,
                price,
                stock,
                item_sku,
                edited_variations,
                edited_images,
                edited_attributes,
                edited_logistics,
                weight
               ):
    # Current time stamp
    timestamp = int(time.time())
    
    # payload
    payload = {
                "category_id": category_id,
                "name": name,
                "description": description,
                "price": price,
                "stock": stock,
                "item_sku": item_sku,
                "images": edited_images,
                "weight": weight,
                "logistics": edited_logistics,
                # "days_to_ship": days_to_ship,
                "partner_id": partner_id,
                "shopid": shopid,
                "timestamp": timestamp
               }
    
    # 判断条件是否为空
    if edited_variations != '[]':
        payload['variations'] = edited_variations
        
    if edited_attributes != '[]':
        payload['attributes'] = edited_attributes
        
    # print(payload)

    url = 'https://partner.shopeemobile.com/api/v1/item/add'

    # post_message_to_shopee_api
    logging.info('add_product - Add Product SKU: ' + str(item_sku))
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    # print(parsed)
    
    # 查找是否有error
    if 'error' in parsed.keys():
        logging.warning(parsed)
        return False
    else:
        item_id = parsed['item_id']
        # 查找是否有failed images
        if 'fail_image' in parsed.keys():
            # 判断是否有图片上传失败；如果失败要重传
            try:
                fail_image_list = parsed['fail_image']
                # print(fail_image_list)
                logging.info('add_product - Try to upload failed images.')
                for fail_image in fail_image_list:
                    # 查找在原来的image list里面，它是在哪个位置；要把它放回到原来的位置上
                    logging.info('add_product - Now upload failed image: ' + str(fail_image))
                    fail_image_position = 0
                    for index, value in enumerate(edited_images):
                        original_image_url = value['url']
                        logging.info('Original images: ' + str(original_image_url))
                        if original_image_url == fail_image:
                            fail_image_position = index + 1
                            logging.info('add_product - Failed images ' + str(fail_image) + ' is at location ' + str(fail_image_position))
                    logging.info('add_product - Upload image to position: ' + str(fail_image_position))
                    add_product_image_to_certain_location(partner_id, shopid, shop_key, item_id, fail_image, fail_image_position)        
                    # add_product_image(partner_id, shopid, shop_key, item_id, fail_image_list)
                logging.info('add_product - Images are added.')
            except Exception as err:
                logging.info('add_product - An exception occurred: ' + str(err))
        logging.info('add_product - Product ID: ' + str(item_id) + ' is added.')
        return True

# %%
# shop parameter list# shop  
# partner_id, shopid, shop_name, shop_key
shop_parameter_list = [\
   [12155, 23070969, 'poweradapter.tw', 'de5e924b8ed680bc9b22a6c402058154340333ff05641a38069f2856a2f3e24e'],
   [12156, 25482220, 'tengus.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [14689, 53580963, 'qianjiaozi.my', '93815a723e386c9b91379a94f31538853582e02e085e180e0d52c841f7b53e19'],
   [12156, 59848325, 'tengus.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 59846508, 'tengus.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 58707738, 'qianjiaozi', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [12156, 62417386, 'tengus1.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62417551, 'tengus2.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416366, 'tengus1.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416544, 'tengus2.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418141, 'tengus1.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418493, 'tengus2.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 63534861, 'qianjiaozitw1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [17701, 62887142, 'yilanlu.tw', 'f3e23e0a873b0d74bb8a05b03a77e7a7a03bfebdba622d685b64aa926467d8b9'],
   [16363, 66377809, 'qianjiaozi1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3']
  ]

columns = ['partner_id', 'shopid', 'shop_name', 'shop_key']
shop_parameter_df = pd.DataFrame(shop_parameter_list, columns=columns)
# shop_parameter_df

# %%
def delect_inactive_skus_and_upload_again(partner_id, shopid, shop_name, shop_key):
    # 1. get item list
    all_item_list = get_item_list(partner_id, shopid, shop_key)
    # 2. get item detail list
    item_detail_list = get_item_detail(partner_id, shopid, shop_key, all_item_list)
    # 3. filter item detail list
    # 选上线超过60天仍然0销量的产品；把没有attributes的产品去掉
    item_detail_list = item_detail_list[item_detail_list['days_since_live'] >= 60]
    item_detail_list = item_detail_list[item_detail_list['sales'] == 0]
    item_detail_list = item_detail_list.sort_values(by='days_since_live', ascending=False)
    item_detail_list = item_detail_list[item_detail_list['attributes'].str.len() != 0]
    item_detail_list = item_detail_list[item_detail_list['stock'] > 0]
    # 如果不存在这样的list，直接跳过
    if len(item_detail_list) != 0:
        # 4. get item attributes list
        column_name = 'attributes'
        selected_key_list = ['attribute_id', 'attribute_value']
        converted_column_name = 'edited attributes'
        retrieve_dict_and_convert_to_df_column(item_detail_list, column_name, selected_key_list, converted_column_name)
        # 5. 把attribute_id改为attributes_id；注意：如果原本的产品没有填任何attribute，直接忽略
        for value in item_detail_list['edited attributes']:
            for dict_value in value:
                dict_value['attributes_id'] = dict_value.pop('attribute_id')
                dict_value['value'] = dict_value.pop('attribute_value')
        # 6. 看店铺所有分类的必填attributes
        category_id_list = item_detail_list['category_id'].drop_duplicates()
        # 7. 获取这个店铺所有分类的attributes list
        attribute_full_list = pd.DataFrame()
        for category_id in category_id_list:
            # print(int(category_id))
            category_id = int(category_id)
            category_attribute = get_category_attributes(partner_id, shopid, shop_key, category_id)
            attribute_full_list = attribute_full_list.append(category_attribute)
        # 8. 给每个必填attribute提供default value
        attribute_default_value_list = [
            [5794, 9547, '握力'],
            [11460, 9547, '握力']
        ]
        attribute_default_value_columns = ['category_id', 'attribute_id', 'value']
        attribute_default_value_df = pd.DataFrame(attribute_default_value_list, columns=attribute_default_value_columns)
        attribute_full_list = pd.merge(attribute_full_list, attribute_default_value_df, how='left',
                                   left_on=['category_id', 'attribute_id'], right_on=['category_id', 'attribute_id'])
        # 9. 检查每个产品的attributes
        # 检查现有的attributes是否在表里；如果不存在，要删除
        # 如果缺了必填的attributes，要补充回来
        for index, value in item_detail_list.iterrows():
            # 拿到每个产品的cat id
            category_id = value['category_id']
            # 创建一个空list，装这个产品的所有现有attributes
            existing_attribute = []

            # for loop所有这个产品的attributes，放在existing_attribute
            for dict_value in value['edited attributes']:
                existing_attribute.append(dict_value['attributes_id'])
            # print(existing_attribute)

            # 把这个cat的必填attribute拉出来
            cat_mandatory_attribute_df = (attribute_full_list[(attribute_full_list['category_id'] == category_id)
                                                               & (attribute_full_list['is_mandatory'] == True)])
            # print((cat_mandatory_attribute_list))

            # 把这个cat的非必填attribute拉出来
            cat_optional_attribute_df = (attribute_full_list[(attribute_full_list['category_id'] == category_id)
                                                               & (attribute_full_list['is_mandatory'] == False)])
            # print((cat_optional_attribute_list))

            # 判断必填attributes是不是在现有attributes内
            for index, attr in cat_mandatory_attribute_df.iterrows():
                mandatory_attribute_id = attr['attribute_id']
                mandatory_attribute_value = attr['value']

                if mandatory_attribute_id not in existing_attribute:
                    # print('attr: ' + str(mandatory_attribute_id) + ' is not in mandatory_attribute_list.')
                    attr_dict = {'attributes_id': mandatory_attribute_id,
                                 'value': mandatory_attribute_value}
                    value['edited attributes'].append(attr_dict)

            # 判断现有非必填attributes内是否有不符合的非必填attributes
            for attr in existing_attribute:
                # print(attr)
                if attr not in list(cat_mandatory_attribute_df['attribute_id']):
                    if attr not in list(cat_optional_attribute_df['attribute_id']):
                        print('attr: ' + str(attr) + ' is not in optional_attribute_list.')
                        # 删除这个不符合的非必填项
                        for dict_value in value['edited attributes']:
                            if dict_value['attributes_id'] == attr:
                                del dict_value

        # 10. 删减variations的内容
        column_name = 'variations'
        selected_key_list = ['name', 'stock', 'price', 'variation_sku']
        converted_column_name = 'edited variations'
        retrieve_dict_and_convert_to_df_column(item_detail_list, column_name, selected_key_list, converted_column_name)                 
        # 11. 删减logistics的内容
        column_name = 'logistics'
        selected_key_list = ['logistic_id', 'enabled']
        converted_column_name = 'edited logistics'
        retrieve_dict_and_convert_to_df_column(item_detail_list, column_name, selected_key_list, converted_column_name)
        # 12. 转换images的内容
        column_name = 'images'
        converted_column_name = 'edited images'
        retrieve_image_and_convert_to_dict(item_detail_list, column_name, converted_column_name)
        # 13. 选择需要提交的内容
        selected_columns = ["category_id","name","description","price","stock","item_sku","edited variations","images","edited attributes","edited logistics","weight","days_to_ship", 'item_id', 'edited images']
        edited_item_detail_list = item_detail_list[selected_columns]    
        # 测试
        test_item_detail_list = edited_item_detail_list[:10]
        test_item_detail_list    
        # 14. 先删除产品，再新增产品
        for index, item in test_item_detail_list.iterrows():
            category_id = item[0]
            name = item[1]
            description = item[2]
            price = item[3]
            stock = item[4]
            item_sku = item[5]
            edited_variations = item[6]
            images = item[7]
            edited_attributes = item[8]
            edited_logistics = item[9]
            weight = item[10]
            # days_to_ship = 3
            product_id = item[12]
            edited_images = item[13]

            # print(images)



            # add product
            add_product_success = add_product(partner_id, shopid, shop_key,
                                               category_id,
                                               name,
                                               description,
                                               price,
                                               stock,
                                               item_sku,
                                               edited_variations,
                                               edited_images,
                                               edited_attributes,
                                               edited_logistics,
                                               weight
                                               )    
            if add_product_success == True:
                # delete product
                delete_product(partner_id, shopid, shop_key, product_id)
    else:
        logging.warning('add_product - Theres are not products under this filter for ' + str(shop_name))

# %%
def get_attribute_category_list(partner_id, shopid, shop_name, shop_key):
    # 1. get item list
    all_item_list = get_item_list(partner_id, shopid, shop_key)
    # 2. get item detail list
    item_detail_list = get_item_detail(partner_id, shopid, shop_key, all_item_list)
    item_detail_list.to_csv('D://item_detail_list.csv', sep=',')
    # 3. filter item detail list
    # 如果不存在这样的list，直接跳过
    if len(item_detail_list) != 0:
        # 6. 看店铺所有分类的必填attributes
        category_id_list = item_detail_list['category_id'].drop_duplicates()
        # 7. 获取这个店铺所有分类的attributes list
        attribute_full_list = pd.DataFrame()
        for category_id in category_id_list:
            # print(int(category_id))
            category_id = int(category_id)
            category_attribute = get_category_attributes(partner_id, shopid, shop_key, category_id)
            attribute_full_list = attribute_full_list.append(category_attribute)
    return attribute_full_list

# %%
# 执行
attribute_list_for_all_shop = pd.DataFrame()
to_run_shop_list = [25482220,
                    59846508, 23070969, 58707738]

for index, shop_parameter in shop_parameter_df.iterrows():
    partner_id = shop_parameter[0]
    shopid = shop_parameter[1]
    shop_name = shop_parameter[2]
    shop_key = shop_parameter[3]
    
    if shopid in to_run_shop_list:
        delect_inactive_skus_and_upload_again(partner_id, shopid, shop_name, shop_key)
        # images = ['https://t12.baidu.com/it/u=2105759597,3540269422&fm=173&app=25&f=JPEG?w=500&h=518&s=3DBB6A96EA533CCC3E6F59A20300E009','https://t12.baidu.com/it/u=667913453,121168607&fm=173&app=25&f=JPEG?w=500&h=309&s=B582EBB47E1B2CC042B2D9A20300E008']
        # item_id = 1196145106
        # image_url = 'https://t12.baidu.com/it/u=2105759597,3540269422&fm=173&app=25&f=JPEG?w=500&h=518&s=3DBB6A96EA533CCC3E6F59A20300E009'
        # image_position = 2
        # add_product_image(partner_id, shopid, shop_key, item_id, images)
        # add_product_image_to_certain_location(partner_id, shopid, shop_key, item_id, image_url, image_position)
 
    # try:
        # 查找所有店铺的attribute list
        # attribute_list = get_attribute_category_list(partner_id, shopid, shop_name, shop_key)
        # attribute_list_for_all_shop = attribute_list_for_all_shop.append(attribute_list)
    # except:
        # pass
    
# attribute_list_for_all_shop
# Out:
#  2018-06-03 14:30:48,335 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:49,780 - INFO - Retrieving item from page 1
#  2018-06-03 14:30:49,784 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:50,034 - INFO - Remove duplicate records.
#  2018-06-03 14:30:50,037 - INFO - Retrieved item list.
#  2018-06-03 14:30:50,039 - INFO - Now retrieving 1213653046 detail.
#  2018-06-03 14:30:50,043 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:50,694 - INFO - Retrieved 1213653046 detail.
#  2018-06-03 14:30:50,696 - INFO - Now retrieving 1213652863 detail.
#  2018-06-03 14:30:50,701 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:51,180 - INFO - Retrieved 1213652863 detail.
#  2018-06-03 14:30:51,181 - INFO - Now retrieving 1213652630 detail.
#  2018-06-03 14:30:51,185 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:51,611 - INFO - Retrieved 1213652630 detail.
#  2018-06-03 14:30:51,612 - INFO - Now retrieving 1210519315 detail.
#  2018-06-03 14:30:51,614 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:52,112 - INFO - Retrieved 1210519315 detail.
#  2018-06-03 14:30:52,114 - INFO - Now retrieving 1210519153 detail.
#  2018-06-03 14:30:52,117 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:52,544 - INFO - Retrieved 1210519153 detail.
#  2018-06-03 14:30:52,545 - INFO - Now retrieving 1210518988 detail.
#  2018-06-03 14:30:52,549 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:53,019 - INFO - Retrieved 1210518988 detail.
#  2018-06-03 14:30:53,020 - INFO - Now retrieving 1210518806 detail.
#  2018-06-03 14:30:53,023 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:53,539 - INFO - Retrieved 1210518806 detail.
#  2018-06-03 14:30:53,540 - INFO - Now retrieving 1210518721 detail.
#  2018-06-03 14:30:53,543 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:53,965 - INFO - Retrieved 1210518721 detail.
#  2018-06-03 14:30:53,966 - INFO - Now retrieving 289819285 detail.
#  2018-06-03 14:30:53,969 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:54,428 - INFO - Retrieved 289819285 detail.
#  2018-06-03 14:30:54,429 - INFO - Now retrieving 714258341 detail.
#  2018-06-03 14:30:54,433 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:55,126 - INFO - Retrieved 714258341 detail.
#  2018-06-03 14:30:55,127 - INFO - Now retrieving 714259330 detail.
#  2018-06-03 14:30:55,130 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:55,545 - INFO - Retrieved 714259330 detail.
#  2018-06-03 14:30:55,546 - INFO - Now retrieving 714259996 detail.
#  2018-06-03 14:30:55,550 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:56,066 - INFO - Retrieved 714259996 detail.
#  2018-06-03 14:30:56,067 - INFO - Now retrieving 714261044 detail.
#  2018-06-03 14:30:56,071 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:56,492 - INFO - Retrieved 714261044 detail.
#  2018-06-03 14:30:56,493 - INFO - Now retrieving 692636431 detail.
#  2018-06-03 14:30:56,496 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:57,292 - INFO - Retrieved 692636431 detail.
#  2018-06-03 14:30:57,293 - INFO - Now retrieving 692636435 detail.
#  2018-06-03 14:30:57,296 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:57,746 - INFO - Retrieved 692636435 detail.
#  2018-06-03 14:30:57,748 - INFO - Now retrieving 714264130 detail.
#  2018-06-03 14:30:57,752 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:58,299 - INFO - Retrieved 714264130 detail.
#  2018-06-03 14:30:58,301 - INFO - Now retrieving 714265338 detail.
#  2018-06-03 14:30:58,304 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:58,730 - INFO - Retrieved 714265338 detail.
#  2018-06-03 14:30:58,731 - INFO - Now retrieving 714269270 detail.
#  2018-06-03 14:30:58,734 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:59,287 - INFO - Retrieved 714269270 detail.
#  2018-06-03 14:30:59,288 - INFO - Now retrieving 714270605 detail.
#  2018-06-03 14:30:59,291 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:30:59,801 - INFO - Retrieved 714270605 detail.
#  2018-06-03 14:30:59,802 - INFO - Now retrieving 714271171 detail.
#  2018-06-03 14:30:59,806 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:00,252 - INFO - Retrieved 714271171 detail.
#  2018-06-03 14:31:00,253 - INFO - Now retrieving 714271936 detail.
#  2018-06-03 14:31:00,257 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:00,744 - INFO - Retrieved 714271936 detail.
#  2018-06-03 14:31:00,745 - INFO - Now retrieving 714272553 detail.
#  2018-06-03 14:31:00,748 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:01,105 - INFO - Retrieved 714272553 detail.
#  2018-06-03 14:31:01,106 - INFO - Now retrieving 714273131 detail.
#  2018-06-03 14:31:01,110 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:01,539 - INFO - Retrieved 714273131 detail.
#  2018-06-03 14:31:01,540 - INFO - Now retrieving 692636390 detail.
#  2018-06-03 14:31:01,543 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:01,976 - INFO - Retrieved 692636390 detail.
#  2018-06-03 14:31:01,977 - INFO - Now retrieving 692636393 detail.
#  2018-06-03 14:31:01,981 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:02,579 - INFO - Retrieved 692636393 detail.
#  2018-06-03 14:31:02,580 - INFO - Now retrieving 692636423 detail.
#  2018-06-03 14:31:02,583 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:03,177 - INFO - Retrieved 692636423 detail.
#  2018-06-03 14:31:03,177 - INFO - Now retrieving 692636451 detail.
#  2018-06-03 14:31:03,180 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:03,634 - INFO - Retrieved 692636451 detail.
#  2018-06-03 14:31:03,635 - INFO - Now retrieving 714246361 detail.
#  2018-06-03 14:31:03,638 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:04,470 - INFO - Retrieved 714246361 detail.
#  2018-06-03 14:31:04,471 - INFO - Now retrieving 714246479 detail.
#  2018-06-03 14:31:04,474 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:04,970 - INFO - Retrieved 714246479 detail.
#  2018-06-03 14:31:04,970 - INFO - Now retrieving 714273694 detail.
#  2018-06-03 14:31:04,972 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:05,486 - INFO - Retrieved 714273694 detail.
#  2018-06-03 14:31:05,487 - INFO - Now retrieving 692636373 detail.
#  2018-06-03 14:31:05,491 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:05,844 - INFO - Retrieved 692636373 detail.
#  2018-06-03 14:31:05,845 - INFO - Now retrieving 692636384 detail.
#  2018-06-03 14:31:05,848 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:06,208 - INFO - Retrieved 692636384 detail.
#  2018-06-03 14:31:06,209 - INFO - Now retrieving 692642614 detail.
#  2018-06-03 14:31:06,212 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:06,667 - INFO - Retrieved 692642614 detail.
#  2018-06-03 14:31:06,668 - INFO - Now retrieving 289815417 detail.
#  2018-06-03 14:31:06,672 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:07,053 - INFO - Retrieved 289815417 detail.
#  2018-06-03 14:31:07,054 - INFO - Now retrieving 714255768 detail.
#  2018-06-03 14:31:07,057 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:07,463 - INFO - Retrieved 714255768 detail.
#  2018-06-03 14:31:07,464 - INFO - Now retrieving 289817643 detail.
#  2018-06-03 14:31:07,467 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:07,893 - INFO - Retrieved 289817643 detail.
#  2018-06-03 14:31:07,894 - INFO - Now retrieving 289817722 detail.
#  2018-06-03 14:31:07,897 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:08,338 - INFO - Retrieved 289817722 detail.
#  2018-06-03 14:31:08,340 - INFO - Now retrieving 289817750 detail.
#  2018-06-03 14:31:08,343 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:09,015 - INFO - Retrieved 289817750 detail.
#  2018-06-03 14:31:09,016 - INFO - Now retrieving 289817813 detail.
#  2018-06-03 14:31:09,019 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:09,576 - INFO - Retrieved 289817813 detail.
#  2018-06-03 14:31:09,577 - INFO - Now retrieving 714246499 detail.
#  2018-06-03 14:31:09,580 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:10,116 - INFO - Retrieved 714246499 detail.
#  2018-06-03 14:31:10,117 - INFO - Now retrieving 714254359 detail.
#  2018-06-03 14:31:10,120 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:10,699 - INFO - Retrieved 714254359 detail.
#  2018-06-03 14:31:10,700 - INFO - Now retrieving 289819286 detail.
#  2018-06-03 14:31:10,703 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:11,133 - INFO - Retrieved 289819286 detail.
#  2018-06-03 14:31:11,134 - INFO - Now retrieving 289819304 detail.
#  2018-06-03 14:31:11,138 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:11,641 - INFO - Retrieved 289819304 detail.
#  2018-06-03 14:31:11,642 - INFO - Now retrieving 692636406 detail.
#  2018-06-03 14:31:11,645 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:12,065 - INFO - Retrieved 692636406 detail.
#  2018-06-03 14:31:12,067 - INFO - Now retrieving 1201451488 detail.
#  2018-06-03 14:31:12,070 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:12,526 - INFO - Retrieved 1201451488 detail.
#  2018-06-03 14:31:12,527 - INFO - Now retrieving 1201520781 detail.
#  2018-06-03 14:31:12,531 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:13,428 - INFO - Retrieved 1201520781 detail.
#  2018-06-03 14:31:13,429 - INFO - Now retrieving 1121446661 detail.
#  2018-06-03 14:31:13,432 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:14,813 - INFO - Retrieved 1121446661 detail.
#  2018-06-03 14:31:14,814 - INFO - Now retrieving 1121455576 detail.
#  2018-06-03 14:31:14,817 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:15,321 - INFO - Retrieved 1121455576 detail.
#  2018-06-03 14:31:15,322 - INFO - Now retrieving 288208978 detail.
#  2018-06-03 14:31:15,326 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:16,233 - INFO - Retrieved 288208978 detail.
#  2018-06-03 14:31:16,235 - INFO - Now retrieving 1207749262 detail.
#  2018-06-03 14:31:16,238 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:16,693 - INFO - Retrieved 1207749262 detail.
#  2018-06-03 14:31:16,694 - INFO - Now retrieving 1194753393 detail.
#  2018-06-03 14:31:16,696 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:17,121 - INFO - Retrieved 1194753393 detail.
#  2018-06-03 14:31:17,122 - INFO - Now retrieving 1201389382 detail.
#  2018-06-03 14:31:17,125 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:17,602 - INFO - Retrieved 1201389382 detail.
#  2018-06-03 14:31:17,603 - INFO - Now retrieving 1201442342 detail.
#  2018-06-03 14:31:17,607 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:18,041 - INFO - Retrieved 1201442342 detail.
#  2018-06-03 14:31:18,042 - INFO - Now retrieving 1121423066 detail.
#  2018-06-03 14:31:18,045 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:18,647 - INFO - Retrieved 1121423066 detail.
#  2018-06-03 14:31:18,648 - INFO - Now retrieving 1201520555 detail.
#  2018-06-03 14:31:18,651 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:19,108 - INFO - Retrieved 1201520555 detail.
#  2018-06-03 14:31:19,109 - INFO - Now retrieving 1207775713 detail.
#  2018-06-03 14:31:19,114 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:19,578 - INFO - Retrieved 1207775713 detail.
#  2018-06-03 14:31:19,579 - INFO - Now retrieving 1194753512 detail.
#  2018-06-03 14:31:19,585 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:20,181 - INFO - Retrieved 1194753512 detail.
#  2018-06-03 14:31:20,181 - INFO - Now retrieving 1194753760 detail.
#  2018-06-03 14:31:20,184 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:20,685 - INFO - Retrieved 1194753760 detail.
#  2018-06-03 14:31:20,687 - INFO - Now retrieving 1201389248 detail.
#  2018-06-03 14:31:20,691 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:21,126 - INFO - Retrieved 1201389248 detail.
#  2018-06-03 14:31:21,127 - INFO - Now retrieving 1196145009 detail.
#  2018-06-03 14:31:21,130 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:21,572 - INFO - Retrieved 1196145009 detail.
#  2018-06-03 14:31:21,573 - INFO - Now retrieving 1196145106 detail.
#  2018-06-03 14:31:21,576 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:22,000 - INFO - Retrieved 1196145106 detail.
#  2018-06-03 14:31:22,001 - INFO - Now retrieving 1201418221 detail.
#  2018-06-03 14:31:22,004 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:22,421 - INFO - Retrieved 1201418221 detail.
#  2018-06-03 14:31:22,422 - INFO - Now retrieving 1201424104 detail.
#  2018-06-03 14:31:22,425 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:23,151 - INFO - Retrieved 1201424104 detail.
#  2018-06-03 14:31:23,152 - INFO - Now retrieving 1201482004 detail.
#  2018-06-03 14:31:23,156 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:23,618 - INFO - Retrieved 1201482004 detail.
#  2018-06-03 14:31:23,619 - INFO - Now retrieving 1201520969 detail.
#  2018-06-03 14:31:23,622 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:24,030 - INFO - Retrieved 1201520969 detail.
#  2018-06-03 14:31:24,031 - INFO - Now retrieving 1201521158 detail.
#  2018-06-03 14:31:24,035 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:24,400 - INFO - Retrieved 1201521158 detail.
#  2018-06-03 14:31:24,401 - INFO - Now retrieving 1201521509 detail.
#  2018-06-03 14:31:24,404 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:24,812 - INFO - Retrieved 1201521509 detail.
#  2018-06-03 14:31:24,813 - INFO - Now retrieving 1207775358 detail.
#  2018-06-03 14:31:24,817 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:25,237 - INFO - Retrieved 1207775358 detail.
#  2018-06-03 14:31:25,238 - INFO - Now retrieving 1207775892 detail.
#  2018-06-03 14:31:25,242 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:25,715 - INFO - Retrieved 1207775892 detail.
#  2018-06-03 14:31:25,716 - INFO - Now retrieving 1204640528 detail.
#  2018-06-03 14:31:25,720 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:26,142 - INFO - Retrieved 1204640528 detail.
#  2018-06-03 14:31:26,143 - INFO - Now retrieving 1204640760 detail.
#  2018-06-03 14:31:26,146 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:26,546 - INFO - Retrieved 1204640760 detail.
#  2018-06-03 14:31:26,547 - INFO - Now retrieving 1204641072 detail.
#  2018-06-03 14:31:26,551 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:27,064 - INFO - Retrieved 1204641072 detail.
#  2018-06-03 14:31:27,064 - INFO - Now retrieving 1201451913 detail.
#  2018-06-03 14:31:27,067 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:27,531 - INFO - Retrieved 1201451913 detail.
#  2018-06-03 14:31:27,532 - INFO - Now retrieving 1201482091 detail.
#  2018-06-03 14:31:27,535 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:27,978 - INFO - Retrieved 1201482091 detail.
#  2018-06-03 14:31:27,979 - INFO - Now retrieving 692636409 detail.
#  2018-06-03 14:31:27,982 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:28,419 - INFO - Retrieved 692636409 detail.
#  2018-06-03 14:31:28,429 - WARNING - add_product - Theres are not products under this filter for poweradapter.tw
#  2018-06-03 14:31:28,433 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:29,027 - INFO - Retrieving item from page 1
#  2018-06-03 14:31:29,030 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:29,405 - INFO - Retrieving item from page 2
#  2018-06-03 14:31:29,408 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:29,847 - INFO - Retrieving item from page 3
#  2018-06-03 14:31:29,850 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:30,304 - INFO - Retrieving item from page 4
#  2018-06-03 14:31:30,310 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:31,695 - INFO - Retrieving item from page 5
#  2018-06-03 14:31:31,698 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:32,122 - INFO - Retrieving item from page 6
#  2018-06-03 14:31:32,126 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:32,582 - INFO - Retrieving item from page 7
#  2018-06-03 14:31:32,586 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:32,999 - INFO - Retrieving item from page 8
#  2018-06-03 14:31:33,002 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:33,610 - INFO - Retrieving item from page 9
#  2018-06-03 14:31:33,614 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:33,989 - INFO - Retrieving item from page 10
#  2018-06-03 14:31:33,993 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:34,466 - INFO - Retrieving item from page 11
#  2018-06-03 14:31:34,469 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:34,908 - INFO - Retrieving item from page 12
#  2018-06-03 14:31:34,911 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:35,208 - INFO - Remove duplicate records.
#  2018-06-03 14:31:35,211 - INFO - Retrieved item list.
#  2018-06-03 14:31:35,213 - INFO - Now retrieving 952642940 detail.
#  2018-06-03 14:31:35,216 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:35,680 - INFO - Retrieved 952642940 detail.
#  2018-06-03 14:31:35,682 - INFO - Now retrieving 978226125 detail.
#  2018-06-03 14:31:35,686 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:36,287 - INFO - Retrieved 978226125 detail.
#  2018-06-03 14:31:36,288 - INFO - Now retrieving 957896177 detail.
#  2018-06-03 14:31:36,292 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:36,879 - INFO - Retrieved 957896177 detail.
#  2018-06-03 14:31:36,880 - INFO - Now retrieving 675681678 detail.
#  2018-06-03 14:31:36,884 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:37,340 - INFO - Retrieved 675681678 detail.
#  2018-06-03 14:31:37,341 - INFO - Now retrieving 843423938 detail.
#  2018-06-03 14:31:37,345 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:37,834 - INFO - Retrieved 843423938 detail.
#  2018-06-03 14:31:37,835 - INFO - Now retrieving 888054914 detail.
#  2018-06-03 14:31:37,839 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:38,306 - INFO - Retrieved 888054914 detail.
#  2018-06-03 14:31:38,307 - INFO - Now retrieving 648875242 detail.
#  2018-06-03 14:31:38,310 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:38,869 - INFO - Retrieved 648875242 detail.
#  2018-06-03 14:31:38,870 - INFO - Now retrieving 820067918 detail.
#  2018-06-03 14:31:38,873 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:39,300 - INFO - Retrieved 820067918 detail.
#  2018-06-03 14:31:39,301 - INFO - Now retrieving 871833501 detail.
#  2018-06-03 14:31:39,304 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:39,805 - INFO - Retrieved 871833501 detail.
#  2018-06-03 14:31:39,806 - INFO - Now retrieving 815106212 detail.
#  2018-06-03 14:31:39,808 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:40,225 - INFO - Retrieved 815106212 detail.
#  2018-06-03 14:31:40,226 - INFO - Now retrieving 894027605 detail.
#  2018-06-03 14:31:40,228 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:40,690 - INFO - Retrieved 894027605 detail.
#  2018-06-03 14:31:40,691 - INFO - Now retrieving 624856293 detail.
#  2018-06-03 14:31:40,693 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:41,181 - INFO - Retrieved 624856293 detail.
#  2018-06-03 14:31:41,182 - INFO - Now retrieving 863449052 detail.
#  2018-06-03 14:31:41,185 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:41,703 - INFO - Retrieved 863449052 detail.
#  2018-06-03 14:31:41,704 - INFO - Now retrieving 804762990 detail.
#  2018-06-03 14:31:41,708 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:42,167 - INFO - Retrieved 804762990 detail.
#  2018-06-03 14:31:42,168 - INFO - Now retrieving 815054468 detail.
#  2018-06-03 14:31:42,172 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:42,689 - INFO - Retrieved 815054468 detail.
#  2018-06-03 14:31:42,690 - INFO - Now retrieving 891055023 detail.
#  2018-06-03 14:31:42,693 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:43,184 - INFO - Retrieved 891055023 detail.
#  2018-06-03 14:31:43,185 - INFO - Now retrieving 843586997 detail.
#  2018-06-03 14:31:43,191 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:43,756 - INFO - Retrieved 843586997 detail.
#  2018-06-03 14:31:43,757 - INFO - Now retrieving 809410645 detail.
#  2018-06-03 14:31:43,761 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:45,552 - INFO - Retrieved 809410645 detail.
#  2018-06-03 14:31:45,553 - INFO - Now retrieving 812177313 detail.
#  2018-06-03 14:31:45,556 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:45,977 - INFO - Retrieved 812177313 detail.
#  2018-06-03 14:31:45,978 - INFO - Now retrieving 661259703 detail.
#  2018-06-03 14:31:45,982 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:46,706 - INFO - Retrieved 661259703 detail.
#  2018-06-03 14:31:46,707 - INFO - Now retrieving 649033416 detail.
#  2018-06-03 14:31:46,711 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:47,380 - INFO - Retrieved 649033416 detail.
#  2018-06-03 14:31:47,381 - INFO - Now retrieving 675668333 detail.
#  2018-06-03 14:31:47,385 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:47,830 - INFO - Retrieved 675668333 detail.
#  2018-06-03 14:31:47,831 - INFO - Now retrieving 863298840 detail.
#  2018-06-03 14:31:47,833 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:48,394 - INFO - Retrieved 863298840 detail.
#  2018-06-03 14:31:48,395 - INFO - Now retrieving 806803125 detail.
#  2018-06-03 14:31:48,399 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:48,847 - INFO - Retrieved 806803125 detail.
#  2018-06-03 14:31:48,849 - INFO - Now retrieving 891036711 detail.
#  2018-06-03 14:31:48,852 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:49,275 - INFO - Retrieved 891036711 detail.
#  2018-06-03 14:31:49,276 - INFO - Now retrieving 619000110 detail.
#  2018-06-03 14:31:49,281 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:49,822 - INFO - Retrieved 619000110 detail.
#  2018-06-03 14:31:49,823 - INFO - Now retrieving 622743560 detail.
#  2018-06-03 14:31:49,826 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:50,337 - INFO - Retrieved 622743560 detail.
#  2018-06-03 14:31:50,337 - INFO - Now retrieving 619000233 detail.
#  2018-06-03 14:31:50,340 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:50,723 - INFO - Retrieved 619000233 detail.
#  2018-06-03 14:31:50,724 - INFO - Now retrieving 812561116 detail.
#  2018-06-03 14:31:50,727 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:51,304 - INFO - Retrieved 812561116 detail.
#  2018-06-03 14:31:51,305 - INFO - Now retrieving 823729332 detail.
#  2018-06-03 14:31:51,308 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:51,802 - INFO - Retrieved 823729332 detail.
#  2018-06-03 14:31:51,803 - INFO - Now retrieving 624685591 detail.
#  2018-06-03 14:31:51,806 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:52,201 - INFO - Retrieved 624685591 detail.
#  2018-06-03 14:31:52,202 - INFO - Now retrieving 853194244 detail.
#  2018-06-03 14:31:52,205 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:52,836 - INFO - Retrieved 853194244 detail.
#  2018-06-03 14:31:52,837 - INFO - Now retrieving 902516220 detail.
#  2018-06-03 14:31:52,840 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:53,330 - INFO - Retrieved 902516220 detail.
#  2018-06-03 14:31:53,331 - INFO - Now retrieving 845114948 detail.
#  2018-06-03 14:31:53,334 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:53,874 - INFO - Retrieved 845114948 detail.
#  2018-06-03 14:31:53,875 - INFO - Now retrieving 844777709 detail.
#  2018-06-03 14:31:53,879 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:54,354 - INFO - Retrieved 844777709 detail.
#  2018-06-03 14:31:54,355 - INFO - Now retrieving 843346174 detail.
#  2018-06-03 14:31:54,358 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:54,779 - INFO - Retrieved 843346174 detail.
#  2018-06-03 14:31:54,780 - INFO - Now retrieving 1124292285 detail.
#  2018-06-03 14:31:54,783 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:55,260 - INFO - Retrieved 1124292285 detail.
#  2018-06-03 14:31:55,261 - INFO - Now retrieving 670106828 detail.
#  2018-06-03 14:31:55,264 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:55,738 - INFO - Retrieved 670106828 detail.
#  2018-06-03 14:31:55,739 - INFO - Now retrieving 657165235 detail.
#  2018-06-03 14:31:55,742 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:56,130 - INFO - Retrieved 657165235 detail.
#  2018-06-03 14:31:56,131 - INFO - Now retrieving 848143265 detail.
#  2018-06-03 14:31:56,134 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:56,778 - INFO - Retrieved 848143265 detail.
#  2018-06-03 14:31:56,779 - INFO - Now retrieving 820176735 detail.
#  2018-06-03 14:31:56,782 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:57,401 - INFO - Retrieved 820176735 detail.
#  2018-06-03 14:31:57,402 - INFO - Now retrieving 843538849 detail.
#  2018-06-03 14:31:57,405 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:57,901 - INFO - Retrieved 843538849 detail.
#  2018-06-03 14:31:57,903 - INFO - Now retrieving 806782760 detail.
#  2018-06-03 14:31:57,907 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:58,445 - INFO - Retrieved 806782760 detail.
#  2018-06-03 14:31:58,446 - INFO - Now retrieving 622743544 detail.
#  2018-06-03 14:31:58,449 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:59,032 - INFO - Retrieved 622743544 detail.
#  2018-06-03 14:31:59,033 - INFO - Now retrieving 1145319177 detail.
#  2018-06-03 14:31:59,037 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:31:59,666 - INFO - Retrieved 1145319177 detail.
#  2018-06-03 14:31:59,666 - INFO - Now retrieving 1029498327 detail.
#  2018-06-03 14:31:59,670 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:01,058 - INFO - Retrieved 1029498327 detail.
#  2018-06-03 14:32:01,059 - INFO - Now retrieving 622677476 detail.
#  2018-06-03 14:32:01,062 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:01,977 - INFO - Retrieved 622677476 detail.
#  2018-06-03 14:32:01,978 - INFO - Now retrieving 1150971767 detail.
#  2018-06-03 14:32:01,981 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:02,452 - INFO - Retrieved 1150971767 detail.
#  2018-06-03 14:32:02,453 - INFO - Now retrieving 1124222362 detail.
#  2018-06-03 14:32:02,457 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:03,017 - INFO - Retrieved 1124222362 detail.
#  2018-06-03 14:32:03,017 - INFO - Now retrieving 999744467 detail.
#  2018-06-03 14:32:03,021 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:03,571 - INFO - Retrieved 999744467 detail.
#  2018-06-03 14:32:03,572 - INFO - Now retrieving 1118432878 detail.
#  2018-06-03 14:32:03,575 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:04,030 - INFO - Retrieved 1118432878 detail.
#  2018-06-03 14:32:04,031 - INFO - Now retrieving 622677367 detail.
#  2018-06-03 14:32:04,035 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:04,509 - INFO - Retrieved 622677367 detail.
#  2018-06-03 14:32:04,510 - INFO - Now retrieving 859866479 detail.
#  2018-06-03 14:32:04,513 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:04,913 - INFO - Retrieved 859866479 detail.
#  2018-06-03 14:32:04,914 - INFO - Now retrieving 622677454 detail.
#  2018-06-03 14:32:04,917 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:05,477 - INFO - Retrieved 622677454 detail.
#  2018-06-03 14:32:05,478 - INFO - Now retrieving 802004707 detail.
#  2018-06-03 14:32:05,482 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:05,976 - INFO - Retrieved 802004707 detail.
#  2018-06-03 14:32:05,977 - INFO - Now retrieving 1151108682 detail.
#  2018-06-03 14:32:05,980 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:06,634 - INFO - Retrieved 1151108682 detail.
#  2018-06-03 14:32:06,635 - INFO - Now retrieving 1116385098 detail.
#  2018-06-03 14:32:06,638 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:07,097 - INFO - Retrieved 1116385098 detail.
#  2018-06-03 14:32:07,098 - INFO - Now retrieving 1019901216 detail.
#  2018-06-03 14:32:07,101 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:07,507 - INFO - Retrieved 1019901216 detail.
#  2018-06-03 14:32:07,508 - INFO - Now retrieving 797827438 detail.
#  2018-06-03 14:32:07,511 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:07,962 - INFO - Retrieved 797827438 detail.
#  2018-06-03 14:32:07,964 - INFO - Now retrieving 624851659 detail.
#  2018-06-03 14:32:07,967 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:08,455 - INFO - Retrieved 624851659 detail.
#  2018-06-03 14:32:08,456 - INFO - Now retrieving 1045052117 detail.
#  2018-06-03 14:32:08,459 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:08,900 - INFO - Retrieved 1045052117 detail.
#  2018-06-03 14:32:08,901 - INFO - Now retrieving 1138999203 detail.
#  2018-06-03 14:32:08,904 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:09,413 - INFO - Retrieved 1138999203 detail.
#  2018-06-03 14:32:09,414 - INFO - Now retrieving 781619137 detail.
#  2018-06-03 14:32:09,417 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:09,917 - INFO - Retrieved 781619137 detail.
#  2018-06-03 14:32:09,918 - INFO - Now retrieving 1021784696 detail.
#  2018-06-03 14:32:09,922 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:10,455 - INFO - Retrieved 1021784696 detail.
#  2018-06-03 14:32:10,456 - INFO - Now retrieving 1139029149 detail.
#  2018-06-03 14:32:10,460 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:10,863 - INFO - Retrieved 1139029149 detail.
#  2018-06-03 14:32:10,864 - INFO - Now retrieving 801949922 detail.
#  2018-06-03 14:32:10,868 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:11,344 - INFO - Retrieved 801949922 detail.
#  2018-06-03 14:32:11,345 - INFO - Now retrieving 1150963554 detail.
#  2018-06-03 14:32:11,349 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:13,182 - INFO - Retrieved 1150963554 detail.
#  2018-06-03 14:32:13,183 - INFO - Now retrieving 1150964581 detail.
#  2018-06-03 14:32:13,186 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:13,583 - INFO - Retrieved 1150964581 detail.
#  2018-06-03 14:32:13,584 - INFO - Now retrieving 1151111515 detail.
#  2018-06-03 14:32:13,587 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:14,262 - INFO - Retrieved 1151111515 detail.
#  2018-06-03 14:32:14,263 - INFO - Now retrieving 803709406 detail.
#  2018-06-03 14:32:14,266 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:14,698 - INFO - Retrieved 803709406 detail.
#  2018-06-03 14:32:14,699 - INFO - Now retrieving 670598247 detail.
#  2018-06-03 14:32:14,702 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:15,190 - INFO - Retrieved 670598247 detail.
#  2018-06-03 14:32:15,192 - INFO - Now retrieving 884789663 detail.
#  2018-06-03 14:32:15,195 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:15,768 - INFO - Retrieved 884789663 detail.
#  2018-06-03 14:32:15,769 - INFO - Now retrieving 1016861462 detail.
#  2018-06-03 14:32:15,772 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:16,267 - INFO - Retrieved 1016861462 detail.
#  2018-06-03 14:32:16,268 - INFO - Now retrieving 999718243 detail.
#  2018-06-03 14:32:16,272 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:16,705 - INFO - Retrieved 999718243 detail.
#  2018-06-03 14:32:16,706 - INFO - Now retrieving 670609247 detail.
#  2018-06-03 14:32:16,711 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:17,228 - INFO - Retrieved 670609247 detail.
#  2018-06-03 14:32:17,229 - INFO - Now retrieving 1151152743 detail.
#  2018-06-03 14:32:17,233 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:17,721 - INFO - Retrieved 1151152743 detail.
#  2018-06-03 14:32:17,722 - INFO - Now retrieving 1093121799 detail.
#  2018-06-03 14:32:17,726 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:18,168 - INFO - Retrieved 1093121799 detail.
#  2018-06-03 14:32:18,169 - INFO - Now retrieving 955822237 detail.
#  2018-06-03 14:32:18,172 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:18,709 - INFO - Retrieved 955822237 detail.
#  2018-06-03 14:32:18,710 - INFO - Now retrieving 859814857 detail.
#  2018-06-03 14:32:18,713 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:19,139 - INFO - Retrieved 859814857 detail.
#  2018-06-03 14:32:19,140 - INFO - Now retrieving 1139004710 detail.
#  2018-06-03 14:32:19,143 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:19,628 - INFO - Retrieved 1139004710 detail.
#  2018-06-03 14:32:19,629 - INFO - Now retrieving 1139023798 detail.
#  2018-06-03 14:32:19,633 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:20,154 - INFO - Retrieved 1139023798 detail.
#  2018-06-03 14:32:20,155 - INFO - Now retrieving 1108673977 detail.
#  2018-06-03 14:32:20,158 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:20,578 - INFO - Retrieved 1108673977 detail.
#  2018-06-03 14:32:20,580 - INFO - Now retrieving 802001066 detail.
#  2018-06-03 14:32:20,583 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:21,042 - INFO - Retrieved 802001066 detail.
#  2018-06-03 14:32:21,043 - INFO - Now retrieving 1053517596 detail.
#  2018-06-03 14:32:21,046 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:21,493 - INFO - Retrieved 1053517596 detail.
#  2018-06-03 14:32:21,494 - INFO - Now retrieving 1053534067 detail.
#  2018-06-03 14:32:21,497 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:22,003 - INFO - Retrieved 1053534067 detail.
#  2018-06-03 14:32:22,004 - INFO - Now retrieving 815007154 detail.
#  2018-06-03 14:32:22,007 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:22,490 - INFO - Retrieved 815007154 detail.
#  2018-06-03 14:32:22,491 - INFO - Now retrieving 1011913098 detail.
#  2018-06-03 14:32:22,494 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:23,080 - INFO - Retrieved 1011913098 detail.
#  2018-06-03 14:32:23,081 - INFO - Now retrieving 865742552 detail.
#  2018-06-03 14:32:23,085 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:23,537 - INFO - Retrieved 865742552 detail.
#  2018-06-03 14:32:23,538 - INFO - Now retrieving 946081217 detail.
#  2018-06-03 14:32:23,541 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:24,093 - INFO - Retrieved 946081217 detail.
#  2018-06-03 14:32:24,093 - INFO - Now retrieving 955830397 detail.
#  2018-06-03 14:32:24,096 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:24,689 - INFO - Retrieved 955830397 detail.
#  2018-06-03 14:32:24,690 - INFO - Now retrieving 1138985452 detail.
#  2018-06-03 14:32:24,694 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:25,257 - INFO - Retrieved 1138985452 detail.
#  2018-06-03 14:32:25,258 - INFO - Now retrieving 624854668 detail.
#  2018-06-03 14:32:25,262 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:25,684 - INFO - Retrieved 624854668 detail.
#  2018-06-03 14:32:25,685 - INFO - Now retrieving 1108661230 detail.
#  2018-06-03 14:32:25,688 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:26,147 - INFO - Retrieved 1108661230 detail.
#  2018-06-03 14:32:26,148 - INFO - Now retrieving 1068298522 detail.
#  2018-06-03 14:32:26,152 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:26,651 - INFO - Retrieved 1068298522 detail.
#  2018-06-03 14:32:26,652 - INFO - Now retrieving 1108664710 detail.
#  2018-06-03 14:32:26,655 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:27,127 - INFO - Retrieved 1108664710 detail.
#  2018-06-03 14:32:27,128 - INFO - Now retrieving 1139020485 detail.
#  2018-06-03 14:32:27,130 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:27,853 - INFO - Retrieved 1139020485 detail.
#  2018-06-03 14:32:27,854 - INFO - Now retrieving 1068331070 detail.
#  2018-06-03 14:32:27,859 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:28,236 - INFO - Retrieved 1068331070 detail.
#  2018-06-03 14:32:28,238 - INFO - Now retrieving 1068340130 detail.
#  2018-06-03 14:32:28,244 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:28,694 - INFO - Retrieved 1068340130 detail.
#  2018-06-03 14:32:28,695 - INFO - Now retrieving 801983710 detail.
#  2018-06-03 14:32:28,699 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:29,131 - INFO - Retrieved 801983710 detail.
#  2018-06-03 14:32:29,131 - INFO - Now retrieving 622677456 detail.
#  2018-06-03 14:32:29,135 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:29,612 - INFO - Retrieved 622677456 detail.
#  2018-06-03 14:32:29,614 - INFO - Now retrieving 965611068 detail.
#  2018-06-03 14:32:29,617 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:30,049 - INFO - Retrieved 965611068 detail.
#  2018-06-03 14:32:30,050 - INFO - Now retrieving 622677489 detail.
#  2018-06-03 14:32:30,053 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:30,558 - INFO - Retrieved 622677489 detail.
#  2018-06-03 14:32:30,560 - INFO - Now retrieving 1053529290 detail.
#  2018-06-03 14:32:30,563 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:31,016 - INFO - Retrieved 1053529290 detail.
#  2018-06-03 14:32:31,017 - INFO - Now retrieving 803279232 detail.
#  2018-06-03 14:32:31,021 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:31,570 - INFO - Retrieved 803279232 detail.
#  2018-06-03 14:32:31,571 - INFO - Now retrieving 622681936 detail.
#  2018-06-03 14:32:31,574 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:32,121 - INFO - Retrieved 622681936 detail.
#  2018-06-03 14:32:32,122 - INFO - Now retrieving 1080987514 detail.
#  2018-06-03 14:32:32,126 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:32,660 - INFO - Retrieved 1080987514 detail.
#  2018-06-03 14:32:32,661 - INFO - Now retrieving 803300398 detail.
#  2018-06-03 14:32:32,664 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:33,095 - INFO - Retrieved 803300398 detail.
#  2018-06-03 14:32:33,096 - INFO - Now retrieving 803318156 detail.
#  2018-06-03 14:32:33,100 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:33,605 - INFO - Retrieved 803318156 detail.
#  2018-06-03 14:32:33,606 - INFO - Now retrieving 843331922 detail.
#  2018-06-03 14:32:33,610 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:34,114 - INFO - Retrieved 843331922 detail.
#  2018-06-03 14:32:34,115 - INFO - Now retrieving 1093302214 detail.
#  2018-06-03 14:32:34,118 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:34,849 - INFO - Retrieved 1093302214 detail.
#  2018-06-03 14:32:34,850 - INFO - Now retrieving 1016847300 detail.
#  2018-06-03 14:32:34,854 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:35,348 - INFO - Retrieved 1016847300 detail.
#  2018-06-03 14:32:35,349 - INFO - Now retrieving 1093188804 detail.
#  2018-06-03 14:32:35,354 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:37,673 - INFO - Retrieved 1093188804 detail.
#  2018-06-03 14:32:37,675 - INFO - Now retrieving 1085050383 detail.
#  2018-06-03 14:32:37,678 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:38,169 - INFO - Retrieved 1085050383 detail.
#  2018-06-03 14:32:38,170 - INFO - Now retrieving 978228596 detail.
#  2018-06-03 14:32:38,174 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:38,694 - INFO - Retrieved 978228596 detail.
#  2018-06-03 14:32:38,695 - INFO - Now retrieving 962468601 detail.
#  2018-06-03 14:32:38,699 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:39,114 - INFO - Retrieved 962468601 detail.
#  2018-06-03 14:32:39,115 - INFO - Now retrieving 859692676 detail.
#  2018-06-03 14:32:39,119 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:39,723 - INFO - Retrieved 859692676 detail.
#  2018-06-03 14:32:39,725 - INFO - Now retrieving 1013969618 detail.
#  2018-06-03 14:32:39,728 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:40,262 - INFO - Retrieved 1013969618 detail.
#  2018-06-03 14:32:40,263 - INFO - Now retrieving 1108607756 detail.
#  2018-06-03 14:32:40,266 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:40,951 - INFO - Retrieved 1108607756 detail.
#  2018-06-03 14:32:40,952 - INFO - Now retrieving 1108611762 detail.
#  2018-06-03 14:32:40,955 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:41,383 - INFO - Retrieved 1108611762 detail.
#  2018-06-03 14:32:41,384 - INFO - Now retrieving 1108627351 detail.
#  2018-06-03 14:32:41,388 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:41,868 - INFO - Retrieved 1108627351 detail.
#  2018-06-03 14:32:41,869 - INFO - Now retrieving 874696446 detail.
#  2018-06-03 14:32:41,874 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:42,393 - INFO - Retrieved 874696446 detail.
#  2018-06-03 14:32:42,394 - INFO - Now retrieving 859792942 detail.
#  2018-06-03 14:32:42,398 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:42,946 - INFO - Retrieved 859792942 detail.
#  2018-06-03 14:32:42,947 - INFO - Now retrieving 978233299 detail.
#  2018-06-03 14:32:42,951 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-06-03 14:32:43,446 - INFO - Retrieved 978233299 detail.
#  2018-06-03 14:32:43,447 - INFO - Now retrieving 622677368 detail.
#  2018-06-03 14:32:43,451 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
