# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy

# %%
# Current time stamp
timestamp = int(time.time())

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
# Shop Parameter
partner_id = 12155
shopid = 23070969

# %%
# get_auth_signature
def get_auth_signature(url, payload):
    # API Key
    shopee_secret = 'de5e924b8ed680bc9b22a6c402058154340333ff05641a38069f2856a2f3e24e'
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# URL
url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# Parameter
pagination_offset = 0
pagination_entries_per_page = 100

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "pagination_offset":pagination_offset,
           "pagination_entries_per_page":pagination_entries_per_page}
print(payload)
# Out:
# {'partner_id': 12155, 'shopid': 23070969, 'timestamp': 1511316223, 'pagination_offset': 0, 'pagination_entries_per_page': 100}

# %%
# Auth Signature
Auth_signature = get_auth_signature(url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                 items   more
# 0   {'item_id': 692636435, 'shopid': 23070969, 'st...  False
# 1   {'item_id': 692636432, 'shopid': 23070969, 'st...  False
# 2   {'item_id': 692636431, 'shopid': 23070969, 'st...  False
# 3   {'item_id': 692636426, 'shopid': 23070969, 'st...  False
# 4   {'item_id': 692636425, 'shopid': 23070969, 'st...  False
# 5   {'item_id': 692636424, 'shopid': 23070969, 'st...  False
# 6   {'item_id': 692636423, 'shopid': 23070969, 'st...  False
# 7   {'item_id': 692636422, 'shopid': 23070969, 'st...  False
# 8   {'item_id': 692636419, 'shopid': 23070969, 'st...  False
# 9   {'item_id': 692636409, 'shopid': 23070969, 'st...  False
# 10  {'item_id': 692636407, 'shopid': 23070969, 'st...  False
# 11  {'item_id': 692636405, 'shopid': 23070969, 'st...  False
# 12  {'item_id': 692636400, 'shopid': 23070969, 'st...  False
# 13  {'item_id': 692636396, 'shopid': 23070969, 'st...  False
# 14  {'item_id': 692636393, 'shopid': 23070969, 'st...  False
# 15  {'item_id': 692636390, 'shopid': 23070969, 'st...  False
# 16  {'item_id': 692636384, 'shopid': 23070969, 'st...  False
# 17  {'item_id': 692636376, 'shopid': 23070969, 'st...  False
# 18  {'item_id': 692636375, 'shopid': 23070969, 'st...  False
# 19  {'item_id': 692636377, 'shopid': 23070969, 'st...  False
# 20  {'item_id': 692636406, 'shopid': 23070969, 'st...  False
# 21  {'item_id': 423964945, 'shopid': 23070969, 'st...  False
# 22  {'item_id': 289815417, 'shopid': 23070969, 'st...  False
# 23  {'item_id': 692636373, 'shopid': 23070969, 'st...  False
# 24  {'item_id': 289817813, 'shopid': 23070969, 'st...  False
# 25  {'item_id': 692636439, 'shopid': 23070969, 'st...  False
# 26  {'item_id': 692636440, 'shopid': 23070969, 'st...  False
# 27  {'item_id': 692636448, 'shopid': 23070969, 'st...  False
# 28  {'item_id': 692636450, 'shopid': 23070969, 'st...  False
# 29  {'item_id': 692636451, 'shopid': 23070969, 'st...  False
# 30  {'item_id': 692636455, 'shopid': 23070969, 'st...  False
# 31  {'item_id': 692636458, 'shopid': 23070969, 'st...  False
# 32  {'item_id': 692636460, 'shopid': 23070969, 'st...  False
# 33  {'item_id': 692639116, 'shopid': 23070969, 'st...  False
# 34  {'item_id': 692640311, 'shopid': 23070969, 'st...  False
# 35  {'item_id': 692641763, 'shopid': 23070969, 'st...  False
# 36  {'item_id': 692642614, 'shopid': 23070969, 'st...  False
# 37  {'item_id': 692636465, 'shopid': 23070969, 'st...  False
# 38  {'item_id': 692636463, 'shopid': 23070969, 'st...  False
# 39  {'item_id': 289819286, 'shopid': 23070969, 'st...  False
# 40  {'item_id': 289817722, 'shopid': 23070969, 'st...  False
# 41  {'item_id': 289819304, 'shopid': 23070969, 'st...  False
# 42  {'item_id': 423974128, 'shopid': 23070969, 'st...  False
# 43  {'item_id': 289819285, 'shopid': 23070969, 'st...  False
# 44  {'item_id': 288208978, 'shopid': 23070969, 'st...  False
# 45  {'item_id': 289817643, 'shopid': 23070969, 'st...  False
# 46  {'item_id': 289817750, 'shopid': 23070969, 'st...  False
# 47  {'item_id': 289815382, 'shopid': 23070969, 'st...  False

# %%
# 漂亮打印Json
item_list = json_normalize(parsed['items'])
item_list
# Out:
#       item_id    shopid  status
# 0   692636435  23070969  NORMAL
# 1   692636432  23070969  NORMAL
# 2   692636431  23070969  NORMAL
# 3   692636426  23070969  NORMAL
# 4   692636425  23070969  NORMAL
# 5   692636424  23070969  NORMAL
# 6   692636423  23070969  NORMAL
# 7   692636422  23070969  NORMAL
# 8   692636419  23070969  NORMAL
# 9   692636409  23070969  NORMAL
# 10  692636407  23070969  NORMAL
# 11  692636405  23070969  NORMAL
# 12  692636400  23070969  NORMAL
# 13  692636396  23070969  NORMAL
# 14  692636393  23070969  NORMAL
# 15  692636390  23070969  NORMAL
# 16  692636384  23070969  NORMAL
# 17  692636376  23070969  NORMAL
# 18  692636375  23070969  NORMAL
# 19  692636377  23070969  NORMAL
# 20  692636406  23070969  NORMAL
# 21  423964945  23070969  NORMAL
# 22  289815417  23070969  NORMAL
# 23  692636373  23070969  NORMAL
# 24  289817813  23070969  NORMAL
# 25  692636439  23070969  NORMAL
# 26  692636440  23070969  NORMAL
# 27  692636448  23070969  NORMAL
# 28  692636450  23070969  NORMAL
# 29  692636451  23070969  NORMAL
# 30  692636455  23070969  NORMAL
# 31  692636458  23070969  NORMAL
# 32  692636460  23070969  NORMAL
# 33  692639116  23070969  NORMAL
# 34  692640311  23070969  NORMAL
# 35  692641763  23070969  NORMAL
# 36  692642614  23070969  NORMAL
# 37  692636465  23070969  NORMAL
# 38  692636463  23070969  NORMAL
# 39  289819286  23070969  NORMAL
# 40  289817722  23070969  NORMAL
# 41  289819304  23070969  NORMAL
# 42  423974128  23070969  NORMAL
# 43  289819285  23070969  NORMAL
# 44  288208978  23070969  NORMAL
# 45  289817643  23070969  NORMAL
# 46  289817750  23070969  NORMAL
# 47  289815382  23070969  NORMAL

# %%
# 获取商品库存
item_detail_url = 'https://partner.shopeemobile.com/api/v1/items/update_stock'

# %%
# 参数
stock = 1001
# 表
product_list = json_normalize(parsed['items'])
product_list.dtypes
# Out:
# item_id     int64
# shopid      int64
# status     object
# dtype: object

# %%
payload = {"partner_id":partner_id,
               "shopid":shopid,
               "timestamp":timestamp,
               "item_id":int(item_id),
               "stock":stock}
print(json.dumps(payload))
# Out:
# {"partner_id": 12155, "shopid": 23070969, "timestamp": 1511316223, "item_id": 692636390, "stock": 1001}

# %%
# 无限循环
i = 1
while True:
    if i % 2==0:
        stock = 1000
    else:
        stock = 1001
        
    print("Now run the " + str(i) + " time.")
        
    # 历遍
    for item_id in product_list['item_id']:

        timestamp = int(time.time())
        
        payload = {"partner_id":partner_id,
                   "shopid":shopid,
                   "timestamp":timestamp,
                   "item_id":int(item_id),
                   "stock":stock}

        # print(json.dumps(payload))

        Auth_signature = get_auth_signature(item_detail_url, payload)
        # HTML Header

        headers = {"Host": "partner.shopeemobile.com",
                    "Content-Type": "application/json",
                    "Content-Length": "89",
                    "Authorization": Auth_signature}
        # HTML Body
        payload = json.dumps(payload)
        # Post Request
        r = requests.post(item_detail_url, data=payload, headers=headers)
        print(r.text)
        # Notice
        print(str(item_id) + ' stock updated.')
        time.sleep(30)
        
    i = i + 1
# Out:
# Now run the 1 time.
# {"item":{"item_id":692636435,"modified_time":1511316257}}
# 692636435 stock updated.
# {"item":{"item_id":692636432,"modified_time":1511316287}}
# 692636432 stock updated.
# {"item":{"item_id":692636431,"modified_time":1511316317}}
# 692636431 stock updated.
# {"item":{"item_id":692636426,"modified_time":1511316348}}
# 692636426 stock updated.
# {"item":{"item_id":692636425,"modified_time":1511316378}}
# 692636425 stock updated.
# {"item":{"item_id":692636424,"modified_time":1511316408}}
# 692636424 stock updated.
# {"item":{"item_id":692636423,"modified_time":1511316438}}
# 692636423 stock updated.
# {"item":{"item_id":692636422,"modified_time":1511316468}}
# 692636422 stock updated.
# {"item":{"item_id":692636419,"modified_time":1511316499}}
# 692636419 stock updated.
# {"item":{"item_id":692636409,"modified_time":1511316529}}
# 692636409 stock updated.
# {"item":{"item_id":692636407,"modified_time":1511316559}}
# 692636407 stock updated.
# {"item":{"item_id":692636405,"modified_time":1511316589}}
# 692636405 stock updated.
# {"item":{"item_id":692636400,"modified_time":1511316620}}
# 692636400 stock updated.
# {"item":{"item_id":692636396,"modified_time":1511316650}}
# 692636396 stock updated.
# {"item":{"item_id":692636393,"modified_time":1511316680}}
# 692636393 stock updated.
# {"item":{"item_id":692636390,"modified_time":1511316710}}
# 692636390 stock updated.
# {"item":{"item_id":692636384,"modified_time":1511316740}}
# 692636384 stock updated.
# {"item":{"item_id":692636376,"modified_time":1511316770}}
# 692636376 stock updated.
# {"item":{"item_id":692636375,"modified_time":1511316801}}
# 692636375 stock updated.
# {"item":{"item_id":692636377,"modified_time":1511316831}}
# 692636377 stock updated.
# {"item":{"item_id":692636406,"modified_time":1511316861}}
# 692636406 stock updated.
# {"item":{"item_id":423964945,"modified_time":1511316891}}
# 423964945 stock updated.
# {"item":{"item_id":289815417,"modified_time":1511316921}}
# 289815417 stock updated.
# {"item":{"item_id":692636373,"modified_time":1511316951}}
# 692636373 stock updated.
# {"msg":"this item is ongoing promotion","error":"error_permission"}
# 289817813 stock updated.
# {"item":{"item_id":692636439,"modified_time":1511317012}}
# 692636439 stock updated.
# {"item":{"item_id":692636440,"modified_time":1511317042}}
# 692636440 stock updated.
# {"item":{"item_id":692636448,"modified_time":1511317072}}
# 692636448 stock updated.
# {"item":{"item_id":692636450,"modified_time":1511317103}}
# 692636450 stock updated.
# {"item":{"item_id":692636451,"modified_time":1511317133}}
# 692636451 stock updated.
# {"item":{"item_id":692636455,"modified_time":1511317163}}
# 692636455 stock updated.
# {"item":{"item_id":692636458,"modified_time":1511317193}}
# 692636458 stock updated.
# {"item":{"item_id":692636460,"modified_time":1511317223}}
# 692636460 stock updated.
# {"item":{"item_id":692639116,"modified_time":1511317254}}
# 692639116 stock updated.
# {"item":{"item_id":692640311,"modified_time":1511317284}}
# 692640311 stock updated.
# {"item":{"item_id":692641763,"modified_time":1511317314}}
# 692641763 stock updated.
# {"item":{"item_id":692642614,"modified_time":1511317344}}
# 692642614 stock updated.
# {"item":{"item_id":692636465,"modified_time":1511317374}}
# 692636465 stock updated.
# {"item":{"item_id":692636463,"modified_time":1511317405}}
# 692636463 stock updated.
# {"msg":"this item is ongoing promotion","error":"error_permission"}
# 289819286 stock updated.
# {"msg":"this item is ongoing promotion","error":"error_permission"}
# 289817722 stock updated.
# {"msg":"this item is ongoing promotion","error":"error_permission"}
# 289819304 stock updated.
# {"item":{"item_id":423974128,"modified_time":1511317525}}
# 423974128 stock updated.
