# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy

# %%
# Current time stamp
timestamp = int(time.time())

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
# Shop Parameter
partner_id = 12155
shopid = 23070969
shop_key = 'de5e924b8ed680bc9b22a6c402058154340333ff05641a38069f2856a2f3e24e'

# %%
# get_auth_signature
def get_auth_signature(url, payload):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# URL
url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# Parameter
pagination_offset = 0
pagination_entries_per_page = 100

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "pagination_offset":pagination_offset,
           "pagination_entries_per_page":pagination_entries_per_page}
print(payload)
# Out:
# {'partner_id': 12155, 'shopid': 23070969, 'timestamp': 1516591437, 'pagination_offset': 0, 'pagination_entries_per_page': 100}

# %%
# Auth Signature
Auth_signature = get_auth_signature(url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                 items  more
# 0   {'item_id': 289819285, 'shopid': 23070969, 'st...  True
# 1   {'item_id': 289817722, 'shopid': 23070969, 'st...  True
# 2   {'item_id': 692636384, 'shopid': 23070969, 'st...  True
# 3   {'item_id': 692636435, 'shopid': 23070969, 'st...  True
# 4   {'item_id': 692636375, 'shopid': 23070969, 'st...  True
# 5   {'item_id': 714246437, 'shopid': 23070969, 'st...  True
# 6   {'item_id': 714258341, 'shopid': 23070969, 'st...  True
# 7   {'item_id': 714246435, 'shopid': 23070969, 'st...  True
# 8   {'item_id': 289817643, 'shopid': 23070969, 'st...  True
# 9   {'item_id': 714259335, 'shopid': 23070969, 'st...  True
# 10  {'item_id': 714246434, 'shopid': 23070969, 'st...  True
# 11  {'item_id': 714259330, 'shopid': 23070969, 'st...  True
# 12  {'item_id': 714246433, 'shopid': 23070969, 'st...  True
# 13  {'item_id': 714271603, 'shopid': 23070969, 'st...  True
# 14  {'item_id': 714246430, 'shopid': 23070969, 'st...  True
# 15  {'item_id': 714246482, 'shopid': 23070969, 'st...  True
# 16  {'item_id': 714246479, 'shopid': 23070969, 'st...  True
# 17  {'item_id': 714246443, 'shopid': 23070969, 'st...  True
# 18  {'item_id': 288208978, 'shopid': 23070969, 'st...  True
# 19  {'item_id': 714246468, 'shopid': 23070969, 'st...  True
# 20  {'item_id': 714246461, 'shopid': 23070969, 'st...  True
# 21  {'item_id': 714246503, 'shopid': 23070969, 'st...  True
# 22  {'item_id': 714246499, 'shopid': 23070969, 'st...  True
# 23  {'item_id': 289817750, 'shopid': 23070969, 'st...  True
# 24  {'item_id': 289815382, 'shopid': 23070969, 'st...  True
# 25  {'item_id': 289819286, 'shopid': 23070969, 'st...  True
# 26  {'item_id': 289817813, 'shopid': 23070969, 'st...  True
# 27  {'item_id': 692636406, 'shopid': 23070969, 'st...  True
# 28  {'item_id': 714255091, 'shopid': 23070969, 'st...  True
# 29  {'item_id': 714255768, 'shopid': 23070969, 'st...  True
# ..                                                ...   ...
# 70  {'item_id': 714265848, 'shopid': 23070969, 'st...  True
# 71  {'item_id': 692636422, 'shopid': 23070969, 'st...  True
# 72  {'item_id': 714264913, 'shopid': 23070969, 'st...  True
# 73  {'item_id': 714264459, 'shopid': 23070969, 'st...  True
# 74  {'item_id': 692636423, 'shopid': 23070969, 'st...  True
# 75  {'item_id': 714265338, 'shopid': 23070969, 'st...  True
# 76  {'item_id': 692636419, 'shopid': 23070969, 'st...  True
# 77  {'item_id': 714267005, 'shopid': 23070969, 'st...  True
# 78  {'item_id': 692636407, 'shopid': 23070969, 'st...  True
# 79  {'item_id': 714268309, 'shopid': 23070969, 'st...  True
# 80  {'item_id': 714268772, 'shopid': 23070969, 'st...  True
# 81  {'item_id': 692636400, 'shopid': 23070969, 'st...  True
# 82  {'item_id': 692636405, 'shopid': 23070969, 'st...  True
# 83  {'item_id': 714246365, 'shopid': 23070969, 'st...  True
# 84  {'item_id': 714269270, 'shopid': 23070969, 'st...  True
# 85  {'item_id': 714246408, 'shopid': 23070969, 'st...  True
# 86  {'item_id': 714269818, 'shopid': 23070969, 'st...  True
# 87  {'item_id': 714246402, 'shopid': 23070969, 'st...  True
# 88  {'item_id': 714270605, 'shopid': 23070969, 'st...  True
# 89  {'item_id': 714246429, 'shopid': 23070969, 'st...  True
# 90  {'item_id': 714246472, 'shopid': 23070969, 'st...  True
# 91  {'item_id': 692636396, 'shopid': 23070969, 'st...  True
# 92  {'item_id': 714246361, 'shopid': 23070969, 'st...  True
# 93  {'item_id': 714264130, 'shopid': 23070969, 'st...  True
# 94  {'item_id': 714246413, 'shopid': 23070969, 'st...  True
# 95  {'item_id': 692636377, 'shopid': 23070969, 'st...  True
# 96  {'item_id': 714246405, 'shopid': 23070969, 'st...  True
# 97  {'item_id': 692636409, 'shopid': 23070969, 'st...  True
# 98  {'item_id': 714271171, 'shopid': 23070969, 'st...  True
# 99  {'item_id': 289819304, 'shopid': 23070969, 'st...  True
#
# [100 rows x 2 columns]

# %%
# 漂亮打印Json
item_list = json_normalize(parsed['items'])
item_list
# Out:
#       item_id    shopid  status  update_time
# 0   289819285  23070969  NORMAL   1516585612
# 1   289817722  23070969  NORMAL   1516585582
# 2   692636384  23070969  NORMAL   1516585552
# 3   692636435  23070969  NORMAL   1516585521
# 4   692636375  23070969  NORMAL   1516585491
# 5   714246437  23070969  NORMAL   1516585461
# 6   714258341  23070969  NORMAL   1516585431
# 7   714246435  23070969  NORMAL   1516585401
# 8   289817643  23070969  NORMAL   1516585370
# 9   714259335  23070969  NORMAL   1516585340
# 10  714246434  23070969  NORMAL   1516585310
# 11  714259330  23070969  NORMAL   1516585280
# 12  714246433  23070969  NORMAL   1516585249
# 13  714271603  23070969  NORMAL   1516585219
# 14  714246430  23070969  NORMAL   1516585189
# 15  714246482  23070969  NORMAL   1516585159
# 16  714246479  23070969  NORMAL   1516585128
# 17  714246443  23070969  NORMAL   1516585095
# 18  288208978  23070969  NORMAL   1516585065
# 19  714246468  23070969  NORMAL   1516585035
# 20  714246461  23070969  NORMAL   1516585005
# 21  714246503  23070969  NORMAL   1516584974
# 22  714246499  23070969  NORMAL   1516584944
# 23  289817750  23070969  NORMAL   1516584914
# 24  289815382  23070969  NORMAL   1516584883
# 25  289819286  23070969  NORMAL   1516584853
# 26  289817813  23070969  NORMAL   1516584823
# 27  692636406  23070969  NORMAL   1516584793
# 28  714255091  23070969  NORMAL   1516584763
# 29  714255768  23070969  NORMAL   1516584732
# ..        ...       ...     ...          ...
# 70  714265848  23070969  NORMAL   1516583492
# 71  692636422  23070969  NORMAL   1516583462
# 72  714264913  23070969  NORMAL   1516583432
# 73  714264459  23070969  NORMAL   1516583401
# 74  692636423  23070969  NORMAL   1516583371
# 75  714265338  23070969  NORMAL   1516583341
# 76  692636419  23070969  NORMAL   1516583311
# 77  714267005  23070969  NORMAL   1516583280
# 78  692636407  23070969  NORMAL   1516583250
# 79  714268309  23070969  NORMAL   1516583220
# 80  714268772  23070969  NORMAL   1516583190
# 81  692636400  23070969  NORMAL   1516583160
# 82  692636405  23070969  NORMAL   1516583129
# 83  714246365  23070969  NORMAL   1516583099
# 84  714269270  23070969  NORMAL   1516583069
# 85  714246408  23070969  NORMAL   1516583039
# 86  714269818  23070969  NORMAL   1516583009
# 87  714246402  23070969  NORMAL   1516582979
# 88  714270605  23070969  NORMAL   1516582948
# 89  714246429  23070969  NORMAL   1516582918
# 90  714246472  23070969  NORMAL   1516582888
# 91  692636396  23070969  NORMAL   1516582858
# 92  714246361  23070969  NORMAL   1516582827
# 93  714264130  23070969  NORMAL   1516582797
# 94  714246413  23070969  NORMAL   1516582767
# 95  692636377  23070969  NORMAL   1516582737
# 96  714246405  23070969  NORMAL   1516582707
# 97  692636409  23070969  NORMAL   1516582677
# 98  714271171  23070969  NORMAL   1516582646
# 99  289819304  23070969  NORMAL   1516582616
#
# [100 rows x 4 columns]

# %%
# 获取商品库存
item_detail_url = 'https://partner.shopeemobile.com/api/v1/items/update_stock'

# %%
# 参数
stock = 1001
# 表
product_list = json_normalize(parsed['items'])
product_list.dtypes
# Out:
# item_id         int64
# shopid          int64
# status         object
# update_time     int64
# dtype: object

# %%
'''
payload = {"partner_id":partner_id,
               "shopid":shopid,
               "timestamp":timestamp,
               "item_id":int(item_id),
               "stock":stock}
print(json.dumps(payload))
'''
# Out:
# '\npayload = {"partner_id":partner_id,\n               "shopid":shopid,\n               "timestamp":timestamp,\n               "item_id":int(item_id),\n               "stock":stock}\nprint(json.dumps(payload))\n'

# %%
# 无限循环
i = 1
while True:
    if i % 2==0:
        stock = 1000
    else:
        stock = 1001
        
    print("Now run the " + str(i) + " time.")
        
    # 历遍
    for item_id in product_list['item_id']:

        timestamp = int(time.time())
        
        payload = {"partner_id":partner_id,
                   "shopid":shopid,
                   "timestamp":timestamp,
                   "item_id":int(item_id),
                   "stock":stock}

        # print(json.dumps(payload))

        Auth_signature = get_auth_signature(item_detail_url, payload)
        # HTML Header

        headers = {"Host": "partner.shopeemobile.com",
                    "Content-Type": "application/json",
                    "Content-Length": "89",
                    "Authorization": Auth_signature}
        # HTML Body
        payload = json.dumps(payload)
        # Post Request
        r = None
        try_time = 0
        
        while r is None:
            try:
                r = requests.post(item_detail_url, data=payload, headers=headers)
            except Exception as err:
                try_time += 1
                print('An exception happened: ' + str(err) + ", post fails. Try again. Try " + str(try_time) + " time.")
                pass
            
        print(r.text)
        # Notice
        print(str(item_id) + ' stock updated.')
        time.sleep(30)
        
    i = i + 1
# Out:
# Now run the 1 time.
# {"item":{"item_id":289819285,"modified_time":1516591441}}
# 289819285 stock updated.
# {"item":{"item_id":289817722,"modified_time":1516591471}}
# 289817722 stock updated.
# {"item":{"item_id":692636384,"modified_time":1516591501}}
# 692636384 stock updated.
# {"item":{"item_id":692636435,"modified_time":1516591531}}
# 692636435 stock updated.
# {"item":{"item_id":692636375,"modified_time":1516591561}}
# 692636375 stock updated.
# {"item":{"item_id":714246437,"modified_time":1516591592}}
# 714246437 stock updated.
# {"item":{"item_id":714258341,"modified_time":1516591622}}
# 714258341 stock updated.
# {"item":{"item_id":714246435,"modified_time":1516591652}}
# 714246435 stock updated.
# {"item":{"item_id":289817643,"modified_time":1516591683}}
# 289817643 stock updated.
# {"item":{"item_id":714259335,"modified_time":1516591713}}
# 714259335 stock updated.
# {"item":{"item_id":714246434,"modified_time":1516591743}}
# 714246434 stock updated.
# {"item":{"item_id":714259330,"modified_time":1516591773}}
# 714259330 stock updated.
# {"item":{"item_id":714246433,"modified_time":1516591803}}
# 714246433 stock updated.
# {"item":{"item_id":714271603,"modified_time":1516591833}}
# 714271603 stock updated.
# {"item":{"item_id":714246430,"modified_time":1516591864}}
# 714246430 stock updated.
# {"item":{"item_id":714246482,"modified_time":1516591894}}
# 714246482 stock updated.
# {"item":{"item_id":714246479,"modified_time":1516591924}}
# 714246479 stock updated.
# {"item":{"item_id":714246443,"modified_time":1516591954}}
# 714246443 stock updated.
# {"item":{"item_id":288208978,"modified_time":1516591984}}
# 288208978 stock updated.
# {"item":{"item_id":714246468,"modified_time":1516592015}}
# 714246468 stock updated.
# {"item":{"item_id":714246461,"modified_time":1516592045}}
# 714246461 stock updated.
# {"item":{"item_id":714246503,"modified_time":1516592075}}
# 714246503 stock updated.
# {"item":{"item_id":714246499,"modified_time":1516592106}}
# 714246499 stock updated.
# {"item":{"item_id":289817750,"modified_time":1516592136}}
# 289817750 stock updated.
# {"item":{"item_id":289815382,"modified_time":1516592166}}
# 289815382 stock updated.
# {"item":{"item_id":289819286,"modified_time":1516592197}}
# 289819286 stock updated.
# {"item":{"item_id":289817813,"modified_time":1516592227}}
# 289817813 stock updated.
# {"item":{"item_id":692636406,"modified_time":1516592257}}
# 692636406 stock updated.
# {"item":{"item_id":714255091,"modified_time":1516592288}}
# 714246402 stock updated.
# {"item":{"item_id":714270605,"modified_time":1516597130}}
# 714270605 stock updated.
# {"item":{"item_id":714246429,"modified_time":1516597160}}
# 714246429 stock updated.
# {"item":{"item_id":714246472,"modified_time":1516597190}}
# 714246472 stock updated.
# {"item":{"item_id":692636396,"modified_time":1516597220}}
# 692636396 stock updated.
# {"item":{"item_id":714246361,"modified_time":1516597251}}
# 714246361 stock updated.
# {"item":{"item_id":714264130,"modified_time":1516597281}}
# 714264130 stock updated.
# {"item":{"item_id":714246413,"modified_time":1516597311}}
# 714246413 stock updated.
# {"item":{"item_id":692636377,"modified_time":1516597341}}
# 692636377 stock updated.
# {"item":{"item_id":714246405,"modified_time":1516597371}}
# 714246405 stock updated.
# {"item":{"item_id":692636409,"modified_time":1516597401}}
# 692636409 stock updated.
# {"item":{"item_id":714271171,"modified_time":1516597432}}
# 714271171 stock updated.
# {"item":{"item_id":289819304,"modified_time":1516597462}}
# 289819304 stock updated.
# Now run the 3 time.
# {"item":{"item_id":289819285,"modified_time":1516597492}}
# 289819285 stock updated.
# {"item":{"item_id":289817722,"modified_time":1516597522}}
# 289817722 stock updated.
# {"item":{"item_id":692636384,"modified_time":1516597552}}
# 692636384 stock updated.
# {"item":{"item_id":692636435,"modified_time":1516597582}}
# 692636435 stock updated.
# {"item":{"item_id":692636375,"modified_time":1516597613}}
# 692636375 stock updated.
# {"item":{"item_id":714246437,"modified_time":1516597643}}
# 714246437 stock updated.
# {"item":{"item_id":714258341,"modified_time":1516597673}}
# 714258341 stock updated.
# {"item":{"item_id":714246435,"modified_time":1516597703}}
# 714246435 stock updated.
# {"item":{"item_id":289817643,"modified_time":1516597733}}
# 289817643 stock updated.
# {"item":{"item_id":714259335,"modified_time":1516597764}}
# 714259335 stock updated.
# {"item":{"item_id":714246434,"modified_time":1516597794}}
# 714246434 stock updated.
# {"item":{"item_id":714259330,"modified_time":1516597824}}
# 714259330 stock updated.
# {"item":{"item_id":714246433,"modified_time":1516597854}}
# 714246433 stock updated.
# {"item":{"item_id":714271603,"modified_time":1516597884}}
# 714271603 stock updated.
# {"item":{"item_id":714246430,"modified_time":1516597914}}
# 714246430 stock updated.
# {"item":{"item_id":714246482,"modified_time":1516597954}}
# 714246482 stock updated.
# {"item":{"item_id":714246479,"modified_time":1516597984}}
# 714246479 stock updated.
# {"item":{"item_id":714246443,"modified_time":1516598014}}
# 714246443 stock updated.
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     146             raise NewConnectionError(
# --> 147                 self, "Failed to establish a new connection: %s" % e)
#     148
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x00000214681EA588>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     362         if new_retry.is_exhausted():
# --> 363             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     364
#
# MaxRetryError: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/items/update_stock (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x00000214681EA588>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-18-8405a706cb1c> in <module>()
#      32         payload = json.dumps(payload)
#      33         # Post Request
# ---> 34         r = requests.post(item_detail_url, data=payload, headers=headers)
#      35         print(r.text)
#      36         # Notice
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     108     """
#     109
# --> 110     return request('post', url, data=data, json=json, **kwargs)
#     111
#     112
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/items/update_stock (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x00000214681EA588>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
