# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy

# %%
# Current time stamp
timestamp = int(time.time())

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
# Shop Parameter
partner_id = 12156
shopid = 25482220
shop_key = '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'

# %%
# get_auth_signature
def get_auth_signature(url, payload):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# Get Item List URL
get_item_list_url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# Parameter
pagination_offset = 0
pagination_entries_per_page = 100

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "pagination_offset":pagination_offset,
           "pagination_entries_per_page":pagination_entries_per_page}
print(payload)
# Out:
# {'partner_id': 12156, 'shopid': 25482220, 'timestamp': 1511512006, 'pagination_offset': 0, 'pagination_entries_per_page': 100}

# %%
# Auth Signature
Auth_signature = get_auth_signature(get_item_list_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(get_item_list_url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                 items  more
# 0   {'item_id': 624854737, 'shopid': 25482220, 'st...  True
# 1   {'item_id': 622681961, 'shopid': 25482220, 'st...  True
# 2   {'item_id': 622681974, 'shopid': 25482220, 'st...  True
# 3   {'item_id': 624854784, 'shopid': 25482220, 'st...  True
# 4   {'item_id': 675681678, 'shopid': 25482220, 'st...  True
# 5   {'item_id': 624856255, 'shopid': 25482220, 'st...  True
# 6   {'item_id': 624854606, 'shopid': 25482220, 'st...  True
# 7   {'item_id': 709686157, 'shopid': 25482220, 'st...  True
# 8   {'item_id': 624703578, 'shopid': 25482220, 'st...  True
# 9   {'item_id': 624703581, 'shopid': 25482220, 'st...  True
# 10  {'item_id': 624856239, 'shopid': 25482220, 'st...  True
# 11  {'item_id': 661259703, 'shopid': 25482220, 'st...  True
# 12  {'item_id': 661250231, 'shopid': 25482220, 'st...  True
# 13  {'item_id': 661232215, 'shopid': 25482220, 'st...  True
# 14  {'item_id': 624854668, 'shopid': 25482220, 'st...  True
# 15  {'item_id': 657172500, 'shopid': 25482220, 'st...  True
# 16  {'item_id': 657165235, 'shopid': 25482220, 'st...  True
# 17  {'item_id': 657157986, 'shopid': 25482220, 'st...  True
# 18  {'item_id': 649033416, 'shopid': 25482220, 'st...  True
# 19  {'item_id': 624699951, 'shopid': 25482220, 'st...  True
# 20  {'item_id': 624703582, 'shopid': 25482220, 'st...  True
# 21  {'item_id': 624854605, 'shopid': 25482220, 'st...  True
# 22  {'item_id': 622667141, 'shopid': 25482220, 'st...  True
# 23  {'item_id': 622667149, 'shopid': 25482220, 'st...  True
# 24  {'item_id': 622667142, 'shopid': 25482220, 'st...  True
# 25  {'item_id': 648913990, 'shopid': 25482220, 'st...  True
# 26  {'item_id': 648875242, 'shopid': 25482220, 'st...  True
# 27  {'item_id': 624856291, 'shopid': 25482220, 'st...  True
# 28  {'item_id': 624856292, 'shopid': 25482220, 'st...  True
# 29  {'item_id': 624856274, 'shopid': 25482220, 'st...  True
# ..                                                ...   ...
# 70  {'item_id': 624767283, 'shopid': 25482220, 'st...  True
# 71  {'item_id': 624767279, 'shopid': 25482220, 'st...  True
# 72  {'item_id': 622743512, 'shopid': 25482220, 'st...  True
# 73  {'item_id': 622677405, 'shopid': 25482220, 'st...  True
# 74  {'item_id': 622677398, 'shopid': 25482220, 'st...  True
# 75  {'item_id': 622677393, 'shopid': 25482220, 'st...  True
# 76  {'item_id': 622677399, 'shopid': 25482220, 'st...  True
# 77  {'item_id': 622677368, 'shopid': 25482220, 'st...  True
# 78  {'item_id': 622677367, 'shopid': 25482220, 'st...  True
# 79  {'item_id': 622667130, 'shopid': 25482220, 'st...  True
# 80  {'item_id': 622667125, 'shopid': 25482220, 'st...  True
# 81  {'item_id': 618446328, 'shopid': 25482220, 'st...  True
# 82  {'item_id': 619000103, 'shopid': 25482220, 'st...  True
# 83  {'item_id': 619000110, 'shopid': 25482220, 'st...  True
# 84  {'item_id': 619000231, 'shopid': 25482220, 'st...  True
# 85  {'item_id': 619000233, 'shopid': 25482220, 'st...  True
# 86  {'item_id': 698481812, 'shopid': 25482220, 'st...  True
# 87  {'item_id': 660855872, 'shopid': 25482220, 'st...  True
# 88  {'item_id': 660844415, 'shopid': 25482220, 'st...  True
# 89  {'item_id': 660832220, 'shopid': 25482220, 'st...  True
# 90  {'item_id': 622681929, 'shopid': 25482220, 'st...  True
# 91  {'item_id': 622681935, 'shopid': 25482220, 'st...  True
# 92  {'item_id': 622681936, 'shopid': 25482220, 'st...  True
# 93  {'item_id': 624851745, 'shopid': 25482220, 'st...  True
# 94  {'item_id': 675661325, 'shopid': 25482220, 'st...  True
# 95  {'item_id': 624703548, 'shopid': 25482220, 'st...  True
# 96  {'item_id': 624700099, 'shopid': 25482220, 'st...  True
# 97  {'item_id': 622780052, 'shopid': 25482220, 'st...  True
# 98  {'item_id': 675668333, 'shopid': 25482220, 'st...  True
# 99  {'item_id': 624703563, 'shopid': 25482220, 'st...  True
#
# [100 rows x 2 columns]

# %%
# 漂亮打印Json
item_list = json_normalize(parsed['items'])
item_list
# Out:
#       item_id    shopid  status
# 0   624854737  25482220  NORMAL
# 1   622681961  25482220  NORMAL
# 2   622681974  25482220  NORMAL
# 3   624854784  25482220  NORMAL
# 4   675681678  25482220  NORMAL
# 5   624856255  25482220  NORMAL
# 6   624854606  25482220  NORMAL
# 7   709686157  25482220  NORMAL
# 8   624703578  25482220  NORMAL
# 9   624703581  25482220  NORMAL
# 10  624856239  25482220  NORMAL
# 11  661259703  25482220  NORMAL
# 12  661250231  25482220  NORMAL
# 13  661232215  25482220  NORMAL
# 14  624854668  25482220  NORMAL
# 15  657172500  25482220  NORMAL
# 16  657165235  25482220  NORMAL
# 17  657157986  25482220  NORMAL
# 18  649033416  25482220  NORMAL
# 19  624699951  25482220  NORMAL
# 20  624703582  25482220  NORMAL
# 21  624854605  25482220  NORMAL
# 22  622667141  25482220  NORMAL
# 23  622667149  25482220  NORMAL
# 24  622667142  25482220  NORMAL
# 25  648913990  25482220  NORMAL
# 26  648875242  25482220  NORMAL
# 27  624856291  25482220  NORMAL
# 28  624856292  25482220  NORMAL
# 29  624856274  25482220  NORMAL
# ..        ...       ...     ...
# 70  624767283  25482220  NORMAL
# 71  624767279  25482220  NORMAL
# 72  622743512  25482220  NORMAL
# 73  622677405  25482220  NORMAL
# 74  622677398  25482220  NORMAL
# 75  622677393  25482220  NORMAL
# 76  622677399  25482220  NORMAL
# 77  622677368  25482220  NORMAL
# 78  622677367  25482220  NORMAL
# 79  622667130  25482220  NORMAL
# 80  622667125  25482220  NORMAL
# 81  618446328  25482220  NORMAL
# 82  619000103  25482220  NORMAL
# 83  619000110  25482220  NORMAL
# 84  619000231  25482220  NORMAL
# 85  619000233  25482220  NORMAL
# 86  698481812  25482220  NORMAL
# 87  660855872  25482220  NORMAL
# 88  660844415  25482220  NORMAL
# 89  660832220  25482220  NORMAL
# 90  622681929  25482220  NORMAL
# 91  622681935  25482220  NORMAL
# 92  622681936  25482220  NORMAL
# 93  624851745  25482220  NORMAL
# 94  675661325  25482220  NORMAL
# 95  624703548  25482220  NORMAL
# 96  624700099  25482220  NORMAL
# 97  622780052  25482220  NORMAL
# 98  675668333  25482220  NORMAL
# 99  624703563  25482220  NORMAL
#
# [100 rows x 3 columns]

# %%
# 测试update variation stock
# Get Item Detail URL
get_item_detail_url = 'https://partner.shopeemobile.com/api/v1/item/get'

# %%
# Parameter
item_id = 698626249

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "item_id":item_id}
print(payload)
# Out:
# {'partner_id': 12156, 'shopid': 25482220, 'timestamp': 1511512006, 'item_id': 698626249}

# %%
# Auth Signature
Auth_signature = get_auth_signature(get_item_detail_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(get_item_detail_url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                             item
# attributes     [{'attribute_id': 8319, 'attribute_name': '適用年...
# category_id                                                 8308
# create_time                                           1511159953
# currency                                                     TWD
# description    現貨供應，品質保證\n廣東小富蘭克婦幼用品有限公司是一家集研發、生產和銷售為一體的專業婦嬰企...
# has_variation                                               True
# images         [http://f.shopee.tw/file/5d4fc0f8d5e64f8c91789...
# item_id                                                698626249
# item_sku                                               3163-3164
# name                  嬰幼兒裝長袖 長版上衣  秋冬打底內衣套裝 純棉保暖睡衣  男童女童家居服 1-5歲
# price                                                        249
# shopid                                                  25482220
# status                                                    NORMAL
# stock                                                         90
# update_time                                           1511494604
# variations     [{'create_time': 1511159953, 'name': '藍色73cm',...
# weight                                                       0.1

# %%
item_data_frame = json_normalize(parsed['item'])
item_data_frame = item_data_frame[['item_id', 'variations']]
item_data_frame
# Out:
#      item_id                                         variations
# 0  698626249  [{'status': 'MODEL_NORMAL', 'update_time': 151...

# %%
item_data_frame_json = item_data_frame.to_json(orient='records')
item_data_frame_json
json.loads(item_data_frame_json)
# Out:
# [{'item_id': 698626249,
#   'variations': [{'create_time': 1511159953,
#     'name': '藍色73cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494089,
#     'variation_id': 545993431,
#     'variation_sku': '3163-藍色73cm'},
#    {'create_time': 1511159953,
#     'name': '藍色80cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494119,
#     'variation_id': 545993432,
#     'variation_sku': '3163-藍色80cm'},
#    {'create_time': 1511159953,
#     'name': '藍色90cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494149,
#     'variation_id': 545993433,
#     'variation_sku': '3163-藍色90cm'},
#    {'create_time': 1511159953,
#     'name': '藍色100cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494180,
#     'variation_id': 545993434,
#     'variation_sku': '3164-藍色100cm'},
#    {'create_time': 1511159953,
#     'name': '藍色110cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494210,
#     'variation_id': 545993435,
#     'variation_sku': '3164-藍色110cm'},
#    {'create_time': 1511159953,
#     'name': '藍色120cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494240,
#     'variation_id': 545993436,
#     'variation_sku': '3164-藍色120cm'},
#    {'create_time': 1511159953,
#     'name': '黃色73cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494271,
#     'variation_id': 545993437,
#     'variation_sku': '3163-黃色73cm'},
#    {'create_time': 1511159953,
#     'name': '黃色80cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494301,
#     'variation_id': 545993438,
#     'variation_sku': '3163-黃色80cm'},
#    {'create_time': 1511159953,
#     'name': '黃色90cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494331,
#     'variation_id': 545993439,
#     'variation_sku': '3163-黃色90cm'},
#    {'create_time': 1511159953,
#     'name': '黃色100cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494362,
#     'variation_id': 545993440,
#     'variation_sku': '3164-黃色100cm'},
#    {'create_time': 1511159953,
#     'name': '黃色110cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494392,
#     'variation_id': 545993441,
#     'variation_sku': '3164-黃色110cm'},
#    {'create_time': 1511159953,
#     'name': '黃色120cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494422,
#     'variation_id': 545993442,
#     'variation_sku': '3164-黃色120cm'},
#    {'create_time': 1511159953,
#     'name': '紅色73cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494453,
#     'variation_id': 545993443,
#     'variation_sku': '3163-紅色73cm'},
#    {'create_time': 1511159953,
#     'name': '紅色80cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494483,
#     'variation_id': 545993444,
#     'variation_sku': '3163-紅色80cm'},
#    {'create_time': 1511159953,
#     'name': '紅色90cm',
#     'price': 249.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494513,
#     'variation_id': 545993445,
#     'variation_sku': '3163-紅色90cm'},
#    {'create_time': 1511159953,
#     'name': '紅色100cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494543,
#     'variation_id': 545993446,
#     'variation_sku': '3164-紅色100cm'},
#    {'create_time': 1511159953,
#     'name': '紅色110cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494573,
#     'variation_id': 545993447,
#     'variation_sku': '3164-紅色110cm'},
#    {'create_time': 1511159953,
#     'name': '紅色120cm',
#     'price': 299.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1511494604,
#     'variation_id': 545993448,
#     'variation_sku': '3164-紅色120cm'}]}]

# %%
final_item_data_frame = json_normalize(json.loads(item_data_frame_json),record_path='variations',meta=['item_id'])
final_item_data_frame
# Out:
#     create_time     name  price        status  stock  update_time  \
# 0    1511159953   藍色73cm  249.0  MODEL_NORMAL      5   1511494089
# 1    1511159953   藍色80cm  249.0  MODEL_NORMAL      5   1511494119
# 2    1511159953   藍色90cm  249.0  MODEL_NORMAL      5   1511494149
# 3    1511159953  藍色100cm  299.0  MODEL_NORMAL      5   1511494180
# 4    1511159953  藍色110cm  299.0  MODEL_NORMAL      5   1511494210
# 5    1511159953  藍色120cm  299.0  MODEL_NORMAL      5   1511494240
# 6    1511159953   黃色73cm  249.0  MODEL_NORMAL      5   1511494271
# 7    1511159953   黃色80cm  249.0  MODEL_NORMAL      5   1511494301
# 8    1511159953   黃色90cm  249.0  MODEL_NORMAL      5   1511494331
# 9    1511159953  黃色100cm  299.0  MODEL_NORMAL      5   1511494362
# 10   1511159953  黃色110cm  299.0  MODEL_NORMAL      5   1511494392
# 11   1511159953  黃色120cm  299.0  MODEL_NORMAL      5   1511494422
# 12   1511159953   紅色73cm  249.0  MODEL_NORMAL      5   1511494453
# 13   1511159953   紅色80cm  249.0  MODEL_NORMAL      5   1511494483
# 14   1511159953   紅色90cm  249.0  MODEL_NORMAL      5   1511494513
# 15   1511159953  紅色100cm  299.0  MODEL_NORMAL      5   1511494543
# 16   1511159953  紅色110cm  299.0  MODEL_NORMAL      5   1511494573
# 17   1511159953  紅色120cm  299.0  MODEL_NORMAL      5   1511494604
#
#     variation_id variation_sku    item_id
# 0      545993431   3163-藍色73cm  698626249
# 1      545993432   3163-藍色80cm  698626249
# 2      545993433   3163-藍色90cm  698626249
# 3      545993434  3164-藍色100cm  698626249
# 4      545993435  3164-藍色110cm  698626249
# 5      545993436  3164-藍色120cm  698626249
# 6      545993437   3163-黃色73cm  698626249
# 7      545993438   3163-黃色80cm  698626249
# 8      545993439   3163-黃色90cm  698626249
# 9      545993440  3164-黃色100cm  698626249
# 10     545993441  3164-黃色110cm  698626249
# 11     545993442  3164-黃色120cm  698626249
# 12     545993443   3163-紅色73cm  698626249
# 13     545993444   3163-紅色80cm  698626249
# 14     545993445   3163-紅色90cm  698626249
# 15     545993446  3164-紅色100cm  698626249
# 16     545993447  3164-紅色110cm  698626249
# 17     545993448  3164-紅色120cm  698626249

# %%
# update variation stock url
update_variation_stock_url = 'https://partner.shopeemobile.com/api/v1/items/update_variation_stock'

# %%
# Parameter
item_id = 698626249
variation_id = 545993431
stock_to_update = 9

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "item_id":item_id,
           "variation_id":variation_id,
           "stock":stock_to_update}
print(payload)
# Out:
# {'partner_id': 12156, 'shopid': 25482220, 'timestamp': 1511512006, 'item_id': 698626249, 'variation_id': 545993431, 'stock': 9}

# %%
# Auth Signature
Auth_signature = get_auth_signature(update_variation_stock_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
# r = requests.post(update_variation_stock_url, data=payload, headers=headers)
# r.text

# %%
# 正式批量修改variation
# 有限循环，避免更新不完整跳出，更新1000次
i = 1
while True:
    if i % 2==0:
        stock_add = 1
    else:
        stock_add = -1
    
    if i == 1000:
        break
    
    print("Now run the " + str(i) + " time.")

    for item_id in item_list['item_id']:
        # Get Item Detail URL
        get_item_detail_url = 'https://partner.shopeemobile.com/api/v1/item/get'
        # Current time stamp
        timestamp = int(time.time())
        # payload
        payload = {"partner_id":partner_id,
                   "shopid":shopid,
                   "timestamp":timestamp,
                   "item_id":int(item_id)}
        # Auth Signature
        Auth_signature = get_auth_signature(get_item_detail_url, payload)
        # HTML Header
        headers = {"Host": "partner.shopeemobile.com",
                    "Content-Type": "application/json",
                    "Content-Length": "89",
                    "Authorization": Auth_signature}
        # HTML Body
        payload = json.dumps(payload)
        # Post Request
        r = requests.post(get_item_detail_url, data=payload, headers=headers)
        # 打印原始Json
        parsed = json.loads(r.text)
        result = json.dumps(parsed, indent=4, sort_keys=True)
        # Try是否有Varation，如果没有就跳过
        try:
            # 列出variation
            item_data_frame = json_normalize(parsed['item'])
            item_data_frame = item_data_frame[['item_id', 'variations']]
            # variation to json，列出item_id
            item_data_frame_json = item_data_frame.to_json(orient='records')
            # final variation data frame，列出含item_id的variation列表
            final_item_data_frame = json_normalize(json.loads(item_data_frame_json),record_path='variations',meta=['item_id'])

            # update variation stock url
            update_variation_stock_url = 'https://partner.shopeemobile.com/api/v1/items/update_variation_stock'

            # 找出每一个variation id，进行update variation stock
            for variation_id, variation_stock in zip(final_item_data_frame['variation_id'], final_item_data_frame['stock']):
                # Current time stamp
                timestamp = int(time.time())

                # 判断原有stock的大小，如果小于5的话，直接更改为10
                if int(variation_stock) < 5:
                    variation_stock = 10

                # payload
                payload = {"partner_id":partner_id,
                           "shopid":shopid,
                           "timestamp":timestamp,
                           "item_id":int(item_id),
                           "variation_id":int(variation_id),
                           "stock":int(variation_stock) + stock_add}
                # Auth Signature
                Auth_signature = get_auth_signature(update_variation_stock_url, payload)
                # HTML Header
                headers = {"Host": "partner.shopeemobile.com",
                            "Content-Type": "application/json",
                            "Content-Length": "89",
                            "Authorization": Auth_signature}
                # HTML Body
                payload = json.dumps(payload)
                # Post Request
                r = requests.post(update_variation_stock_url, data=payload, headers=headers)
                print(r.text)
                # Notice
                print(str(item_id) + ', ' + str(variation_id) + ' stock updated to ' + str(int(variation_stock) + stock_add))
                time.sleep(30)
        except Exception as err:
            print('An exception occured: ' + str(err))
            
    i = i + 1
# Out:
# Now run the 1 time.
# {"item":{"item_id":624854737,"variation_id":466337409,"modified_time":1511512044}}
# 624854737, 466337409 stock updated to 4
# {"item":{"item_id":624854737,"variation_id":466337411,"modified_time":1511512075}}
# 624854737, 466337411 stock updated to 4
# {"item":{"item_id":624854737,"variation_id":466337413,"modified_time":1511512105}}
# 624854737, 466337413 stock updated to 4
# {"item":{"item_id":624854737,"variation_id":466337415,"modified_time":1511512135}}
# 624854737, 466337415 stock updated to 4
# {"item":{"item_id":624854737,"variation_id":466337417,"modified_time":1511512165}}
# 624854737, 466337417 stock updated to 4
