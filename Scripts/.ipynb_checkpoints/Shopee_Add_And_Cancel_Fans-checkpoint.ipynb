# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
# 屏幕最大化，且指定下载目录
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

prefs = {"profile.default_content_settings.popups": 0,
         "directory_upgrade": True}
options.add_experimental_option("prefs", prefs)

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
# main page
main_page_url = "http://shopee.co.id"
browser.get(main_page_url)

# remove ads, refresh again
browser.get(main_page_url)
time.sleep(10)

# %%
# login
LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
'''
有关Selenium Compound class names not permitted的错误
可以参考https://stackoverflow.com/questions/37771604/selenium-compound-class-names-not-permitted
使用css_selector解决即可
'''
# 点击登入，弹出账户密码输入框
LoginElem[1].click()
time.sleep(10)

# %%
acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
try:
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('tengus.id')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('tengus1803')
except:
    time.sleep(30)
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('tengus.id')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('tengus1803')
time.sleep(10)

# %%
Login_button_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
time.sleep(10)
Login_button_elem[1].click()

# %%
# change current tab size
browser.set_window_size(400, 862)

# %%
# switch to my fans list
my_fans_list_page = 'https://shopee.co.id/shop/59846508/following/?__classic__=1'
browser.get(my_fans_list_page)

# %%
# cancel certain number of following fans
to_cancel_num_of_following = 400
num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))

# page down until we get at least 400 fans to cancel
while num_of_following_display <= 500:
    body = browser.find_element_by_css_selector('body')
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(5)
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
# Out:
# 520

# %%
following_buttons = browser.find_elements_by_css_selector('.btn-follow.active.follow.L14')
# Out:
# 520

# %%
browser.maximize_window()
time.sleep(5)

# page up to the top
scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)

# %%
i = 0
total_cancel_num_of_following = to_cancel_num_of_following
while i <= total_cancel_num_of_following - 1:
    while to_cancel_num_of_following > 0:
        print('Now run the ' + str(i + 1) + ' time.')
        if following_buttons[i].text == '关注中':
            shopid = following_buttons[i].get_attribute('shopid')
            following_buttons[i].click()
            time.sleep(5)
            to_cancel_num_of_following -= 1
            i += 1
            print(str(shopid) + ' is not following now, ' + str(to_cancel_num_of_following) + ' following remains.')
# Out:
# Now run the 1 time.
# 808483 is not following now, 399 following remains.
# Now run the 2 time.
# 20713154 is not following now, 398 following remains.
# Now run the 3 time.
# 48566707 is not following now, 397 following remains.
# Now run the 4 time.
# 20469294 is not following now, 396 following remains.
# Now run the 5 time.
# 67847826 is not following now, 395 following remains.
# Now run the 6 time.
# 6079161 is not following now, 394 following remains.
# Now run the 7 time.
# 53128526 is not following now, 393 following remains.
# Now run the 8 time.
# 67907900 is not following now, 392 following remains.
# Now run the 9 time.
# 67838414 is not following now, 391 following remains.
# Now run the 10 time.
# 43735579 is not following now, 390 following remains.
# Now run the 11 time.
# 17591061 is not following now, 389 following remains.
# Now run the 12 time.
# 41298735 is not following now, 388 following remains.
# Now run the 13 time.
# 38303542 is not following now, 387 following remains.
# Now run the 14 time.
# 30314601 is not following now, 386 following remains.
# Now run the 15 time.
# 22168130 is not following now, 385 following remains.
# Now run the 16 time.
# 15289373 is not following now, 384 following remains.
# Now run the 17 time.
# 57558024 is not following now, 383 following remains.
# Now run the 18 time.
# 68000219 is not following now, 382 following remains.
# Now run the 19 time.
# 24628757 is not following now, 381 following remains.
# Now run the 20 time.
# 19759999 is not following now, 380 following remains.
# Now run the 21 time.
# 36893913 is not following now, 379 following remains.
# Now run the 22 time.
# 64032114 is not following now, 378 following remains.
# Now run the 23 time.
# 32790549 is not following now, 377 following remains.
# Now run the 24 time.
# 52732274 is not following now, 376 following remains.
# Now run the 25 time.
# 370081 is not following now, 375 following remains.
# Now run the 26 time.
# 31793582 is not following now, 374 following remains.
# Now run the 27 time.
# 65954188 is not following now, 373 following remains.
# Now run the 28 time.
# 56398270 is not following now, 372 following remains.
# Now run the 29 time.
# 28633337 is not following now, 371 following remains.
# Now run the 30 time.
# 41130276 is not following now, 370 following remains.
# Now run the 31 time.
# 56149878 is not following now, 369 following remains.
# Now run the 32 time.
# 20938795 is not following now, 368 following remains.
# Now run the 33 time.
# 17203821 is not following now, 367 following remains.
# Now run the 34 time.
# 11087190 is not following now, 366 following remains.
# Now run the 35 time.
# 19045298 is not following now, 365 following remains.
# Now run the 36 time.
# 60714549 is not following now, 364 following remains.
# Now run the 37 time.
# 54198038 is not following now, 363 following remains.
# Now run the 38 time.
# 9256007 is not following now, 362 following remains.
# Now run the 39 time.
# 18507492 is not following now, 361 following remains.
# Now run the 40 time.
# 66343449 is not following now, 360 following remains.
# Now run the 41 time.
# 67927903 is not following now, 359 following remains.
# Now run the 42 time.
# 44484198 is not following now, 358 following remains.
# Now run the 43 time.
# 66993408 is not following now, 357 following remains.
# Now run the 44 time.
# 64727622 is not following now, 356 following remains.
# Now run the 45 time.
# 23993893 is not following now, 355 following remains.
# Now run the 46 time.
# 20224462 is not following now, 354 following remains.
# Now run the 47 time.
# 67800270 is not following now, 353 following remains.
# Now run the 48 time.
# 64008375 is not following now, 352 following remains.
# Now run the 49 time.
# 20604521 is not following now, 351 following remains.
# Now run the 50 time.
# 60164651 is not following now, 350 following remains.
# Now run the 51 time.
# 47225654 is not following now, 349 following remains.
# Now run the 52 time.
# 60892271 is not following now, 348 following remains.
# Now run the 53 time.
# 68183733 is not following now, 347 following remains.
# Now run the 54 time.
# 38329577 is not following now, 346 following remains.
# Now run the 55 time.
# 20747541 is not following now, 345 following remains.
# Now run the 56 time.
# 35013516 is not following now, 344 following remains.
# Now run the 57 time.
# 36952211 is not following now, 343 following remains.
# Now run the 58 time.
# 50382812 is not following now, 342 following remains.
# Now run the 59 time.
# 18375475 is not following now, 341 following remains.
# Now run the 60 time.
# 27306926 is not following now, 340 following remains.
# Now run the 61 time.
# 60089130 is not following now, 339 following remains.
# Now run the 62 time.
# 64974900 is not following now, 338 following remains.
# Now run the 63 time.
# 13233993 is not following now, 337 following remains.
# Now run the 64 time.
# 24046033 is not following now, 336 following remains.
# Now run the 65 time.
# 18907111 is not following now, 335 following remains.
# Now run the 66 time.
# 62771709 is not following now, 334 following remains.
# Now run the 67 time.
# 1367635 is not following now, 333 following remains.
# Now run the 68 time.
# 34603090 is not following now, 332 following remains.
# Now run the 69 time.
# 59555559 is not following now, 331 following remains.
# Now run the 70 time.
# 9753252 is not following now, 330 following remains.
# Now run the 71 time.
# 34517392 is not following now, 329 following remains.
# Now run the 72 time.
# 67099470 is not following now, 328 following remains.
# Now run the 73 time.
# 5654267 is not following now, 327 following remains.
# Now run the 74 time.
# 65679273 is not following now, 326 following remains.
# Now run the 75 time.
# 67176364 is not following now, 325 following remains.
# Now run the 76 time.
# 66442038 is not following now, 324 following remains.
# Now run the 77 time.
# 7364412 is not following now, 323 following remains.
# Now run the 78 time.
# 43812382 is not following now, 322 following remains.
# Now run the 79 time.
# 25989514 is not following now, 321 following remains.
# Now run the 80 time.
# 65453440 is not following now, 320 following remains.
# Now run the 81 time.
# 42554338 is not following now, 319 following remains.
# Now run the 82 time.
# 36337575 is not following now, 318 following remains.
# Now run the 83 time.
# 37518184 is not following now, 317 following remains.
# Now run the 84 time.
# 59945925 is not following now, 316 following remains.
# Now run the 85 time.
# 62407589 is not following now, 315 following remains.
# Now run the 86 time.
# 66884587 is not following now, 314 following remains.
# Now run the 87 time.
# 38822562 is not following now, 313 following remains.
# Now run the 88 time.
# 61988905 is not following now, 312 following remains.
# Now run the 89 time.
# 68204198 is not following now, 311 following remains.
# Now run the 90 time.
# 2127500 is not following now, 310 following remains.
# Now run the 91 time.
# 42534082 is not following now, 309 following remains.
# Now run the 92 time.
# 66845770 is not following now, 308 following remains.
# Now run the 93 time.
# 52531917 is not following now, 307 following remains.
# Now run the 94 time.
# 14071927 is not following now, 306 following remains.
# Now run the 95 time.
# 8993615 is not following now, 305 following remains.
# Now run the 96 time.
# 9023819 is not following now, 304 following remains.
# Now run the 97 time.
# 66502915 is not following now, 303 following remains.
# Now run the 98 time.
# 66793704 is not following now, 302 following remains.
# Now run the 99 time.
# 23568876 is not following now, 301 following remains.
# Now run the 100 time.
# 55442613 is not following now, 300 following remains.
# Now run the 101 time.
# 2939559 is not following now, 299 following remains.
# Now run the 102 time.
# 40955422 is not following now, 298 following remains.
# Now run the 103 time.
# 17444443 is not following now, 297 following remains.
# Now run the 104 time.
# 45990529 is not following now, 296 following remains.
# Now run the 105 time.
# 67778187 is not following now, 295 following remains.
# Now run the 106 time.
# 13913854 is not following now, 294 following remains.
# Now run the 107 time.
# 22866978 is not following now, 293 following remains.
# Now run the 108 time.
# 68141764 is not following now, 292 following remains.
# Now run the 109 time.
# 42869015 is not following now, 291 following remains.
# Now run the 110 time.
# 57887804 is not following now, 290 following remains.
# Now run the 111 time.
# 22284061 is not following now, 289 following remains.
# Now run the 112 time.
# 60570217 is not following now, 288 following remains.
# Now run the 113 time.
# 56975613 is not following now, 287 following remains.
# Now run the 114 time.
# 46101454 is not following now, 286 following remains.
# Now run the 115 time.
# 63278243 is not following now, 285 following remains.
# Now run the 116 time.
# 21874650 is not following now, 284 following remains.
# Now run the 117 time.
# 50531800 is not following now, 283 following remains.
# Now run the 118 time.
# 18001336 is not following now, 282 following remains.
# Now run the 119 time.
# 13039664 is not following now, 281 following remains.
# Now run the 120 time.
# 40789892 is not following now, 280 following remains.
# Now run the 121 time.
# 40457416 is not following now, 279 following remains.
# Now run the 122 time.
# 41050693 is not following now, 278 following remains.
# Now run the 123 time.
# 67899740 is not following now, 277 following remains.
# Now run the 124 time.
# 4835476 is not following now, 276 following remains.
# Now run the 125 time.
# 51084205 is not following now, 275 following remains.
# Now run the 126 time.
# 6635384 is not following now, 274 following remains.
# Now run the 127 time.
# 27894496 is not following now, 273 following remains.
# Now run the 128 time.
# 11119853 is not following now, 272 following remains.
# Now run the 129 time.
# 56681772 is not following now, 271 following remains.
# Now run the 130 time.
# 29888167 is not following now, 270 following remains.
# Now run the 131 time.
# 38053434 is not following now, 269 following remains.
# Now run the 132 time.
# 66015853 is not following now, 268 following remains.
# Now run the 133 time.
# 6331947 is not following now, 267 following remains.
# Now run the 134 time.
# 67929923 is not following now, 266 following remains.
# Now run the 135 time.
# 20079163 is not following now, 265 following remains.
# Now run the 136 time.
# 64903320 is not following now, 264 following remains.
# Now run the 137 time.
# 9693032 is not following now, 263 following remains.
# Now run the 138 time.
# 10641597 is not following now, 262 following remains.
# Now run the 139 time.
# 1515450 is not following now, 261 following remains.
# Now run the 140 time.
# 12434829 is not following now, 260 following remains.
# Now run the 141 time.
# 7217643 is not following now, 259 following remains.
# Now run the 142 time.
# 41582845 is not following now, 258 following remains.
# Now run the 143 time.
# 46690100 is not following now, 257 following remains.
# Now run the 144 time.
# 32660256 is not following now, 256 following remains.
# Now run the 145 time.
# 11766951 is not following now, 255 following remains.
# Now run the 146 time.
# 26135267 is not following now, 254 following remains.
# Now run the 147 time.
# 7421348 is not following now, 253 following remains.
# Now run the 148 time.
# 56519090 is not following now, 252 following remains.
# Now run the 149 time.
# 35519869 is not following now, 251 following remains.
# Now run the 150 time.
# 58007892 is not following now, 250 following remains.
# Now run the 151 time.
# 22436517 is not following now, 249 following remains.
# Now run the 152 time.
# 15345850 is not following now, 248 following remains.
# Now run the 153 time.
# 51627013 is not following now, 247 following remains.
# Now run the 154 time.
# 6303674 is not following now, 246 following remains.
# Now run the 155 time.
# 58660432 is not following now, 245 following remains.
# Now run the 156 time.
# 58146640 is not following now, 244 following remains.
# Now run the 157 time.
# 6202657 is not following now, 243 following remains.
# Now run the 158 time.
# 20623657 is not following now, 242 following remains.
# Now run the 159 time.
# 35729283 is not following now, 241 following remains.
# Now run the 160 time.
# 49221997 is not following now, 240 following remains.
# Now run the 161 time.
# 61037238 is not following now, 239 following remains.
# Now run the 162 time.
# 5531816 is not following now, 238 following remains.
# Now run the 163 time.
# 49670239 is not following now, 237 following remains.
# Now run the 164 time.
# 34304043 is not following now, 236 following remains.
# Now run the 165 time.
# 43289172 is not following now, 235 following remains.
# Now run the 166 time.
# 22912125 is not following now, 234 following remains.
# Now run the 167 time.
# 26056723 is not following now, 233 following remains.
# Now run the 168 time.
# 51706188 is not following now, 232 following remains.
# Now run the 169 time.
# 2785008 is not following now, 231 following remains.
# Now run the 170 time.
# 22810204 is not following now, 230 following remains.
# Now run the 171 time.
# 19755191 is not following now, 229 following remains.
# Now run the 172 time.
# 67721788 is not following now, 228 following remains.
# Now run the 173 time.
# 3163850 is not following now, 227 following remains.
# Now run the 174 time.
# 3747895 is not following now, 226 following remains.
# Now run the 175 time.
# 93703 is not following now, 225 following remains.
# Now run the 176 time.
# 40128541 is not following now, 224 following remains.
# Now run the 177 time.
# 32243681 is not following now, 223 following remains.
# Now run the 178 time.
# 58828333 is not following now, 222 following remains.
# Now run the 179 time.
# 53553411 is not following now, 221 following remains.
# Now run the 180 time.
# 68062097 is not following now, 220 following remains.
# Now run the 181 time.
# 39646318 is not following now, 219 following remains.
# Now run the 182 time.
# 38898366 is not following now, 218 following remains.
# Now run the 183 time.
# 35707105 is not following now, 217 following remains.
# Now run the 184 time.
# 68207020 is not following now, 216 following remains.
# Now run the 185 time.
# 31941414 is not following now, 215 following remains.
# Now run the 186 time.
# 9902815 is not following now, 214 following remains.
# Now run the 187 time.
# 39500534 is not following now, 213 following remains.
# Now run the 188 time.
# 29600722 is not following now, 212 following remains.
# Now run the 189 time.
# 37895110 is not following now, 211 following remains.
# Now run the 190 time.
# 15765837 is not following now, 210 following remains.
# Now run the 191 time.
# 34704608 is not following now, 209 following remains.
# Now run the 192 time.
# 12564264 is not following now, 208 following remains.
# Now run the 193 time.
# 11167624 is not following now, 207 following remains.
# Now run the 194 time.
# 58639098 is not following now, 206 following remains.
# Now run the 195 time.
# 46905043 is not following now, 205 following remains.
# Now run the 196 time.
# 22266290 is not following now, 204 following remains.
# Now run the 197 time.
# 13185699 is not following now, 203 following remains.
# Now run the 198 time.
# 64766617 is not following now, 202 following remains.
# Now run the 199 time.
# 54294166 is not following now, 201 following remains.
# Now run the 200 time.
# 51896877 is not following now, 200 following remains.
# Now run the 201 time.
# 34866670 is not following now, 199 following remains.
# Now run the 202 time.
# 54012356 is not following now, 198 following remains.
# Now run the 203 time.
# 48243863 is not following now, 197 following remains.
# Now run the 204 time.
# 68216163 is not following now, 196 following remains.
# Now run the 205 time.
# 53096528 is not following now, 195 following remains.
# Now run the 206 time.
# 66574501 is not following now, 194 following remains.
# Now run the 207 time.
# 55623201 is not following now, 193 following remains.
# Now run the 208 time.
# 19673403 is not following now, 192 following remains.
# Now run the 209 time.
# 41069469 is not following now, 191 following remains.
# Now run the 210 time.
# 13327302 is not following now, 190 following remains.
# Now run the 211 time.
# 59536741 is not following now, 189 following remains.
# Now run the 212 time.
# 735729 is not following now, 188 following remains.
# Now run the 213 time.
# 14154863 is not following now, 187 following remains.
# Now run the 214 time.
# 61436386 is not following now, 186 following remains.
# Now run the 215 time.
# 21023768 is not following now, 185 following remains.
# Now run the 216 time.
# 66662856 is not following now, 184 following remains.
# Now run the 217 time.
# 30178290 is not following now, 183 following remains.
# Now run the 218 time.
# 62606392 is not following now, 182 following remains.
# Now run the 219 time.
# 64177904 is not following now, 181 following remains.
# Now run the 220 time.
# 47171977 is not following now, 180 following remains.
# Now run the 221 time.
# 40671454 is not following now, 179 following remains.
# Now run the 222 time.
# 33950382 is not following now, 178 following remains.
# Now run the 223 time.
# 10808197 is not following now, 177 following remains.
# Now run the 224 time.
# 733531 is not following now, 176 following remains.
# Now run the 225 time.
# 51064745 is not following now, 175 following remains.
# Now run the 226 time.
# 61076565 is not following now, 174 following remains.
# Now run the 227 time.
# 28159675 is not following now, 173 following remains.
# Now run the 228 time.
# 20025063 is not following now, 172 following remains.
# Now run the 229 time.
# 43452287 is not following now, 171 following remains.
# Now run the 230 time.
# 52976399 is not following now, 170 following remains.
# Now run the 231 time.
# 56974674 is not following now, 169 following remains.
# Now run the 232 time.
# 11213532 is not following now, 168 following remains.
# Now run the 233 time.
# 58134303 is not following now, 167 following remains.
# Now run the 234 time.
# 16777623 is not following now, 166 following remains.
# Now run the 235 time.
# 60866595 is not following now, 165 following remains.
# Now run the 236 time.
# 51593257 is not following now, 164 following remains.
# Now run the 237 time.
# 1605775 is not following now, 163 following remains.
# Now run the 238 time.
# 48740161 is not following now, 162 following remains.
# Now run the 239 time.
# 64414716 is not following now, 161 following remains.
# Now run the 240 time.
# 67499585 is not following now, 160 following remains.
# Now run the 241 time.
# 64189716 is not following now, 159 following remains.
# Now run the 242 time.
# 14920770 is not following now, 158 following remains.
# Now run the 243 time.
# 48204786 is not following now, 157 following remains.
# Now run the 244 time.
# 67937871 is not following now, 156 following remains.
# Now run the 245 time.
# 1836182 is not following now, 155 following remains.
# Now run the 246 time.
# 59899871 is not following now, 154 following remains.
# Now run the 247 time.
# 48762993 is not following now, 153 following remains.
# Now run the 248 time.
# 15155231 is not following now, 152 following remains.
# Now run the 249 time.
# 10233457 is not following now, 151 following remains.
# Now run the 250 time.
# 67371704 is not following now, 150 following remains.
# Now run the 251 time.
# 57634182 is not following now, 149 following remains.
# Now run the 252 time.
# 68223814 is not following now, 148 following remains.
# Now run the 253 time.
# 43008017 is not following now, 147 following remains.
# Now run the 254 time.
# 10651753 is not following now, 146 following remains.
# Now run the 255 time.
# 67382460 is not following now, 145 following remains.
# Now run the 256 time.
# 67905917 is not following now, 144 following remains.
# Now run the 257 time.
# 38029354 is not following now, 143 following remains.
# Now run the 258 time.
# 37310954 is not following now, 142 following remains.
# Now run the 259 time.
# 19194302 is not following now, 141 following remains.
# Now run the 260 time.
# 11503479 is not following now, 140 following remains.
# Now run the 261 time.
# 18731826 is not following now, 139 following remains.
# Now run the 262 time.
# 58414861 is not following now, 138 following remains.
# Now run the 263 time.
# 60936053 is not following now, 137 following remains.
# Now run the 264 time.
# 67947690 is not following now, 136 following remains.
# Now run the 265 time.
# 60125539 is not following now, 135 following remains.
# Now run the 266 time.
# 20595967 is not following now, 134 following remains.
# Now run the 267 time.
# 29016876 is not following now, 133 following remains.
# Now run the 268 time.
# 61933956 is not following now, 132 following remains.
# Now run the 269 time.
# 9946959 is not following now, 131 following remains.
# Now run the 270 time.
# 23801127 is not following now, 130 following remains.
# Now run the 271 time.
# 67315068 is not following now, 129 following remains.
# Now run the 272 time.
# 28634903 is not following now, 128 following remains.
# Now run the 273 time.
# 25907813 is not following now, 127 following remains.
# Now run the 274 time.
# 5731467 is not following now, 126 following remains.
# Now run the 275 time.
# 54832807 is not following now, 125 following remains.
# Now run the 276 time.
# 68109803 is not following now, 124 following remains.
# Now run the 277 time.
# 45212534 is not following now, 123 following remains.
# Now run the 278 time.
# 20812932 is not following now, 122 following remains.
# Now run the 279 time.
# 34737203 is not following now, 121 following remains.
# Now run the 280 time.
# 42049263 is not following now, 120 following remains.
# Now run the 281 time.
# 21091859 is not following now, 119 following remains.
# Now run the 282 time.
# 8456076 is not following now, 118 following remains.
# Now run the 283 time.
# 59550682 is not following now, 117 following remains.
# Now run the 284 time.
# 18608967 is not following now, 116 following remains.
# Now run the 285 time.
# 26568559 is not following now, 115 following remains.
# Now run the 286 time.
# 65072997 is not following now, 114 following remains.
# Now run the 287 time.
# 68151163 is not following now, 113 following remains.
# Now run the 288 time.
# 38142253 is not following now, 112 following remains.
# Now run the 289 time.
# 12533215 is not following now, 111 following remains.
# Now run the 290 time.
# 15781226 is not following now, 110 following remains.
# Now run the 291 time.
# 37989920 is not following now, 109 following remains.
# Now run the 292 time.
# 50942212 is not following now, 108 following remains.
# Now run the 293 time.
# 21476861 is not following now, 107 following remains.
# Now run the 294 time.
# 64074527 is not following now, 106 following remains.
# Now run the 295 time.
# 23781869 is not following now, 105 following remains.
# Now run the 296 time.
# 23961721 is not following now, 104 following remains.
# Now run the 297 time.
# 33136141 is not following now, 103 following remains.
# Now run the 298 time.
# 65298661 is not following now, 102 following remains.
# Now run the 299 time.
# 67185768 is not following now, 101 following remains.
# Now run the 300 time.
# 17506521 is not following now, 100 following remains.
# Now run the 301 time.
# 24078754 is not following now, 99 following remains.
# Now run the 302 time.
# 8558394 is not following now, 98 following remains.
# Now run the 303 time.
# 23556159 is not following now, 97 following remains.
# Now run the 304 time.
# 8876069 is not following now, 96 following remains.
# Now run the 305 time.
# 35678544 is not following now, 95 following remains.
# Now run the 306 time.
# 4462610 is not following now, 94 following remains.
# Now run the 307 time.
# 10171169 is not following now, 93 following remains.
# Now run the 308 time.
# 65423792 is not following now, 92 following remains.
# Now run the 309 time.
# 21296931 is not following now, 91 following remains.
# Now run the 310 time.
# 67889862 is not following now, 90 following remains.
# Now run the 311 time.
# 8100637 is not following now, 89 following remains.
# Now run the 312 time.
# 68227016 is not following now, 88 following remains.
# Now run the 313 time.
# 68230014 is not following now, 87 following remains.
# Now run the 314 time.
# 68208733 is not following now, 86 following remains.
# Now run the 315 time.
# 37008490 is not following now, 85 following remains.
# Now run the 316 time.
# 19448540 is not following now, 84 following remains.
# Now run the 317 time.
# 36279890 is not following now, 83 following remains.
# Now run the 318 time.
# 8892620 is not following now, 82 following remains.
# Now run the 319 time.
# 65309267 is not following now, 81 following remains.
# Now run the 320 time.
# 6274313 is not following now, 80 following remains.
# Now run the 321 time.
# 49410133 is not following now, 79 following remains.
# Now run the 322 time.
# 47225025 is not following now, 78 following remains.
# Now run the 323 time.
# 14953566 is not following now, 77 following remains.
# Now run the 324 time.
# 15068966 is not following now, 76 following remains.
# Now run the 325 time.
# 18853930 is not following now, 75 following remains.
# Now run the 326 time.
# 4855775 is not following now, 74 following remains.
# Now run the 327 time.
# 6392369 is not following now, 73 following remains.
# Now run the 328 time.
# 47870894 is not following now, 72 following remains.
# Now run the 329 time.
# 37101349 is not following now, 71 following remains.
# Now run the 330 time.
# 16553414 is not following now, 70 following remains.
# Now run the 331 time.
# 5494397 is not following now, 69 following remains.
# Now run the 332 time.
# 39055121 is not following now, 68 following remains.
# Now run the 333 time.
# 57738724 is not following now, 67 following remains.
# Now run the 334 time.
# 12705867 is not following now, 66 following remains.
# Now run the 335 time.
# 5762631 is not following now, 65 following remains.
# Now run the 336 time.
# 17419630 is not following now, 64 following remains.
# Now run the 337 time.
# 15829817 is not following now, 63 following remains.
# Now run the 338 time.
# 35829452 is not following now, 62 following remains.
# Now run the 339 time.
# 51324604 is not following now, 61 following remains.
# Now run the 340 time.
# 45664075 is not following now, 60 following remains.
# Now run the 341 time.
# 14010204 is not following now, 59 following remains.
# Now run the 342 time.
# 14451316 is not following now, 58 following remains.
# Now run the 343 time.
# 49030781 is not following now, 57 following remains.
# Now run the 344 time.
# 57919019 is not following now, 56 following remains.
# Now run the 345 time.
# 20287557 is not following now, 55 following remains.
# Now run the 346 time.
# 30194502 is not following now, 54 following remains.
# Now run the 347 time.
# 20481605 is not following now, 53 following remains.
# Now run the 348 time.
# 12469469 is not following now, 52 following remains.
# Now run the 349 time.
# 48497197 is not following now, 51 following remains.
# Now run the 350 time.
# 10549737 is not following now, 50 following remains.
# Now run the 351 time.
# 34948584 is not following now, 49 following remains.
# Now run the 352 time.
# 54423150 is not following now, 48 following remains.
# Now run the 353 time.
# 8848016 is not following now, 47 following remains.
# Now run the 354 time.
# 29110636 is not following now, 46 following remains.
# Now run the 355 time.
# 4039999 is not following now, 45 following remains.
# Now run the 356 time.
# 21246049 is not following now, 44 following remains.
# Now run the 357 time.
# 29264145 is not following now, 43 following remains.
# Now run the 358 time.
# 20414695 is not following now, 42 following remains.
# Now run the 359 time.
# 37311614 is not following now, 41 following remains.
# Now run the 360 time.
# 34809223 is not following now, 40 following remains.
# Now run the 361 time.
# 54542780 is not following now, 39 following remains.
# Now run the 362 time.
# 10506722 is not following now, 38 following remains.
# Now run the 363 time.
# 28085487 is not following now, 37 following remains.
# Now run the 364 time.
# 5627119 is not following now, 36 following remains.
# Now run the 365 time.
# 43901525 is not following now, 35 following remains.
# Now run the 366 time.
# 47018629 is not following now, 34 following remains.
# Now run the 367 time.
# 22521648 is not following now, 33 following remains.
# Now run the 368 time.
# 42737872 is not following now, 32 following remains.
# Now run the 369 time.
# 26579505 is not following now, 31 following remains.
# Now run the 370 time.
# 8640331 is not following now, 30 following remains.
# Now run the 371 time.
# 23852670 is not following now, 29 following remains.
# Now run the 372 time.
# 28519029 is not following now, 28 following remains.
# Now run the 373 time.
# 33525016 is not following now, 27 following remains.
# Now run the 374 time.
# 52466561 is not following now, 26 following remains.
# Now run the 375 time.
# 20641422 is not following now, 25 following remains.
# Now run the 376 time.
# 11036405 is not following now, 24 following remains.
# Now run the 377 time.
# 7215933 is not following now, 23 following remains.
# Now run the 378 time.
# 9911617 is not following now, 22 following remains.
# Now run the 379 time.
# 47659865 is not following now, 21 following remains.
# Now run the 380 time.
# 6175809 is not following now, 20 following remains.
# Now run the 381 time.
# 39278087 is not following now, 19 following remains.
# Now run the 382 time.
# 12452592 is not following now, 18 following remains.
# Now run the 383 time.
# 18767148 is not following now, 17 following remains.
# Now run the 384 time.
# 10974201 is not following now, 16 following remains.
# Now run the 385 time.
# 9330431 is not following now, 15 following remains.
# Now run the 386 time.
# 4154629 is not following now, 14 following remains.
# Now run the 387 time.
# 18570410 is not following now, 13 following remains.
# Now run the 388 time.
# 11702075 is not following now, 12 following remains.
# Now run the 389 time.
# 22045403 is not following now, 11 following remains.
# Now run the 390 time.
# 5523652 is not following now, 10 following remains.
# Now run the 391 time.
# 61985707 is not following now, 9 following remains.
# Now run the 392 time.
# 27648722 is not following now, 8 following remains.
# Now run the 393 time.
# 8048870 is not following now, 7 following remains.
# Now run the 394 time.
# 32095589 is not following now, 6 following remains.
# Now run the 395 time.
# 50804134 is not following now, 5 following remains.
# Now run the 396 time.
# 59801973 is not following now, 4 following remains.
# Now run the 397 time.
# 3306291 is not following now, 3 following remains.
# Now run the 398 time.
# 19235362 is not following now, 2 following remains.
# Now run the 399 time.
# 36729278 is not following now, 1 following remains.
# Now run the 400 time.
# 59482312 is not following now, 0 following remains.

# %%
# add fans from Top Seller's shop
top_shop_url = 'https://shopee.co.id/shop/13484023/followers/?__classic__=1'
browser.get(top_shop_url)

# %%
# add certain number of fans
to_add_num_of_following = 400
num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))

# %%
# page down until we get at least 400 fans to cancel
while num_of_following_display <= 1000:
    body = browser.find_element_by_css_selector('body')
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(5)
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    
num_of_following_display
# Out:
# 1009

# %%
following_buttons = browser.find_elements_by_css_selector('.btn-follow.follow.L14')
len(following_buttons)
# Out:
# 20

# %%
i = 0
total_add_num_of_following = to_add_num_of_following

scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)

while i <= total_add_num_of_following - 1:  
    while to_add_num_of_following > 0:
        print('Now run the ' + str(i + 1) + ' time.')
        if following_buttons[i].text == '+ 关注':
            # print(following_buttons[i].text)
            shopid = following_buttons[i].get_attribute('shopid')
            following_buttons[i].click()
            time.sleep(5)
            to_add_num_of_following -= 1
            i += 1
            print(str(shopid) + ' is following now, ' + str(to_add_num_of_following) + ' following remains.')
# Out:
# Now run the 1 time.
# + 关注
# 42872277 is following now, 394 following remains.
# Now run the 2 time.
# + 关注
# 53491709 is following now, 393 following remains.
# Now run the 3 time.
# + 关注
# 7245127 is following now, 392 following remains.
# Now run the 4 time.
# + 关注
# 8598147 is following now, 391 following remains.
# Now run the 5 time.
# + 关注
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-30a1656bd7f0> in <module>()
#      11             shopid = following_buttons[i].get_attribute('shopid')
#      12             following_buttons[i].click()
# ---> 13             time.sleep(5)
#      14             to_add_num_of_following -= 1
#      15             i += 1
#
# KeyboardInterrupt:

# %%
# 关闭
browser.quit()
