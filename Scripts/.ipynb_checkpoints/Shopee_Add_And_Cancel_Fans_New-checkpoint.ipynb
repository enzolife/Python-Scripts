# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time
import datetime
import logging
import os

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

today_date_string = today_date.strftime('%Y_%m_%d')

# %%
# os.getcwd()

# %%
log_file_name = 'shopee_add_and_cancel_fans_log\\shopee_add_and_cancel_fans_log_' + today_date_string + '.txt'

# logging.basicConfig(filename=log_file_name, level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# 屏幕最大化，且指定下载目录
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

prefs = {"profile.default_content_settings.popups": 0,
         "directory_upgrade": True}
options.add_experimental_option("prefs", prefs)

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
# browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
# 所需参数
# 站点；站点后缀；账户；密码；站点top卖家shopid；top卖家username（方便识别）
shop_list = [['tw', 'tw', 23070969, 'poweradapter.tw', 'kuangyiqiao1991', 9469128, 'alonso.tw'],
             ['tw', 'tw', 25482220, 'tengus.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 58707738, 'qianjiaozi', 'qianjiaozi888', 26513957, 'beibei.tw'],
             ['tw', 'tw', 66377809, 'qianjiaozi1', 'qianjiaozi888', 23068230, 'iu.tw'],
             ['tw', 'tw', 62416366, 'tengus1.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 62416544, 'tengus2.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 63534861, 'qianjiaozitw1', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 62887142, 'yilanlu.tw', 'yilanlu888', 23481977, 'huoyi.tw'],
             ['my', 'com.my', 53580963, 'qianjiaozi.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 59848325, 'tengus.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 62418141, 'tengus1.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 62418493, 'tengus2.my', 'tengus1803', 10891137, 'winners.my'],
             ['id', 'co.id', 59846508, 'tengus.id', 'tengus1803', 28135012, 'sunnyfun.id']
             #['id', 'co.id', 62417386, 'tengus1.id', 'tengus1803', 28135012, 'sunnyfun.id'],
             #['id', 'co.id', 62417551, 'tengus2.id', 'tengus1803', 28135012, 'sunnyfun.id']]

# %%
# 转换为dataframe
shop_df_columns = ['site', 'site_suffix', 'shopid', 'acc', 'pwd', 'top_shop_id', 'top_shop_username']
shop_df = pd.DataFrame(shop_list, columns=shop_df_columns)

# %%
# 关注及关注中多语言
following_language = ['关注中', '關注中', 'Following', 'Mengikuti']
not_following_language = ['+ 关注', '+ 關注', '+ Follow', '+ Ikuti']

# %%
# 取关后关注函数
def add_and_cancel_fans(site, site_suffix, shopid, acc, pwd, top_shop_id, top_shop_username):
    # 打开浏览器
    logging.info('Open the browser.')
    browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)
    
    # main page
    main_page_url = "http://shopee." + site_suffix
    browser.get(main_page_url)
    time.sleep(10)
    
    # remove ads, refresh again
    browser.get(main_page_url)
    time.sleep(10)

    # if the shop is on my site, should press the button to choose language
    if site == 'my':
        language_selector = browser.find_elements_by_css_selector('.shopee-button-outline.shopee-button-outline--primary-reverse')
        language_selector[2].click()
        logging.info('Choose Chinese as language.')
        time.sleep(10)
    
    # login
    logging.info('Start to login.')
    LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
    
    # 点击登入，弹出账户密码输入框
    LoginElem[1].click()
    time.sleep(10)
    
    # 输入
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    try:
        acc_password_input_elem[0].click()
        acc_password_input_elem[0].send_keys(acc)
        acc_password_input_elem[1].click()
        acc_password_input_elem[1].send_keys(pwd)
    except:
        time.sleep(30)
        acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
        acc_password_input_elem[0].click()
        acc_password_input_elem[0].send_keys(acc)
        acc_password_input_elem[1].click()
        acc_password_input_elem[1].send_keys(pwd)
    time.sleep(10)
    
    # 点击提交
    Login_button_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
    Login_button_elem[0].click()
    logging.info('Login completed.')
    time.sleep(10)
    
    # switch to my following list
    logging.info('Switch to my following list.')
    my_fans_list_page = 'https://shopee.' + site_suffix + '/shop/' + str(shopid) + '/following/?__classic__=1'
    browser.get(my_fans_list_page)
    
    # cancel certain number of following fans
    to_cancel_num_of_following = 400
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    
    # in case the following number is not greater than 500
    max_roll_time = 100
    roll_time = 0
    
    # page down until we get at least 500 fans to cancel
    while num_of_following_display <= 500 and roll_time <= max_roll_time:
        body = browser.find_element_by_css_selector('body')
        body.send_keys(Keys.END)
        time.sleep(2)
        num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
        logging.info(str(num_of_following_display) + ' following on the list.')
        roll_time += 1
        logging.info('Roll the page for ' + str(roll_time) + ' time.')
    following_buttons = browser.find_elements_by_css_selector('.btn-follow.active.follow.L14')
    
    # actual following to cancel
    to_cancel_num_of_following = min(num_of_following_display, to_cancel_num_of_following)
    
    # page up to the top
    scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)
    
    # start to cancel following
    logging.info('Start to cancel following.')
    i = 0
    total_cancel_num_of_following = to_cancel_num_of_following
    while i <= total_cancel_num_of_following - 1:
        while to_cancel_num_of_following > 0:
            logging.info('Now run the ' + str(i + 1) + ' time.')
            if following_buttons[i].text in following_language:
                buyer_shopid = following_buttons[i].get_attribute('shopid')
                following_buttons[i].click()
                time.sleep(1)
                to_cancel_num_of_following -= 1
                i += 1
                logging.info(acc + ': ' + str(buyer_shopid) + ' is not following now, ' + str(to_cancel_num_of_following) + ' following remains.')
    
    # add fans from Top Seller's followers
    logging.info('Switch to top seller follower page.')
    top_shop_url = 'https://shopee.' + site_suffix + '/shop/' + str(top_shop_id) + '/followers/?__classic__=1'
    browser.get(top_shop_url)
    
    # add certain number of fans
    to_add_num_of_following = 400
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    
    # page down until we get at least 400 fans to cancel
    logging.info('Start to roll down.')
    while num_of_following_display <= 1000:
        body = browser.find_element_by_css_selector('body')
        # body.send_keys(Keys.PAGE_DOWN)
        body.send_keys(Keys.END)
        time.sleep(2)
        num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    following_buttons = browser.find_elements_by_css_selector('.btn-follow.follow.L14')
    
    # start to follow buyers from top shop
    logging.info('Start to follow buyers.')
    i = 0
    total_add_num_of_following = to_add_num_of_following
    scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)

    while i <= total_add_num_of_following - 1:  
        while to_add_num_of_following > 0:
            logging.info('Now run the ' + str(i + 1) + ' time.')
            if following_buttons[i].text in not_following_language:
                # print(following_buttons[i].text)
                buyer_shopid = following_buttons[i].get_attribute('shopid')
                following_buttons[i].click()
                time.sleep(1)
                to_add_num_of_following -= 1
                logging.info(acc + ': ' + str(buyer_shopid) + ' is following now, ' + str(to_add_num_of_following) + ' following remains.')
            else:
                logging.info('Skip this one. It\'s following already.')
            i += 1    
    
    # 关闭
    browser.quit()

# %%
# 历遍所有shop
for index, my_shop in shop_df.iterrows():
    site = my_shop[0]
    site_suffix = my_shop[1]
    shopid = my_shop[2]
    acc = my_shop[3]
    pwd = my_shop[4]
    top_shop_id = my_shop[5]
    top_shop_username = my_shop[6]
    
    # 执行
    try:
        logging.info('Now it\'s running the script on ' + acc + '.')
        add_and_cancel_fans(site, site_suffix, shopid, acc, pwd, top_shop_id, top_shop_username)
        logging.info('Finished running the script on ' + acc + '.')
    except Exception as err:
        logging.info('An exception occurred: ' + err + '.')
# Out:
# 2018-05-13 17:01:11,431 - INFO - Now it's running the script on qianjiaozi.my.
# 2018-05-13 17:01:11,432 - INFO - Open the browser.
# 2018-05-13 17:02:44,105 - INFO - Choose Chinese as language.
# 2018-05-13 17:02:54,107 - INFO - Start to login.
# 2018-05-13 17:03:14,718 - INFO - Login completed.
# 2018-05-13 17:03:24,719 - INFO - Switch to my following list.
# 2018-05-13 17:04:01,327 - INFO - 40 following on the list.
# 2018-05-13 17:04:01,327 - INFO - Roll the page for 1 time.
# 2018-05-13 17:04:03,383 - INFO - 60 following on the list.
# 2018-05-13 17:04:03,384 - INFO - Roll the page for 2 time.
# 2018-05-13 17:04:05,431 - INFO - 80 following on the list.
# 2018-05-13 17:04:05,432 - INFO - Roll the page for 3 time.
# 2018-05-13 17:04:07,488 - INFO - 100 following on the list.
# 2018-05-13 17:04:07,488 - INFO - Roll the page for 4 time.
# 2018-05-13 17:04:09,544 - INFO - 120 following on the list.
# 2018-05-13 17:04:09,544 - INFO - Roll the page for 5 time.
# 2018-05-13 17:04:11,606 - INFO - 140 following on the list.
# 2018-05-13 17:04:11,606 - INFO - Roll the page for 6 time.
# 2018-05-13 17:04:13,664 - INFO - 160 following on the list.
# 2018-05-13 17:04:13,664 - INFO - Roll the page for 7 time.
# 2018-05-13 17:04:15,736 - INFO - 180 following on the list.
# 2018-05-13 17:04:15,736 - INFO - Roll the page for 8 time.
# 2018-05-13 17:04:17,814 - INFO - 200 following on the list.
# 2018-05-13 17:04:17,815 - INFO - Roll the page for 9 time.
# 2018-05-13 17:04:19,934 - INFO - 220 following on the list.
# 2018-05-13 17:04:19,935 - INFO - Roll the page for 10 time.
# 2018-05-13 17:04:22,047 - INFO - 240 following on the list.
# 2018-05-13 17:04:22,048 - INFO - Roll the page for 11 time.
# 2018-05-13 17:04:24,123 - INFO - 260 following on the list.
# 2018-05-13 17:04:24,123 - INFO - Roll the page for 12 time.
# 2018-05-13 17:04:26,230 - INFO - 280 following on the list.
# 2018-05-13 17:04:26,231 - INFO - Roll the page for 13 time.
# 2018-05-13 17:04:28,368 - INFO - 300 following on the list.
# 2018-05-13 17:04:28,369 - INFO - Roll the page for 14 time.
# 2018-05-13 17:04:30,507 - INFO - 320 following on the list.
# 2018-05-13 17:04:30,508 - INFO - Roll the page for 15 time.
# 2018-05-13 17:04:32,679 - INFO - 340 following on the list.
# 2018-05-13 17:04:32,681 - INFO - Roll the page for 16 time.
# 2018-05-13 17:04:34,847 - INFO - 360 following on the list.
# 2018-05-13 17:04:34,848 - INFO - Roll the page for 17 time.
# 2018-05-13 17:04:36,955 - INFO - 380 following on the list.
# 2018-05-13 17:04:36,955 - INFO - Roll the page for 18 time.
# 2018-05-13 17:04:39,073 - INFO - 400 following on the list.
# 2018-05-13 17:04:39,074 - INFO - Roll the page for 19 time.
# 2018-05-13 17:04:41,180 - INFO - 420 following on the list.
# 2018-05-13 17:04:41,181 - INFO - Roll the page for 20 time.
# 2018-05-13 17:04:43,282 - INFO - 440 following on the list.
# 2018-05-13 17:04:43,283 - INFO - Roll the page for 21 time.
# 2018-05-13 17:04:45,392 - INFO - 460 following on the list.
# 2018-05-13 17:04:45,393 - INFO - Roll the page for 22 time.
# 2018-05-13 17:04:47,512 - INFO - 480 following on the list.
# 2018-05-13 17:04:47,513 - INFO - Roll the page for 23 time.
# 2018-05-13 17:04:49,642 - INFO - 500 following on the list.
# 2018-05-13 17:04:49,643 - INFO - Roll the page for 24 time.
# 2018-05-13 17:04:51,778 - INFO - 520 following on the list.
# 2018-05-13 17:04:51,779 - INFO - Roll the page for 25 time.
# 2018-05-13 17:04:51,910 - INFO - Start to cancel following.
# 2018-05-13 17:04:51,911 - INFO - Now run the 1 time.
# 2018-05-13 17:04:53,003 - INFO - qianjiaozi.my: 19837942 is not following now, 399 following remains.
# 2018-05-13 17:04:53,004 - INFO - Now run the 2 time.
# 2018-05-13 17:04:54,086 - INFO - qianjiaozi.my: 6329559 is not following now, 398 following remains.
# 2018-05-13 17:04:54,086 - INFO - Now run the 3 time.
# 2018-05-13 17:04:55,171 - INFO - qianjiaozi.my: 34251517 is not following now, 397 following remains.
# 2018-05-13 17:04:55,172 - INFO - Now run the 4 time.
# 2018-05-13 17:04:56,276 - INFO - qianjiaozi.my: 10080149 is not following now, 396 following remains.
# 2018-05-13 17:04:56,277 - INFO - Now run the 5 time.
# 2018-05-13 17:04:57,369 - INFO - qianjiaozi.my: 14903764 is not following now, 395 following remains.
# 2018-05-13 17:04:57,369 - INFO - Now run the 6 time.
# 2018-05-13 17:04:58,457 - INFO - qianjiaozi.my: 49165578 is not following now, 394 following remains.
# 2018-05-13 17:04:58,457 - INFO - Now run the 7 time.
# 2018-05-13 17:04:59,544 - INFO - qianjiaozi.my: 13119979 is not following now, 393 following remains.
# 2018-05-13 17:04:59,546 - INFO - Now run the 8 time.
# 2018-05-13 17:05:00,643 - INFO - qianjiaozi.my: 34039318 is not following now, 392 following remains.
# 2018-05-13 17:05:00,643 - INFO - Now run the 9 time.
# 2018-05-13 17:05:01,753 - INFO - qianjiaozi.my: 45842893 is not following now, 391 following remains.
# 2018-05-13 17:05:01,753 - INFO - Now run the 10 time.
# 2018-05-13 17:05:02,851 - INFO - qianjiaozi.my: 25487958 is not following now, 390 following remains.
# 2018-05-13 17:05:02,852 - INFO - Now run the 11 time.
# 2018-05-13 17:05:03,961 - INFO - qianjiaozi.my: 46139510 is not following now, 389 following remains.
# 2018-05-13 17:05:03,961 - INFO - Now run the 12 time.
# 2018-05-13 17:05:05,047 - INFO - qianjiaozi.my: 48096464 is not following now, 388 following remains.
# 2018-05-13 17:05:05,047 - INFO - Now run the 13 time.
# 2018-05-13 17:05:06,130 - INFO - qianjiaozi.my: 24380177 is not following now, 387 following remains.
# 2018-05-13 17:05:06,130 - INFO - Now run the 14 time.
# 2018-05-13 17:05:07,234 - INFO - qianjiaozi.my: 68141067 is not following now, 386 following remains.
# 2018-05-13 17:05:07,234 - INFO - Now run the 15 time.
# 2018-05-13 17:05:08,334 - INFO - qianjiaozi.my: 58587764 is not following now, 385 following remains.
# 2018-05-13 17:05:08,334 - INFO - Now run the 16 time.
# 2018-05-13 17:05:09,436 - INFO - qianjiaozi.my: 58093186 is not following now, 384 following remains.
# 2018-05-13 17:05:09,436 - INFO - Now run the 17 time.
# 2018-05-13 17:05:10,535 - INFO - qianjiaozi.my: 58762129 is not following now, 383 following remains.
# 2018-05-13 17:05:10,535 - INFO - Now run the 18 time.
# 2018-05-13 17:05:11,619 - INFO - qianjiaozi.my: 44456680 is not following now, 382 following remains.
# 2018-05-13 17:05:11,620 - INFO - Now run the 19 time.
# 2018-05-13 17:05:12,723 - INFO - qianjiaozi.my: 66523743 is not following now, 381 following remains.
# 2018-05-13 17:05:12,724 - INFO - Now run the 20 time.
# 2018-05-13 17:05:13,808 - INFO - qianjiaozi.my: 11193370 is not following now, 380 following remains.
# 2018-05-13 17:05:13,808 - INFO - Now run the 21 time.
# 2018-05-13 17:05:14,904 - INFO - qianjiaozi.my: 14394050 is not following now, 379 following remains.
# 2018-05-13 17:05:14,904 - INFO - Now run the 22 time.
# 2018-05-13 17:05:15,990 - INFO - qianjiaozi.my: 9676558 is not following now, 378 following remains.
# 2018-05-13 17:05:15,990 - INFO - Now run the 23 time.
# 2018-05-13 17:05:17,074 - INFO - qianjiaozi.my: 6336216 is not following now, 377 following remains.
# 2018-05-13 17:05:17,075 - INFO - Now run the 24 time.
# 2018-05-13 17:05:18,175 - INFO - qianjiaozi.my: 8429454 is not following now, 376 following remains.
# 2018-05-13 17:05:18,175 - INFO - Now run the 25 time.
# 2018-05-13 17:05:19,279 - INFO - qianjiaozi.my: 63880904 is not following now, 375 following remains.
# 2018-05-13 17:05:19,279 - INFO - Now run the 26 time.
# 2018-05-13 17:05:20,382 - INFO - qianjiaozi.my: 39720913 is not following now, 374 following remains.
# 2018-05-13 17:05:20,384 - INFO - Now run the 27 time.
# 2018-05-13 17:05:21,513 - INFO - qianjiaozi.my: 39578068 is not following now, 373 following remains.
# 2018-05-13 17:05:21,513 - INFO - Now run the 28 time.
# 2018-05-13 17:05:22,599 - INFO - qianjiaozi.my: 8425123 is not following now, 372 following remains.
# 2018-05-13 17:05:22,600 - INFO - Now run the 29 time.
# 2018-05-13 17:05:23,714 - INFO - qianjiaozi.my: 68330947 is not following now, 371 following remains.
# 2018-05-13 17:05:23,716 - INFO - Now run the 30 time.
# 2018-05-13 17:05:24,834 - INFO - qianjiaozi.my: 68321133 is not following now, 370 following remains.
# 2018-05-13 17:05:24,835 - INFO - Now run the 31 time.
# 2018-05-13 17:05:25,968 - INFO - qianjiaozi.my: 42487665 is not following now, 369 following remains.
# 2018-05-13 17:05:25,969 - INFO - Now run the 32 time.
# 2018-05-13 17:05:27,145 - INFO - qianjiaozi.my: 12336001 is not following now, 368 following remains.
# 2018-05-13 17:05:27,145 - INFO - Now run the 33 time.
# 2018-05-13 17:05:28,242 - INFO - qianjiaozi.my: 166346 is not following now, 367 following remains.
# 2018-05-13 17:05:28,242 - INFO - Now run the 34 time.
# 2018-05-13 17:05:29,342 - INFO - qianjiaozi.my: 44846439 is not following now, 366 following remains.
# 2018-05-13 17:05:29,343 - INFO - Now run the 35 time.
# 2018-05-13 17:05:30,441 - INFO - qianjiaozi.my: 39947267 is not following now, 365 following remains.
# 2018-05-13 17:05:30,443 - INFO - Now run the 36 time.
# 2018-05-13 17:05:31,544 - INFO - qianjiaozi.my: 66510938 is not following now, 364 following remains.
# 2018-05-13 17:05:31,546 - INFO - Now run the 37 time.
# 2018-05-13 17:05:32,680 - INFO - qianjiaozi.my: 64934947 is not following now, 363 following remains.
# 2018-05-13 17:05:32,681 - INFO - Now run the 38 time.
# 2018-05-13 17:05:33,806 - INFO - qianjiaozi.my: 41509545 is not following now, 362 following remains.
# 2018-05-13 17:05:33,807 - INFO - Now run the 39 time.
# 2018-05-13 17:05:34,927 - INFO - qianjiaozi.my: 13383106 is not following now, 361 following remains.
# 2018-05-13 17:05:34,928 - INFO - Now run the 40 time.
# 2018-05-13 17:05:36,017 - INFO - qianjiaozi.my: 8803694 is not following now, 360 following remains.
# 2018-05-13 17:05:36,017 - INFO - Now run the 41 time.
# 2018-05-13 17:05:37,120 - INFO - qianjiaozi.my: 49901812 is not following now, 359 following remains.
# 2018-05-13 17:05:37,120 - INFO - Now run the 42 time.
# 2018-05-13 17:05:38,205 - INFO - qianjiaozi.my: 497708 is not following now, 358 following remains.
# 2018-05-13 17:05:38,206 - INFO - Now run the 43 time.
# 2018-05-13 17:05:39,289 - INFO - qianjiaozi.my: 32337302 is not following now, 357 following remains.
# 2018-05-13 17:05:39,289 - INFO - Now run the 44 time.
# 2018-05-13 17:05:40,382 - INFO - qianjiaozi.my: 12397564 is not following now, 356 following remains.
# 2018-05-13 17:05:40,383 - INFO - Now run the 45 time.
# 2018-05-13 17:05:41,483 - INFO - qianjiaozi.my: 7966688 is not following now, 355 following remains.
# 2018-05-13 17:05:41,483 - INFO - Now run the 46 time.
# 2018-05-13 17:05:42,593 - INFO - qianjiaozi.my: 17395998 is not following now, 354 following remains.
# 2018-05-13 17:05:42,593 - INFO - Now run the 47 time.
# 2018-05-13 17:05:43,677 - INFO - qianjiaozi.my: 57295673 is not following now, 353 following remains.
# 2018-05-13 17:05:43,678 - INFO - Now run the 48 time.
# 2018-05-13 17:05:44,770 - INFO - qianjiaozi.my: 64926212 is not following now, 352 following remains.
# 2018-05-13 17:05:44,770 - INFO - Now run the 49 time.
# 2018-05-13 17:05:45,863 - INFO - qianjiaozi.my: 48752327 is not following now, 351 following remains.
# 2018-05-13 17:05:45,863 - INFO - Now run the 50 time.
# 2018-05-13 17:05:46,964 - INFO - qianjiaozi.my: 62576411 is not following now, 350 following remains.
# 2018-05-13 17:05:46,965 - INFO - Now run the 51 time.
# 2018-05-13 17:05:48,063 - INFO - qianjiaozi.my: 67336019 is not following now, 349 following remains.
# 2018-05-13 17:05:48,064 - INFO - Now run the 52 time.
# 2018-05-13 17:05:49,159 - INFO - qianjiaozi.my: 58253972 is not following now, 348 following remains.
# 2018-05-13 17:05:49,159 - INFO - Now run the 53 time.
# 2018-05-13 17:05:50,261 - INFO - qianjiaozi.my: 8367362 is not following now, 347 following remains.
# 2018-05-13 17:05:50,262 - INFO - Now run the 54 time.
# 2018-05-13 17:05:51,362 - INFO - qianjiaozi.my: 21091830 is not following now, 346 following remains.
# 2018-05-13 17:05:51,362 - INFO - Now run the 55 time.
# 2018-05-13 17:05:52,464 - INFO - qianjiaozi.my: 68225076 is not following now, 345 following remains.
# 2018-05-13 17:05:52,464 - INFO - Now run the 56 time.
# 2018-05-13 17:05:53,566 - INFO - qianjiaozi.my: 412479 is not following now, 344 following remains.
# 2018-05-13 17:05:53,566 - INFO - Now run the 57 time.
# 2018-05-13 17:05:54,668 - INFO - qianjiaozi.my: 27514495 is not following now, 343 following remains.
# 2018-05-13 17:05:54,668 - INFO - Now run the 58 time.
# 2018-05-13 17:05:55,753 - INFO - qianjiaozi.my: 57088550 is not following now, 342 following remains.
# 2018-05-13 17:05:55,754 - INFO - Now run the 59 time.
# 2018-05-13 17:05:56,839 - INFO - qianjiaozi.my: 27782693 is not following now, 341 following remains.
# 2018-05-13 17:05:56,839 - INFO - Now run the 60 time.
# 2018-05-13 17:05:57,937 - INFO - qianjiaozi.my: 68190716 is not following now, 340 following remains.
# 2018-05-13 17:05:57,937 - INFO - Now run the 61 time.
# 2018-05-13 17:05:59,024 - INFO - qianjiaozi.my: 65033319 is not following now, 339 following remains.
# 2018-05-13 17:05:59,024 - INFO - Now run the 62 time.
# 2018-05-13 17:06:00,106 - INFO - qianjiaozi.my: 35568820 is not following now, 338 following remains.
# 2018-05-13 17:06:00,106 - INFO - Now run the 63 time.
# 2018-05-13 17:06:01,209 - INFO - qianjiaozi.my: 46455498 is not following now, 337 following remains.
# 2018-05-13 17:06:01,210 - INFO - Now run the 64 time.
# 2018-05-13 17:06:02,314 - INFO - qianjiaozi.my: 28900812 is not following now, 336 following remains.
# 2018-05-13 17:06:02,315 - INFO - Now run the 65 time.
# 2018-05-13 17:06:03,398 - INFO - qianjiaozi.my: 40011256 is not following now, 335 following remains.
# 2018-05-13 17:06:03,399 - INFO - Now run the 66 time.
# 2018-05-13 17:06:04,499 - INFO - qianjiaozi.my: 62994786 is not following now, 334 following remains.
# 2018-05-13 17:06:04,499 - INFO - Now run the 67 time.
# 2018-05-13 17:06:05,584 - INFO - qianjiaozi.my: 52420405 is not following now, 333 following remains.
# 2018-05-13 17:06:05,584 - INFO - Now run the 68 time.
# 2018-05-13 17:06:06,681 - INFO - qianjiaozi.my: 31573946 is not following now, 332 following remains.
# 2018-05-13 17:06:06,681 - INFO - Now run the 69 time.
# 2018-05-13 17:06:07,782 - INFO - qianjiaozi.my: 46585267 is not following now, 331 following remains.
# 2018-05-13 17:06:07,782 - INFO - Now run the 70 time.
# 2018-05-13 17:06:08,869 - INFO - qianjiaozi.my: 55583017 is not following now, 330 following remains.
# 2018-05-13 17:06:08,869 - INFO - Now run the 71 time.
# 2018-05-13 17:06:09,972 - INFO - qianjiaozi.my: 63616510 is not following now, 329 following remains.
# 2018-05-13 17:06:09,972 - INFO - Now run the 72 time.
# 2018-05-13 17:06:11,065 - INFO - qianjiaozi.my: 18482593 is not following now, 328 following remains.
# 2018-05-13 17:06:11,065 - INFO - Now run the 73 time.
# 2018-05-13 17:06:12,170 - INFO - qianjiaozi.my: 16988555 is not following now, 327 following remains.
# 2018-05-13 17:06:12,171 - INFO - Now run the 74 time.
# 2018-05-13 17:06:13,269 - INFO - qianjiaozi.my: 35980174 is not following now, 326 following remains.
# 2018-05-13 17:06:13,269 - INFO - Now run the 75 time.
# 2018-05-13 17:06:14,404 - INFO - qianjiaozi.my: 55159692 is not following now, 325 following remains.
# 2018-05-13 17:06:14,405 - INFO - Now run the 76 time.
# 2018-05-13 17:06:15,510 - INFO - qianjiaozi.my: 30804080 is not following now, 324 following remains.
# 2018-05-13 17:06:15,510 - INFO - Now run the 77 time.
# 2018-05-13 17:06:16,614 - INFO - qianjiaozi.my: 9937655 is not following now, 323 following remains.
# 2018-05-13 17:06:16,615 - INFO - Now run the 78 time.
# 2018-05-13 17:06:17,726 - INFO - qianjiaozi.my: 22820497 is not following now, 322 following remains.
# 2018-05-13 17:06:17,726 - INFO - Now run the 79 time.
# 2018-05-13 17:06:18,859 - INFO - qianjiaozi.my: 37561056 is not following now, 321 following remains.
# 2018-05-13 17:06:18,859 - INFO - Now run the 80 time.
# 2018-05-13 17:06:19,964 - INFO - qianjiaozi.my: 17231054 is not following now, 320 following remains.
# 2018-05-13 17:06:19,965 - INFO - Now run the 81 time.
# 2018-05-13 17:06:21,081 - INFO - qianjiaozi.my: 43811369 is not following now, 319 following remains.
# 2018-05-13 17:06:21,082 - INFO - Now run the 82 time.
# 2018-05-13 17:06:22,161 - INFO - qianjiaozi.my: 25208168 is not following now, 318 following remains.
# 2018-05-13 17:06:22,161 - INFO - Now run the 83 time.
# 2018-05-13 17:06:23,251 - INFO - qianjiaozi.my: 56567397 is not following now, 317 following remains.
# 2018-05-13 17:06:23,253 - INFO - Now run the 84 time.
# 2018-05-13 17:06:24,384 - INFO - qianjiaozi.my: 14825577 is not following now, 316 following remains.
# 2018-05-13 17:06:24,385 - INFO - Now run the 85 time.
# 2018-05-13 17:06:25,499 - INFO - qianjiaozi.my: 36457530 is not following now, 315 following remains.
# 2018-05-13 17:06:25,499 - INFO - Now run the 86 time.
# 2018-05-13 17:06:26,603 - INFO - qianjiaozi.my: 42458003 is not following now, 314 following remains.
# 2018-05-13 17:06:26,604 - INFO - Now run the 87 time.
# 2018-05-13 17:06:27,738 - INFO - qianjiaozi.my: 58639439 is not following now, 313 following remains.
# 2018-05-13 17:06:27,739 - INFO - Now run the 88 time.
# 2018-05-13 17:06:28,913 - INFO - qianjiaozi.my: 15331001 is not following now, 312 following remains.
# 2018-05-13 17:06:28,914 - INFO - Now run the 89 time.
# 2018-05-13 17:06:30,055 - INFO - qianjiaozi.my: 1714546 is not following now, 311 following remains.
# 2018-05-13 17:06:30,055 - INFO - Now run the 90 time.
# 2018-05-13 17:06:31,155 - INFO - qianjiaozi.my: 67422239 is not following now, 310 following remains.
# 2018-05-13 17:06:31,155 - INFO - Now run the 91 time.
# 2018-05-13 17:06:32,248 - INFO - qianjiaozi.my: 8946209 is not following now, 309 following remains.
# 2018-05-13 17:06:32,248 - INFO - Now run the 92 time.
# 2018-05-13 17:06:33,351 - INFO - qianjiaozi.my: 65355306 is not following now, 308 following remains.
# 2018-05-13 17:06:33,351 - INFO - Now run the 93 time.
# 2018-05-13 17:06:34,443 - INFO - qianjiaozi.my: 41004785 is not following now, 307 following remains.
# 2018-05-13 17:06:34,445 - INFO - Now run the 94 time.
# 2018-05-13 17:06:35,545 - INFO - qianjiaozi.my: 54614603 is not following now, 306 following remains.
# 2018-05-13 17:06:35,545 - INFO - Now run the 95 time.
# 2018-05-13 17:06:36,633 - INFO - qianjiaozi.my: 13759465 is not following now, 305 following remains.
# 2018-05-13 17:06:36,633 - INFO - Now run the 96 time.
# 2018-05-13 17:06:37,731 - INFO - qianjiaozi.my: 52547039 is not following now, 304 following remains.
# 2018-05-13 17:06:37,732 - INFO - Now run the 97 time.
# 2018-05-13 17:06:38,834 - INFO - qianjiaozi.my: 60674255 is not following now, 303 following remains.
# 2018-05-13 17:06:38,835 - INFO - Now run the 98 time.
# 2018-05-13 17:06:39,934 - INFO - qianjiaozi.my: 18495924 is not following now, 302 following remains.
# 2018-05-13 17:06:39,934 - INFO - Now run the 99 time.
# 2018-05-13 17:06:41,033 - INFO - qianjiaozi.my: 24421077 is not following now, 301 following remains.
# 2018-05-13 17:06:41,033 - INFO - Now run the 100 time.
# 2018-05-13 17:06:42,135 - INFO - qianjiaozi.my: 50355931 is not following now, 300 following remains.
# 2018-05-13 17:06:42,135 - INFO - Now run the 101 time.
# 2018-05-13 17:06:43,226 - INFO - qianjiaozi.my: 14039935 is not following now, 299 following remains.
# 2018-05-13 17:06:43,226 - INFO - Now run the 102 time.
# 2018-05-13 17:06:44,319 - INFO - qianjiaozi.my: 37380877 is not following now, 298 following remains.
# 2018-05-13 17:06:44,319 - INFO - Now run the 103 time.
# 2018-05-13 17:06:45,403 - INFO - qianjiaozi.my: 68358788 is not following now, 297 following remains.
# 2018-05-13 17:06:45,404 - INFO - Now run the 104 time.
# 2018-05-13 17:06:46,489 - INFO - qianjiaozi.my: 14140947 is not following now, 296 following remains.
# 2018-05-13 17:06:46,490 - INFO - Now run the 105 time.
# 2018-05-13 17:06:47,579 - INFO - qianjiaozi.my: 16199039 is not following now, 295 following remains.
# 2018-05-13 17:06:47,579 - INFO - Now run the 106 time.
# 2018-05-13 17:06:48,665 - INFO - qianjiaozi.my: 64286590 is not following now, 294 following remains.
# 2018-05-13 17:06:48,665 - INFO - Now run the 107 time.
# 2018-05-13 17:06:49,762 - INFO - qianjiaozi.my: 16629833 is not following now, 293 following remains.
# 2018-05-13 17:06:49,762 - INFO - Now run the 108 time.
# 2018-05-13 17:06:50,864 - INFO - qianjiaozi.my: 2488837 is not following now, 292 following remains.
# 2018-05-13 17:06:50,865 - INFO - Now run the 109 time.
# 2018-05-13 17:06:51,978 - INFO - qianjiaozi.my: 42106780 is not following now, 291 following remains.
# 2018-05-13 17:06:51,978 - INFO - Now run the 110 time.
# 2018-05-13 17:06:53,080 - INFO - qianjiaozi.my: 59665431 is not following now, 290 following remains.
# 2018-05-13 17:06:53,080 - INFO - Now run the 111 time.
# 2018-05-13 17:06:54,178 - INFO - qianjiaozi.my: 20535180 is not following now, 289 following remains.
# 2018-05-13 17:06:54,178 - INFO - Now run the 112 time.
# 2018-05-13 17:06:55,400 - INFO - qianjiaozi.my: 68049497 is not following now, 288 following remains.
# 2018-05-13 17:06:55,400 - INFO - Now run the 113 time.
# 2018-05-13 17:06:56,485 - INFO - qianjiaozi.my: 64120029 is not following now, 287 following remains.
# 2018-05-13 17:06:56,485 - INFO - Now run the 114 time.
# 2018-05-13 17:06:57,572 - INFO - qianjiaozi.my: 64595148 is not following now, 286 following remains.
# 2018-05-13 17:06:57,572 - INFO - Now run the 115 time.
# 2018-05-13 17:06:58,659 - INFO - qianjiaozi.my: 62085278 is not following now, 285 following remains.
# 2018-05-13 17:06:58,659 - INFO - Now run the 116 time.
# 2018-05-13 17:06:59,758 - INFO - qianjiaozi.my: 29479734 is not following now, 284 following remains.
# 2018-05-13 17:06:59,758 - INFO - Now run the 117 time.
# 2018-05-13 17:07:00,843 - INFO - qianjiaozi.my: 25849345 is not following now, 283 following remains.
# 2018-05-13 17:07:00,844 - INFO - Now run the 118 time.
# 2018-05-13 17:07:01,928 - INFO - qianjiaozi.my: 66636643 is not following now, 282 following remains.
# 2018-05-13 17:07:01,928 - INFO - Now run the 119 time.
# 2018-05-13 17:07:03,025 - INFO - qianjiaozi.my: 65646264 is not following now, 281 following remains.
# 2018-05-13 17:07:03,025 - INFO - Now run the 120 time.
# 2018-05-13 17:07:04,171 - INFO - qianjiaozi.my: 65707248 is not following now, 280 following remains.
# 2018-05-13 17:07:04,171 - INFO - Now run the 121 time.
# 2018-05-13 17:07:05,278 - INFO - qianjiaozi.my: 52852822 is not following now, 279 following remains.
# 2018-05-13 17:07:05,278 - INFO - Now run the 122 time.
# 2018-05-13 17:07:06,378 - INFO - qianjiaozi.my: 52667798 is not following now, 278 following remains.
# 2018-05-13 17:07:06,378 - INFO - Now run the 123 time.
# 2018-05-13 17:07:07,467 - INFO - qianjiaozi.my: 15121727 is not following now, 277 following remains.
# 2018-05-13 17:07:07,467 - INFO - Now run the 124 time.
# 2018-05-13 17:07:08,563 - INFO - qianjiaozi.my: 25314400 is not following now, 276 following remains.
# 2018-05-13 17:07:08,564 - INFO - Now run the 125 time.
# 2018-05-13 17:07:09,672 - INFO - qianjiaozi.my: 65490295 is not following now, 275 following remains.
# 2018-05-13 17:07:09,672 - INFO - Now run the 126 time.
# 2018-05-13 17:07:10,763 - INFO - qianjiaozi.my: 62483515 is not following now, 274 following remains.
# 2018-05-13 17:07:10,764 - INFO - Now run the 127 time.
# 2018-05-13 17:07:11,850 - INFO - qianjiaozi.my: 68508241 is not following now, 273 following remains.
# 2018-05-13 17:07:11,850 - INFO - Now run the 128 time.
# 2018-05-13 17:07:12,951 - INFO - qianjiaozi.my: 63296020 is not following now, 272 following remains.
# 2018-05-13 17:07:12,951 - INFO - Now run the 129 time.
# 2018-05-13 17:07:14,037 - INFO - qianjiaozi.my: 68391608 is not following now, 271 following remains.
# 2018-05-13 17:07:14,037 - INFO - Now run the 130 time.
# 2018-05-13 17:07:15,124 - INFO - qianjiaozi.my: 68507499 is not following now, 270 following remains.
# 2018-05-13 17:07:15,125 - INFO - Now run the 131 time.
# 2018-05-13 17:07:16,227 - INFO - qianjiaozi.my: 18774833 is not following now, 269 following remains.
# 2018-05-13 17:07:16,228 - INFO - Now run the 132 time.
# 2018-05-13 17:07:17,341 - INFO - qianjiaozi.my: 19694693 is not following now, 268 following remains.
# 2018-05-13 17:07:17,341 - INFO - Now run the 133 time.
# 2018-05-13 17:07:18,442 - INFO - qianjiaozi.my: 13041139 is not following now, 267 following remains.
# 2018-05-13 17:07:18,443 - INFO - Now run the 134 time.
# 2018-05-13 17:07:19,542 - INFO - qianjiaozi.my: 57267757 is not following now, 266 following remains.
# 2018-05-13 17:07:19,542 - INFO - Now run the 135 time.
# 2018-05-13 17:07:20,631 - INFO - qianjiaozi.my: 22095009 is not following now, 265 following remains.
# 2018-05-13 17:07:20,631 - INFO - Now run the 136 time.
# 2018-05-13 17:07:21,746 - INFO - qianjiaozi.my: 66318078 is not following now, 264 following remains.
# 2018-05-13 17:07:21,746 - INFO - Now run the 137 time.
# 2018-05-13 17:07:22,847 - INFO - qianjiaozi.my: 27611666 is not following now, 263 following remains.
# 2018-05-13 17:07:22,847 - INFO - Now run the 138 time.
# 2018-05-13 17:07:23,965 - INFO - qianjiaozi.my: 61124836 is not following now, 262 following remains.
# 2018-05-13 17:07:23,966 - INFO - Now run the 139 time.
# 2018-05-13 17:07:25,102 - INFO - qianjiaozi.my: 17103001 is not following now, 261 following remains.
# 2018-05-13 17:07:25,104 - INFO - Now run the 140 time.
# 2018-05-13 17:07:26,214 - INFO - qianjiaozi.my: 44245995 is not following now, 260 following remains.
# 2018-05-13 17:07:26,215 - INFO - Now run the 141 time.
# 2018-05-13 17:07:27,340 - INFO - qianjiaozi.my: 65648499 is not following now, 259 following remains.
# 2018-05-13 17:07:27,341 - INFO - Now run the 142 time.
# 2018-05-13 17:07:28,458 - INFO - qianjiaozi.my: 54092714 is not following now, 258 following remains.
# 2018-05-13 17:07:28,459 - INFO - Now run the 143 time.
# 2018-05-13 17:07:29,552 - INFO - qianjiaozi.my: 21054978 is not following now, 257 following remains.
# 2018-05-13 17:07:29,554 - INFO - Now run the 144 time.
# 2018-05-13 17:07:30,653 - INFO - qianjiaozi.my: 30363523 is not following now, 256 following remains.
# 2018-05-13 17:07:30,654 - INFO - Now run the 145 time.
# 2018-05-13 17:07:31,777 - INFO - qianjiaozi.my: 39655430 is not following now, 255 following remains.
# 2018-05-13 17:07:31,777 - INFO - Now run the 146 time.
# 2018-05-13 17:07:32,864 - INFO - qianjiaozi.my: 22643358 is not following now, 254 following remains.
# 2018-05-13 17:07:32,865 - INFO - Now run the 147 time.
# 2018-05-13 17:07:33,974 - INFO - qianjiaozi.my: 43764843 is not following now, 253 following remains.
# 2018-05-13 17:07:33,975 - INFO - Now run the 148 time.
# 2018-05-13 17:07:35,108 - INFO - qianjiaozi.my: 68547401 is not following now, 252 following remains.
# 2018-05-13 17:07:35,110 - INFO - Now run the 149 time.
# 2018-05-13 17:07:36,244 - INFO - qianjiaozi.my: 62772572 is not following now, 251 following remains.
# 2018-05-13 17:07:36,244 - INFO - Now run the 150 time.
# 2018-05-13 17:07:37,327 - INFO - qianjiaozi.my: 39417239 is not following now, 250 following remains.
# 2018-05-13 17:07:37,327 - INFO - Now run the 151 time.
# 2018-05-13 17:07:38,429 - INFO - qianjiaozi.my: 66275774 is not following now, 249 following remains.
# 2018-05-13 17:07:38,430 - INFO - Now run the 152 time.
# 2018-05-13 17:07:39,517 - INFO - qianjiaozi.my: 64960424 is not following now, 248 following remains.
# 2018-05-13 17:07:39,518 - INFO - Now run the 153 time.
# 2018-05-13 17:07:40,606 - INFO - qianjiaozi.my: 20449631 is not following now, 247 following remains.
# 2018-05-13 17:07:40,606 - INFO - Now run the 154 time.
# 2018-05-13 17:07:41,700 - INFO - qianjiaozi.my: 27636640 is not following now, 246 following remains.
# 2018-05-13 17:07:41,700 - INFO - Now run the 155 time.
# 2018-05-13 17:07:42,801 - INFO - qianjiaozi.my: 26799702 is not following now, 245 following remains.
# 2018-05-13 17:07:42,802 - INFO - Now run the 156 time.
# 2018-05-13 17:07:43,888 - INFO - qianjiaozi.my: 43160830 is not following now, 244 following remains.
# 2018-05-13 17:07:43,888 - INFO - Now run the 157 time.
# 2018-05-13 17:07:44,987 - INFO - qianjiaozi.my: 32920392 is not following now, 243 following remains.
# 2018-05-13 17:07:44,988 - INFO - Now run the 158 time.
# 2018-05-13 17:07:46,071 - INFO - qianjiaozi.my: 33454142 is not following now, 242 following remains.
# 2018-05-13 17:07:46,072 - INFO - Now run the 159 time.
# 2018-05-13 17:07:47,173 - INFO - qianjiaozi.my: 53326576 is not following now, 241 following remains.
# 2018-05-13 17:07:47,173 - INFO - Now run the 160 time.
# 2018-05-13 17:07:48,259 - INFO - qianjiaozi.my: 2415088 is not following now, 240 following remains.
# 2018-05-13 17:07:48,259 - INFO - Now run the 161 time.
# 2018-05-13 17:07:49,342 - INFO - qianjiaozi.my: 60744305 is not following now, 239 following remains.
# 2018-05-13 17:07:49,342 - INFO - Now run the 162 time.
# 2018-05-13 17:07:50,428 - INFO - qianjiaozi.my: 18639411 is not following now, 238 following remains.
# 2018-05-13 17:07:50,429 - INFO - Now run the 163 time.
# 2018-05-13 17:07:51,529 - INFO - qianjiaozi.my: 38661356 is not following now, 237 following remains.
# 2018-05-13 17:07:51,529 - INFO - Now run the 164 time.
# 2018-05-13 17:07:52,618 - INFO - qianjiaozi.my: 24746312 is not following now, 236 following remains.
# 2018-05-13 17:07:52,618 - INFO - Now run the 165 time.
# 2018-05-13 17:07:53,701 - INFO - qianjiaozi.my: 14576894 is not following now, 235 following remains.
# 2018-05-13 17:07:53,702 - INFO - Now run the 166 time.
# 2018-05-13 17:07:54,799 - INFO - qianjiaozi.my: 68417017 is not following now, 234 following remains.
# 2018-05-13 17:07:54,799 - INFO - Now run the 167 time.
# 2018-05-13 17:07:55,898 - INFO - qianjiaozi.my: 47895218 is not following now, 233 following remains.
# 2018-05-13 17:07:55,899 - INFO - Now run the 168 time.
# 2018-05-13 17:07:56,999 - INFO - qianjiaozi.my: 9239175 is not following now, 232 following remains.
# 2018-05-13 17:07:56,999 - INFO - Now run the 169 time.
# 2018-05-13 17:07:58,117 - INFO - qianjiaozi.my: 34137417 is not following now, 231 following remains.
# 2018-05-13 17:07:58,117 - INFO - Now run the 170 time.
# 2018-05-13 17:07:59,220 - INFO - qianjiaozi.my: 35589518 is not following now, 230 following remains.
# 2018-05-13 17:07:59,220 - INFO - Now run the 171 time.
# 2018-05-13 17:08:00,308 - INFO - qianjiaozi.my: 8595222 is not following now, 229 following remains.
# 2018-05-13 17:08:00,309 - INFO - Now run the 172 time.
# 2018-05-13 17:08:01,403 - INFO - qianjiaozi.my: 52452477 is not following now, 228 following remains.
# 2018-05-13 17:08:01,403 - INFO - Now run the 173 time.
# 2018-05-13 17:08:02,496 - INFO - qianjiaozi.my: 59871218 is not following now, 227 following remains.
# 2018-05-13 17:08:02,496 - INFO - Now run the 174 time.
# 2018-05-13 17:08:03,582 - INFO - qianjiaozi.my: 24195300 is not following now, 226 following remains.
# 2018-05-13 17:08:03,582 - INFO - Now run the 175 time.
# 2018-05-13 17:08:04,675 - INFO - qianjiaozi.my: 7542781 is not following now, 225 following remains.
# 2018-05-13 17:08:04,676 - INFO - Now run the 176 time.
# 2018-05-13 17:08:05,778 - INFO - qianjiaozi.my: 57359313 is not following now, 224 following remains.
# 2018-05-13 17:08:05,778 - INFO - Now run the 177 time.
# 2018-05-13 17:08:06,863 - INFO - qianjiaozi.my: 58000857 is not following now, 223 following remains.
# 2018-05-13 17:08:06,863 - INFO - Now run the 178 time.
# 2018-05-13 17:08:07,966 - INFO - qianjiaozi.my: 9251905 is not following now, 222 following remains.
# 2018-05-13 17:08:07,967 - INFO - Now run the 179 time.
# 2018-05-13 17:08:09,064 - INFO - qianjiaozi.my: 1745159 is not following now, 221 following remains.
# 2018-05-13 17:08:09,064 - INFO - Now run the 180 time.
# 2018-05-13 17:08:10,166 - INFO - qianjiaozi.my: 16910241 is not following now, 220 following remains.
# 2018-05-13 17:08:10,167 - INFO - Now run the 181 time.
# 2018-05-13 17:08:11,260 - INFO - qianjiaozi.my: 68612703 is not following now, 219 following remains.
# 2018-05-13 17:08:11,260 - INFO - Now run the 182 time.
# 2018-05-13 17:08:12,350 - INFO - qianjiaozi.my: 55913916 is not following now, 218 following remains.
# 2018-05-13 17:08:12,350 - INFO - Now run the 183 time.
# 2018-05-13 17:08:13,442 - INFO - qianjiaozi.my: 19747798 is not following now, 217 following remains.
# 2018-05-13 17:08:13,442 - INFO - Now run the 184 time.
# 2018-05-13 17:08:14,539 - INFO - qianjiaozi.my: 16283126 is not following now, 216 following remains.
# 2018-05-13 17:08:14,540 - INFO - Now run the 185 time.
# 2018-05-13 17:08:15,645 - INFO - qianjiaozi.my: 10247778 is not following now, 215 following remains.
# 2018-05-13 17:08:15,645 - INFO - Now run the 186 time.
# 2018-05-13 17:08:16,740 - INFO - qianjiaozi.my: 13076085 is not following now, 214 following remains.
# 2018-05-13 17:08:16,741 - INFO - Now run the 187 time.
# 2018-05-13 17:08:17,862 - INFO - qianjiaozi.my: 38338926 is not following now, 213 following remains.
# 2018-05-13 17:08:17,863 - INFO - Now run the 188 time.
# 2018-05-13 17:08:18,959 - INFO - qianjiaozi.my: 57446114 is not following now, 212 following remains.
# 2018-05-13 17:08:18,960 - INFO - Now run the 189 time.
# 2018-05-13 17:08:20,058 - INFO - qianjiaozi.my: 51818264 is not following now, 211 following remains.
# 2018-05-13 17:08:20,058 - INFO - Now run the 190 time.
# 2018-05-13 17:08:21,160 - INFO - qianjiaozi.my: 68571021 is not following now, 210 following remains.
# 2018-05-13 17:08:21,161 - INFO - Now run the 191 time.
# 2018-05-13 17:08:22,247 - INFO - qianjiaozi.my: 58307409 is not following now, 209 following remains.
# 2018-05-13 17:08:22,248 - INFO - Now run the 192 time.
# 2018-05-13 17:08:23,348 - INFO - qianjiaozi.my: 50920291 is not following now, 208 following remains.
# 2018-05-13 17:08:23,350 - INFO - Now run the 193 time.
# 2018-05-13 17:08:24,462 - INFO - qianjiaozi.my: 53262055 is not following now, 207 following remains.
# 2018-05-13 17:08:24,463 - INFO - Now run the 194 time.
# 2018-05-13 17:08:25,565 - INFO - qianjiaozi.my: 55724672 is not following now, 206 following remains.
# 2018-05-13 17:08:25,567 - INFO - Now run the 195 time.
# 2018-05-13 17:08:26,716 - INFO - qianjiaozi.my: 37751082 is not following now, 205 following remains.
# 2018-05-13 17:08:26,717 - INFO - Now run the 196 time.
# 2018-05-13 17:08:27,838 - INFO - qianjiaozi.my: 68551410 is not following now, 204 following remains.
# 2018-05-13 17:08:27,839 - INFO - Now run the 197 time.
# 2018-05-13 17:08:28,936 - INFO - qianjiaozi.my: 5506773 is not following now, 203 following remains.
# 2018-05-13 17:08:28,937 - INFO - Now run the 198 time.
# 2018-05-13 17:08:30,057 - INFO - qianjiaozi.my: 46748700 is not following now, 202 following remains.
# 2018-05-13 17:08:30,057 - INFO - Now run the 199 time.
# 2018-05-13 17:08:31,140 - INFO - qianjiaozi.my: 7652149 is not following now, 201 following remains.
# 2018-05-13 17:08:31,141 - INFO - Now run the 200 time.
# 2018-05-13 17:08:32,256 - INFO - qianjiaozi.my: 28845938 is not following now, 200 following remains.
# 2018-05-13 17:08:32,257 - INFO - Now run the 201 time.
# 2018-05-13 17:08:33,360 - INFO - qianjiaozi.my: 31543113 is not following now, 199 following remains.
# 2018-05-13 17:08:33,361 - INFO - Now run the 202 time.
# 2018-05-13 17:08:34,495 - INFO - qianjiaozi.my: 18097112 is not following now, 198 following remains.
# 2018-05-13 17:08:34,496 - INFO - Now run the 203 time.
# 2018-05-13 17:08:35,614 - INFO - qianjiaozi.my: 719614 is not following now, 197 following remains.
# 2018-05-13 17:08:35,615 - INFO - Now run the 204 time.
# 2018-05-13 17:08:36,735 - INFO - qianjiaozi.my: 21673419 is not following now, 196 following remains.
# 2018-05-13 17:08:36,736 - INFO - Now run the 205 time.
# 2018-05-13 17:08:37,850 - INFO - qianjiaozi.my: 67050492 is not following now, 195 following remains.
# 2018-05-13 17:08:37,852 - INFO - Now run the 206 time.
# 2018-05-13 17:08:38,984 - INFO - qianjiaozi.my: 62959400 is not following now, 194 following remains.
# 2018-05-13 17:08:38,985 - INFO - Now run the 207 time.
# 2018-05-13 17:08:40,099 - INFO - qianjiaozi.my: 57994352 is not following now, 193 following remains.
# 2018-05-13 17:08:40,100 - INFO - Now run the 208 time.
# 2018-05-13 17:08:41,204 - INFO - qianjiaozi.my: 8900494 is not following now, 192 following remains.
# 2018-05-13 17:08:41,204 - INFO - Now run the 209 time.
# 2018-05-13 17:08:42,305 - INFO - qianjiaozi.my: 50109567 is not following now, 191 following remains.
# 2018-05-13 17:08:42,305 - INFO - Now run the 210 time.
# 2018-05-13 17:08:43,410 - INFO - qianjiaozi.my: 10056532 is not following now, 190 following remains.
# 2018-05-13 17:08:43,411 - INFO - Now run the 211 time.
# 2018-05-13 17:08:44,501 - INFO - qianjiaozi.my: 22988423 is not following now, 189 following remains.
# 2018-05-13 17:08:44,501 - INFO - Now run the 212 time.
# 2018-05-13 17:08:45,625 - INFO - qianjiaozi.my: 30119270 is not following now, 188 following remains.
# 2018-05-13 17:08:45,626 - INFO - Now run the 213 time.
# 2018-05-13 17:08:46,712 - INFO - qianjiaozi.my: 31582380 is not following now, 187 following remains.
# 2018-05-13 17:08:46,713 - INFO - Now run the 214 time.
# 2018-05-13 17:08:47,804 - INFO - qianjiaozi.my: 55286292 is not following now, 186 following remains.
# 2018-05-13 17:08:47,805 - INFO - Now run the 215 time.
# 2018-05-13 17:08:48,907 - INFO - qianjiaozi.my: 29829191 is not following now, 185 following remains.
# 2018-05-13 17:08:48,907 - INFO - Now run the 216 time.
# 2018-05-13 17:08:49,999 - INFO - qianjiaozi.my: 66338501 is not following now, 184 following remains.
# 2018-05-13 17:08:49,999 - INFO - Now run the 217 time.
# 2018-05-13 17:08:51,097 - INFO - qianjiaozi.my: 61423923 is not following now, 183 following remains.
# 2018-05-13 17:08:51,097 - INFO - Now run the 218 time.
# 2018-05-13 17:08:52,194 - INFO - qianjiaozi.my: 65939575 is not following now, 182 following remains.
# 2018-05-13 17:08:52,195 - INFO - Now run the 219 time.
# 2018-05-13 17:08:53,283 - INFO - qianjiaozi.my: 64731394 is not following now, 181 following remains.
# 2018-05-13 17:08:53,283 - INFO - Now run the 220 time.
# 2018-05-13 17:08:54,380 - INFO - qianjiaozi.my: 67722456 is not following now, 180 following remains.
# 2018-05-13 17:08:54,380 - INFO - Now run the 221 time.
# 2018-05-13 17:08:55,483 - INFO - qianjiaozi.my: 41007472 is not following now, 179 following remains.
# 2018-05-13 17:08:55,483 - INFO - Now run the 222 time.
# 2018-05-13 17:09:01,602 - INFO - qianjiaozi.my: 35967190 is not following now, 178 following remains.
# 2018-05-13 17:09:01,602 - INFO - Now run the 223 time.
# 2018-05-13 17:09:07,700 - INFO - qianjiaozi.my: 50786633 is not following now, 177 following remains.
# 2018-05-13 17:09:07,700 - INFO - Now run the 224 time.
# 2018-05-13 17:09:13,812 - INFO - qianjiaozi.my: 64942073 is not following now, 176 following remains.
# 2018-05-13 17:09:13,813 - INFO - Now run the 225 time.
# 2018-05-13 17:09:19,936 - INFO - qianjiaozi.my: 55055568 is not following now, 175 following remains.
# 2018-05-13 17:09:19,936 - INFO - Now run the 226 time.
# 2018-05-13 17:09:26,049 - INFO - qianjiaozi.my: 12392174 is not following now, 174 following remains.
# 2018-05-13 17:09:26,051 - INFO - Now run the 227 time.
# 2018-05-13 17:09:32,194 - INFO - qianjiaozi.my: 64539592 is not following now, 173 following remains.
# 2018-05-13 17:09:32,195 - INFO - Now run the 228 time.
# 2018-05-13 17:09:38,316 - INFO - qianjiaozi.my: 55946433 is not following now, 172 following remains.
# 2018-05-13 17:09:38,316 - INFO - Now run the 229 time.
# 2018-05-13 17:09:44,432 - INFO - qianjiaozi.my: 15648265 is not following now, 171 following remains.
# 2018-05-13 17:09:44,432 - INFO - Now run the 230 time.
# 2018-05-13 17:09:50,533 - INFO - qianjiaozi.my: 68270286 is not following now, 170 following remains.
# 2018-05-13 17:09:50,534 - INFO - Now run the 231 time.
# 2018-05-13 17:09:56,624 - INFO - qianjiaozi.my: 59290985 is not following now, 169 following remains.
# 2018-05-13 17:09:56,624 - INFO - Now run the 232 time.
# 2018-05-13 17:10:02,733 - INFO - qianjiaozi.my: 42809927 is not following now, 168 following remains.
# 2018-05-13 17:10:02,733 - INFO - Now run the 233 time.
# 2018-05-13 17:10:08,837 - INFO - qianjiaozi.my: 27093535 is not following now, 167 following remains.
# 2018-05-13 17:10:08,837 - INFO - Now run the 234 time.
# 2018-05-13 17:10:14,953 - INFO - qianjiaozi.my: 65769693 is not following now, 166 following remains.
# 2018-05-13 17:10:14,954 - INFO - Now run the 235 time.
# 2018-05-13 17:10:21,057 - INFO - qianjiaozi.my: 49219886 is not following now, 165 following remains.
# 2018-05-13 17:10:21,057 - INFO - Now run the 236 time.
# 2018-05-13 17:10:27,155 - INFO - qianjiaozi.my: 36553300 is not following now, 164 following remains.
# 2018-05-13 17:10:27,156 - INFO - Now run the 237 time.
# 2018-05-13 17:10:33,327 - INFO - qianjiaozi.my: 21138053 is not following now, 163 following remains.
# 2018-05-13 17:10:33,329 - INFO - Now run the 238 time.
# 2018-05-13 17:10:39,486 - INFO - qianjiaozi.my: 63526358 is not following now, 162 following remains.
# 2018-05-13 17:10:39,487 - INFO - Now run the 239 time.
# 2018-05-13 17:10:45,607 - INFO - qianjiaozi.my: 33412045 is not following now, 161 following remains.
# 2018-05-13 17:10:45,608 - INFO - Now run the 240 time.
# 2018-05-13 17:10:51,718 - INFO - qianjiaozi.my: 61137135 is not following now, 160 following remains.
# 2018-05-13 17:10:51,718 - INFO - Now run the 241 time.
# 2018-05-13 17:10:57,833 - INFO - qianjiaozi.my: 14904755 is not following now, 159 following remains.
# 2018-05-13 17:10:57,833 - INFO - Now run the 242 time.
# 2018-05-13 17:11:03,934 - INFO - qianjiaozi.my: 63212464 is not following now, 158 following remains.
# 2018-05-13 17:11:03,934 - INFO - Now run the 243 time.
# 2018-05-13 17:11:10,033 - INFO - qianjiaozi.my: 17816227 is not following now, 157 following remains.
# 2018-05-13 17:11:10,035 - INFO - Now run the 244 time.
# 2018-05-13 17:11:16,179 - INFO - qianjiaozi.my: 22361632 is not following now, 156 following remains.
# 2018-05-13 17:11:16,179 - INFO - Now run the 245 time.
# 2018-05-13 17:11:22,286 - INFO - qianjiaozi.my: 58323888 is not following now, 155 following remains.
# 2018-05-13 17:11:22,287 - INFO - Now run the 246 time.
# 2018-05-13 17:11:28,446 - INFO - qianjiaozi.my: 61807579 is not following now, 154 following remains.
# 2018-05-13 17:11:28,448 - INFO - Now run the 247 time.
# 2018-05-13 17:11:34,592 - INFO - qianjiaozi.my: 17000026 is not following now, 153 following remains.
# 2018-05-13 17:11:34,593 - INFO - Now run the 248 time.
# 2018-05-13 17:11:40,730 - INFO - qianjiaozi.my: 45756701 is not following now, 152 following remains.
# 2018-05-13 17:11:40,732 - INFO - Now run the 249 time.
# 2018-05-13 17:11:46,866 - INFO - qianjiaozi.my: 56771071 is not following now, 151 following remains.
# 2018-05-13 17:11:46,867 - INFO - Now run the 250 time.
# 2018-05-13 17:11:52,985 - INFO - qianjiaozi.my: 53211423 is not following now, 150 following remains.
# 2018-05-13 17:11:52,986 - INFO - Now run the 251 time.
# 2018-05-13 17:11:59,077 - INFO - qianjiaozi.my: 68809866 is not following now, 149 following remains.
# 2018-05-13 17:11:59,077 - INFO - Now run the 252 time.
# 2018-05-13 17:12:05,187 - INFO - qianjiaozi.my: 68231042 is not following now, 148 following remains.
# 2018-05-13 17:12:05,187 - INFO - Now run the 253 time.
# 2018-05-13 17:12:11,292 - INFO - qianjiaozi.my: 19336492 is not following now, 147 following remains.
# 2018-05-13 17:12:11,292 - INFO - Now run the 254 time.
# 2018-05-13 17:12:17,389 - INFO - qianjiaozi.my: 62284800 is not following now, 146 following remains.
# 2018-05-13 17:12:17,390 - INFO - Now run the 255 time.
# 2018-05-13 17:12:23,507 - INFO - qianjiaozi.my: 3281213 is not following now, 145 following remains.
# 2018-05-13 17:12:23,507 - INFO - Now run the 256 time.
# 2018-05-13 17:12:29,603 - INFO - qianjiaozi.my: 66911115 is not following now, 144 following remains.
# 2018-05-13 17:12:29,604 - INFO - Now run the 257 time.
# 2018-05-13 17:12:35,762 - INFO - qianjiaozi.my: 30566355 is not following now, 143 following remains.
# 2018-05-13 17:12:35,765 - INFO - Now run the 258 time.
# 2018-05-13 17:12:41,950 - INFO - qianjiaozi.my: 61314540 is not following now, 142 following remains.
# 2018-05-13 17:12:41,952 - INFO - Now run the 259 time.
# 2018-05-13 17:12:48,072 - INFO - qianjiaozi.my: 6119487 is not following now, 141 following remains.
# 2018-05-13 17:12:48,073 - INFO - Now run the 260 time.
# 2018-05-13 17:12:54,184 - INFO - qianjiaozi.my: 61178858 is not following now, 140 following remains.
# 2018-05-13 17:12:54,185 - INFO - Now run the 261 time.
# 2018-05-13 17:13:00,323 - INFO - qianjiaozi.my: 31683779 is not following now, 139 following remains.
# 2018-05-13 17:13:00,324 - INFO - Now run the 262 time.
# 2018-05-13 17:13:06,467 - INFO - qianjiaozi.my: 3793452 is not following now, 138 following remains.
# 2018-05-13 17:13:06,467 - INFO - Now run the 263 time.
# 2018-05-13 17:13:12,571 - INFO - qianjiaozi.my: 20229495 is not following now, 137 following remains.
# 2018-05-13 17:13:12,571 - INFO - Now run the 264 time.
# 2018-05-13 17:13:18,674 - INFO - qianjiaozi.my: 61743216 is not following now, 136 following remains.
# 2018-05-13 17:13:18,674 - INFO - Now run the 265 time.
# 2018-05-13 17:13:24,783 - INFO - qianjiaozi.my: 24768381 is not following now, 135 following remains.
# 2018-05-13 17:13:24,785 - INFO - Now run the 266 time.
# 2018-05-13 17:13:30,887 - INFO - qianjiaozi.my: 67591156 is not following now, 134 following remains.
# 2018-05-13 17:13:30,888 - INFO - Now run the 267 time.
# 2018-05-13 17:13:37,055 - INFO - qianjiaozi.my: 68738438 is not following now, 133 following remains.
# 2018-05-13 17:13:37,056 - INFO - Now run the 268 time.
# 2018-05-13 17:13:43,258 - INFO - qianjiaozi.my: 45865894 is not following now, 132 following remains.
# 2018-05-13 17:13:43,259 - INFO - Now run the 269 time.
# 2018-05-13 17:13:49,404 - INFO - qianjiaozi.my: 64529056 is not following now, 131 following remains.
# 2018-05-13 17:13:49,404 - INFO - Now run the 270 time.
# 2018-05-13 17:13:55,531 - INFO - qianjiaozi.my: 59629955 is not following now, 130 following remains.
# 2018-05-13 17:13:55,531 - INFO - Now run the 271 time.
# 2018-05-13 17:14:01,652 - INFO - qianjiaozi.my: 60870815 is not following now, 129 following remains.
# 2018-05-13 17:14:01,653 - INFO - Now run the 272 time.
# 2018-05-13 17:14:07,767 - INFO - qianjiaozi.my: 67293682 is not following now, 128 following remains.
# 2018-05-13 17:14:07,768 - INFO - Now run the 273 time.
# 2018-05-13 17:14:13,898 - INFO - qianjiaozi.my: 62521146 is not following now, 127 following remains.
# 2018-05-13 17:14:13,898 - INFO - Now run the 274 time.
# 2018-05-13 17:14:20,020 - INFO - qianjiaozi.my: 39715267 is not following now, 126 following remains.
# 2018-05-13 17:14:20,020 - INFO - Now run the 275 time.
# 2018-05-13 17:14:26,131 - INFO - qianjiaozi.my: 10232579 is not following now, 125 following remains.
# 2018-05-13 17:14:26,132 - INFO - Now run the 276 time.
# 2018-05-13 17:14:32,254 - INFO - qianjiaozi.my: 53482808 is not following now, 124 following remains.
# 2018-05-13 17:14:32,254 - INFO - Now run the 277 time.
# 2018-05-13 17:14:38,383 - INFO - qianjiaozi.my: 33340624 is not following now, 123 following remains.
# 2018-05-13 17:14:38,384 - INFO - Now run the 278 time.
# 2018-05-13 17:14:44,514 - INFO - qianjiaozi.my: 10475395 is not following now, 122 following remains.
# 2018-05-13 17:14:44,515 - INFO - Now run the 279 time.
# 2018-05-13 17:14:50,684 - INFO - qianjiaozi.my: 16568960 is not following now, 121 following remains.
# 2018-05-13 17:14:50,685 - INFO - Now run the 280 time.
# 2018-05-13 17:14:56,803 - INFO - qianjiaozi.my: 64389692 is not following now, 120 following remains.
# 2018-05-13 17:14:56,804 - INFO - Now run the 281 time.
# 2018-05-13 17:15:02,916 - INFO - qianjiaozi.my: 45352598 is not following now, 119 following remains.
# 2018-05-13 17:15:02,916 - INFO - Now run the 282 time.
# 2018-05-13 17:15:09,036 - INFO - qianjiaozi.my: 58247168 is not following now, 118 following remains.
# 2018-05-13 17:15:09,036 - INFO - Now run the 283 time.
# 2018-05-13 17:15:15,146 - INFO - qianjiaozi.my: 42749518 is not following now, 117 following remains.
# 2018-05-13 17:15:15,146 - INFO - Now run the 284 time.
# 2018-05-13 17:15:21,272 - INFO - qianjiaozi.my: 59130908 is not following now, 116 following remains.
# 2018-05-13 17:15:21,272 - INFO - Now run the 285 time.
# ...
# 2018-05-13 19:23:45,102 - INFO - tengus1.id: 49527489 is following now, 15 following remains.
# 2018-05-13 19:23:45,102 - INFO - Now run the 386 time.
# 2018-05-13 19:23:46,220 - INFO - tengus1.id: 18508213 is following now, 14 following remains.
# 2018-05-13 19:23:46,221 - INFO - Now run the 387 time.
# 2018-05-13 19:23:47,403 - INFO - tengus1.id: 22070457 is following now, 13 following remains.
# 2018-05-13 19:23:47,404 - INFO - Now run the 388 time.
# 2018-05-13 19:23:48,562 - INFO - tengus1.id: 67978346 is following now, 12 following remains.
# 2018-05-13 19:23:48,563 - INFO - Now run the 389 time.
# 2018-05-13 19:23:49,705 - INFO - tengus1.id: 24773547 is following now, 11 following remains.
# 2018-05-13 19:23:49,705 - INFO - Now run the 390 time.
# 2018-05-13 19:23:50,810 - INFO - tengus1.id: 69025198 is following now, 10 following remains.
# 2018-05-13 19:23:50,810 - INFO - Now run the 391 time.
# 2018-05-13 19:23:51,969 - INFO - tengus1.id: 20297576 is following now, 9 following remains.
# 2018-05-13 19:23:51,969 - INFO - Now run the 392 time.
# 2018-05-13 19:23:53,115 - INFO - tengus1.id: 37820105 is following now, 8 following remains.
# 2018-05-13 19:23:53,115 - INFO - Now run the 393 time.
# 2018-05-13 19:23:54,228 - INFO - tengus1.id: 30310619 is following now, 7 following remains.
# 2018-05-13 19:23:54,229 - INFO - Now run the 394 time.
# 2018-05-13 19:23:55,393 - INFO - tengus1.id: 14679263 is following now, 6 following remains.
# 2018-05-13 19:23:55,394 - INFO - Now run the 395 time.
# 2018-05-13 19:23:56,556 - INFO - tengus1.id: 16908195 is following now, 5 following remains.
# 2018-05-13 19:23:56,556 - INFO - Now run the 396 time.
# 2018-05-13 19:23:57,664 - INFO - tengus1.id: 46242879 is following now, 4 following remains.
# 2018-05-13 19:23:57,664 - INFO - Now run the 397 time.
# 2018-05-13 19:23:58,831 - INFO - tengus1.id: 61100592 is following now, 3 following remains.
# 2018-05-13 19:23:58,831 - INFO - Now run the 398 time.
# 2018-05-13 19:23:59,933 - INFO - tengus1.id: 54541071 is following now, 2 following remains.
# 2018-05-13 19:23:59,933 - INFO - Now run the 399 time.
# 2018-05-13 19:24:01,051 - INFO - tengus1.id: 12129373 is following now, 1 following remains.
# 2018-05-13 19:24:01,051 - INFO - Now run the 400 time.
# 2018-05-13 19:24:02,215 - INFO - tengus1.id: 29028555 is following now, 0 following remains.
# 2018-05-13 19:24:05,271 - INFO - Finished running the script on tengus1.id.
# 2018-05-13 19:24:05,272 - INFO - Now it's running the script on tengus2.id.
# 2018-05-13 19:24:05,273 - INFO - Open the browser.
# 2018-05-13 19:25:14,817 - INFO - Start to login.
# 2018-05-13 19:25:35,443 - INFO - Login completed.
# 2018-05-13 19:25:45,446 - INFO - Switch to my following list.
# 2018-05-13 19:26:20,916 - INFO - 1 following on the list.
# 2018-05-13 19:26:20,917 - INFO - Roll the page for 1 time.
# 2018-05-13 19:26:22,953 - INFO - 1 following on the list.
# 2018-05-13 19:26:22,954 - INFO - Roll the page for 2 time.
# 2018-05-13 19:26:25,011 - INFO - 1 following on the list.
# 2018-05-13 19:26:25,013 - INFO - Roll the page for 3 time.
# 2018-05-13 19:26:27,070 - INFO - 1 following on the list.
# 2018-05-13 19:26:27,071 - INFO - Roll the page for 4 time.
# 2018-05-13 19:26:29,108 - INFO - 1 following on the list.
# 2018-05-13 19:26:29,109 - INFO - Roll the page for 5 time.
# 2018-05-13 19:26:31,145 - INFO - 1 following on the list.
# 2018-05-13 19:26:31,145 - INFO - Roll the page for 6 time.
# 2018-05-13 19:26:33,180 - INFO - 1 following on the list.
# 2018-05-13 19:26:33,181 - INFO - Roll the page for 7 time.
# 2018-05-13 19:26:35,222 - INFO - 1 following on the list.
# 2018-05-13 19:26:35,223 - INFO - Roll the page for 8 time.
# 2018-05-13 19:26:37,259 - INFO - 1 following on the list.
# 2018-05-13 19:26:37,259 - INFO - Roll the page for 9 time.
# 2018-05-13 19:26:39,296 - INFO - 1 following on the list.
# 2018-05-13 19:26:39,297 - INFO - Roll the page for 10 time.
# 2018-05-13 19:26:41,344 - INFO - 1 following on the list.
# 2018-05-13 19:26:41,345 - INFO - Roll the page for 11 time.
# 2018-05-13 19:26:43,422 - INFO - 1 following on the list.
# 2018-05-13 19:26:43,423 - INFO - Roll the page for 12 time.
# 2018-05-13 19:26:45,483 - INFO - 1 following on the list.
# 2018-05-13 19:26:45,484 - INFO - Roll the page for 13 time.
# 2018-05-13 19:26:47,540 - INFO - 1 following on the list.
# 2018-05-13 19:26:47,541 - INFO - Roll the page for 14 time.
# 2018-05-13 19:26:49,595 - INFO - 1 following on the list.
# 2018-05-13 19:26:49,595 - INFO - Roll the page for 15 time.
# 2018-05-13 19:26:51,627 - INFO - 1 following on the list.
# 2018-05-13 19:26:51,627 - INFO - Roll the page for 16 time.
# 2018-05-13 19:26:53,661 - INFO - 1 following on the list.
# 2018-05-13 19:26:53,661 - INFO - Roll the page for 17 time.
# 2018-05-13 19:26:55,695 - INFO - 1 following on the list.
# 2018-05-13 19:26:55,696 - INFO - Roll the page for 18 time.
# 2018-05-13 19:26:57,727 - INFO - 1 following on the list.
# 2018-05-13 19:26:57,728 - INFO - Roll the page for 19 time.
# 2018-05-13 19:26:59,766 - INFO - 1 following on the list.
# 2018-05-13 19:26:59,766 - INFO - Roll the page for 20 time.
# 2018-05-13 19:27:01,801 - INFO - 1 following on the list.
# 2018-05-13 19:27:01,801 - INFO - Roll the page for 21 time.
# 2018-05-13 19:27:03,834 - INFO - 1 following on the list.
# 2018-05-13 19:27:03,835 - INFO - Roll the page for 22 time.
# 2018-05-13 19:27:05,868 - INFO - 1 following on the list.
# 2018-05-13 19:27:05,868 - INFO - Roll the page for 23 time.
# 2018-05-13 19:27:07,901 - INFO - 1 following on the list.
# 2018-05-13 19:27:07,902 - INFO - Roll the page for 24 time.
# 2018-05-13 19:27:09,934 - INFO - 1 following on the list.
# 2018-05-13 19:27:09,934 - INFO - Roll the page for 25 time.
# 2018-05-13 19:27:11,968 - INFO - 1 following on the list.
# 2018-05-13 19:27:11,969 - INFO - Roll the page for 26 time.
# 2018-05-13 19:27:14,004 - INFO - 1 following on the list.
# 2018-05-13 19:27:14,004 - INFO - Roll the page for 27 time.
# 2018-05-13 19:27:16,039 - INFO - 1 following on the list.
# 2018-05-13 19:27:16,039 - INFO - Roll the page for 28 time.
# 2018-05-13 19:27:18,072 - INFO - 1 following on the list.
# 2018-05-13 19:27:18,073 - INFO - Roll the page for 29 time.
# 2018-05-13 19:27:20,122 - INFO - 1 following on the list.
# 2018-05-13 19:27:20,123 - INFO - Roll the page for 30 time.
# 2018-05-13 19:27:22,202 - INFO - 1 following on the list.
# 2018-05-13 19:27:22,204 - INFO - Roll the page for 31 time.
# 2018-05-13 19:27:24,292 - INFO - 1 following on the list.
# 2018-05-13 19:27:24,293 - INFO - Roll the page for 32 time.
# 2018-05-13 19:27:26,372 - INFO - 1 following on the list.
# 2018-05-13 19:27:26,373 - INFO - Roll the page for 33 time.
# 2018-05-13 19:27:28,449 - INFO - 1 following on the list.
# 2018-05-13 19:27:28,450 - INFO - Roll the page for 34 time.
# 2018-05-13 19:27:30,483 - INFO - 1 following on the list.
# 2018-05-13 19:27:30,484 - INFO - Roll the page for 35 time.
# 2018-05-13 19:27:32,520 - INFO - 1 following on the list.
# 2018-05-13 19:27:32,520 - INFO - Roll the page for 36 time.
# 2018-05-13 19:27:34,554 - INFO - 1 following on the list.
# 2018-05-13 19:27:34,555 - INFO - Roll the page for 37 time.
# 2018-05-13 19:27:36,592 - INFO - 1 following on the list.
# 2018-05-13 19:27:36,592 - INFO - Roll the page for 38 time.
# 2018-05-13 19:27:38,627 - INFO - 1 following on the list.
# 2018-05-13 19:27:38,627 - INFO - Roll the page for 39 time.
# 2018-05-13 19:27:40,663 - INFO - 1 following on the list.
# 2018-05-13 19:27:40,663 - INFO - Roll the page for 40 time.
# 2018-05-13 19:27:42,712 - INFO - 1 following on the list.
# 2018-05-13 19:27:42,714 - INFO - Roll the page for 41 time.
# 2018-05-13 19:27:44,797 - INFO - 1 following on the list.
# 2018-05-13 19:27:44,799 - INFO - Roll the page for 42 time.
# 2018-05-13 19:27:46,856 - INFO - 1 following on the list.
# 2018-05-13 19:27:46,858 - INFO - Roll the page for 43 time.
# 2018-05-13 19:27:48,926 - INFO - 1 following on the list.
# 2018-05-13 19:27:48,927 - INFO - Roll the page for 44 time.
# 2018-05-13 19:27:50,960 - INFO - 1 following on the list.
# 2018-05-13 19:27:50,960 - INFO - Roll the page for 45 time.
# 2018-05-13 19:27:52,995 - INFO - 1 following on the list.
# 2018-05-13 19:27:52,995 - INFO - Roll the page for 46 time.
# 2018-05-13 19:27:55,033 - INFO - 1 following on the list.
# 2018-05-13 19:27:55,034 - INFO - Roll the page for 47 time.
# 2018-05-13 19:27:57,067 - INFO - 1 following on the list.
# 2018-05-13 19:27:57,068 - INFO - Roll the page for 48 time.
# 2018-05-13 19:27:59,102 - INFO - 1 following on the list.
# 2018-05-13 19:27:59,103 - INFO - Roll the page for 49 time.
# 2018-05-13 19:28:01,138 - INFO - 1 following on the list.
# 2018-05-13 19:28:01,139 - INFO - Roll the page for 50 time.
# 2018-05-13 19:28:03,170 - INFO - 1 following on the list.
# 2018-05-13 19:28:03,170 - INFO - Roll the page for 51 time.
# 2018-05-13 19:28:05,206 - INFO - 1 following on the list.
# 2018-05-13 19:28:05,207 - INFO - Roll the page for 52 time.
# 2018-05-13 19:28:07,245 - INFO - 1 following on the list.
# 2018-05-13 19:28:07,246 - INFO - Roll the page for 53 time.
# 2018-05-13 19:28:09,280 - INFO - 1 following on the list.
# 2018-05-13 19:28:09,281 - INFO - Roll the page for 54 time.
# 2018-05-13 19:28:11,316 - INFO - 1 following on the list.
# 2018-05-13 19:28:11,316 - INFO - Roll the page for 55 time.
# 2018-05-13 19:28:13,352 - INFO - 1 following on the list.
# 2018-05-13 19:28:13,352 - INFO - Roll the page for 56 time.
# 2018-05-13 19:28:15,385 - INFO - 1 following on the list.
# 2018-05-13 19:28:15,386 - INFO - Roll the page for 57 time.
# 2018-05-13 19:28:17,420 - INFO - 1 following on the list.
# 2018-05-13 19:28:17,421 - INFO - Roll the page for 58 time.
# 2018-05-13 19:28:19,466 - INFO - 1 following on the list.
# 2018-05-13 19:28:19,468 - INFO - Roll the page for 59 time.
# 2018-05-13 19:28:21,534 - INFO - 1 following on the list.
# 2018-05-13 19:28:21,536 - INFO - Roll the page for 60 time.
# 2018-05-13 19:28:23,606 - INFO - 1 following on the list.
# 2018-05-13 19:28:23,607 - INFO - Roll the page for 61 time.
# 2018-05-13 19:28:25,660 - INFO - 1 following on the list.
# 2018-05-13 19:28:25,661 - INFO - Roll the page for 62 time.
# 2018-05-13 19:28:27,732 - INFO - 1 following on the list.
# 2018-05-13 19:28:27,733 - INFO - Roll the page for 63 time.
# 2018-05-13 19:28:29,766 - INFO - 1 following on the list.
# 2018-05-13 19:28:29,767 - INFO - Roll the page for 64 time.
# 2018-05-13 19:28:31,799 - INFO - 1 following on the list.
# 2018-05-13 19:28:31,800 - INFO - Roll the page for 65 time.
# 2018-05-13 19:28:33,836 - INFO - 1 following on the list.
# 2018-05-13 19:28:33,837 - INFO - Roll the page for 66 time.
# 2018-05-13 19:28:35,868 - INFO - 1 following on the list.
# 2018-05-13 19:28:35,869 - INFO - Roll the page for 67 time.
# 2018-05-13 19:28:37,902 - INFO - 1 following on the list.
# 2018-05-13 19:28:37,903 - INFO - Roll the page for 68 time.
# 2018-05-13 19:28:39,936 - INFO - 1 following on the list.
# 2018-05-13 19:28:39,937 - INFO - Roll the page for 69 time.
# 2018-05-13 19:28:41,973 - INFO - 1 following on the list.
# 2018-05-13 19:28:41,973 - INFO - Roll the page for 70 time.
# 2018-05-13 19:28:44,017 - INFO - 1 following on the list.
# 2018-05-13 19:28:44,018 - INFO - Roll the page for 71 time.
# 2018-05-13 19:28:46,087 - INFO - 1 following on the list.
# 2018-05-13 19:28:46,088 - INFO - Roll the page for 72 time.
# 2018-05-13 19:28:48,172 - INFO - 1 following on the list.
# 2018-05-13 19:28:48,174 - INFO - Roll the page for 73 time.
# 2018-05-13 19:28:50,230 - INFO - 1 following on the list.
# 2018-05-13 19:28:50,231 - INFO - Roll the page for 74 time.
# 2018-05-13 19:28:52,266 - INFO - 1 following on the list.
# 2018-05-13 19:28:52,266 - INFO - Roll the page for 75 time.
# 2018-05-13 19:28:54,301 - INFO - 1 following on the list.
# 2018-05-13 19:28:54,301 - INFO - Roll the page for 76 time.
# 2018-05-13 19:28:56,333 - INFO - 1 following on the list.
# 2018-05-13 19:28:56,334 - INFO - Roll the page for 77 time.
# 2018-05-13 19:28:58,369 - INFO - 1 following on the list.
# 2018-05-13 19:28:58,369 - INFO - Roll the page for 78 time.
# 2018-05-13 19:29:00,404 - INFO - 1 following on the list.
# 2018-05-13 19:29:00,405 - INFO - Roll the page for 79 time.
# 2018-05-13 19:29:02,439 - INFO - 1 following on the list.
# 2018-05-13 19:29:02,440 - INFO - Roll the page for 80 time.
# 2018-05-13 19:29:04,477 - INFO - 1 following on the list.
# 2018-05-13 19:29:04,477 - INFO - Roll the page for 81 time.
# 2018-05-13 19:29:06,511 - INFO - 1 following on the list.
# 2018-05-13 19:29:06,511 - INFO - Roll the page for 82 time.
# 2018-05-13 19:29:08,543 - INFO - 1 following on the list.
# 2018-05-13 19:29:08,544 - INFO - Roll the page for 83 time.
# 2018-05-13 19:29:10,578 - INFO - 1 following on the list.
# 2018-05-13 19:29:10,579 - INFO - Roll the page for 84 time.
# 2018-05-13 19:29:12,612 - INFO - 1 following on the list.
# 2018-05-13 19:29:12,613 - INFO - Roll the page for 85 time.
# 2018-05-13 19:29:14,650 - INFO - 1 following on the list.
# 2018-05-13 19:29:14,652 - INFO - Roll the page for 86 time.
# 2018-05-13 19:29:16,686 - INFO - 1 following on the list.
# 2018-05-13 19:29:16,686 - INFO - Roll the page for 87 time.
# 2018-05-13 19:29:18,722 - INFO - 1 following on the list.
# 2018-05-13 19:29:18,723 - INFO - Roll the page for 88 time.
# 2018-05-13 19:29:20,755 - INFO - 1 following on the list.
# 2018-05-13 19:29:20,756 - INFO - Roll the page for 89 time.
# 2018-05-13 19:29:22,798 - INFO - 1 following on the list.
# 2018-05-13 19:29:22,799 - INFO - Roll the page for 90 time.
# 2018-05-13 19:29:24,874 - INFO - 1 following on the list.
# 2018-05-13 19:29:24,876 - INFO - Roll the page for 91 time.
# 2018-05-13 19:29:26,935 - INFO - 1 following on the list.
# 2018-05-13 19:29:26,936 - INFO - Roll the page for 92 time.
# 2018-05-13 19:29:29,008 - INFO - 1 following on the list.
# 2018-05-13 19:29:29,008 - INFO - Roll the page for 93 time.
# 2018-05-13 19:29:31,040 - INFO - 1 following on the list.
# 2018-05-13 19:29:31,041 - INFO - Roll the page for 94 time.
# 2018-05-13 19:29:33,074 - INFO - 1 following on the list.
# 2018-05-13 19:29:33,075 - INFO - Roll the page for 95 time.
# 2018-05-13 19:29:35,111 - INFO - 1 following on the list.
# 2018-05-13 19:29:35,112 - INFO - Roll the page for 96 time.
# 2018-05-13 19:29:37,146 - INFO - 1 following on the list.
# 2018-05-13 19:29:37,147 - INFO - Roll the page for 97 time.
# 2018-05-13 19:29:39,181 - INFO - 1 following on the list.
# 2018-05-13 19:29:39,182 - INFO - Roll the page for 98 time.
# 2018-05-13 19:29:41,216 - INFO - 1 following on the list.
# 2018-05-13 19:29:41,217 - INFO - Roll the page for 99 time.
# 2018-05-13 19:29:43,253 - INFO - 1 following on the list.
# 2018-05-13 19:29:43,254 - INFO - Roll the page for 100 time.
# 2018-05-13 19:29:45,296 - INFO - 1 following on the list.
# 2018-05-13 19:29:45,298 - INFO - Roll the page for 101 time.
# 2018-05-13 19:29:45,379 - INFO - Start to cancel following.
# 2018-05-13 19:29:45,379 - INFO - Now run the 1 time.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-9a4911ba3fa0> in <module>()
#      13         logging.info('Now it\'s running the script on ' + acc + '.')
# ---> 14         add_and_cancel_fans(site, site_suffix, shopid, acc, pwd, top_shop_id, top_shop_username)
#      15         logging.info('Finished running the script on ' + acc + '.')
#
# <ipython-input-10-be6701560bab> in add_and_cancel_fans(site, site_suffix, shopid, acc, pwd, top_shop_id, top_shop_username)
#      89             logging.info('Now run the ' + str(i + 1) + ' time.')
# ---> 90             if following_buttons[i].text in following_language:
#      91                 buyer_shopid = following_buttons[i].get_attribute('shopid')
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9a4911ba3fa0> in <module>()
#      15         logging.info('Finished running the script on ' + acc + '.')
#      16     except Exception as err:
# ---> 17         logging.info('An exception occurred: ' + err + '.')
#
# TypeError: Can't convert 'IndexError' object to str implicitly

# %%
# browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
# browser.get('https://shopee.com.my')

# %%
# language_selector = browser.find_elements_by_css_selector('.shopee-button-outline.shopee-button-outline--primary-reverse')
# len(language_selector)

# %%
#language_selector[2].click()
