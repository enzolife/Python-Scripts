# %%
from selenium import webdriver
import pandas as pd
import time

# %%
buyer_info_path = "D://Buyer_Info.xlsx"
buyer_info = pd.read_excel(buyer_info_path)
buyer_info[:1]
# Out:
#      userid     username                        concat  count
# 0  32352918  shopee.shop  http://shopee.tw/shopee.shop    163

# %%
'''
buyer_info_path = "D://comment_person_url.csv"
buyer_info = pd.read_csv(buyer_info_path)
buyer_info[:1]
'''
# Out:
# '\nbuyer_info_path = "D://comment_person_url.csv"\nbuyer_info = pd.read_csv(buyer_info_path)\nbuyer_info[:1]\n'

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path)

# %%
type(browser)
# Out:
# selenium.webdriver.chrome.webdriver.WebDriver

# %%
browser.get('http://shopee.tw/yu001157')

# %%
LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
'''
有关Selenium Compound class names not permitted的错误
可以参考https://stackoverflow.com/questions/37771604/selenium-compound-class-names-not-permitted
使用css_selector解决即可
'''
LoginElem[1].text
# Out:
# '登入'

# %%
# 点击登入，弹出账户密码输入框
LoginElem[1].click()

# %%
acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
try:
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('poweradapter.tw')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('kuangyiqiao1991')
except:
    time.sleep(30)
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('poweradapter.tw')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('kuangyiqiao1991')

# %%
Login_buttom_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
Login_buttom_elem[1].text
# Out:
# '登入'

# %%
time.sleep(10)
Login_buttom_elem[1].click()

# %%
# for website in buyer_info[1001:1500]["comment_person_url"]:
# for website in buyer_info[1501:2000]["comment_person_url"]:
for website in buyer_info[2001:2500]["concat"]:
    browser.get(website)
    time.sleep(10)
    try:
        elem = browser.find_element_by_class_name('section-seller-overview-horizontal__icon')
        print('Found <%s> element with that class name!' % (elem.tag_name))
        elem.click()
        print(website + ' is clicked.')
    except:
        print('Was not able to find an element with that name in ' + website)
# Out:
# Found <span> element with that class name!
# http://shopee.tw/peggy.hwu is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ak1220pz is clicked.
# Found <span> element with that class name!
# http://shopee.tw/xuan_0829 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/leeboyi is clicked.
# Found <span> element with that class name!
# http://shopee.tw/c0816xian1 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tag500804 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/liao861030 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/beautyboball is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kitty66230 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jiangrose is clicked.
# Found <span> element with that class name!
# http://shopee.tw/bill54036403 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/accc0326 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/j2215872 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/linyu810213 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/rick91828 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kiki0411pp is clicked.
# Found <span> element with that class name!
# http://shopee.tw/rrtt8880 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/titi6399 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/fish710111 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/as830624 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/aazz1212 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/iyhpuf is clicked.
# Found <span> element with that class name!
# http://shopee.tw/allen603 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/pk0976383005 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/huangzongsheng is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sunnywangpig11 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/hero1100 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/aaronboy19950609 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/x7997911 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/anna0520719 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/aaa4803 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/seed1027 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/grdobrg is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a11115889 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/apologize1102 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/olivia701801 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/yujung10 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/joe0861720 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/love721023 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/totommko0606 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ruby23076 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/d5010 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/abc0935359548 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/aurorapan is clicked.
# Found <span> element with that class name!
# http://shopee.tw/z7310768 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/nickpai is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tw2928_42237 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/annaangus is clicked.
# Found <span> element with that class name!
# http://shopee.tw/j137824659 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/e123456789212 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chingwuc is clicked.
# Found <span> element with that class name!
# http://shopee.tw/monica77630 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/yitingloveyihong is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kouami is clicked.
# Found <span> element with that class name!
# http://shopee.tw/nai0218 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/gizz999a is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tianxin5257 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/me9933 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/we714063 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/leve0425 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/willy1130 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jyon520 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sherry95519 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/cindykitty520 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/willson0216 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/3068zg is clicked.
# Found <span> element with that class name!
# http://shopee.tw/akially is clicked.
# Found <span> element with that class name!
# http://shopee.tw/k8026500 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jimmyliums is clicked.
# Found <span> element with that class name!
# http://shopee.tw/smile371027 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/joanna94224 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/penquin2 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sheldon0531 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/patty3037 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/easoncc is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sung861211 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a0989199376 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/candyfloss_g. is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sichingwang is clicked.
# Found <span> element with that class name!
# http://shopee.tw/trissalin is clicked.
# Found <span> element with that class name!
# http://shopee.tw/joyce55543 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a132366 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chiaching97 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/alma_shop is clicked.
# Found <span> element with that class name!
# http://shopee.tw/una881217 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/_janet is clicked.
# Found <span> element with that class name!
# http://shopee.tw/willlin is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vincent_0827 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tue120 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tnyou is clicked.
# Found <span> element with that class name!
# http://shopee.tw/annie52015 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/lost19941215 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/q76335 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/wayne12121121 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/avavlee is clicked.
# Found <span> element with that class name!
# http://shopee.tw/monkey12156 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/febefun2012 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/fiona_fi0205 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/doggie9127263352 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/leanne159 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/faith123 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/in.adidas0516 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/camellia5_4 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/p6403052020 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jchou7878 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/e570115 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/unahuang1344 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/veegen_ty is clicked.
# Found <span> element with that class name!
# http://shopee.tw/pink104526 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/asd0921449543 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/qwe0826 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/j77122605 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/apaaa1875 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/evon4188 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/violakuo925 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/she026 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vivian0928 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/carolyn827 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/by007pk is clicked.
# Found <span> element with that class name!
# http://shopee.tw/stu87413 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jaixin is clicked.
# Found <span> element with that class name!
# http://shopee.tw/heyhey0827 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tgbyhn5789 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/emilyhuamg is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chin9999 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/p200507 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/projectevox is clicked.
# Found <span> element with that class name!
# http://shopee.tw/leonzerg is clicked.
# Found <span> element with that class name!
# http://shopee.tw/alice052789673 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ww33nnddzz is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tw7909_45116 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/nervkaworu is clicked.
# Found <span> element with that class name!
# http://shopee.tw/__yujie77539 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kimxiujin is clicked.
# Found <span> element with that class name!
# http://shopee.tw/viviansetma is clicked.
# Found <span> element with that class name!
# http://shopee.tw/exo.l.an is clicked.
# Found <span> element with that class name!
# http://shopee.tw/boddy0120 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/dopezhi is clicked.
# Found <span> element with that class name!
# http://shopee.tw/p6212520 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/xiaojun8310 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/adrien_hsieh is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a0909280921 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/scott650202 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/marspaul is clicked.
# Found <span> element with that class name!
# http://shopee.tw/cage.hsieh is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chiaoyalin0225 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/zhuily0213 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/i0023you is clicked.
# Found <span> element with that class name!
# http://shopee.tw/shuang0831 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/wendy32662 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ruopinglin is clicked.
# Found <span> element with that class name!
# http://shopee.tw/h94pjo6 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/love_520638 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/lnigu is clicked.
# Found <span> element with that class name!
# http://shopee.tw/f245p369q7 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/wayhowwang is clicked.
# Found <span> element with that class name!
# http://shopee.tw/j_i_wu is clicked.
# Found <span> element with that class name!
# http://shopee.tw/candyslo is clicked.
# Found <span> element with that class name!
# http://shopee.tw/karen.2017 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/shrimpmoz is clicked.
# Found <span> element with that class name!
# http://shopee.tw/linfatfat is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ivy0420 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kerry2005 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/yuhsiu1012 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/qwertyuiop930126 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/niutail is clicked.
# Found <span> element with that class name!
# http://shopee.tw/pooh1211 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kidyellowzzz is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chenliangwei is clicked.
# Found <span> element with that class name!
# http://shopee.tw/christina84919 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/s950392 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/likemayday5566 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/gemgloria is clicked.
# Found <span> element with that class name!
# http://shopee.tw/slifer005 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/4yahandsome is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vanessa58808 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/linda831013 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/linsichn is clicked.
# Found <span> element with that class name!
# http://shopee.tw/hsh5500 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/marni0817 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/xiamhongchiu is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tw2360_92872 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ivy_lin88 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/elly0988524790 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tw5044_37839 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a0936260810 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/xup6280 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/soul020196 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/stw_jenny is clicked.
# Found <span> element with that class name!
# http://shopee.tw/bear780923 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/spain1028 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sandy23756 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chiachunyeh is clicked.
# Found <span> element with that class name!
# http://shopee.tw/j631102 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tw0058_23068 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/morganhuang is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ayu813 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ramsea is clicked.
# Found <span> element with that class name!
# http://shopee.tw/huitian0918391159 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/qaz9900 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ss0989618157 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/pinhung1 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/hanhanxie is clicked.
# Found <span> element with that class name!
# http://shopee.tw/c5891058 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vivian.wu.0415 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ahz079 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/iou2807 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a3308793 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/flycat0714 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/zcom723 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/cc610 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/bscosmetic is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tw3107_35516 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/for808 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/zoe0918 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/goalscoring is clicked.
# Found <span> element with that class name!
# http://shopee.tw/zxczxc0113 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/sasha8317 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/mk6918mk6918 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/lovequeenyes is clicked.
# Found <span> element with that class name!
# http://shopee.tw/nenred is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vivian_nn is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kj0041215 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/yeyisin is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ya5566 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/qwewq0956 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/pokopekolove is clicked.
# Found <span> element with that class name!
# http://shopee.tw/irene5673 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/dsa61615 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/juliahahaha is clicked.
# Found <span> element with that class name!
# http://shopee.tw/1ling_1115 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vickychit is clicked.
# Found <span> element with that class name!
# http://shopee.tw/fish20010705 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/yoyosan is clicked.
# Found <span> element with that class name!
# http://shopee.tw/vivi841220 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/tiyuanyang is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jyun0206 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/buting57 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jenny0955054129 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/easonchen is clicked.
# Found <span> element with that class name!
# http://shopee.tw/w971955w971955 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/peace1997225 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/slyvie0825 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ching0312 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/army12300 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/a19980410 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ym700212 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/alinkgz is clicked.
# Found <span> element with that class name!
# http://shopee.tw/ame861012 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/cat7315 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/chen_yi1121 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/jeremy88050292 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/winx_54 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/love08may is clicked.
# Found <span> element with that class name!
# http://shopee.tw/kiki10202001 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/qiao20121012 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/zozo901226 is clicked.
# Found <span> element with that class name!
# http://shopee.tw/trueloveu is clicked.
# Found <span> element with that class name!
# http://shopee.tw/emilymeichin is clicked.
