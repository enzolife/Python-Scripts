# %%
import pandas as pd
import os
import logging

# %%
logging.basicConfig(level=logging.INFO, format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
baojiadan_folder = 'D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\-E·J- 2014.5.1\\2015.9.26 燕文\\'

# %%
baojiadan_file_list = list()

# %%
for file_name in os.listdir(baojiadan_folder):
    if file_name.startswith('广州燕文报价单'):
        baojiadan_file_list.append(file_name)

# %%
latest_baojiadan_file_name = baojiadan_file_list[-1]
# latest_baojiadan_file_name

# %%
latest_baojiadan_path = os.path.join(baojiadan_folder, latest_baojiadan_file_name)
# latest_baojiadan_path

# %%
baojiadan_sheets_dict = pd.read_excel(latest_baojiadan_path, sheetname=None)
# type(baojiadan)

# %%
wanted_shipping_service_list = ['燕文航空挂号小包-普货',
                                '燕文航空挂号小包-特货',
                                '燕文航空易派小包-普货',
                                '燕文航空易派小包-特货',
                                '燕文专线优先小包',
                                '燕文专线追踪小包-普货',
                                '燕文专线追踪小包-特货',
                                '燕邮宝挂号',
                                '中英YODEL专线-标准',
                                '中英YODEL专线-小包(不含电)',
                                '中英YODEL专线-小包(含电)',
                                '中邮北京挂号小包',
                                '中邮北京线下E邮宝',
                                '中邮广州挂号小包',
                                '中邮深圳挂号小包',
                                '比利时挂号小包（上海）',
                                '比利时挂号小包（香港）',
                                '德邮香港挂号小包',
                                '德邮香港挂号小包-特货',
                                '韩国epacket小包-深圳',
                                '荷兰邮政e-packet小包-特货',
                                '荷兰邮政挂号小包(不含电)',
                                '荷兰邮政挂号小包(含电)',
                                '荷兰邮政挂号小包(配电)',
                                '马来西亚挂号小包-深圳',
                                '瑞士邮政挂号小包(不含电)',
                                '瑞士邮政挂号小包(含电)',
                                '瑞邮派小包',
                                '土耳其邮政挂号小包(不含电)',
                                '土耳其邮政挂号小包(含电)',
                                '香港邮政挂号小包',
                                '新加坡邮政挂号小包',
                                '燕文CN挂号小包',
                                '燕文C优先小包']

# %%
export_path = os.path.join(baojiadan_folder, '报价单','燕文报价表格.xlsx')
writer = pd.ExcelWriter(export_path)

for service_name in wanted_shipping_service_list:
    if service_name in baojiadan_sheets_dict.keys():
        logging.info(service_name + ' is ready to export.')
        df = baojiadan_sheets_dict[service_name]
        try:
            for c in df.columns:
                for index, r in enumerate(df[c]):
                    if r == '国家':
                        country_cell_location = [index, c]
                        # print(country_cell_location)
                        break
            df = df[country_cell_location[0]:]
            df = df.dropna(how='all')
            df = df[df[country_cell_location[1]].str.len() < 10]
            
            df.to_excel(writer, sheet_name=service_name, index=False)
            logging.info(service_name + ' exported.')
            # df.to_csv(os.path.join(baojiadan_folder, '报价单', key + '.csv'))
        except:
            logging.info(service_name + ' failed to export.')
            pass
        # df.to_csv(os.path.join(baojiadan_folder, '报价单', key + '.xlsx'))
        
writer.save()
# Out:
#  2019-02-03 23:18:35,967 - INFO - 燕文航空挂号小包-普货 is ready to export.
#  2019-02-03 23:18:36,001 - INFO - 燕文航空挂号小包-普货 exported.
#  2019-02-03 23:18:36,008 - INFO - 燕文航空挂号小包-特货 is ready to export.
#  2019-02-03 23:18:36,029 - INFO - 燕文航空挂号小包-特货 exported.
#  2019-02-03 23:18:36,036 - INFO - 燕文航空易派小包-普货 is ready to export.
#  2019-02-03 23:18:36,046 - INFO - 燕文航空易派小包-普货 exported.
#  2019-02-03 23:18:36,047 - INFO - 燕文航空易派小包-特货 is ready to export.
#  2019-02-03 23:18:36,056 - INFO - 燕文航空易派小包-特货 exported.
#  2019-02-03 23:18:36,056 - INFO - 燕文专线优先小包 is ready to export.
#  2019-02-03 23:18:36,061 - INFO - 燕文专线优先小包 exported.
#  2019-02-03 23:18:36,061 - INFO - 燕文专线追踪小包-普货 is ready to export.
#  2019-02-03 23:18:36,068 - INFO - 燕文专线追踪小包-普货 exported.
#  2019-02-03 23:18:36,069 - INFO - 燕文专线追踪小包-特货 is ready to export.
#  2019-02-03 23:18:36,080 - INFO - 燕文专线追踪小包-特货 exported.
#  2019-02-03 23:18:36,081 - INFO - 燕邮宝挂号 is ready to export.
#  2019-02-03 23:18:36,086 - INFO - 燕邮宝挂号 exported.
#  2019-02-03 23:18:36,087 - INFO - 中英YODEL专线-标准 is ready to export.
#  2019-02-03 23:18:36,091 - INFO - 中英YODEL专线-标准 exported.
#  2019-02-03 23:18:36,092 - INFO - 中英YODEL专线-小包(不含电) is ready to export.
#  2019-02-03 23:18:36,097 - INFO - 中英YODEL专线-小包(不含电) exported.
#  2019-02-03 23:18:36,098 - INFO - 中英YODEL专线-小包(含电) is ready to export.
#  2019-02-03 23:18:36,102 - INFO - 中英YODEL专线-小包(含电) exported.
#  2019-02-03 23:18:36,103 - INFO - 中邮北京挂号小包 is ready to export.
#  2019-02-03 23:18:36,138 - INFO - 中邮北京挂号小包 exported.
#  2019-02-03 23:18:36,145 - INFO - 中邮北京线下E邮宝 is ready to export.
#  2019-02-03 23:18:36,160 - INFO - 中邮北京线下E邮宝 exported.
#  2019-02-03 23:18:36,161 - INFO - 中邮广州挂号小包 is ready to export.
#  2019-02-03 23:18:36,196 - INFO - 中邮广州挂号小包 exported.
#  2019-02-03 23:18:36,197 - INFO - 中邮深圳挂号小包 is ready to export.
#  2019-02-03 23:18:36,230 - INFO - 中邮深圳挂号小包 exported.
#  2019-02-03 23:18:36,235 - INFO - 比利时挂号小包（上海） is ready to export.
#  2019-02-03 23:18:36,244 - INFO - 比利时挂号小包（上海） exported.
#  2019-02-03 23:18:36,247 - INFO - 比利时挂号小包（香港） is ready to export.
#  2019-02-03 23:18:36,253 - INFO - 比利时挂号小包（香港） exported.
#  2019-02-03 23:18:36,259 - INFO - 德邮香港挂号小包 is ready to export.
#  2019-02-03 23:18:36,267 - INFO - 德邮香港挂号小包 exported.
#  2019-02-03 23:18:36,268 - INFO - 德邮香港挂号小包-特货 is ready to export.
#  2019-02-03 23:18:36,284 - INFO - 德邮香港挂号小包-特货 exported.
#  2019-02-03 23:18:36,285 - INFO - 韩国epacket小包-深圳 is ready to export.
#  2019-02-03 23:18:36,297 - INFO - 韩国epacket小包-深圳 exported.
#  2019-02-03 23:18:36,297 - INFO - 荷兰邮政e-packet小包-特货 is ready to export.
#  2019-02-03 23:18:36,309 - INFO - 荷兰邮政e-packet小包-特货 exported.
#  2019-02-03 23:18:36,310 - INFO - 荷兰邮政挂号小包(不含电) is ready to export.
#  2019-02-03 23:18:36,343 - INFO - 荷兰邮政挂号小包(不含电) exported.
#  2019-02-03 23:18:36,348 - INFO - 荷兰邮政挂号小包(含电) is ready to export.
#  2019-02-03 23:18:36,378 - INFO - 荷兰邮政挂号小包(含电) exported.
#  2019-02-03 23:18:36,386 - INFO - 荷兰邮政挂号小包(配电) is ready to export.
#  2019-02-03 23:18:36,399 - INFO - 荷兰邮政挂号小包(配电) exported.
#  2019-02-03 23:18:36,399 - INFO - 马来西亚挂号小包-深圳 is ready to export.
#  2019-02-03 23:18:36,423 - INFO - 马来西亚挂号小包-深圳 exported.
#  2019-02-03 23:18:36,427 - INFO - 瑞士邮政挂号小包(不含电) is ready to export.
#  2019-02-03 23:18:36,432 - INFO - 瑞士邮政挂号小包(不含电) exported.
#  2019-02-03 23:18:36,433 - INFO - 瑞士邮政挂号小包(含电) is ready to export.
#  2019-02-03 23:18:36,440 - INFO - 瑞士邮政挂号小包(含电) exported.
#  2019-02-03 23:18:36,441 - INFO - 瑞邮派小包 is ready to export.
#  2019-02-03 23:18:36,453 - INFO - 瑞邮派小包 exported.
#  2019-02-03 23:18:36,454 - INFO - 土耳其邮政挂号小包(不含电) is ready to export.
#  2019-02-03 23:18:36,475 - INFO - 土耳其邮政挂号小包(不含电) exported.
#  2019-02-03 23:18:36,476 - INFO - 土耳其邮政挂号小包(含电) is ready to export.
#  2019-02-03 23:18:36,486 - INFO - 土耳其邮政挂号小包(含电) exported.
#  2019-02-03 23:18:36,487 - INFO - 香港邮政挂号小包 is ready to export.
#  2019-02-03 23:18:36,491 - INFO - 香港邮政挂号小包 failed to export.
#  2019-02-03 23:18:36,491 - INFO - 新加坡邮政挂号小包 is ready to export.
#  2019-02-03 23:18:36,496 - INFO - 新加坡邮政挂号小包 exported.
#  2019-02-03 23:18:36,498 - INFO - 燕文CN挂号小包 is ready to export.
#  2019-02-03 23:18:36,536 - INFO - 燕文CN挂号小包 exported.
#  2019-02-03 23:18:36,540 - INFO - 燕文C优先小包 is ready to export.
#  2019-02-03 23:18:36,552 - INFO - 燕文C优先小包 exported.

# %%
'新加坡邮政挂号小包' in baojiadan_sheets_dict.keys()
# Out:
# True

# %%
baojiadan_sheets_dict['新加坡邮政挂号小包']
# Out:
#                                             新加坡邮政挂号小包  \
# 0                                                生效日期
# 1                                                 产品号
# 2                                                资费专区
# 3                                                 NaN
# 4                                                  一区
# 5                                                  二区
# 6                                                  三区
# 7                                                  四区
# 8                                                  五区
# 9                                                  六区
# 10  新加坡小包发货须知：\t\t\t\t\t\t\t\n1.参考时效：亚洲、欧美等发达国家8-1...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                            分区国家对应表
# 17                                                 分区
# 18                                                 二区
# 19                                                 六区
# 20                                                 三区
# 21                                                 四区
# 22                                                 五区
# 23                                                 一区
#
#                                            Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 0                                 2018-10-19 00:00:00          NaN        NaN
# 1                                                 106          NaN        NaN
# 2                                                  资费     挂号费（元/件）        NaN
# 3                                              （元/kg）  0.001-0.1kg  0.101-2kg
# 4                                                  98           21         13
# 5                                                 109           21         13
# 6                                                 121           21         13
# 7                                                 125           21         13
# 8                                                 130           21         13
# 9                                                 147           21         13
# 10                                                NaN          NaN        NaN
# 11                                                NaN          NaN        NaN
# 12                                                NaN          NaN        NaN
# 13                                                NaN          NaN        NaN
# 14                                                NaN          NaN        NaN
# 15                                                NaN          NaN        NaN
# 16                                                NaN          NaN        NaN
# 17                                                 国家          NaN        NaN
# 18  马尔代夫,蒙古,孟加拉国,缅甸,挪威,帕劳,尼泊尔,斯里兰卡,巴基斯坦,萨摩亚,中国台湾,汤...          NaN        NaN
# 19                                               其他国家          NaN        NaN
# 20  马耳他,阿曼,马其顿,摩尔多瓦,摩纳哥,阿塞拜疆,土耳其,圣马力诺,斯洛伐克,格陵兰岛,白俄...          NaN        NaN
# 21                                            俄罗斯,乌克兰          NaN        NaN
# 22  委内瑞拉,法属马约特岛,巴西,马约特,法属南部领地,智利,塞舌尔,尼日利亚,墨西哥,南非,毛...          NaN        NaN
# 23  澳大利亚,加拿大,德国,法国,美国,马来西亚,奥地利,日本,瑞典,瑞士,泰国,英国,意大利,...          NaN        NaN
#
#     返回主目录
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN

# %%
df = baojiadan_sheets_dict['比利时挂号小包（香港）']
for c in df.columns:
    for index, r in enumerate(df[c]):
        if r == '国家':
            country_cell_location = [index, c]
            print(country_cell_location)
            break
# Out:
# [2, '比利时挂号小包（香港）']

# %%
df = df[country_cell_location[0]:]
df
# Out:
#                                           比利时挂号小包（香港） Unnamed: 1 Unnamed: 2  \
# 2                                                  国家  0.001-2kg        NaN
# 3                                                 NaN   价格（元/KG）   处理费（元/件）
# 4                                                  美国         77         34
# 5                                                  英国         68         35
# 6                                                  法国         67         35
# 7                                                澳大利亚        100         28
# 8                                                  德国         68         35
# 9                                                 加拿大         76         35
# 10                                                西班牙         78         28
# 11                                                以色列         76         28
# 12                                                 瑞典         66         40
# 13                                                阿联酋        107         26
# 14                                                爱尔兰         79         47
# 15                                               爱沙尼亚         74         26
# 16                                                奥地利         55         43
# 17                                               保加利亚        117         20
# 18                                                比利时         65         35
# 19                                                 冰岛         62         51
# 20                                                 波兰         70         26
# 21                                                 丹麦         85         41
# 22                                                俄罗斯         79         32
# 23                                                 芬兰         80         42
# 24                                                 荷兰         67         28
# 25                                                 捷克         68         25
# 26                                               克罗地亚         72         33
# 27                                               拉脱维亚         76         25
# 28                                                立陶宛         70         25
# 29                                                卢森堡         48         40
# 30                                               罗马尼亚         76         25
# 31                                                马耳他         76         32
# 32                                               马来西亚        115         26
# 33                                                 南非        119         20
# 34                                                 挪威         77         41
# 35                                                葡萄牙         77         28
# 36                                                 瑞士         53         60
# 37                                               塞浦路斯         76         32
# 38                                               斯洛伐克         73         26
# 39                                              斯洛文尼亚         60         40
# 40                                                 希腊         78         35
# 41                                                新西兰        104         28
# 42                                                匈牙利         73         26
# 43                                                意大利         67         41
# 44  1. 重量/尺寸限制：限重：2kg， 周长不超过90cm，单边长不超过60cm。 \t\t\...        NaN        NaN
# 45                                                NaN        NaN        NaN
# 46                                                NaN        NaN        NaN
# 47                                                NaN        NaN        NaN
# 48                                                NaN        NaN        NaN
# 49                                                NaN        NaN        NaN
#
#     返回主目录
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN

# %%
df = df.dropna(how='all')
df
# Out:
#                                           比利时挂号小包（香港） Unnamed: 1 Unnamed: 2  \
# 2                                                  国家  0.001-2kg        NaN
# 3                                                 NaN   价格（元/KG）   处理费（元/件）
# 4                                                  美国         77         34
# 5                                                  英国         68         35
# 6                                                  法国         67         35
# 7                                                澳大利亚        100         28
# 8                                                  德国         68         35
# 9                                                 加拿大         76         35
# 10                                                西班牙         78         28
# 11                                                以色列         76         28
# 12                                                 瑞典         66         40
# 13                                                阿联酋        107         26
# 14                                                爱尔兰         79         47
# 15                                               爱沙尼亚         74         26
# 16                                                奥地利         55         43
# 17                                               保加利亚        117         20
# 18                                                比利时         65         35
# 19                                                 冰岛         62         51
# 20                                                 波兰         70         26
# 21                                                 丹麦         85         41
# 22                                                俄罗斯         79         32
# 23                                                 芬兰         80         42
# 24                                                 荷兰         67         28
# 25                                                 捷克         68         25
# 26                                               克罗地亚         72         33
# 27                                               拉脱维亚         76         25
# 28                                                立陶宛         70         25
# 29                                                卢森堡         48         40
# 30                                               罗马尼亚         76         25
# 31                                                马耳他         76         32
# 32                                               马来西亚        115         26
# 33                                                 南非        119         20
# 34                                                 挪威         77         41
# 35                                                葡萄牙         77         28
# 36                                                 瑞士         53         60
# 37                                               塞浦路斯         76         32
# 38                                               斯洛伐克         73         26
# 39                                              斯洛文尼亚         60         40
# 40                                                 希腊         78         35
# 41                                                新西兰        104         28
# 42                                                匈牙利         73         26
# 43                                                意大利         67         41
# 44  1. 重量/尺寸限制：限重：2kg， 周长不超过90cm，单边长不超过60cm。 \t\t\...        NaN        NaN
#
#     返回主目录
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN

# %%
df = df[df[country_cell_location[1]].str.len() < 10]
df
# Out:
#    比利时挂号小包（香港） Unnamed: 1 Unnamed: 2  返回主目录
# 2           国家  0.001-2kg        NaN    NaN
# 4           美国         77         34    NaN
# 5           英国         68         35    NaN
# 6           法国         67         35    NaN
# 7         澳大利亚        100         28    NaN
# 8           德国         68         35    NaN
# 9          加拿大         76         35    NaN
# 10         西班牙         78         28    NaN
# 11         以色列         76         28    NaN
# 12          瑞典         66         40    NaN
# 13         阿联酋        107         26    NaN
# 14         爱尔兰         79         47    NaN
# 15        爱沙尼亚         74         26    NaN
# 16         奥地利         55         43    NaN
# 17        保加利亚        117         20    NaN
# 18         比利时         65         35    NaN
# 19          冰岛         62         51    NaN
# 20          波兰         70         26    NaN
# 21          丹麦         85         41    NaN
# 22         俄罗斯         79         32    NaN
# 23          芬兰         80         42    NaN
# 24          荷兰         67         28    NaN
# 25          捷克         68         25    NaN
# 26        克罗地亚         72         33    NaN
# 27        拉脱维亚         76         25    NaN
# 28         立陶宛         70         25    NaN
# 29         卢森堡         48         40    NaN
# 30        罗马尼亚         76         25    NaN
# 31         马耳他         76         32    NaN
# 32        马来西亚        115         26    NaN
# 33          南非        119         20    NaN
# 34          挪威         77         41    NaN
# 35         葡萄牙         77         28    NaN
# 36          瑞士         53         60    NaN
# 37        塞浦路斯         76         32    NaN
# 38        斯洛伐克         73         26    NaN
# 39       斯洛文尼亚         60         40    NaN
# 40          希腊         78         35    NaN
# 41         新西兰        104         28    NaN
# 42         匈牙利         73         26    NaN
# 43         意大利         67         41    NaN
