# %% [raw]
# Name: ____________         Date: ____________

# %% [markdown]
# **Note**: For all the questions, if you are not sure of a specific answer, you can describe your logic and the way you thought.

# %% [markdown]
# ## Statistics

# %% [raw]
# 1.The following data is from a random sample: 5, 1, 3, 3, 8. Compute the sample mean, sample standard deviation and sample median?
#
#
# 4, 根号7（2.65）, 3
#
#
# 2.Suppose X is a random variable with E(X) = 5 and Var(X) = 2. What is E(X^2)?
#
#
# 27
#
# E(X^2) = Var(X)^2 + Var(X^2)
#
#
# 3.Suppose that P(A)=0.4, P(B)=0.3 and P(A ∪ B) = 0.58. Are A and B independent?
#
#
# independent
#
#
#
# 4.There are 3 arrangements of the word DAD, namely DAD, ADD, and DDA. How many arrangements are there of the word PROBABILITY?
#
#
#
# 11! / 2! *2! = 9979200
#
#
#
# 5.Suppose that you are taking a multiple-choice test with c choices for each question. In answering a question on this test, the probability that you know the answer is p. If you don’t know the answer, you choose one at random. What is the probability that you knew the answer to a question, given that you answered it correctly?
#
#
# p / (p + (1-p) / c)
#
#
#
# because of P(A|B) = P(AB) / P(B)
#
#
#
#
# 6. Flip a coin 1000 times, got 538 heads and 462 tails, explain how would you calculate whether the difference is significant enough to question the fairness of the coin (other than by coincidence).
#
#
#
#
# 假设检验，95% 把握 not fair

# %% [markdown]
# ## python

# %% [raw]
# >>> x = [1, 2]
# >>> y = z = x
# >>> y = [1, 2, 3]
# >>> z = z.append(4)
# >>> x
#
# ___[1,2,4]___

# %% [raw]
# >>> 0 and 1/0
#
# ___0___

# %% [raw]
# >>> def much(wow):
#         if much == wow:
#             such = lambda wow: wow
#             def wow(much):
#                 return such(much)
#             return wow
#         return 99
#
# >>> wow = 6
# >>> much(much)(wow)
#
# ___6___

# %% [raw]
# Given an integer, write a function to determine if it is a power of three.
#
# def is_power_of_three(n):
#     """
#     Example:
#     >>> is_power_of_three(8)
#     False
#     >>> is_power_of_three(27)
#     True
#     >>> is_power_of_three(0)
#     False
#     """
#
#     while loop +1
#
#     or recursion +2

# %% [markdown]
# ## SQL

# %% [raw]
# Table: Person
#
# +-------------+---------+
# | Column Name | Type    |
# +-------------+---------+
# | PersonId    | int     |
# | FirstName   | varchar |
# | LastName    | varchar |
# +-------------+---------+
# PersonId is the primary key column for this table.
# Table: Address
#
# +-------------+---------+
# | Column Name | Type    |
# +-------------+---------+
# | AddressId   | int     |
# | PersonId    | int     |
# | City        | varchar |
# | State       | varchar |
# +-------------+---------+
# AddressId is the primary key column for this table.
#
#
# Write a SQL query for a report that provides the following information for each person in the Person table, regardless if there is an address for each of those people:
#
# PersonId, FirstName, LastName, City, State
#
#
#
#
#
#
#
# join

# %% [raw]
# Write a SQL query to find all duplicate emails in a table named Person.
#
# +----+---------+
# | Id | Email   |
# +----+---------+
# | 1  | a@b.com |
# | 2  | c@d.com |
# | 3  | a@b.com |
# +----+---------+
# For example, your query should return the following for the above table:
#
# +---------+
# | Email   |
# +---------+
# | a@b.com |
# +---------+
# Note: All emails are in lowercase.
#
#
#
#
#
#
#
#
#
# group by and having

# %% [raw]
# Write a SQL query to get how many orders each seller had in each country in a table named seller_sales_information.
#
#
# Table: seller_sales_infomation
#
# +----------+-----------+---------------+
# | order_id | seller_id | order_country |
# +----------+-----------+---------------+
# |   c409   |    a01    |      CN       |
# |   c372   |    a01    |      CN       |
# |   c302   |    a01    |      CN       |
# |   t121   |    a01    |      TH       |
# |   s201   |    b01    |      SG       |
# |   t242   |    b01    |      TH       |
# |   c563   |    c01    |      CN       |
# |   s507   |    c01    |      SG       |
# +----------+-----------+---------------+
#
#
# Your query should return the following output for the above table:
# (for the seller who doesn't have an order in a certain country, output 0 in total_orders for that country)
# +-----------+---------------+--------------+
# | seller_id | order_country | total_orders |
# +-----------+---------------+--------------+
# |    a01    |       CN      |      3       |
# |    a01    |       SG      |      0       |
# |    a01    |       TH      |      1       |
# |    b01    |       CN      |      0       |
# |    b01    |       SG      |      1       |
# |    b01    |       TH      |      1       |
# |    c01    |       CN      |      1       |
# |    c01    |       SG      |      1       |
# |    c01    |       TH      |      0       |
# +-----------+---------------+--------------+
#
#
#
# Please write a query to get desired output.
#
#
#
#
#
#
#
#
#
#
#
# cross join 或者自建表join

# %% [markdown]
# ## database

# %% [raw]
# What is primary key and foreign key?
#
#
# primary key: unique, not null, only one for a table,
#
# 一个表中的 FOREIGN KEY 指向另一个表中的 PRIMARY KEY。

# %% [raw]
# Please explain what is the pros and cons of indexing for a table in a database and why?
#
#
#
#
#
# query quicker
#
#
#
#
#
# insert slower, space,

# %% [markdown]
# ## engineering

# %% [raw]
# What is the difference between thread and process, and when to utilize which when doing parallel programming?
#
#
# 多个线程可以读写同一块内存
#
# IO任务用多线程， 计算任务用多进程

# %% [raw]
# How do you intend to process 100G csv file (for an aggregation result) with 8G memory laptop?
#
#
#
#
#
#
#
#
#
#
# iterator by chunk

# %% [markdown]
# ## machine learning

# %% [raw]
# Please describe a commonly used machine learning pipeline.
#
#
#
#
#
#
#
#
# EDA - Data cleaning - feature engineering - algorithm selection - model training

# %% [markdown]
# ## Analysis

# %% [raw]
# There are many things affecting the conversion rate (CV) of a shop (orders / views by customers), please list at least 3 factors which might affect CV and your corresponding strategy for a higher CV.

# %% [raw]
# What do you think are the most important things in business analysis. What is your strength?
