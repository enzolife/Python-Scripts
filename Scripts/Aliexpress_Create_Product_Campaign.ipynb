# %%
from selenium import webdriver
import pandas as pd
import time
import datetime

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180523限时限量折扣(2)'
campaign_start_date = datetime.datetime(2018, 5, 24, 0, 0)
campaign_end_date = datetime.datetime(2018, 6, 6, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()

# %%
# 点击结束日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-360d8e838554> in <module>()
#       3 campaign_end_date_input[1].click()
#       4 # 选择日期
# ----> 5 browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
#
# IndexError: list index out of range

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2015.2.18 速卖通//2016.11.26 速卖通数据分析//2016.12.18 速卖通商品分析.xlsm"
product_list = pd.read_excel(product_list_path, sheetname='商品分析')
product_list
# Out:
#             商品ID                                               商品标题     平台  \
# 0    32597758635  19V 4.74A 90W Universal Power Adapter Charger ...  TOTAL
# 1    32296973236  19.5V 4.62A 90W Ac Power Adapter Charger For D...  TOTAL
# 2    32326661278  19V 4.74A 90W Laptop Universal Power Adapter C...  TOTAL
# 3    32298664354  22.5V 1.25A 30W Power Adapter Charger For IRob...  TOTAL
# 4    32297759407  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 5    32821187508  20V 4.5A 90W Long Type Laptop Power Adapter Ch...  TOTAL
# 6    32828507962  20V 3.25A 65W Universal USB Type C Laptop Mobi...  TOTAL
# 7    32357103637  12V 3A 36W Tablet Ac Car Power Adapter Charger...  TOTAL
# 8    32298356440  19.5V 3.34A 65W AC Laptop Power Adapter Charge...  TOTAL
# 9    32753723716  15V 16V 19V 19.5V 20V Auto Voltage Universal P...  TOTAL
# 10   32464588670  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 11   32484354951  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 12   32695774510  20V 3.25A 65W Power Adapter Travel Charger For...  TOTAL
# 13   32299300578  12V 3.33A 40W Laptop AC Power Adapter Charger ...  TOTAL
# 14   32483143464  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 15   32298767545  19.5V 4.62A 90W Laptop Ac Power Adapter Charge...  TOTAL
# 16   32462417929  19V 2.37A 45W Laptop AC Power Adapter Charger ...  TOTAL
# 17   32486535722  19V 1.75A 33W AC Laptop Power Adapter Charger ...  TOTAL
# 18   32743951215  20V 2.25A 45W Travel Power Adapter Charger For...  TOTAL
# 19   32440656276  90W Laptop AC Universal Power Adapter Charger ...  TOTAL
# 20   32365466196  20V 3.25A 65W Ac Laptop Power Adapter Charger ...  TOTAL
# 21   32485945798  12V 3.6A 43W Ac Laptop Power Adapter Charger F...  TOTAL
# 22   32298791846  19.5V 4.62A 90W Laptop AC Power Adapter Charge...  TOTAL
# 23   32743835649  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 24   32818813553  20V 3.25A 65W Long Type Laptop Power Adapter C...  TOTAL
# 25   32465020088  20V 4.5A 90W Ac Laptop Power Adapter Charger F...  TOTAL
# 26   32297599525  19.5V 4.7A 90W Laptop Ac Power Adapter Charger...  TOTAL
# 27   32297310674  19V 4.74A 90W Laptop Ac Power Adapter Charger ...  TOTAL
# 28   32487768278  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 29   32297837238  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# ..           ...                                                ...    ...
# 162  32462986131  12V 2.58A 36W Laptop AC Power Adapter Charger ...  TOTAL
# 163  32743178948  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 164  32464568887  19V 2.1A 40W Laptop Ac Power Adapter Charger F...  TOTAL
# 165  32485994958  12V 3.6A 43W AC Tablet Power Adapter Charger F...  TOTAL
# 166  32719915375  USB Charging Cable For Lenovo Yoga 3 Yoga 4 Yo...  TOTAL
# 167  32740994989  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 168  32743847362  19V 2.37A 45W Travel Power Adapter Charger For...  TOTAL
# 169  32440170604  33W Factory Direct Laptop AC Power Adapter Cha...  TOTAL
# 170  32298250561  19.5V 3.33A Laptop AC Power Adapter Charger Fo...  TOTAL
# 171  32344628700  19V 1.58A 30W Laptop AC Power Adapter For Acer...  TOTAL
# 172  32441849650  45W Laptop Ac Power Adapter Charger For Asus U...  TOTAL
# 173  32435582916  65W Power Adapter Charger For Lenovo G400 G500...  TOTAL
# 174  32483111961  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 175  32464900691  19V 1.75A 33W Laptop AC Power Adapter Charger ...  TOTAL
# 176  32304508173  19V 4.74A 90W Power Adapter Charger For HP Lap...  TOTAL
# 177  32808498905  10.5V 2.9A 30W Collapsible Portable Laptop Pow...  TOTAL
# 178  32808502216  12V 3A 36W Collapsible Portable Laptop Power A...  TOTAL
# 179  32818324398  12V 2.58A 36W Light Version Tablet Power Adapt...  TOTAL
# 180  32298632647  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 181  32464375211  12V 3.6A 48W Ac Laptop Power Adapter Charger F...  TOTAL
# 182  32695737418  20V 2.25A 45W AC Laptop Power Adapter For Leno...  TOTAL
# 183  32297041583  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 184  32345555876  19V 2.37A 45W Laptop Ac Power Adapter Charger ...  TOTAL
# 185  32297652061  12V 3.6A Power Adapter Charger Carregador Port...  TOTAL
# 186  32741165783  19V 2.37A 45W Travel Power Adapter Charger For...  TOTAL
# 187  32440414994  40W AC Factory Direct Laptop Power Adapter Cha...  TOTAL
# 188  32297057887  12V 2.58A 36W Car Power Adapter Charger For Mi...  TOTAL
# 189  32441908668  36W AC Laptop Power Adapter Charger For Micros...  TOTAL
# 190  32343650161  12V 3.6A 45W Laptop AC Power Adapter For Micro...  TOTAL
# 191  32462223205  12V 3A 36W Laptop AC Power Adapter Charger For...  TOTAL
#
#      老买家支付买家数  老买家下单买家数  老买家支付金额  老买家支付订单数  老买家下单订单数 老买家浏览-下单转化率  老买家商品页访客数  \
# 0          10        11   235.80        10        11      10.58%        104
# 1           6         6   588.35         7         7      25.00%         24
# 2           4         4    68.45         4         4       5.80%         69
# 3           3         3    41.88         3         3      25.00%         12
# 4           2         2    66.13         2         2       8.00%         25
# 5           2         2    30.48         2         2      11.76%         17
# 6           1         1    25.88         1         1       8.33%         12
# 7           2         2   152.00         2         2      66.67%          3
# 8           2         2    41.81         2         2      15.38%         13
# 9           1         1    18.75         1         1       5.00%         20
# 10          0         0     0.00         0         0       0.00%          8
# 11          1         1     9.75         1         1       6.25%         16
# 12          1         1    13.75         1         1       5.00%         20
# 13          1         1    13.35         1         1      11.11%          9
# 14          0         0     0.00         0         0       0.00%          7
# 15          0         0     0.00         0         0       0.00%          6
# 16          0         0     0.00         0         0       0.00%          1
# 17          1         1    19.66         1         2      20.00%          5
# 18          0         0     0.00         0         0       0.00%          0
# 19          0         0     0.00         0         0       0.00%          6
# 20          1         1     9.75         1         1      10.00%         10
# 21          2         2    39.00         2         2     100.00%          2
# 22          0         0     0.00         0         0       0.00%          6
# 23          1         1    16.88         1         1      20.00%          5
# 24          1         1     9.60         1         1      33.33%          3
# 25          0         0     0.00         0         0       0.00%         16
# 26          0         0     0.00         0         0       0.00%         12
# 27          2         2    19.56         2         2      40.00%          5
# 28          0         0     0.00         0         0       0.00%          2
# 29          0         0     0.00         0         0       0.00%          8
# ..        ...       ...      ...       ...       ...         ...        ...
# 162         0         0     0.00         0         0       0.00%          1
# 163         0         0     0.00         0         0       0.00%          0
# 164         0         0     0.00         0         0       0.00%          1
# 165         0         0     0.00         0         0       0.00%          0
# 166         0         0     0.00         0         0       0.00%          0
# 167         0         0     0.00         0         0       0.00%          0
# 168         0         0     0.00         0         0       0.00%          0
# 169         0         0     0.00         0         0       0.00%          0
# 170         0         0     0.00         0         0       0.00%          0
# 171         0         0     0.00         0         0       0.00%          1
# 172         0         0     0.00         0         0       0.00%          0
# 173         0         0     0.00         0         0       0.00%          0
# 174         0         0     0.00         0         0       0.00%          0
# 175         0         0     0.00         0         0       0.00%          1
# 176         0         0     0.00         0         0       0.00%          0
# 177         0         0     0.00         0         0       0.00%          0
# 178         0         0     0.00         0         0       0.00%          0
# 179         0         0     0.00         0         0       0.00%          1
# 180         0         0     0.00         0         0       0.00%          0
# 181         0         0     0.00         0         0       0.00%          0
# 182         0         0     0.00         0         0       0.00%          0
# 183         0         0     0.00         0         0       0.00%          0
# 184         0         0     0.00         0         0       0.00%          0
# 185         0         0     0.00         0         0       0.00%          0
# 186         0         0     0.00         0         0       0.00%          0
# 187         0         0     0.00         0         0       0.00%          0
# 188         0         0     0.00         0         0       0.00%          0
# 189         0         0     0.00         0         0       0.00%          0
# 190         0         0     0.00         0         0       0.00%          0
# 191         0         0     0.00         0         0       0.00%          0
#
#      ...    下单订单数  支付买家数  支付订单数     支付金额     支付金额% 支付金额% Cumulative 风控订单数  \
# 0    ...      123     97     97  1504.64  0.268034         0.268034     0
# 1    ...       22     21     22   776.27  0.138284         0.406318     0
# 2    ...       31     29     29   547.07  0.097454         0.503772     0
# 3    ...       29     27     27   301.76  0.053755         0.557527     0
# 4    ...       23     22     22   269.92  0.048083         0.605610     0
# 5    ...       20     19     19   235.63  0.041975         0.647585     0
# 6    ...        9      8      8   208.15  0.037080         0.684665     0
# 7    ...        3      3      3   159.80  0.028467         0.713131     0
# 8    ...       12     12     12   155.52  0.027704         0.740835     0
# 9    ...        7      6      6   117.48  0.020928         0.761763     0
# 10   ...        4      4      4   111.17  0.019804         0.781567     0
# 11   ...       11     11     11   106.05  0.018892         0.800458     0
# 12   ...        8      6      6    82.00  0.014607         0.815066     0
# 13   ...       11      7      7    71.50  0.012737         0.827802     0
# 14   ...        6      6      6    58.57  0.010434         0.838236     0
# 15   ...        1      1      1    46.55  0.008292         0.846528     0
# 16   ...        4      4      4    45.95  0.008185         0.854714     0
# 17   ...        4      3      3    44.95  0.008007         0.862721     0
# 18   ...        2      2      2    44.81  0.007982         0.870704     0
# 19   ...        3      3      3    43.94  0.007827         0.878531     0
# 20   ...        4      4      4    39.00  0.006947         0.885478     0
# 21   ...        2      2      2    39.00  0.006947         0.892426     0
# 22   ...        5      4      4    38.86  0.006922         0.899348     0
# 23   ...        2      2      2    33.76  0.006014         0.905362     0
# 24   ...        3      3      3    33.57  0.005980         0.911342     0
# 25   ...        2      2      2    29.81  0.005310         0.916653     0
# 26   ...        3      3      3    29.50  0.005255         0.921908     0
# 27   ...        4      3      3    29.34  0.005227         0.927134     0
# 28   ...        3      2      2    21.61  0.003850         0.930984     0
# 29   ...        2      2      2    21.42  0.003816         0.934800     0
# ..   ...      ...    ...    ...      ...       ...              ...   ...
# 162  ...        0      0      0     0.00  0.000000         1.000000     0
# 163  ...        0      0      0     0.00  0.000000         1.000000     0
# 164  ...        0      0      0     0.00  0.000000         1.000000     0
# 165  ...        0      0      0     0.00  0.000000         1.000000     0
# 166  ...        0      0      0     0.00  0.000000         1.000000     0
# 167  ...        0      0      0     0.00  0.000000         1.000000     0
# 168  ...        0      0      0     0.00  0.000000         1.000000     0
# 169  ...        0      0      0     0.00  0.000000         1.000000     0
# 170  ...        0      0      0     0.00  0.000000         1.000000     0
# 171  ...        0      0      0     0.00  0.000000         1.000000     0
# 172  ...        0      0      0     0.00  0.000000         1.000000     0
# 173  ...        0      0      0     0.00  0.000000         1.000000     0
# 174  ...        0      0      0     0.00  0.000000         1.000000     0
# 175  ...        0      0      0     0.00  0.000000         1.000000     0
# 176  ...        0      0      0     0.00  0.000000         1.000000     0
# 177  ...        0      0      0     0.00  0.000000         1.000000     0
# 178  ...        0      0      0     0.00  0.000000         1.000000     0
# 179  ...        0      0      0     0.00  0.000000         1.000000     0
# 180  ...        0      0      0     0.00  0.000000         1.000000     0
# 181  ...        0      0      0     0.00  0.000000         1.000000     0
# 182  ...        0      0      0     0.00  0.000000         1.000000     0
# 183  ...        0      0      0     0.00  0.000000         1.000000     0
# 184  ...        0      0      0     0.00  0.000000         1.000000     0
# 185  ...        0      0      0     0.00  0.000000         1.000000     0
# 186  ...        0      0      0     0.00  0.000000         1.000000     0
# 187  ...        0      0      0     0.00  0.000000         1.000000     0
# 188  ...        0      0      0     0.00  0.000000         1.000000     0
# 189  ...        0      0      0     0.00  0.000000         1.000000     0
# 190  ...        0      0      0     0.00  0.000000         1.000000     0
# 191  ...        0      0      0     0.00  0.000000         1.000000     0
#
#      风控金额   退款金额  退款订单数
# 0       0  13.80      1
# 1       0  31.02      1
# 2       0  53.01      3
# 3       0  10.47      1
# 4       0   0.00      0
# 5       0   9.48      1
# 6       0  97.64      2
# 7       0  91.20      1
# 8       0  13.50      1
# 9       0   0.00      0
# 10      0   0.00      0
# 11      0   0.00      0
# 12      0   6.74      1
# 13      0   0.00      0
# 14      0   4.63      1
# 15      0   0.00      0
# 16      0   0.00      0
# 17      0   0.00      0
# 18      0   0.00      0
# 19      0   0.00      0
# 20      0   0.00      0
# 21      0   0.00      0
# 22      0  19.28      2
# 23      0  16.88      1
# 24      0   0.00      0
# 25      0   0.00      0
# 26      0   0.00      0
# 27      0  10.58      1
# 28      0   0.00      0
# 29      0   0.00      0
# ..    ...    ...    ...
# 162     0   0.00      0
# 163     0   0.00      0
# 164     0   0.00      0
# 165     0   0.00      0
# 166     0   0.00      0
# 167     0   0.00      0
# 168     0   0.00      0
# 169     0   0.00      0
# 170     0   0.00      0
# 171     0   0.00      0
# 172     0   0.00      0
# 173     0   0.00      0
# 174     0   0.00      0
# 175     0   0.00      0
# 176     0   0.00      0
# 177     0   0.00      0
# 178     0   0.00      0
# 179     0   0.00      0
# 180     0   0.00      0
# 181     0   0.00      0
# 182     0   0.00      0
# 183     0   0.00      0
# 184     0   0.00      0
# 185     0   0.00      0
# 186     0   0.00      0
# 187     0   0.00      0
# 188     0   0.00      0
# 189     0   0.00      0
# 190     0   0.00      0
# 191     0   0.00      0
#
# [192 rows x 33 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['商品ID'][:40]:
for product_id in product_list['商品ID'][40:81]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    try:
        product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
        product_search_button.click()
        time.sleep(5)
        # 点击全选
        select_all_box = browser.find_element_by_id("checkbox-all")
        select_all_box.click()
        time.sleep(5)
    except Exception as err:
        print("Can't find this product: " + str(err))
        pass

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
