# %%
from selenium import webdriver
import pandas as pd
import time
import datetime

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180508限时限量折扣(1)'
campaign_start_date = datetime.datetime(2018, 5, 10, 0, 0)
campaign_end_date = datetime.datetime(2018, 5, 23, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()

# %%
# 点击结束日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2015.2.18 速卖通//2016.11.26 速卖通数据分析//2016.12.18 速卖通商品分析.xlsm"
product_list = pd.read_excel(product_list_path, sheetname='商品分析')
product_list
# Out:
#             商品ID                                               商品标题     平台  \
# 0    32597758635  19V 4.74A 90W Universal Power Adapter Charger ...  TOTAL
# 1    32296973236  19.5V 4.62A 90W Ac Power Adapter Charger For D...  TOTAL
# 2    32326661278  19V 4.74A 90W Laptop Universal Power Adapter C...  TOTAL
# 3    32828507962  20V 3.25A 65W Universal USB Type C Laptop Mobi...  TOTAL
# 4    32297759407  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 5    32695774510  20V 3.25A 65W Power Adapter Travel Charger For...  TOTAL
# 6    32365466196  20V 3.25A 65W Ac Laptop Power Adapter Charger ...  TOTAL
# 7    32484354951  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 8    32753723716  15V 16V 19V 19.5V 20V Auto Voltage Universal P...  TOTAL
# 9    32298664354  22.5V 1.25A 30W Power Adapter Charger For IRob...  TOTAL
# 10   32821187508  20V 4.5A 90W Long Type Laptop Power Adapter Ch...  TOTAL
# 11   32298356440  19.5V 3.34A 65W AC Laptop Power Adapter Charge...  TOTAL
# 12   32695725619  19V 3.42A 65W Power Adapter For ASUS Zenbook U...  TOTAL
# 13   32483143464  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 14   32817726909  20V 2A 40W Portable Laptop Power Adapter Charg...  TOTAL
# 15   32807609716  20V 4.5A 90W Power Adapter Charger For Lenovo ...  TOTAL
# 16   32297369401  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 17   32464588670  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 18   32487768278  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 19   32484544534  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# 20   32297837238  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# 21   32297003488  19V 4.74A 90W Ac Power Adapter Charger For Asu...  TOTAL
# 22   32298098621  19V 4.74A 90W Laptop Ac Power Adapter Charger ...  TOTAL
# 23   32485945798  12V 3.6A 43W Ac Laptop Power Adapter Charger F...  TOTAL
# 24   32298767545  19.5V 4.62A 90W Laptop Ac Power Adapter Charge...  TOTAL
# 25   32462898820  12V 3.6A 45W Laptop Ac Power Adapter Charger F...  TOTAL
# 26   32297599525  19.5V 4.7A 90W Laptop Ac Power Adapter Charger...  TOTAL
# 27   32298294121  19.5V 2.31A 45W Laptop Ac Power Adapter Charge...  TOTAL
# 28   32465020088  20V 4.5A 90W Ac Laptop Power Adapter Charger F...  TOTAL
# 29   32464656233  19V 2.37A 45W Laptop Ac Power Adapter Charger ...  TOTAL
# ..           ...                                                ...    ...
# 163  32695737418  20V 2.25A 45W AC Laptop Power Adapter For Leno...  TOTAL
# 164  32298695838  19V 1.58A Laptop AC Power Adapter Charger For ...  TOTAL
# 165  32291654413  18.5V 3.5A AC Laptop Power Adapter Charger For...  TOTAL
# 166  32807641189  20V 3.25A 60W Power Adapter Charger For Lenovo...  TOTAL
# 167  32298512923  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 168  32819622586  5.2V 2.5A 13W Portable Tablet Power Adapter Ch...  TOTAL
# 169  32743178948  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 170  32298250561  19.5V 3.33A Laptop AC Power Adapter Charger Fo...  TOTAL
# 171  32464375211  12V 3.6A 48W Ac Laptop Power Adapter Charger F...  TOTAL
# 172  32441439325  48W Ac Laptop Power Adapter Charger For Micros...  TOTAL
# 173  32344628700  19V 1.58A 30W Laptop AC Power Adapter For Acer...  TOTAL
# 174  32743879142  19V 1.75A 33W Travel Power Adapter Charger For...  TOTAL
# 175  32441908668  36W AC Laptop Power Adapter Charger For Micros...  TOTAL
# 176  32345555876  19V 2.37A 45W Laptop Ac Power Adapter Charger ...  TOTAL
# 177  32741165783  19V 2.37A 45W Travel Power Adapter Charger For...  TOTAL
# 178  32462223205  12V 3A 36W Laptop AC Power Adapter Charger For...  TOTAL
# 179  32485994958  12V 3.6A 43W AC Tablet Power Adapter Charger F...  TOTAL
# 180  32435638867  33W Laptop AC Power Adapter Charger For ASUS V...  TOTAL
# 181  32807949168  12V 2.58A 36W Collapsible Portable Laptop Powe...  TOTAL
# 182  32299304416  19V 1.58A 30W Laptop AC Power Adapter Charger ...  TOTAL
# 183  32462986131  12V 2.58A 36W Laptop AC Power Adapter Charger ...  TOTAL
# 184  32440170604  33W Factory Direct Laptop AC Power Adapter Cha...  TOTAL
# 185  32817730865  20V 2A 40W Portable Laptop Power Adapter Charg...  TOTAL
# 186  32808664944  12V 3.6A 48W Collapsible Portable Laptop Power...  TOTAL
# 187  32598820805  5.2V 2.5A To 3A 18W AC Laptop Power Adapter Ch...  TOTAL
# 188  32343650161  12V 3.6A 45W Laptop AC Power Adapter For Micro...  TOTAL
# 189  32298632647  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 190  32808502216  12V 3A 36W Collapsible Portable Laptop Power A...  TOTAL
# 191  32483111961  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 192  32304508173  19V 4.74A 90W Power Adapter Charger For HP Lap...  TOTAL
#
#      老买家支付买家数  老买家下单买家数  老买家支付金额  老买家支付订单数  老买家下单订单数 老买家浏览-下单转化率  老买家商品页访客数  \
# 0          18        19   363.82        18        19      14.50%        131
# 1           7         7   403.54         7         7      25.00%         28
# 2           6         6   112.28         6         7       7.89%         76
# 3           1         1    26.25         1         1      12.50%          8
# 4           0         0     0.00         0         0       0.00%         32
# 5           1         1    13.50         1         1       5.00%         20
# 6           6         6   132.41         6         6      26.09%         23
# 7           2         2    55.15         2         2      11.76%         17
# 8           2         2    41.93         2         2      10.00%         20
# 9           1         1    20.94         1         1       6.67%         15
# 10          1         1    10.08         1         1       5.26%         19
# 11          1         1    10.34         1         1      10.00%         10
# 12          1         1    68.75         1         1      14.29%          7
# 13          0         0     0.00         0         0       0.00%         10
# 14          1         1    90.00         1         1     100.00%          1
# 15          0         0     0.00         0         0       0.00%          7
# 16          1         1    40.50         1         1      16.67%          6
# 17          0         0     0.00         0         0       0.00%          7
# 18          0         0     0.00         0         0       0.00%          2
# 19          2         2    29.20         2         2      33.33%          6
# 20          1         2     9.18         1         2      12.50%         16
# 21          3         3    55.65         3         3      60.00%          5
# 22          3         3    41.48         3         3      42.86%          7
# 23          0         0     0.00         0         0       0.00%          0
# 24          0         0     0.00         0         0       0.00%          6
# 25          4         4    41.30         4         4      57.14%          7
# 26          0         0     0.00         0         0       0.00%          4
# 27          2         2    16.97         2         2      33.33%          6
# 28          1         1    16.55         1         1      14.29%          7
# 29          0         0     0.00         0         0       0.00%          1
# ..        ...       ...      ...       ...       ...         ...        ...
# 163         0         0     0.00         0         0       0.00%          0
# 164         0         0     0.00         0         0       0.00%          0
# 165         0         0     0.00         0         0       0.00%          0
# 166         0         0     0.00         0         0       0.00%          0
# 167         0         0     0.00         0         0       0.00%          1
# 168         0         0     0.00         0         0       0.00%          0
# 169         0         0     0.00         0         0       0.00%          0
# 170         0         0     0.00         0         0       0.00%          0
# 171         0         0     0.00         0         0       0.00%          0
# 172         0         0     0.00         0         0       0.00%          0
# 173         0         0     0.00         0         0       0.00%          0
# 174         0         0     0.00         0         0       0.00%          0
# 175         0         0     0.00         0         0       0.00%          0
# 176         0         0     0.00         0         0       0.00%          1
# 177         0         0     0.00         0         0       0.00%          0
# 178         0         0     0.00         0         0       0.00%          0
# 179         0         0     0.00         0         0       0.00%          0
# 180         0         0     0.00         0         0       0.00%          0
# 181         0         0     0.00         0         0       0.00%          0
# 182         0         0     0.00         0         0       0.00%          0
# 183         0         0     0.00         0         0       0.00%          0
# 184         0         0     0.00         0         0       0.00%          0
# 185         0         0     0.00         0         0       0.00%          0
# 186         0         0     0.00         0         0       0.00%          0
# 187         0         0     0.00         0         0       0.00%          0
# 188         0         0     0.00         0         0       0.00%          0
# 189         0         0     0.00         0         0       0.00%          0
# 190         0         0     0.00         0         0       0.00%          0
# 191         0         0     0.00         0         0       0.00%          0
# 192         0         0     0.00         0         0       0.00%          0
#
#      ...    下单订单数  支付买家数  支付订单数     支付金额     支付金额% 支付金额% Cumulative 风控订单数  \
# 0    ...      110    102    102  1584.96  0.210831         0.210831     0
# 1    ...       29     27     28  1143.31  0.152083         0.362914     0
# 2    ...       54     47     47   981.31  0.130534         0.493448     0
# 3    ...       19     18     18   470.75  0.062619         0.556067     0
# 4    ...       25     22     22   267.47  0.035579         0.591646     0
# 5    ...       19     18     18   243.50  0.032390         0.624036     0
# 6    ...       18     15     16   226.74  0.030161         0.654197     0
# 7    ...       16     16     16   217.90  0.028985         0.683182     0
# 8    ...       12     11     11   208.82  0.027777         0.710960     0
# 9    ...       20     18     18   196.29  0.026110         0.737070     0
# 10   ...       16     16     16   184.15  0.024496         0.761566     0
# 11   ...       14     13     13   160.44  0.021342         0.782907     0
# 12   ...        4      4      4   123.00  0.016361         0.799269     0
# 13   ...       13     12     12   113.12  0.015047         0.814316     0
# 14   ...        1      1      1    90.00  0.011972         0.826288     0
# 15   ...        8      8      8    81.00  0.010775         0.837063     0
# 16   ...        4      4      4    63.64  0.008465         0.845528     0
# 17   ...        6      6      6    62.49  0.008312         0.853840     0
# 18   ...        6      6      6    59.71  0.007943         0.861783     0
# 19   ...        5      5      5    57.61  0.007663         0.869446     0
# 20   ...        7      6      6    56.46  0.007510         0.876957     0
# 21   ...        3      3      3    55.65  0.007403         0.884359     0
# 22   ...        4      4      4    51.07  0.006793         0.891152     0
# 23   ...        3      3      3    48.75  0.006485         0.897637     0
# 24   ...        1      1      1    46.55  0.006192         0.903829     0
# 25   ...        4      4      4    41.30  0.005494         0.909323     0
# 26   ...        4      4      4    37.15  0.004942         0.914265     0
# 27   ...        4      4      4    36.84  0.004900         0.919165     0
# 28   ...        2      2      2    31.36  0.004172         0.923337     0
# 29   ...        3      3      3    31.33  0.004168         0.927504     0
# ..   ...      ...    ...    ...      ...       ...              ...   ...
# 163  ...        0      0      0     0.00  0.000000         1.000000     0
# 164  ...        0      0      0     0.00  0.000000         1.000000     0
# 165  ...        0      0      0     0.00  0.000000         1.000000     0
# 166  ...        0      0      0     0.00  0.000000         1.000000     0
# 167  ...        0      0      0     0.00  0.000000         1.000000     0
# 168  ...        0      0      0     0.00  0.000000         1.000000     0
# 169  ...        0      0      0     0.00  0.000000         1.000000     0
# 170  ...        0      0      0     0.00  0.000000         1.000000     0
# 171  ...        0      0      0     0.00  0.000000         1.000000     0
# 172  ...        0      0      0     0.00  0.000000         1.000000     0
# 173  ...        0      0      0     0.00  0.000000         1.000000     0
# 174  ...        0      0      0     0.00  0.000000         1.000000     0
# 175  ...        0      0      0     0.00  0.000000         1.000000     0
# 176  ...        0      0      0     0.00  0.000000         1.000000     0
# 177  ...        0      0      0     0.00  0.000000         1.000000     0
# 178  ...        0      0      0     0.00  0.000000         1.000000     0
# 179  ...        0      0      0     0.00  0.000000         1.000000     0
# 180  ...        0      0      0     0.00  0.000000         1.000000     0
# 181  ...        0      0      0     0.00  0.000000         1.000000     0
# 182  ...        0      0      0     0.00  0.000000         1.000000     0
# 183  ...        0      0      0     0.00  0.000000         1.000000     0
# 184  ...        0      0      0     0.00  0.000000         1.000000     0
# 185  ...        0      0      0     0.00  0.000000         1.000000     0
# 186  ...        0      0      0     0.00  0.000000         1.000000     0
# 187  ...        0      0      0     0.00  0.000000         1.000000     0
# 188  ...        0      0      0     0.00  0.000000         1.000000     0
# 189  ...        0      0      0     0.00  0.000000         1.000000     0
# 190  ...        0      0      0     0.00  0.000000         1.000000     0
# 191  ...        0      0      0     0.00  0.000000         1.000000     0
# 192  ...        0      0      0     0.00  0.000000         1.000000     0
#
#      风控金额   退款金额  退款订单数
# 0       0   0.00      1
# 1       0  48.70      2
# 2       0  22.50      1
# 3       0   0.00      0
# 4       0   4.81      1
# 5       0  13.50      1
# 6       0   0.00      1
# 7       0   8.69      1
# 8       0   0.11      2
# 9       0  20.93      2
# 10      0   9.73      1
# 11      0   0.00      0
# 12      0   0.00      0
# 13      0   0.00      0
# 14      0   0.00      0
# 15      0   0.00      0
# 16      0   0.00      0
# 17      0  10.33      1
# 18      0   0.00      0
# 19      0   8.95      1
# 20      0   9.64      1
# 21      0   0.00      0
# 22      0   0.00      0
# 23      0   0.00      0
# 24      0   0.00      0
# 25      0   0.00      0
# 26      0   0.00      0
# 27      0   0.00      0
# 28      0   0.00      0
# 29      0   0.00      0
# ..    ...    ...    ...
# 163     0   0.00      0
# 164     0   0.00      0
# 165     0   0.00      0
# 166     0   0.00      0
# 167     0   0.00      0
# 168     0   0.00      0
# 169     0   0.00      0
# 170     0   0.00      0
# 171     0   0.00      0
# 172     0   0.00      0
# 173     0   0.00      0
# 174     0   0.00      0
# 175     0   0.00      0
# 176     0   0.00      0
# 177     0   0.00      0
# 178     0   0.00      0
# 179     0   0.00      0
# 180     0   0.00      0
# 181     0   0.00      0
# 182     0   0.00      0
# 183     0   0.00      0
# 184     0   0.00      0
# 185     0   0.00      0
# 186     0   0.00      0
# 187     0   0.00      0
# 188     0   0.00      0
# 189     0   0.00      0
# 190     0   0.00      0
# 191     0   0.00      0
# 192     0   0.00      0
#
# [193 rows x 33 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['商品ID'][:40]:
for product_id in product_list['商品ID'][40:81]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    try:
        product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
        product_search_button.click()
        # 点击全选
        select_all_box = browser.find_element_by_id("checkbox-all")
        select_all_box.click()
        time.sleep(5)
    except Exception as err:
        print("Can't find this product: " + str(err))
        pass

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
