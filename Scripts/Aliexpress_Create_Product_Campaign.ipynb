# %%
from selenium import webdriver
import pandas as pd
import time
import datetime

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180123限时限量折扣(2)'
campaign_start_date = datetime.datetime(2018, 1, 25, 0, 0)
campaign_end_date = datetime.datetime(2018, 1, 31, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-e261a465843f> in <module>()
#       3 campaign_start_date_input[0].click()
#       4 # 选择日期
# ----> 5 browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()
#
# IndexError: list index out of range

# %%
# 点击开始日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2016.12.15 店小秘数据分析//2017.10.24 各渠道运费明细//2017.12.12 商品平均重量及运费.xlsx"
product_list = pd.read_excel(product_list_path, sheetname='商品平均重量及运费')
product_list
# Out:
#             SKU  运单数      平均重量       平均运费  \
# 0   32326661278  779  0.394872  38.067831
# 1   32365466196  228  0.221254  24.292851
# 2   32484354951  121  0.224917  25.212314
# 3   32484544534  110  0.260136  27.448000
# 4   32821187508  101  0.351168  33.320792
# 5   32296973236  100  0.324610  31.372700
# 6   32297599525   94  0.278649  28.157021
# 7   32297837238   92  0.283413  29.643478
# 8   32297759407   89  0.215539  25.676292
# 9   32597758635   87  0.385759  37.327471
# 10  32297595871   54  0.184648  21.664815
# 11  32298664354   50  0.195080  23.624800
# 12  32483143464   42  0.253548  26.164286
# 13  32298356440   37  0.263919  27.413784
# 14  32695774510   33  0.294455  29.263939
# 15  32297490462   28  0.329857  31.119286
# 16  32297754126   25  0.230920  25.092800
# 17  32487732817   22  0.100364  16.847727
# 18  32486535722   22  0.219318  24.887273
# 19  32753723716   20  0.448150  43.843000
# 20  32297310674   17  0.276353  27.947059
# 21  32464588670   15  0.209067  28.278667
# 22  32298294121   15  0.152600  22.460000
# 23  32818813553   15  0.228800  26.105333
# 24  32482682071   15  0.244667  26.341333
# 25  32298098621   15  0.276200  26.251333
# 26  32828507962   14  0.290500  31.896429
# 27  32602982934   12  0.347750  36.380000
# 28  32781762868   10  0.157100  26.819000
# 29  32807609716   10  0.331900  33.422000
# ..          ...  ...       ...        ...
# 70  32345555876    2  0.146500  20.265000
# 71  32297681857    2  0.284000  41.195000
# 72  32299332366    1  0.146000  19.680000
# 73  32297550062    1  0.148000   8.730000
# 74  32443688412    1  0.215000  38.400000
# 75  32298695838    1  0.160000  20.800000
# 76  32297385358    1  0.213000  23.570000
# 77  32441849650    1  0.200000  26.000000
# 78  32304484427    1  0.261000  28.880000
# 79  32292636557    1  0.290000  30.960000
# 80  32441813994    1  0.192000  23.270000
# 81  32435582916    1  0.228000  28.640000
# 82  32298188648    1  0.225000  23.630000
# 83  32740932249    1  0.258000  25.780000
# 84  32740994989    1  0.204000  19.000000
# 85  32696396222    1  0.302000  33.160000
# 86  32802877834    1  0.187000  18.160000
# 87  32364751375    1  0.145000  17.640000
# 88  32298138011    1  0.213000  22.540000
# 89  32807949168    1  0.156000  25.420000
# 90  32740365684    1  0.201000  26.130000
# 91  32808660934    1  0.144000  33.230000
# 92  32298508909    1  0.202000   8.690000
# 93  32485945798    1  0.218000  33.280000
# 94  32298512923    1  0.095000  20.500000
# 95  32808486643    1  0.157000  23.640000
# 96  32819622566    1  0.227000  27.970000
# 97  32740349966    1  0.207000  27.250000
# 98  32483805137    1  0.226000  43.510000
# 99  32365984073    1  0.141000  27.040000
#
#                                            商品明细表.商品标题  \
# 0   19V 4.74A 90W Universal Power Adapter Laptop C...
# 1   20V 3.25A 65W Ac Laptop Power Adapter Charger ...
# 2   20V 3.25A 65W AC Laptop Power Adapter Charger ...
# 3   19V 4.74A 90W Ac Laptop Power Adapter Charger ...
# 4   20V 4.5A 90W Long Type Laptop Power Adapter Ch...
# 5   19.5V 4.62A 90W Ac Power Adapter Charger For D...
# 6   19.5V 4.7A 90W Laptop Ac Power Adapter Charger...
# 7   19V 4.74A 90W Ac Laptop Power Adapter Charger ...
# 8   19.5V 3.33A 65W Laptop Ac Power Adapter Charge...
# 9   18.5V 19V 19.5V 20V 4.74A 90W Universal Power ...
# 10  20V 3.25A 65W Laptop Ac Power Adapter Charger ...
# 11  22.5V 1.25A 30W Power Adapter Charger For IRob...
# 12  19V 4.74A 90W AC Laptop Power Adapter Charger ...
# 13  19.5V 3.34A 65W AC Laptop Power Adapter Charge...
# 14  20V 3.25A 65W Power Adapter Travel Charger For...
# 15  19.5V 4.62A 90W Laptop Ac Power Adapter Charge...
# 16  19.5V 3.33A 65W Ac Power Adapter Charger Carre...
# 17  12V 3A 36W AC Laptop Car Power Adapter Charger...
# 18  19V 1.75A 33W AC Laptop Power Adapter Charger ...
# 19  15V 16V 19V 19.5V 20V Auto Voltage Universal P...
# 20  19V 4.74A 90W Laptop Ac Power Adapter Charger ...
# 21  19V 1.75A 33W Laptop Ac Power Adapter Charger ...
# 22  19.5V 2.31A 45W Laptop Ac Power Adapter Charge...
# 23  20V 3.25A 65W Long Type Laptop Power Adapter C...
# 24  19V 3.42A 65W AC Laptop Power Adapter Charger ...
# 25  19V 4.74A 90W Laptop Ac Power Adapter Charger ...
# 26  20V 3.25A 65W Universal USB Type C Laptop Mobi...
# 27  19V 3.42A 65W Universal Power Adapter Charger ...
# 28  19V 1.75A 33W Portable Travel Charger Power Ad...
# 29  20V 4.5A 90W Power Adapter Charger For Lenovo ...
# ..                                                ...
# 70  19V 2.37A 45W Laptop Ac Power Adapter Charger ...
# 71  19.5V 4.62A 90W AC Laptop Power Adapter Charge...
# 72  20V 2A 40W Laptop AC Power Adapter Charger For...
# 73  19V 2.37A 45W AC Laptop Power Adapter Charger ...
# 74  40W Laptop Ac Power Adapter Charger For Samsun...
# 75  19V 1.58A Laptop AC Power Adapter Charger For ...
# 76  19V 2.37A 45W Laptop Ac Power Adapter Charger ...
# 77  45W Laptop Ac Power Adapter Charger For Asus U...
# 78  19V 4.74A 90W AC Power Adapter Charger Carrega...
# 79  19V 4.74A AC Laptop Power Adapter Charger For ...
# 80  45W Laptop Ac Power Adapter Charger For Toshib...
# 81  65W Power Adapter Charger For Lenovo G400 G500...
# 82  19V 3.42A 65W Laptop Ac Power Adapter Charger ...
# 83  19.5V 3.33A 65W Travel Power Adapter Charger F...
# 84  19V 3.42A 65W Travel Power Adapter Charger For...
# 85  19.5V 3.33A 65W Laptop AC Power Adapter For HP...
# 86  20V 5V 2A 40W Portable Laptop Power Adapter Ch...
# 87  12V 1.5A 18W Laptop AC Power Adapter Charger F...
# 88  12V 3.33A 40W Laptop AC Power Adapter Charger ...
# 89  12V 2.58A 36W Collapsible Portable Laptop Powe...
# 90  10.5V 3.8A To 4.3A Travel Power Adapter For So...
# 91  19V 1.75A 33W Laptop Power Adapter Charger For...
# 92  18.5V 3.5A 65W AC Power Adapter Charger For HP...
# 93  12V 3.6A 43W Ac Laptop Power Adapter Charger F...
# 94  19V 4.74A 90W AC Laptop Power Adapter Charger ...
# 95  15V 1.6A 24W Collapsible Portable Laptop Power...
# 96  20V 3.25A 65W Long Type Power Adapter Charger ...
# 97  20V 3.25A 65W Travel Power Adapter Charger For...
# 98  19.5V 3.33A 65W AC Laptop Power Adapter Charge...
# 99  12V 1.5A 18W Laptop AC Power Adapter Charger F...
#
#                                      商品明细表.附图1（URL）地址  Unnamed: 6  1688价格  \
# 0   http://ae01.alicdn.com/kf/HTB1iM5rLFXXXXbEXXXX...         NaN      40
# 1   http://ae01.alicdn.com/kf/HTB1u1uZIXXXXXceXpXX...         NaN      26
# 2   http://ae01.alicdn.com/kf/HTB1ifXaJVXXXXXqXpXX...         NaN      26
# 3   http://ae01.alicdn.com/kf/HTB141JVJVXXXXX1XpXX...         NaN      23
# 4   http://ae01.alicdn.com/kf/HTB1Bx8ISXXXXXbaXpXX...         NaN      23
# 5   http://ae01.alicdn.com/kf/HTB12e77HFXXXXbOXFXX...         NaN      26
# 6   http://ae01.alicdn.com/kf/HTB1hG1HHVXXXXXTXFXX...         NaN      23
# 7   http://ae01.alicdn.com/kf/HTB1i3WuHVXXXXX6aXXX...         NaN      23
# 8   http://ae01.alicdn.com/kf/HTB1bTayHVXXXXbjXVXX...         NaN      26
# 9   http://ae01.alicdn.com/kf/HTB1JWDuLpXXXXbxXXXX...         NaN      38
# 10  http://ae01.alicdn.com/kf/HTB1D7WzHVXXXXbiXVXX...         NaN      26
# 11  http://ae01.alicdn.com/kf/HTB1FaMQLpXXXXX9XXXX...         NaN      27
# 12  http://ae01.alicdn.com/kf/HTB17qcTJFXXXXbkXXXX...         NaN      23
# 13  http://ae01.alicdn.com/kf/HTB1EOutHVXXXXXraXXX...         NaN      26
# 14  http://ae01.alicdn.com/kf/HTB18GX1KVXXXXaAapXX...         NaN      40
# 15  http://ae01.alicdn.com/kf/HTB1.yivHVXXXXc0XVXX...         NaN      26
# 16  http://ae01.alicdn.com/kf/HTB15besHVXXXXX7aXXX...         NaN      26
# 17  http://ae01.alicdn.com/kf/HTB1V_NyJVXXXXanXpXX...         NaN      15
# 18  http://ae01.alicdn.com/kf/HTB1Lf8kJVXXXXafXVXX...         NaN      28
# 19  http://ae01.alicdn.com/kf/HTB153gENFXXXXaJapXX...         NaN      50
# 20  http://ae01.alicdn.com/kf/HTB12TA7HFXXXXX7XVXX...         NaN      23
# 21  http://ae01.alicdn.com/kf/HTB1GiYKJpXXXXXzXFXX...         NaN      28
# 22  http://ae01.alicdn.com/kf/HTB1NQmwHVXXXXb5XVXX...         NaN      23
# 23  http://ae01.alicdn.com/kf/HTB1XAGoSXXXXXc7XpXX...         NaN      22
# 24  http://ae01.alicdn.com/kf/HTB1N6sqJFXXXXbDXVXX...         NaN      23
# 25  http://ae01.alicdn.com/kf/HTB1BWeyHVXXXXacXVXX...         NaN      23
# 26  http://ae01.alicdn.com/kf/HTB1wuFeSVXXXXaOXFXX...         NaN      65
# 27  http://ae01.alicdn.com/kf/HTB1MI72LpXXXXaNXFXX...         NaN      36
# 28  http://ae01.alicdn.com/kf/HTB1df.TOFXXXXaCapXX...         NaN      38
# 29  http://ae01.alicdn.com/kf/HTB1Fp2tQVXXXXadXpXX...         NaN      22
# ..                                                ...         ...     ...
# 70  http://ae01.alicdn.com/kf/HTB1nIttHVXXXXcfXXXX...         NaN      23
# 71  http://ae01.alicdn.com/kf/HTB1YqE0HFXXXXc4XVXX...         NaN      26
# 72  http://ae01.alicdn.com/kf/HTB1giCOHVXXXXbnXXXX...         NaN      18
# 73  http://ae01.alicdn.com/kf/HTB1WFiLHVXXXXaHXpXX...         NaN      23
# 74  http://ae01.alicdn.com/kf/HTB1VJaxJXXXXXXuaXXX...         NaN      28
# 75  http://ae01.alicdn.com/kf/HTB1SDmgHVXXXXbYXVXX...         NaN      19
# 76  http://ae01.alicdn.com/kf/HTB16qGCHVXXXXXJXVXX...         NaN      15
# 77  http://ae01.alicdn.com/kf/HTB1CHOtJXXXXXb_aXXX...         NaN      28
# 78  http://ae01.alicdn.com/kf/HTB1FTCJHVXXXXbnXpXX...         NaN      23
# 79  http://ae01.alicdn.com/kf/HTB1wEGOHVXXXXbYXXXX...         NaN      25
# 80  http://ae01.alicdn.com/kf/HTB1gD1vJXXXXXb5XVXX...         NaN      28
# 81  http://ae01.alicdn.com/kf/HTB1Mas5IVXXXXbWXpXX...         NaN      23
# 82  http://ae01.alicdn.com/kf/HTB1QpiMHVXXXXX5XpXX...         NaN      20
# 83  http://ae01.alicdn.com/kf/HTB12L.qNpXXXXbfXXXX...         NaN      38
# 84  http://ae01.alicdn.com/kf/HTB1S7vTNpXXXXcuaXXX...         NaN      38
# 85  http://ae01.alicdn.com/kf/HTB1WaR0KVXXXXbKapXX...         NaN      40
# 86  http://ae01.alicdn.com/kf/HTB1_l6jQpXXXXaKapXX...         NaN      63
# 87  http://ae01.alicdn.com/kf/HTB1DPq5IXXXXXXdXpXX...         NaN      18
# 88  http://ae01.alicdn.com/kf/HTB1jCeMHVXXXXXpXpXX...         NaN      22
# 89  http://ae01.alicdn.com/kf/HTB1sZPsQVXXXXbHaXXX...         NaN      40
# 90  http://ae01.alicdn.com/kf/HTB1RcQjNpXXXXaPXpXX...         NaN      38
# 91  http://ae01.alicdn.com/kf/HTB1e_fNQVXXXXbGXFXX...         NaN      23
# 92  http://ae01.alicdn.com/kf/HTB1lUmtHVXXXXXTaXXX...         NaN      25
# 93  http://ae01.alicdn.com/kf/HTB1jmNBJVXXXXaaXpXX...         NaN      27
# 94  http://ae01.alicdn.com/kf/HTB1sJivHVXXXXcWXVXX...         NaN      23
# 95  http://ae01.alicdn.com/kf/HTB1RY6JQVXXXXaaXVXX...         NaN      40
# 96  http://ae01.alicdn.com/kf/HTB1y8SqSXXXXXaaXFXX...         NaN      23
# 97  http://ae01.alicdn.com/kf/HTB1a0fLNpXXXXcDapXX...         NaN      38
# 98  http://ae01.alicdn.com/kf/HTB1Hh5jJVXXXXazXpXX...         NaN      23
# 99  http://ae01.alicdn.com/kf/HTB14jSOIXXXXXcxXFXX...         NaN      23
#
#     1688价格+运费  最低价格（不含佣金）  最低价格（含佣金）       5%利润      10%利润
# 0   78.067831   12.194195  12.835995  13.477795  14.119594
# 1   50.292851    7.855743   8.269203   8.682664   9.096124
# 2   51.212314    7.999363   8.420383   8.841402   9.262421
# 3   50.448000    7.879978   8.294713   8.709449   9.124185
# 4   56.320792    8.797308   9.260324   9.723340  10.186356
# 5   57.372700    8.961616   9.433280   9.904944  10.376608
# 6   51.157021    7.990727   8.411291   8.831856   9.252420
# 7   52.643478    8.222911   8.655696   9.088481   9.521266
# 8   51.676292    8.071837   8.496670   8.921504   9.346337
# 9   75.327471   11.766151  12.385422  13.004693  13.623964
# 10  47.664815    7.445244   7.837099   8.228954   8.620809
# 11  50.624800    7.907594   8.323783   8.739972   9.156161
# 12  49.164286    7.679461   8.083644   8.487826   8.892008
# 13  53.413784    8.343233   8.782351   9.221468   9.660586
# 14  69.263939   10.819027  11.388450  11.957872  12.527295
# 15  57.119286    8.922032   9.391613   9.861194  10.330774
# 16  51.092800    7.980695   8.400732   8.820769   9.240805
# 17  31.847727    4.974615   5.236437   5.498259   5.760081
# 18  52.887273    8.260992   8.695781   9.130570   9.565359
# 19  93.843000   14.658277  15.429765  16.201253  16.972741
# 20  50.947059    7.957931   8.376769   8.795607   9.214446
# 21  56.278667    8.790728   9.253398   9.716067  10.178737
# 22  45.460000    7.100852   7.474581   7.848310   8.222039
# 23  48.105333    7.514053   7.909530   8.305006   8.700482
# 24  49.341333    7.707116   8.112754   8.518392   8.924029
# 25  49.251333    7.693058   8.097956   8.502854   8.907752
# 26  96.896429   15.135222  15.931813  16.728403  17.524994
# 27  72.380000   11.305756  11.900796  12.495836  13.090875
# 28  64.819000   10.124728  10.657608  11.190489  11.723369
# 29  55.422000    8.656916   9.112544   9.568171  10.023798
# ..        ...         ...        ...        ...        ...
# 70  43.265000    6.757993   7.113677   7.469361   7.825045
# 71  67.195000   10.495859  11.048273  11.600686  12.153100
# 72  37.680000    5.885616   6.195385   6.505155   6.814924
# 73  31.730000    4.956226   5.217080   5.477934   5.738788
# 74  66.400000   10.371680  10.917558  11.463436  12.009314
# 75  39.800000    6.216760   6.543958   6.871156   7.198354
# 76  38.570000    6.024634   6.341720   6.658806   6.975892
# 77  54.000000    8.434800   8.878737   9.322674   9.766611
# 78  51.880000    8.103656   8.530164   8.956672   9.383181
# 79  55.960000    8.740952   9.201002   9.661052  10.121102
# 80  51.270000    8.008374   8.429867   8.851361   9.272854
# 81  51.640000    8.066168   8.490703   8.915238   9.339773
# 82  43.630000    6.815006   7.173691   7.532375   7.891060
# 83  63.780000    9.962436  10.486775  11.011113  11.535452
# 84  57.000000    8.903400   9.372000   9.840600  10.309200
# 85  73.160000   11.427592  12.029044  12.630496  13.231949
# 86  81.160000   12.677192  13.344413  14.011633  14.678854
# 87  35.640000    5.566968   5.859966   6.152965   6.445963
# 88  44.540000    6.957148   7.323314   7.689479   8.055645
# 89  65.420000   10.218604  10.756425  11.294247  11.832068
# 90  64.130000   10.017106  10.544322  11.071538  11.598754
# 91  56.230000    8.783126   9.245396   9.707666  10.169935
# 92  33.690000    5.262378   5.539345   5.816313   6.093280
# 93  60.280000    9.415736   9.911301  10.406866  10.902431
# 94  43.500000    6.794700   7.152316   7.509932   7.867547
# 95  63.640000    9.940568  10.463756  10.986944  11.510131
# 96  50.970000    7.961514   8.380541   8.799568   9.218595
# 97  65.250000   10.192050  10.728474  11.264897  11.801321
# 98  66.510000   10.388862  10.935644  11.482426  12.029209
# 99  50.040000    7.816248   8.227629   8.639011   9.050392
#
# [100 rows x 13 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['SKU'][1:40]:
for product_id in product_list['SKU'][40:80]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
    product_search_button.click()
    # 点击全选
    select_all_box = browser.find_element_by_id("checkbox-all")
    select_all_box.click()
    time.sleep(5) 

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
