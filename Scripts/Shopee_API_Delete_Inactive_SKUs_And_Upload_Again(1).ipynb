# %%
import requests
import time
import datetime as dt
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy
import logging

# %%
logging.basicConfig(level=logging.INFO, 
                    format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
# Date
today_date = dt.date.today() + dt.timedelta(days=0)
yesterday_date = dt.date.today() + dt.timedelta(days=-1)
seven_days_before_date = dt.date.today() + dt.timedelta(days=-7)

# %%
# get_auth_signature
def get_auth_signature(url, payload, shop_key):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
def post_message_to_shopee_api(url, payload, shop_key):
    # Auth Signature
    auth_signature = get_auth_signature(url, payload, shop_key) 
    # HTML Header
    headers = {"Host": "partner.shopeemobile.com",
                "Content-Type": "application/json",
                "Content-Length": "89",
                "Authorization": auth_signature}
    # HTML Body
    payload = json.dumps(payload)
    # Post Request
    r = requests.post(url, data=payload, headers=headers)
    # 打印原始Json
    parsed = json.loads(r.text)
    return parsed

# %%
# get_item_list
def get_item_list(partner_id, shopid, shop_key):
    # parameters
    max_page = 200
    pagination_entries_per_page = 100
    i = 0
    # Current time stamp
    timestamp = int(time.time())
    # URL
    url = 'https://partner.shopeemobile.com/api/v1/items/get'
    
    try:
        while i <= max_page:
            # start entry
            start_entry = i * pagination_entries_per_page
            # Parameter
            pagination_offset = start_entry
            # payload
            payload = {"partner_id":partner_id,
                       "shopid":shopid,
                       "timestamp":timestamp,
                       "pagination_offset":pagination_offset,
                       "pagination_entries_per_page":pagination_entries_per_page}
            # post_message_to_shopee_api
            parsed = post_message_to_shopee_api(url, payload, shop_key)
            # 漂亮打印Json
            item_list = json_normalize(parsed['items'])
            # 排除update_time
            selected_column = ['item_id', 'shopid', 'status']
            item_list = item_list[selected_column]

            # 合并
            if i == 0:
                all_item_list = item_list
            else:
                all_item_list = all_item_list.append(item_list)

            i += 1
            logging.info('Retrieving item from page ' + str(i))
    except:
        pass

    # 去重
    logging.info('Remove duplicate records.')
    all_item_list = all_item_list.drop_duplicates('item_id').reset_index()
    logging.info('Retrieved item list.')
    return all_item_list

# %%
# get_item_detail
def get_item_detail(partner_id, shopid, shop_key, all_item_list):
    # empty item_detail_list
    item_detail_list = pd.DataFrame()
    # Current time stamp
    timestamp = int(time.time())
    # get item detail
    url = 'https://partner.shopeemobile.com/api/v1/item/get'
    
    for key, item in all_item_list.iterrows():
        try:
            item_id = item['item_id']
            logging.info('Now retrieving ' + str(item_id) + ' detail.')
            # payload
            payload = {"partner_id":partner_id,
                       "shopid":shopid,
                       "timestamp":timestamp,
                       "item_id": item_id}
            # post_message_to_shopee_api
            parsed = post_message_to_shopee_api(url, payload, shop_key)
            # 漂亮打印Json
            item_detail = json_normalize(parsed['item'])
            item_detail_list = item_detail_list.append(item_detail)
            logging.info('Retrieved ' + str(item_id) + ' detail.')
        except:
            pass

    # convert timestamp to date
    item_detail_list['create_time'] = pd.to_datetime(item_detail_list['create_time'], unit='s').dt.date
    item_detail_list['update_time'] = pd.to_datetime(item_detail_list['update_time'], unit='s').dt.date
    item_detail_list['days_since_live'] = (today_date - item_detail_list['create_time']).dt.days    
    
    return item_detail_list

# %%
# retrieve_dict_and_convert_to_df_column
def retrieve_dict_and_convert_to_df_column(dataframe, column_name, selected_key_list, converted_column_name):

    edited_column_list = []

    for index, record in dataframe.iterrows():
        to_edit_column = pd.DataFrame(record[column_name])
        try:
            to_edit_column = to_edit_column[selected_key_list]
            to_edit_column_dict = to_edit_column.to_dict('records')
        except:
            to_edit_column_dict = '[]'
        edited_column_list.append(to_edit_column_dict)
    
    dataframe[converted_column_name] = edited_column_list
    return dataframe

# %%
# retrieve_image_and_convert_to_dict
def retrieve_image_and_convert_to_dict(dataframe, column_name, converted_column_name):
    edited_column_list = []
    for index, record in dataframe.iterrows():
        img_url_dict_list = []
        to_edit_column = pd.DataFrame(record[column_name])
        for index, img_url in to_edit_column.iterrows():
            img_url_dict = {'url': img_url[0]}
            img_url_dict_list.append(img_url_dict)
        edited_column_list.append(img_url_dict_list)
    dataframe[converted_column_name] = edited_column_list
    return dataframe

# %%
# 根据每个分类，找到必填的attributes，然后填上
def get_category_attributes(partner_id, shopid, shop_key, category_id):
    # Current time stamp
    timestamp = int(time.time())
    
    payload = {"partner_id":partner_id,
               "shopid": shopid,
               "timestamp": timestamp,
               "category_id": category_id}

    url = 'https://partner.shopeemobile.com/api/v1/item/attributes/get'

    # post_message_to_shopee_api
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    # 漂亮打印Json
    attribute_list = json_normalize(parsed['attributes'])
    attribute_list['category_id'] = category_id
    
    # 查找是否有error
    
    return attribute_list

# %%
# 找店铺分类
def get_category_info(partner_id, shopid, shop_key):
    
    # Current time stamp
    timestamp = int(time.time())
    
    payload = {"partner_id":partner_id,
               "shopid": shopid,
               "timestamp": timestamp}

    url = 'https://partner.shopeemobile.com/api/v1/item/categories/get'

    # post_message_to_shopee_api
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    # 漂亮打印Json
    category_list = json_normalize(parsed['categories'])
    
    # 查找是否有error
    
    return category_list

# %%
# 删除产品
def delete_product(partner_id, shopid, shop_key, delete_product_id):
    # Current time stamp
    timestamp = int(time.time())
    
    # payload
    payload = {
               "item_id": delete_product_id,
               "partner_id": partner_id,
               "shopid": shopid,
               "timestamp": timestamp
               }

    # print(payload)
    
    url = 'https://partner.shopeemobile.com/api/v1/item/delete'

    # post_message_to_shopee_api
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    logging.info('Product ID: ' + str(delete_product_id) + ' is deleted.')
    
    # 查找是否有error

# %%
# 添加商品图片
def add_product_image(partner_id, shopid, shop_key, item_id, images):
    # 上传中可能失败；尝试到找不到fail_image为止
    while len(images) != 0:
        # Current time stamp
        timestamp = int(time.time())

        # payload
        payload = {
                    "item_id": item_id,
                    "images": images,
                    "partner_id": partner_id,
                    "shopid": shopid,
                    "timestamp": timestamp
                   }

        url = 'https://partner.shopeemobile.com/api/v1/item/img/add'

        # post_message_to_shopee_api
        parsed = post_message_to_shopee_api(url, payload, shop_key)
        # print(parsed)
        logging.info('add_product_image - Images for Product ID: ' + str(item_id) + ' are added.')
        # 清空images
        images = []
        
        # 查找是否有error

        # 查找是否有上传失败的图片
        if 'fail_image' in parsed.keys():
            logging.info('add_product_image - Start to upload failed images.')
            images = parsed['fail_image']

# %%
# 新增产品
def add_product(partner_id, shopid, shop_key,
                category_id,
                name,
                description,
                price,
                stock,
                item_sku,
                edited_variations,
                edited_images,
                edited_attributes,
                edited_logistics,
                weight
               ):
    # Current time stamp
    timestamp = int(time.time())
    
    # payload
    payload = {
                "category_id": category_id,
                "name": name,
                "description": description,
                "price": price,
                "stock": stock,
                "item_sku": item_sku,
                "images": edited_images,
                "weight": weight,
                "logistics": edited_logistics,
                # "days_to_ship": days_to_ship,
                "partner_id": partner_id,
                "shopid": shopid,
                "timestamp": timestamp
               }
    
    # 判断条件是否为空
    if edited_variations != '[]':
        payload['variations'] = edited_variations
        
    if edited_attributes != '[]':
        payload['attributes'] = edited_attributes
        
    # print(payload)

    url = 'https://partner.shopeemobile.com/api/v1/item/add'

    # post_message_to_shopee_api
    logging.info('add_product - Add Product SKU: ' + str(item_sku))
    parsed = post_message_to_shopee_api(url, payload, shop_key)
    # print(parsed)
    
    # 查找是否有error
    if 'error' in parsed.keys():
        logging.warning(parsed)
    else:
        item_id = parsed['item_id']
        logging.info('add_product - Product ID: ' + str(item_id) + ' is added.')

        # 判断是否有图片上传失败；如果失败要重传
        try:
            fail_image_list = parsed['fail_image']
            # print(fail_image_list)
            logging.info('add_product - Try to upload failed images.')
            add_product_image(partner_id, shopid, shop_key, item_id, fail_image_list)
            logging.info('add_product - Images are added.')
        except Exception as err:
            logging.info('add_product - An exception occurred: ' + str(err))

# %%
# shop parameter list# shop  
# partner_id, shopid, shop_name, shop_key
shop_parameter_list = [\
   [12155, 23070969, 'poweradapter.tw', 'de5e924b8ed680bc9b22a6c402058154340333ff05641a38069f2856a2f3e24e'],
   [12156, 25482220, 'tengus.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [14689, 53580963, 'qianjiaozi.my', '93815a723e386c9b91379a94f31538853582e02e085e180e0d52c841f7b53e19'],
   [12156, 59848325, 'tengus.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 59846508, 'tengus.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 58707738, 'qianjiaozi', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [12156, 62417386, 'tengus1.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62417551, 'tengus2.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416366, 'tengus1.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416544, 'tengus2.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418141, 'tengus1.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418493, 'tengus2.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 63534861, 'qianjiaozitw1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [17701, 62887142, 'yilanlu.tw', 'f3e23e0a873b0d74bb8a05b03a77e7a7a03bfebdba622d685b64aa926467d8b9'],
   [16363, 66377809, 'qianjiaozi1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3']
  ]

columns = ['partner_id', 'shopid', 'shop_name', 'shop_key']
shop_parameter_df = pd.DataFrame(shop_parameter_list, columns=columns)
# shop_parameter_df

# %%
def delect_inactive_skus_and_upload_again(partner_id, shopid, shop_name, shop_key):
    # 1. get item list
    all_item_list = get_item_list(partner_id, shopid, shop_key)
    # 2. get item detail list
    item_detail_list = get_item_detail(partner_id, shopid, shop_key, all_item_list)
    # 3. filter item detail list
    # 选上线超过60天仍然0销量的产品
    item_detail_list = item_detail_list[item_detail_list['days_since_live'] >= 60]
    item_detail_list = item_detail_list[item_detail_list['sales'] == 0]
    item_detail_list = item_detail_list.sort_values(by='days_since_live', ascending=False)
    # 4. get item attributes list
    column_name = 'attributes'
    selected_key_list = ['attribute_id', 'attribute_value']
    converted_column_name = 'edited attributes'
    retrieve_dict_and_convert_to_df_column(item_detail_list, column_name, selected_key_list, converted_column_name)
    # 5. 把attribute_id改为attributes_id
    for value in item_detail_list['edited attributes']:
        for dict_value in value:
            dict_value['attributes_id'] = dict_value.pop('attribute_id')
            dict_value['value'] = dict_value.pop('attribute_value')
    # 6. 看店铺所有分类的必填attributes
    category_id_list = item_detail_list['category_id'].drop_duplicates()
    # 7. 获取这个店铺所有分类的attributes list
    attribute_full_list = pd.DataFrame()
    for category_id in category_id_list:
        # print(int(category_id))
        category_id = int(category_id)
        category_attribute = get_category_attributes(partner_id, shopid, shop_key, category_id)
        attribute_full_list = attribute_full_list.append(category_attribute)
    # 8. 给每个必填attribute提供default value
    attribute_default_value_list = [
        [5794, 9547, '握力'],
        [11460, 9547, '握力']
    ]
    attribute_default_value_columns = ['category_id', 'attribute_id', 'value']
    attribute_default_value_df = pd.DataFrame(attribute_default_value_list, columns=attribute_default_value_columns)
    attribute_full_list = pd.merge(attribute_full_list, attribute_default_value_df, how='left',
                               left_on=['category_id', 'attribute_id'], right_on=['category_id', 'attribute_id'])
    # 9. 检查每个产品的attributes
    # 检查现有的attributes是否在表里；如果不存在，要删除
    # 如果缺了必填的attributes，要补充回来
    for index, value in item_detail_list.iterrows():
        # 拿到每个产品的cat id
        category_id = value['category_id']
        # 创建一个空list，装这个产品的所有现有attributes
        existing_attribute = []

        # for loop所有这个产品的attributes，放在existing_attribute
        for dict_value in value['edited attributes']:
            existing_attribute.append(dict_value['attributes_id'])
        # print(existing_attribute)

        # 把这个cat的必填attribute拉出来
        cat_mandatory_attribute_df = (attribute_full_list[(attribute_full_list['category_id'] == category_id)
                                                           & (attribute_full_list['is_mandatory'] == True)])
        # print((cat_mandatory_attribute_list))

        # 把这个cat的非必填attribute拉出来
        cat_optional_attribute_df = (attribute_full_list[(attribute_full_list['category_id'] == category_id)
                                                           & (attribute_full_list['is_mandatory'] == False)])
        # print((cat_optional_attribute_list))

        # 判断必填attributes是不是在现有attributes内
        for index, attr in cat_mandatory_attribute_df.iterrows():
            mandatory_attribute_id = attr['attribute_id']
            mandatory_attribute_value = attr['value']

            if mandatory_attribute_id not in existing_attribute:
                # print('attr: ' + str(mandatory_attribute_id) + ' is not in mandatory_attribute_list.')
                attr_dict = {'attributes_id': mandatory_attribute_id,
                             'value': mandatory_attribute_value}
                value['edited attributes'].append(attr_dict)

        # 判断现有非必填attributes内是否有不符合的非必填attributes
        for attr in existing_attribute:
            # print(attr)
            if attr not in list(cat_mandatory_attribute_df['attribute_id']):
                if attr not in list(cat_optional_attribute_df['attribute_id']):
                    print('attr: ' + str(attr) + ' is not in optional_attribute_list.')
                    # 删除这个不符合的非必填项
                    for dict_value in value['edited attributes']:
                        if dict_value['attributes_id'] == attr:
                            del dict_value
    
    # 10. 删减variations的内容
    column_name = 'variations'
    selected_key_list = ['name', 'stock', 'price', 'variation_sku']
    converted_column_name = 'edited variations'
    retrieve_dict_and_convert_to_df_column(item_detail_list, column_name, selected_key_list, converted_column_name)                 
    # 11. 删减logistics的内容
    column_name = 'logistics'
    selected_key_list = ['logistic_id', 'enabled']
    converted_column_name = 'edited logistics'
    retrieve_dict_and_convert_to_df_column(item_detail_list, column_name, selected_key_list, converted_column_name)
    # 12. 转换images的内容
    column_name = 'images'
    converted_column_name = 'edited images'
    retrieve_image_and_convert_to_dict(item_detail_list, column_name, converted_column_name)
    # 13. 选择需要提交的内容
    selected_columns = ["category_id","name","description","price","stock","item_sku","edited variations","images","edited attributes","edited logistics","weight","days_to_ship", 'item_id', 'edited images']
    edited_item_detail_list = item_detail_list[selected_columns]    
    # 测试
    test_item_detail_list = edited_item_detail_list[:3]
    test_item_detail_list    
    # 14. 先删除产品，再新增产品
    for index, item in test_item_detail_list.iterrows():
        category_id = item[0]
        name = item[1]
        description = item[2]
        price = item[3]
        stock = item[4]
        item_sku = item[5]
        edited_variations = item[6]
        images = item[7]
        edited_attributes = item[8]
        edited_logistics = item[9]
        weight = item[10]
        # days_to_ship = 3
        product_id = item[12]
        edited_images = item[13]

        # print(images)

        # delete product
        # delete_product(partner_id, shopid, shop_key, product_id)

        # add product
        add_product(partner_id, shopid, shop_key,
                   category_id,
                   name,
                   description,
                   price,
                   stock,
                   item_sku,
                   edited_variations,
                   edited_images,
                   edited_attributes,
                   edited_logistics,
                   weight
                   )

# %%
# 执行
for index, shop_parameter in shop_parameter_df.iterrows():
    partner_id = shop_parameter[0]
    shopid = shop_parameter[1]
    shop_name = shop_parameter[2]
    shop_key = shop_parameter[3]
    
    if shopid == 23070969:
        delect_inactive_skus_and_upload_again(partner_id, shopid, shop_name, shop_key)
        # images = ['https://t12.baidu.com/it/u=2105759597,3540269422&fm=173&app=25&f=JPEG?w=500&h=518&s=3DBB6A96EA533CCC3E6F59A20300E009','https://t12.baidu.com/it/u=667913453,121168607&fm=173&app=25&f=JPEG?w=500&h=309&s=B582EBB47E1B2CC042B2D9A20300E008']
        # item_id = 1194753880
        # add_product_image(partner_id, shopid, shop_key, item_id, images)
# Out:
#  2018-05-27 23:58:06,660 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:07,132 - INFO - Retrieving item from page 1
#  2018-05-27 23:58:07,135 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:07,505 - INFO - Retrieving item from page 2
#  2018-05-27 23:58:07,509 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:07,900 - INFO - Remove duplicate records.
#  2018-05-27 23:58:07,903 - INFO - Retrieved item list.
#  2018-05-27 23:58:07,905 - INFO - Now retrieving 1197685136 detail.
#  2018-05-27 23:58:07,908 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:08,457 - INFO - Retrieved 1197685136 detail.
#  2018-05-27 23:58:08,458 - INFO - Now retrieving 1197685051 detail.
#  2018-05-27 23:58:08,461 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:09,224 - INFO - Retrieved 1197685051 detail.
#  2018-05-27 23:58:09,225 - INFO - Now retrieving 1196145106 detail.
#  2018-05-27 23:58:09,229 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:09,858 - INFO - Retrieved 1196145106 detail.
#  2018-05-27 23:58:09,859 - INFO - Now retrieving 1196145009 detail.
#  2018-05-27 23:58:09,861 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:10,712 - INFO - Retrieved 1196145009 detail.
#  2018-05-27 23:58:10,713 - INFO - Now retrieving 1194753760 detail.
#  2018-05-27 23:58:10,717 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:11,140 - INFO - Retrieved 1194753760 detail.
#  2018-05-27 23:58:11,141 - INFO - Now retrieving 1194753512 detail.
#  2018-05-27 23:58:11,144 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:11,592 - INFO - Retrieved 1194753512 detail.
#  2018-05-27 23:58:11,593 - INFO - Now retrieving 1194753393 detail.
#  2018-05-27 23:58:11,596 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:12,108 - INFO - Retrieved 1194753393 detail.
#  2018-05-27 23:58:12,109 - INFO - Now retrieving 1121446661 detail.
#  2018-05-27 23:58:12,112 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:12,658 - INFO - Retrieved 1121446661 detail.
#  2018-05-27 23:58:12,659 - INFO - Now retrieving 1121455576 detail.
#  2018-05-27 23:58:12,662 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:13,101 - INFO - Retrieved 1121455576 detail.
#  2018-05-27 23:58:13,102 - INFO - Now retrieving 1121423066 detail.
#  2018-05-27 23:58:13,105 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:13,492 - INFO - Retrieved 1121423066 detail.
#  2018-05-27 23:58:13,493 - INFO - Now retrieving 725349781 detail.
#  2018-05-27 23:58:13,497 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:14,033 - INFO - Retrieved 725349781 detail.
#  2018-05-27 23:58:14,033 - INFO - Now retrieving 725351767 detail.
#  2018-05-27 23:58:14,036 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:14,463 - INFO - Retrieved 725351767 detail.
#  2018-05-27 23:58:14,464 - INFO - Now retrieving 725352772 detail.
#  2018-05-27 23:58:14,466 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:14,942 - INFO - Retrieved 725352772 detail.
#  2018-05-27 23:58:14,943 - INFO - Now retrieving 288208978 detail.
#  2018-05-27 23:58:14,945 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:15,358 - INFO - Retrieved 288208978 detail.
#  2018-05-27 23:58:15,359 - INFO - Now retrieving 289817750 detail.
#  2018-05-27 23:58:15,363 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:15,790 - INFO - Retrieved 289817750 detail.
#  2018-05-27 23:58:15,791 - INFO - Now retrieving 289817643 detail.
#  2018-05-27 23:58:15,795 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:16,287 - INFO - Retrieved 289817643 detail.
#  2018-05-27 23:58:16,288 - INFO - Now retrieving 289817813 detail.
#  2018-05-27 23:58:16,291 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:16,879 - INFO - Retrieved 289817813 detail.
#  2018-05-27 23:58:16,881 - INFO - Now retrieving 289819286 detail.
#  2018-05-27 23:58:16,884 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:17,461 - INFO - Retrieved 289819286 detail.
#  2018-05-27 23:58:17,462 - INFO - Now retrieving 289819304 detail.
#  2018-05-27 23:58:17,465 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:18,031 - INFO - Retrieved 289819304 detail.
#  2018-05-27 23:58:18,032 - INFO - Now retrieving 289817722 detail.
#  2018-05-27 23:58:18,035 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:18,780 - INFO - Retrieved 289817722 detail.
#  2018-05-27 23:58:18,781 - INFO - Now retrieving 692636419 detail.
#  2018-05-27 23:58:18,785 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:19,572 - INFO - Retrieved 692636419 detail.
#  2018-05-27 23:58:19,573 - INFO - Now retrieving 692636375 detail.
#  2018-05-27 23:58:19,577 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:20,125 - INFO - Retrieved 692636375 detail.
#  2018-05-27 23:58:20,125 - INFO - Now retrieving 692636377 detail.
#  2018-05-27 23:58:20,129 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:20,712 - INFO - Retrieved 692636377 detail.
#  2018-05-27 23:58:20,713 - INFO - Now retrieving 714255768 detail.
#  2018-05-27 23:58:20,716 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:21,286 - INFO - Retrieved 714255768 detail.
#  2018-05-27 23:58:21,287 - INFO - Now retrieving 692636406 detail.
#  2018-05-27 23:58:21,290 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:21,758 - INFO - Retrieved 692636406 detail.
#  2018-05-27 23:58:21,759 - INFO - Now retrieving 714255091 detail.
#  2018-05-27 23:58:21,761 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:22,269 - INFO - Retrieved 714255091 detail.
#  2018-05-27 23:58:22,270 - INFO - Now retrieving 714254359 detail.
#  2018-05-27 23:58:22,274 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:22,716 - INFO - Retrieved 714254359 detail.
#  2018-05-27 23:58:22,717 - INFO - Now retrieving 289815417 detail.
#  2018-05-27 23:58:22,720 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:23,160 - INFO - Retrieved 289815417 detail.
#  2018-05-27 23:58:23,161 - INFO - Now retrieving 714247264 detail.
#  2018-05-27 23:58:23,165 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:23,750 - INFO - Retrieved 714247264 detail.
#  2018-05-27 23:58:23,750 - INFO - Now retrieving 714246489 detail.
#  2018-05-27 23:58:23,756 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:24,158 - INFO - Retrieved 714246489 detail.
#  2018-05-27 23:58:24,159 - INFO - Now retrieving 714246503 detail.
#  2018-05-27 23:58:24,163 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:24,578 - INFO - Retrieved 714246503 detail.
#  2018-05-27 23:58:24,579 - INFO - Now retrieving 714246495 detail.
#  2018-05-27 23:58:24,583 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:25,084 - INFO - Retrieved 714246495 detail.
#  2018-05-27 23:58:25,085 - INFO - Now retrieving 714246499 detail.
#  2018-05-27 23:58:25,089 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:25,618 - INFO - Retrieved 714246499 detail.
#  2018-05-27 23:58:25,619 - INFO - Now retrieving 714246443 detail.
#  2018-05-27 23:58:25,622 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:26,016 - INFO - Retrieved 714246443 detail.
#  2018-05-27 23:58:26,017 - INFO - Now retrieving 714246472 detail.
#  2018-05-27 23:58:26,020 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:26,482 - INFO - Retrieved 714246472 detail.
#  2018-05-27 23:58:26,482 - INFO - Now retrieving 714246461 detail.
#  2018-05-27 23:58:26,486 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:27,029 - INFO - Retrieved 714246461 detail.
#  2018-05-27 23:58:27,030 - INFO - Now retrieving 714246479 detail.
#  2018-05-27 23:58:27,034 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:28,440 - INFO - Retrieved 714246479 detail.
#  2018-05-27 23:58:28,441 - INFO - Now retrieving 714246468 detail.
#  2018-05-27 23:58:28,445 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:28,929 - INFO - Retrieved 714246468 detail.
#  2018-05-27 23:58:28,930 - INFO - Now retrieving 714246429 detail.
#  2018-05-27 23:58:28,934 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:29,449 - INFO - Retrieved 714246429 detail.
#  2018-05-27 23:58:29,450 - INFO - Now retrieving 714246482 detail.
#  2018-05-27 23:58:29,452 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:29,891 - INFO - Retrieved 714246482 detail.
#  2018-05-27 23:58:29,892 - INFO - Now retrieving 714246430 detail.
#  2018-05-27 23:58:29,896 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:30,332 - INFO - Retrieved 714246430 detail.
#  2018-05-27 23:58:30,333 - INFO - Now retrieving 714246433 detail.
#  2018-05-27 23:58:30,336 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:30,770 - INFO - Retrieved 714246433 detail.
#  2018-05-27 23:58:30,771 - INFO - Now retrieving 714246435 detail.
#  2018-05-27 23:58:30,774 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:31,230 - INFO - Retrieved 714246435 detail.
#  2018-05-27 23:58:31,231 - INFO - Now retrieving 714246437 detail.
#  2018-05-27 23:58:31,234 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:31,682 - INFO - Retrieved 714246437 detail.
#  2018-05-27 23:58:31,683 - INFO - Now retrieving 714246434 detail.
#  2018-05-27 23:58:31,686 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:32,196 - INFO - Retrieved 714246434 detail.
#  2018-05-27 23:58:32,197 - INFO - Now retrieving 714246405 detail.
#  2018-05-27 23:58:32,200 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:32,760 - INFO - Retrieved 714246405 detail.
#  2018-05-27 23:58:32,761 - INFO - Now retrieving 714246402 detail.
#  2018-05-27 23:58:32,764 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:33,307 - INFO - Retrieved 714246402 detail.
#  2018-05-27 23:58:33,308 - INFO - Now retrieving 714246413 detail.
#  2018-05-27 23:58:33,312 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:33,783 - INFO - Retrieved 714246413 detail.
#  2018-05-27 23:58:33,784 - INFO - Now retrieving 714246408 detail.
#  2018-05-27 23:58:33,788 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:34,278 - INFO - Retrieved 714246408 detail.
#  2018-05-27 23:58:34,279 - INFO - Now retrieving 714246365 detail.
#  2018-05-27 23:58:34,282 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:34,735 - INFO - Retrieved 714246365 detail.
#  2018-05-27 23:58:34,736 - INFO - Now retrieving 692636373 detail.
#  2018-05-27 23:58:34,739 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:35,153 - INFO - Retrieved 692636373 detail.
#  2018-05-27 23:58:35,153 - INFO - Now retrieving 714246361 detail.
#  2018-05-27 23:58:35,157 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:35,613 - INFO - Retrieved 714246361 detail.
#  2018-05-27 23:58:35,615 - INFO - Now retrieving 692636458 detail.
#  2018-05-27 23:58:35,618 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:36,061 - INFO - Retrieved 692636458 detail.
#  2018-05-27 23:58:36,062 - INFO - Now retrieving 692636439 detail.
#  2018-05-27 23:58:36,065 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:36,494 - INFO - Retrieved 692636439 detail.
#  2018-05-27 23:58:36,495 - INFO - Now retrieving 692636460 detail.
#  2018-05-27 23:58:36,499 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:37,059 - INFO - Retrieved 692636460 detail.
#  2018-05-27 23:58:37,060 - INFO - Now retrieving 692636465 detail.
#  2018-05-27 23:58:37,063 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:37,553 - INFO - Retrieved 692636465 detail.
#  2018-05-27 23:58:37,554 - INFO - Now retrieving 692642614 detail.
#  2018-05-27 23:58:37,558 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:37,961 - INFO - Retrieved 692642614 detail.
#  2018-05-27 23:58:37,962 - INFO - Now retrieving 692636451 detail.
#  2018-05-27 23:58:37,965 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:38,387 - INFO - Retrieved 692636451 detail.
#  2018-05-27 23:58:38,387 - INFO - Now retrieving 692636384 detail.
#  2018-05-27 23:58:38,390 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:38,883 - INFO - Retrieved 692636384 detail.
#  2018-05-27 23:58:38,884 - INFO - Now retrieving 714273694 detail.
#  2018-05-27 23:58:38,887 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:39,489 - INFO - Retrieved 714273694 detail.
#  2018-05-27 23:58:39,490 - INFO - Now retrieving 714273131 detail.
#  2018-05-27 23:58:39,493 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:40,049 - INFO - Retrieved 714273131 detail.
#  2018-05-27 23:58:40,050 - INFO - Now retrieving 692636390 detail.
#  2018-05-27 23:58:40,053 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:40,511 - INFO - Retrieved 692636390 detail.
#  2018-05-27 23:58:40,512 - INFO - Now retrieving 714272553 detail.
#  2018-05-27 23:58:40,517 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:41,047 - INFO - Retrieved 714272553 detail.
#  2018-05-27 23:58:41,047 - INFO - Now retrieving 714271936 detail.
#  2018-05-27 23:58:41,051 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:41,805 - INFO - Retrieved 714271936 detail.
#  2018-05-27 23:58:41,806 - INFO - Now retrieving 692636393 detail.
#  2018-05-27 23:58:41,809 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:42,725 - INFO - Retrieved 692636393 detail.
#  2018-05-27 23:58:42,726 - INFO - Now retrieving 714271603 detail.
#  2018-05-27 23:58:42,729 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:43,813 - INFO - Retrieved 714271603 detail.
#  2018-05-27 23:58:43,814 - INFO - Now retrieving 714270605 detail.
#  2018-05-27 23:58:43,818 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:44,425 - INFO - Retrieved 714270605 detail.
#  2018-05-27 23:58:44,426 - INFO - Now retrieving 692636400 detail.
#  2018-05-27 23:58:44,430 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:44,801 - INFO - Retrieved 692636400 detail.
#  2018-05-27 23:58:44,803 - INFO - Now retrieving 714271171 detail.
#  2018-05-27 23:58:44,806 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:45,209 - INFO - Retrieved 714271171 detail.
#  2018-05-27 23:58:45,210 - INFO - Now retrieving 714269818 detail.
#  2018-05-27 23:58:45,214 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:45,647 - INFO - Retrieved 714269818 detail.
#  2018-05-27 23:58:45,648 - INFO - Now retrieving 714269270 detail.
#  2018-05-27 23:58:45,651 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:46,109 - INFO - Retrieved 714269270 detail.
#  2018-05-27 23:58:46,110 - INFO - Now retrieving 714268309 detail.
#  2018-05-27 23:58:46,114 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:46,533 - INFO - Retrieved 714268309 detail.
#  2018-05-27 23:58:46,534 - INFO - Now retrieving 714267005 detail.
#  2018-05-27 23:58:46,538 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:46,978 - INFO - Retrieved 714267005 detail.
#  2018-05-27 23:58:46,979 - INFO - Now retrieving 714265848 detail.
#  2018-05-27 23:58:46,982 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:47,420 - INFO - Retrieved 714265848 detail.
#  2018-05-27 23:58:47,420 - INFO - Now retrieving 692636409 detail.
#  2018-05-27 23:58:47,423 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:47,903 - INFO - Retrieved 692636409 detail.
#  2018-05-27 23:58:47,904 - INFO - Now retrieving 692636422 detail.
#  2018-05-27 23:58:47,907 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:48,332 - INFO - Retrieved 692636422 detail.
#  2018-05-27 23:58:48,333 - INFO - Now retrieving 714265338 detail.
#  2018-05-27 23:58:48,336 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:48,852 - INFO - Retrieved 714265338 detail.
#  2018-05-27 23:58:48,853 - INFO - Now retrieving 714264459 detail.
#  2018-05-27 23:58:48,856 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:49,277 - INFO - Retrieved 714264459 detail.
#  2018-05-27 23:58:49,278 - INFO - Now retrieving 714264913 detail.
#  2018-05-27 23:58:49,281 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:49,806 - INFO - Retrieved 714264913 detail.
#  2018-05-27 23:58:49,807 - INFO - Now retrieving 692636424 detail.
#  2018-05-27 23:58:49,810 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:50,279 - INFO - Retrieved 692636424 detail.
#  2018-05-27 23:58:50,280 - INFO - Now retrieving 692636423 detail.
#  2018-05-27 23:58:50,284 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:50,715 - INFO - Retrieved 692636423 detail.
#  2018-05-27 23:58:50,716 - INFO - Now retrieving 714264130 detail.
#  2018-05-27 23:58:50,719 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:51,154 - INFO - Retrieved 714264130 detail.
#  2018-05-27 23:58:51,155 - INFO - Now retrieving 714263328 detail.
#  2018-05-27 23:58:51,158 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:51,593 - INFO - Retrieved 714263328 detail.
#  2018-05-27 23:58:51,594 - INFO - Now retrieving 714262638 detail.
#  2018-05-27 23:58:51,598 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:52,027 - INFO - Retrieved 714262638 detail.
#  2018-05-27 23:58:52,028 - INFO - Now retrieving 692636425 detail.
#  2018-05-27 23:58:52,030 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:52,714 - INFO - Retrieved 692636425 detail.
#  2018-05-27 23:58:52,715 - INFO - Now retrieving 714262262 detail.
#  2018-05-27 23:58:52,718 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:53,211 - INFO - Retrieved 714262262 detail.
#  2018-05-27 23:58:53,213 - INFO - Now retrieving 714261721 detail.
#  2018-05-27 23:58:53,216 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:53,618 - INFO - Retrieved 714261721 detail.
#  2018-05-27 23:58:53,618 - INFO - Now retrieving 692636431 detail.
#  2018-05-27 23:58:53,621 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:54,072 - INFO - Retrieved 692636431 detail.
#  2018-05-27 23:58:54,073 - INFO - Now retrieving 714261044 detail.
#  2018-05-27 23:58:54,076 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:54,577 - INFO - Retrieved 714261044 detail.
#  2018-05-27 23:58:54,578 - INFO - Now retrieving 714259996 detail.
#  2018-05-27 23:58:54,582 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:55,002 - INFO - Retrieved 714259996 detail.
#  2018-05-27 23:58:55,003 - INFO - Now retrieving 714260422 detail.
#  2018-05-27 23:58:55,006 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:56,157 - INFO - Retrieved 714260422 detail.
#  2018-05-27 23:58:56,158 - INFO - Now retrieving 714259330 detail.
#  2018-05-27 23:58:56,161 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:56,674 - INFO - Retrieved 714259330 detail.
#  2018-05-27 23:58:56,675 - INFO - Now retrieving 714259323 detail.
#  2018-05-27 23:58:56,678 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:57,143 - INFO - Retrieved 714259323 detail.
#  2018-05-27 23:58:57,144 - INFO - Now retrieving 714259351 detail.
#  2018-05-27 23:58:57,148 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:57,602 - INFO - Retrieved 714259351 detail.
#  2018-05-27 23:58:57,603 - INFO - Now retrieving 714259335 detail.
#  2018-05-27 23:58:57,607 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:58,442 - INFO - Retrieved 714259335 detail.
#  2018-05-27 23:58:58,443 - INFO - Now retrieving 714259334 detail.
#  2018-05-27 23:58:58,447 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:58,894 - INFO - Retrieved 714259334 detail.
#  2018-05-27 23:58:58,895 - INFO - Now retrieving 692636435 detail.
#  2018-05-27 23:58:58,898 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:59,346 - INFO - Retrieved 692636435 detail.
#  2018-05-27 23:58:59,347 - INFO - Now retrieving 692636376 detail.
#  2018-05-27 23:58:59,351 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:58:59,958 - INFO - Retrieved 692636376 detail.
#  2018-05-27 23:58:59,959 - INFO - Now retrieving 714258779 detail.
#  2018-05-27 23:58:59,962 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:00,546 - INFO - Retrieved 714258779 detail.
#  2018-05-27 23:59:00,547 - INFO - Now retrieving 714258341 detail.
#  2018-05-27 23:59:00,551 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:01,163 - INFO - Retrieved 714258341 detail.
#  2018-05-27 23:59:01,164 - INFO - Now retrieving 714257427 detail.
#  2018-05-27 23:59:01,168 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:01,754 - INFO - Retrieved 714257427 detail.
#  2018-05-27 23:59:01,755 - INFO - Now retrieving 714256660 detail.
#  2018-05-27 23:59:01,758 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:02,339 - INFO - Retrieved 714256660 detail.
#  2018-05-27 23:59:02,340 - INFO - Now retrieving 725348865 detail.
#  2018-05-27 23:59:02,348 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:03,083 - INFO - Retrieved 725348865 detail.
#  2018-05-27 23:59:03,084 - INFO - Now retrieving 692636407 detail.
#  2018-05-27 23:59:03,088 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:03,490 - INFO - Retrieved 692636407 detail.
#  2018-05-27 23:59:03,491 - INFO - Now retrieving 714268772 detail.
#  2018-05-27 23:59:03,495 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:04,619 - INFO - Retrieved 714268772 detail.
#  2018-05-27 23:59:04,620 - INFO - Now retrieving 289819285 detail.
#  2018-05-27 23:59:04,623 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:05,103 - INFO - Retrieved 289819285 detail.
#  2018-05-27 23:59:05,237 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:05,635 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:06,821 - INFO - add_product - Add Product SKU: 32297550062
#  2018-05-27 23:59:06,824 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:09,019 - WARNING - {'error': 'error_duplicate', 'msg': 'item is duplicate'}
#  2018-05-27 23:59:09,020 - INFO - add_product - Add Product SKU: 32464588670
#  2018-05-27 23:59:09,024 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:11,640 - WARNING - {'error': 'error_duplicate', 'msg': 'item is duplicate'}
#  2018-05-27 23:59:11,641 - INFO - add_product - Add Product SKU: 32695681988
#  2018-05-27 23:59:11,645 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:13,356 - INFO - add_product - Product ID: 1197696633 is added.
#  2018-05-27 23:59:13,357 - INFO - add_product - Try to upload failed images.
#  2018-05-27 23:59:13,360 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-27 23:59:14,114 - INFO - add_product_image - Images for Product ID: 1197696633 are added.
#  2018-05-27 23:59:14,115 - INFO - add_product - Images are added.
