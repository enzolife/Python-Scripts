# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pandas.io.json import json_normalize

import numpy
import logging

# %%
# Current time stamp
timestamp = int(time.time())

# %%
logging.basicConfig(level=logging.INFO, format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
# logging.info('yes')

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
today_date.strftime('%Y_%m_%d')
# Out:
# '2018_05_11'

# %%
# shop parameter list
# partner_id, shopid, shop_name, shop_key
shop_parameter_list = [\
   [12156, 25482220, 'tengus.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [14689, 53580963, 'qianjiaozi.my', '93815a723e386c9b91379a94f31538853582e02e085e180e0d52c841f7b53e19'],
   [12156, 59848325, 'tengus.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 59846508, 'tengus.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 58707738, 'qianjiaozi', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [12156, 62417386, 'tengus1.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62417551, 'tengus2.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416366, 'tengus1.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416544, 'tengus2.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418141, 'tengus1.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418493, 'tengus2.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 63534861, 'qianjiaozitw1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [17701, 62887142, 'yilanlu.tw', 'f3e23e0a873b0d74bb8a05b03a77e7a7a03bfebdba622d685b64aa926467d8b9'],
   [16363, 66377809, 'qianjiaozi1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3']
  ]

columns = ['partner_id', 'shopid', 'shop_name', 'shop_key']
shop_parameter_df = pd.DataFrame(shop_parameter_list, columns=columns)
# shop_parameter_df

# %%
# get_auth_signature
def get_auth_signature(url, payload, shop_key):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# URL
url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# get all item for each shop & get item_detail for each item
for key, shop in shop_parameter_df.iterrows():
    all_item_list = pd.DataFrame()
    # parameter
    partner_id = shop['partner_id']
    shopid = shop['shopid']
    shop_key = shop['shop_key']
    shop_name = shop['shop_name']
    timestamp = int(time.time())
    
    # get all item
    logging.info('Retrieving item from ' + shop_name + '.')
    max_page = 200
    pagination_entries_per_page = 100
    i = 0

    try:
        while i <= max_page:
            # start entry
            start_entry = i * pagination_entries_per_page

            # Parameter
            pagination_offset = start_entry

            # payload
            payload = {"partner_id":partner_id,
                       "shopid":shopid,
                       "timestamp":timestamp,
                       "pagination_offset":pagination_offset,
                       "pagination_entries_per_page":pagination_entries_per_page}
            # Auth Signature
            Auth_signature = get_auth_signature(url, payload, shop_key)
            # HTML Header
            headers = {"Host": "partner.shopeemobile.com",
                        "Content-Type": "application/json",
                        "Content-Length": "89",
                        "Authorization": Auth_signature}
            # HTML Body
            payload = json.dumps(payload)
            # Post Request
            r = requests.post(url, data=payload, headers=headers)
            # 打印原始Json
            parsed = json.loads(r.text)
            # 漂亮打印Json
            item_list = json_normalize(parsed['items'])
            # 排除update_time
            selected_column = ['item_id', 'shopid', 'status']
            item_list = item_list[selected_column]

            # 合并
            if i == 0:
                all_item_list = item_list
            else:
                all_item_list = all_item_list.append(item_list)
            i += 1
            logging.info('Retrieving item from page ' + str(i))
    except:
        pass

    # 判断item_list是否非空
    if all_item_list.empty:
        logging.info('No item in shopid:' + str(shopid) + '.')
    else:
        # 去重
        logging.info('Remove duplicate records.')
        all_item_list = all_item_list.drop_duplicates('item_id').reset_index()
        logging.info('Retrieved item list.')
        
        # get item detail
        item_detail_url = 'https://partner.shopeemobile.com/api/v1/item/get'
        
        item_detail_list = pd.DataFrame()
        
        for key, item in all_item_list.iterrows():
            try:
                item_id = item['item_id']
                logging.info('Now retrieving itemid: ' + str(item_id) + ' detail.')
                # payload
                payload = {"partner_id":partner_id,
                           "shopid":shopid,
                           "timestamp":timestamp,
                           "item_id": item_id}
                # Auth Signature
                Auth_signature = get_auth_signature(item_detail_url, payload, shop_key)
                # HTML Header
                headers = {"Host": "partner.shopeemobile.com",
                            "Content-Type": "application/json",
                            "Content-Length": "89",
                            "Authorization": Auth_signature}
                # HTML Body
                payload = json.dumps(payload)
                # Post Request
                r = requests.post(item_detail_url, data=payload, headers=headers)
                # 打印原始Json
                parsed = json.loads(r.text)
                # 提取item部分
                item_detail = json_normalize(parsed['item'])
                # 只提取所需columns
                item_detail_columns = ['item_id', 'item_sku', 'likes', 'name', 'create_time', 'update_time', 'original_price',
                                       'price', 'sales', 'shopid', 'status', 'stock', 'views', 'currency', 'category_id']
                item_detail = item_detail[item_detail_columns]
                # 替换column names
                replace_columns_name = {
                    'item_id': '产品ID',
                    'item_sku': '商品SKU',
                    'likes': '点赞数',
                    'name': '产品名',
                    'create_time': '创建时间',
                    'update_time': '最后更新时间',
                    'original_price': '原价',
                    'price': '现价',
                    'sales': '销量',
                    'shopid': '店铺ID',
                    'status': '产品状态',
                    'stock': '库存', 
                    'views': '点击量',
                    'currency': '货币',
                    'category_id': '分类ID'
                }
                item_detail = item_detail.rename(columns=replace_columns_name)
                # column重新排序
                sort_columns = [
                    '产品ID',
                    '店铺ID',
                    '商品SKU',
                    '产品状态',
                    '产品名',
                    '货币',
                    '创建时间',
                    '最后更新时间',
                    '原价',
                    '现价',
                    '点赞数',
                    '点击量',
                    '销量',
                    '库存',
                    '分类ID'
                ]
                item_detail = item_detail[sort_columns]
                
                # 添加到总表
                item_detail_list = item_detail_list.append(item_detail)
                # print(item_detail)
                logging.info('Retrieved ' + str(item_id) + ' detail.')
            except:
                logging.info('Retrieve ' + str(item_id) + ' not successfully.')
                pass

        # 添加记录时间
        item_detail_list['记录时间'] = today_date
        # 修改create / update time的格式
        item_detail_list['创建时间'] = pd.to_datetime(item_detail_list['创建时间'], unit='s').dt.date
        item_detail_list['最后更新时间'] = pd.to_datetime(item_detail_list['最后更新时间'], unit='s').dt.date
        # 添加销量/点击量
        item_detail_list['销量/点击量'] = item_detail_list['销量']/item_detail_list['点击量']
        # 添加销量/点赞数
        item_detail_list['销量/点赞数'] = item_detail_list['销量']/item_detail_list['点赞数']
        # 产品是否在折扣中
        item_detail_list['促销中？'] = item_detail_list['原价'] != item_detail_list['现价']            
        # 按销量排序
        item_detail_list = item_detail_list.sort_values(by=['销量'], ascending=False)
        
        # export to yifang cloud
        export_folder = 'D://Program Files (x86)//FangCloudV2//寶寶優選//寶寶優選公共资料库//10 【数据】//'
        item_detail_list.to_csv(export_folder + "item_detail_list_ " + str(shopid)+ "_" + today_date.strftime('%Y_%m_%d') + ".csv", sep=',')

logging.info('Finished.')
# Out:
#  2018-05-11 21:45:12,446 - INFO - Retrieving item from tengus.tw.
#  2018-05-11 21:45:12,462 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:14,259 - INFO - Retrieving item from page 1
#  2018-05-11 21:45:14,264 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:14,880 - INFO - Retrieving item from page 2
#  2018-05-11 21:45:14,882 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:15,404 - INFO - Retrieving item from page 3
#  2018-05-11 21:45:15,406 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:15,936 - INFO - Retrieving item from page 4
#  2018-05-11 21:45:15,941 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:16,392 - INFO - Retrieving item from page 5
#  2018-05-11 21:45:16,400 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:16,925 - INFO - Retrieving item from page 6
#  2018-05-11 21:45:16,929 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:17,573 - INFO - Retrieving item from page 7
#  2018-05-11 21:45:17,583 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:18,082 - INFO - Retrieving item from page 8
#  2018-05-11 21:45:18,089 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:18,484 - INFO - Retrieving item from page 9
#  2018-05-11 21:45:18,488 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:19,328 - INFO - Retrieving item from page 10
#  2018-05-11 21:45:19,331 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:20,022 - INFO - Retrieving item from page 11
#  2018-05-11 21:45:20,030 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:20,525 - INFO - Retrieving item from page 12
#  2018-05-11 21:45:20,533 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:21,803 - INFO - Retrieving item from page 13
#  2018-05-11 21:45:21,810 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:22,631 - INFO - Retrieving item from page 14
#  2018-05-11 21:45:22,634 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:23,046 - INFO - Retrieving item from page 15
#  2018-05-11 21:45:23,053 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:23,493 - INFO - Remove duplicate records.
#  2018-05-11 21:45:23,507 - INFO - Retrieved item list.
#  2018-05-11 21:45:23,512 - INFO - Now retrieving itemid: 1147113817 detail.
#  2018-05-11 21:45:23,519 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:24,777 - INFO - Retrieved 1147113817 detail.
#  2018-05-11 21:45:24,777 - INFO - Now retrieving itemid: 968411202 detail.
#  2018-05-11 21:45:24,780 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:25,208 - INFO - Retrieved 968411202 detail.
#  2018-05-11 21:45:25,210 - INFO - Now retrieving itemid: 968423403 detail.
#  2018-05-11 21:45:25,215 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:26,125 - INFO - Retrieved 968423403 detail.
#  2018-05-11 21:45:26,126 - INFO - Now retrieving itemid: 1085020487 detail.
#  2018-05-11 21:45:26,130 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:27,406 - INFO - Retrieved 1085020487 detail.
#  2018-05-11 21:45:27,408 - INFO - Now retrieving itemid: 1085022746 detail.
#  2018-05-11 21:45:27,416 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:28,118 - INFO - Retrieved 1085022746 detail.
#  2018-05-11 21:45:28,119 - INFO - Now retrieving itemid: 1085040297 detail.
#  2018-05-11 21:45:28,126 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:28,862 - INFO - Retrieved 1085040297 detail.
#  2018-05-11 21:45:28,864 - INFO - Now retrieving itemid: 1085044033 detail.
#  2018-05-11 21:45:28,872 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:29,599 - INFO - Retrieved 1085044033 detail.
#  2018-05-11 21:45:29,600 - INFO - Now retrieving itemid: 1068287899 detail.
#  2018-05-11 21:45:29,602 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:30,540 - INFO - Retrieved 1068287899 detail.
#  2018-05-11 21:45:30,541 - INFO - Now retrieving itemid: 1068311149 detail.
#  2018-05-11 21:45:30,546 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:31,609 - INFO - Retrieved 1068311149 detail.
#  2018-05-11 21:45:31,610 - INFO - Now retrieving itemid: 1068331070 detail.
#  2018-05-11 21:45:31,613 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:32,260 - INFO - Retrieved 1068331070 detail.
#  2018-05-11 21:45:32,278 - INFO - Retrieving item from qianjiaozi.my.
#  2018-05-11 21:45:32,283 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:32,789 - INFO - Retrieving item from page 1
#  2018-05-11 21:45:32,791 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:33,512 - INFO - Retrieving item from page 2
#  2018-05-11 21:45:33,517 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:34,284 - INFO - Retrieving item from page 3
#  2018-05-11 21:45:34,289 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:35,008 - INFO - Remove duplicate records.
#  2018-05-11 21:45:35,014 - INFO - Retrieved item list.
#  2018-05-11 21:45:35,019 - INFO - Now retrieving itemid: 1056094904 detail.
#  2018-05-11 21:45:35,026 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:35,667 - INFO - Retrieved 1056094904 detail.
#  2018-05-11 21:45:35,667 - INFO - Now retrieving itemid: 1118467762 detail.
#  2018-05-11 21:45:35,670 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:36,246 - INFO - Retrieved 1118467762 detail.
#  2018-05-11 21:45:36,247 - INFO - Now retrieving itemid: 1116449870 detail.
#  2018-05-11 21:45:36,249 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:37,011 - INFO - Retrieved 1116449870 detail.
#  2018-05-11 21:45:37,012 - INFO - Now retrieving itemid: 1116451306 detail.
#  2018-05-11 21:45:37,015 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:37,469 - INFO - Retrieved 1116451306 detail.
#  2018-05-11 21:45:37,469 - INFO - Now retrieving itemid: 1116459894 detail.
#  2018-05-11 21:45:37,472 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:38,081 - INFO - Retrieved 1116459894 detail.
#  2018-05-11 21:45:38,082 - INFO - Now retrieving itemid: 1118467246 detail.
#  2018-05-11 21:45:38,087 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:38,546 - INFO - Retrieved 1118467246 detail.
#  2018-05-11 21:45:38,548 - INFO - Now retrieving itemid: 1116453976 detail.
#  2018-05-11 21:45:38,552 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:39,066 - INFO - Retrieved 1116453976 detail.
#  2018-05-11 21:45:39,067 - INFO - Now retrieving itemid: 1118466618 detail.
#  2018-05-11 21:45:39,070 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:39,547 - INFO - Retrieved 1118466618 detail.
#  2018-05-11 21:45:39,548 - INFO - Now retrieving itemid: 1116446671 detail.
#  2018-05-11 21:45:39,551 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:39,934 - INFO - Retrieved 1116446671 detail.
#  2018-05-11 21:45:39,936 - INFO - Now retrieving itemid: 1118465958 detail.
#  2018-05-11 21:45:39,941 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:40,423 - INFO - Retrieved 1118465958 detail.
#  2018-05-11 21:45:40,439 - INFO - Retrieving item from tengus.my.
#  2018-05-11 21:45:40,444 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:40,993 - INFO - Retrieving item from page 1
#  2018-05-11 21:45:41,001 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:41,708 - INFO - Retrieving item from page 2
#  2018-05-11 21:45:41,710 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:42,384 - INFO - Remove duplicate records.
#  2018-05-11 21:45:42,387 - INFO - Retrieved item list.
#  2018-05-11 21:45:42,389 - INFO - Now retrieving itemid: 983692889 detail.
#  2018-05-11 21:45:42,392 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:42,868 - INFO - Retrieved 983692889 detail.
#  2018-05-11 21:45:42,869 - INFO - Now retrieving itemid: 995087736 detail.
#  2018-05-11 21:45:42,874 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:43,278 - INFO - Retrieved 995087736 detail.
#  2018-05-11 21:45:43,279 - INFO - Now retrieving itemid: 995089663 detail.
#  2018-05-11 21:45:43,283 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:44,221 - INFO - Retrieved 995089663 detail.
#  2018-05-11 21:45:44,222 - INFO - Now retrieving itemid: 992006477 detail.
#  2018-05-11 21:45:44,226 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:44,940 - INFO - Retrieved 992006477 detail.
#  2018-05-11 21:45:44,941 - INFO - Now retrieving itemid: 991844554 detail.
#  2018-05-11 21:45:44,945 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:45,499 - INFO - Retrieved 991844554 detail.
#  2018-05-11 21:45:45,500 - INFO - Now retrieving itemid: 991944686 detail.
#  2018-05-11 21:45:45,503 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:45,896 - INFO - Retrieved 991944686 detail.
#  2018-05-11 21:45:45,897 - INFO - Now retrieving itemid: 991914417 detail.
#  2018-05-11 21:45:45,900 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:47,230 - INFO - Retrieved 991914417 detail.
#  2018-05-11 21:45:47,231 - INFO - Now retrieving itemid: 995082294 detail.
#  2018-05-11 21:45:47,234 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:47,829 - INFO - Retrieved 995082294 detail.
#  2018-05-11 21:45:47,830 - INFO - Now retrieving itemid: 995090585 detail.
#  2018-05-11 21:45:47,833 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:48,120 - INFO - Retrieved 995090585 detail.
#  2018-05-11 21:45:48,121 - INFO - Now retrieving itemid: 995088460 detail.
#  2018-05-11 21:45:48,124 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:49,593 - INFO - Retrieved 995088460 detail.
#  2018-05-11 21:45:49,600 - INFO - Retrieving item from tengus.id.
#  2018-05-11 21:45:49,603 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:50,021 - INFO - Retrieving item from page 1
#  2018-05-11 21:45:50,024 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:50,504 - INFO - Retrieving item from page 2
#  2018-05-11 21:45:50,511 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:50,846 - INFO - Remove duplicate records.
#  2018-05-11 21:45:50,848 - INFO - Retrieved item list.
#  2018-05-11 21:45:50,850 - INFO - Now retrieving itemid: 1015520813 detail.
#  2018-05-11 21:45:50,852 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:51,251 - INFO - Retrieved 1015520813 detail.
#  2018-05-11 21:45:51,252 - INFO - Now retrieving itemid: 1037780931 detail.
#  2018-05-11 21:45:51,259 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:51,591 - INFO - Retrieved 1037780931 detail.
#  2018-05-11 21:45:51,593 - INFO - Now retrieving itemid: 1037790938 detail.
#  2018-05-11 21:45:51,597 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:52,109 - INFO - Retrieved 1037790938 detail.
#  2018-05-11 21:45:52,110 - INFO - Now retrieving itemid: 1037793922 detail.
#  2018-05-11 21:45:52,112 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:52,517 - INFO - Retrieved 1037793922 detail.
#  2018-05-11 21:45:52,518 - INFO - Now retrieving itemid: 1037803313 detail.
#  2018-05-11 21:45:52,521 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:53,300 - INFO - Retrieved 1037803313 detail.
#  2018-05-11 21:45:53,301 - INFO - Now retrieving itemid: 1041862309 detail.
#  2018-05-11 21:45:53,304 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:53,638 - INFO - Retrieved 1041862309 detail.
#  2018-05-11 21:45:53,639 - INFO - Now retrieving itemid: 1037820208 detail.
#  2018-05-11 21:45:53,642 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:54,076 - INFO - Retrieved 1037820208 detail.
#  2018-05-11 21:45:54,078 - INFO - Now retrieving itemid: 1044643906 detail.
#  2018-05-11 21:45:54,081 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:54,507 - INFO - Retrieved 1044643906 detail.
#  2018-05-11 21:45:54,508 - INFO - Now retrieving itemid: 1044645968 detail.
#  2018-05-11 21:45:54,512 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:55,181 - INFO - Retrieved 1044645968 detail.
#  2018-05-11 21:45:55,183 - INFO - Now retrieving itemid: 1044649133 detail.
#  2018-05-11 21:45:55,186 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:55,545 - INFO - Retrieved 1044649133 detail.
#  2018-05-11 21:45:55,551 - INFO - Retrieving item from qianjiaozi.
#  2018-05-11 21:45:55,554 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:56,271 - INFO - Retrieving item from page 1
#  2018-05-11 21:45:56,274 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:57,215 - INFO - Retrieving item from page 2
#  2018-05-11 21:45:57,218 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:57,758 - INFO - Retrieving item from page 3
#  2018-05-11 21:45:57,765 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:58,286 - INFO - Retrieving item from page 4
#  2018-05-11 21:45:58,290 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:58,707 - INFO - Retrieving item from page 5
#  2018-05-11 21:45:58,709 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:59,033 - INFO - Remove duplicate records.
#  2018-05-11 21:45:59,036 - INFO - Retrieved item list.
#  2018-05-11 21:45:59,038 - INFO - Now retrieving itemid: 1147447353 detail.
#  2018-05-11 21:45:59,040 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:59,485 - INFO - Retrieved 1147447353 detail.
#  2018-05-11 21:45:59,486 - INFO - Now retrieving itemid: 1147422512 detail.
#  2018-05-11 21:45:59,491 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:45:59,937 - INFO - Retrieved 1147422512 detail.
#  2018-05-11 21:45:59,938 - INFO - Now retrieving itemid: 1147403767 detail.
#  2018-05-11 21:45:59,941 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:00,811 - INFO - Retrieved 1147403767 detail.
#  2018-05-11 21:46:00,812 - INFO - Now retrieving itemid: 1087246726 detail.
#  2018-05-11 21:46:00,815 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:01,328 - INFO - Retrieved 1087246726 detail.
#  2018-05-11 21:46:01,329 - INFO - Now retrieving itemid: 1026187025 detail.
#  2018-05-11 21:46:01,332 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:01,806 - INFO - Retrieved 1026187025 detail.
#  2018-05-11 21:46:01,807 - INFO - Now retrieving itemid: 961393827 detail.
#  2018-05-11 21:46:01,809 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:02,238 - INFO - Retrieved 961393827 detail.
#  2018-05-11 21:46:02,240 - INFO - Now retrieving itemid: 1108413996 detail.
#  2018-05-11 21:46:02,246 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:02,807 - INFO - Retrieved 1108413996 detail.
#  2018-05-11 21:46:02,809 - INFO - Now retrieving itemid: 959175740 detail.
#  2018-05-11 21:46:02,815 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:03,438 - INFO - Retrieved 959175740 detail.
#  2018-05-11 21:46:03,439 - INFO - Now retrieving itemid: 1146242936 detail.
#  2018-05-11 21:46:03,442 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:04,017 - INFO - Retrieved 1146242936 detail.
#  2018-05-11 21:46:04,018 - INFO - Now retrieving itemid: 1146183856 detail.
#  2018-05-11 21:46:04,022 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:04,421 - INFO - Retrieved 1146183856 detail.
#  2018-05-11 21:46:04,437 - INFO - Retrieving item from tengus1.id.
#  2018-05-11 21:46:04,442 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:05,216 - INFO - No item in shopid:62417386.
#  2018-05-11 21:46:05,219 - INFO - Retrieving item from tengus2.id.
#  2018-05-11 21:46:05,229 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:05,500 - INFO - No item in shopid:62417551.
#  2018-05-11 21:46:05,501 - INFO - Retrieving item from tengus1.tw.
#  2018-05-11 21:46:05,504 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:06,098 - INFO - Retrieving item from page 1
#  2018-05-11 21:46:06,105 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:06,526 - INFO - Retrieving item from page 2
#  2018-05-11 21:46:06,530 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:06,792 - INFO - Remove duplicate records.
#  2018-05-11 21:46:06,794 - INFO - Retrieved item list.
#  2018-05-11 21:46:06,796 - INFO - Now retrieving itemid: 1143949545 detail.
#  2018-05-11 21:46:06,800 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:07,208 - INFO - Retrieved 1143949545 detail.
#  2018-05-11 21:46:07,210 - INFO - Now retrieving itemid: 1069637876 detail.
#  2018-05-11 21:46:07,217 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:07,635 - INFO - Retrieved 1069637876 detail.
#  2018-05-11 21:46:07,636 - INFO - Now retrieving itemid: 1069650936 detail.
#  2018-05-11 21:46:07,639 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:08,019 - INFO - Retrieved 1069650936 detail.
#  2018-05-11 21:46:08,020 - INFO - Now retrieving itemid: 1092713166 detail.
#  2018-05-11 21:46:08,023 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:08,897 - INFO - Retrieved 1092713166 detail.
#  2018-05-11 21:46:08,898 - INFO - Now retrieving itemid: 1092713240 detail.
#  2018-05-11 21:46:08,901 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:09,429 - INFO - Retrieved 1092713240 detail.
#  2018-05-11 21:46:09,431 - INFO - Now retrieving itemid: 1143949380 detail.
#  2018-05-11 21:46:09,437 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:09,922 - INFO - Retrieved 1143949380 detail.
#  2018-05-11 21:46:09,923 - INFO - Now retrieving itemid: 1122079969 detail.
#  2018-05-11 21:46:09,927 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:10,379 - INFO - Retrieved 1122079969 detail.
#  2018-05-11 21:46:10,380 - INFO - Now retrieving itemid: 1143949697 detail.
#  2018-05-11 21:46:10,384 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:10,793 - INFO - Retrieved 1143949697 detail.
#  2018-05-11 21:46:10,794 - INFO - Now retrieving itemid: 1143949296 detail.
#  2018-05-11 21:46:10,798 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:11,366 - INFO - Retrieved 1143949296 detail.
#  2018-05-11 21:46:11,368 - INFO - Now retrieving itemid: 1143949576 detail.
#  2018-05-11 21:46:11,376 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:11,932 - INFO - Retrieved 1143949576 detail.
#  2018-05-11 21:46:11,939 - INFO - Retrieving item from tengus2.tw.
#  2018-05-11 21:46:11,942 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:12,517 - INFO - Retrieving item from page 1
#  2018-05-11 21:46:12,519 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:13,024 - INFO - Remove duplicate records.
#  2018-05-11 21:46:13,026 - INFO - Retrieved item list.
#  2018-05-11 21:46:13,028 - INFO - Now retrieving itemid: 1140668105 detail.
#  2018-05-11 21:46:13,032 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:13,776 - INFO - Retrieved 1140668105 detail.
#  2018-05-11 21:46:13,777 - INFO - Now retrieving itemid: 1140671243 detail.
#  2018-05-11 21:46:13,782 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:14,267 - INFO - Retrieved 1140671243 detail.
#  2018-05-11 21:46:14,268 - INFO - Now retrieving itemid: 1140674835 detail.
#  2018-05-11 21:46:14,270 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:15,321 - INFO - Retrieved 1140674835 detail.
#  2018-05-11 21:46:15,322 - INFO - Now retrieving itemid: 1140678672 detail.
#  2018-05-11 21:46:15,324 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:16,952 - INFO - Retrieved 1140678672 detail.
#  2018-05-11 21:46:16,953 - INFO - Now retrieving itemid: 1140683453 detail.
#  2018-05-11 21:46:16,956 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:17,470 - INFO - Retrieved 1140683453 detail.
#  2018-05-11 21:46:17,471 - INFO - Now retrieving itemid: 1053684074 detail.
#  2018-05-11 21:46:17,474 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:18,231 - INFO - Retrieved 1053684074 detail.
#  2018-05-11 21:46:18,232 - INFO - Now retrieving itemid: 1061501842 detail.
#  2018-05-11 21:46:18,234 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:18,827 - INFO - Retrieved 1061501842 detail.
#  2018-05-11 21:46:18,829 - INFO - Now retrieving itemid: 1056122895 detail.
#  2018-05-11 21:46:18,835 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:19,619 - INFO - Retrieved 1056122895 detail.
#  2018-05-11 21:46:19,620 - INFO - Now retrieving itemid: 1061507615 detail.
#  2018-05-11 21:46:19,623 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:20,035 - INFO - Retrieved 1061507615 detail.
#  2018-05-11 21:46:20,036 - INFO - Now retrieving itemid: 1056135395 detail.
#  2018-05-11 21:46:20,039 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:20,639 - INFO - Retrieved 1056135395 detail.
#  2018-05-11 21:46:20,644 - INFO - Retrieving item from tengus1.my.
#  2018-05-11 21:46:20,648 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:20,910 - INFO - No item in shopid:62418141.
#  2018-05-11 21:46:20,912 - INFO - Retrieving item from tengus2.my.
#  2018-05-11 21:46:20,916 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:21,394 - INFO - No item in shopid:62418493.
#  2018-05-11 21:46:21,395 - INFO - Retrieving item from qianjiaozitw1.
#  2018-05-11 21:46:21,398 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:21,835 - INFO - Retrieving item from page 1
#  2018-05-11 21:46:21,839 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:22,189 - INFO - Remove duplicate records.
#  2018-05-11 21:46:22,192 - INFO - Retrieved item list.
#  2018-05-11 21:46:22,194 - INFO - Now retrieving itemid: 1141338247 detail.
#  2018-05-11 21:46:22,197 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:23,047 - INFO - Retrieved 1141338247 detail.
#  2018-05-11 21:46:23,049 - INFO - Now retrieving itemid: 1145375082 detail.
#  2018-05-11 21:46:23,054 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:23,872 - INFO - Retrieved 1145375082 detail.
#  2018-05-11 21:46:23,872 - INFO - Now retrieving itemid: 1145373801 detail.
#  2018-05-11 21:46:23,875 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:24,390 - INFO - Retrieved 1145373801 detail.
#  2018-05-11 21:46:24,391 - INFO - Now retrieving itemid: 1145372298 detail.
#  2018-05-11 21:46:24,393 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:25,227 - INFO - Retrieved 1145372298 detail.
#  2018-05-11 21:46:25,228 - INFO - Now retrieving itemid: 1141850879 detail.
#  2018-05-11 21:46:25,231 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:25,730 - INFO - Retrieved 1141850879 detail.
#  2018-05-11 21:46:25,730 - INFO - Now retrieving itemid: 1141847495 detail.
#  2018-05-11 21:46:25,733 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:26,137 - INFO - Retrieved 1141847495 detail.
#  2018-05-11 21:46:26,138 - INFO - Now retrieving itemid: 1141860803 detail.
#  2018-05-11 21:46:26,141 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:26,545 - INFO - Retrieved 1141860803 detail.
#  2018-05-11 21:46:26,546 - INFO - Now retrieving itemid: 1141858098 detail.
#  2018-05-11 21:46:26,549 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:27,115 - INFO - Retrieved 1141858098 detail.
#  2018-05-11 21:46:27,116 - INFO - Now retrieving itemid: 1141854660 detail.
#  2018-05-11 21:46:27,119 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:27,783 - INFO - Retrieved 1141854660 detail.
#  2018-05-11 21:46:27,784 - INFO - Now retrieving itemid: 1141842306 detail.
#  2018-05-11 21:46:27,787 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:28,678 - INFO - Retrieved 1141842306 detail.
#  2018-05-11 21:46:28,683 - INFO - Retrieving item from yilanlu.tw.
#  2018-05-11 21:46:28,687 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:29,206 - INFO - Retrieving item from page 1
#  2018-05-11 21:46:29,210 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:29,724 - INFO - Retrieving item from page 2
#  2018-05-11 21:46:29,731 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:30,173 - INFO - Remove duplicate records.
#  2018-05-11 21:46:30,176 - INFO - Retrieved item list.
#  2018-05-11 21:46:30,177 - INFO - Now retrieving itemid: 1035272491 detail.
#  2018-05-11 21:46:30,180 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:30,834 - INFO - Retrieved 1035272491 detail.
#  2018-05-11 21:46:30,836 - INFO - Now retrieving itemid: 1038216484 detail.
#  2018-05-11 21:46:30,844 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:31,932 - INFO - Retrieved 1038216484 detail.
#  2018-05-11 21:46:31,933 - INFO - Now retrieving itemid: 1038814187 detail.
#  2018-05-11 21:46:31,937 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:33,415 - INFO - Retrieved 1038814187 detail.
#  2018-05-11 21:46:33,416 - INFO - Now retrieving itemid: 1038918198 detail.
#  2018-05-11 21:46:33,420 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:34,278 - INFO - Retrieved 1038918198 detail.
#  2018-05-11 21:46:34,279 - INFO - Now retrieving itemid: 1039120823 detail.
#  2018-05-11 21:46:34,283 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:35,047 - INFO - Retrieved 1039120823 detail.
#  2018-05-11 21:46:35,049 - INFO - Now retrieving itemid: 1039170820 detail.
#  2018-05-11 21:46:35,057 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:35,483 - INFO - Retrieved 1039170820 detail.
#  2018-05-11 21:46:35,485 - INFO - Now retrieving itemid: 1039870995 detail.
#  2018-05-11 21:46:35,488 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:36,744 - INFO - Retrieved 1039870995 detail.
#  2018-05-11 21:46:36,745 - INFO - Now retrieving itemid: 1040067179 detail.
#  2018-05-11 21:46:36,748 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:37,575 - INFO - Retrieved 1040067179 detail.
#  2018-05-11 21:46:37,576 - INFO - Now retrieving itemid: 1040092306 detail.
#  2018-05-11 21:46:37,579 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:38,245 - INFO - Retrieved 1040092306 detail.
#  2018-05-11 21:46:38,246 - INFO - Now retrieving itemid: 1040754644 detail.
#  2018-05-11 21:46:38,249 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:39,011 - INFO - Retrieved 1040754644 detail.
#  2018-05-11 21:46:39,018 - INFO - Retrieving item from qianjiaozi1.
#  2018-05-11 21:46:39,021 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:39,633 - INFO - Retrieving item from page 1
#  2018-05-11 21:46:39,637 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:40,078 - INFO - Remove duplicate records.
#  2018-05-11 21:46:40,081 - INFO - Retrieved item list.
#  2018-05-11 21:46:40,083 - INFO - Now retrieving itemid: 1147723445 detail.
#  2018-05-11 21:46:40,086 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:40,792 - INFO - Retrieved 1147723445 detail.
#  2018-05-11 21:46:40,794 - INFO - Now retrieving itemid: 1147694164 detail.
#  2018-05-11 21:46:40,798 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:41,378 - INFO - Retrieved 1147694164 detail.
#  2018-05-11 21:46:41,380 - INFO - Now retrieving itemid: 1110482718 detail.
#  2018-05-11 21:46:41,387 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:41,848 - INFO - Retrieved 1110482718 detail.
#  2018-05-11 21:46:41,849 - INFO - Now retrieving itemid: 1146540247 detail.
#  2018-05-11 21:46:41,853 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:42,543 - INFO - Retrieved 1146540247 detail.
#  2018-05-11 21:46:42,544 - INFO - Now retrieving itemid: 1146359137 detail.
#  2018-05-11 21:46:42,547 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:43,891 - INFO - Retrieved 1146359137 detail.
#  2018-05-11 21:46:43,892 - INFO - Now retrieving itemid: 1145113042 detail.
#  2018-05-11 21:46:43,897 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:44,592 - INFO - Retrieved 1145113042 detail.
#  2018-05-11 21:46:44,593 - INFO - Now retrieving itemid: 1144682788 detail.
#  2018-05-11 21:46:44,596 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:45,384 - INFO - Retrieved 1144682788 detail.
#  2018-05-11 21:46:45,385 - INFO - Now retrieving itemid: 1140424449 detail.
#  2018-05-11 21:46:45,389 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:46,112 - INFO - Retrieved 1140424449 detail.
#  2018-05-11 21:46:46,114 - INFO - Now retrieving itemid: 1144307675 detail.
#  2018-05-11 21:46:46,117 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:46,620 - INFO - Retrieved 1144307675 detail.
#  2018-05-11 21:46:46,621 - INFO - Now retrieving itemid: 1107271866 detail.
#  2018-05-11 21:46:46,623 - INFO - Starting new HTTPS connection (1): partner.shopeemobile.com
#  2018-05-11 21:46:48,848 - INFO - Retrieved 1107271866 detail.
#  2018-05-11 21:46:48,853 - INFO - Finished.
