# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pandas.io.json import json_normalize

import numpy
import logging

# %%
# Current time stamp
timestamp = int(time.time())

# %%
logging.basicConfig(level=logging.INFO, format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
# logging.info('yes')

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
today_date.strftime('%Y_%m_%d')
# Out:
# '2018_05_11'

# %%
# shop parameter list
# partner_id, shopid, shop_name, shop_key
shop_parameter_list = [\
   [12156, 25482220, 'tengus.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [14689, 53580963, 'qianjiaozi.my', '93815a723e386c9b91379a94f31538853582e02e085e180e0d52c841f7b53e19'],
   [12156, 59848325, 'tengus.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 59846508, 'tengus.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 58707738, 'qianjiaozi', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [12156, 62417386, 'tengus1.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62417551, 'tengus2.id', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416366, 'tengus1.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62416544, 'tengus2.tw', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418141, 'tengus1.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [12156, 62418493, 'tengus2.my', '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'],
   [16363, 63534861, 'qianjiaozitw1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3'],
   [17701, 62887142, 'yilanlu.tw', 'f3e23e0a873b0d74bb8a05b03a77e7a7a03bfebdba622d685b64aa926467d8b9'],
   [16363, 66377809, 'qianjiaozi1', 'ff53513499d845aa1a2fccc7d3731f43a6ce8939d0375a1cc4f31eb1cb916ea3']
  ]

columns = ['partner_id', 'shopid', 'shop_name', 'shop_key']
shop_parameter_df = pd.DataFrame(shop_parameter_list, columns=columns)
# shop_parameter_df

# %%
# get_auth_signature
def get_auth_signature(url, payload, shop_key):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# URL
url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# get all item for each shop & get item_detail for each item
for key, shop in shop_parameter_df.iterrows():
    all_item_list = pd.DataFrame()
    # parameter
    partner_id = shop['partner_id']
    shopid = shop['shopid']
    shop_key = shop['shop_key']
    shop_name = shop['shop_name']
    timestamp = int(time.time())
    
    # get all item
    logging.info('Retrieving item from ' + shop_name + '.')
    max_page = 200
    pagination_entries_per_page = 100
    i = 0

    try:
        while i <= max_page:
            # start entry
            start_entry = i * pagination_entries_per_page

            # Parameter
            pagination_offset = start_entry

            # payload
            payload = {"partner_id":partner_id,
                       "shopid":shopid,
                       "timestamp":timestamp,
                       "pagination_offset":pagination_offset,
                       "pagination_entries_per_page":pagination_entries_per_page}
            # Auth Signature
            Auth_signature = get_auth_signature(url, payload, shop_key)
            # HTML Header
            headers = {"Host": "partner.shopeemobile.com",
                        "Content-Type": "application/json",
                        "Content-Length": "89",
                        "Authorization": Auth_signature}
            # HTML Body
            payload = json.dumps(payload)
            # Post Request
            r = requests.post(url, data=payload, headers=headers)
            # 打印原始Json
            parsed = json.loads(r.text)
            # 漂亮打印Json
            item_list = json_normalize(parsed['items'])
            # 排除update_time
            selected_column = ['item_id', 'shopid', 'status']
            item_list = item_list[selected_column]

            # 合并
            if i == 0:
                all_item_list = item_list
            else:
                all_item_list = all_item_list.append(item_list)
            i += 1
            logging.info('Retrieving item from page ' + str(i))
    except:
        pass

    # 判断item_list是否非空
    if all_item_list.empty:
        logging.info('No item in shopid:' + str(shopid) + '.')
    else:
        # 去重
        logging.info('Remove duplicate records.')
        all_item_list = all_item_list.drop_duplicates('item_id').reset_index()
        logging.info('Retrieved item list.')
        
        # get item detail
        item_detail_url = 'https://partner.shopeemobile.com/api/v1/item/get'
        
        item_detail_list = pd.DataFrame()
        
        for key, item in all_item_list.iterrows():
            try:
                item_id = item['item_id']
                logging.info('Now retrieving itemid: ' + str(item_id) + ' detail.')
                # payload
                payload = {"partner_id":partner_id,
                           "shopid":shopid,
                           "timestamp":timestamp,
                           "item_id": item_id}
                # Auth Signature
                Auth_signature = get_auth_signature(item_detail_url, payload, shop_key)
                # HTML Header
                headers = {"Host": "partner.shopeemobile.com",
                            "Content-Type": "application/json",
                            "Content-Length": "89",
                            "Authorization": Auth_signature}
                # HTML Body
                payload = json.dumps(payload)
                # Post Request
                r = requests.post(item_detail_url, data=payload, headers=headers)
                # 打印原始Json
                parsed = json.loads(r.text)
                # 提取item部分
                item_detail = json_normalize(parsed['item'])
                # 只提取所需columns
                item_detail_columns = ['item_id', 'item_sku', 'likes', 'name', 'original_price', 'price', 'sales', 'shopid', 'status', 'stock', 'views', 'currency']
                item_detail = item_detail[item_detail_columns]
                # 替换column names
                replace_columns_name = {
                    'item_id': '产品ID',
                    'item_sku': '商品SKU',
                    'likes': '点赞数',
                    'name': '产品名',
                    'original_price': '原价',
                    'price': '现价',
                    'sales': '销量',
                    'shopid': '店铺ID',
                    'status': '产品状态',
                    'stock': '库存', 
                    'views': '点击量',
                    'currency': '货币'
                }
                item_detail = item_detail.rename(columns=replace_columns_name)
                # column重新排序
                sort_columns = [
                    '产品ID',
                    '店铺ID',
                    '商品SKU',
                    '产品状态',
                    '产品名',
                    '货币',
                    '原价',
                    '现价',
                    '点赞数',
                    '点击量',
                    '销量',
                    '库存'
                ]
                item_detail = item_detail[sort_columns]
                
                # 添加到总表
                item_detail_list = item_detail_list.append(item_detail)
                # print(item_detail)
                logging.info('Retrieved ' + str(item_id) + ' detail.')
            except:
                logging.info('Retrieve ' + str(item_id) + ' not successfully.')
                pass

        # 添加记录时间
        item_detail_list['记录时间'] = today_date
        # 添加销量/点击量
        item_detail_list['销量/点击量'] = item_detail_list['销量']/item_detail_list['点击量']
        # 添加销量/点赞数
        item_detail_list['销量/点赞数'] = item_detail_list['销量']/item_detail_list['点赞数']
        # 产品是否在折扣中
        item_detail_list['促销中？'] = item_detail_list['原价'] != item_detail_list['现价']            
        # 按销量排序
        item_detail_list = item_detail_list.sort_values(by=['销量'], ascending=False)
        
        item_detail_list.to_csv("D://item_detail_list_ " + str(shopid)+ "_" + today_date.strftime('%Y_%m_%d') + ".csv", sep=',')

logging.info('Finished.')
# Out:
#  2018-05-11 18:36:25,790 - INFO - Retrieving item from tengus.tw.
#  2018-05-11 18:36:26,162 - INFO - Retrieving item from page 1
#  2018-05-11 18:36:26,506 - INFO - Retrieving item from page 2
#  2018-05-11 18:36:27,062 - INFO - Retrieving item from page 3
#  2018-05-11 18:36:27,457 - INFO - Retrieving item from page 4
#  2018-05-11 18:36:27,835 - INFO - Retrieving item from page 5
#  2018-05-11 18:36:28,177 - INFO - Retrieving item from page 6
#  2018-05-11 18:36:28,565 - INFO - Retrieving item from page 7
#  2018-05-11 18:36:28,969 - INFO - Retrieving item from page 8
#  2018-05-11 18:36:29,378 - INFO - Retrieving item from page 9
#  2018-05-11 18:36:29,730 - INFO - Retrieving item from page 10
#  2018-05-11 18:36:30,064 - INFO - Retrieving item from page 11
#  2018-05-11 18:36:30,446 - INFO - Retrieving item from page 12
#  2018-05-11 18:36:31,119 - INFO - Retrieving item from page 13
#  2018-05-11 18:36:31,517 - INFO - Retrieving item from page 14
#  2018-05-11 18:36:31,977 - INFO - Retrieving item from page 15
#  2018-05-11 18:36:32,208 - INFO - Remove duplicate records.
#  2018-05-11 18:36:32,216 - INFO - Retrieved item list.
#  2018-05-11 18:36:32,225 - INFO - Now retrieving 1147113817 detail.
#  2018-05-11 18:36:32,556 - INFO - Retrieved 1147113817 detail.
#  2018-05-11 18:36:32,559 - INFO - Now retrieving 968411202 detail.
#  2018-05-11 18:36:32,881 - INFO - Retrieved 968411202 detail.
#  2018-05-11 18:36:32,884 - INFO - Now retrieving 968423403 detail.
#  2018-05-11 18:36:33,265 - INFO - Retrieved 968423403 detail.
#  2018-05-11 18:36:33,268 - INFO - Now retrieving 1085020487 detail.
#  2018-05-11 18:36:33,585 - INFO - Retrieved 1085020487 detail.
#  2018-05-11 18:36:33,588 - INFO - Now retrieving 1085022746 detail.
#  2018-05-11 18:36:34,019 - INFO - Retrieved 1085022746 detail.
#  2018-05-11 18:36:34,021 - INFO - Now retrieving 1085040297 detail.
#  2018-05-11 18:36:34,354 - INFO - Retrieved 1085040297 detail.
#  2018-05-11 18:36:34,357 - INFO - Now retrieving 1085044033 detail.
#  2018-05-11 18:36:34,960 - INFO - Retrieved 1085044033 detail.
#  2018-05-11 18:36:34,962 - INFO - Now retrieving 1068287899 detail.
#  2018-05-11 18:36:35,315 - INFO - Retrieved 1068287899 detail.
#  2018-05-11 18:36:35,317 - INFO - Now retrieving 1068311149 detail.
#  2018-05-11 18:36:35,965 - INFO - Retrieved 1068311149 detail.
#  2018-05-11 18:36:35,969 - INFO - Now retrieving 1068331070 detail.
#  2018-05-11 18:36:36,475 - INFO - Retrieved 1068331070 detail.
#  2018-05-11 18:36:36,479 - INFO - Now retrieving 1068340130 detail.
#  2018-05-11 18:36:57,490 - INFO - Now retrieving 1068346750 detail.
#  2018-05-11 18:37:18,498 - INFO - Now retrieving 1068355309 detail.
#  2018-05-11 18:37:39,507 - INFO - Now retrieving 1080983423 detail.
#  2018-05-11 18:38:00,514 - INFO - Now retrieving 1080993150 detail.
#  2018-05-11 18:38:21,528 - INFO - Now retrieving 1093172321 detail.
#  2018-05-11 18:38:42,540 - INFO - Now retrieving 1093167595 detail.
#  2018-05-11 18:39:03,554 - INFO - Now retrieving 1093164446 detail.
#  2018-05-11 18:39:24,567 - INFO - Now retrieving 1093134897 detail.
#  2018-05-11 18:39:45,579 - INFO - Now retrieving 1093131710 detail.
#  2018-05-11 18:40:06,593 - INFO - Now retrieving 1093125247 detail.
#  2018-05-11 18:40:27,598 - INFO - Now retrieving 1093121799 detail.
#  2018-05-11 18:40:48,609 - INFO - Now retrieving 1121340020 detail.
#  2018-05-11 18:41:09,617 - INFO - Now retrieving 624716924 detail.
#  2018-05-11 18:41:30,624 - INFO - Now retrieving 624818013 detail.
#  2018-05-11 18:41:51,637 - INFO - Now retrieving 622681936 detail.
#  2018-05-11 18:42:12,649 - INFO - Now retrieving 622681929 detail.
#  2018-05-11 18:42:33,657 - INFO - Now retrieving 670560198 detail.
#  2018-05-11 18:42:54,663 - INFO - Now retrieving 670609247 detail.
#  2018-05-11 18:43:15,673 - INFO - Now retrieving 670598247 detail.
#  2018-05-11 18:43:36,687 - INFO - Now retrieving 950281163 detail.
#  2018-05-11 18:43:57,699 - INFO - Now retrieving 950286855 detail.
#  2018-05-11 18:44:18,711 - INFO - Now retrieving 950343686 detail.
#  2018-05-11 18:44:39,723 - INFO - Now retrieving 622681935 detail.
#  2018-05-11 18:45:00,727 - INFO - Now retrieving 1145323625 detail.
#  2018-05-11 18:45:21,732 - INFO - Now retrieving 622677456 detail.
#  2018-05-11 18:45:42,743 - INFO - Now retrieving 622677454 detail.
#  2018-05-11 18:46:03,752 - INFO - Now retrieving 952696379 detail.
#  2018-05-11 18:46:24,761 - INFO - Now retrieving 952678963 detail.
#  2018-05-11 18:46:45,773 - INFO - Now retrieving 952705367 detail.
#  2018-05-11 18:47:06,786 - INFO - Now retrieving 957896177 detail.
#  2018-05-11 18:47:27,799 - INFO - Now retrieving 1019838360 detail.
#  2018-05-11 18:47:48,811 - INFO - Now retrieving 989856754 detail.
#  2018-05-11 18:48:09,824 - INFO - Now retrieving 1016855188 detail.
#  2018-05-11 18:48:30,839 - INFO - Now retrieving 1093182806 detail.
#  2018-05-11 18:48:51,852 - INFO - Now retrieving 989833394 detail.
#  2018-05-11 18:49:12,865 - INFO - Now retrieving 622677462 detail.
#  2018-05-11 18:49:33,877 - INFO - Now retrieving 1124258999 detail.
#  2018-05-11 18:49:54,889 - INFO - Now retrieving 957903566 detail.
#  2018-05-11 18:50:15,931 - INFO - Now retrieving 730019324 detail.
#  2018-05-11 18:50:36,940 - INFO - Now retrieving 989803765 detail.
#  2018-05-11 18:50:57,950 - INFO - Now retrieving 950316484 detail.
#  2018-05-11 18:51:18,964 - INFO - Now retrieving 622677489 detail.
#  2018-05-11 18:51:39,976 - INFO - Now retrieving 797844363 detail.
#  2018-05-11 18:52:00,990 - INFO - Now retrieving 803300398 detail.
#  2018-05-11 18:52:21,999 - INFO - Now retrieving 803318156 detail.
#  2018-05-11 18:52:43,014 - INFO - Now retrieving 947983025 detail.
#  2018-05-11 18:53:04,026 - INFO - Now retrieving 992458808 detail.
#  2018-05-11 18:53:25,034 - INFO - Now retrieving 1011913098 detail.
#  2018-05-11 18:53:46,046 - INFO - Now retrieving 1011917279 detail.
#  2018-05-11 18:54:07,059 - INFO - Now retrieving 1016847300 detail.
#  2018-05-11 18:54:28,073 - INFO - Now retrieving 1026587307 detail.
#  2018-05-11 18:54:49,082 - INFO - Now retrieving 1053510977 detail.
#  2018-05-11 18:55:10,095 - INFO - Now retrieving 1085036505 detail.
#  2018-05-11 18:55:31,105 - INFO - Now retrieving 1108668657 detail.
#  2018-05-11 18:55:52,114 - INFO - Now retrieving 1116405403 detail.
#  2018-05-11 18:56:13,126 - INFO - Now retrieving 1118423851 detail.
#  2018-05-11 18:56:34,135 - INFO - Now retrieving 1118435536 detail.
#  2018-05-11 18:56:55,144 - INFO - Now retrieving 1124255128 detail.
#  2018-05-11 18:57:16,157 - INFO - Now retrieving 622677476 detail.
#  2018-05-11 18:57:37,169 - INFO - Now retrieving 957936121 detail.
#  2018-05-11 18:57:58,181 - INFO - Now retrieving 999850346 detail.
#  2018-05-11 18:58:19,184 - INFO - Now retrieving 1053502775 detail.
#  2018-05-11 18:58:40,192 - INFO - Now retrieving 1026508395 detail.
#  2018-05-11 18:59:01,202 - INFO - Now retrieving 1093302214 detail.
#  2018-05-11 18:59:22,208 - INFO - Now retrieving 1016861462 detail.
#  2018-05-11 18:59:43,224 - INFO - Now retrieving 803279232 detail.
#  2018-05-11 19:00:04,235 - INFO - Now retrieving 622677491 detail.
#  2018-05-11 19:00:25,246 - INFO - Now retrieving 1068316623 detail.
#  2018-05-11 19:00:46,256 - INFO - Now retrieving 1145331759 detail.
#  2018-05-11 19:01:07,270 - INFO - Now retrieving 1139008374 detail.
#  2018-05-11 19:01:28,283 - INFO - Now retrieving 1139038676 detail.
#  2018-05-11 19:01:49,296 - INFO - Now retrieving 1139017677 detail.
#  2018-05-11 19:02:10,301 - INFO - Now retrieving 1139040974 detail.
#  2018-05-11 19:02:31,309 - INFO - Now retrieving 1121336660 detail.
#  2018-05-11 19:02:52,322 - INFO - Now retrieving 1139071366 detail.
#  2018-05-11 19:03:13,334 - INFO - Now retrieving 1139075035 detail.
#  2018-05-11 19:03:34,347 - INFO - Now retrieving 1138985452 detail.
#  2018-05-11 19:03:55,361 - INFO - Now retrieving 1139046257 detail.
#  2018-05-11 19:04:16,377 - INFO - Now retrieving 1139036226 detail.
#  2018-05-11 19:04:37,389 - INFO - Now retrieving 1138999203 detail.
#  2018-05-11 19:04:58,401 - INFO - Now retrieving 1139033924 detail.
#  2018-05-11 19:05:19,421 - INFO - Now retrieving 1139043883 detail.
#  2018-05-11 19:05:40,430 - INFO - Now retrieving 1139066504 detail.
#  2018-05-11 19:06:01,441 - INFO - Now retrieving 1139023798 detail.
#  2018-05-11 19:06:22,453 - INFO - Now retrieving 1139020485 detail.
#  2018-05-11 19:06:43,468 - INFO - Now retrieving 1139069343 detail.
#  2018-05-11 19:07:04,481 - INFO - Now retrieving 1139012107 detail.
#  2018-05-11 19:07:25,490 - INFO - Now retrieving 1139015298 detail.
#  2018-05-11 19:07:46,505 - INFO - Now retrieving 1139026647 detail.
#  2018-05-11 19:08:07,520 - INFO - Now retrieving 1139064268 detail.
#  2018-05-11 19:08:28,531 - INFO - Now retrieving 1139031894 detail.
#  2018-05-11 19:08:49,543 - INFO - Now retrieving 1139004710 detail.
#  2018-05-11 19:09:10,551 - INFO - Now retrieving 1139029149 detail.
#  2018-05-11 19:09:31,560 - INFO - Now retrieving 1139055398 detail.
#  2018-05-11 19:09:52,567 - INFO - Now retrieving 1139062119 detail.
#  2018-05-11 19:10:13,578 - INFO - Now retrieving 1145315043 detail.
#  2018-05-11 19:10:34,589 - INFO - Now retrieving 1145319177 detail.
#  2018-05-11 19:10:55,602 - INFO - Now retrieving 1145327193 detail.
#  2018-05-11 19:11:16,611 - INFO - Now retrieving 1145226477 detail.
#  2018-05-11 19:11:37,621 - INFO - Now retrieving 1145239094 detail.
#  2018-05-11 19:11:58,635 - INFO - Now retrieving 1145266244 detail.
#  2018-05-11 19:12:19,649 - INFO - Now retrieving 1145193424 detail.
#  2018-05-11 19:12:40,656 - INFO - Now retrieving 1145208876 detail.
#  2018-05-11 19:13:01,668 - INFO - Now retrieving 1145250875 detail.
#  2018-05-11 19:13:22,680 - INFO - Now retrieving 1093188804 detail.
#  2018-05-11 19:13:43,692 - INFO - Now retrieving 952642940 detail.
#  2018-05-11 19:14:04,705 - INFO - Now retrieving 965611068 detail.
#  2018-05-11 19:14:25,717 - INFO - Now retrieving 1053529290 detail.
#  2018-05-11 19:14:46,729 - INFO - Now retrieving 865762957 detail.
#  2018-05-11 19:15:07,740 - INFO - Now retrieving 859866479 detail.
#  2018-05-11 19:15:28,992 - INFO - Now retrieving 1108627351 detail.
#  2018-05-11 19:15:50,000 - INFO - Now retrieving 865740839 detail.
#  2018-05-11 19:16:11,013 - INFO - Now retrieving 999744467 detail.
#  2018-05-11 19:16:32,027 - INFO - Now retrieving 801949922 detail.
#  2018-05-11 19:16:53,033 - INFO - Now retrieving 1124222362 detail.
#  2018-05-11 19:17:14,045 - INFO - Now retrieving 809365858 detail.
#  2018-05-11 19:17:35,055 - INFO - Now retrieving 801997230 detail.
#  2018-05-11 19:17:56,068 - INFO - Now retrieving 1079389143 detail.
#  2018-05-11 19:18:17,082 - INFO - Now retrieving 859966741 detail.
#  2018-05-11 19:18:38,092 - INFO - Now retrieving 884781341 detail.
#  2018-05-11 19:18:59,098 - INFO - Now retrieving 999718243 detail.
#  2018-05-11 19:19:20,112 - INFO - Now retrieving 978233299 detail.
#  2018-05-11 19:19:41,123 - INFO - Now retrieving 884760026 detail.
#  2018-05-11 19:20:02,137 - INFO - Now retrieving 1016877770 detail.
#  2018-05-11 19:20:23,147 - INFO - Now retrieving 624854668 detail.
#  2018-05-11 19:20:44,159 - INFO - Now retrieving 801364435 detail.
#  2018-05-11 19:21:05,167 - INFO - Now retrieving 1124234383 detail.
#  2018-05-11 19:21:26,178 - INFO - Now retrieving 816874130 detail.
#  2018-05-11 19:21:47,191 - INFO - Now retrieving 624818123 detail.
#  2018-05-11 19:22:08,204 - INFO - Now retrieving 1080973828 detail.
#  2018-05-11 19:22:29,215 - INFO - Now retrieving 806194576 detail.
#  2018-05-11 19:22:50,226 - INFO - Now retrieving 812177568 detail.
#  2018-05-11 19:23:11,237 - INFO - Now retrieving 624817941 detail.
#  2018-05-11 19:23:32,250 - INFO - Now retrieving 999800451 detail.
#  2018-05-11 19:23:53,263 - INFO - Now retrieving 1121352360 detail.
#  2018-05-11 19:24:14,275 - INFO - Now retrieving 884766430 detail.
#  2018-05-11 19:24:35,288 - INFO - Now retrieving 832131703 detail.
#  2018-05-11 19:24:56,301 - INFO - Now retrieving 884789663 detail.
#  2018-05-11 19:25:17,313 - INFO - Now retrieving 1121299011 detail.
#  2018-05-11 19:25:38,328 - INFO - Now retrieving 1085029966 detail.
#  2018-05-11 19:25:59,341 - INFO - Now retrieving 801322488 detail.
#  2018-05-11 19:26:20,354 - INFO - Now retrieving 859965188 detail.
#  2018-05-11 19:26:41,367 - INFO - Now retrieving 812177386 detail.
#  2018-05-11 19:27:02,378 - INFO - Now retrieving 1053486869 detail.
#  2018-05-11 19:27:23,390 - INFO - Now retrieving 803709406 detail.
#  2018-05-11 19:27:44,397 - INFO - Now retrieving 884773395 detail.
#  2018-05-11 19:28:05,409 - INFO - Now retrieving 948043563 detail.
#  2018-05-11 19:28:26,420 - INFO - Now retrieving 1013998326 detail.
#  2018-05-11 19:28:47,433 - INFO - Now retrieving 1016870373 detail.
#  2018-05-11 19:29:08,441 - INFO - Now retrieving 1121314786 detail.
#  2018-05-11 19:29:29,450 - INFO - Now retrieving 1138980556 detail.
#  2018-05-11 19:29:50,464 - INFO - Now retrieving 802001066 detail.
#  2018-05-11 19:30:11,480 - INFO - Now retrieving 859967389 detail.
#  2018-05-11 19:30:32,737 - INFO - Now retrieving 965710715 detail.
#  2018-05-11 19:30:53,748 - INFO - Now retrieving 884810343 detail.
#  2018-05-11 19:31:14,761 - INFO - Now retrieving 859979406 detail.
#  2018-05-11 19:31:35,779 - INFO - Now retrieving 1016891421 detail.
#  2018-05-11 19:31:56,788 - INFO - Now retrieving 884802337 detail.
#  2018-05-11 19:32:17,803 - INFO - Now retrieving 806333257 detail.
#  2018-05-11 19:32:38,815 - INFO - Now retrieving 978222429 detail.
#  2018-05-11 19:32:59,826 - INFO - Now retrieving 1127212456 detail.
#  2018-05-11 19:33:20,833 - INFO - Now retrieving 859963960 detail.
#  2018-05-11 19:33:41,839 - INFO - Now retrieving 1016886396 detail.
#  2018-05-11 19:34:02,850 - INFO - Now retrieving 884832766 detail.
#  2018-05-11 19:34:23,856 - INFO - Now retrieving 1108616772 detail.
#  2018-05-11 19:34:44,866 - INFO - Now retrieving 823718317 detail.
#  2018-05-11 19:35:05,878 - INFO - Now retrieving 859990395 detail.
#  2018-05-11 19:35:26,885 - INFO - Now retrieving 965675160 detail.
#  2018-05-11 19:35:47,894 - INFO - Now retrieving 622677368 detail.
#  2018-05-11 19:36:08,905 - INFO - Now retrieving 1104936670 detail.
#  2018-05-11 19:36:29,911 - INFO - Now retrieving 1079406310 detail.
#  2018-05-11 19:36:50,926 - INFO - Now retrieving 1080954768 detail.
#  2018-05-11 19:37:11,938 - INFO - Now retrieving 1010621330 detail.
#  2018-05-11 19:37:32,952 - INFO - Now retrieving 624851659 detail.
#  2018-05-11 19:37:53,965 - INFO - Now retrieving 1086590423 detail.
#  2018-05-11 19:38:14,977 - INFO - Now retrieving 1108661230 detail.
#  2018-05-11 19:38:35,990 - INFO - Now retrieving 1108664710 detail.
#  2018-05-11 19:38:57,003 - INFO - Now retrieving 1080930385 detail.
#  2018-05-11 19:39:18,017 - INFO - Now retrieving 622677393 detail.
#  2018-05-11 19:39:39,029 - INFO - Now retrieving 1080937948 detail.
#  2018-05-11 19:40:00,043 - INFO - Now retrieving 806157565 detail.
#  2018-05-11 19:40:21,054 - INFO - Now retrieving 1055910945 detail.
#  2018-05-11 19:40:42,063 - INFO - Now retrieving 1085054349 detail.
#  2018-05-11 19:41:03,074 - INFO - Now retrieving 837853509 detail.
#  2018-05-11 19:41:24,087 - INFO - Now retrieving 622677398 detail.
#  2018-05-11 19:41:45,100 - INFO - Now retrieving 1019901216 detail.
#  2018-05-11 19:42:06,113 - INFO - Now retrieving 1086695761 detail.
#  2018-05-11 19:42:27,126 - INFO - Now retrieving 1085050383 detail.
#  2018-05-11 19:42:48,139 - INFO - Now retrieving 1108676903 detail.
#  2018-05-11 19:43:09,153 - INFO - Now retrieving 1085057275 detail.
#  2018-05-11 19:43:30,165 - INFO - Now retrieving 1019876950 detail.
#  2018-05-11 19:43:51,177 - INFO - Now retrieving 675661325 detail.
#  2018-05-11 19:44:12,189 - INFO - Now retrieving 1080967999 detail.
#  2018-05-11 19:44:33,202 - INFO - Now retrieving 797827438 detail.
#  2018-05-11 19:44:54,216 - INFO - Now retrieving 1055965129 detail.
#  2018-05-11 19:45:15,230 - INFO - Now retrieving 622677367 detail.
#  2018-05-11 19:45:36,498 - INFO - Now retrieving 802004707 detail.
#  2018-05-11 19:45:57,511 - INFO - Now retrieving 1079393629 detail.
#  2018-05-11 19:46:18,524 - INFO - Now retrieving 1108614403 detail.
#  2018-05-11 19:46:39,537 - INFO - Now retrieving 1068298522 detail.
#  2018-05-11 19:47:00,543 - INFO - Now retrieving 622677399 detail.
#  2018-05-11 19:47:21,551 - INFO - Now retrieving 1055959968 detail.
#  2018-05-11 19:47:42,560 - INFO - Now retrieving 1086701125 detail.
#  2018-05-11 19:48:03,568 - INFO - Now retrieving 1055938062 detail.
#  2018-05-11 19:48:24,574 - INFO - Now retrieving 801989258 detail.
#  2018-05-11 19:48:45,588 - INFO - Now retrieving 946081217 detail.
#  2018-05-11 19:49:06,605 - INFO - Now retrieving 1068322084 detail.
#  2018-05-11 19:49:27,619 - INFO - Now retrieving 1080944204 detail.
#  2018-05-11 19:49:48,625 - INFO - Now retrieving 1079345376 detail.
#  2018-05-11 19:50:09,631 - INFO - Now retrieving 1079397404 detail.
#  2018-05-11 19:50:30,641 - INFO - Now retrieving 1079401364 detail.
#  2018-05-11 19:50:51,660 - INFO - Now retrieving 843580796 detail.
#  2018-05-11 19:51:12,668 - INFO - Now retrieving 1108680053 detail.
#  2018-05-11 19:51:33,679 - INFO - Now retrieving 884859653 detail.
#  2018-05-11 19:51:54,691 - INFO - Now retrieving 1026526350 detail.
#  2018-05-11 19:52:15,698 - INFO - Now retrieving 622667119 detail.
#  2018-05-11 19:52:36,712 - INFO - Now retrieving 837900711 detail.
#  2018-05-11 19:52:57,725 - INFO - Now retrieving 804697286 detail.
#  2018-05-11 19:53:18,735 - INFO - Now retrieving 837828539 detail.
#  2018-05-11 19:53:39,743 - INFO - Now retrieving 859760874 detail.
#  2018-05-11 19:54:00,752 - INFO - Now retrieving 1080962011 detail.
#  2018-05-11 19:54:21,763 - INFO - Now retrieving 968453628 detail.
#  2018-05-11 19:54:42,773 - INFO - Now retrieving 816895933 detail.
#  2018-05-11 19:55:03,785 - INFO - Now retrieving 624854726 detail.
#  2018-05-11 19:55:24,795 - INFO - Now retrieving 1079353015 detail.
#  2018-05-11 19:55:45,807 - INFO - Now retrieving 1010619874 detail.
#  2018-05-11 19:56:06,816 - INFO - Now retrieving 1055931708 detail.
#  2018-05-11 19:56:27,828 - INFO - Now retrieving 768235653 detail.
#  2018-05-11 19:56:48,843 - INFO - Now retrieving 973783328 detail.
#  2018-05-11 19:57:09,853 - INFO - Now retrieving 1053492669 detail.
#  2018-05-11 19:57:30,857 - INFO - Now retrieving 1079380929 detail.
#  2018-05-11 19:57:51,872 - INFO - Now retrieving 1080987514 detail.
#  2018-05-11 19:58:12,880 - INFO - Now retrieving 843331922 detail.
#  2018-05-11 19:58:33,893 - INFO - Now retrieving 1068335755 detail.
#  2018-05-11 19:58:54,904 - INFO - Now retrieving 1053534067 detail.
#  2018-05-11 19:59:15,927 - INFO - Now retrieving 803653126 detail.
#  2018-05-11 19:59:36,939 - INFO - Now retrieving 1108673977 detail.
#  2018-05-11 19:59:57,948 - INFO - Now retrieving 1042833201 detail.
#  2018-05-11 20:00:18,963 - INFO - Now retrieving 1053476164 detail.
#  2018-05-11 20:00:40,979 - INFO - Now retrieving 1053514195 detail.
#  2018-05-11 20:01:01,989 - INFO - Now retrieving 831853772 detail.
#  2018-05-11 20:01:22,994 - INFO - Now retrieving 865742552 detail.
#  2018-05-11 20:01:44,008 - INFO - Now retrieving 859783698 detail.
#  2018-05-11 20:02:05,023 - INFO - Now retrieving 952627885 detail.
#  2018-05-11 20:02:26,034 - INFO - Now retrieving 859872710 detail.
#  2018-05-11 20:02:47,045 - INFO - Now retrieving 1079372192 detail.
#  2018-05-11 20:03:08,055 - INFO - Now retrieving 1042852178 detail.
#  2018-05-11 20:03:29,066 - INFO - Now retrieving 999838620 detail.
#  2018-05-11 20:03:50,073 - INFO - Now retrieving 999859240 detail.
#  2018-05-11 20:04:11,080 - INFO - Now retrieving 1108611762 detail.
#  2018-05-11 20:04:11,233 - INFO - Now retrieving 989762068 detail.
#  2018-05-11 20:04:11,361 - INFO - Now retrieving 978213661 detail.
#  2018-05-11 20:04:11,515 - INFO - Now retrieving 1013991671 detail.
#  2018-05-11 20:04:11,726 - INFO - Now retrieving 973797961 detail.
#  2018-05-11 20:04:11,892 - INFO - Now retrieving 1053524231 detail.
#  2018-05-11 20:04:12,018 - INFO - Now retrieving 1042919052 detail.
#  2018-05-11 20:04:12,230 - INFO - Now retrieving 988777401 detail.
#  2018-05-11 20:04:12,488 - INFO - Now retrieving 1013969618 detail.
#  2018-05-11 20:04:12,626 - INFO - Now retrieving 1026509519 detail.
#  2018-05-11 20:04:13,129 - INFO - Now retrieving 802008734 detail.
#  2018-05-11 20:04:13,486 - INFO - Now retrieving 999842423 detail.
#  2018-05-11 20:04:13,789 - INFO - Now retrieving 815007154 detail.
#  2018-05-11 20:04:14,000 - INFO - Now retrieving 978226125 detail.
#  2018-05-11 20:04:14,175 - INFO - Now retrieving 1026457940 detail.
#  2018-05-11 20:04:14,391 - INFO - Now retrieving 1026514644 detail.
#  2018-05-11 20:04:15,032 - INFO - Now retrieving 863198955 detail.
#  2018-05-11 20:04:15,203 - INFO - Now retrieving 820067665 detail.
#  2018-05-11 20:04:15,387 - INFO - Now retrieving 859810951 detail.
#  2018-05-11 20:04:15,561 - INFO - Now retrieving 859773227 detail.
#  2018-05-11 20:04:15,745 - INFO - Now retrieving 806170086 detail.
#  2018-05-11 20:04:15,954 - INFO - Now retrieving 965734189 detail.
#  2018-05-11 20:04:16,259 - INFO - Now retrieving 955812173 detail.
#  2018-05-11 20:04:16,645 - INFO - Now retrieving 1045052117 detail.
#  2018-05-11 20:04:16,896 - INFO - Now retrieving 955839218 detail.
#  2018-05-11 20:04:17,120 - INFO - Now retrieving 973761509 detail.
#  2018-05-11 20:04:17,330 - INFO - Now retrieving 973787593 detail.
#  2018-05-11 20:04:17,557 - INFO - Now retrieving 1021806184 detail.
#  2018-05-11 20:04:17,722 - INFO - Now retrieving 973793982 detail.
#  2018-05-11 20:04:17,943 - INFO - Now retrieving 1026500159 detail.
#  2018-05-11 20:04:18,134 - INFO - Now retrieving 1021858859 detail.
#  2018-05-11 20:04:18,299 - INFO - Now retrieving 660832220 detail.
#  2018-05-11 20:04:18,453 - INFO - Now retrieving 945970945 detail.
#  2018-05-11 20:04:18,602 - INFO - Now retrieving 948106964 detail.
#  2018-05-11 20:04:18,771 - INFO - Now retrieving 860011065 detail.
#  2018-05-11 20:04:19,310 - INFO - Now retrieving 978228596 detail.
#  2018-05-11 20:04:19,672 - INFO - Now retrieving 859692676 detail.
#  2018-05-11 20:04:19,925 - INFO - Now retrieving 1026518122 detail.
#  2018-05-11 20:04:20,110 - INFO - Now retrieving 1013976014 detail.
#  2018-05-11 20:04:20,389 - INFO - Now retrieving 828010067 detail.
#  2018-05-11 20:04:20,604 - INFO - Now retrieving 859792942 detail.
#  2018-05-11 20:04:20,793 - INFO - Now retrieving 843348822 detail.
#  2018-05-11 20:04:20,961 - INFO - Now retrieving 992451952 detail.
#  2018-05-11 20:04:21,308 - INFO - Now retrieving 992468329 detail.
#  2018-05-11 20:04:21,478 - INFO - Now retrieving 859716502 detail.
#  2018-05-11 20:04:21,668 - INFO - Now retrieving 859814857 detail.
#  2018-05-11 20:04:21,831 - INFO - Now retrieving 952653782 detail.
#  2018-05-11 20:04:22,082 - INFO - Now retrieving 955822237 detail.
#  2018-05-11 20:04:22,250 - INFO - Now retrieving 1026434032 detail.
#  2018-05-11 20:04:22,420 - INFO - Now retrieving 859766425 detail.
#  2018-05-11 20:04:22,600 - INFO - Now retrieving 759477648 detail.
#  2018-05-11 20:04:22,897 - INFO - Now retrieving 843295701 detail.
#  2018-05-11 20:04:23,057 - INFO - Now retrieving 1053517596 detail.
#  2018-05-11 20:04:23,300 - INFO - Now retrieving 1042824576 detail.
#  2018-05-11 20:04:23,429 - INFO - Now retrieving 820099943 detail.
#  2018-05-11 20:04:23,587 - INFO - Now retrieving 999854072 detail.
#  2018-05-11 20:04:23,749 - INFO - Now retrieving 859998436 detail.
#  2018-05-11 20:04:23,993 - INFO - Now retrieving 950329694 detail.
#  2018-05-11 20:04:24,299 - INFO - Now retrieving 828308515 detail.
#  2018-05-11 20:04:24,603 - INFO - Now retrieving 955830397 detail.
#  2018-05-11 20:04:24,901 - INFO - Now retrieving 660844415 detail.
#  2018-05-11 20:04:25,078 - INFO - Now retrieving 955801855 detail.
#  2018-05-11 20:04:25,254 - INFO - Now retrieving 884855494 detail.
#  2018-05-11 20:04:25,394 - INFO - Now retrieving 660855872 detail.
#  2018-05-11 20:04:25,586 - INFO - Now retrieving 999822076 detail.
#  2018-05-11 20:04:25,771 - INFO - Now retrieving 799031923 detail.
#  2018-05-11 20:04:25,981 - INFO - Now retrieving 843378632 detail.
#  2018-05-11 20:04:26,164 - INFO - Now retrieving 837948027 detail.
#  2018-05-11 20:04:26,410 - INFO - Now retrieving 962368412 detail.
#  2018-05-11 20:04:26,619 - INFO - Now retrieving 837864833 detail.
#  2018-05-11 20:04:26,786 - INFO - Now retrieving 779460776 detail.
#  2018-05-11 20:04:26,948 - INFO - Now retrieving 865749062 detail.
#  2018-05-11 20:04:27,160 - INFO - Now retrieving 885744412 detail.
#  2018-05-11 20:04:27,315 - INFO - Now retrieving 809345894 detail.
#  2018-05-11 20:04:27,446 - INFO - Now retrieving 820067996 detail.
#  2018-05-11 20:04:27,673 - INFO - Now retrieving 730001418 detail.
#  2018-05-11 20:04:27,913 - INFO - Now retrieving 730053575 detail.
#  2018-05-11 20:04:28,075 - INFO - Now retrieving 730067824 detail.
#  2018-05-11 20:04:28,251 - INFO - Now retrieving 803602097 detail.
#  2018-05-11 20:04:28,414 - INFO - Now retrieving 709686157 detail.
#  2018-05-11 20:04:28,585 - INFO - Now retrieving 648913990 detail.
#  2018-05-11 20:04:28,817 - INFO - Now retrieving 783418676 detail.
#  2018-05-11 20:04:28,982 - INFO - Now retrieving 1021784696 detail.
#  2018-05-11 20:04:29,151 - INFO - Now retrieving 801983710 detail.
#  2018-05-11 20:04:29,319 - INFO - Now retrieving 806318740 detail.
#  2018-05-11 20:04:29,533 - INFO - Now retrieving 1079362797 detail.
#  2018-05-11 20:04:29,761 - INFO - Now retrieving 1086687276 detail.
#  2018-05-11 20:04:29,920 - INFO - Now retrieving 1085016780 detail.
#  2018-05-11 20:04:30,066 - INFO - Now retrieving 859711189 detail.
#  2018-05-11 20:04:30,482 - INFO - Now retrieving 1108607756 detail.
#  2018-05-11 20:04:30,757 - INFO - Now retrieving 837845065 detail.
#  2018-05-11 20:04:31,024 - INFO - Now retrieving 1021836098 detail.
#  2018-05-11 20:04:31,212 - INFO - Now retrieving 1108623701 detail.
#  2018-05-11 20:04:31,469 - INFO - Now retrieving 781619137 detail.
#  2018-05-11 20:04:31,672 - INFO - Now retrieving 1068362115 detail.
#  2018-05-11 20:04:31,840 - INFO - Now retrieving 1080951790 detail.
#  2018-05-11 20:04:32,028 - INFO - Now retrieving 1086692616 detail.
#  2018-05-11 20:04:32,153 - INFO - Now retrieving 1042913813 detail.
#  2018-05-11 20:04:32,331 - INFO - Now retrieving 1093128195 detail.
#  2018-05-11 20:04:32,495 - INFO - Now retrieving 845106475 detail.
#  2018-05-11 20:04:32,657 - INFO - Now retrieving 845145961 detail.
#  2018-05-11 20:04:32,821 - INFO - Now retrieving 962468601 detail.
#  2018-05-11 20:04:33,008 - INFO - Now retrieving 1056001827 detail.
#  2018-05-11 20:04:33,141 - INFO - Now retrieving 884843041 detail.
#  2018-05-11 20:04:33,296 - INFO - Now retrieving 1056011364 detail.
#  2018-05-11 20:04:33,424 - INFO - Now retrieving 1055952127 detail.
#  2018-05-11 20:04:33,802 - INFO - Now retrieving 968437918 detail.
#  2018-05-11 20:04:33,952 - INFO - Now retrieving 984193814 detail.
#  2018-05-11 20:04:34,117 - INFO - Now retrieving 1042894755 detail.
#  2018-05-11 20:04:34,293 - INFO - Now retrieving 1130257881 detail.
#  2018-05-11 20:04:34,503 - INFO - Now retrieving 842222267 detail.
#  2018-05-11 20:04:34,676 - INFO - Now retrieving 842231331 detail.
#  2018-05-11 20:04:34,889 - INFO - Now retrieving 842236277 detail.
#  2018-05-11 20:04:35,061 - INFO - Now retrieving 842246864 detail.
#  2018-05-11 20:04:35,217 - INFO - Now retrieving 1121344009 detail.
#  2018-05-11 20:04:35,388 - INFO - Now retrieving 1127223219 detail.
#  2018-05-11 20:04:35,615 - INFO - Now retrieving 1127224885 detail.
#  2018-05-11 20:04:35,788 - INFO - Now retrieving 1127216561 detail.
#  2018-05-11 20:04:36,153 - INFO - Now retrieving 1127215610 detail.
#  2018-05-11 20:04:36,360 - INFO - Now retrieving 1124292285 detail.
#  2018-05-11 20:04:36,528 - INFO - Now retrieving 1124284232 detail.
#  2018-05-11 20:04:36,689 - INFO - Now retrieving 1124250631 detail.
#  2018-05-11 20:04:36,868 - INFO - Now retrieving 1124240092 detail.
#  2018-05-11 20:04:37,031 - INFO - Now retrieving 1124229397 detail.
#  2018-05-11 20:04:37,182 - INFO - Now retrieving 1124226508 detail.
#  2018-05-11 20:04:37,334 - INFO - Now retrieving 1121293191 detail.
#  2018-05-11 20:04:37,500 - INFO - Now retrieving 1118432878 detail.
#  2018-05-11 20:04:37,679 - INFO - Now retrieving 1118427748 detail.
#  2018-05-11 20:04:38,029 - INFO - Now retrieving 1118421187 detail.
#  2018-05-11 20:04:38,204 - INFO - Now retrieving 1116382776 detail.
#  2018-05-11 20:04:38,372 - INFO - Now retrieving 1116399387 detail.
#  2018-05-11 20:04:38,513 - INFO - Now retrieving 1116385098 detail.
#  2018-05-11 20:04:38,687 - INFO - Now retrieving 1116395632 detail.
#  2018-05-11 20:04:38,852 - INFO - Now retrieving 1116392653 detail.
#  2018-05-11 20:04:39,005 - INFO - Now retrieving 1116389824 detail.
#  2018-05-11 20:04:39,173 - INFO - Now retrieving 1116379253 detail.
#  2018-05-11 20:04:39,349 - INFO - Now retrieving 1116377668 detail.
#  2018-05-11 20:04:39,487 - INFO - Now retrieving 1116375218 detail.
#  2018-05-11 20:04:39,679 - INFO - Now retrieving 803730848 detail.
#  2018-05-11 20:04:39,855 - INFO - Now retrieving 806207218 detail.
#  2018-05-11 20:04:40,023 - INFO - Now retrieving 806670988 detail.
#  2018-05-11 20:04:40,227 - INFO - Now retrieving 804762990 detail.
#  2018-05-11 20:04:40,418 - INFO - Now retrieving 992457721 detail.
#  2018-05-11 20:04:40,564 - INFO - Now retrieving 843393699 detail.
#  2018-05-11 20:04:40,959 - INFO - Now retrieving 831772186 detail.
#  2018-05-11 20:04:41,181 - INFO - Now retrieving 872053388 detail.
#  2018-05-11 20:04:41,373 - INFO - Now retrieving 871784055 detail.
#  2018-05-11 20:04:41,549 - INFO - Now retrieving 871833501 detail.
#  2018-05-11 20:04:41,694 - INFO - Now retrieving 865977607 detail.
#  2018-05-11 20:04:41,825 - INFO - Now retrieving 865964380 detail.
#  2018-05-11 20:04:41,990 - INFO - Now retrieving 871706340 detail.
#  2018-05-11 20:04:42,245 - INFO - Now retrieving 871703264 detail.
#  2018-05-11 20:04:42,392 - INFO - Now retrieving 865908231 detail.
#  2018-05-11 20:04:42,559 - INFO - Now retrieving 865838868 detail.
#  2018-05-11 20:04:42,837 - INFO - Now retrieving 865761005 detail.
#  2018-05-11 20:04:43,271 - INFO - Now retrieving 871772976 detail.
#  2018-05-11 20:04:43,423 - INFO - Now retrieving 871764415 detail.
#  2018-05-11 20:04:43,558 - INFO - Now retrieving 871761040 detail.
#  2018-05-11 20:04:43,731 - INFO - Now retrieving 871754562 detail.
#  2018-05-11 20:04:43,895 - INFO - Now retrieving 871731448 detail.
#  2018-05-11 20:04:44,071 - INFO - Now retrieving 871727655 detail.
#  2018-05-11 20:04:44,510 - INFO - Now retrieving 871720037 detail.
#  2018-05-11 20:04:44,667 - INFO - Now retrieving 871722643 detail.
#  2018-05-11 20:04:44,835 - INFO - Now retrieving 871718302 detail.
#  2018-05-11 20:04:44,985 - INFO - Now retrieving 871713365 detail.
#  2018-05-11 20:04:45,119 - INFO - Now retrieving 871794395 detail.
#  2018-05-11 20:04:45,267 - INFO - Now retrieving 871776780 detail.
#  2018-05-11 20:04:45,449 - INFO - Now retrieving 871792447 detail.
#  2018-05-11 20:04:45,596 - INFO - Now retrieving 871787688 detail.
#  2018-05-11 20:04:45,792 - INFO - Now retrieving 871781172 detail.
#  2018-05-11 20:04:45,978 - INFO - Now retrieving 871775898 detail.
#  2018-05-11 20:04:46,328 - INFO - Now retrieving 874832434 detail.
#  2018-05-11 20:04:46,482 - INFO - Now retrieving 874743054 detail.
#  2018-05-11 20:04:46,647 - INFO - Now retrieving 871844828 detail.
#  2018-05-11 20:04:46,808 - INFO - Now retrieving 874849843 detail.
#  2018-05-11 20:04:46,965 - INFO - Now retrieving 874721342 detail.
#  2018-05-11 20:04:47,454 - INFO - Now retrieving 874777922 detail.
#  2018-05-11 20:04:47,588 - INFO - Now retrieving 874806063 detail.
#  2018-05-11 20:04:47,724 - INFO - Now retrieving 865769611 detail.
#  2018-05-11 20:04:47,884 - INFO - Now retrieving 871867684 detail.
#  2018-05-11 20:04:48,042 - INFO - Now retrieving 874841044 detail.
#  2018-05-11 20:04:48,446 - INFO - Now retrieving 871991780 detail.
#  2018-05-11 20:04:48,608 - INFO - Now retrieving 871920576 detail.
#  2018-05-11 20:04:48,751 - INFO - Now retrieving 874879886 detail.
#  2018-05-11 20:04:48,878 - INFO - Now retrieving 871891858 detail.
#  2018-05-11 20:04:49,024 - INFO - Now retrieving 874696446 detail.
#  2018-05-11 20:04:49,234 - INFO - Now retrieving 874705878 detail.
#  2018-05-11 20:04:49,374 - INFO - Now retrieving 874735078 detail.
#  2018-05-11 20:04:49,544 - INFO - Now retrieving 874824650 detail.
#  2018-05-11 20:04:49,712 - INFO - Now retrieving 888054914 detail.
#  2018-05-11 20:04:49,940 - INFO - Now retrieving 865837219 detail.
#  2018-05-11 20:04:50,124 - INFO - Now retrieving 865935710 detail.
#  2018-05-11 20:04:50,292 - INFO - Now retrieving 872090436 detail.
#  2018-05-11 20:04:50,484 - INFO - Now retrieving 872120107 detail.
#  2018-05-11 20:04:50,664 - INFO - Now retrieving 942418550 detail.
#  2018-05-11 20:04:50,995 - INFO - Now retrieving 942412856 detail.
#  2018-05-11 20:04:51,155 - INFO - Now retrieving 942404519 detail.
#  2018-05-11 20:04:51,376 - INFO - Now retrieving 942398529 detail.
#  2018-05-11 20:04:51,534 - INFO - Now retrieving 942423934 detail.
#  2018-05-11 20:04:51,692 - INFO - Now retrieving 940099973 detail.
#  2018-05-11 20:04:51,850 - INFO - Now retrieving 940080353 detail.
#  2018-05-11 20:04:52,015 - INFO - Now retrieving 940069750 detail.
#  2018-05-11 20:04:52,169 - INFO - Now retrieving 940055926 detail.
#  2018-05-11 20:04:52,335 - INFO - Now retrieving 914411679 detail.
#  2018-05-11 20:04:52,481 - INFO - Now retrieving 914404999 detail.
#  2018-05-11 20:04:52,643 - INFO - Now retrieving 914397067 detail.
#  2018-05-11 20:04:52,783 - INFO - Now retrieving 914387459 detail.
#  2018-05-11 20:04:52,953 - INFO - Now retrieving 914381030 detail.
#  2018-05-11 20:04:53,118 - INFO - Now retrieving 914373785 detail.
#  2018-05-11 20:04:53,330 - INFO - Now retrieving 914360877 detail.
#  2018-05-11 20:04:53,493 - INFO - Now retrieving 914348392 detail.
#  2018-05-11 20:04:53,648 - INFO - Now retrieving 914341939 detail.
#  2018-05-11 20:04:53,839 - INFO - Now retrieving 912353283 detail.
#  2018-05-11 20:04:54,060 - INFO - Now retrieving 912349173 detail.
#  2018-05-11 20:04:54,220 - INFO - Now retrieving 912338553 detail.
#  2018-05-11 20:04:54,379 - INFO - Now retrieving 912327568 detail.
#  2018-05-11 20:04:54,673 - INFO - Now retrieving 912308265 detail.
#  2018-05-11 20:04:54,833 - INFO - Now retrieving 912302579 detail.
#  2018-05-11 20:04:54,982 - INFO - Now retrieving 912298880 detail.
#  2018-05-11 20:04:55,152 - INFO - Now retrieving 912294356 detail.
#  2018-05-11 20:04:55,317 - INFO - Now retrieving 910471007 detail.
#  2018-05-11 20:04:55,467 - INFO - Now retrieving 910464645 detail.
#  2018-05-11 20:04:55,637 - INFO - Now retrieving 910459578 detail.
#  2018-05-11 20:04:55,799 - INFO - Now retrieving 910453052 detail.
#  2018-05-11 20:04:55,964 - INFO - Now retrieving 910446821 detail.
#  2018-05-11 20:04:56,132 - INFO - Now retrieving 910440922 detail.
#  2018-05-11 20:04:56,319 - INFO - Now retrieving 910431441 detail.
#  2018-05-11 20:04:56,497 - INFO - Now retrieving 910423967 detail.
#  2018-05-11 20:04:56,697 - INFO - Now retrieving 910417878 detail.
#  2018-05-11 20:04:56,870 - INFO - Now retrieving 910410586 detail.
#  2018-05-11 20:04:57,142 - INFO - Now retrieving 907484330 detail.
#  2018-05-11 20:04:57,302 - INFO - Now retrieving 907466965 detail.
#  2018-05-11 20:04:57,487 - INFO - Now retrieving 910491413 detail.
#  2018-05-11 20:04:57,652 - INFO - Now retrieving 907445368 detail.
#  2018-05-11 20:04:57,813 - INFO - Now retrieving 907437214 detail.
#  2018-05-11 20:04:58,008 - INFO - Now retrieving 907424305 detail.
#  2018-05-11 20:04:58,318 - INFO - Now retrieving 907412573 detail.
#  2018-05-11 20:04:58,516 - INFO - Now retrieving 907406761 detail.
#  2018-05-11 20:04:58,663 - INFO - Now retrieving 904678774 detail.
#  2018-05-11 20:04:58,806 - INFO - Now retrieving 904667910 detail.
#  2018-05-11 20:04:58,973 - INFO - Now retrieving 904655215 detail.
#  2018-05-11 20:04:59,123 - INFO - Now retrieving 904646548 detail.
#  2018-05-11 20:04:59,284 - INFO - Now retrieving 904487579 detail.
#  2018-05-11 20:04:59,451 - INFO - Now retrieving 902634236 detail.
#  2018-05-11 20:04:59,618 - INFO - Now retrieving 902626862 detail.
#  2018-05-11 20:04:59,835 - INFO - Now retrieving 902621641 detail.
#  2018-05-11 20:04:59,983 - INFO - Now retrieving 902604882 detail.
#  2018-05-11 20:05:00,154 - INFO - Now retrieving 902567564 detail.
#  2018-05-11 20:05:00,333 - INFO - Now retrieving 902526972 detail.
#  2018-05-11 20:05:00,590 - INFO - Now retrieving 902516220 detail.
#  2018-05-11 20:05:00,846 - INFO - Now retrieving 902510716 detail.
#  2018-05-11 20:05:01,018 - INFO - Now retrieving 902504560 detail.
#  2018-05-11 20:05:01,194 - INFO - Now retrieving 902491039 detail.
#  2018-05-11 20:05:01,746 - INFO - Now retrieving 899154904 detail.
#  2018-05-11 20:05:01,911 - INFO - Now retrieving 899133815 detail.
#  2018-05-11 20:05:02,079 - INFO - Now retrieving 898827592 detail.
#  2018-05-11 20:05:02,239 - INFO - Now retrieving 898805643 detail.
#  2018-05-11 20:05:02,418 - INFO - Now retrieving 898794324 detail.
#  2018-05-11 20:05:02,587 - INFO - Now retrieving 898785470 detail.
#  2018-05-11 20:05:02,768 - INFO - Now retrieving 898773741 detail.
#  2018-05-11 20:05:02,929 - INFO - Now retrieving 898765312 detail.
#  2018-05-11 20:05:03,092 - INFO - Now retrieving 898755884 detail.
#  2018-05-11 20:05:03,250 - INFO - Now retrieving 896156091 detail.
#  2018-05-11 20:05:03,445 - INFO - Now retrieving 896143359 detail.
#  2018-05-11 20:05:03,725 - INFO - Now retrieving 896125092 detail.
#  2018-05-11 20:05:03,923 - INFO - Now retrieving 896116864 detail.
#  2018-05-11 20:05:04,149 - INFO - Now retrieving 896102213 detail.
#  2018-05-11 20:05:04,343 - INFO - Now retrieving 896075119 detail.
#  2018-05-11 20:05:04,509 - INFO - Now retrieving 896030900 detail.
#  2018-05-11 20:05:04,680 - INFO - Now retrieving 896015242 detail.
#  2018-05-11 20:05:04,855 - INFO - Now retrieving 896009392 detail.
#  2018-05-11 20:05:05,020 - INFO - Now retrieving 896003941 detail.
#  2018-05-11 20:05:05,186 - INFO - Now retrieving 894097695 detail.
#  2018-05-11 20:05:05,551 - INFO - Now retrieving 894084510 detail.
#  2018-05-11 20:05:05,700 - INFO - Now retrieving 894072848 detail.
#  2018-05-11 20:05:05,870 - INFO - Now retrieving 894066120 detail.
#  2018-05-11 20:05:06,027 - INFO - Now retrieving 894040819 detail.
#  2018-05-11 20:05:06,204 - INFO - Now retrieving 894027605 detail.
#  2018-05-11 20:05:06,422 - INFO - Now retrieving 894016567 detail.
#  2018-05-11 20:05:06,592 - INFO - Now retrieving 893999014 detail.
#  2018-05-11 20:05:06,755 - INFO - Now retrieving 893989866 detail.
#  2018-05-11 20:05:06,962 - INFO - Now retrieving 893981005 detail.
#  2018-05-11 20:05:07,146 - INFO - Now retrieving 893971569 detail.
#  2018-05-11 20:05:07,320 - INFO - Now retrieving 893965036 detail.
#  2018-05-11 20:05:07,485 - INFO - Now retrieving 893958440 detail.
#  2018-05-11 20:05:07,774 - INFO - Now retrieving 893951530 detail.
#  2018-05-11 20:05:08,024 - INFO - Now retrieving 893936905 detail.
#  2018-05-11 20:05:08,200 - INFO - Now retrieving 893930194 detail.
#  2018-05-11 20:05:08,377 - INFO - Now retrieving 893922122 detail.
#  2018-05-11 20:05:08,526 - INFO - Now retrieving 893913224 detail.
#  2018-05-11 20:05:08,695 - INFO - Now retrieving 893906964 detail.
#  2018-05-11 20:05:08,842 - INFO - Now retrieving 893898986 detail.
#  2018-05-11 20:05:09,033 - INFO - Now retrieving 893892403 detail.
#  2018-05-11 20:05:09,200 - INFO - Now retrieving 893882933 detail.
#  2018-05-11 20:05:09,621 - INFO - Now retrieving 893875090 detail.
#  2018-05-11 20:05:09,782 - INFO - Now retrieving 893865724 detail.
#  2018-05-11 20:05:09,981 - INFO - Now retrieving 893857603 detail.
#  2018-05-11 20:05:10,169 - INFO - Now retrieving 893842022 detail.
#  2018-05-11 20:05:10,365 - INFO - Now retrieving 893834820 detail.
#  2018-05-11 20:05:10,585 - INFO - Now retrieving 893827960 detail.
#  2018-05-11 20:05:10,767 - INFO - Now retrieving 893820295 detail.
#  2018-05-11 20:05:10,911 - INFO - Now retrieving 893797209 detail.
#  2018-05-11 20:05:11,041 - INFO - Now retrieving 893788287 detail.
#  2018-05-11 20:05:11,209 - INFO - Now retrieving 893773079 detail.
#  2018-05-11 20:05:11,360 - INFO - Now retrieving 893766894 detail.
#  2018-05-11 20:05:11,595 - INFO - Now retrieving 893620000 detail.
#  2018-05-11 20:05:11,770 - INFO - Now retrieving 893613574 detail.
#  2018-05-11 20:05:11,921 - INFO - Now retrieving 893606388 detail.
#  2018-05-11 20:05:12,081 - INFO - Now retrieving 892392382 detail.
#  2018-05-11 20:05:12,333 - INFO - Now retrieving 892380680 detail.
#  2018-05-11 20:05:12,561 - INFO - Now retrieving 892357493 detail.
#  2018-05-11 20:05:12,698 - INFO - Now retrieving 892333763 detail.
#  2018-05-11 20:05:12,864 - INFO - Now retrieving 892320455 detail.
#  2018-05-11 20:05:13,029 - INFO - Now retrieving 892309834 detail.
#  2018-05-11 20:05:13,249 - INFO - Now retrieving 892297433 detail.
#  2018-05-11 20:05:13,537 - INFO - Now retrieving 892259074 detail.
#  2018-05-11 20:05:13,673 - INFO - Now retrieving 892249123 detail.
#  2018-05-11 20:05:13,820 - INFO - Now retrieving 892239160 detail.
#  2018-05-11 20:05:13,984 - INFO - Now retrieving 892184184 detail.
#  2018-05-11 20:05:14,144 - INFO - Now retrieving 892170803 detail.
#  2018-05-11 20:05:14,300 - INFO - Now retrieving 891620782 detail.
#  2018-05-11 20:05:14,468 - INFO - Now retrieving 891588413 detail.
#  2018-05-11 20:05:14,627 - INFO - Now retrieving 891577362 detail.
#  2018-05-11 20:05:14,811 - INFO - Now retrieving 891556291 detail.
#  2018-05-11 20:05:14,957 - INFO - Now retrieving 891420483 detail.
#  2018-05-11 20:05:15,136 - INFO - Now retrieving 891224570 detail.
#  2018-05-11 20:05:15,315 - INFO - Now retrieving 891208886 detail.
#  2018-05-11 20:05:15,471 - INFO - Now retrieving 891188284 detail.
#  2018-05-11 20:05:15,638 - INFO - Now retrieving 891174421 detail.
#  2018-05-11 20:05:15,786 - INFO - Now retrieving 888063549 detail.
#  2018-05-11 20:05:15,952 - INFO - Now retrieving 888023030 detail.
#  2018-05-11 20:05:16,177 - INFO - Now retrieving 888010736 detail.
#  2018-05-11 20:05:16,339 - INFO - Now retrieving 888001314 detail.
#  2018-05-11 20:05:16,578 - INFO - Now retrieving 887990512 detail.
#  2018-05-11 20:05:16,730 - INFO - Now retrieving 887970350 detail.
#  2018-05-11 20:05:16,958 - INFO - Now retrieving 887957202 detail.
#  2018-05-11 20:05:17,143 - INFO - Now retrieving 887927693 detail.
#  2018-05-11 20:05:17,310 - INFO - Now retrieving 891093171 detail.
#  2018-05-11 20:05:17,521 - INFO - Now retrieving 891036711 detail.
#  2018-05-11 20:05:17,693 - INFO - Now retrieving 887904201 detail.
#  2018-05-11 20:05:17,854 - INFO - Now retrieving 891055023 detail.
#  2018-05-11 20:05:17,983 - INFO - Now retrieving 892282236 detail.
#  2018-05-11 20:05:18,220 - INFO - Now retrieving 894057886 detail.
#  2018-05-11 20:05:18,341 - INFO - Now retrieving 899178595 detail.
#  2018-05-11 20:05:18,473 - INFO - Now retrieving 899190113 detail.
#  2018-05-11 20:05:18,611 - INFO - Now retrieving 907430252 detail.
#  2018-05-11 20:05:18,751 - INFO - Now retrieving 912331493 detail.
#  2018-05-11 20:05:18,913 - INFO - Now retrieving 912345714 detail.
#  2018-05-11 20:05:19,074 - INFO - Now retrieving 914416597 detail.
#  2018-05-11 20:05:19,241 - INFO - Now retrieving 907458979 detail.
#  2018-05-11 20:05:19,439 - INFO - Now retrieving 940111882 detail.
#  2018-05-11 20:05:19,600 - INFO - Now retrieving 962431435 detail.
#  2018-05-11 20:05:19,793 - INFO - Now retrieving 962412524 detail.
#  2018-05-11 20:05:19,962 - INFO - Now retrieving 957949997 detail.
#  2018-05-11 20:05:20,143 - INFO - Now retrieving 957945785 detail.
#  2018-05-11 20:05:20,309 - INFO - Now retrieving 981355912 detail.
#  2018-05-11 20:05:20,499 - INFO - Now retrieving 981350848 detail.
#  2018-05-11 20:05:20,672 - INFO - Now retrieving 856865210 detail.
#  2018-05-11 20:05:20,795 - INFO - Now retrieving 856198710 detail.
#  2018-05-11 20:05:21,114 - INFO - Now retrieving 863265958 detail.
#  2018-05-11 20:05:21,271 - INFO - Now retrieving 863378117 detail.
#  2018-05-11 20:05:21,445 - INFO - Now retrieving 856112512 detail.
#  2018-05-11 20:05:21,636 - INFO - Now retrieving 856928692 detail.
#  2018-05-11 20:05:21,798 - INFO - Now retrieving 981343966 detail.
#  2018-05-11 20:05:21,963 - INFO - Now retrieving 856187957 detail.
#  2018-05-11 20:05:22,103 - INFO - Now retrieving 981330926 detail.
#  2018-05-11 20:05:22,258 - INFO - Now retrieving 853313966 detail.
#  2018-05-11 20:05:22,442 - INFO - Now retrieving 855932246 detail.
#  2018-05-11 20:05:22,614 - INFO - Now retrieving 842105946 detail.
#  2018-05-11 20:05:22,799 - INFO - Now retrieving 856082519 detail.
#  2018-05-11 20:05:23,091 - INFO - Now retrieving 856166059 detail.
#  2018-05-11 20:05:23,307 - INFO - Now retrieving 856936806 detail.
#  2018-05-11 20:05:23,473 - INFO - Now retrieving 981341998 detail.
#  2018-05-11 20:05:23,824 - INFO - Now retrieving 832098492 detail.
#  2018-05-11 20:05:24,013 - INFO - Now retrieving 852205656 detail.
#  2018-05-11 20:05:24,332 - INFO - Now retrieving 828175197 detail.
#  2018-05-11 20:05:24,502 - INFO - Now retrieving 809476840 detail.
#  2018-05-11 20:05:24,669 - INFO - Now retrieving 657157986 detail.
#  2018-05-11 20:05:24,969 - INFO - Now retrieving 827999999 detail.
#  2018-05-11 20:05:25,139 - INFO - Now retrieving 856059075 detail.
#  2018-05-11 20:05:25,289 - INFO - Now retrieving 856916609 detail.
#  2018-05-11 20:05:25,468 - INFO - Now retrieving 855955761 detail.
#  2018-05-11 20:05:25,645 - INFO - Now retrieving 816907609 detail.
#  2018-05-11 20:05:25,835 - INFO - Now retrieving 816995233 detail.
#  2018-05-11 20:05:25,996 - INFO - Now retrieving 828265975 detail.
#  2018-05-11 20:05:26,140 - INFO - Now retrieving 981345913 detail.
#  2018-05-11 20:05:26,306 - INFO - Now retrieving 816974781 detail.
#  2018-05-11 20:05:26,452 - INFO - Now retrieving 823824601 detail.
#  2018-05-11 20:05:26,631 - INFO - Now retrieving 863422013 detail.
#  2018-05-11 20:05:26,802 - INFO - Now retrieving 856843004 detail.
#  2018-05-11 20:05:26,962 - INFO - Now retrieving 816923155 detail.
#  2018-05-11 20:05:27,131 - INFO - Now retrieving 828148835 detail.
#  2018-05-11 20:05:27,313 - INFO - Now retrieving 853287843 detail.
#  2018-05-11 20:05:27,641 - INFO - Now retrieving 820067936 detail.
#  2018-05-11 20:05:27,945 - INFO - Now retrieving 981329143 detail.
#  2018-05-11 20:05:28,097 - INFO - Now retrieving 981349625 detail.
#  2018-05-11 20:05:28,273 - INFO - Now retrieving 817018209 detail.
#  2018-05-11 20:05:28,428 - INFO - Now retrieving 987494382 detail.
#  2018-05-11 20:05:28,588 - INFO - Now retrieving 981354383 detail.
#  2018-05-11 20:05:28,752 - INFO - Now retrieving 820067885 detail.
#  2018-05-11 20:05:28,943 - INFO - Now retrieving 820067662 detail.
#  2018-05-11 20:05:29,110 - INFO - Now retrieving 820067743 detail.
#  2018-05-11 20:05:29,287 - INFO - Now retrieving 981340568 detail.
#  2018-05-11 20:05:29,465 - INFO - Now retrieving 865747546 detail.
#  2018-05-11 20:05:29,664 - INFO - Now retrieving 856825094 detail.
#  2018-05-11 20:05:29,812 - INFO - Now retrieving 992445094 detail.
#  2018-05-11 20:05:29,982 - INFO - Now retrieving 981325967 detail.
#  2018-05-11 20:05:30,164 - INFO - Now retrieving 856758347 detail.
#  2018-05-11 20:05:30,345 - INFO - Now retrieving 856178967 detail.
#  2018-05-11 20:05:30,512 - INFO - Now retrieving 820067691 detail.
#  2018-05-11 20:05:30,909 - INFO - Now retrieving 657172500 detail.
#  2018-05-11 20:05:31,081 - INFO - Now retrieving 850935489 detail.
#  2018-05-11 20:05:31,249 - INFO - Now retrieving 981333987 detail.
#  2018-05-11 20:05:31,401 - INFO - Now retrieving 1029498327 detail.
#  2018-05-11 20:05:31,570 - INFO - Now retrieving 863173039 detail.
#  2018-05-11 20:05:31,744 - INFO - Now retrieving 865766777 detail.
#  2018-05-11 20:05:31,912 - INFO - Now retrieving 863391563 detail.
#  2018-05-11 20:05:32,083 - INFO - Now retrieving 863289607 detail.
#  2018-05-11 20:05:32,246 - INFO - Now retrieving 863128845 detail.
#  2018-05-11 20:05:32,427 - INFO - Now retrieving 863069582 detail.
#  2018-05-11 20:05:32,579 - INFO - Now retrieving 827955278 detail.
#  2018-05-11 20:05:32,727 - INFO - Now retrieving 843545308 detail.
#  2018-05-11 20:05:32,893 - INFO - Now retrieving 622743692 detail.
#  2018-05-11 20:05:33,045 - INFO - Now retrieving 622743660 detail.
#  2018-05-11 20:05:33,213 - INFO - Now retrieving 622772865 detail.
#  2018-05-11 20:05:33,341 - INFO - Now retrieving 622772864 detail.
#  2018-05-11 20:05:33,576 - INFO - Now retrieving 622772867 detail.
# ...
#  2018-05-11 20:19:02,195 - INFO - Retrieved 1053517957 detail.
#  2018-05-11 20:19:02,197 - INFO - Now retrieving 1053599040 detail.
#  2018-05-11 20:19:02,837 - INFO - Retrieved 1053599040 detail.
#  2018-05-11 20:19:02,839 - INFO - Now retrieving 1054289592 detail.
#  2018-05-11 20:19:04,047 - INFO - Retrieved 1054289592 detail.
#  2018-05-11 20:19:04,051 - INFO - Now retrieving 1051106422 detail.
#  2018-05-11 20:19:04,537 - INFO - Retrieved 1051106422 detail.
#  2018-05-11 20:19:04,539 - INFO - Now retrieving 1045546222 detail.
#  2018-05-11 20:19:04,934 - INFO - Retrieved 1045546222 detail.
#  2018-05-11 20:19:04,938 - INFO - Now retrieving 1052716893 detail.
#  2018-05-11 20:19:05,406 - INFO - Retrieved 1052716893 detail.
#  2018-05-11 20:19:05,408 - INFO - Now retrieving 1067851766 detail.
#  2018-05-11 20:19:06,004 - INFO - Retrieved 1067851766 detail.
#  2018-05-11 20:19:06,005 - INFO - Now retrieving 1073114699 detail.
#  2018-05-11 20:19:06,429 - INFO - Retrieved 1073114699 detail.
#  2018-05-11 20:19:06,432 - INFO - Now retrieving 1054848309 detail.
#  2018-05-11 20:19:06,814 - INFO - Retrieved 1054848309 detail.
#  2018-05-11 20:19:06,816 - INFO - Now retrieving 1055350402 detail.
#  2018-05-11 20:19:07,149 - INFO - Retrieved 1055350402 detail.
#  2018-05-11 20:19:07,151 - INFO - Now retrieving 1037384980 detail.
#  2018-05-11 20:19:08,067 - INFO - Retrieved 1037384980 detail.
#  2018-05-11 20:19:08,071 - INFO - Now retrieving 1073087295 detail.
#  2018-05-11 20:19:08,469 - INFO - Retrieved 1073087295 detail.
#  2018-05-11 20:19:08,471 - INFO - Now retrieving 1092785065 detail.
#  2018-05-11 20:19:08,939 - INFO - Retrieved 1092785065 detail.
#  2018-05-11 20:19:08,942 - INFO - Now retrieving 1036850685 detail.
#  2018-05-11 20:19:09,495 - INFO - Retrieved 1036850685 detail.
#  2018-05-11 20:19:09,497 - INFO - Now retrieving 1067415715 detail.
#  2018-05-11 20:19:09,975 - INFO - Retrieved 1067415715 detail.
#  2018-05-11 20:19:09,978 - INFO - Now retrieving 1104260830 detail.
#  2018-05-11 20:19:10,318 - INFO - Retrieved 1104260830 detail.
#  2018-05-11 20:19:10,319 - INFO - Now retrieving 1101308310 detail.
#  2018-05-11 20:19:10,659 - INFO - Retrieved 1101308310 detail.
#  2018-05-11 20:19:10,661 - INFO - Now retrieving 1074444530 detail.
#  2018-05-11 20:19:11,018 - INFO - Retrieved 1074444530 detail.
#  2018-05-11 20:19:11,022 - INFO - Now retrieving 1059044145 detail.
#  2018-05-11 20:19:11,482 - INFO - Retrieved 1059044145 detail.
#  2018-05-11 20:19:11,486 - INFO - Now retrieving 1057747243 detail.
#  2018-05-11 20:19:12,133 - INFO - Retrieved 1057747243 detail.
#  2018-05-11 20:19:12,137 - INFO - Now retrieving 1098306803 detail.
#  2018-05-11 20:19:12,563 - INFO - Retrieved 1098306803 detail.
#  2018-05-11 20:19:12,567 - INFO - Now retrieving 1059018883 detail.
#  2018-05-11 20:19:12,916 - INFO - Retrieved 1059018883 detail.
#  2018-05-11 20:19:12,919 - INFO - Now retrieving 1067597163 detail.
#  2018-05-11 20:19:13,439 - INFO - Retrieved 1067597163 detail.
#  2018-05-11 20:19:13,442 - INFO - Now retrieving 1081012203 detail.
#  2018-05-11 20:19:13,764 - INFO - Retrieved 1081012203 detail.
#  2018-05-11 20:19:13,767 - INFO - Now retrieving 1073292682 detail.
#  2018-05-11 20:19:14,100 - INFO - Retrieved 1073292682 detail.
#  2018-05-11 20:19:14,104 - INFO - Now retrieving 1077814942 detail.
#  2018-05-11 20:19:14,459 - INFO - Retrieved 1077814942 detail.
#  2018-05-11 20:19:14,461 - INFO - Now retrieving 1087335522 detail.
#  2018-05-11 20:19:15,186 - INFO - Retrieved 1087335522 detail.
#  2018-05-11 20:19:15,189 - INFO - Now retrieving 1055234202 detail.
#  2018-05-11 20:19:15,792 - INFO - Retrieved 1055234202 detail.
#  2018-05-11 20:19:15,795 - INFO - Now retrieving 1058954082 detail.
#  2018-05-11 20:19:16,224 - INFO - Retrieved 1058954082 detail.
#  2018-05-11 20:19:16,227 - INFO - Now retrieving 1075887002 detail.
#  2018-05-11 20:19:16,568 - INFO - Retrieved 1075887002 detail.
#  2018-05-11 20:19:16,570 - INFO - Now retrieving 1086372969 detail.
#  2018-05-11 20:19:17,975 - INFO - Retrieved 1086372969 detail.
#  2018-05-11 20:19:17,977 - INFO - Now retrieving 1080451269 detail.
#  2018-05-11 20:19:19,800 - INFO - Retrieved 1080451269 detail.
#  2018-05-11 20:19:19,802 - INFO - Now retrieving 1063569805 detail.
#  2018-05-11 20:19:20,160 - INFO - Retrieved 1063569805 detail.
#  2018-05-11 20:19:20,162 - INFO - Now retrieving 1075083606 detail.
#  2018-05-11 20:19:20,527 - INFO - Retrieved 1075083606 detail.
#  2018-05-11 20:19:20,530 - INFO - Now retrieving 1055468740 detail.
#  2018-05-11 20:19:20,911 - INFO - Retrieved 1055468740 detail.
#  2018-05-11 20:19:20,914 - INFO - Now retrieving 1089376267 detail.
#  2018-05-11 20:19:21,237 - INFO - Retrieved 1089376267 detail.
#  2018-05-11 20:19:21,240 - INFO - Now retrieving 1038142696 detail.
#  2018-05-11 20:19:21,580 - INFO - Retrieved 1038142696 detail.
#  2018-05-11 20:19:21,584 - INFO - Now retrieving 1073349492 detail.
#  2018-05-11 20:19:22,306 - INFO - Retrieved 1073349492 detail.
#  2018-05-11 20:19:22,309 - INFO - Now retrieving 1075992956 detail.
#  2018-05-11 20:19:22,866 - INFO - Retrieved 1075992956 detail.
#  2018-05-11 20:19:22,868 - INFO - Now retrieving 1054521132 detail.
#  2018-05-11 20:19:23,236 - INFO - Retrieved 1054521132 detail.
#  2018-05-11 20:19:23,239 - INFO - Now retrieving 1073517427 detail.
#  2018-05-11 20:19:23,619 - INFO - Retrieved 1073517427 detail.
#  2018-05-11 20:19:23,621 - INFO - Now retrieving 1067734296 detail.
#  2018-05-11 20:19:24,092 - INFO - Retrieved 1067734296 detail.
#  2018-05-11 20:19:24,095 - INFO - Now retrieving 1104231053 detail.
#  2018-05-11 20:19:25,658 - INFO - Retrieved 1104231053 detail.
#  2018-05-11 20:19:25,660 - INFO - Now retrieving 1074819993 detail.
#  2018-05-11 20:19:26,024 - INFO - Retrieved 1074819993 detail.
#  2018-05-11 20:19:26,026 - INFO - Now retrieving 1055125784 detail.
#  2018-05-11 20:19:26,343 - INFO - Retrieved 1055125784 detail.
#  2018-05-11 20:19:26,346 - INFO - Now retrieving 1073547416 detail.
#  2018-05-11 20:19:26,705 - INFO - Retrieved 1073547416 detail.
#  2018-05-11 20:19:26,707 - INFO - Now retrieving 1077876607 detail.
#  2018-05-11 20:19:27,096 - INFO - Retrieved 1077876607 detail.
#  2018-05-11 20:19:27,097 - INFO - Now retrieving 1054900204 detail.
#  2018-05-11 20:19:27,556 - INFO - Retrieved 1054900204 detail.
#  2018-05-11 20:19:27,559 - INFO - Now retrieving 1076026493 detail.
#  2018-05-11 20:19:27,991 - INFO - Retrieved 1076026493 detail.
#  2018-05-11 20:19:27,992 - INFO - Now retrieving 1077694273 detail.
#  2018-05-11 20:19:28,329 - INFO - Retrieved 1077694273 detail.
#  2018-05-11 20:19:28,331 - INFO - Now retrieving 1098281579 detail.
#  2018-05-11 20:19:28,686 - INFO - Retrieved 1098281579 detail.
#  2018-05-11 20:19:28,687 - INFO - Now retrieving 1037450093 detail.
#  2018-05-11 20:19:28,993 - INFO - Retrieved 1037450093 detail.
#  2018-05-11 20:19:28,995 - INFO - Now retrieving 1075846159 detail.
#  2018-05-11 20:19:29,427 - INFO - Retrieved 1075846159 detail.
#  2018-05-11 20:19:29,428 - INFO - Now retrieving 1054441953 detail.
#  2018-05-11 20:19:29,755 - INFO - Retrieved 1054441953 detail.
#  2018-05-11 20:19:29,758 - INFO - Now retrieving 1038059213 detail.
#  2018-05-11 20:19:30,144 - INFO - Retrieved 1038059213 detail.
#  2018-05-11 20:19:30,148 - INFO - Now retrieving 1062836084 detail.
#  2018-05-11 20:19:30,652 - INFO - Retrieved 1062836084 detail.
#  2018-05-11 20:19:30,656 - INFO - Now retrieving 1060642119 detail.
#  2018-05-11 20:19:31,031 - INFO - Retrieved 1060642119 detail.
#  2018-05-11 20:19:31,033 - INFO - Now retrieving 1060472924 detail.
#  2018-05-11 20:19:31,578 - INFO - Retrieved 1060472924 detail.
#  2018-05-11 20:19:31,579 - INFO - Now retrieving 1061081395 detail.
#  2018-05-11 20:19:32,057 - INFO - Retrieved 1061081395 detail.
#  2018-05-11 20:19:32,059 - INFO - Now retrieving 1073242911 detail.
#  2018-05-11 20:19:32,515 - INFO - Retrieved 1073242911 detail.
#  2018-05-11 20:19:32,518 - INFO - Now retrieving 1078667678 detail.
#  2018-05-11 20:19:32,922 - INFO - Retrieved 1078667678 detail.
#  2018-05-11 20:19:32,926 - INFO - Now retrieving 1080566521 detail.
#  2018-05-11 20:19:33,843 - INFO - Retrieved 1080566521 detail.
#  2018-05-11 20:19:33,846 - INFO - Now retrieving 1075919511 detail.
#  2018-05-11 20:19:35,636 - INFO - Retrieved 1075919511 detail.
#  2018-05-11 20:19:35,640 - INFO - Now retrieving 1058247918 detail.
#  2018-05-11 20:19:36,083 - INFO - Retrieved 1058247918 detail.
#  2018-05-11 20:19:36,086 - INFO - Now retrieving 1061207161 detail.
#  2018-05-11 20:19:36,528 - INFO - Retrieved 1061207161 detail.
#  2018-05-11 20:19:36,529 - INFO - Now retrieving 1057937717 detail.
#  2018-05-11 20:19:36,848 - INFO - Retrieved 1057937717 detail.
#  2018-05-11 20:19:36,850 - INFO - Now retrieving 1074503828 detail.
#  2018-05-11 20:19:37,239 - INFO - Retrieved 1074503828 detail.
#  2018-05-11 20:19:37,242 - INFO - Now retrieving 1058312739 detail.
#  2018-05-11 20:19:37,576 - INFO - Retrieved 1058312739 detail.
#  2018-05-11 20:19:37,579 - INFO - Now retrieving 1104300388 detail.
#  2018-05-11 20:19:38,754 - INFO - Retrieved 1104300388 detail.
#  2018-05-11 20:19:38,757 - INFO - Now retrieving 1075006208 detail.
#  2018-05-11 20:19:39,200 - INFO - Retrieved 1075006208 detail.
#  2018-05-11 20:19:39,202 - INFO - Now retrieving 1058995226 detail.
#  2018-05-11 20:19:39,540 - INFO - Retrieved 1058995226 detail.
#  2018-05-11 20:19:39,542 - INFO - Now retrieving 1037245926 detail.
#  2018-05-11 20:19:39,856 - INFO - Retrieved 1037245926 detail.
#  2018-05-11 20:19:39,864 - INFO - Retrieving item from qianjiaozi1.
#  2018-05-11 20:19:40,192 - INFO - Retrieving item from page 1
#  2018-05-11 20:19:40,367 - INFO - Remove duplicate records.
#  2018-05-11 20:19:40,375 - INFO - Retrieved item list.
#  2018-05-11 20:19:40,380 - INFO - Now retrieving 1147723445 detail.
#  2018-05-11 20:19:40,735 - INFO - Retrieved 1147723445 detail.
#  2018-05-11 20:19:40,738 - INFO - Now retrieving 1147694164 detail.
#  2018-05-11 20:19:41,185 - INFO - Retrieved 1147694164 detail.
#  2018-05-11 20:19:41,189 - INFO - Now retrieving 1110482718 detail.
#  2018-05-11 20:19:41,768 - INFO - Retrieved 1110482718 detail.
#  2018-05-11 20:19:41,772 - INFO - Now retrieving 1146540247 detail.
#  2018-05-11 20:19:42,502 - INFO - Retrieved 1146540247 detail.
#  2018-05-11 20:19:42,505 - INFO - Now retrieving 1146359137 detail.
#  2018-05-11 20:19:43,079 - INFO - Retrieved 1146359137 detail.
#  2018-05-11 20:19:43,082 - INFO - Now retrieving 1145113042 detail.
#  2018-05-11 20:19:43,626 - INFO - Retrieved 1145113042 detail.
#  2018-05-11 20:19:43,627 - INFO - Now retrieving 1144682788 detail.
#  2018-05-11 20:19:43,959 - INFO - Retrieved 1144682788 detail.
#  2018-05-11 20:19:43,962 - INFO - Now retrieving 1140424449 detail.
#  2018-05-11 20:19:44,773 - INFO - Retrieved 1140424449 detail.
#  2018-05-11 20:19:44,777 - INFO - Now retrieving 1144307675 detail.
#  2018-05-11 20:19:45,397 - INFO - Retrieved 1144307675 detail.
#  2018-05-11 20:19:45,399 - INFO - Now retrieving 1107271866 detail.
#  2018-05-11 20:19:45,979 - INFO - Retrieved 1107271866 detail.
#  2018-05-11 20:19:45,982 - INFO - Now retrieving 1118087214 detail.
#  2018-05-11 20:19:46,780 - INFO - Retrieved 1118087214 detail.
#  2018-05-11 20:19:46,782 - INFO - Now retrieving 1118106443 detail.
#  2018-05-11 20:19:47,398 - INFO - Retrieved 1118106443 detail.
#  2018-05-11 20:19:47,401 - INFO - Now retrieving 1110523548 detail.
#  2018-05-11 20:19:47,780 - INFO - Retrieved 1110523548 detail.
#  2018-05-11 20:19:47,782 - INFO - Now retrieving 1140541730 detail.
#  2018-05-11 20:19:48,206 - INFO - Retrieved 1140541730 detail.
#  2018-05-11 20:19:48,209 - INFO - Now retrieving 1140446327 detail.
#  2018-05-11 20:19:48,577 - INFO - Retrieved 1140446327 detail.
#  2018-05-11 20:19:48,579 - INFO - Now retrieving 1110956638 detail.
#  2018-05-11 20:19:48,905 - INFO - Retrieved 1110956638 detail.
#  2018-05-11 20:19:48,907 - INFO - Now retrieving 1110938246 detail.
#  2018-05-11 20:19:49,348 - INFO - Retrieved 1110938246 detail.
#  2018-05-11 20:19:49,349 - INFO - Now retrieving 1110949102 detail.
#  2018-05-11 20:19:49,666 - INFO - Retrieved 1110949102 detail.
#  2018-05-11 20:19:49,667 - INFO - Now retrieving 1115994195 detail.
#  2018-05-11 20:19:49,977 - INFO - Retrieved 1115994195 detail.
#  2018-05-11 20:19:49,979 - INFO - Now retrieving 1095854671 detail.
#  2018-05-11 20:19:51,225 - INFO - Retrieved 1095854671 detail.
#  2018-05-11 20:19:51,228 - INFO - Now retrieving 1104242482 detail.
#  2018-05-11 20:19:51,631 - INFO - Retrieved 1104242482 detail.
#  2018-05-11 20:19:51,633 - INFO - Now retrieving 1108461277 detail.
#  2018-05-11 20:19:51,992 - INFO - Retrieved 1108461277 detail.
#  2018-05-11 20:19:51,994 - INFO - Now retrieving 1108444730 detail.
#  2018-05-11 20:19:52,554 - INFO - Retrieved 1108444730 detail.
#  2018-05-11 20:19:52,557 - INFO - Now retrieving 1131837193 detail.
#  2018-05-11 20:19:52,899 - INFO - Retrieved 1131837193 detail.
#  2018-05-11 20:19:52,902 - INFO - Now retrieving 1129254056 detail.
#  2018-05-11 20:19:54,356 - INFO - Retrieved 1129254056 detail.
#  2018-05-11 20:19:54,358 - INFO - Now retrieving 1131852005 detail.
#  2018-05-11 20:19:54,727 - INFO - Retrieved 1131852005 detail.
#  2018-05-11 20:19:54,730 - INFO - Now retrieving 1131870930 detail.
#  2018-05-11 20:19:55,257 - INFO - Retrieved 1131870930 detail.
#  2018-05-11 20:19:55,259 - INFO - Now retrieving 1095827164 detail.
#  2018-05-11 20:19:55,868 - INFO - Retrieved 1095827164 detail.
#  2018-05-11 20:19:55,871 - INFO - Now retrieving 1104169326 detail.
#  2018-05-11 20:19:57,130 - INFO - Retrieved 1104169326 detail.
#  2018-05-11 20:19:57,132 - INFO - Now retrieving 1104278525 detail.
#  2018-05-11 20:19:57,681 - INFO - Retrieved 1104278525 detail.
#  2018-05-11 20:19:57,682 - INFO - Now retrieving 1096101748 detail.
#  2018-05-11 20:19:58,236 - INFO - Retrieved 1096101748 detail.
#  2018-05-11 20:19:58,239 - INFO - Now retrieving 1128918302 detail.
#  2018-05-11 20:19:58,593 - INFO - Retrieved 1128918302 detail.
#  2018-05-11 20:19:58,596 - INFO - Now retrieving 1129238931 detail.
#  2018-05-11 20:19:58,959 - INFO - Retrieved 1129238931 detail.
#  2018-05-11 20:19:58,960 - INFO - Now retrieving 1128910790 detail.
#  2018-05-11 20:19:59,301 - INFO - Retrieved 1128910790 detail.
#  2018-05-11 20:19:59,305 - INFO - Now retrieving 1128898048 detail.
#  2018-05-11 20:19:59,866 - INFO - Retrieved 1128898048 detail.
#  2018-05-11 20:19:59,869 - INFO - Now retrieving 1129114239 detail.
#  2018-05-11 20:20:00,349 - INFO - Retrieved 1129114239 detail.
#  2018-05-11 20:20:00,353 - INFO - Now retrieving 1128945957 detail.
#  2018-05-11 20:20:00,699 - INFO - Retrieved 1128945957 detail.
#  2018-05-11 20:20:00,701 - INFO - Now retrieving 1095660295 detail.
#  2018-05-11 20:20:01,005 - INFO - Retrieved 1095660295 detail.
#  2018-05-11 20:20:01,009 - INFO - Now retrieving 1113193548 detail.
#  2018-05-11 20:20:01,639 - INFO - Retrieved 1113193548 detail.
#  2018-05-11 20:20:01,642 - INFO - Now retrieving 1122407255 detail.
#  2018-05-11 20:20:01,939 - INFO - Retrieved 1122407255 detail.
#  2018-05-11 20:20:01,940 - INFO - Now retrieving 1122368717 detail.
#  2018-05-11 20:20:02,284 - INFO - Retrieved 1122368717 detail.
#  2018-05-11 20:20:02,286 - INFO - Now retrieving 1115957135 detail.
#  2018-05-11 20:20:02,588 - INFO - Retrieved 1115957135 detail.
#  2018-05-11 20:20:02,590 - INFO - Now retrieving 1115867964 detail.
#  2018-05-11 20:20:02,954 - INFO - Retrieved 1115867964 detail.
#  2018-05-11 20:20:02,958 - INFO - Now retrieving 1115829461 detail.
#  2018-05-11 20:20:03,372 - INFO - Retrieved 1115829461 detail.
#  2018-05-11 20:20:03,375 - INFO - Now retrieving 1108486468 detail.
#  2018-05-11 20:20:03,776 - INFO - Retrieved 1108486468 detail.
#  2018-05-11 20:20:03,779 - INFO - Now retrieving 1108477934 detail.
#  2018-05-11 20:20:04,163 - INFO - Retrieved 1108477934 detail.
#  2018-05-11 20:20:04,166 - INFO - Now retrieving 1108492159 detail.
#  2018-05-11 20:20:04,580 - INFO - Retrieved 1108492159 detail.
#  2018-05-11 20:20:04,584 - INFO - Now retrieving 1095778855 detail.
#  2018-05-11 20:20:04,966 - INFO - Retrieved 1095778855 detail.
#  2018-05-11 20:20:04,986 - INFO - Finished.
