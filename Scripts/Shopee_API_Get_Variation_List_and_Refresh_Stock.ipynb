# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy

# %%
# Current time stamp
timestamp = int(time.time())

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
# Shop Parameter；台湾
partner_id = 12156
shopid = 25482220
shop_key = '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'

# Shop Parameter；马来
partner_id = 14689
shopid = 53580963
shop_key = '93815a723e386c9b91379a94f31538853582e02e085e180e0d52c841f7b53e19'

# %%
# get_auth_signature
def get_auth_signature(url, payload):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# Get Item List URL
get_item_list_url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# Parameter
pagination_offset = 0
pagination_entries_per_page = 100

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "pagination_offset":pagination_offset,
           "pagination_entries_per_page":pagination_entries_per_page}
print(payload)
# Out:
# {'partner_id': 14689, 'shopid': 53580963, 'timestamp': 1520227779, 'pagination_offset': 0, 'pagination_entries_per_page': 100}

# %%
# Auth Signature
Auth_signature = get_auth_signature(get_item_list_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(get_item_list_url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                 items   more
# 0   {'item_id': 959367075, 'shopid': 53580963, 'st...  False
# 1   {'item_id': 959366491, 'shopid': 53580963, 'st...  False
# 2   {'item_id': 953890236, 'shopid': 53580963, 'st...  False
# 3   {'item_id': 955060577, 'shopid': 53580963, 'st...  False
# 4   {'item_id': 957365059, 'shopid': 53580963, 'st...  False
# 5   {'item_id': 957364214, 'shopid': 53580963, 'st...  False
# 6   {'item_id': 957361874, 'shopid': 53580963, 'st...  False
# 7   {'item_id': 957351215, 'shopid': 53580963, 'st...  False
# 8   {'item_id': 953208473, 'shopid': 53580963, 'st...  False
# 9   {'item_id': 947254286, 'shopid': 53580963, 'st...  False
# 10  {'item_id': 947247497, 'shopid': 53580963, 'st...  False
# 11  {'item_id': 944000095, 'shopid': 53580963, 'st...  False
# 12  {'item_id': 943948426, 'shopid': 53580963, 'st...  False
# 13  {'item_id': 943948443, 'shopid': 53580963, 'st...  False
# 14  {'item_id': 943948421, 'shopid': 53580963, 'st...  False
# Parameter
item_id = 698626249
item_id = 943948372

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "item_id":item_id}
print(payload)
# Out:
# {'partner_id': 14689, 'shopid': 53580963, 'timestamp': 1520227779, 'item_id': 943948372}

# %%
# Auth Signature
Auth_signature = get_auth_signature(get_item_detail_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(get_item_detail_url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                              item
# attributes      [{'attribute_id': 9818, 'attribute_name': 'Bra...
# category_id                                                  7040
# create_time                                            1519631838
# currency                                                      MYR
# description     📢Seckill!📢 Baby belly band,  Umbilical cord pr...
# has_variation                                                True
# images          [http://f.shopee.com.my/file/4dd68b8bab9bb4843...
# item_id                                                 943948372
# item_sku                                                    41800
# likes                                                           1
# logistics       [{'logistic_id': 28016, 'logistic_name': 'Stan...
# name            📢Seckill!📢 Baby belly band,  Umbilical cord pr...
# original_price                                                9.9
# price                                                         9.9
# sales                                                           0
# shopid                                                   53580963
# status                                                     NORMAL
# stock                                                          25
# update_time                                            1519631838
# variations      [{'create_time': 1519631838, 'name': 'Yellow-1...
# views                                                           3
# weight                                                       0.08
# wholesales                                                     []

# %%
item_data_frame = json_normalize(parsed['item'])
item_data_frame = item_data_frame[['item_id', 'variations']]
item_data_frame
# Out:
#      item_id                                         variations
# 0  943948372  [{'status': 'MODEL_NORMAL', 'original_price': ...

# %%
item_data_frame_json = item_data_frame.to_json(orient='records')
item_data_frame_json
json.loads(item_data_frame_json)
# Out:
# [{'item_id': 943948372,
#   'variations': [{'create_time': 1519631838,
#     'name': 'Yellow-10*47cm',
#     'original_price': 9.9,
#     'price': 9.9,
#     'status': 'MODEL_NORMAL',
#     'stock': 7,
#     'update_time': 1519631838,
#     'variation_id': 791304096,
#     'variation_sku': '41800-黃色-10*47cm'},
#    {'create_time': 1519631838,
#     'name': 'Blue-10*47cm',
#     'original_price': 9.9,
#     'price': 9.9,
#     'status': 'MODEL_NORMAL',
#     'stock': 8,
#     'update_time': 1519631838,
#     'variation_id': 791304098,
#     'variation_sku': '41800-藍色-10*47cm'},
#    {'create_time': 1519631838,
#     'name': 'Pink-10*47cm',
#     'original_price': 9.9,
#     'price': 9.9,
#     'status': 'MODEL_NORMAL',
#     'stock': 10,
#     'update_time': 1519631838,
#     'variation_id': 791304100,
#     'variation_sku': '41800-粉色-10*47cm'}]}]

# %%
final_item_data_frame = json_normalize(json.loads(item_data_frame_json),record_path='variations',meta=['item_id'])
final_item_data_frame
# Out:
#    create_time            name  original_price  price        status  stock  \
# 0   1519631838  Yellow-10*47cm             9.9    9.9  MODEL_NORMAL      7
# 1   1519631838    Blue-10*47cm             9.9    9.9  MODEL_NORMAL      8
# 2   1519631838    Pink-10*47cm             9.9    9.9  MODEL_NORMAL     10
#
#    update_time  variation_id     variation_sku    item_id
# 0   1519631838     791304096  41800-黃色-10*47cm  943948372
# 1   1519631838     791304098  41800-藍色-10*47cm  943948372
# 2   1519631838     791304100  41800-粉色-10*47cm  943948372

# %%
# update variation stock url
update_variation_stock_url = 'https://partner.shopeemobile.com/api/v1/items/update_variation_stock'

# %%
# Parameter
item_id = 698626249
variation_id = 545993431
stock_to_update = 9

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "item_id":item_id,
           "variation_id":variation_id,
           "stock":stock_to_update}
print(payload)
# Out:
# {'partner_id': 14689, 'shopid': 53580963, 'timestamp': 1520227779, 'item_id': 698626249, 'variation_id': 545993431, 'stock': 9}

# %%
# Auth Signature
Auth_signature = get_auth_signature(update_variation_stock_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
# r = requests.post(update_variation_stock_url, data=payload, headers=headers)
# r.text

# %%
# 正式批量修改variation
# 有限循环，避免更新不完整跳出，更新1000次
i = 1
while True:
    if i % 2==0:
        stock_add = 1
    else:
        stock_add = -1
    
    if i == 1000:
        break
    
    print("Now run the " + str(i) + " time.")

    for item_id in item_list['item_id']:
        # Get Item Detail URL
        get_item_detail_url = 'https://partner.shopeemobile.com/api/v1/item/get'
        # Current time stamp
        timestamp = int(time.time())
        # payload
        payload = {"partner_id":partner_id,
                   "shopid":shopid,
                   "timestamp":timestamp,
                   "item_id":int(item_id)}
        # Auth Signature
        Auth_signature = get_auth_signature(get_item_detail_url, payload)
        # HTML Header
        headers = {"Host": "partner.shopeemobile.com",
                    "Content-Type": "application/json",
                    "Content-Length": "89",
                    "Authorization": Auth_signature}
        # HTML Body
        payload = json.dumps(payload)
        # Post Request
        r = requests.post(get_item_detail_url, data=payload, headers=headers)
        # 打印原始Json
        parsed = json.loads(r.text)
        result = json.dumps(parsed, indent=4, sort_keys=True)
        # Try是否有Varation，如果没有就跳过
        try:
            # 列出variation
            item_data_frame = json_normalize(parsed['item'])
            item_data_frame = item_data_frame[['item_id', 'variations']]
            # variation to json，列出item_id
            item_data_frame_json = item_data_frame.to_json(orient='records')
            # final variation data frame，列出含item_id的variation列表
            final_item_data_frame = json_normalize(json.loads(item_data_frame_json),record_path='variations',meta=['item_id'])

            # update variation stock url
            update_variation_stock_url = 'https://partner.shopeemobile.com/api/v1/items/update_variation_stock'

            # 找出每一个variation id，进行update variation stock
            for variation_id, variation_stock in zip(final_item_data_frame['variation_id'], final_item_data_frame['stock']):
                # Current time stamp
                timestamp = int(time.time())

                # 判断原有stock的大小，如果小于5的话，直接更改为10
                if int(variation_stock) < 5:
                    variation_stock = 10

                # payload
                payload = {"partner_id":partner_id,
                           "shopid":shopid,
                           "timestamp":timestamp,
                           "item_id":int(item_id),
                           "variation_id":int(variation_id),
                           "stock":int(variation_stock) + stock_add}
                # Auth Signature
                Auth_signature = get_auth_signature(update_variation_stock_url, payload)
                # HTML Header
                headers = {"Host": "partner.shopeemobile.com",
                            "Content-Type": "application/json",
                            "Content-Length": "89",
                            "Authorization": Auth_signature}
                # HTML Body
                payload = json.dumps(payload)
                # Post Request
                r = requests.post(update_variation_stock_url, data=payload, headers=headers)
                print(r.text)
                # Notice
                print(str(item_id) + ', ' + str(variation_id) + ' stock updated to ' + str(int(variation_stock) + stock_add))
                time.sleep(30)
        except Exception as err:
            print('An exception occured: ' + str(err))
            
    i = i + 1
# Out:
# Now run the 1 time.
# {"item":{"item_id":959367075,"variation_id":806317064,"modified_time":1520227829}}
# 959367075, 806317064 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317065,"modified_time":1520227859}}
# 959367075, 806317065 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317066,"modified_time":1520227890}}
# 959367075, 806317066 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317067,"modified_time":1520227920}}
# 959367075, 806317067 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317068,"modified_time":1520227950}}
# 959367075, 806317068 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317069,"modified_time":1520227980}}
# 959367075, 806317069 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317070,"modified_time":1520228011}}
# 959367075, 806317070 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317071,"modified_time":1520228041}}
# 959367075, 806317071 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317072,"modified_time":1520228071}}
# 959367075, 806317072 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317073,"modified_time":1520228102}}
# 959367075, 806317073 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317074,"modified_time":1520228132}}
# 959367075, 806317074 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317075,"modified_time":1520228162}}
# 959367075, 806317075 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317076,"modified_time":1520228193}}
# 959367075, 806317076 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317077,"modified_time":1520228223}}
# 959367075, 806317077 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317078,"modified_time":1520228253}}
# 959367075, 806317078 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317079,"modified_time":1520228283}}
# 959367075, 806317079 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317080,"modified_time":1520228314}}
# 959367075, 806317080 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317081,"modified_time":1520228344}}
# 959367075, 806317081 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317082,"modified_time":1520228375}}
# 959367075, 806317082 stock updated to 9
# {"item":{"item_id":959367075,"variation_id":806317083,"modified_time":1520228405}}
# 959367075, 806317083 stock updated to 9
# {"item":{"item_id":959366491,"variation_id":806316562,"modified_time":1520228435}}
# 953195879, 799746657 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748368,"modified_time":1520349546}}
# 953196865, 799748368 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748369,"modified_time":1520349576}}
# 953196865, 799748369 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748370,"modified_time":1520349606}}
# 953196865, 799748370 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748371,"modified_time":1520349637}}
# 953196865, 799748371 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748372,"modified_time":1520349667}}
# 953196865, 799748372 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748373,"modified_time":1520349697}}
# 953196865, 799748373 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748374,"modified_time":1520349727}}
# 953196865, 799748374 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748375,"modified_time":1520349757}}
# 953196865, 799748375 stock updated to 9
# {"item":{"item_id":953196865,"variation_id":799748376,"modified_time":1520349788}}
# 953196865, 799748376 stock updated to 9
# {"item":{"item_id":953207429,"variation_id":799762668,"modified_time":1520349818}}
# 953207429, 799762668 stock updated to 7
# {"item":{"item_id":953207429,"variation_id":799762669,"modified_time":1520349849}}
# 953207429, 799762669 stock updated to 8
# {"item":{"item_id":951204071,"variation_id":797498961,"modified_time":1520349879}}
# 951204071, 797498961 stock updated to 9
# {"item":{"item_id":951204071,"variation_id":797498962,"modified_time":1520349909}}
# 951204071, 797498962 stock updated to 9
# {"item":{"item_id":951201256,"variation_id":797495606,"modified_time":1520349949}}
# 951201256, 797495606 stock updated to 8
# {"item":{"item_id":951200007,"variation_id":797494464,"modified_time":1520349984}}
# 951200007, 797494464 stock updated to 9
# An exception occured: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/items/update_variation_stock (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001DA53398828>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
# An exception occured: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
# {"item":{"item_id":951186172,"variation_id":797475105,"modified_time":1520350109}}
# 951186172, 797475105 stock updated to 9
# {"item":{"item_id":951186172,"variation_id":797475106,"modified_time":1520350139}}
# 951186172, 797475106 stock updated to 9
# An exception occured: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
# {"item":{"item_id":951184971,"variation_id":797473622,"modified_time":1520350230}}
# 951184971, 797473622 stock updated to 8
# {"item":{"item_id":951184971,"variation_id":797473623,"modified_time":1520350264}}
# 951184971, 797473623 stock updated to 8
# {"item":{"item_id":951184971,"variation_id":797473624,"modified_time":1520350295}}
# 951184971, 797473624 stock updated to 8
# {"item":{"item_id":951181542,"variation_id":797467825,"modified_time":1520350326}}
# 951181542, 797467825 stock updated to 10
# {"item":{"item_id":951178835,"variation_id":797462882,"modified_time":1520350360}}
# 951178835, 797462882 stock updated to 9
# {"item":{"item_id":951178835,"variation_id":797462883,"modified_time":1520350393}}
# 951178835, 797462883 stock updated to 9
# An exception occured: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/items/update_variation_stock (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001DA53323F28>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
# {"item":{"item_id":951176374,"variation_id":797458597,"modified_time":1520350446}}
# 951176374, 797458597 stock updated to 9
# {"item":{"item_id":951176374,"variation_id":797458598,"modified_time":1520350476}}
# 951176374, 797458598 stock updated to 9
# {"item":{"item_id":951176374,"variation_id":797458599,"modified_time":1520350507}}
# 951176374, 797458599 stock updated to 9
# {"item":{"item_id":951176374,"variation_id":797458600,"modified_time":1520350537}}
# 951176374, 797458600 stock updated to 9
# {"item":{"item_id":951176374,"variation_id":797458601,"modified_time":1520350568}}
# 951176374, 797458601 stock updated to 9
# {"item":{"item_id":951176374,"variation_id":797458602,"modified_time":1520350599}}
# 951176374, 797458602 stock updated to 9
# An exception occured: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
# {"item":{"item_id":951176402,"variation_id":797458670,"modified_time":1520350710}}
# 951176402, 797458670 stock updated to 8
# {"item":{"item_id":951176402,"variation_id":797458671,"modified_time":1520350742}}
# 951176402, 797458671 stock updated to 9
# {"item":{"item_id":951176402,"variation_id":797458672,"modified_time":1520350781}}
# 951176402, 797458672 stock updated to 8
# {"item":{"item_id":951176369,"variation_id":797458583,"modified_time":1520350821}}
# 951176369, 797458583 stock updated to 9
# {"item":{"item_id":951176369,"variation_id":797458586,"modified_time":1520350852}}
# 951176369, 797458586 stock updated to 9
# An exception occured: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/items/update_variation_stock (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001DA5334AE48>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     146             raise NewConnectionError(
# --> 147                 self, "Failed to establish a new connection: %s" % e)
#     148
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001DA5334A470>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     362         if new_retry.is_exhausted():
# --> 363             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     364
#
# MaxRetryError: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/item/get (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001DA5334A470>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-55-0571a727a86b> in <module>()
#      33         payload = json.dumps(payload)
#      34         # Post Request
# ---> 35         r = requests.post(get_item_detail_url, data=payload, headers=headers)
#      36         # 打印原始Json
#      37         parsed = json.loads(r.text)
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     108     """
#     109
# --> 110     return request('post', url, data=data, json=json, **kwargs)
#     111
#     112
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='partner.shopeemobile.com', port=443): Max retries exceeded with url: /api/v1/item/get (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001DA5334A470>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
