# %%
import requests
import time
import datetime
import pandas as pd

import hashlib
import hmac
import base64

import json

from pprint import pprint 

from pandas.io.json import json_normalize

import numpy

# %%
# Current time stamp
timestamp = int(time.time())

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

# %%
# Shop Parameter
partner_id = 12156
shopid = 25482220
shop_key = '60dbb2b5bcd937be4d6101cf70677908da72f4988c533d0c07b997fd22acd4f2'

# %%
# get_auth_signature
def get_auth_signature(url, payload):
    # API Key
    shopee_secret = shop_key
    # Post Message
    post_message = url + '|' + json.dumps(payload)
    # HMAC-SHA256
    message = bytes(post_message, 'utf-8')
    secret = bytes(shopee_secret, 'utf-8')
    hash = hmac.new(secret, message, hashlib.sha256)
    auth_signature = hash.hexdigest()
    return auth_signature

# %%
# Get Item List URL
get_item_list_url = 'https://partner.shopeemobile.com/api/v1/items/get'

# %%
# Parameter
pagination_offset = 0
pagination_entries_per_page = 100

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "pagination_offset":pagination_offset,
           "pagination_entries_per_page":pagination_entries_per_page}
print(payload)
# Out:
# {'partner_id': 12156, 'shopid': 25482220, 'timestamp': 1516373032, 'pagination_offset': 0, 'pagination_entries_per_page': 100}

# %%
# Auth Signature
Auth_signature = get_auth_signature(get_item_list_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(get_item_list_url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                 items  more
# 0   {'item_id': 799036297, 'shopid': 25482220, 'st...  True
# 1   {'item_id': 793225835, 'shopid': 25482220, 'st...  True
# 2   {'item_id': 712457456, 'shopid': 25482220, 'st...  True
# 3   {'item_id': 845145961, 'shopid': 25482220, 'st...  True
# 4   {'item_id': 845303761, 'shopid': 25482220, 'st...  True
# 5   {'item_id': 845330652, 'shopid': 25482220, 'st...  True
# 6   {'item_id': 845339681, 'shopid': 25482220, 'st...  True
# 7   {'item_id': 845357158, 'shopid': 25482220, 'st...  True
# 8   {'item_id': 845364059, 'shopid': 25482220, 'st...  True
# 9   {'item_id': 845371308, 'shopid': 25482220, 'st...  True
# 10  {'item_id': 812177568, 'shopid': 25482220, 'st...  True
# 11  {'item_id': 848263653, 'shopid': 25482220, 'st...  True
# 12  {'item_id': 848254136, 'shopid': 25482220, 'st...  True
# 13  {'item_id': 848243872, 'shopid': 25482220, 'st...  True
# 14  {'item_id': 848236633, 'shopid': 25482220, 'st...  True
# 15  {'item_id': 848225809, 'shopid': 25482220, 'st...  True
# 16  {'item_id': 848212341, 'shopid': 25482220, 'st...  True
# 17  {'item_id': 848203510, 'shopid': 25482220, 'st...  True
# 18  {'item_id': 848196133, 'shopid': 25482220, 'st...  True
# 19  {'item_id': 848187728, 'shopid': 25482220, 'st...  True
# 20  {'item_id': 848181009, 'shopid': 25482220, 'st...  True
# 21  {'item_id': 848173267, 'shopid': 25482220, 'st...  True
# 22  {'item_id': 848161015, 'shopid': 25482220, 'st...  True
# 23  {'item_id': 848149783, 'shopid': 25482220, 'st...  True
# 24  {'item_id': 848143265, 'shopid': 25482220, 'st...  True
# 25  {'item_id': 848131741, 'shopid': 25482220, 'st...  True
# 26  {'item_id': 848126813, 'shopid': 25482220, 'st...  True
# 27  {'item_id': 848124456, 'shopid': 25482220, 'st...  True
# 28  {'item_id': 848072934, 'shopid': 25482220, 'st...  True
# 29  {'item_id': 848068548, 'shopid': 25482220, 'st...  True
# ..                                                ...   ...
# 70  {'item_id': 843361190, 'shopid': 25482220, 'st...  True
# 71  {'item_id': 843364563, 'shopid': 25482220, 'st...  True
# 72  {'item_id': 843372542, 'shopid': 25482220, 'st...  True
# 73  {'item_id': 843378632, 'shopid': 25482220, 'st...  True
# 74  {'item_id': 843380323, 'shopid': 25482220, 'st...  True
# 75  {'item_id': 843389045, 'shopid': 25482220, 'st...  True
# 76  {'item_id': 843423938, 'shopid': 25482220, 'st...  True
# 77  {'item_id': 843431983, 'shopid': 25482220, 'st...  True
# 78  {'item_id': 843439645, 'shopid': 25482220, 'st...  True
# 79  {'item_id': 843561383, 'shopid': 25482220, 'st...  True
# 80  {'item_id': 843399489, 'shopid': 25482220, 'st...  True
# 81  {'item_id': 843411470, 'shopid': 25482220, 'st...  True
# 82  {'item_id': 843406854, 'shopid': 25482220, 'st...  True
# 83  {'item_id': 843393699, 'shopid': 25482220, 'st...  True
# 84  {'item_id': 843520083, 'shopid': 25482220, 'st...  True
# 85  {'item_id': 843545308, 'shopid': 25482220, 'st...  True
# 86  {'item_id': 843551000, 'shopid': 25482220, 'st...  True
# 87  {'item_id': 843555474, 'shopid': 25482220, 'st...  True
# 88  {'item_id': 843568002, 'shopid': 25482220, 'st...  True
# 89  {'item_id': 843574428, 'shopid': 25482220, 'st...  True
# 90  {'item_id': 843580796, 'shopid': 25482220, 'st...  True
# 91  {'item_id': 812561258, 'shopid': 25482220, 'st...  True
# 92  {'item_id': 843371845, 'shopid': 25482220, 'st...  True
# 93  {'item_id': 843303685, 'shopid': 25482220, 'st...  True
# 94  {'item_id': 843275607, 'shopid': 25482220, 'st...  True
# 95  {'item_id': 843183887, 'shopid': 25482220, 'st...  True
# 96  {'item_id': 842246864, 'shopid': 25482220, 'st...  True
# 97  {'item_id': 842236277, 'shopid': 25482220, 'st...  True
# 98  {'item_id': 842231331, 'shopid': 25482220, 'st...  True
# 99  {'item_id': 842222267, 'shopid': 25482220, 'st...  True
#
# [100 rows x 2 columns]

# %%
# 漂亮打印Json
item_list = json_normalize(parsed['items'])
item_list
# Out:
#       item_id    shopid  status  update_time
# 0   799036297  25482220  NORMAL   1516364551
# Out:
# {'partner_id': 12156, 'shopid': 25482220, 'timestamp': 1516373032, 'item_id': 698626249}

# %%
# Auth Signature
Auth_signature = get_auth_signature(get_item_detail_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
r = requests.post(get_item_detail_url, data=payload, headers=headers)

# %%
# 打印原始Json
parsed = json.loads(r.text)
result = json.dumps(parsed, indent=4, sort_keys=True)
pd.read_json(result)
# Out:
#                                                              item
# attributes      [{'attribute_id': 8319, 'attribute_name': '適用年...
# category_id                                                  8308
# create_time                                            1511159953
# currency                                                      TWD
# description     現貨供應，品質保證\n廣東小富蘭克婦幼用品有限公司是一家集研發、生產和銷售為一體的專業婦嬰企...
# has_variation                                                True
# images          [http://f.shopee.tw/file/5d4fc0f8d5e64f8c91789...
# item_id                                                 698626249
# item_sku                                                3163-3164
# logistics       [{'logistic_id': 38011, 'logistic_name': '圓通-黑...
# name                   嬰幼兒裝長袖 長版上衣  秋冬打底內衣套裝 純棉保暖睡衣  男童女童家居服 1-5歲
# original_price                                                149
# price                                                         149
# shopid                                                   25482220
# status                                                     NORMAL
# stock                                                          90
# update_time                                            1515417892
# variations      [{'create_time': 1511159953, 'name': '藍色73cm-6...
# weight                                                        0.1
# wholesales                                                     []

# %%
item_data_frame = json_normalize(parsed['item'])
item_data_frame = item_data_frame[['item_id', 'variations']]
item_data_frame
# Out:
#      item_id                                         variations
# 0  698626249  [{'status': 'MODEL_NORMAL', 'original_price': ...

# %%
item_data_frame_json = item_data_frame.to_json(orient='records')
item_data_frame_json
json.loads(item_data_frame_json)
# Out:
# [{'item_id': 698626249,
#   'variations': [{'create_time': 1511159953,
#     'name': '藍色73cm-6~12個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993431,
#     'variation_sku': '3163-藍色73cm'},
#    {'create_time': 1511159953,
#     'name': '藍色80cm-12~18個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993432,
#     'variation_sku': '3163-藍色80cm'},
#    {'create_time': 1511159953,
#     'name': '藍色90cm-18~24個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993433,
#     'variation_sku': '3163-藍色90cm'},
#    {'create_time': 1511159953,
#     'name': '藍色100cm-2~3歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993434,
#     'variation_sku': '3164-藍色100cm'},
#    {'create_time': 1511159953,
#     'name': '藍色110cm-3~4歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993435,
#     'variation_sku': '3164-藍色110cm'},
#    {'create_time': 1511159953,
#     'name': '藍色120cm-4~5歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993436,
#     'variation_sku': '3164-藍色120cm'},
#    {'create_time': 1511159953,
#     'name': '黃色73cm-6~12個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993437,
#     'variation_sku': '3163-黃色73cm'},
#    {'create_time': 1511159953,
#     'name': '黃色80cm-12~18個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993438,
#     'variation_sku': '3163-黃色80cm'},
#    {'create_time': 1511159953,
#     'name': '黃色90cm-18~24個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993439,
#     'variation_sku': '3163-黃色90cm'},
#    {'create_time': 1511159953,
#     'name': '黃色100cm-2~3歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993440,
#     'variation_sku': '3164-黃色100cm'},
#    {'create_time': 1511159953,
#     'name': '黃色110cm-3~4歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993441,
#     'variation_sku': '3164-黃色110cm'},
#    {'create_time': 1511159953,
#     'name': '黃色120cm-4~5歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993442,
#     'variation_sku': '3164-黃色120cm'},
#    {'create_time': 1511159953,
#     'name': '紅色73cm-6~12個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993443,
#     'variation_sku': '3163-紅色73cm'},
#    {'create_time': 1511159953,
#     'name': '紅色80cm-12~18個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993444,
#     'variation_sku': '3163-紅色80cm'},
#    {'create_time': 1511159953,
#     'name': '紅色90cm-18~24個月',
#     'original_price': 149.0,
#     'price': 149.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993445,
#     'variation_sku': '3163-紅色90cm'},
#    {'create_time': 1511159953,
#     'name': '紅色100cm-2~3歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993446,
#     'variation_sku': '3164-紅色100cm'},
#    {'create_time': 1511159953,
#     'name': '紅色110cm-3~4歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993447,
#     'variation_sku': '3164-紅色110cm'},
#    {'create_time': 1511159953,
#     'name': '紅色120cm-4~5歲',
#     'original_price': 169.0,
#     'price': 169.0,
#     'status': 'MODEL_NORMAL',
#     'stock': 5,
#     'update_time': 1512994711,
#     'variation_id': 545993448,
#     'variation_sku': '3164-紅色120cm'}]}]

# %%
final_item_data_frame = json_normalize(json.loads(item_data_frame_json),record_path='variations',meta=['item_id'])
final_item_data_frame
# Out:
#     create_time            name  original_price  price        status  stock  \
# 0    1511159953   藍色73cm-6~12個月           149.0  149.0  MODEL_NORMAL      5
# 1    1511159953  藍色80cm-12~18個月           149.0  149.0  MODEL_NORMAL      5
# 2    1511159953  藍色90cm-18~24個月           149.0  149.0  MODEL_NORMAL      5
# 3    1511159953    藍色100cm-2~3歲           169.0  169.0  MODEL_NORMAL      5
# 4    1511159953    藍色110cm-3~4歲           169.0  169.0  MODEL_NORMAL      5
# 5    1511159953    藍色120cm-4~5歲           169.0  169.0  MODEL_NORMAL      5
# 6    1511159953   黃色73cm-6~12個月           149.0  149.0  MODEL_NORMAL      5
# 7    1511159953  黃色80cm-12~18個月           149.0  149.0  MODEL_NORMAL      5
# 8    1511159953  黃色90cm-18~24個月           149.0  149.0  MODEL_NORMAL      5
# 9    1511159953    黃色100cm-2~3歲           169.0  169.0  MODEL_NORMAL      5
# 10   1511159953    黃色110cm-3~4歲           169.0  169.0  MODEL_NORMAL      5
# 11   1511159953    黃色120cm-4~5歲           169.0  169.0  MODEL_NORMAL      5
# 12   1511159953   紅色73cm-6~12個月           149.0  149.0  MODEL_NORMAL      5
# 13   1511159953  紅色80cm-12~18個月           149.0  149.0  MODEL_NORMAL      5
# 14   1511159953  紅色90cm-18~24個月           149.0  149.0  MODEL_NORMAL      5
# 15   1511159953    紅色100cm-2~3歲           169.0  169.0  MODEL_NORMAL      5
# 16   1511159953    紅色110cm-3~4歲           169.0  169.0  MODEL_NORMAL      5
# 17   1511159953    紅色120cm-4~5歲           169.0  169.0  MODEL_NORMAL      5
#
#     update_time  variation_id variation_sku    item_id
# 0    1512994711     545993431   3163-藍色73cm  698626249
# 1    1512994711     545993432   3163-藍色80cm  698626249
# 2    1512994711     545993433   3163-藍色90cm  698626249
# 3    1512994711     545993434  3164-藍色100cm  698626249
# 4    1512994711     545993435  3164-藍色110cm  698626249
# 5    1512994711     545993436  3164-藍色120cm  698626249
# 6    1512994711     545993437   3163-黃色73cm  698626249
# 7    1512994711     545993438   3163-黃色80cm  698626249
# 8    1512994711     545993439   3163-黃色90cm  698626249
# 9    1512994711     545993440  3164-黃色100cm  698626249
# 10   1512994711     545993441  3164-黃色110cm  698626249
# 11   1512994711     545993442  3164-黃色120cm  698626249
# 12   1512994711     545993443   3163-紅色73cm  698626249
# 13   1512994711     545993444   3163-紅色80cm  698626249
# 14   1512994711     545993445   3163-紅色90cm  698626249
# 15   1512994711     545993446  3164-紅色100cm  698626249
# 16   1512994711     545993447  3164-紅色110cm  698626249
# 17   1512994711     545993448  3164-紅色120cm  698626249

# %%
# update variation stock url
update_variation_stock_url = 'https://partner.shopeemobile.com/api/v1/items/update_variation_stock'

# %%
# Parameter
item_id = 698626249
variation_id = 545993431
stock_to_update = 9

# %%
# payload
payload = {"partner_id":partner_id,
           "shopid":shopid,
           "timestamp":timestamp,
           "item_id":item_id,
           "variation_id":variation_id,
           "stock":stock_to_update}
print(payload)
# Out:
# {'partner_id': 12156, 'shopid': 25482220, 'timestamp': 1516373032, 'item_id': 698626249, 'variation_id': 545993431, 'stock': 9}

# %%
# Auth Signature
Auth_signature = get_auth_signature(update_variation_stock_url, payload)

# %%
# HTML Header
headers = {"Host": "partner.shopeemobile.com",
            "Content-Type": "application/json",
            "Content-Length": "89",
            "Authorization": Auth_signature}

# %%
# HTML Body
payload = json.dumps(payload)

# %%
# Post Request
# r = requests.post(update_variation_stock_url, data=payload, headers=headers)
# r.text

# %%
# 正式批量修改variation
# 有限循环，避免更新不完整跳出，更新1000次
i = 1
while True:
    if i % 2==0:
        stock_add = 1
    else:
        stock_add = -1
    
    if i == 1000:
        break
    
    print("Now run the " + str(i) + " time.")

    for item_id in item_list['item_id']:
        # Get Item Detail URL
        get_item_detail_url = 'https://partner.shopeemobile.com/api/v1/item/get'
        # Current time stamp
        timestamp = int(time.time())
        # payload
        payload = {"partner_id":partner_id,
                   "shopid":shopid,
                   "timestamp":timestamp,
                   "item_id":int(item_id)}
        # Auth Signature
        Auth_signature = get_auth_signature(get_item_detail_url, payload)
        # HTML Header
        headers = {"Host": "partner.shopeemobile.com",
                    "Content-Type": "application/json",
                    "Content-Length": "89",
                    "Authorization": Auth_signature}
        # HTML Body
        payload = json.dumps(payload)
        # Post Request
        r = requests.post(get_item_detail_url, data=payload, headers=headers)
        # 打印原始Json
        parsed = json.loads(r.text)
        result = json.dumps(parsed, indent=4, sort_keys=True)
        # Try是否有Varation，如果没有就跳过
        try:
            # 列出variation
            item_data_frame = json_normalize(parsed['item'])
            item_data_frame = item_data_frame[['item_id', 'variations']]
            # variation to json，列出item_id
            item_data_frame_json = item_data_frame.to_json(orient='records')
            # final variation data frame，列出含item_id的variation列表
            final_item_data_frame = json_normalize(json.loads(item_data_frame_json),record_path='variations',meta=['item_id'])

            # update variation stock url
            update_variation_stock_url = 'https://partner.shopeemobile.com/api/v1/items/update_variation_stock'

            # 找出每一个variation id，进行update variation stock
            for variation_id, variation_stock in zip(final_item_data_frame['variation_id'], final_item_data_frame['stock']):
                # Current time stamp
                timestamp = int(time.time())

                # 判断原有stock的大小，如果小于5的话，直接更改为10
                if int(variation_stock) < 5:
                    variation_stock = 10

                # payload
                payload = {"partner_id":partner_id,
                           "shopid":shopid,
                           "timestamp":timestamp,
                           "item_id":int(item_id),
                           "variation_id":int(variation_id),
                           "stock":int(variation_stock) + stock_add}
                # Auth Signature
                Auth_signature = get_auth_signature(update_variation_stock_url, payload)
                # HTML Header
                headers = {"Host": "partner.shopeemobile.com",
                            "Content-Type": "application/json",
                            "Content-Length": "89",
                            "Authorization": Auth_signature}
                # HTML Body
                payload = json.dumps(payload)
                # Post Request
                r = requests.post(update_variation_stock_url, data=payload, headers=headers)
                print(r.text)
                # Notice
                print(str(item_id) + ', ' + str(variation_id) + ' stock updated to ' + str(int(variation_stock) + stock_add))
                time.sleep(30)
        except Exception as err:
            print('An exception occured: ' + str(err))
            
    i = i + 1
# Out:
# Now run the 1 time.
# {"item":{"item_id":799036297,"variation_id":681157037,"modified_time":1516373034}}
# 799036297, 681157037 stock updated to 9
# {"item":{"item_id":799036297,"variation_id":681157038,"modified_time":1516373065}}
# 799036297, 681157038 stock updated to 9
# {"item":{"item_id":799036297,"variation_id":681157039,"modified_time":1516373095}}
# 799036297, 681157039 stock updated to 9
# {"item":{"item_id":799036297,"variation_id":681157040,"modified_time":1516373125}}
# 799036297, 681157040 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550057,"modified_time":1516373155}}
# 793225835, 673550057 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550058,"modified_time":1516373186}}
# 793225835, 673550058 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550059,"modified_time":1516373216}}
# 793225835, 673550059 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550060,"modified_time":1516373246}}
# 793225835, 673550060 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550061,"modified_time":1516373276}}
# 793225835, 673550061 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550062,"modified_time":1516373306}}
# 793225835, 673550062 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550063,"modified_time":1516373337}}
# 793225835, 673550063 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550064,"modified_time":1516373367}}
# 793225835, 673550064 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550065,"modified_time":1516373397}}
# 793225835, 673550065 stock updated to 9
# {"item":{"item_id":793225835,"variation_id":673550066,"modified_time":1516373427}}
# 793225835, 673550066 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786329,"modified_time":1516373458}}
# 712457456, 563786329 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786330,"modified_time":1516373488}}
# 712457456, 563786330 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786331,"modified_time":1516373518}}
# 712457456, 563786331 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786332,"modified_time":1516373548}}
# 712457456, 563786332 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786333,"modified_time":1516373579}}
# 712457456, 563786333 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786334,"modified_time":1516373609}}
# 712457456, 563786334 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786335,"modified_time":1516373639}}
# {"item":{"item_id":624856274,"variation_id":466340435,"modified_time":1516384232}}
# 624856274, 466340435 stock updated to 8
# {"item":{"item_id":624856274,"variation_id":466340436,"modified_time":1516384263}}
# 624856274, 466340436 stock updated to 8
# {"item":{"item_id":624856265,"variation_id":466340394,"modified_time":1516384294}}
# 624856265, 466340394 stock updated to 6
# {"item":{"item_id":624856265,"variation_id":466340395,"modified_time":1516384324}}
# 624856265, 466340395 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340396,"modified_time":1516384354}}
# 624856265, 466340396 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340397,"modified_time":1516384384}}
# 624856265, 466340397 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340398,"modified_time":1516384414}}
# 624856265, 466340398 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340399,"modified_time":1516384445}}
# 624856265, 466340399 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340400,"modified_time":1516384475}}
# 624856265, 466340400 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340401,"modified_time":1516384505}}
# 624856265, 466340401 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340402,"modified_time":1516384535}}
# 624856265, 466340402 stock updated to 7
# {"item":{"item_id":624856265,"variation_id":466340403,"modified_time":1516384565}}
# 624856265, 466340403 stock updated to 7
# {"item":{"item_id":624856269,"variation_id":466340408,"modified_time":1516384596}}
# 624856269, 466340408 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340411,"modified_time":1516384626}}
# 624856269, 466340411 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340413,"modified_time":1516384656}}
# 624856269, 466340413 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340416,"modified_time":1516384687}}
# 624856269, 466340416 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340418,"modified_time":1516384717}}
# 624856269, 466340418 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340421,"modified_time":1516384747}}
# 624856269, 466340421 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340422,"modified_time":1516384777}}
# 624856269, 466340422 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340423,"modified_time":1516384808}}
# 624856269, 466340423 stock updated to 8
# {"item":{"item_id":624856269,"variation_id":466340424,"modified_time":1516384838}}
# 624856269, 466340424 stock updated to 7
# ...
# {"item":{"item_id":843303685,"variation_id":728481844,"modified_time":1516420666}}
# 843303685, 728481844 stock updated to 10
# {"item":{"item_id":843303685,"variation_id":728481845,"modified_time":1516420696}}
# 843303685, 728481845 stock updated to 10
# {"item":{"item_id":843303685,"variation_id":728481846,"modified_time":1516420726}}
# 843303685, 728481846 stock updated to 10
# {"item":{"item_id":843275607,"variation_id":728438374,"modified_time":1516420757}}
# 843275607, 728438374 stock updated to 10
# {"item":{"item_id":843275607,"variation_id":728438375,"modified_time":1516420787}}
# 843275607, 728438375 stock updated to 10
# {"item":{"item_id":843183887,"variation_id":728308795,"modified_time":1516420818}}
# 843183887, 728308795 stock updated to 10
# {"item":{"item_id":712457456,"variation_id":563786339,"modified_time":1516422450}}
# 712457456, 563786339 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786340,"modified_time":1516422481}}
# 712457456, 563786340 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786341,"modified_time":1516422511}}
# 712457456, 563786341 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786342,"modified_time":1516422541}}
# 712457456, 563786342 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786343,"modified_time":1516422571}}
# 712457456, 563786343 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786344,"modified_time":1516422602}}
# 712457456, 563786344 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786345,"modified_time":1516422632}}
# 712457456, 563786345 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786346,"modified_time":1516422662}}
# 712457456, 563786346 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786347,"modified_time":1516422692}}
# 712457456, 563786347 stock updated to 9
# {"item":{"item_id":712457456,"variation_id":563786348,"modified_time":1516422723}}
# 712457456, 563786348 stock updated to 9
# {"item":{"item_id":845145961,"variation_id":730332393,"modified_time":1516422753}}
# 845145961, 730332393 stock updated to 9
# {"item":{"item_id":845145961,"variation_id":730332394,"modified_time":1516422783}}
# 845145961, 730332394 stock updated to 9
# {"item":{"item_id":845145961,"variation_id":730332395,"modified_time":1516422813}}
# 845145961, 730332395 stock updated to 9
# {"item":{"item_id":845303761,"variation_id":730544586,"modified_time":1516422847}}
# 845303761, 730544586 stock updated to 9
# {"item":{"item_id":845303761,"variation_id":730544588,"modified_time":1516422877}}
# 845303761, 730544588 stock updated to 9
# {"item":{"item_id":845330652,"variation_id":730573879,"modified_time":1516422919}}
# 845330652, 730573879 stock updated to 9
# {"item":{"item_id":845330652,"variation_id":730573880,"modified_time":1516422954}}
# 845330652, 730573880 stock updated to 9
# {"item":{"item_id":845330652,"variation_id":730573881,"modified_time":1516422997}}
# 845330652, 730573881 stock updated to 9
# {"item":{"item_id":845339681,"variation_id":730585296,"modified_time":1516423030}}
# 845339681, 730585296 stock updated to 9
# {"item":{"item_id":845357158,"variation_id":730607259,"modified_time":1516423061}}
# 845357158, 730607259 stock updated to 9
# {"item":{"item_id":845357158,"variation_id":730607261,"modified_time":1516423095}}
# 845357158, 730607261 stock updated to 9
# {"item":{"item_id":845364059,"variation_id":730616853,"modified_time":1516423129}}
# 845364059, 730616853 stock updated to 9
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     416             try:
# --> 417                 cnx.do_handshake()
#     418             except OpenSSL.SSL.WantReadError:
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1425         result = _lib.SSL_do_handshake(self._ssl)
# -> 1426         self._raise_ssl_error(self._ssl, result)
#    1427
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1166                         raise SysCallError(errno, errorcode.get(errno))
# -> 1167                 raise SysCallError(-1, "Unexpected EOF")
#    1168             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     322             server_hostname=hostname,
# --> 323             ssl_context=context)
#     324
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     323     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 324         return context.wrap_socket(sock, server_hostname=server_hostname)
#     325
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     423             except OpenSSL.SSL.Error as e:
# --> 424                 raise ssl.SSLError('bad handshake: %r' % e)
#     425             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     623             clean_exit = False
# --> 624             raise SSLError(e)
#     625
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-33-0571a727a86b> in <module>()
#      33         payload = json.dumps(payload)
#      34         # Post Request
# ---> 35         r = requests.post(get_item_detail_url, data=payload, headers=headers)
#      36         # 打印原始Json
#      37         parsed = json.loads(r.text)
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     108     """
#     109
# --> 110     return request('post', url, data=data, json=json, **kwargs)
#     111
#     112
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     495         except (_SSLError, _HTTPError) as e:
#     496             if isinstance(e, _SSLError):
# --> 497                 raise SSLError(e, request=request)
#     498             elif isinstance(e, ReadTimeoutError):
#     499                 raise ReadTimeout(e, request=request)
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
