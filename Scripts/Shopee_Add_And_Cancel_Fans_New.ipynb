# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time
import logging

# %%
logging.basicConfig(level=logging.INFO, format=' %(asctime)s - %(levelname)s - %(message)s')

# %%
# 屏幕最大化，且指定下载目录
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

prefs = {"profile.default_content_settings.popups": 0,
         "directory_upgrade": True}
options.add_experimental_option("prefs", prefs)

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
# browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
# 所需参数
# 站点；站点后缀；账户；密码；站点top卖家shopid；top卖家username（方便识别）
shop_list = [['tw', 'tw', 23070969, 'poweradapter.tw', 'kuangyiqiao1991', 9469128, 'alonso.tw'],
             ['tw', 'tw', 25482220, 'tengus.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 58707738, 'qianjiaozi', 'qianjiaozi888', 23068230, 'iu.tw'],
             ['tw', 'tw', 66377809, 'qianjiaozi1', 'qianjiaozi888', 23068230, 'iu.tw'],
             ['tw', 'tw', 62416366, 'tengus1.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 62416544, 'tengus2.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 63534861, 'qianjiaozitw1', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 62887142, 'yilanlu.tw', 'yilanlu888', 23481977, 'huoyi.tw'],
             ['my', 'com.my', 53580963, 'qianjiaozi.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 59848325, 'tengus.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 62418141, 'tengus1.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 62418493, 'tengus2.my', 'tengus1803', 10891137, 'winners.my'],
             ['id', 'co.id', 59846508, 'tengus.id', 'tengus1803', 28135012, 'sunnyfun.id'],
             ['id', 'co.id', 62417386, 'tengus1.id', 'tengus1803', 28135012, 'sunnyfun.id'],
             ['id', 'co.id', 62417551, 'tengus2.id', 'tengus1803', 28135012, 'sunnyfun.id']]

# %%
# 转换为dataframe
shop_df_columns = ['site', 'site_suffix', 'shopid', 'acc', 'pwd', 'top_shop_id', 'top_shop_username']
shop_df = pd.DataFrame(shop_list, columns=shop_df_columns)

# %%
# 关注及关注中多语言
following_language = ['关注中', '關注中', 'Following', 'Mengikuti']
not_following_language = ['+ 关注', '+ 關注', '+ Follow', '+ Ikuti']

# %%
# 取关后关注函数
def add_and_cancel_fans(site, site_suffix, shopid, acc, pwd, top_shop_id, top_shop_username):
    # 打开浏览器
    logging.info('Open the browser.')
    browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)
    
    # main page
    main_page_url = "http://shopee." + site_suffix
    browser.get(main_page_url)
    time.sleep(10)
    
    # if the shop is on my site, should press the button to choose language
    if site == 'my':
        language_selector = browser.find_elements_by_css_selector('.shopee-button-outline.shopee-button-outline--primary-reverse')
        language_selector[2].click()
        logging.info('Choose Chinese as language.')
        time.sleep(10)
    
    # remove ads, refresh again
    browser.get(main_page_url)
    time.sleep(10)
    
    # login
    logging.info('Start to login.')
    LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
    
    # 点击登入，弹出账户密码输入框
    LoginElem[1].click()
    time.sleep(10)
    
    # 输入
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    try:
        acc_password_input_elem[0].click()
        acc_password_input_elem[0].send_keys(acc)
        acc_password_input_elem[1].click()
        acc_password_input_elem[1].send_keys(pwd)
    except:
        time.sleep(30)
        acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
        acc_password_input_elem[0].click()
        acc_password_input_elem[0].send_keys(acc)
        acc_password_input_elem[1].click()
        acc_password_input_elem[1].send_keys(pwd)
    time.sleep(10)
    
    # 点击提交
    Login_button_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
    Login_button_elem[0].click()
    logging.info('Login completed.')
    time.sleep(10)
    
    # switch to my following list
    logging.info('Switch to my following list.')
    my_fans_list_page = 'https://shopee.' + site_suffix + '/shop/' + str(shopid) + '/following/?__classic__=1'
    browser.get(my_fans_list_page)
    
    # cancel certain number of following fans
    to_cancel_num_of_following = 400
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    
    # in case the following number is not greater than 500
    max_roll_time = 100
    roll_time = 0
    
    # page down until we get at least 500 fans to cancel
    while num_of_following_display <= 500 and roll_time <= max_roll_time:
        body = browser.find_element_by_css_selector('body')
        body.send_keys(Keys.END)
        time.sleep(5)
        num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
        logging.info(str(num_of_following_display) + ' following on the list.')
        roll_time += 1
        logging.info('Roll the page for ' + str(roll_time) + ' time.')
    following_buttons = browser.find_elements_by_css_selector('.btn-follow.active.follow.L14')
    
    # actual following to cancel
    to_cancel_num_of_following = min(num_of_following_display, to_cancel_num_of_following)
    
    # page up to the top
    scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)
    
    # start to cancel following
    logging.info('Start to cancel following.')
    i = 0
    total_cancel_num_of_following = to_cancel_num_of_following
    while i <= total_cancel_num_of_following - 1:
        while to_cancel_num_of_following > 0:
            logging.info('Now run the ' + str(i + 1) + ' time.')
            if following_buttons[i].text in following_language:
                shopid = following_buttons[i].get_attribute('shopid')
                following_buttons[i].click()
                time.sleep(5)
                to_cancel_num_of_following -= 1
                i += 1
                logging.info(str(shopid) + ' is not following now, ' + str(to_cancel_num_of_following) + ' following remains.')
    
    # add fans from Top Seller's followers
    logging.info('Switch to top seller follower page.')
    top_shop_url = 'https://shopee.' + site_suffix + '/shop/' + str(top_shop_id) + '/followers/?__classic__=1'
    browser.get(top_shop_url)
    
    # add certain number of fans
    to_add_num_of_following = 400
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    
    # page down until we get at least 400 fans to cancel
    logging.info('Start to roll down.')
    while num_of_following_display <= 1000:
        body = browser.find_element_by_css_selector('body')
        # body.send_keys(Keys.PAGE_DOWN)
        body.send_keys(Keys.END)
        time.sleep(5)
        num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    following_buttons = browser.find_elements_by_css_selector('.btn-follow.follow.L14')
    
    # start to follow buyers from top shop
    logging.info('Start to follow buyers.')
    i = 0
    total_add_num_of_following = to_add_num_of_following
    scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)

    while i <= total_add_num_of_following - 1:  
        while to_add_num_of_following > 0:
            logging.info('Now run the ' + str(i + 1) + ' time.')
            if following_buttons[i].text in not_following_language:
                # print(following_buttons[i].text)
                shopid = following_buttons[i].get_attribute('shopid')
                following_buttons[i].click()
                time.sleep(5)
                to_add_num_of_following -= 1
                logging.info(str(shopid) + ' is following now, ' + str(to_add_num_of_following) + ' following remains.')
            else:
                logging.info('Skip this one. It\'s following already.')
            i += 1    
    
    # 关闭
    browser.quit()

# %%
# 历遍所有shop
for index, my_shop in shop_df.iterrows():
    site = my_shop[0]
    site_suffix = my_shop[1]
    shopid = my_shop[2]
    acc = my_shop[3]
    pwd = my_shop[4]
    top_shop_id = my_shop[5]
    top_shop_username = my_shop[6]
    
    # 执行
    logging.info('Now it\'s running the script on ' + acc + '.')
    add_and_cancel_fans(site, site_suffix, shopid, acc, pwd, top_shop_id, top_shop_username)
# Out:
#  2018-05-11 08:23:39,768 - INFO - Now it's running the script on poweradapter.tw.
#  2018-05-11 08:23:39,769 - INFO - Open the browser.
#  2018-05-11 08:24:40,354 - INFO - Start to login.
#  2018-05-11 08:25:01,127 - INFO - Login completed.
#  2018-05-11 08:25:11,128 - INFO - Switch to my following list.
#  2018-05-11 08:25:49,699 - INFO - 40 following on the list.
#  2018-05-11 08:25:49,700 - INFO - Roll the page for 1 time.
#  2018-05-11 08:25:54,775 - INFO - 60 following on the list.
#  2018-05-11 08:25:54,777 - INFO - Roll the page for 2 time.
#  2018-05-11 08:25:59,876 - INFO - 80 following on the list.
#  2018-05-11 08:25:59,876 - INFO - Roll the page for 3 time.
#  2018-05-11 08:26:04,942 - INFO - 100 following on the list.
#  2018-05-11 08:26:04,943 - INFO - Roll the page for 4 time.
#  2018-05-11 08:26:10,026 - INFO - 120 following on the list.
#  2018-05-11 08:26:10,027 - INFO - Roll the page for 5 time.
#  2018-05-11 08:26:15,136 - INFO - 140 following on the list.
#  2018-05-11 08:26:15,137 - INFO - Roll the page for 6 time.
#  2018-05-11 08:26:20,287 - INFO - 160 following on the list.
#  2018-05-11 08:26:20,289 - INFO - Roll the page for 7 time.
#  2018-05-11 08:26:25,404 - INFO - 180 following on the list.
#  2018-05-11 08:26:25,404 - INFO - Roll the page for 8 time.
#  2018-05-11 08:26:30,474 - INFO - 200 following on the list.
#  2018-05-11 08:26:30,475 - INFO - Roll the page for 9 time.
#  2018-05-11 08:26:35,538 - INFO - 220 following on the list.
#  2018-05-11 08:26:35,538 - INFO - Roll the page for 10 time.
#  2018-05-11 08:26:40,632 - INFO - 240 following on the list.
#  2018-05-11 08:26:40,633 - INFO - Roll the page for 11 time.
#  2018-05-11 08:26:45,716 - INFO - 260 following on the list.
#  2018-05-11 08:26:45,717 - INFO - Roll the page for 12 time.
#  2018-05-11 08:26:50,803 - INFO - 280 following on the list.
#  2018-05-11 08:26:50,804 - INFO - Roll the page for 13 time.
#  2018-05-11 08:26:55,896 - INFO - 300 following on the list.
#  2018-05-11 08:26:55,896 - INFO - Roll the page for 14 time.
#  2018-05-11 08:27:00,991 - INFO - 320 following on the list.
#  2018-05-11 08:27:00,992 - INFO - Roll the page for 15 time.
#  2018-05-11 08:27:06,093 - INFO - 340 following on the list.
#  2018-05-11 08:27:06,094 - INFO - Roll the page for 16 time.
#  2018-05-11 08:27:11,241 - INFO - 360 following on the list.
#  2018-05-11 08:27:11,242 - INFO - Roll the page for 17 time.
#  2018-05-11 08:27:16,344 - INFO - 380 following on the list.
#  2018-05-11 08:27:16,346 - INFO - Roll the page for 18 time.
#  2018-05-11 08:27:21,435 - INFO - 400 following on the list.
#  2018-05-11 08:27:21,436 - INFO - Roll the page for 19 time.
#  2018-05-11 08:27:26,589 - INFO - 420 following on the list.
#  2018-05-11 08:27:26,590 - INFO - Roll the page for 20 time.
#  2018-05-11 08:27:31,730 - INFO - 440 following on the list.
#  2018-05-11 08:27:31,731 - INFO - Roll the page for 21 time.
#  2018-05-11 08:27:36,880 - INFO - 460 following on the list.
#  2018-05-11 08:27:36,881 - INFO - Roll the page for 22 time.
#  2018-05-11 08:27:42,001 - INFO - 480 following on the list.
#  2018-05-11 08:27:42,003 - INFO - Roll the page for 23 time.
#  2018-05-11 08:27:47,135 - INFO - 500 following on the list.
#  2018-05-11 08:27:47,136 - INFO - Roll the page for 24 time.
#  2018-05-11 08:27:52,264 - INFO - 520 following on the list.
#  2018-05-11 08:27:52,265 - INFO - Roll the page for 25 time.
#  2018-05-11 08:27:52,398 - INFO - Start to cancel following.
#  2018-05-11 08:27:52,399 - INFO - Now run the 1 time.
#  2018-05-11 08:27:57,537 - INFO - 24151465 is not following now, 399 following remains.
#  2018-05-11 08:27:57,539 - INFO - Now run the 2 time.
#  2018-05-11 08:28:02,673 - INFO - 129318 is not following now, 398 following remains.
#  2018-05-11 08:28:02,674 - INFO - Now run the 3 time.
#  2018-05-11 08:28:07,754 - INFO - 36529754 is not following now, 397 following remains.
#  2018-05-11 08:28:07,755 - INFO - Now run the 4 time.
#  2018-05-11 08:28:12,867 - INFO - 42636657 is not following now, 396 following remains.
#  2018-05-11 08:28:12,868 - INFO - Now run the 5 time.
#  2018-05-11 08:28:17,982 - INFO - 36700094 is not following now, 395 following remains.
#  2018-05-11 08:28:17,983 - INFO - Now run the 6 time.
#  2018-05-11 08:28:23,076 - INFO - 10335089 is not following now, 394 following remains.
#  2018-05-11 08:28:23,076 - INFO - Now run the 7 time.
#  2018-05-11 08:28:28,181 - INFO - 27296100 is not following now, 393 following remains.
#  2018-05-11 08:28:28,182 - INFO - Now run the 8 time.
#  2018-05-11 08:28:33,267 - INFO - 3385188 is not following now, 392 following remains.
#  2018-05-11 08:28:33,267 - INFO - Now run the 9 time.
#  2018-05-11 08:28:38,375 - INFO - 7961996 is not following now, 391 following remains.
#  2018-05-11 08:28:38,376 - INFO - Now run the 10 time.
#  2018-05-11 08:28:43,478 - INFO - 21933140 is not following now, 390 following remains.
#  2018-05-11 08:28:43,479 - INFO - Now run the 11 time.
#  2018-05-11 08:28:48,568 - INFO - 2442585 is not following now, 389 following remains.
#  2018-05-11 08:28:48,568 - INFO - Now run the 12 time.
#  2018-05-11 08:28:53,675 - INFO - 7279278 is not following now, 388 following remains.
#  2018-05-11 08:28:53,675 - INFO - Now run the 13 time.
#  2018-05-11 08:28:58,795 - INFO - 23850646 is not following now, 387 following remains.
#  2018-05-11 08:28:58,796 - INFO - Now run the 14 time.
#  2018-05-11 08:29:03,910 - INFO - 14870991 is not following now, 386 following remains.
#  2018-05-11 08:29:03,910 - INFO - Now run the 15 time.
#  2018-05-11 08:29:09,009 - INFO - 18990271 is not following now, 385 following remains.
#  2018-05-11 08:29:09,010 - INFO - Now run the 16 time.
#  2018-05-11 08:29:14,135 - INFO - 6074319 is not following now, 384 following remains.
#  2018-05-11 08:29:14,135 - INFO - Now run the 17 time.
#  2018-05-11 08:29:19,221 - INFO - 3890934 is not following now, 383 following remains.
#  2018-05-11 08:29:19,221 - INFO - Now run the 18 time.
#  2018-05-11 08:29:24,345 - INFO - 42702924 is not following now, 382 following remains.
#  2018-05-11 08:29:24,345 - INFO - Now run the 19 time.
#  2018-05-11 08:29:29,449 - INFO - 41753992 is not following now, 381 following remains.
#  2018-05-11 08:29:29,450 - INFO - Now run the 20 time.
#  2018-05-11 08:29:34,558 - INFO - 19491046 is not following now, 380 following remains.
#  2018-05-11 08:29:34,558 - INFO - Now run the 21 time.
#  2018-05-11 08:29:39,655 - INFO - 9423385 is not following now, 379 following remains.
#  2018-05-11 08:29:39,656 - INFO - Now run the 22 time.
#  2018-05-11 08:29:44,783 - INFO - 5236084 is not following now, 378 following remains.
#  2018-05-11 08:29:44,784 - INFO - Now run the 23 time.
#  2018-05-11 08:29:49,875 - INFO - 3786149 is not following now, 377 following remains.
#  2018-05-11 08:29:49,876 - INFO - Now run the 24 time.
#  2018-05-11 08:29:54,980 - INFO - 2730084 is not following now, 376 following remains.
#  2018-05-11 08:29:54,980 - INFO - Now run the 25 time.
#  2018-05-11 08:30:00,099 - INFO - 26899490 is not following now, 375 following remains.
#  2018-05-11 08:30:00,101 - INFO - Now run the 26 time.
#  2018-05-11 08:30:05,224 - INFO - 34340321 is not following now, 374 following remains.
#  2018-05-11 08:30:05,224 - INFO - Now run the 27 time.
#  2018-05-11 08:30:10,348 - INFO - 39162534 is not following now, 373 following remains.
#  2018-05-11 08:30:10,348 - INFO - Now run the 28 time.
#  2018-05-11 08:30:15,451 - INFO - 42168741 is not following now, 372 following remains.
#  2018-05-11 08:30:15,452 - INFO - Now run the 29 time.
#  2018-05-11 08:30:20,585 - INFO - 6658212 is not following now, 371 following remains.
#  2018-05-11 08:30:20,586 - INFO - Now run the 30 time.
#  2018-05-11 08:30:25,690 - INFO - 1492524 is not following now, 370 following remains.
#  2018-05-11 08:30:25,692 - INFO - Now run the 31 time.
#  2018-05-11 08:30:30,813 - INFO - 2124396 is not following now, 369 following remains.
#  2018-05-11 08:30:30,813 - INFO - Now run the 32 time.
#  2018-05-11 08:30:35,924 - INFO - 8938709 is not following now, 368 following remains.
#  2018-05-11 08:30:35,926 - INFO - Now run the 33 time.
#  2018-05-11 08:30:41,050 - INFO - 6291024 is not following now, 367 following remains.
#  2018-05-11 08:30:41,051 - INFO - Now run the 34 time.
#  2018-05-11 08:30:46,185 - INFO - 40445518 is not following now, 366 following remains.
#  2018-05-11 08:30:46,186 - INFO - Now run the 35 time.
#  2018-05-11 08:30:51,292 - INFO - 3106600 is not following now, 365 following remains.
#  2018-05-11 08:30:51,293 - INFO - Now run the 36 time.
#  2018-05-11 08:30:56,408 - INFO - 5212725 is not following now, 364 following remains.
#  2018-05-11 08:30:56,409 - INFO - Now run the 37 time.
#  2018-05-11 08:31:01,549 - INFO - 1096512 is not following now, 363 following remains.
#  2018-05-11 08:31:01,550 - INFO - Now run the 38 time.
#  2018-05-11 08:31:06,660 - INFO - 11861204 is not following now, 362 following remains.
#  2018-05-11 08:31:06,660 - INFO - Now run the 39 time.
#  2018-05-11 08:31:11,780 - INFO - 6212514 is not following now, 361 following remains.
#  2018-05-11 08:31:11,780 - INFO - Now run the 40 time.
#  2018-05-11 08:31:16,870 - INFO - 270306 is not following now, 360 following remains.
#  2018-05-11 08:31:16,871 - INFO - Now run the 41 time.
#  2018-05-11 08:31:21,992 - INFO - 31937118 is not following now, 359 following remains.
#  2018-05-11 08:31:21,992 - INFO - Now run the 42 time.
#  2018-05-11 08:31:27,108 - INFO - 5195912 is not following now, 358 following remains.
#  2018-05-11 08:31:27,109 - INFO - Now run the 43 time.
#  2018-05-11 08:31:32,233 - INFO - 9120677 is not following now, 357 following remains.
#  2018-05-11 08:31:32,233 - INFO - Now run the 44 time.
#  2018-05-11 08:31:37,340 - INFO - 3275683 is not following now, 356 following remains.
#  2018-05-11 08:31:37,340 - INFO - Now run the 45 time.
#  2018-05-11 08:31:42,430 - INFO - 386477 is not following now, 355 following remains.
#  2018-05-11 08:31:42,431 - INFO - Now run the 46 time.
#  2018-05-11 08:31:47,555 - INFO - 22689874 is not following now, 354 following remains.
#  2018-05-11 08:31:47,556 - INFO - Now run the 47 time.
#  2018-05-11 08:31:52,644 - INFO - 1393111 is not following now, 353 following remains.
#  2018-05-11 08:31:52,644 - INFO - Now run the 48 time.
#  2018-05-11 08:31:57,731 - INFO - 6018374 is not following now, 352 following remains.
#  2018-05-11 08:31:57,732 - INFO - Now run the 49 time.
#  2018-05-11 08:32:02,836 - INFO - 3579257 is not following now, 351 following remains.
#  2018-05-11 08:32:02,836 - INFO - Now run the 50 time.
#  2018-05-11 08:32:07,924 - INFO - 2479818 is not following now, 350 following remains.
#  2018-05-11 08:32:07,925 - INFO - Now run the 51 time.
#  2018-05-11 08:32:13,034 - INFO - 5391489 is not following now, 349 following remains.
#  2018-05-11 08:32:13,034 - INFO - Now run the 52 time.
#  2018-05-11 08:32:18,152 - INFO - 3447133 is not following now, 348 following remains.
#  2018-05-11 08:32:18,152 - INFO - Now run the 53 time.
#  2018-05-11 08:32:23,275 - INFO - 4636873 is not following now, 347 following remains.
#  2018-05-11 08:32:23,276 - INFO - Now run the 54 time.
#  2018-05-11 08:32:28,415 - INFO - 332765 is not following now, 346 following remains.
#  2018-05-11 08:32:28,416 - INFO - Now run the 55 time.
#  2018-05-11 08:32:33,550 - INFO - 26630477 is not following now, 345 following remains.
#  2018-05-11 08:32:33,551 - INFO - Now run the 56 time.
#  2018-05-11 08:32:38,693 - INFO - 41116954 is not following now, 344 following remains.
#  2018-05-11 08:32:38,695 - INFO - Now run the 57 time.
#  2018-05-11 08:32:43,836 - INFO - 19094748 is not following now, 343 following remains.
#  2018-05-11 08:32:43,837 - INFO - Now run the 58 time.
#  2018-05-11 08:32:48,954 - INFO - 36807967 is not following now, 342 following remains.
#  2018-05-11 08:32:48,955 - INFO - Now run the 59 time.
#  2018-05-11 08:32:54,072 - INFO - 189520 is not following now, 341 following remains.
#  2018-05-11 08:32:54,073 - INFO - Now run the 60 time.
#  2018-05-11 08:32:59,184 - INFO - 1483317 is not following now, 340 following remains.
#  2018-05-11 08:32:59,184 - INFO - Now run the 61 time.
#  2018-05-11 08:33:04,274 - INFO - 26790505 is not following now, 339 following remains.
#  2018-05-11 08:33:04,274 - INFO - Now run the 62 time.
#  2018-05-11 08:33:09,374 - INFO - 5579194 is not following now, 338 following remains.
#  2018-05-11 08:33:09,375 - INFO - Now run the 63 time.
#  2018-05-11 08:33:14,476 - INFO - 36931426 is not following now, 337 following remains.
#  2018-05-11 08:33:14,478 - INFO - Now run the 64 time.
#  2018-05-11 08:33:19,589 - INFO - 11973266 is not following now, 336 following remains.
#  2018-05-11 08:33:19,589 - INFO - Now run the 65 time.
#  2018-05-11 08:33:24,694 - INFO - 9834586 is not following now, 335 following remains.
#  2018-05-11 08:33:24,694 - INFO - Now run the 66 time.
#  2018-05-11 08:33:29,812 - INFO - 10351883 is not following now, 334 following remains.
#  2018-05-11 08:33:29,813 - INFO - Now run the 67 time.
#  2018-05-11 08:33:34,902 - INFO - 3474255 is not following now, 333 following remains.
#  2018-05-11 08:33:34,904 - INFO - Now run the 68 time.
#  2018-05-11 08:33:40,024 - INFO - 6612286 is not following now, 332 following remains.
#  2018-05-11 08:33:40,025 - INFO - Now run the 69 time.
#  2018-05-11 08:33:45,148 - INFO - 5292546 is not following now, 331 following remains.
#  2018-05-11 08:33:45,149 - INFO - Now run the 70 time.
#  2018-05-11 08:33:50,290 - INFO - 16613451 is not following now, 330 following remains.
#  2018-05-11 08:33:50,290 - INFO - Now run the 71 time.
#  2018-05-11 08:33:55,380 - INFO - 38619758 is not following now, 329 following remains.
#  2018-05-11 08:33:55,380 - INFO - Now run the 72 time.
#  2018-05-11 08:34:00,483 - INFO - 14402446 is not following now, 328 following remains.
#  2018-05-11 08:34:00,483 - INFO - Now run the 73 time.
#  2018-05-11 08:34:05,572 - INFO - 4844057 is not following now, 327 following remains.
#  2018-05-11 08:34:05,572 - INFO - Now run the 74 time.
#  2018-05-11 08:34:10,661 - INFO - 7444360 is not following now, 326 following remains.
#  2018-05-11 08:34:10,661 - INFO - Now run the 75 time.
#  2018-05-11 08:34:15,753 - INFO - 11800834 is not following now, 325 following remains.
#  2018-05-11 08:34:15,753 - INFO - Now run the 76 time.
#  2018-05-11 08:34:20,851 - INFO - 23622819 is not following now, 324 following remains.
#  2018-05-11 08:34:20,852 - INFO - Now run the 77 time.
#  2018-05-11 08:34:25,945 - INFO - 21624051 is not following now, 323 following remains.
#  2018-05-11 08:34:25,945 - INFO - Now run the 78 time.
#  2018-05-11 08:34:31,034 - INFO - 2596716 is not following now, 322 following remains.
#  2018-05-11 08:34:31,035 - INFO - Now run the 79 time.
#  2018-05-11 08:34:36,140 - INFO - 6450617 is not following now, 321 following remains.
#  2018-05-11 08:34:36,140 - INFO - Now run the 80 time.
#  2018-05-11 08:34:41,230 - INFO - 18129840 is not following now, 320 following remains.
#  2018-05-11 08:34:41,231 - INFO - Now run the 81 time.
#  2018-05-11 08:34:46,359 - INFO - 5035934 is not following now, 319 following remains.
#  2018-05-11 08:34:46,361 - INFO - Now run the 82 time.
#  2018-05-11 08:34:51,487 - INFO - 17843038 is not following now, 318 following remains.
#  2018-05-11 08:34:51,488 - INFO - Now run the 83 time.
#  2018-05-11 08:34:56,597 - INFO - 42815296 is not following now, 317 following remains.
#  2018-05-11 08:34:56,598 - INFO - Now run the 84 time.
#  2018-05-11 08:35:01,715 - INFO - 2931623 is not following now, 316 following remains.
#  2018-05-11 08:35:01,716 - INFO - Now run the 85 time.
#  2018-05-11 08:35:06,834 - INFO - 6775922 is not following now, 315 following remains.
#  2018-05-11 08:35:06,835 - INFO - Now run the 86 time.
#  2018-05-11 08:35:11,942 - INFO - 18818260 is not following now, 314 following remains.
#  2018-05-11 08:35:11,943 - INFO - Now run the 87 time.
#  2018-05-11 08:35:17,048 - INFO - 14093075 is not following now, 313 following remains.
#  2018-05-11 08:35:17,049 - INFO - Now run the 88 time.
#  2018-05-11 08:35:22,174 - INFO - 4639356 is not following now, 312 following remains.
#  2018-05-11 08:35:22,174 - INFO - Now run the 89 time.
#  2018-05-11 08:35:27,260 - INFO - 7893432 is not following now, 311 following remains.
#  2018-05-11 08:35:27,261 - INFO - Now run the 90 time.
#  2018-05-11 08:35:32,378 - INFO - 7454066 is not following now, 310 following remains.
#  2018-05-11 08:35:32,379 - INFO - Now run the 91 time.
#  2018-05-11 08:35:37,490 - INFO - 25383562 is not following now, 309 following remains.
#  2018-05-11 08:35:37,491 - INFO - Now run the 92 time.
#  2018-05-11 08:35:42,627 - INFO - 3862495 is not following now, 308 following remains.
#  2018-05-11 08:35:42,628 - INFO - Now run the 93 time.
#  2018-05-11 08:35:47,734 - INFO - 35274938 is not following now, 307 following remains.
#  2018-05-11 08:35:47,735 - INFO - Now run the 94 time.
#  2018-05-11 08:35:52,860 - INFO - 4532183 is not following now, 306 following remains.
#  2018-05-11 08:35:52,861 - INFO - Now run the 95 time.
#  2018-05-11 08:35:57,949 - INFO - 19505790 is not following now, 305 following remains.
#  2018-05-11 08:35:57,949 - INFO - Now run the 96 time.
#  2018-05-11 08:36:03,049 - INFO - 35239770 is not following now, 304 following remains.
#  2018-05-11 08:36:03,050 - INFO - Now run the 97 time.
#  2018-05-11 08:36:08,157 - INFO - 38794430 is not following now, 303 following remains.
#  2018-05-11 08:36:08,158 - INFO - Now run the 98 time.
#  2018-05-11 08:36:13,292 - INFO - 22193999 is not following now, 302 following remains.
#  2018-05-11 08:36:13,294 - INFO - Now run the 99 time.
#  2018-05-11 08:36:18,421 - INFO - 2535527 is not following now, 301 following remains.
#  2018-05-11 08:36:18,422 - INFO - Now run the 100 time.
#  2018-05-11 08:36:23,510 - INFO - 7821016 is not following now, 300 following remains.
#  2018-05-11 08:36:23,510 - INFO - Now run the 101 time.
#  2018-05-11 08:36:28,614 - INFO - 7700533 is not following now, 299 following remains.
#  2018-05-11 08:36:28,616 - INFO - Now run the 102 time.
#  2018-05-11 08:36:33,735 - INFO - 5752520 is not following now, 298 following remains.
#  2018-05-11 08:36:33,737 - INFO - Now run the 103 time.
#  2018-05-11 08:36:38,858 - INFO - 2329957 is not following now, 297 following remains.
#  2018-05-11 08:36:38,860 - INFO - Now run the 104 time.
#  2018-05-11 08:36:43,981 - INFO - 26382769 is not following now, 296 following remains.
#  2018-05-11 08:36:43,983 - INFO - Now run the 105 time.
#  2018-05-11 08:36:49,101 - INFO - 29676447 is not following now, 295 following remains.
#  2018-05-11 08:36:49,103 - INFO - Now run the 106 time.
#  2018-05-11 08:36:54,242 - INFO - 22387682 is not following now, 294 following remains.
#  2018-05-11 08:36:54,243 - INFO - Now run the 107 time.
#  2018-05-11 08:36:59,343 - INFO - 19389060 is not following now, 293 following remains.
#  2018-05-11 08:36:59,344 - INFO - Now run the 108 time.
#  2018-05-11 08:37:04,455 - INFO - 16713707 is not following now, 292 following remains.
#  2018-05-11 08:37:04,455 - INFO - Now run the 109 time.
#  2018-05-11 08:37:09,558 - INFO - 3948255 is not following now, 291 following remains.
#  2018-05-11 08:37:09,559 - INFO - Now run the 110 time.
#  2018-05-11 08:37:14,659 - INFO - 2338988 is not following now, 290 following remains.
#  2018-05-11 08:37:14,659 - INFO - Now run the 111 time.
#  2018-05-11 08:37:19,750 - INFO - 12624622 is not following now, 289 following remains.
#  2018-05-11 08:37:19,751 - INFO - Now run the 112 time.
#  2018-05-11 08:37:24,874 - INFO - 9231918 is not following now, 288 following remains.
#  2018-05-11 08:37:24,874 - INFO - Now run the 113 time.
#  2018-05-11 08:37:29,960 - INFO - 41525944 is not following now, 287 following remains.
#  2018-05-11 08:37:29,961 - INFO - Now run the 114 time.
#  2018-05-11 08:37:35,071 - INFO - 17125382 is not following now, 286 following remains.
#  2018-05-11 08:37:35,072 - INFO - Now run the 115 time.
#  2018-05-11 08:37:40,193 - INFO - 32966136 is not following now, 285 following remains.
#  2018-05-11 08:37:40,194 - INFO - Now run the 116 time.
#  2018-05-11 08:37:45,315 - INFO - 1484847 is not following now, 284 following remains.
#  2018-05-11 08:37:45,315 - INFO - Now run the 117 time.
#  2018-05-11 08:37:50,416 - INFO - 8310982 is not following now, 283 following remains.
#  2018-05-11 08:37:50,418 - INFO - Now run the 118 time.
#  2018-05-11 08:37:55,524 - INFO - 886944 is not following now, 282 following remains.
#  2018-05-11 08:37:55,525 - INFO - Now run the 119 time.
#  2018-05-11 08:38:00,625 - INFO - 4368457 is not following now, 281 following remains.
#  2018-05-11 08:38:00,627 - INFO - Now run the 120 time.
#  2018-05-11 08:38:05,768 - INFO - 36551203 is not following now, 280 following remains.
#  2018-05-11 08:38:05,770 - INFO - Now run the 121 time.
#  2018-05-11 08:38:10,894 - INFO - 17810045 is not following now, 279 following remains.
#  2018-05-11 08:38:10,895 - INFO - Now run the 122 time.
#  2018-05-11 08:38:15,980 - INFO - 16089075 is not following now, 278 following remains.
#  2018-05-11 08:38:15,981 - INFO - Now run the 123 time.
#  2018-05-11 08:38:21,101 - INFO - 6584309 is not following now, 277 following remains.
#  2018-05-11 08:38:21,102 - INFO - Now run the 124 time.
#  2018-05-11 08:38:26,209 - INFO - 5645283 is not following now, 276 following remains.
#  2018-05-11 08:38:26,209 - INFO - Now run the 125 time.
#  2018-05-11 08:38:31,331 - INFO - 10462368 is not following now, 275 following remains.
#  2018-05-11 08:38:31,332 - INFO - Now run the 126 time.
#  2018-05-11 08:38:36,430 - INFO - 6347751 is not following now, 274 following remains.
#  2018-05-11 08:38:36,431 - INFO - Now run the 127 time.
#  2018-05-11 08:38:41,570 - INFO - 22120293 is not following now, 273 following remains.
#  2018-05-11 08:38:41,570 - INFO - Now run the 128 time.
#  2018-05-11 08:38:46,669 - INFO - 39447969 is not following now, 272 following remains.
#  2018-05-11 08:38:46,670 - INFO - Now run the 129 time.
#  2018-05-11 08:38:51,753 - INFO - 41672886 is not following now, 271 following remains.
#  2018-05-11 08:38:51,754 - INFO - Now run the 130 time.
#  2018-05-11 08:38:56,875 - INFO - 22571111 is not following now, 270 following remains.
#  2018-05-11 08:38:56,875 - INFO - Now run the 131 time.
#  2018-05-11 08:39:01,982 - INFO - 2064703 is not following now, 269 following remains.
#  2018-05-11 08:39:01,983 - INFO - Now run the 132 time.
#  2018-05-11 08:39:07,084 - INFO - 14240400 is not following now, 268 following remains.
#  2018-05-11 08:39:07,085 - INFO - Now run the 133 time.
#  2018-05-11 08:39:12,223 - INFO - 2711184 is not following now, 267 following remains.
#  2018-05-11 08:39:12,224 - INFO - Now run the 134 time.
#  2018-05-11 08:39:17,350 - INFO - 4774535 is not following now, 266 following remains.
#  2018-05-11 08:39:17,351 - INFO - Now run the 135 time.
#  2018-05-11 08:39:22,473 - INFO - 38809629 is not following now, 265 following remains.
#  2018-05-11 08:39:22,474 - INFO - Now run the 136 time.
#  2018-05-11 08:39:27,595 - INFO - 10016349 is not following now, 264 following remains.
#  2018-05-11 08:39:27,595 - INFO - Now run the 137 time.
#  2018-05-11 08:39:32,697 - INFO - 42668122 is not following now, 263 following remains.
#  2018-05-11 08:39:32,698 - INFO - Now run the 138 time.
#  2018-05-11 08:39:37,803 - INFO - 5614640 is not following now, 262 following remains.
#  2018-05-11 08:39:37,804 - INFO - Now run the 139 time.
#  2018-05-11 08:39:42,893 - INFO - 20247239 is not following now, 261 following remains.
#  2018-05-11 08:39:42,895 - INFO - Now run the 140 time.
#  2018-05-11 08:39:48,029 - INFO - 9156140 is not following now, 260 following remains.
#  2018-05-11 08:39:48,030 - INFO - Now run the 141 time.
#  2018-05-11 08:39:53,148 - INFO - 6138360 is not following now, 259 following remains.
#  2018-05-11 08:39:53,149 - INFO - Now run the 142 time.
#  2018-05-11 08:39:58,262 - INFO - 6280187 is not following now, 258 following remains.
#  2018-05-11 08:39:58,263 - INFO - Now run the 143 time.
#  2018-05-11 08:40:03,395 - INFO - 31245074 is not following now, 257 following remains.
#  2018-05-11 08:40:03,397 - INFO - Now run the 144 time.
#  2018-05-11 08:40:08,519 - INFO - 42876028 is not following now, 256 following remains.
#  2018-05-11 08:40:08,520 - INFO - Now run the 145 time.
#  2018-05-11 08:40:13,625 - INFO - 7292002 is not following now, 255 following remains.
#  2018-05-11 08:40:13,625 - INFO - Now run the 146 time.
#  2018-05-11 08:40:18,718 - INFO - 17987597 is not following now, 254 following remains.
#  2018-05-11 08:40:18,720 - INFO - Now run the 147 time.
#  2018-05-11 08:40:23,854 - INFO - 41207384 is not following now, 253 following remains.
#  2018-05-11 08:40:23,854 - INFO - Now run the 148 time.
#  2018-05-11 08:40:28,946 - INFO - 6323545 is not following now, 252 following remains.
#  2018-05-11 08:40:28,947 - INFO - Now run the 149 time.
#  2018-05-11 08:40:34,065 - INFO - 7825786 is not following now, 251 following remains.
#  2018-05-11 08:40:34,065 - INFO - Now run the 150 time.
#  2018-05-11 08:40:39,156 - INFO - 7503662 is not following now, 250 following remains.
#  2018-05-11 08:40:39,158 - INFO - Now run the 151 time.
#  2018-05-11 08:40:44,279 - INFO - 3545153 is not following now, 249 following remains.
#  2018-05-11 08:40:44,280 - INFO - Now run the 152 time.
#  2018-05-11 08:40:49,413 - INFO - 7076649 is not following now, 248 following remains.
#  2018-05-11 08:40:49,414 - INFO - Now run the 153 time.
#  2018-05-11 08:40:54,535 - INFO - 4995747 is not following now, 247 following remains.
#  2018-05-11 08:40:54,536 - INFO - Now run the 154 time.
#  2018-05-11 08:40:59,638 - INFO - 2037519 is not following now, 246 following remains.
#  2018-05-11 08:40:59,639 - INFO - Now run the 155 time.
#  2018-05-11 08:41:04,738 - INFO - 23651366 is not following now, 245 following remains.
#  2018-05-11 08:41:04,740 - INFO - Now run the 156 time.
#  2018-05-11 08:41:09,866 - INFO - 10729875 is not following now, 244 following remains.
#  2018-05-11 08:41:09,868 - INFO - Now run the 157 time.
#  2018-05-11 08:41:14,997 - INFO - 41100748 is not following now, 243 following remains.
#  2018-05-11 08:41:14,998 - INFO - Now run the 158 time.
#  2018-05-11 08:41:20,101 - INFO - 2919951 is not following now, 242 following remains.
#  2018-05-11 08:41:20,101 - INFO - Now run the 159 time.
#  2018-05-11 08:41:25,204 - INFO - 14028166 is not following now, 241 following remains.
#  2018-05-11 08:41:25,206 - INFO - Now run the 160 time.
#  2018-05-11 08:41:30,326 - INFO - 14505762 is not following now, 240 following remains.
#  2018-05-11 08:41:30,327 - INFO - Now run the 161 time.
#  2018-05-11 08:41:35,429 - INFO - 13046240 is not following now, 239 following remains.
#  2018-05-11 08:41:35,429 - INFO - Now run the 162 time.
#  2018-05-11 08:41:40,520 - INFO - 42805642 is not following now, 238 following remains.
#  2018-05-11 08:41:40,521 - INFO - Now run the 163 time.
#  2018-05-11 08:41:45,653 - INFO - 10957110 is not following now, 237 following remains.
#  2018-05-11 08:41:45,653 - INFO - Now run the 164 time.
#  2018-05-11 08:41:50,743 - INFO - 3146215 is not following now, 236 following remains.
#  2018-05-11 08:41:50,745 - INFO - Now run the 165 time.
#  2018-05-11 08:41:55,874 - INFO - 1168203 is not following now, 235 following remains.
#  2018-05-11 08:41:55,875 - INFO - Now run the 166 time.
#  2018-05-11 08:42:00,967 - INFO - 10629577 is not following now, 234 following remains.
#  2018-05-11 08:42:00,968 - INFO - Now run the 167 time.
#  2018-05-11 08:42:06,051 - INFO - 14072240 is not following now, 233 following remains.
#  2018-05-11 08:42:06,052 - INFO - Now run the 168 time.
#  2018-05-11 08:42:11,154 - INFO - 5165133 is not following now, 232 following remains.
#  2018-05-11 08:42:11,155 - INFO - Now run the 169 time.
#  2018-05-11 08:42:16,276 - INFO - 13600624 is not following now, 231 following remains.
#  2018-05-11 08:42:16,277 - INFO - Now run the 170 time.
#  2018-05-11 08:42:21,378 - INFO - 8889170 is not following now, 230 following remains.
#  2018-05-11 08:42:21,380 - INFO - Now run the 171 time.
#  2018-05-11 08:42:26,535 - INFO - 587613 is not following now, 229 following remains.
#  2018-05-11 08:42:26,536 - INFO - Now run the 172 time.
#  2018-05-11 08:42:31,624 - INFO - 35386739 is not following now, 228 following remains.
#  2018-05-11 08:42:31,625 - INFO - Now run the 173 time.
#  2018-05-11 08:42:36,745 - INFO - 580785 is not following now, 227 following remains.
#  2018-05-11 08:42:36,746 - INFO - Now run the 174 time.
#  2018-05-11 08:42:41,833 - INFO - 9360629 is not following now, 226 following remains.
#  2018-05-11 08:42:41,834 - INFO - Now run the 175 time.
#  2018-05-11 08:42:46,934 - INFO - 10669300 is not following now, 225 following remains.
#  2018-05-11 08:42:46,935 - INFO - Now run the 176 time.
#  2018-05-11 08:42:52,060 - INFO - 42594010 is not following now, 224 following remains.
#  2018-05-11 08:42:52,061 - INFO - Now run the 177 time.
#  2018-05-11 08:42:57,142 - INFO - 16669578 is not following now, 223 following remains.
#  2018-05-11 08:42:57,142 - INFO - Now run the 178 time.
#  2018-05-11 08:43:02,229 - INFO - 2887138 is not following now, 222 following remains.
#  2018-05-11 08:43:02,230 - INFO - Now run the 179 time.
#  2018-05-11 08:43:07,352 - INFO - 10614879 is not following now, 221 following remains.
#  2018-05-11 08:43:07,353 - INFO - Now run the 180 time.
#  2018-05-11 08:43:12,469 - INFO - 5707962 is not following now, 220 following remains.
#  2018-05-11 08:43:12,469 - INFO - Now run the 181 time.
#  2018-05-11 08:43:17,591 - INFO - 3474265 is not following now, 219 following remains.
#  2018-05-11 08:43:17,592 - INFO - Now run the 182 time.
#  2018-05-11 08:43:22,674 - INFO - 15023052 is not following now, 218 following remains.
#  2018-05-11 08:43:22,676 - INFO - Now run the 183 time.
#  2018-05-11 08:43:27,798 - INFO - 31307305 is not following now, 217 following remains.
#  2018-05-11 08:43:27,798 - INFO - Now run the 184 time.
#  2018-05-11 08:43:32,886 - INFO - 42031159 is not following now, 216 following remains.
#  2018-05-11 08:43:32,887 - INFO - Now run the 185 time.
#  2018-05-11 08:43:38,008 - INFO - 1935618 is not following now, 215 following remains.
#  2018-05-11 08:43:38,009 - INFO - Now run the 186 time.
#  2018-05-11 08:43:43,136 - INFO - 7429040 is not following now, 214 following remains.
#  2018-05-11 08:43:43,138 - INFO - Now run the 187 time.
#  2018-05-11 08:43:48,247 - INFO - 38655791 is not following now, 213 following remains.
#  2018-05-11 08:43:48,247 - INFO - Now run the 188 time.
#  2018-05-11 08:43:53,333 - INFO - 16039134 is not following now, 212 following remains.
#  2018-05-11 08:43:53,335 - INFO - Now run the 189 time.
#  2018-05-11 08:43:58,471 - INFO - 20846983 is not following now, 211 following remains.
#  2018-05-11 08:43:58,472 - INFO - Now run the 190 time.
#  2018-05-11 08:44:03,575 - INFO - 3542476 is not following now, 210 following remains.
#  2018-05-11 08:44:03,575 - INFO - Now run the 191 time.
#  2018-05-11 08:44:08,695 - INFO - 6050417 is not following now, 209 following remains.
#  2018-05-11 08:44:08,695 - INFO - Now run the 192 time.
#  2018-05-11 08:44:13,799 - INFO - 10631190 is not following now, 208 following remains.
#  2018-05-11 08:44:13,800 - INFO - Now run the 193 time.
#  2018-05-11 08:44:18,902 - INFO - 9031858 is not following now, 207 following remains.
#  2018-05-11 08:44:18,903 - INFO - Now run the 194 time.
#  2018-05-11 08:44:24,024 - INFO - 26727106 is not following now, 206 following remains.
#  2018-05-11 08:44:24,024 - INFO - Now run the 195 time.
#  2018-05-11 08:44:29,109 - INFO - 3506291 is not following now, 205 following remains.
#  2018-05-11 08:44:29,110 - INFO - Now run the 196 time.
#  2018-05-11 08:44:34,230 - INFO - 14216079 is not following now, 204 following remains.
#  2018-05-11 08:44:34,231 - INFO - Now run the 197 time.
#  2018-05-11 08:44:39,333 - INFO - 25168456 is not following now, 203 following remains.
#  2018-05-11 08:44:39,334 - INFO - Now run the 198 time.
#  2018-05-11 08:44:44,454 - INFO - 42950142 is not following now, 202 following remains.
#  2018-05-11 08:44:44,455 - INFO - Now run the 199 time.
#  2018-05-11 08:44:49,543 - INFO - 2710341 is not following now, 201 following remains.
#  2018-05-11 08:44:49,545 - INFO - Now run the 200 time.
#  2018-05-11 08:44:54,678 - INFO - 24800774 is not following now, 200 following remains.
#  2018-05-11 08:44:54,678 - INFO - Now run the 201 time.
#  2018-05-11 08:44:59,769 - INFO - 3771608 is not following now, 199 following remains.
#  2018-05-11 08:44:59,769 - INFO - Now run the 202 time.
#  2018-05-11 08:45:04,854 - INFO - 39691954 is not following now, 198 following remains.
#  2018-05-11 08:45:04,854 - INFO - Now run the 203 time.
#  2018-05-11 08:45:09,941 - INFO - 16681571 is not following now, 197 following remains.
#  2018-05-11 08:45:09,942 - INFO - Now run the 204 time.
#  2018-05-11 08:45:15,043 - INFO - 42487347 is not following now, 196 following remains.
#  2018-05-11 08:45:15,044 - INFO - Now run the 205 time.
#  2018-05-11 08:45:20,133 - INFO - 38777998 is not following now, 195 following remains.
#  2018-05-11 08:45:20,134 - INFO - Now run the 206 time.
#  2018-05-11 08:45:25,252 - INFO - 22559969 is not following now, 194 following remains.
#  2018-05-11 08:45:25,252 - INFO - Now run the 207 time.
#  2018-05-11 08:45:30,342 - INFO - 5109552 is not following now, 193 following remains.
#  2018-05-11 08:45:30,343 - INFO - Now run the 208 time.
#  2018-05-11 08:45:35,442 - INFO - 12502139 is not following now, 192 following remains.
#  2018-05-11 08:45:35,444 - INFO - Now run the 209 time.
#  2018-05-11 08:45:40,563 - INFO - 18882321 is not following now, 191 following remains.
#  2018-05-11 08:45:40,563 - INFO - Now run the 210 time.
#  2018-05-11 08:45:45,668 - INFO - 9455458 is not following now, 190 following remains.
#  2018-05-11 08:45:45,669 - INFO - Now run the 211 time.
#  2018-05-11 08:45:50,755 - INFO - 3502546 is not following now, 189 following remains.
#  2018-05-11 08:45:50,756 - INFO - Now run the 212 time.
#  2018-05-11 08:45:55,889 - INFO - 4099674 is not following now, 188 following remains.
#  2018-05-11 08:45:55,890 - INFO - Now run the 213 time.
#  2018-05-11 08:46:01,013 - INFO - 21140829 is not following now, 187 following remains.
#  2018-05-11 08:46:01,015 - INFO - Now run the 214 time.
#  2018-05-11 08:46:06,149 - INFO - 11018211 is not following now, 186 following remains.
#  2018-05-11 08:46:06,149 - INFO - Now run the 215 time.
#  2018-05-11 08:46:11,253 - INFO - 10306524 is not following now, 185 following remains.
#  2018-05-11 08:46:11,254 - INFO - Now run the 216 time.
#  2018-05-11 08:46:16,372 - INFO - 3011919 is not following now, 184 following remains.
#  2018-05-11 08:46:16,373 - INFO - Now run the 217 time.
#  2018-05-11 08:46:21,493 - INFO - 9218838 is not following now, 183 following remains.
#  2018-05-11 08:46:21,495 - INFO - Now run the 218 time.
#  2018-05-11 08:46:26,630 - INFO - 11408208 is not following now, 182 following remains.
#  2018-05-11 08:46:26,630 - INFO - Now run the 219 time.
#  2018-05-11 08:46:31,737 - INFO - 24122472 is not following now, 181 following remains.
#  2018-05-11 08:46:31,739 - INFO - Now run the 220 time.
#  2018-05-11 08:46:37,157 - INFO - 10725506 is not following now, 180 following remains.
#  2018-05-11 08:46:37,157 - INFO - Now run the 221 time.
#  2018-05-11 08:46:42,247 - INFO - 5501428 is not following now, 179 following remains.
#  2018-05-11 08:46:42,248 - INFO - Now run the 222 time.
#  2018-05-11 08:46:47,340 - INFO - 140680 is not following now, 178 following remains.
#  2018-05-11 08:46:47,342 - INFO - Now run the 223 time.
#  2018-05-11 08:46:52,478 - INFO - 26995724 is not following now, 177 following remains.
#  2018-05-11 08:46:52,479 - INFO - Now run the 224 time.
#  2018-05-11 08:46:57,615 - INFO - 6661114 is not following now, 176 following remains.
#  2018-05-11 08:46:57,615 - INFO - Now run the 225 time.
#  2018-05-11 08:47:02,724 - INFO - 16494192 is not following now, 175 following remains.
#  2018-05-11 08:47:02,724 - INFO - Now run the 226 time.
#  2018-05-11 08:47:07,845 - INFO - 5437038 is not following now, 174 following remains.
#  2018-05-11 08:47:07,845 - INFO - Now run the 227 time.
