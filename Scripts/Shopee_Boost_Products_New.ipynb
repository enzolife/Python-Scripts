# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time
import datetime
import logging
import os

import random

# %%
# Date
today_date = datetime.date.today() + datetime.timedelta(days=0)
yesterday_date = datetime.date.today() + datetime.timedelta(days=-1)
seven_days_before_date = datetime.date.today() + datetime.timedelta(days=-7)

today_date_string = today_date.strftime('%Y_%m_%d')

# %%
log_file_name = 'shopee_add_and_cancel_fans_log\\shopee_add_and_cancel_fans_log_' + today_date_string + '.txt'

# logging.basicConfig(filename=log_file_name, level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# 屏幕最大化，且指定下载目录
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

prefs = {"profile.default_content_settings.popups": 0,
         "directory_upgrade": True}
options.add_experimental_option("prefs", prefs)

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
# browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
# 所需参数
# 站点；站点后缀；账户；密码；站点top卖家shopid；top卖家username（方便识别）
shop_list = [['tw', 'tw', 23070969, 'poweradapter.tw', 'kuangyiqiao1991', 9469128, 'alonso.tw'],
             ['tw', 'tw', 25482220, 'tengus.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 58707738, 'qianjiaozi', 'qianjiaozi888', 26513957, 'beibei.tw'],
             ['tw', 'tw', 66377809, 'qianjiaozi1', 'qianjiaozi888', 23068230, 'iu.tw'],
             ['tw', 'tw', 62416366, 'tengus1.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 62416544, 'tengus2.tw', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 63534861, 'qianjiaozitw1', 'tengus1803', 23068230, 'iu.tw'],
             ['tw', 'tw', 62887142, 'yilanlu.tw', 'yilanlu888', 23481977, 'huoyi.tw'],
             ['my', 'com.my', 53580963, 'qianjiaozi.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 59848325, 'tengus.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 62418141, 'tengus1.my', 'tengus1803', 10891137, 'winners.my'],
             ['my', 'com.my', 62418493, 'tengus2.my', 'tengus1803', 10891137, 'winners.my'],
             ['id', 'co.id', 59846508, 'tengus.id', 'tengus1803', 28135012, 'sunnyfun.id'],
             ['id', 'co.id', 62417386, 'tengus1.id', 'tengus1803', 28135012, 'sunnyfun.id'],
             ['id', 'co.id', 62417551, 'tengus2.id', 'tengus1803', 28135012, 'sunnyfun.id']
            ]

# %%
# 转换为dataframe
shop_df_columns = ['site', 'site_suffix', 'shopid', 'acc', 'pwd', 'top_shop_id', 'top_shop_username']
shop_df = pd.DataFrame(shop_list, columns=shop_df_columns)

# %%
# 商品置顶函数
def boost_product(site, site_suffix, shopid, acc, pwd):
    # 打开浏览器
    logging.info('Open the browser.')
    browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)
    
    # main page
    main_page_url = "http://shopee." + site_suffix
    browser.get(main_page_url)
    time.sleep(10)
    
    # remove ads, refresh again
    browser.get(main_page_url)
    time.sleep(10)

    # if the shop is on my site, should press the button to choose language
    if site == 'my':
        language_selector = browser.find_elements_by_css_selector('.shopee-button-outline.shopee-button-outline--primary-reverse')
        language_selector[2].click()
        logging.info('Choose Chinese as language.')
        time.sleep(10)
    
    # login
    logging.info('Start to login.')
    LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
    
    # 点击登入，弹出账户密码输入框
    LoginElem[1].click()
    time.sleep(10)
    
    # 输入
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    try:
        acc_password_input_elem[0].click()
        acc_password_input_elem[0].send_keys(acc)
        acc_password_input_elem[1].click()
        acc_password_input_elem[1].send_keys(pwd)
    except:
        time.sleep(30)
        acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
        acc_password_input_elem[0].click()
        acc_password_input_elem[0].send_keys(acc)
        acc_password_input_elem[1].click()
        acc_password_input_elem[1].send_keys(pwd)
    time.sleep(10)
    
    # 点击提交
    Login_button_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
    Login_button_elem[0].click()
    time.sleep(10)
    
    # switch to my seller center
    logging.info('Switch to my seller center.')
    seller_center_main_page = 'https://seller.shopee.' + site_suffix
    browser.get(seller_center_main_page)
    time.sleep(10)
    
    # my products page
    logging.info('Switch to my products page')
    my_products = browser.find_elements_by_css_selector('.home-big-button__title')
    my_products[0].click()
    time.sleep(10)
    
    # product boost
    try:
        my_products_boost = browser.find_elements_by_css_selector('.shopee-button.shopee-button--inactive.shopee-button--frameless.shopee-button--medium.ember-view')
        logging.info('There are ' + str(len(my_products_boost)) + ' products can be boosted on the product list page.')
        # random select 5 products to boost and sort ascending
        random_num_list = random.sample(range(0, len(my_products_boost)-1), 5)
        logging.info('Product # ' + str(random_num_list) + ' will be boosted.')
        
        for index, random_num in enumerate(random_num_list):
            try:
                # use location_once_scrolled_into_view to locate the element location
                my_products_boost[random_num].location_once_scrolled_into_view
                my_products_boost[random_num].click()
                logging.info('Boost ' + str(index + 1) + ' product.')
            except Exception as err:
                logging.warning('An exception occurred: ' + str(err))
        logging.info('Product Boost is completed.')
    except Exception as err:
        logging.warning('An exception occurred: ' + str(err))
    
    # 关闭
    browser.quit()

# %%
# 历遍所有shop
for index, my_shop in shop_df.iterrows():
    site = my_shop[0]
    site_suffix = my_shop[1]
    shopid = my_shop[2]
    acc = my_shop[3]
    pwd = my_shop[4]
    
    # 执行
    try:
        logging.info('Now it\'s running the script on ' + acc + '.')
        boost_product(site, site_suffix, shopid, acc, pwd)
        logging.info('Finished running the script on ' + acc + '.')
    except Exception as err:
        logging.warning('An exception occurred: ' + str(err) + '.')
# Out:
# 2018-05-19 15:25:15,655 - INFO - Now it's running the script on poweradapter.tw.
# 2018-05-19 15:25:15,656 - INFO - Open the browser.
# 2018-05-19 15:26:13,894 - INFO - Start to login.
# 2018-05-19 15:26:44,538 - INFO - Switch to my seller center.
# 2018-05-19 15:27:09,691 - INFO - Switch to my products page
# 2018-05-19 15:27:19,827 - INFO - There are 22 products can be boosted on the product list page.
# 2018-05-19 15:27:19,828 - INFO - Product # [15, 12, 9, 6, 3] will be boosted.
# 2018-05-19 15:27:19,942 - INFO - Boost 1 product.
# 2018-05-19 15:27:20,024 - INFO - Boost 2 product.
# 2018-05-19 15:27:20,120 - INFO - Boost 3 product.
# 2018-05-19 15:27:20,127 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:27:20,133 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:27:20,134 - INFO - Product Boost is completed.
# 2018-05-19 15:27:23,202 - INFO - Finished running the script on poweradapter.tw.
# 2018-05-19 15:27:23,203 - INFO - Now it's running the script on tengus.tw.
# 2018-05-19 15:27:23,204 - INFO - Open the browser.
# 2018-05-19 15:28:18,625 - INFO - Start to login.
# 2018-05-19 15:28:49,200 - INFO - Switch to my seller center.
# 2018-05-19 15:29:13,265 - INFO - Switch to my products page
# 2018-05-19 15:29:23,405 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:29:23,405 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:29:26,485 - INFO - Finished running the script on tengus.tw.
# 2018-05-19 15:29:26,486 - INFO - Now it's running the script on qianjiaozi.
# 2018-05-19 15:29:26,487 - INFO - Open the browser.
# 2018-05-19 15:30:38,414 - INFO - Start to login.
# 2018-05-19 15:31:08,950 - INFO - Switch to my seller center.
# 2018-05-19 15:31:35,576 - INFO - Switch to my products page
# 2018-05-19 15:31:48,695 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:31:48,695 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:31:51,756 - INFO - Finished running the script on qianjiaozi.
# 2018-05-19 15:31:51,759 - INFO - Now it's running the script on qianjiaozi1.
# 2018-05-19 15:31:51,760 - INFO - Open the browser.
# 2018-05-19 15:33:03,527 - INFO - Start to login.
# 2018-05-19 15:33:34,211 - INFO - Switch to my seller center.
# 2018-05-19 15:33:59,980 - INFO - Switch to my products page
# 2018-05-19 15:34:10,120 - INFO - There are 21 products can be boosted on the product list page.
# 2018-05-19 15:34:10,121 - INFO - Product # [1, 5, 8, 13, 16] will be boosted.
# 2018-05-19 15:34:10,218 - INFO - Boost 1 product.
# 2018-05-19 15:34:10,304 - INFO - Boost 2 product.
# 2018-05-19 15:34:10,311 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:34:10,319 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:34:10,327 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:34:10,327 - INFO - Product Boost is completed.
# 2018-05-19 15:34:13,402 - INFO - Finished running the script on qianjiaozi1.
# 2018-05-19 15:34:13,403 - INFO - Now it's running the script on tengus1.tw.
# 2018-05-19 15:34:13,404 - INFO - Open the browser.
# 2018-05-19 15:35:06,313 - INFO - Start to login.
# 2018-05-19 15:35:36,912 - INFO - Switch to my seller center.
# 2018-05-19 15:36:02,765 - INFO - Switch to my products page
# 2018-05-19 15:36:12,921 - INFO - There are 22 products can be boosted on the product list page.
# 2018-05-19 15:36:12,922 - INFO - Product # [17, 2, 20, 18, 3] will be boosted.
# 2018-05-19 15:36:13,162 - INFO - Boost 1 product.
# 2018-05-19 15:36:13,232 - WARNING - An exception occurred: Message: unknown error: Element <div id="ember3986" class="shopee-button shopee-button--inactive shopee-button--frameless shopee-button--medium ember-view">...</div> is not clickable at point (1092, 12). Other element would receive the click: <div class="text">...</div>
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:36:13,318 - INFO - Boost 3 product.
# 2018-05-19 15:36:13,417 - INFO - Boost 4 product.
# 2018-05-19 15:36:13,426 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:36:13,426 - INFO - Product Boost is completed.
# 2018-05-19 15:36:16,486 - INFO - Finished running the script on tengus1.tw.
# 2018-05-19 15:36:16,487 - INFO - Now it's running the script on tengus2.tw.
# 2018-05-19 15:36:16,488 - INFO - Open the browser.
# 2018-05-19 15:37:27,490 - INFO - Start to login.
# 2018-05-19 15:37:58,037 - INFO - Switch to my seller center.
# 2018-05-19 15:38:22,858 - INFO - Switch to my products page
# 2018-05-19 15:38:33,005 - INFO - There are 21 products can be boosted on the product list page.
# 2018-05-19 15:38:33,006 - INFO - Product # [6, 16, 3, 17, 11] will be boosted.
# 2018-05-19 15:38:33,112 - INFO - Boost 1 product.
# 2018-05-19 15:38:33,248 - INFO - Boost 2 product.
# 2018-05-19 15:38:33,255 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:38:33,262 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:38:33,268 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:38:33,268 - INFO - Product Boost is completed.
# 2018-05-19 15:38:36,338 - INFO - Finished running the script on tengus2.tw.
# 2018-05-19 15:38:36,339 - INFO - Now it's running the script on qianjiaozitw1.
# 2018-05-19 15:38:36,340 - INFO - Open the browser.
# 2018-05-19 15:39:47,163 - INFO - Start to login.
# 2018-05-19 15:40:17,792 - INFO - Switch to my seller center.
# 2018-05-19 15:40:46,978 - INFO - Switch to my products page
# 2018-05-19 15:40:57,100 - INFO - There are 20 products can be boosted on the product list page.
# 2018-05-19 15:40:57,101 - INFO - Product # [15, 5, 0, 10, 17] will be boosted.
# 2018-05-19 15:40:57,262 - INFO - Boost 1 product.
# 2018-05-19 15:40:57,268 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:40:57,275 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:40:57,283 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:40:57,291 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:40:57,291 - INFO - Product Boost is completed.
# 2018-05-19 15:41:00,351 - INFO - Finished running the script on qianjiaozitw1.
# 2018-05-19 15:41:00,351 - INFO - Now it's running the script on yilanlu.tw.
# 2018-05-19 15:41:00,352 - INFO - Open the browser.
# 2018-05-19 15:42:10,716 - INFO - Start to login.
# 2018-05-19 15:42:41,318 - INFO - Switch to my seller center.
# 2018-05-19 15:43:07,203 - INFO - Switch to my products page
# 2018-05-19 15:43:17,351 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:43:17,352 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:43:20,424 - INFO - Finished running the script on yilanlu.tw.
# 2018-05-19 15:43:20,425 - INFO - Now it's running the script on qianjiaozi.my.
# 2018-05-19 15:43:20,426 - INFO - Open the browser.
# 2018-05-19 15:44:52,439 - INFO - Choose Chinese as language.
# 2018-05-19 15:45:02,441 - INFO - Start to login.
# 2018-05-19 15:45:33,120 - INFO - Switch to my seller center.
# 2018-05-19 15:45:57,606 - INFO - Switch to my products page
# 2018-05-19 15:46:07,720 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:46:07,720 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:46:10,802 - INFO - Finished running the script on qianjiaozi.my.
# 2018-05-19 15:46:10,803 - INFO - Now it's running the script on tengus.my.
# 2018-05-19 15:46:10,804 - INFO - Open the browser.
# 2018-05-19 15:47:44,529 - INFO - Choose Chinese as language.
# 2018-05-19 15:47:54,532 - INFO - Start to login.
# 2018-05-19 15:48:25,154 - INFO - Switch to my seller center.
# 2018-05-19 15:48:49,818 - INFO - Switch to my products page
# 2018-05-19 15:49:00,004 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:49:00,004 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:49:03,065 - INFO - Finished running the script on tengus.my.
# 2018-05-19 15:49:03,066 - INFO - Now it's running the script on tengus1.my.
# 2018-05-19 15:49:03,066 - INFO - Open the browser.
# 2018-05-19 15:50:03,058 - INFO - Choose Chinese as language.
# 2018-05-19 15:50:13,060 - INFO - Start to login.
# 2018-05-19 15:50:43,684 - INFO - Switch to my seller center.
# 2018-05-19 15:51:08,199 - INFO - Switch to my products page
# 2018-05-19 15:51:18,320 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:51:18,321 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:51:21,387 - INFO - Finished running the script on tengus1.my.
# 2018-05-19 15:51:21,388 - INFO - Now it's running the script on tengus2.my.
# 2018-05-19 15:51:21,388 - INFO - Open the browser.
# 2018-05-19 15:52:54,522 - INFO - Choose Chinese as language.
# 2018-05-19 15:53:04,522 - INFO - Start to login.
# 2018-05-19 15:53:35,192 - INFO - Switch to my seller center.
# 2018-05-19 15:53:59,691 - INFO - Switch to my products page
# 2018-05-19 15:54:09,811 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:54:09,811 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:54:12,880 - INFO - Finished running the script on tengus2.my.
# 2018-05-19 15:54:12,881 - INFO - Now it's running the script on tengus.id.
# 2018-05-19 15:54:12,882 - INFO - Open the browser.
# 2018-05-19 15:55:24,449 - INFO - Start to login.
# 2018-05-19 15:55:55,024 - INFO - Switch to my seller center.
# 2018-05-19 15:56:20,307 - INFO - Switch to my products page
# 2018-05-19 15:56:30,437 - INFO - There are 23 products can be boosted on the product list page.
# 2018-05-19 15:56:30,438 - INFO - Product # [14, 5, 4, 16, 3] will be boosted.
# 2018-05-19 15:56:30,563 - INFO - Boost 1 product.
# 2018-05-19 15:56:30,639 - INFO - Boost 2 product.
# 2018-05-19 15:56:30,724 - INFO - Boost 3 product.
# 2018-05-19 15:56:30,822 - INFO - Boost 4 product.
# 2018-05-19 15:56:30,828 - WARNING - An exception occurred: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=66.0.3359.117)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.16299 x86_64)
#
# 2018-05-19 15:56:30,829 - INFO - Product Boost is completed.
# 2018-05-19 15:56:33,894 - INFO - Finished running the script on tengus.id.
# 2018-05-19 15:56:33,895 - INFO - Now it's running the script on tengus1.id.
# 2018-05-19 15:56:33,896 - INFO - Open the browser.
# 2018-05-19 15:57:47,130 - INFO - Start to login.
# 2018-05-19 15:58:17,782 - INFO - Switch to my seller center.
# 2018-05-19 15:58:43,395 - INFO - Switch to my products page
# 2018-05-19 15:58:53,547 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 15:58:53,548 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 15:58:56,631 - INFO - Finished running the script on tengus1.id.
# 2018-05-19 15:58:56,632 - INFO - Now it's running the script on tengus2.id.
# 2018-05-19 15:58:56,633 - INFO - Open the browser.
# 2018-05-19 16:00:08,289 - INFO - Start to login.
# 2018-05-19 16:00:38,823 - INFO - Switch to my seller center.
# 2018-05-19 16:01:03,628 - INFO - Switch to my products page
# 2018-05-19 16:01:13,746 - INFO - There are 0 products can be boosted on the product list page.
# 2018-05-19 16:01:13,747 - WARNING - An exception occurred: Sample larger than population
# 2018-05-19 16:01:16,814 - INFO - Finished running the script on tengus2.id.
