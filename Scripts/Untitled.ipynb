# %%
import pandas as pd
import os
import datetime

# %%
os.chdir("D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\")
os.getcwd()
# Out:
# 'D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12'

# %%
seller_index_path = os.path.join(os.getcwd(), "2016.8.28 Seller Index Data", "seller_index.csv")
seller_index_path
# Out:
# 'D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.8.28 Seller Index Data\\seller_index.csv'

# %%
pwd = os.getcwd()
os.chdir(os.path.dirname(seller_index_path))
seller_index = pd.read_csv(os.path.basename(seller_index_path), index_col=None, header=0, encoding="GB18030")
os.chdir(pwd)
seller_index.head()
# Out:
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 1  Avg Daily Orders MTD Child Account Name  \
# 0           0  2018-01-05                   NaN                NaN
# 1           1         NaN                   0.0         mioshop.id
# 2           2         NaN                   0.0       rosegoods.id
# 3           3         NaN                   0.0           moily.id
# 4           4         NaN                   0.0      myrongoods.id
#
#   Child Account Owner Child Account Record Type  Child ShopID  Child UserID  \
# 0                 NaN                       NaN           NaN           NaN
# 1           Vicky Liu                     RM-ID    50929356.0    50930744.0
# 2           Vicky Liu                     RM-ID    50929419.0    50930807.0
# ...

# %%
seller_index.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Avg Daily Orders MTD',
#  'Child Account Name',
#  'Child Account Owner',
#  'Child Account Record Type',
#  'Child ShopID',
#  'Child UserID',
#  'Date Transferred From Onboarding Team',
#  'GP Account ID',
#  'GP Account Lead Name',
#  'GP Account Lead Size',
#  'GP Account Name',
#  'GP Account Owner',
#  'GP Account Seller Classification',
#  'GP Account Shopee Account Created Date',
#  'GP Date Transferred From Onboarding Team',
#  'Shopee Account Created Date',
#  'primary category']

# %%
lead_index_path = os.path.join(os.getcwd(), "2017.8.11 Lead Index Data", "lead_index.csv")
lead_index_path
# Out:
# 'D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2017.8.11 Lead Index Data\\lead_index.csv'

# %%
pwd = os.getcwd()
os.chdir(os.path.dirname(lead_index_path))
lead_index = pd.read_csv(os.path.basename(lead_index_path), index_col=None, header=0, encoding="GB18030")
os.chdir(pwd)
lead_index.head()
# Out:
# C:\Users\Enzo.kuang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 1  Average Sales Cycle Average Unit Price  \
# 0           0         NaN                  NaN                NaN
# 1           1         NaN                  NaN                NaN
# 2           2         NaN                  NaN                NaN
# 3           3         NaN                  NaN                NaN
# 4           4         NaN                  NaN                NaN
#
#   Average Unit Price Currency Business License Number City Claimed Date  \
# 0                         NaN                     NaN  NaN          NaN
# 1                         NaN                     NaN  NaN          NaN
# 2                         NaN                     NaN  NaN          NaN
# ...

# %%
lead_index.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Average Sales Cycle',
#  'Average Unit Price',
#  'Average Unit Price Currency',
#  'Business License Number',
#  'City',
#  'Claimed Date',
#  'Company Size',
#  'Date Transferred to Onboarding Queue',
#  'Date of Status Changed From Open',
#  'Experience',
#  'Key Brands 1',
#  'Lead Gen',
#  'Lead Size',
#  'Lead Source Details',
#  'Lead Status',
#  'Office Province',
#  'Open Lead Duration',
#  'Primary Category',
#  'Reason for Junk Lead',
#  'SKU Potential',
#  'Sales Lead: Created Date',
#  'Sales Lead: ID',
#  'Sales Lead: Lead Name',
#  'Sales Lead: Owner Name',
#  'Second Category',
#  'Seller Attribute',
#  'Seller Classification',
#  'Shipping City',
#  'Shipping Province',
#  'Source',
#  'Storefront URL',
#  'Total Daily Orders on All Platforms',
#  'Updated on']

# %%
lead_group = lead_index['Sales Lead: ID'].groupby(lead_index['Sales Lead: Owner Name']).count()
lead_group
# Out:
# Sales Lead: Owner Name
# Alex Dong                                    557
# Alice Huang                                  424
# Andrea Ke                                      4
# Anita Xiao                                   164
# Bella Liu                                     63
# BiYuan Li                                    138
# Bin Li                                        11
# Boey Peng                                    148
# CB - Leads for On Boarding Team               25
# CB - Leads for On Boarding Team(SH Team)      18
# Carye Ma                                     502
# Catherine Xian                                71
# Chloe Zeng                                    72
# Christine Tang                               129
# Cindy Jin                                    155
# Cody Xiao                                      1
# Conner Liao                                   11
# Cross Border Leads                           187
# Derek Chen                                     1
# ...

# %%
lead_index['Claimed Date'] = pd.to_datetime(lead_index['Claimed Date'])

start_of_w_2 = datetime.date(2017,12,18)
end_of_w_2 = datetime.date(2017,12,24)

lead_index_claim_date_is_w_2 = lead_index[(lead_index['Claimed Date'] >= start_of_w_2) & (lead_index['Claimed Date'] <= end_of_w_2)]
lead_index_claim_date_is_w_2.head()
# Out:
#       Unnamed: 0  Unnamed: 1  Average Sales Cycle Average Unit Price  \
# 1406        1406         NaN                  NaN                5.0
# 1473        1473         NaN                  NaN               10.0
# 2170        2170         NaN                  NaN               13.0
# 3547        3547         NaN                  NaN               50.0
# 3676        3676         NaN                  NaN               50.0
#
#      Average Unit Price Currency Business License Number      City  \
# 1406                         USD      91350524156349401B      Anxi
# 1473                         USD      91440300683793862W  Shenzhen
# 2170                         USD      91440300359873043G  Shenzhen
# 3547                         USD      91441900617994922G        东莞
# 3676                         USD      91410105MA3X72LXXE        郑州
#
#      Claimed Date Company Size Date Transferred to Onboarding Queue  \
# 1406   2017-12-20        31-50                                  NaN
# ...

# %%
lead_index_claim_date_is_w_2_group = lead_index_claim_date_is_w_2['Sales Lead: ID'].groupby(lead_index_claim_date_is_w_2['Sales Lead: Owner Name']).count()
lead_index_claim_date_is_w_2_group
# Out:
# Sales Lead: Owner Name
# Boey Peng         2
# Chloe Zeng        1
# Ivan Wu           4
# Johnny Chen       1
# Jun Li            6
# Leo Li          188
# Nikki Yu          2
# Ruby Song         1
# Shelly Zhuo       3
# Sun Shona         3
# Tommy So          1
# Vicky Liu         1
# Yedda Chen      141
# Yoyo Zhao         3
# Zheng Kai         2
# vincent wang     42
# wu sherry        74
# Name: Sales Lead: ID, dtype: int64

# %%
lead_index_claim_date_is_w_2 = pd.merge(lead_index_claim_date_is_w_2, seller_index, how='left', left_on=['Sales Lead: Lead Name'], right_on=['GP Account Lead Name'])
lead_index_claim_date_is_w_2.head()
# Out:
#    Unnamed: 0_x  Unnamed: 1_x  Average Sales Cycle Average Unit Price  \
# 0          1406           NaN                  NaN                5.0
# 1          1406           NaN                  NaN                5.0
# 2          1406           NaN                  NaN                5.0
# 3          1406           NaN                  NaN                5.0
# 4          1406           NaN                  NaN                5.0
#
#   Average Unit Price Currency Business License Number  City Claimed Date  \
# 0                         USD      91350524156349401B  Anxi   2017-12-20
# 1                         USD      91350524156349401B  Anxi   2017-12-20
# 2                         USD      91350524156349401B  Anxi   2017-12-20
# 3                         USD      91350524156349401B  Anxi   2017-12-20
# 4                         USD      91350524156349401B  Anxi   2017-12-20
#
#   Company Size Date Transferred to Onboarding Queue          ...           \
# ...

# %%
lead_index_claim_date_is_w_2.columns.tolist()
# Out:
# ['Unnamed: 0_x',
#  'Unnamed: 1_x',
#  'Average Sales Cycle',
#  'Average Unit Price',
#  'Average Unit Price Currency',
#  'Business License Number',
#  'City',
#  'Claimed Date',
#  'Company Size',
#  'Date Transferred to Onboarding Queue',
#  'Date of Status Changed From Open',
#  'Experience',
#  'Key Brands 1',
#  'Lead Gen',
#  'Lead Size',
#  'Lead Source Details',
#  'Lead Status',
#  'Office Province',
#  'Open Lead Duration',
#  'Primary Category',
#  'Reason for Junk Lead',
#  'SKU Potential',
#  'Sales Lead: Created Date',
#  'Sales Lead: ID',
#  'Sales Lead: Lead Name',
#  'Sales Lead: Owner Name',
#  'Second Category',
#  'Seller Attribute',
#  'Seller Classification',
#  'Shipping City',
#  'Shipping Province',
#  'Source',
#  'Storefront URL',
#  'Total Daily Orders on All Platforms',
#  'Updated on',
#  'Unnamed: 0_y',
#  'Unnamed: 1_y',
#  'Avg Daily Orders MTD',
#  'Child Account Name',
#  'Child Account Owner',
#  'Child Account Record Type',
#  'Child ShopID',
# ...

# %%
new_shop_path = os.path.join(os.getcwd(), "2016.8.28 Seller Index Data", "new_shop_index.csv")
new_shop_path
# Out:
# 'D:\\Program Files (x86)\\百度云同步盘\\Dropbox\\Shopee 2016.4.12\\2016.8.28 Seller Index Data\\new_shop_index.csv'

# %%
pwd = os.getcwd()
os.chdir(os.path.dirname(new_shop_path))
new_shop_index = pd.read_csv(os.path.basename(new_shop_path), index_col=None, header=0, encoding="GB18030")
os.chdir(pwd)
new_shop_index.head()
# Out:
#    Unnamed: 0  First  Time Reach     PIC     Shop id         Shop name  \
# 0           0                0.0     Jun  13495361.0        delaman.sg
# 1           1                0.0      Ki  14146522.0  tongtongstore.sg
# 2           2                0.0   Vicky  16909707.0        topshop.sg
# 3           3                0.0  Jolene  17230446.0  beverlymemory.sg
# 4           4                0.0  Joanne  17281849.0     leadingsea.sg
#
#                             Shop url Site Update date
# 0        http://shopee.sg/delaman.sg   SG  2017-08-17
# 1  http://shopee.sg/tongtongstore.sg   SG         NaN
# 2        http://shopee.sg/topshop.sg   SG         NaN
# 3  http://shopee.sg/beverlymemory.sg   SG         NaN
# 4     http://shopee.sg/leadingsea.sg   SG         NaN

# %%
lead_index_claim_date_is_w_2 = pd.merge(lead_index_claim_date_is_w_2, new_shop_index, how='left', left_on=['Child ShopID'], right_on=['Shop id'])
lead_index_claim_date_is_w_2.head()
# Out:
#    Unnamed: 0_x  Unnamed: 1_x  Average Sales Cycle Average Unit Price  \
# 0          1406           NaN                  NaN                5.0
# 1          1406           NaN                  NaN                5.0
# 2          1406           NaN                  NaN                5.0
# 3          1406           NaN                  NaN                5.0
# 4          1406           NaN                  NaN                5.0
#
#   Average Unit Price Currency Business License Number  City Claimed Date  \
# 0                         USD      91350524156349401B  Anxi   2017-12-20
# 1                         USD      91350524156349401B  Anxi   2017-12-20
# 2                         USD      91350524156349401B  Anxi   2017-12-20
# 3                         USD      91350524156349401B  Anxi   2017-12-20
# 4                         USD      91350524156349401B  Anxi   2017-12-20
#
#   Company Size Date Transferred to Onboarding Queue     ...      \
# ...

# %%
lead_index_claim_date_is_w_2['Update date'] = pd.to_datetime(lead_index_claim_date_is_w_2['Update date'])

start_of_w_1 = datetime.date(2017,12,25)
end_of_w_1 = datetime.date(2017,12,31)

lead_index_claim_date_is_w_2_new_shop_is_w_1 = lead_index_claim_date_is_w_2[(lead_index_claim_date_is_w_2['']) & ()]
