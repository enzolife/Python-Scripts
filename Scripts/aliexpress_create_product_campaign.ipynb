# %%
from selenium import webdriver
import pandas as pd
import time
import datetime

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180523限时限量折扣(2)'
campaign_start_date = datetime.datetime(2018, 5, 24, 0, 0)
campaign_end_date = datetime.datetime(2018, 6, 6, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()

# %%
# 点击结束日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-360d8e838554> in <module>()
#       3 campaign_end_date_input[1].click()
#       4 # 选择日期
# ----> 5 browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
#
# IndexError: list index out of range

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2015.2.18 速卖通//2016.11.26 速卖通数据分析//2016.12.18 速卖通商品分析.xlsm"
product_list = pd.read_excel(product_list_path, sheetname='商品分析')
product_list
# Out:
#             商品ID                                               商品标题     平台  \
# 0    32597758635  19V 4.74A 90W Universal Power Adapter Charger ...  TOTAL
# 1    32326661278  19V 4.74A 90W Laptop Universal Power Adapter C...  TOTAL
# 2    32828507962  20V 3.25A 65W Universal USB Type C Laptop Mobi...  TOTAL
# 3    32821187508  20V 4.5A 90W Long Type Laptop Power Adapter Ch...  TOTAL
# 4    32297759407  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 5    32753723716  15V 16V 19V 19.5V 20V Auto Voltage Universal P...  TOTAL
# 6    32298664354  22.5V 1.25A 30W Power Adapter Charger For IRob...  TOTAL
# 7    32695774510  20V 3.25A 65W Power Adapter Travel Charger For...  TOTAL
# 8    32695725619  19V 3.42A 65W Power Adapter For ASUS Zenbook U...  TOTAL
# 9    32484354951  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 10   32487768278  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 11   32299300578  12V 3.33A 40W Laptop AC Power Adapter Charger ...  TOTAL
# 12   32296973236  19.5V 4.62A 90W Ac Power Adapter Charger For D...  TOTAL
# 13   32598772988  12V 2.58A 36W AC Laptop Power Adapter Charger ...  TOTAL
# 14   32297369401  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 15   32464588670  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 16   32297599525  19.5V 4.7A 90W Laptop Ac Power Adapter Charger...  TOTAL
# 17   32365466196  20V 3.25A 65W Ac Laptop Power Adapter Charger ...  TOTAL
# 18   32695681988  12V 2A 24W Laptop Power Adapter For Asus Noteb...  TOTAL
# 19   32298294121  19.5V 2.31A 45W Laptop Ac Power Adapter Charge...  TOTAL
# 20   32820399916  12V 3.6A 45W Light Version Tablet Power Adapte...  TOTAL
# 21   32740349966  20V 3.25A 65W Travel Power Adapter Charger For...  TOTAL
# 22   32298282692  19.5V 3.42A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 23   32598820805  5.2V 2.5A To 3A 18W AC Laptop Power Adapter Ch...  TOTAL
# 24   32462898820  12V 3.6A 45W Laptop Ac Power Adapter Charger F...  TOTAL
# 25   32807609716  20V 4.5A 90W Power Adapter Charger For Lenovo ...  TOTAL
# 26   32484544534  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# 27   32297754126  19.5V 3.33A 65W Ac Power Adapter Charger Carre...  TOTAL
# 28   32696360694  10.5V 3.8A 40W Power Adapter For VGP-AC10V10 A...  TOTAL
# 29   32696396222  19.5V 3.33A 65W Laptop AC Power Adapter For HP...  TOTAL
# ..           ...                                                ...    ...
# 160  32435582916  65W Power Adapter Charger For Lenovo G400 G500...  TOTAL
# 161  32299332366  20V 2A 40W Laptop AC Power Adapter Charger For...  TOTAL
# 162  32344557311  19V 1.58A Laptop AC Power Adapter Charger For ...  TOTAL
# 163  32483805137  19.5V 3.33A 65W AC Laptop Power Adapter Charge...  TOTAL
# 164  32443688412  40W Laptop Ac Power Adapter Charger For Samsun...  TOTAL
# 165  32741840737  12V 3.6A 48W Travel Power Adapter Charger For ...  TOTAL
# 166  32297599553  19V 3.42A 65W Laptop Ac Power Adapter Charger ...  TOTAL
# 167  32441829684  33W Laptop Ac Power Adapter Charger For Asus V...  TOTAL
# 168  32304508173  19V 4.74A 90W Power Adapter Charger For HP Lap...  TOTAL
# 169  32740916653  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 170  32464375211  12V 3.6A 48W Ac Laptop Power Adapter Charger F...  TOTAL
# 171  32743178926  19V 3.42A 65W Travel Laptop Power Adapter Char...  TOTAL
# 172  32462986131  12V 2.58A 36W Laptop AC Power Adapter Charger ...  TOTAL
# 173  32442227276  33W AC Laptop Power Adapter Charger For ASUS E...  TOTAL
# 174  32741165783  19V 2.37A 45W Travel Power Adapter Charger For...  TOTAL
# 175  32808660934  19V 1.75A 33W Laptop Power Adapter Charger For...  TOTAL
# 176  32485994958  12V 3.6A 43W AC Tablet Power Adapter Charger F...  TOTAL
# 177  32743178948  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 178  32719915375  USB Charging Cable For Lenovo Yoga 3 Yoga 4 Yo...  TOTAL
# 179  32740940206  19.5V 3.33A 65W Travel Power Adapter Charger F...  TOTAL
# 180  32297057887  12V 2.58A 36W Car Power Adapter Charger For Mi...  TOTAL
# 181  32298632647  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 182  32483111961  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 183  32742975139  12V 2.58A 36W Laptop Travel Power Adapter Char...  TOTAL
# 184  32344628700  19V 1.58A 30W Laptop AC Power Adapter For Acer...  TOTAL
# 185  32612459426  15V 1.6A 24W AC Laptop Power Adapter Charger F...  TOTAL
# 186  32807949168  12V 2.58A 36W Collapsible Portable Laptop Powe...  TOTAL
# 187  32808502216  12V 3A 36W Collapsible Portable Laptop Power A...  TOTAL
# 188  32695737418  20V 2.25A 45W AC Laptop Power Adapter For Leno...  TOTAL
# 189  32817726909  20V 2A 40W Portable Laptop Power Adapter Charg...  TOTAL
#
#      老买家支付买家数  老买家下单买家数  老买家支付金额  老买家支付订单数  老买家下单订单数 老买家浏览-下单转化率  老买家商品页访客数  \
# 0          11        11   341.80        11        11      10.00%        110
# 1           4         5   101.28         4         5      12.20%         41
# 2           0         0     0.00         0         0       0.00%         13
# 3           3         3    29.98         3         3      14.29%         21
# 4           1         1    10.56         1         1       7.14%         14
# 5           0         0     0.00         0         0       0.00%          9
# 6           1         1    11.27         1         1      10.00%         10
# 7           0         0     0.00         0         0       0.00%         11
# 8           1         1    75.00         1         1      33.33%          3
# 9           2         2    29.25         2         2      15.38%         13
# 10          2         2    19.20         2         2      22.22%          9
# 11          0         0     0.00         0         0       0.00%          2
# 12          3         3    31.32         3         4      21.43%         14
# 13          1         1    60.00         1         1     100.00%          1
# 14          1         1    44.10         1         1      50.00%          2
# 15          1         1    10.50         1         1      25.00%          4
# 16          0         0     0.00         0         0       0.00%          9
# 17          1         1    19.50         1         1       9.09%         11
# 18          1         1    40.00         1         1     100.00%          1
# 19          1         1    20.30         1         1      33.33%          3
# 20          1         1    16.66         1         1     100.00%          1
# 21          1         1    12.94         1         1      14.29%          7
# 22          2         2    20.98         2         2      40.00%          5
# 23          0         0     0.00         0         0       0.00%          2
# 24          0         0     0.00         0         0       0.00%          1
# 25          0         0     0.00         0         0       0.00%          3
# 26          0         0     0.00         0         0       0.00%          3
# 27          2         2    20.35         2         2      50.00%          4
# 28          1         1    20.00         1         1     100.00%          1
# 29          0         0     0.00         0         0       0.00%          1
# ..        ...       ...      ...       ...       ...         ...        ...
# 160         0         0     0.00         0         0       0.00%          0
# 161         0         0     0.00         0         0       0.00%          0
# 162         0         0     0.00         0         0       0.00%          0
# 163         0         0     0.00         0         0       0.00%          0
# 164         0         0     0.00         0         0       0.00%          0
# 165         0         0     0.00         0         0       0.00%          0
# 166         0         0     0.00         0         0       0.00%          0
# 167         0         0     0.00         0         0       0.00%          0
# 168         0         0     0.00         0         0       0.00%          0
# 169         0         0     0.00         0         0       0.00%          1
# 170         0         0     0.00         0         0       0.00%          1
# 171         0         0     0.00         0         0       0.00%          0
# 172         0         0     0.00         0         0       0.00%          0
# 173         0         0     0.00         0         0       0.00%          0
# 174         0         0     0.00         0         0       0.00%          0
# 175         0         0     0.00         0         0       0.00%          0
# 176         0         0     0.00         0         0       0.00%          0
# 177         0         0     0.00         0         0       0.00%          0
# 178         0         0     0.00         0         0       0.00%          0
# 179         0         0     0.00         0         0       0.00%          0
# 180         0         0     0.00         0         0       0.00%          0
# 181         0         0     0.00         0         0       0.00%          1
# 182         0         0     0.00         0         0       0.00%          0
# 183         0         0     0.00         0         0       0.00%          1
# 184         0         0     0.00         0         0       0.00%          0
# 185         0         0     0.00         0         0       0.00%          0
# 186         0         0     0.00         0         0       0.00%          0
# 187         0         0     0.00         0         0       0.00%          1
# 188         0         0     0.00         0         0       0.00%          0
# 189         0         0     0.00         0         0       0.00%          0
#
#         ...          支付金额     支付金额%  支付金额% Cumulative  风控订单数  风控金额   退款金额  \
# 0       ...       2229.50  0.461791          0.461791      0     0  92.20
# 1       ...        300.09  0.062157          0.523948      0     0  34.43
# 2       ...        265.46  0.054984          0.578932      0     0  25.88
# 3       ...        203.93  0.042240          0.621172      0     0   0.00
# 4       ...        167.40  0.034673          0.655845      0     0   0.00
# 5       ...        150.87  0.031249          0.687094      0     0  18.75
# 6       ...        125.44  0.025982          0.713076      0     0   0.00
# 7       ...         89.25  0.018486          0.731563      0     0   0.00
# 8       ...         88.50  0.018331          0.749893      0     0   0.00
# 9       ...         87.45  0.018113          0.768007      0     0   0.00
# 10      ...         78.45  0.016249          0.784256      0     0   9.60
# 11      ...         71.87  0.014886          0.799142      0     0   0.00
# 12      ...         62.64  0.012974          0.812117      0     0  10.49
# 13      ...         60.00  0.012428          0.824544      0     0   0.00
# 14      ...         53.53  0.011088          0.835632      0     0   0.00
# 15      ...         52.16  0.010804          0.846436      0     0   0.00
# 16      ...         48.91  0.010131          0.856566      0     0   9.64
# 17      ...         48.59  0.010064          0.866630      0     0   0.00
# 18      ...         40.00  0.008285          0.874916      0     0   0.00
# 19      ...         30.31  0.006278          0.881194      0     0   0.00
# 20      ...         26.26  0.005439          0.886633      0     0   0.00
# 21      ...         25.88  0.005360          0.891993      0     0   0.00
# 22      ...         20.98  0.004346          0.896339      0     0   0.00
# 23      ...         20.94  0.004337          0.900676      0     0   0.00
# 24      ...         20.83  0.004314          0.904991      0     0   0.00
# 25      ...         20.70  0.004288          0.909278      0     0   0.00
# 26      ...         20.59  0.004265          0.913543      0     0   0.00
# 27      ...         20.35  0.004215          0.917758      0     0   0.00
# 28      ...         20.00  0.004143          0.921900      0     0   0.00
# 29      ...         20.00  0.004143          0.926043      0     0   0.00
# ..      ...           ...       ...               ...    ...   ...    ...
# 160     ...          0.00  0.000000          1.000000      0     0   0.00
# 161     ...          0.00  0.000000          1.000000      0     0   0.00
# 162     ...          0.00  0.000000          1.000000      0     0   0.00
# 163     ...          0.00  0.000000          1.000000      0     0   0.00
# 164     ...          0.00  0.000000          1.000000      0     0   0.00
# 165     ...          0.00  0.000000          1.000000      0     0   0.00
# 166     ...          0.00  0.000000          1.000000      0     0   0.00
# 167     ...          0.00  0.000000          1.000000      0     0   0.00
# 168     ...          0.00  0.000000          1.000000      0     0   0.00
# 169     ...          0.00  0.000000          1.000000      0     0   0.00
# 170     ...          0.00  0.000000          1.000000      0     0   0.00
# 171     ...          0.00  0.000000          1.000000      0     0   0.00
# 172     ...          0.00  0.000000          1.000000      0     0   0.00
# 173     ...          0.00  0.000000          1.000000      0     0   0.00
# 174     ...          0.00  0.000000          1.000000      0     0   0.00
# 175     ...          0.00  0.000000          1.000000      0     0   0.00
# 176     ...          0.00  0.000000          1.000000      0     0   0.00
# 177     ...          0.00  0.000000          1.000000      0     0   0.00
# 178     ...          0.00  0.000000          1.000000      0     0   0.00
# 179     ...          0.00  0.000000          1.000000      0     0   0.00
# 180     ...          0.00  0.000000          1.000000      0     0   0.00
# 181     ...          0.00  0.000000          1.000000      0     0   0.00
# 182     ...          0.00  0.000000          1.000000      0     0   0.00
# 183     ...          0.00  0.000000          1.000000      0     0   0.00
# 184     ...          0.00  0.000000          1.000000      0     0   0.00
# 185     ...          0.00  0.000000          1.000000      0     0   0.00
# 186     ...          0.00  0.000000          1.000000      0     0   0.00
# 187     ...          0.00  0.000000          1.000000      0     0   0.00
# 188     ...          0.00  0.000000          1.000000      0     0   0.00
# 189     ...          0.00  0.000000          1.000000      0     0   0.00
#
#     退款订单数  Unnamed: 33  Unnamed: 34  Unnamed: 35
# 0       5          NaN         SKU数   190.000000
# 1       2          NaN    30天动销SKU数    60.000000
# 2       1          NaN          动销%     0.315789
# 3       0          NaN          NaN          NaN
# 4       0          NaN          NaN          NaN
# 5       1          NaN          NaN          NaN
# 6       0          NaN          NaN          NaN
# 7       0          NaN          NaN          NaN
# 8       0          NaN          NaN          NaN
# 9       0          NaN          NaN          NaN
# 10      1          NaN          NaN          NaN
# 11      0          NaN          NaN          NaN
# 12      1          NaN          NaN          NaN
# 13      0          NaN          NaN          NaN
# 14      0          NaN          NaN          NaN
# 15      0          NaN          NaN          NaN
# 16      1          NaN          NaN          NaN
# 17      0          NaN          NaN          NaN
# 18      0          NaN          NaN          NaN
# 19      0          NaN          NaN          NaN
# 20      0          NaN          NaN          NaN
# 21      0          NaN          NaN          NaN
# 22      0          NaN          NaN          NaN
# 23      0          NaN          NaN          NaN
# 24      0          NaN          NaN          NaN
# 25      0          NaN          NaN          NaN
# 26      0          NaN          NaN          NaN
# 27      0          NaN          NaN          NaN
# 28      0          NaN          NaN          NaN
# 29      0          NaN          NaN          NaN
# ..    ...          ...          ...          ...
# 160     0          NaN          NaN          NaN
# 161     0          NaN          NaN          NaN
# 162     0          NaN          NaN          NaN
# 163     0          NaN          NaN          NaN
# 164     0          NaN          NaN          NaN
# 165     0          NaN          NaN          NaN
# 166     0          NaN          NaN          NaN
# 167     0          NaN          NaN          NaN
# 168     0          NaN          NaN          NaN
# 169     0          NaN          NaN          NaN
# 170     0          NaN          NaN          NaN
# 171     0          NaN          NaN          NaN
# 172     0          NaN          NaN          NaN
# 173     0          NaN          NaN          NaN
# 174     0          NaN          NaN          NaN
# 175     0          NaN          NaN          NaN
# 176     0          NaN          NaN          NaN
# 177     0          NaN          NaN          NaN
# 178     0          NaN          NaN          NaN
# 179     0          NaN          NaN          NaN
# 180     0          NaN          NaN          NaN
# 181     0          NaN          NaN          NaN
# 182     0          NaN          NaN          NaN
# 183     0          NaN          NaN          NaN
# 184     0          NaN          NaN          NaN
# 185     0          NaN          NaN          NaN
# 186     0          NaN          NaN          NaN
# 187     0          NaN          NaN          NaN
# 188     0          NaN          NaN          NaN
# 189     0          NaN          NaN          NaN
#
# [190 rows x 36 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['商品ID'][:40]:
for product_id in product_list['商品ID'][40:81]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    try:
        product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
        product_search_button.click()
        time.sleep(5)
        # 点击全选
        select_all_box = browser.find_element_by_id("checkbox-all")
        select_all_box.click()
        time.sleep(5)
    except Exception as err:
        print("Can't find this product: " + str(err))
        pass

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
