# %%
from selenium import webdriver
import pandas as pd
import time
import datetime
import os

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = ".//chrome_driver//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180523限时限量折扣(2)'
campaign_start_date = datetime.datetime(2018, 5, 24, 0, 0)
campaign_end_date = datetime.datetime(2018, 6, 6, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()

# %%
# 点击结束日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-360d8e838554> in <module>()
#       3 campaign_end_date_input[1].click()
#       4 # 选择日期
# ----> 5 browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
#
# IndexError: list index out of range

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2015.2.18 速卖通//2016.11.26 速卖通数据分析//2016.12.18 速卖通商品分析.xlsm"
product_list = pd.read_excel(product_list_path, sheetname='商品分析')
product_list
# Out:
#             商品ID                                               商品标题     平台  \
# 0    32597758635  19V 4.74A 90W Universal Power Adapter Charger ...  TOTAL
# 1    32487768278  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 2    32954377486  20V 3.25A 65W USB C Type C Universal Laptop Po...  TOTAL
# 3    32828507962  20V 3.25A 65W Universal USB Type C Laptop Mobi...  TOTAL
# 4    32326661278  19V 4.74A 90W Laptop Universal Power Adapter C...  TOTAL
# 5    32298664354  22.5V 1.25A 30W Power Adapter Charger For IRob...  TOTAL
# 6    32464656233  19V 2.37A 45W Laptop Ac Power Adapter Charger ...  TOTAL
# 7    32412624689  20V 2A 40W Laptop Ac Power Adapter Charger For...  TOTAL
# 8    32297759407  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 9    32462898820  12V 3.6A 45W Laptop Ac Power Adapter Charger F...  TOTAL
# 10   32484354951  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 11   32298356440  19.5V 3.34A 65W AC Laptop Power Adapter Charge...  TOTAL
# 12   32602982934  19V 3.42A 65W Universal Power Adapter Charger ...  TOTAL
# 13   32753723716  15V 16V 19V 19.5V 20V Auto Voltage Universal P...  TOTAL
# 14   32821187508  20V 4.5A 90W Long Type Laptop Power Adapter Ch...  TOTAL
# 15   33003521931  19V 4.74A 90W Universal Laptop Power Adapter C...  TOTAL
# 16   32298207403  19.5V 3.34A 65W Laptop AC Power Adapter Charge...  TOTAL
# 17   32826554127  5V 9V 12V 15V 20V 65W Type C Laptop Mobile Pho...  TOTAL
# 18   32365466196  20V 3.25A 65W Ac Laptop Power Adapter Charger ...  TOTAL
# 19   32297797059  12V 3A 36W AC Power Adapter Charger For Lenovo...  TOTAL
# 20   32487732817  12V 3A 36W AC Laptop Car Power Adapter Charger...  TOTAL
# 21   32464588670  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 22   32462445872  20V 2.25A 45W Laptop Ac Power Adapter Charger ...  TOTAL
# 23   32297599525  19.5V 4.7A 90W Laptop Ac Power Adapter Charger...  TOTAL
# 24   32431966616  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 25   32695774510  20V 3.25A 65W Power Adapter Travel Charger For...  TOTAL
# 26   32465020088  20V 4.5A 90W Ac Laptop Power Adapter Charger F...  TOTAL
# 27   32440656276  90W Laptop AC Universal Power Adapter Charger ...  TOTAL
# 28   32485945798  12V 3.6A 43W Ac Laptop Power Adapter Charger F...  TOTAL
# 29   32484544534  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# ..           ...                                                ...    ...
# 161  32740994989  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 162  32807949168  12V 2.58A 36W Collapsible Portable Laptop Powe...  TOTAL
# 163  32818324398  12V 2.58A 36W Light Version Tablet Power Adapt...  TOTAL
# 164  32441813994  45W Laptop Ac Power Adapter Charger For Toshib...  TOTAL
# 165  32465708359  19V 2.37A 45W Laptop AC Power Adapter Charger ...  TOTAL
# 166  32296653017  19V 3.16A 60W AC Laptop Power Adapter Charger ...  TOTAL
# 167  32741840702  15V 1.6A 24W Travel Power Adapter Charger For ...  TOTAL
# 168  32291879028  19V 4.74A AC Laptop Power Adapter Charger For ...  TOTAL
# 169  32743879142  19V 1.75A 33W Travel Power Adapter Charger For...  TOTAL
# 170  32740986924  19V 2.37A 45W Laptop AC Travel Power Adapter C...  TOTAL
# 171  32304508173  19V 4.74A 90W Power Adapter Charger For HP Lap...  TOTAL
# 172  32612459426  15V 1.6A 24W AC Laptop Power Adapter Charger F...  TOTAL
# 173  32464900691  19V 1.75A 33W Laptop AC Power Adapter Charger ...  TOTAL
# 174  32808498905  10.5V 2.9A 30W Collapsible Portable Laptop Pow...  TOTAL
# 175  32955040177  22.5V 1.25A 28W Vacuum Cleaner Power Adapter C...  TOTAL
# 176  32440319488  18W Factory Direct Laptop AC Power Adapter Cha...  TOTAL
# 177  32297057887  12V 2.58A 36W Car Power Adapter Charger For Mi...  TOTAL
# 178  32808502216  12V 3A 36W Collapsible Portable Laptop Power A...  TOTAL
# 179  32298632647  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 180  32740916653  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 181  32441439325  48W Ac Laptop Power Adapter Charger For Micros...  TOTAL
# 182  32483837073  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 183  32817726909  20V 2A 40W Portable Laptop Power Adapter Charg...  TOTAL
# 184  32808486643  15V 1.6A 24W Collapsible Portable Laptop Power...  TOTAL
# 185  32291638714  19V 4.74A Ac Laptop Power Adapter Charger For ...  TOTAL
# 186  32743847362  19V 2.37A 45W Travel Power Adapter Charger For...  TOTAL
# 187  32297041583  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 188  32483111961  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 189  32742975139  12V 2.58A 36W Laptop Travel Power Adapter Char...  TOTAL
# 190  32292636557  19V 4.74A AC Laptop Power Adapter Charger For ...  TOTAL
#
#      老买家支付买家数  老买家下单买家数  老买家支付金额  老买家支付订单数  老买家下单订单数  老买家浏览-下单转化率  老买家商品页访客数  \
# 0          20        20   632.31        21        21       0.0621        322
# 1           1         1    10.50         1         2       0.0417         24
# 2           0         0     0.00         0         0       0.0000         19
# 3           4         4    75.01         4         4       0.2222         18
# 4           2         2    38.25         2         2       0.1053         19
# 5           1         1    62.82         1         1       0.2000          5
# 6           2         2   100.18         2         2       0.4000          5
# 7           0         0     0.00         0         0       0.0000          5
# 8           1         1    50.90         1         1       0.0714         14
# 9           1         1    58.86         1         1       0.2000          5
# 10          2         2    29.70         2         2       0.3333          6
# 11          1         1    10.34         1         1       0.2000          5
# 12          0         0     0.00         0         0       0.0000         13
# 13          0         0     0.00         0         0       0.0000          2
# 14          1         1     9.48         1         1       0.0435         23
# 15          0         0     0.00         0         0       0.0000          1
# 16          0         0     0.00         0         0       0.0000          2
# 17          0         0     0.00         0         0       0.0000          1
# 18          0         0     0.00         0         0       0.0000          3
# 19          0         0     0.00         0         0       0.0000          0
# 20          0         0     0.00         0         0       0.0000          3
# 21          1         2    21.00         1         2       0.5000          4
# 22          0         0     0.00         0         0       0.0000          0
# 23          0         0     0.00         0         0       0.0000          4
# 24          1         1     9.59         1         1       0.3333          3
# 25          0         0     0.00         0         0       0.0000          4
# 26          1         1    15.00         1         1       0.5000          2
# 27          0         0     0.00         0         0       0.0000          0
# 28          0         0     0.00         0         0       0.0000          0
# 29          1         1    10.80         1         1       0.2000          5
# ..        ...       ...      ...       ...       ...          ...        ...
# 161         0         0     0.00         0         0       0.0000          0
# 162         0         0     0.00         0         0       0.0000          0
# 163         0         0     0.00         0         0       0.0000          0
# 164         0         0     0.00         0         0       0.0000          0
# 165         0         0     0.00         0         0       0.0000          0
# 166         0         0     0.00         0         0       0.0000          0
# 167         0         0     0.00         0         0       0.0000          0
# 168         0         0     0.00         0         0       0.0000          0
# 169         0         0     0.00         0         0       0.0000          0
# 170         0         0     0.00         0         0       0.0000          0
# 171         0         0     0.00         0         0       0.0000          0
# 172         0         0     0.00         0         0       0.0000          0
# 173         0         0     0.00         0         0       0.0000          0
# 174         0         0     0.00         0         0       0.0000          0
# 175         0         0     0.00         0         0       0.0000          0
# 176         0         0     0.00         0         0       0.0000          0
# 177         0         0     0.00         0         0       0.0000          0
# 178         0         0     0.00         0         0       0.0000          1
# 179         0         0     0.00         0         0       0.0000          0
# 180         0         0     0.00         0         0       0.0000          0
# 181         0         0     0.00         0         0       0.0000          0
# 182         0         0     0.00         0         0       0.0000          0
# 183         0         0     0.00         0         0       0.0000          0
# 184         0         0     0.00         0         0       0.0000          0
# 185         0         0     0.00         0         0       0.0000          0
# 186         0         0     0.00         0         0       0.0000          1
# 187         0         0     0.00         0         0       0.0000          0
# 188         0         0     0.00         0         0       0.0000          0
# 189         0         0     0.00         0         0       0.0000          0
# 190         0         0     0.00         0         0       0.0000          0
#
#         ...       支付金额% Cumulative  支付订单数     支付金额  风控订单数  风控金额    退款金额  \
# 0       ...               0.596974    237  3787.56      1  21.2  118.46
# 1       ...               0.664847     39   430.63      0   0.0   39.20
# 2       ...               0.728123     16   401.46      0   0.0    0.00
# 3       ...               0.781871     16   341.01      0   0.0    0.00
# 4       ...               0.804089      8   140.96      0   0.0    0.00
# 5       ...               0.820564      5   104.53      0   0.0    0.00
# 6       ...               0.836354      2   100.18      0   0.0    0.00
# 7       ...               0.850854      5    92.00      2  35.0    0.00
# 8       ...               0.863772      4    81.96      0   0.0    0.00
# 9       ...               0.876306      3    79.52      0   0.0    0.00
# 10      ...               0.888537      4    77.60      0   0.0    0.00
# 11      ...               0.900525      7    76.06      0   0.0    0.00
# 12      ...               0.909938      4    59.72      0   0.0   81.26
# 13      ...               0.918657      3    55.32      0   0.0    0.00
# 14      ...               0.926071      5    47.04      0   0.0    0.00
# 15      ...               0.933402      2    46.51      0   0.0    0.00
# 16      ...               0.939895      4    41.20      0   0.0    0.00
# 17      ...               0.945357      2    34.65      0   0.0    0.00
# 18      ...               0.950118      3    30.21      0   0.0    0.00
# 19      ...               0.954847      2    30.00      0   0.0    0.00
# 20      ...               0.959432      2    29.09      0   0.0    0.00
# 21      ...               0.962742      1    21.00      0   0.0    0.00
# 22      ...               0.965998      2    20.66      0   0.0    0.00
# 23      ...               0.969194      2    20.28      0   0.0    0.00
# 24      ...               0.972217      2    19.18      0   0.0    0.00
# 25      ...               0.974582      1    15.00      0   0.0    0.00
# 26      ...               0.976946      1    15.00      0   0.0    0.00
# 27      ...               0.979162      1    14.06      0   0.0    0.00
# 28      ...               0.981211      1    13.00      0   0.0    0.00
# 29      ...               0.982913      1    10.80      0   0.0    0.00
# ..      ...                    ...    ...      ...    ...   ...     ...
# 161     ...               1.000000      0     0.00      0   0.0    0.00
# 162     ...               1.000000      0     0.00      0   0.0    0.00
# 163     ...               1.000000      0     0.00      0   0.0    0.00
# 164     ...               1.000000      0     0.00      0   0.0    0.00
# 165     ...               1.000000      0     0.00      0   0.0    0.00
# 166     ...               1.000000      0     0.00      0   0.0    0.00
# 167     ...               1.000000      0     0.00      0   0.0    0.00
# 168     ...               1.000000      0     0.00      0   0.0    0.00
# 169     ...               1.000000      0     0.00      0   0.0    0.00
# 170     ...               1.000000      0     0.00      0   0.0    0.00
# 171     ...               1.000000      0     0.00      0   0.0    0.00
# 172     ...               1.000000      0     0.00      0   0.0    0.00
# 173     ...               1.000000      0     0.00      0   0.0    0.00
# 174     ...               1.000000      0     0.00      0   0.0    0.00
# 175     ...               1.000000      0     0.00      0   0.0    0.00
# 176     ...               1.000000      0     0.00      0   0.0    0.00
# 177     ...               1.000000      0     0.00      0   0.0    0.00
# 178     ...               1.000000      0     0.00      0   0.0    0.00
# 179     ...               1.000000      0     0.00      0   0.0    0.00
# 180     ...               1.000000      0     0.00      0   0.0    0.00
# 181     ...               1.000000      0     0.00      0   0.0    0.00
# 182     ...               1.000000      0     0.00      0   0.0    0.00
# 183     ...               1.000000      0     0.00      0   0.0    0.00
# 184     ...               1.000000      0     0.00      0   0.0    0.00
# 185     ...               1.000000      0     0.00      0   0.0    0.00
# 186     ...               1.000000      0     0.00      0   0.0    0.00
# 187     ...               1.000000      0     0.00      0   0.0    0.00
# 188     ...               1.000000      0     0.00      0   0.0    0.00
# 189     ...               1.000000      0     0.00      0   0.0    0.00
# 190     ...               1.000000      0     0.00      0   0.0    0.00
#
#      退款订单数  Unnamed: 33  Unnamed: 34  Unnamed: 35
# 0       11          NaN         SKU数    191.00000
# 1        3          NaN    30天动销SKU数     41.00000
# 2        0          NaN          动销%      0.21466
# 3        0          NaN          NaN          NaN
# 4        0          NaN          NaN          NaN
# 5        0          NaN          NaN          NaN
# 6        0          NaN          NaN          NaN
# 7        1          NaN          NaN          NaN
# 8        0          NaN          NaN          NaN
# 9        0          NaN          NaN          NaN
# 10       0          NaN          NaN          NaN
# 11       0          NaN          NaN          NaN
# 12       1          NaN          NaN          NaN
# 13       0          NaN          NaN          NaN
# 14       0          NaN          NaN          NaN
# 15       0          NaN          NaN          NaN
# 16       0          NaN          NaN          NaN
# 17       0          NaN          NaN          NaN
# 18       0          NaN          NaN          NaN
# 19       0          NaN          NaN          NaN
# 20       0          NaN          NaN          NaN
# 21       0          NaN          NaN          NaN
# 22       0          NaN          NaN          NaN
# 23       0          NaN          NaN          NaN
# 24       0          NaN          NaN          NaN
# 25       0          NaN          NaN          NaN
# 26       0          NaN          NaN          NaN
# 27       0          NaN          NaN          NaN
# 28       0          NaN          NaN          NaN
# 29       0          NaN          NaN          NaN
# ..     ...          ...          ...          ...
# 161      0          NaN          NaN          NaN
# 162      0          NaN          NaN          NaN
# 163      0          NaN          NaN          NaN
# 164      0          NaN          NaN          NaN
# 165      0          NaN          NaN          NaN
# 166      0          NaN          NaN          NaN
# 167      0          NaN          NaN          NaN
# 168      0          NaN          NaN          NaN
# 169      0          NaN          NaN          NaN
# 170      0          NaN          NaN          NaN
# 171      0          NaN          NaN          NaN
# 172      0          NaN          NaN          NaN
# 173      0          NaN          NaN          NaN
# 174      0          NaN          NaN          NaN
# 175      0          NaN          NaN          NaN
# 176      0          NaN          NaN          NaN
# 177      0          NaN          NaN          NaN
# 178      0          NaN          NaN          NaN
# 179      0          NaN          NaN          NaN
# 180      0          NaN          NaN          NaN
# 181      0          NaN          NaN          NaN
# 182      0          NaN          NaN          NaN
# 183      0          NaN          NaN          NaN
# 184      0          NaN          NaN          NaN
# 185      0          NaN          NaN          NaN
# 186      0          NaN          NaN          NaN
# 187      0          NaN          NaN          NaN
# 188      0          NaN          NaN          NaN
# 189      0          NaN          NaN          NaN
# 190      0          NaN          NaN          NaN
#
# [191 rows x 36 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['商品ID'][:40]:
for product_id in product_list['商品ID'][40:81]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    try:
        product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
        product_search_button.click()
        time.sleep(5)
        # 点击全选
        select_all_box = browser.find_element_by_id("checkbox-all")
        select_all_box.click()
        time.sleep(5)
    except Exception as err:
        print("Can't find this product: " + str(err))
        pass

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
