# %%
from selenium import webdriver
import pandas as pd
import time
import datetime
import os

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = ".//chrome_driver//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180523限时限量折扣(2)'
campaign_start_date = datetime.datetime(2018, 5, 24, 0, 0)
campaign_end_date = datetime.datetime(2018, 6, 6, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()

# %%
# 点击结束日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-360d8e838554> in <module>()
#       3 campaign_end_date_input[1].click()
#       4 # 选择日期
# ----> 5 browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
#
# IndexError: list index out of range

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2015.2.18 速卖通//2016.11.26 速卖通数据分析//2016.12.18 速卖通商品分析.xlsm"
product_list = pd.read_excel(product_list_path, sheetname='商品分析')
product_list
# Out:
#             商品ID                                               商品标题     平台  \
# 0    32597758635  19V 4.74A 90W Universal Power Adapter Charger ...  TOTAL
# 1    32828507962  20V 3.25A 65W Universal USB Type C Laptop Mobi...  TOTAL
# 2    32487768278  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 3    32298664354  22.5V 1.25A 30W Power Adapter Charger For IRob...  TOTAL
# 4    32484354951  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 5    32297759407  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 6    32465020088  20V 4.5A 90W Ac Laptop Power Adapter Charger F...  TOTAL
# 7    32743835649  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 8    32298294121  19.5V 2.31A 45W Laptop Ac Power Adapter Charge...  TOTAL
# 9    32695725619  19V 3.42A 65W Power Adapter For ASUS Zenbook U...  TOTAL
# 10   32741840737  12V 3.6A 48W Travel Power Adapter Charger For ...  TOTAL
# 11   32602982934  19V 3.42A 65W Universal Power Adapter Charger ...  TOTAL
# 12   32753723716  15V 16V 19V 19.5V 20V Auto Voltage Universal P...  TOTAL
# 13   32326661278  19V 4.74A 90W Laptop Universal Power Adapter C...  TOTAL
# 14   32695733622  20V 2.25A 45W AC Power Adapter Travel Charger ...  TOTAL
# 15   32484544534  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# 16   32440656276  90W Laptop AC Universal Power Adapter Charger ...  TOTAL
# 17   32826554127  5V 9V 12V 15V 20V 65W Type C Laptop Mobile Pho...  TOTAL
# 18   32412624689  20V 2A 40W Laptop Ac Power Adapter Charger For...  TOTAL
# 19   32298356440  19.5V 3.34A 65W AC Laptop Power Adapter Charge...  TOTAL
# 20   32695774510  20V 3.25A 65W Power Adapter Travel Charger For...  TOTAL
# 21   32899068443  26.1V 0.78A 20.3W Universal Power Adapter Char...  TOTAL
# 22   32483143464  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 23   32745259113  19V 3.42A 65W Laptop AC Travel Power Adapter C...  TOTAL
# 24   32291851311  19V 4.74A Ac Laptop Power Adapter Charger For ...  TOTAL
# 25   32818324398  12V 2.58A 36W Light Version Tablet Power Adapt...  TOTAL
# 26   32954377486  20V 3.25A 65W USB C Type C Universal Laptop Po...  TOTAL
# 27   32485994958  12V 3.6A 43W AC Tablet Power Adapter Charger F...  TOTAL
# 28   32435582916  65W Power Adapter Charger For Lenovo G400 G500...  TOTAL
# 29   32485945798  12V 3.6A 43W Ac Laptop Power Adapter Charger F...  TOTAL
# ..           ...                                                ...    ...
# 164  32695758600  19V 1.75A 33W AC Laptop Power Adapter For Asus...  TOTAL
# 165  32298816101  19V 3.42A 65W Laptop Ac Power Adapter Charger ...  TOTAL
# 166  32298791846  19.5V 4.62A 90W Laptop AC Power Adapter Charge...  TOTAL
# 167  32486213265  19V 2.15A 40W AC Laptop Power Adapter Charger ...  TOTAL
# 168  32441829684  33W Laptop Ac Power Adapter Charger For Asus V...  TOTAL
# 169  32695737202  20V 3.25A 65W Power Adapter Travel Charger For...  TOTAL
# 170  32741249048  19.5V 3.34A 65W Travel Power Adapter Charger F...  TOTAL
# 171  32443688412  40W Laptop Ac Power Adapter Charger For Samsun...  TOTAL
# 172  32297599553  19V 3.42A 65W Laptop Ac Power Adapter Charger ...  TOTAL
# 173  32303542679  12V 1.5A 18W Laptop AC Power Adapter Charger F...  TOTAL
# 174  32808502216  12V 3A 36W Collapsible Portable Laptop Power A...  TOTAL
# 175  32344557311  19V 1.58A Laptop AC Power Adapter Charger For ...  TOTAL
# 176  32441439325  48W Ac Laptop Power Adapter Charger For Micros...  TOTAL
# 177  32462986131  12V 2.58A 36W Laptop AC Power Adapter Charger ...  TOTAL
# 178  32344628700  19V 1.58A 30W Laptop AC Power Adapter For Acer...  TOTAL
# 179  32743951215  20V 2.25A 45W Travel Power Adapter Charger For...  TOTAL
# 180  32464568887  19V 2.1A 40W Laptop Ac Power Adapter Charger F...  TOTAL
# 181  32807949168  12V 2.58A 36W Collapsible Portable Laptop Powe...  TOTAL
# 182  32440170604  33W Factory Direct Laptop AC Power Adapter Cha...  TOTAL
# 183  32435638867  33W Laptop AC Power Adapter Charger For ASUS V...  TOTAL
# 184  32464375211  12V 3.6A 48W Ac Laptop Power Adapter Charger F...  TOTAL
# 185  32740940206  19.5V 3.33A 65W Travel Power Adapter Charger F...  TOTAL
# 186  32462417929  19V 2.37A 45W Laptop AC Power Adapter Charger ...  TOTAL
# 187  32462223205  12V 3A 36W Laptop AC Power Adapter Charger For...  TOTAL
# 188  32440319488  18W Factory Direct Laptop AC Power Adapter Cha...  TOTAL
# 189  32298099303  12V 3.6A 48W Power Adapter Charger For Microso...  TOTAL
# 190  32297057887  12V 2.58A 36W Car Power Adapter Charger For Mi...  TOTAL
# 191  32304508173  19V 4.74A 90W Power Adapter Charger For HP Lap...  TOTAL
# 192  32719915375  USB Charging Cable For Lenovo Yoga 3 Yoga 4 Yo...  TOTAL
# 193  32298250561  19.5V 3.33A Laptop AC Power Adapter Charger Fo...  TOTAL
#
#      老买家支付买家数  老买家下单买家数  老买家支付金额  老买家支付订单数  老买家下单订单数  老买家浏览-下单转化率  老买家商品页访客数  \
# 0          25        25   584.74        25        25       0.0836        299
# 1           3         3    55.51         3         3       0.0811         37
# 2           4         4    48.30         4         5       0.1739         23
# 3           1         1    10.47         1         1       0.1000         10
# 4           3         3    65.65         3         3       0.4286          7
# 5           2         2    29.22         2         2       0.2857          7
# 6           1         1    89.05         1         1       0.5000          2
# 7           0         0     0.00         0         0       0.0000          2
# 8           1         1     9.72         1         1       0.2500          4
# 9           1         1    75.00         1         1       1.0000          1
# 10          1         1    75.00         1         1       1.0000          1
# 11          0         0     0.00         0         0       0.0000          2
# 12          1         1    36.88         1         1       0.0714         14
# 13          0         0     0.00         0         0       0.0000         27
# 14          0         0     0.00         0         0       0.0000          0
# 15          0         0     0.00         0         0       0.0000          0
# 16          0         0     0.00         0         0       0.0000          3
# 17          0         0     0.00         0         0       0.0000          1
# 18          0         0     0.00         0         0       0.0000          5
# 19          1         1    10.49         1         1       0.3333          3
# 20          0         0     0.00         0         0       0.0000         12
# 21          1         1    13.20         1         1       0.2500          4
# 22          0         0     0.00         0         0       0.0000          2
# 23          0         0     0.00         0         0       0.0000          1
# 24          1         1    19.68         1         1       1.0000          1
# 25          0         0     0.00         0         0       0.0000          0
# 26          0         0     0.00         0         0       0.0000          8
# 27          1         1    16.25         1         1       0.5000          2
# 28          1         1    15.99         1         1       1.0000          1
# 29          1         1    15.11         1         1       1.0000          1
# ..        ...       ...      ...       ...       ...          ...        ...
# 164         0         0     0.00         0         0       0.0000          1
# 165         0         0     0.00         0         0       0.0000          0
# 166         0         0     0.00         0         0       0.0000          2
# 167         0         0     0.00         0         0       0.0000          0
# 168         0         0     0.00         0         0       0.0000          0
# 169         0         0     0.00         0         0       0.0000          0
# 170         0         0     0.00         0         0       0.0000          1
# 171         0         0     0.00         0         0       0.0000          0
# 172         0         0     0.00         0         0       0.0000          0
# 173         0         0     0.00         0         0       0.0000          0
# 174         0         0     0.00         0         0       0.0000          1
# 175         0         0     0.00         0         0       0.0000          0
# 176         0         0     0.00         0         0       0.0000          0
# 177         0         0     0.00         0         0       0.0000          0
# 178         0         0     0.00         0         0       0.0000          0
# 179         0         0     0.00         0         0       0.0000          0
# 180         0         0     0.00         0         0       0.0000          0
# 181         0         0     0.00         0         0       0.0000          0
# 182         0         0     0.00         0         0       0.0000          0
# 183         0         0     0.00         0         0       0.0000          0
# 184         0         0     0.00         0         0       0.0000          0
# 185         0         0     0.00         0         0       0.0000          0
# 186         0         0     0.00         0         0       0.0000          1
# 187         0         0     0.00         0         0       0.0000          0
# 188         0         0     0.00         0         0       0.0000          0
# 189         0         0     0.00         0         0       0.0000          0
# 190         0         0     0.00         0         0       0.0000          0
# 191         0         0     0.00         0         0       0.0000          0
# 192         0         0     0.00         0         0       0.0000          1
# 193         0         0     0.00         0         0       0.0000          0
#
#         ...          支付金额%  支付金额% Cumulative     支付金额  风控订单数  风控金额    退款金额  \
# 0       ...       0.620243          0.620243  4033.38      0     0  148.00
# 1       ...       0.065820          0.686063   428.02      0     0    0.00
# 2       ...       0.062641          0.748704   407.35      0     0    0.00
# 3       ...       0.027685          0.776389   180.03      0     0   11.27
# 4       ...       0.019045          0.795434   123.85      0     0    9.60
# 5       ...       0.017950          0.813385   116.73      0     0    0.00
# 6       ...       0.013694          0.827079    89.05      0     0    0.00
# 7       ...       0.013422          0.840500    87.28      0     0    0.00
# 8       ...       0.012259          0.852760    79.72      0     0    0.00
# 9       ...       0.011533          0.864293    75.00      0     0    0.00
# 10      ...       0.011533          0.875826    75.00      0     0    0.00
# 11      ...       0.010703          0.886529    69.60      0     0    0.00
# 12      ...       0.008555          0.895084    55.63      0     0    0.00
# 13      ...       0.008459          0.903543    55.01      0     0    0.00
# 14      ...       0.006843          0.910386    44.50      0     0    0.00
# 15      ...       0.006643          0.917029    43.20      0     0    0.00
# 16      ...       0.006451          0.923480    41.95      0     0    0.00
# 17      ...       0.005382          0.928863    35.00      0     0    0.00
# 18      ...       0.005382          0.934245    35.00      0     0    0.00
# 19      ...       0.004793          0.939038    31.17      0     0    0.00
# 20      ...       0.004536          0.943574    29.50      0     0   14.75
# 21      ...       0.004035          0.947610    26.24      0     0    0.00
# 22      ...       0.003322          0.950931    21.60      0     0    0.00
# 23      ...       0.003208          0.954139    20.86      0     0    0.00
# 24      ...       0.003026          0.957165    19.68      0     0    0.00
# 25      ...       0.002916          0.960081    18.96      0     0    9.48
# 26      ...       0.002891          0.962972    18.80      0     0    0.00
# 27      ...       0.002499          0.965471    16.25      0     0    0.00
# 28      ...       0.002459          0.967930    15.99      0     0    0.00
# 29      ...       0.002324          0.970253    15.11      0     0    0.00
# ..      ...            ...               ...      ...    ...   ...     ...
# 164     ...       0.000000          1.000000     0.00      0     0    0.00
# 165     ...       0.000000          1.000000     0.00      0     0    0.00
# 166     ...       0.000000          1.000000     0.00      0     0    0.00
# 167     ...       0.000000          1.000000     0.00      0     0    0.00
# 168     ...       0.000000          1.000000     0.00      0     0    0.00
# 169     ...       0.000000          1.000000     0.00      0     0    0.00
# 170     ...       0.000000          1.000000     0.00      0     0    0.00
# 171     ...       0.000000          1.000000     0.00      0     0    0.00
# 172     ...       0.000000          1.000000     0.00      0     0    0.00
# 173     ...       0.000000          1.000000     0.00      0     0    0.00
# 174     ...       0.000000          1.000000     0.00      0     0    0.00
# 175     ...       0.000000          1.000000     0.00      0     0    0.00
# 176     ...       0.000000          1.000000     0.00      0     0    0.00
# 177     ...       0.000000          1.000000     0.00      0     0    0.00
# 178     ...       0.000000          1.000000     0.00      0     0    0.00
# 179     ...       0.000000          1.000000     0.00      0     0    0.00
# 180     ...       0.000000          1.000000     0.00      0     0    0.00
# 181     ...       0.000000          1.000000     0.00      0     0    0.00
# 182     ...       0.000000          1.000000     0.00      0     0    0.00
# 183     ...       0.000000          1.000000     0.00      0     0    0.00
# 184     ...       0.000000          1.000000     0.00      0     0    0.00
# 185     ...       0.000000          1.000000     0.00      0     0    0.00
# 186     ...       0.000000          1.000000     0.00      0     0    0.00
# 187     ...       0.000000          1.000000     0.00      0     0    0.00
# 188     ...       0.000000          1.000000     0.00      0     0    0.00
# 189     ...       0.000000          1.000000     0.00      0     0    0.00
# 190     ...       0.000000          1.000000     0.00      0     0    0.00
# 191     ...       0.000000          1.000000     0.00      0     0    0.00
# 192     ...       0.000000          1.000000     0.00      0     0    0.00
# 193     ...       0.000000          1.000000     0.00      0     0    0.00
#
#      退款订单数  Unnamed: 33  Unnamed: 34  Unnamed: 35
# 0       14          NaN         SKU数   194.000000
# 1        0          NaN    30天动销SKU数    48.000000
# 2        0          NaN          动销%     0.247423
# 3        1          NaN          NaN          NaN
# 4        1          NaN          NaN          NaN
# 5        1          NaN          NaN          NaN
# 6        0          NaN          NaN          NaN
# 7        0          NaN          NaN          NaN
# 8        0          NaN          NaN          NaN
# 9        0          NaN          NaN          NaN
# 10       0          NaN          NaN          NaN
# 11       0          NaN          NaN          NaN
# 12       0          NaN          NaN          NaN
# 13       0          NaN          NaN          NaN
# 14       0          NaN          NaN          NaN
# 15       0          NaN          NaN          NaN
# 16       0          NaN          NaN          NaN
# 17       0          NaN          NaN          NaN
# 18       0          NaN          NaN          NaN
# 19       0          NaN          NaN          NaN
# 20       1          NaN          NaN          NaN
# 21       0          NaN          NaN          NaN
# 22       0          NaN          NaN          NaN
# 23       0          NaN          NaN          NaN
# 24       0          NaN          NaN          NaN
# 25       1          NaN          NaN          NaN
# 26       0          NaN          NaN          NaN
# 27       0          NaN          NaN          NaN
# 28       0          NaN          NaN          NaN
# 29       0          NaN          NaN          NaN
# ..     ...          ...          ...          ...
# 164      0          NaN          NaN          NaN
# 165      0          NaN          NaN          NaN
# 166      0          NaN          NaN          NaN
# 167      0          NaN          NaN          NaN
# 168      0          NaN          NaN          NaN
# 169      0          NaN          NaN          NaN
# 170      0          NaN          NaN          NaN
# 171      0          NaN          NaN          NaN
# 172      0          NaN          NaN          NaN
# 173      0          NaN          NaN          NaN
# 174      0          NaN          NaN          NaN
# 175      0          NaN          NaN          NaN
# 176      0          NaN          NaN          NaN
# 177      0          NaN          NaN          NaN
# 178      0          NaN          NaN          NaN
# 179      0          NaN          NaN          NaN
# 180      0          NaN          NaN          NaN
# 181      0          NaN          NaN          NaN
# 182      0          NaN          NaN          NaN
# 183      0          NaN          NaN          NaN
# 184      0          NaN          NaN          NaN
# 185      0          NaN          NaN          NaN
# 186      0          NaN          NaN          NaN
# 187      0          NaN          NaN          NaN
# 188      0          NaN          NaN          NaN
# 189      0          NaN          NaN          NaN
# 190      0          NaN          NaN          NaN
# 191      0          NaN          NaN          NaN
# 192      0          NaN          NaN          NaN
# 193      0          NaN          NaN          NaN
#
# [194 rows x 36 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['商品ID'][:40]:
for product_id in product_list['商品ID'][40:81]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    try:
        product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
        product_search_button.click()
        time.sleep(5)
        # 点击全选
        select_all_box = browser.find_element_by_id("checkbox-all")
        select_all_box.click()
        time.sleep(5)
    except Exception as err:
        print("Can't find this product: " + str(err))
        pass

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
