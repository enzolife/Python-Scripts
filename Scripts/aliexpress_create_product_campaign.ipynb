# %%
from selenium import webdriver
import pandas as pd
import time
import datetime
import os

# %%
# 屏幕最大化
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = ".//chrome_driver//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
browser.get('https://login.aliexpress.com/?flag=1&return_url=http%3A%2F%2Fmypromotion.aliexpress.com%2Fstore%2Flimiteddiscount%2Flist.htm')

# %%
# 切换到输入密码的iframe
browser.switch_to.frame('alibaba-login-box')

# %%
acc_password_class = ".fm-text"
acc_password_input_elem = browser.find_elements_by_css_selector(acc_password_class)
len(acc_password_input_elem)
# Out:
# 2

# %%
# 输入账户密码登录
acc_password_input_elem[0].click()
acc_password_input_elem[0].send_keys('15622252963@163.com')
acc_password_input_elem[1].click()
acc_password_input_elem[1].send_keys('932584162apple')
time.sleep(10)

# %%
# 点击登录
log_in_button = browser.find_element_by_css_selector('.fm-button.fm-submit')
type(log_in_button)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
log_in_button.click()

# %%
# 点击创建活动
time.sleep(10)
create_campaign_elem = '.list-operate-create.ui-button.ui-button-primary.ui-button-medium'
create_campaign_button = browser.find_element_by_css_selector(create_campaign_elem)
create_campaign_button.click()

# %%
# 活动信息填写
campaign_name = '20180523限时限量折扣(2)'
campaign_start_date = datetime.datetime(2018, 5, 24, 0, 0)
campaign_end_date = datetime.datetime(2018, 6, 6, 0, 0)

# %%
# 填写活动名
campaign_name_input = browser.find_element_by_css_selector(".promotion-title")
campaign_name_input.click()
campaign_name_input.send_keys(campaign_name)

# %%
# 点击开始日期
campaign_start_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_start_date_input[0].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_start_date.strftime('%Y/%m/%d') + '"]')[0].click()

# %%
# 点击结束日期
campaign_end_date_input = browser.find_elements_by_css_selector(".ui-textfield.ui-textfield-system.ui-calendar-trigger")
campaign_end_date_input[1].click()
# 选择日期
browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-360d8e838554> in <module>()
#       3 campaign_end_date_input[1].click()
#       4 # 选择日期
# ----> 5 browser.find_elements_by_xpath('//*[@title="'+ campaign_end_date.strftime('%Y/%m/%d') + '"]')[1].click()
#
# IndexError: list index out of range

# %%
# 点击提交
campaign_submit_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium")
campaign_submit_button.click()
time.sleep(10)

# %%
# 添加商品
add_product_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-medium.before-btn")
add_product_button.click()
time.sleep(10)

# %%
# 切换到输入product id的iframe
browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])

# %%
# 切换回主界面
browser.switch_to.default_content()

# %%
# product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
# product_id_input_box.get_attribute('id')

# %%
# 商品列表
product_list_path = "D://Program Files (x86)//百度云同步盘//Dropbox//-E·J- 2014.5.1//2015.2.18 速卖通//2016.11.26 速卖通数据分析//2016.12.18 速卖通商品分析.xlsm"
product_list = pd.read_excel(product_list_path, sheetname='商品分析')
product_list
# Out:
#             商品ID                                               商品标题     平台  \
# 0    32597758635  19V 4.74A 90W Universal Power Adapter Charger ...  TOTAL
# 1    32828507962  20V 3.25A 65W Universal USB Type C Laptop Mobi...  TOTAL
# 2    32487768278  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 3    32298664354  22.5V 1.25A 30W Power Adapter Charger For IRob...  TOTAL
# 4    32753723716  15V 16V 19V 19.5V 20V Auto Voltage Universal P...  TOTAL
# 5    32326661278  19V 4.74A 90W Laptop Universal Power Adapter C...  TOTAL
# 6    32484354951  20V 3.25A 65W AC Laptop Power Adapter Charger ...  TOTAL
# 7    32297759407  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# 8    32826554127  5V 9V 12V 15V 20V 65W Type C Laptop Mobile Pho...  TOTAL
# 9    32484544534  19V 4.74A 90W Ac Laptop Power Adapter Charger ...  TOTAL
# 10   32412624689  20V 2A 40W Laptop Ac Power Adapter Charger For...  TOTAL
# 11   32821187508  20V 4.5A 90W Long Type Laptop Power Adapter Ch...  TOTAL
# 12   32464656233  19V 2.37A 45W Laptop Ac Power Adapter Charger ...  TOTAL
# 13   32298294121  19.5V 2.31A 45W Laptop Ac Power Adapter Charge...  TOTAL
# 14   32899068443  26.1V 0.78A 20.3W Universal Power Adapter Char...  TOTAL
# 15   32743835649  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 16   32807609716  20V 4.5A 90W Power Adapter Charger For Lenovo ...  TOTAL
# 17   32296973236  19.5V 4.62A 90W Ac Power Adapter Charger For D...  TOTAL
# 18   32440656276  90W Laptop AC Universal Power Adapter Charger ...  TOTAL
# 19   32487732817  12V 3A 36W AC Laptop Car Power Adapter Charger...  TOTAL
# 20   32486535722  19V 1.75A 33W AC Laptop Power Adapter Charger ...  TOTAL
# 21   32464588670  19V 1.75A 33W Laptop Ac Power Adapter Charger ...  TOTAL
# 22   32741117749  20V 3.25A 65W Travel Power Adapter Charger For...  TOTAL
# 23   32602982934  19V 3.42A 65W Universal Power Adapter Charger ...  TOTAL
# 24   32802877834  20V 5V 2A 40W Portable Laptop Power Adapter Ch...  TOTAL
# 25   32441997730  45W Laptop AC Power Adapter Charger For Micros...  TOTAL
# 26   32297599525  19.5V 4.7A 90W Laptop Ac Power Adapter Charger...  TOTAL
# 27   32462046182  12V 1.5A 18W Ac Laptop Power Adapter Charger F...  TOTAL
# 28   32291851311  19V 4.74A Ac Laptop Power Adapter Charger For ...  TOTAL
# 29   32431966616  19.5V 3.33A 65W Laptop Ac Power Adapter Charge...  TOTAL
# ..           ...                                                ...    ...
# 160  32743178948  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 161  32808664944  12V 3.6A 48W Collapsible Portable Laptop Power...  TOTAL
# 162  32740986924  19V 2.37A 45W Laptop AC Travel Power Adapter C...  TOTAL
# 163  32441813994  45W Laptop Ac Power Adapter Charger For Toshib...  TOTAL
# 164  32296089863  19V 4.74A Laptop AC Power Adapter Charger For ...  TOTAL
# 165  32745259113  19V 3.42A 65W Laptop AC Travel Power Adapter C...  TOTAL
# 166  32740916653  19V 3.42A 65W Travel Power Adapter Charger For...  TOTAL
# 167  32298695838  19V 1.58A Laptop AC Power Adapter Charger For ...  TOTAL
# 168  32435638867  33W Laptop AC Power Adapter Charger For ASUS V...  TOTAL
# 169  32299304416  19V 1.58A 30W Laptop AC Power Adapter Charger ...  TOTAL
# 170  32781762868  19V 1.75A 33W Portable Travel Charger Power Ad...  TOTAL
# 171  32462223205  12V 3A 36W Laptop AC Power Adapter Charger For...  TOTAL
# 172  32297652061  12V 3.6A Power Adapter Charger Carregador Port...  TOTAL
# 173  32741840737  12V 3.6A 48W Travel Power Adapter Charger For ...  TOTAL
# 174  32465708359  19V 2.37A 45W Laptop AC Power Adapter Charger ...  TOTAL
# 175  32807949168  12V 2.58A 36W Collapsible Portable Laptop Powe...  TOTAL
# 176  32742975139  12V 2.58A 36W Laptop Travel Power Adapter Char...  TOTAL
# 177  32695681988  12V 2A 24W Laptop Power Adapter For Asus Noteb...  TOTAL
# 178  32483837073  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 179  32304508173  19V 4.74A 90W Power Adapter Charger For HP Lap...  TOTAL
# 180  32742975283  12V 3A 36W AC Laptop Travel Power Adapter Char...  TOTAL
# 181  32344557311  19V 1.58A Laptop AC Power Adapter Charger For ...  TOTAL
# 182  32343650161  12V 3.6A 45W Laptop AC Power Adapter For Micro...  TOTAL
# 183  32298632647  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 184  32696396222  19.5V 3.33A 65W Laptop AC Power Adapter For HP...  TOTAL
# 185  32719915375  USB Charging Cable For Lenovo Yoga 3 Yoga 4 Yo...  TOTAL
# 186  32483111961  19V 4.74A 90W AC Laptop Power Adapter Charger ...  TOTAL
# 187  32297057887  12V 2.58A 36W Car Power Adapter Charger For Mi...  TOTAL
# 188  32297041583  12V 2.58A 36W Power Adapter Charger For Micros...  TOTAL
# 189  32441439325  48W Ac Laptop Power Adapter Charger For Micros...  TOTAL
#
#      老买家支付买家数  老买家下单买家数  老买家支付金额  老买家支付订单数  老买家下单订单数 老买家浏览-下单转化率  老买家商品页访客数  \
# 0          22        23   410.42        23        24       9.91%        232
# 1           1         1    37.50         1         1       7.14%         14
# 2           2         2    18.87         2         2       3.57%         56
# 3           2         2    52.35         2         2      15.38%         13
# 4           1         1   101.23         1         1       9.09%         11
# 5           1         1    91.14         1         1       2.56%         39
# 6           2         2    38.37         2         2      15.38%         13
# 7           1         1    46.55         1         1       7.14%         14
# 8           0         0     0.00         0         0       0.00%          4
# 9           0         0     0.00         0         0       0.00%         22
# 10          1         1    17.00         1         1      10.00%         10
# 11          1         2    11.40         1         2      10.00%         20
# 12          1         1    58.86         1         1      16.67%          6
# 13          0         0     0.00         0         0       0.00%          7
# 14          1         1    13.20         1         1      33.33%          3
# 15          0         0     0.00         0         0       0.00%          4
# 16          0         0     0.00         0         0       0.00%          7
# 17          1         1    10.34         1         1      20.00%          5
# 18          0         0     0.00         0         0       0.00%          6
# 19          0         0     0.00         0         0       0.00%          5
# 20          1         1    31.50         1         1      25.00%          4
# 21          0         0     0.00         0         0       0.00%          5
# 22          0         0     0.00         0         0       0.00%          1
# 23          0         0     0.00         0         0       0.00%          1
# 24          0         0     0.00         0         0       0.00%          1
# 25          0         0     0.00         0         0       0.00%          0
# 26          1         1    10.49         1         1      16.67%          6
# 27          0         0     0.00         0         0       0.00%          3
# 28          0         0     0.00         0         0       0.00%          0
# 29          0         0     0.00         0         0       0.00%          2
# ..        ...       ...      ...       ...       ...         ...        ...
# 160         0         0     0.00         0         0       0.00%          2
# 161         0         0     0.00         0         0       0.00%          0
# 162         0         0     0.00         0         0       0.00%          0
# 163         0         0     0.00         0         0       0.00%          0
# 164         0         0     0.00         0         0       0.00%          3
# 165         0         0     0.00         0         0       0.00%          1
# 166         0         0     0.00         0         0       0.00%          0
# 167         0         0     0.00         0         0       0.00%          0
# 168         0         0     0.00         0         0       0.00%          1
# 169         0         0     0.00         0         0       0.00%          0
# 170         0         0     0.00         0         0       0.00%          0
# 171         0         0     0.00         0         0       0.00%          0
# 172         0         0     0.00         0         0       0.00%          0
# 173         0         0     0.00         0         0       0.00%          0
# 174         0         0     0.00         0         0       0.00%          0
# 175         0         0     0.00         0         0       0.00%          0
# 176         0         0     0.00         0         0       0.00%          0
# 177         0         0     0.00         0         0       0.00%          0
# 178         0         0     0.00         0         0       0.00%          0
# 179         0         0     0.00         0         0       0.00%          0
# 180         0         0     0.00         0         0       0.00%          0
# 181         0         0     0.00         0         0       0.00%          0
# 182         0         0     0.00         0         0       0.00%          0
# 183         0         0     0.00         0         0       0.00%          0
# 184         0         0     0.00         0         0       0.00%          1
# 185         0         0     0.00         0         0       0.00%          0
# 186         0         0     0.00         0         0       0.00%          1
# 187         0         0     0.00         0         0       0.00%          0
# 188         0         0     0.00         0         0       0.00%          0
# 189         0         0     0.00         0         0       0.00%          0
#
#         ...          支付金额     支付金额%  支付金额% Cumulative  风控订单数   风控金额    退款金额  \
# 0       ...       4835.99  0.626502          0.626502      0   0.00  153.82
# 1       ...        448.92  0.058158          0.684660      0   0.00    0.00
# 2       ...        382.12  0.049504          0.734163      0   0.00    9.60
# 3       ...        261.24  0.033844          0.768007      0   0.00    0.00
# 4       ...        193.13  0.025020          0.793027      1  18.44   36.88
# 5       ...        169.67  0.021981          0.815008      0   0.00    0.00
# 6       ...         98.38  0.012745          0.827753      0   0.00    0.00
# 7       ...         95.35  0.012353          0.840106      0   0.00    0.00
# 8       ...         86.45  0.011200          0.851305      0   0.00    0.00
# 9       ...         84.88  0.010996          0.862301      0   0.00    9.62
# 10      ...         76.50  0.009911          0.872212      0   0.00    0.00
# 11      ...         60.20  0.007799          0.880011      0   0.00    0.00
# 12      ...         58.86  0.007625          0.887636      0   0.00    0.00
# 13      ...         57.72  0.007478          0.895114      0   0.00    9.72
# 14      ...         52.32  0.006778          0.901892      0   0.00    0.00
# 15      ...         50.07  0.006487          0.908378      0   0.00   16.88
# 16      ...         44.70  0.005791          0.914169      0   0.00    0.00
# 17      ...         42.71  0.005533          0.919702      0   0.00    0.00
# 18      ...         41.49  0.005375          0.925077      0   0.00    0.00
# 19      ...         38.84  0.005032          0.930109      0   0.00    0.00
# 20      ...         31.50  0.004081          0.934190      0   0.00    0.00
# 21      ...         31.33  0.004059          0.938249      0   0.00    0.00
# 22      ...         30.00  0.003886          0.942135      0   0.00    0.00
# 23      ...         27.60  0.003576          0.945711      0   0.00    0.00
# 24      ...         25.78  0.003340          0.949051      0   0.00    0.00
# 25      ...         21.84  0.002829          0.951880      0   0.00    0.00
# 26      ...         21.13  0.002737          0.954617      0   0.00    0.00
# 27      ...         20.83  0.002699          0.957316      0   0.00   10.50
# 28      ...         19.52  0.002529          0.959845      0   0.00    0.00
# 29      ...         19.33  0.002504          0.962349      0   0.00    0.00
# ..      ...           ...       ...               ...    ...    ...     ...
# 160     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 161     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 162     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 163     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 164     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 165     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 166     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 167     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 168     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 169     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 170     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 171     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 172     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 173     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 174     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 175     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 176     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 177     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 178     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 179     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 180     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 181     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 182     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 183     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 184     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 185     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 186     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 187     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 188     ...          0.00  0.000000          1.000000      0   0.00    0.00
# 189     ...          0.00  0.000000          1.000000      0   0.00    0.00
#
#     退款订单数  Unnamed: 33  Unnamed: 34  Unnamed: 35
# 0      14          NaN         SKU数   190.000000
# 1       0          NaN    30天动销SKU数    52.000000
# 2       1          NaN          动销%     0.273684
# 3       0          NaN          NaN          NaN
# 4       3          NaN          NaN          NaN
# 5       0          NaN          NaN          NaN
# 6       0          NaN          NaN          NaN
# 7       1          NaN          NaN          NaN
# 8       0          NaN          NaN          NaN
# 9       1          NaN          NaN          NaN
# 10      0          NaN          NaN          NaN
# 11      0          NaN          NaN          NaN
# 12      0          NaN          NaN          NaN
# 13      1          NaN          NaN          NaN
# 14      0          NaN          NaN          NaN
# 15      1          NaN          NaN          NaN
# 16      0          NaN          NaN          NaN
# 17      0          NaN          NaN          NaN
# 18      0          NaN          NaN          NaN
# 19      0          NaN          NaN          NaN
# 20      0          NaN          NaN          NaN
# 21      0          NaN          NaN          NaN
# 22      0          NaN          NaN          NaN
# 23      0          NaN          NaN          NaN
# 24      0          NaN          NaN          NaN
# 25      0          NaN          NaN          NaN
# 26      0          NaN          NaN          NaN
# 27      1          NaN          NaN          NaN
# 28      0          NaN          NaN          NaN
# 29      0          NaN          NaN          NaN
# ..    ...          ...          ...          ...
# 160     0          NaN          NaN          NaN
# 161     0          NaN          NaN          NaN
# 162     0          NaN          NaN          NaN
# 163     0          NaN          NaN          NaN
# 164     0          NaN          NaN          NaN
# 165     0          NaN          NaN          NaN
# 166     0          NaN          NaN          NaN
# 167     0          NaN          NaN          NaN
# 168     0          NaN          NaN          NaN
# 169     0          NaN          NaN          NaN
# 170     0          NaN          NaN          NaN
# 171     0          NaN          NaN          NaN
# 172     0          NaN          NaN          NaN
# 173     0          NaN          NaN          NaN
# 174     0          NaN          NaN          NaN
# 175     0          NaN          NaN          NaN
# 176     0          NaN          NaN          NaN
# 177     0          NaN          NaN          NaN
# 178     0          NaN          NaN          NaN
# 179     0          NaN          NaN          NaN
# 180     0          NaN          NaN          NaN
# 181     0          NaN          NaN          NaN
# 182     0          NaN          NaN          NaN
# 183     0          NaN          NaN          NaN
# 184     0          NaN          NaN          NaN
# 185     0          NaN          NaN          NaN
# 186     0          NaN          NaN          NaN
# 187     0          NaN          NaN          NaN
# 188     0          NaN          NaN          NaN
# 189     0          NaN          NaN          NaN
#
# [190 rows x 36 columns]

# %%
# 切换回主界面
# browser.switch_to.default_content()

# %%
# for product_id in product_list['商品ID'][:40]:
for product_id in product_list['商品ID'][40:81]:
    # 切换回主界面
    browser.switch_to.default_content()
    # 切换到输入product id的iframe
    browser.switch_to.frame(browser.find_elements_by_xpath("//iframe[contains(@src,'productSelect')]")[-1])
    # 输入productid
    product_id_input_box = browser.find_elements_by_css_selector(".input-product.txt-tip")[0]
    product_id_input_box.clear()
    product_id_input_box.send_keys(int(product_id))
    # 点击搜索
    try:
        product_search_button = browser.find_element_by_css_selector(".ui-button.ui-button-primary.ui-button-small")
        product_search_button.click()
        time.sleep(5)
        # 点击全选
        select_all_box = browser.find_element_by_id("checkbox-all")
        select_all_box.click()
        time.sleep(5)
    except Exception as err:
        print("Can't find this product: " + str(err))
        pass

# submit_button_click = browser.find_elements_by_css_selector(".ui-button ui-button-primary.ui-button-medium")[-1]
# submit_button_click.click()
