# %%
from selenium import webdriver
import pandas as pd
import time

# %%
buyer_info_path = "D://comment_person_url_id.csv"
buyer_info = pd.read_csv(buyer_info_path)
buyer_info[:1]
# Out:
#    Unnamed: 0                comment_person_url
# 0           0  https://shopee.co.id/ruriinovita

# %%
'''
buyer_info_path = "D://comment_person_url.csv"
buyer_info = pd.read_csv(buyer_info_path)
buyer_info[:1]
'''
# Out:
# '\nbuyer_info_path = "D://comment_person_url.csv"\nbuyer_info = pd.read_csv(buyer_info_path)\nbuyer_info[:1]\n'

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path)

# %%
type(browser)
# Out:
# selenium.webdriver.chrome.webdriver.WebDriver

# %%
browser.get('https://shopee.co.id')
time.sleep(10)

# %%
LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
'''
有关Selenium Compound class names not permitted的错误
可以参考https://stackoverflow.com/questions/37771604/selenium-compound-class-names-not-permitted
使用css_selector解决即可
'''
LoginElem[1].text
# Out:
# 'Login'

# %%
# 点击登入，弹出账户密码输入框
LoginElem[1].click()

# %%
acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
try:
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('tengus.id')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('tengus1803')
except:
    time.sleep(30)
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('tengus.id')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('tengus1803')

# %%
time.sleep(10)
Login_buttom_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
Login_buttom_elem[1].text
# Out:
# 'LOGIN'

# %%
time.sleep(10)
Login_buttom_elem[1].click()

# %%
# for website in buyer_info[1001:1500]["comment_person_url"]:
# for website in buyer_info[1501:2000]["comment_person_url"]:
# for website in buyer_info[2001:2500]["concat"]:
for website in buyer_info[3001:3500]["comment_person_url"]:  
    browser.get(website)
    time.sleep(10)
    try:
        elem = browser.find_element_by_class_name('section-seller-overview-horizontal__icon')
        print('Found <%s> element with that class name!' % (elem.tag_name))
        elem.click()
        print(website + ' is clicked.')
    except:
        print('Was not able to find an element with that name in ' + website)
# Out:
# Was not able to find an element with that name in https://shopee.co.id/evapurbaya
# Found <span> element with that class name!
# https://shopee.co.id/ridahindasah is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/unconkbe is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/diana008 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/balqisputry is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/rezamayang is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/mudjipur is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/hsptr is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/achiargavi16 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/nellyjuju is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/faeyzzqaandyka is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/giskadieno is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/mayasalsabilsalwa is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/susie_yazzrens is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ari_husen is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/irmapurwariutami is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/mytha29 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/irmasitirahayu is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/adeah is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/khodijahalrosadi is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/aspiadel1987 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/marthawie is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/riwendamega is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/verasaman12 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/dhezyshinta20 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/lyayulia83 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/sarifitriaamalia is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/lulurana03 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/dica.fitri.ladona is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/alyaaliando10 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/azkanxacaneme is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/fikhatika is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/tiaraemiliasari24 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ranisoraya90 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/sushanibrohim is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/rooney5553 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/gugi. is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/indrayanidamanik is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ikecindia is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/reisya99 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/erysa_herdiana2207 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/uni_lestari is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/dedehdayana92 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/delvaniamizaryusma is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/nayyarachan is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/nukepradengska31 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/wiwit_widiastuti is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/zubaidahhamid is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/etikjie is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/astrisudrajattt is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/fi3lie is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/tarioryzasativa is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/go.fast.fashion.limited is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/pipi072 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/auliaoktavianty is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/nurheni11 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/sadlycarefa is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/lia.pratiwi1990 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/cristinchazolla is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/lisaaina is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/hartatiksri55 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ekamayarnoorhayati is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/adzkiariyadi is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/jangguik is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/styani_lestari is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/debbyshoope is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/vikyhamadi is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/aeeeni is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/endahhernandah is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/aufa_shop03 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/zula_afandi is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/atikpusposari is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ekawahyuni10 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/dianadeedgr is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/geraldy87 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/asihciptani88 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/aangk001 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ulinnuha_ is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/acepnanang is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/sugara81kint is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/oktavianiyuniaa is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/damayantisetyoaryani is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/lia_adelet is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/firnarahma is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/iznawatie is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/ellenstipana is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/maya24022017 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/maulinatris is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/fitriani260588 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/mitasafi is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/bazlinizam17 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/loanita is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/sitinur05_ is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/fauziah_tasa84 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/sahrulsumantri is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/annisamulya0401 is clicked.
# Found <span> element with that class name!
# https://shopee.co.id/