# %%
import pandas as pd

# %%
file_to_send = pd.read_csv("D:\\file_to_send.csv")

# %%
file_to_send.head()
# Out:
#    Unnamed: 0   user id password        date  \
# 0           0  95642188  ure49sc  2018-10-25
# 1           2  95256579  chs0g5e  2018-10-25
# 2           3  95158276  cefh0u8  2018-10-25
# 3           4  95961094  mqw7x3n  2018-10-25
# 4           5  95698958  7uy46hr  2018-10-25
#
#                 decision_maker_email                final_email_to_send  \
# 0                                NaN                   xuanmu_j@163.com
# 1                                NaN        yks-jimmyjiang@youkeshu.com
# 2                                NaN                    jameszx@163.com
# 3  867319361@qq.com,867319361@qq.com  867319361@qq.com,867319361@qq.com
# 4                                NaN        btflightingwish@outlook.com
#
#      gp_account_id gp_account_name_x gp_account_name_y gp_account_owner  \
# 0  0010K00001u6paK     深圳市漩沐商贸有限责任公司     深圳市漩沐商贸有限责任公司      Mei Wenjuan
# 1  0010K00001u6Y8E    深圳市宏欣本电子商务有限公司    深圳市宏欣本电子商务有限公司      Shelly Zhuo
# ...

# %%
file_to_send['gp_account_id_short'] = file_to_send['gp_account_id'].str[:-3]
file_to_send.head()
# Out:
#    Unnamed: 0   user id password        date  \
# 0           0  95642188  ure49sc  2018-10-25
# 1           2  95256579  chs0g5e  2018-10-25
# 2           3  95158276  cefh0u8  2018-10-25
# 3           4  95961094  mqw7x3n  2018-10-25
# 4           5  95698958  7uy46hr  2018-10-25
#
#                 decision_maker_email                final_email_to_send  \
# 0                                NaN                   xuanmu_j@163.com
# 1                                NaN        yks-jimmyjiang@youkeshu.com
# 2                                NaN                    jameszx@163.com
# 3  867319361@qq.com,867319361@qq.com  867319361@qq.com,867319361@qq.com
# 4                                NaN        btflightingwish@outlook.com
#
#      gp_account_id gp_account_name_x gp_account_name_y gp_account_owner  \
# 0  0010K00001u6paK     深圳市漩沐商贸有限责任公司     深圳市漩沐商贸有限责任公司      Mei Wenjuan
# 1  0010K00001u6Y8E    深圳市宏欣本电子商务有限公司    深圳市宏欣本电子商务有限公司      Shelly Zhuo
# ...

# %%
file_to_send = file_to_send[['gp_account_id', 'gp_account_name_x']]
file_to_send
# Out:
#         gp_account_id  gp_account_name_x
# 0     0010K00001u6paK      深圳市漩沐商贸有限责任公司
# 1     0010K00001u6Y8E     深圳市宏欣本电子商务有限公司
# 2     0010K00001qA6UT      泉州市雄鑫电子科技有限公司
# 3     0010K00001deR7S         深圳星生电子有限公司
# 4     0010K00001u74T3     深圳市糊糊蝶照明科技有限公司
# 5     0010K00001tg57n      合肥耕式链电子科技有限公司
# 6     0010K00001kAIoa       上海贲腾网络科技有限公司
# 7     0010K00001u7e83       福州将夜网络科技有限公司
# 8     0010K00001tgjxc       绍兴泽雅文化传播有限公司
# 9     0010K00001u6Y1N      深圳市思晨电子商务有限公司
# 10    0010K00001u6Y1N      深圳市思晨电子商务有限公司
# 11    0010K00001u6Y52      深圳市超兴电子商务有限公司
# 12    0010K00001u6ptJ        新余市凯容贸易有限公司
# 13    0010K00001u6Y52      深圳市超兴电子商务有限公司
# 14    0010K00001u80ir   莆田市城厢区阿丽达达贸易有限公司
# 15    0010K00001rb7uL        郑州市派罗商贸有限公司
# 16    0010K00001u6Y52      深圳市超兴电子商务有限公司
# 17    0010K00001oT4uP     上海翼翎数据信息技术有限公司
# 18    0010K00001u6p1W     福建鹭优速进出口贸易有限公司
# 19    0012800001J1pHr           Chaoshen
# 20    0010K00001u7ugt        莆田市互联贸易有限公司
# 21    0010K00001tgkZu         沭阳昊妍贸易有限公司
# ...

# %%
def get_jalwar_1():
    print('你好啊泽华')
    
zehua = get_jalwar_1()
print(zehua)
# Out:
# 你好啊泽华
# None

# %%
def get_jalwar_2():
    return '你好啊泽华'
    
zehua = get_jalwar_2()
print(zehua)
# Out:
# 你好啊泽华

# %%
import logging
logging.basicConfig(level=logging.INFO, format=' %(asctime)s - %(levelname)s - %(message)s')

logging.info("你好啊泽华")
# Out:
#  2018-11-01 15:56:07,568 - INFO - 你好啊泽华

# %%
print("你好啊泽华")
# Out:
# 你好啊泽华
