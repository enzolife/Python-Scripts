# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

# %%
# 屏幕最大化，且指定下载目录
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

prefs = {"profile.default_content_settings.popups": 0,
         "directory_upgrade": True}
options.add_experimental_option("prefs", prefs)

# %%
# 使用chromedriver才可以用开发者权限
chrome_driver_path = "D://Program Files (x86)//百度云同步盘//我的软件//chromedriver.exe"
browser = webdriver.Chrome(chrome_driver_path, chrome_options=options)

# %%
# main page
main_page_url = "http://shopee.co.id"
browser.get(main_page_url)

# remove ads, refresh again
browser.get(main_page_url)
time.sleep(10)

# %%
# login
LoginElem = browser.find_elements_by_css_selector('.navbar__link.navbar__link--account.navbar__link--tappable.navbar__link--hoverable.navbar__link-text.navbar__link-text--medium')
'''
有关Selenium Compound class names not permitted的错误
可以参考https://stackoverflow.com/questions/37771604/selenium-compound-class-names-not-permitted
使用css_selector解决即可
'''
# 点击登入，弹出账户密码输入框
LoginElem[1].click()
time.sleep(10)

# %%
acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
try:
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('tengus.id')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('tengus1803')
except:
    time.sleep(30)
    acc_password_input_elem = browser.find_elements_by_css_selector('.input-with-status__input')
    acc_password_input_elem[0].click()
    acc_password_input_elem[0].send_keys('tengus.id')
    acc_password_input_elem[1].click()
    acc_password_input_elem[1].send_keys('tengus1803')
time.sleep(10)

# %%
Login_button_elem = browser.find_elements_by_css_selector('.shopee-button-solid.shopee-button-solid--primary')
time.sleep(10)
Login_button_elem[0].click()

# %%
# change current tab size
# browser.set_window_size(400, 862)

# %%
# switch to my fans list
my_fans_list_page = 'https://shopee.co.id/shop/59846508/following/?__classic__=1'
browser.get(my_fans_list_page)

# %%
# cancel certain number of following fans
to_cancel_num_of_following = 400
num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))

# page down until we get at least 400 fans to cancel
while num_of_following_display <= 500:
    body = browser.find_element_by_css_selector('body')
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(5)
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))

# %%
following_buttons = browser.find_elements_by_css_selector('.btn-follow.active.follow.L14')

# %%
browser.maximize_window()
time.sleep(5)

# page up to the top
scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)

# %%
i = 0
total_cancel_num_of_following = to_cancel_num_of_following
while i <= total_cancel_num_of_following - 1:
    while to_cancel_num_of_following > 0:
        print('Now run the ' + str(i + 1) + ' time.')
        if following_buttons[i].text == '关注中':
            shopid = following_buttons[i].get_attribute('shopid')
            following_buttons[i].click()
            time.sleep(5)
            to_cancel_num_of_following -= 1
            i += 1
            print(str(shopid) + ' is not following now, ' + str(to_cancel_num_of_following) + ' following remains.')
# Out:
# Now run the 1 time.
# 48296771 is not following now, 399 following remains.
# Now run the 2 time.
# 3104144 is not following now, 398 following remains.
# Now run the 3 time.
# 4142429 is not following now, 397 following remains.
# Now run the 4 time.
# 48066138 is not following now, 396 following remains.
# Now run the 5 time.
# 60875244 is not following now, 395 following remains.
# Now run the 6 time.
# 12615728 is not following now, 394 following remains.
# Now run the 7 time.
# 33134325 is not following now, 393 following remains.
# Now run the 8 time.
# 8821512 is not following now, 392 following remains.
# Now run the 9 time.
# 37546951 is not following now, 391 following remains.
# Now run the 10 time.
# 12848815 is not following now, 390 following remains.
# Now run the 11 time.
# 3862655 is not following now, 389 following remains.
# Now run the 12 time.
# 10163197 is not following now, 388 following remains.
# Now run the 13 time.
# 20003431 is not following now, 387 following remains.
# Now run the 14 time.
# 66122659 is not following now, 386 following remains.
# Now run the 15 time.
# 53099393 is not following now, 385 following remains.
# Now run the 16 time.
# 9438123 is not following now, 384 following remains.
# Now run the 17 time.
# 65025358 is not following now, 383 following remains.
# Now run the 18 time.
# 13653344 is not following now, 382 following remains.
# Now run the 19 time.
# 7062120 is not following now, 381 following remains.
# Now run the 20 time.
# 34792302 is not following now, 380 following remains.
# Now run the 21 time.
# 39066419 is not following now, 379 following remains.
# Now run the 22 time.
# 46125986 is not following now, 378 following remains.
# Now run the 23 time.
# 61034865 is not following now, 377 following remains.
# Now run the 24 time.
# 65678501 is not following now, 376 following remains.
# Now run the 25 time.
# 61863050 is not following now, 375 following remains.
# Now run the 26 time.
# 13355632 is not following now, 374 following remains.
# Now run the 27 time.
# 26924443 is not following now, 373 following remains.
# Now run the 28 time.
# 38310788 is not following now, 372 following remains.
# Now run the 29 time.
# 31692895 is not following now, 371 following remains.
# Now run the 30 time.
# 8001593 is not following now, 370 following remains.
# Now run the 31 time.
# 34028888 is not following now, 369 following remains.
# Now run the 32 time.
# 67479991 is not following now, 368 following remains.
# Now run the 33 time.
# 39848803 is not following now, 367 following remains.
# Now run the 34 time.
# 4161894 is not following now, 366 following remains.
# Now run the 35 time.
# 27709580 is not following now, 365 following remains.
# Now run the 36 time.
# 17138456 is not following now, 364 following remains.
# Now run the 37 time.
# 64749840 is not following now, 363 following remains.
# Now run the 38 time.
# 5210856 is not following now, 362 following remains.
# Now run the 39 time.
# 14636998 is not following now, 361 following remains.
# Now run the 40 time.
# 24495795 is not following now, 360 following remains.
# Now run the 41 time.
# 41311802 is not following now, 359 following remains.
# Now run the 42 time.
# 68270487 is not following now, 358 following remains.
# Now run the 43 time.
# 53049798 is not following now, 357 following remains.
# Now run the 44 time.
# 9681143 is not following now, 356 following remains.
# Now run the 45 time.
# 54981628 is not following now, 355 following remains.
# Now run the 46 time.
# 68175215 is not following now, 354 following remains.
# Now run the 47 time.
# 41039203 is not following now, 353 following remains.
# Now run the 48 time.
# 4932301 is not following now, 352 following remains.
# Now run the 49 time.
# 42406991 is not following now, 351 following remains.
# Now run the 50 time.
# 58468649 is not following now, 350 following remains.
# Now run the 51 time.
# 64420349 is not following now, 349 following remains.
# Now run the 52 time.
# 16913026 is not following now, 348 following remains.
# Now run the 53 time.
# 12834264 is not following now, 347 following remains.
# Now run the 54 time.
# 20202375 is not following now, 346 following remains.
# Now run the 55 time.
# 29054926 is not following now, 345 following remains.
# Now run the 56 time.
# 29948521 is not following now, 344 following remains.
# Now run the 57 time.
# 43783673 is not following now, 343 following remains.
# Now run the 58 time.
# 61554790 is not following now, 342 following remains.
# Now run the 59 time.
# 19530295 is not following now, 341 following remains.
# Now run the 60 time.
# 61218579 is not following now, 340 following remains.
# Now run the 61 time.
# 67383335 is not following now, 339 following remains.
# Now run the 62 time.
# 52927278 is not following now, 338 following remains.
# Now run the 63 time.
# 42300648 is not following now, 337 following remains.
# Now run the 64 time.
# 68315312 is not following now, 336 following remains.
# Now run the 65 time.
# 6742965 is not following now, 335 following remains.
# Now run the 66 time.
# 35907931 is not following now, 334 following remains.
# Now run the 67 time.
# 68093335 is not following now, 333 following remains.
# Now run the 68 time.
# 13341335 is not following now, 332 following remains.
# Now run the 69 time.
# 14649369 is not following now, 331 following remains.
# Now run the 70 time.
# 18162462 is not following now, 330 following remains.
# Now run the 71 time.
# 25247307 is not following now, 329 following remains.
# Now run the 72 time.
# 51204538 is not following now, 328 following remains.
# Now run the 73 time.
# 68054589 is not following now, 327 following remains.
# Now run the 74 time.
# 35149354 is not following now, 326 following remains.
# Now run the 75 time.
# 67472493 is not following now, 325 following remains.
# Now run the 76 time.
# 35076643 is not following now, 324 following remains.
# Now run the 77 time.
# 67430597 is not following now, 323 following remains.
# Now run the 78 time.
# 68391636 is not following now, 322 following remains.
# Now run the 79 time.
# 354651 is not following now, 321 following remains.
# Now run the 80 time.
# 22185567 is not following now, 320 following remains.
# Now run the 81 time.
# 15021550 is not following now, 319 following remains.
# Now run the 82 time.
# 64169571 is not following now, 318 following remains.
# Now run the 83 time.
# 54702807 is not following now, 317 following remains.
# Now run the 84 time.
# 68391973 is not following now, 316 following remains.
# Now run the 85 time.
# 42609695 is not following now, 315 following remains.
# Now run the 86 time.
# 65553019 is not following now, 314 following remains.
# Now run the 87 time.
# 49955283 is not following now, 313 following remains.
# Now run the 88 time.
# 18364591 is not following now, 312 following remains.
# Now run the 89 time.
# 19117627 is not following now, 311 following remains.
# Now run the 90 time.
# 12424819 is not following now, 310 following remains.
# Now run the 91 time.
# 38498679 is not following now, 309 following remains.
# Now run the 92 time.
# 65019859 is not following now, 308 following remains.
# Now run the 93 time.
# 44734597 is not following now, 307 following remains.
# Now run the 94 time.
# 18302714 is not following now, 306 following remains.
# Now run the 95 time.
# 10811038 is not following now, 305 following remains.
# Now run the 96 time.
# 62912977 is not following now, 304 following remains.
# Now run the 97 time.
# 24439312 is not following now, 303 following remains.
# Now run the 98 time.
# 22689122 is not following now, 302 following remains.
# Now run the 99 time.
# 54442800 is not following now, 301 following remains.
# Now run the 100 time.
# 57070509 is not following now, 300 following remains.
# Now run the 101 time.
# 58872851 is not following now, 299 following remains.
# Now run the 102 time.
# 42404245 is not following now, 298 following remains.
# Now run the 103 time.
# 62435412 is not following now, 297 following remains.
# Now run the 104 time.
# 25831851 is not following now, 296 following remains.
# Now run the 105 time.
# 30861810 is not following now, 295 following remains.
# Now run the 106 time.
# 67799915 is not following now, 294 following remains.
# Now run the 107 time.
# 10943680 is not following now, 293 following remains.
# Now run the 108 time.
# 68250858 is not following now, 292 following remains.
# Now run the 109 time.
# 32873054 is not following now, 291 following remains.
# Now run the 110 time.
# 60513258 is not following now, 290 following remains.
# Now run the 111 time.
# 31806073 is not following now, 289 following remains.
# Now run the 112 time.
# 42370678 is not following now, 288 following remains.
# Now run the 113 time.
# 11989871 is not following now, 287 following remains.
# Now run the 114 time.
# 52536673 is not following now, 286 following remains.
# Now run the 115 time.
# 58347180 is not following now, 285 following remains.
# Now run the 116 time.
# 67375008 is not following now, 284 following remains.
# Now run the 117 time.
# 15323114 is not following now, 283 following remains.
# Now run the 118 time.
# 43020360 is not following now, 282 following remains.
# Now run the 119 time.
# 68153974 is not following now, 281 following remains.
# Now run the 120 time.
# 39021351 is not following now, 280 following remains.
# Now run the 121 time.
# 68393969 is not following now, 279 following remains.
# Now run the 122 time.
# 18920422 is not following now, 278 following remains.
# Now run the 123 time.
# 68095162 is not following now, 277 following remains.
# Now run the 124 time.
# 5747586 is not following now, 276 following remains.
# Now run the 125 time.
# 56185536 is not following now, 275 following remains.
# Now run the 126 time.
# 67764117 is not following now, 274 following remains.
# Now run the 127 time.
# 52341632 is not following now, 273 following remains.
# Now run the 128 time.
# 46141198 is not following now, 272 following remains.
# Now run the 129 time.
# 66168442 is not following now, 271 following remains.
# Now run the 130 time.
# 4974353 is not following now, 270 following remains.
# Now run the 131 time.
# 23712328 is not following now, 269 following remains.
# Now run the 132 time.
# 62802115 is not following now, 268 following remains.
# Now run the 133 time.
# 40317255 is not following now, 267 following remains.
# Now run the 134 time.
# 50076235 is not following now, 266 following remains.
# Now run the 135 time.
# 9379528 is not following now, 265 following remains.
# Now run the 136 time.
# 24512389 is not following now, 264 following remains.
# Now run the 137 time.
# 58404000 is not following now, 263 following remains.
# Now run the 138 time.
# 3853946 is not following now, 262 following remains.
# Now run the 139 time.
# 41328702 is not following now, 261 following remains.
# Now run the 140 time.
# 5916780 is not following now, 260 following remains.
# Now run the 141 time.
# 33854505 is not following now, 259 following remains.
# Now run the 142 time.
# 15601606 is not following now, 258 following remains.
# Now run the 143 time.
# 21023366 is not following now, 257 following remains.
# Now run the 144 time.
# 11354020 is not following now, 256 following remains.
# Now run the 145 time.
# 55246360 is not following now, 255 following remains.
# Now run the 146 time.
# 13505885 is not following now, 254 following remains.
# Now run the 147 time.
# 31204166 is not following now, 253 following remains.
# Now run the 148 time.
# 6254284 is not following now, 252 following remains.
# Now run the 149 time.
# 20169535 is not following now, 251 following remains.
# Now run the 150 time.
# 15205643 is not following now, 250 following remains.
# Now run the 151 time.
# 57391116 is not following now, 249 following remains.
# Now run the 152 time.
# 51733822 is not following now, 248 following remains.
# Now run the 153 time.
# 9735161 is not following now, 247 following remains.
# Now run the 154 time.
# 68395724 is not following now, 246 following remains.
# Now run the 155 time.
# 36716760 is not following now, 245 following remains.
# Now run the 156 time.
# 11209905 is not following now, 244 following remains.
# Now run the 157 time.
# 31258710 is not following now, 243 following remains.
# Now run the 158 time.
# 67763416 is not following now, 242 following remains.
# Now run the 159 time.
# 62553044 is not following now, 241 following remains.
# Now run the 160 time.
# 7982627 is not following now, 240 following remains.
# Now run the 161 time.
# 24245157 is not following now, 239 following remains.
# Now run the 162 time.
# 22643276 is not following now, 238 following remains.
# Now run the 163 time.
# 54642273 is not following now, 237 following remains.
# Now run the 164 time.
# 19320209 is not following now, 236 following remains.
# Now run the 165 time.
# 23607543 is not following now, 235 following remains.
# Now run the 166 time.
# 67494018 is not following now, 234 following remains.
# Now run the 167 time.
# 58907681 is not following now, 233 following remains.
# Now run the 168 time.
# 46373186 is not following now, 232 following remains.
# Now run the 169 time.
# 24902256 is not following now, 231 following remains.
# Now run the 170 time.
# 27524198 is not following now, 230 following remains.
# Now run the 171 time.
# 28819334 is not following now, 229 following remains.
# Now run the 172 time.
# 68387649 is not following now, 228 following remains.
# Now run the 173 time.
# 6231440 is not following now, 227 following remains.
# Now run the 174 time.
# 12220595 is not following now, 226 following remains.
# Now run the 175 time.
# 57199743 is not following now, 225 following remains.
# Now run the 176 time.
# 6854899 is not following now, 224 following remains.
# Now run the 177 time.
# 17666027 is not following now, 223 following remains.
# Now run the 178 time.
# 7636106 is not following now, 222 following remains.
# Now run the 179 time.
# 8760152 is not following now, 221 following remains.
# Now run the 180 time.
# 5973039 is not following now, 220 following remains.
# Now run the 181 time.
# 36153305 is not following now, 219 following remains.
# Now run the 182 time.
# 30834039 is not following now, 218 following remains.
# Now run the 183 time.
# 198734 is not following now, 217 following remains.
# Now run the 184 time.
# 21341598 is not following now, 216 following remains.
# Now run the 185 time.
# 6189620 is not following now, 215 following remains.
# Now run the 186 time.
# 10792393 is not following now, 214 following remains.
# Now run the 187 time.
# 65749193 is not following now, 213 following remains.
# Now run the 188 time.
# 44692989 is not following now, 212 following remains.
# Now run the 189 time.
# 37977070 is not following now, 211 following remains.
# Now run the 190 time.
# 14170237 is not following now, 210 following remains.
# Now run the 191 time.
# 67941935 is not following now, 209 following remains.
# Now run the 192 time.
# 21806440 is not following now, 208 following remains.
# Now run the 193 time.
# 54492630 is not following now, 207 following remains.
# Now run the 194 time.
# 49074262 is not following now, 206 following remains.
# Now run the 195 time.
# 22681035 is not following now, 205 following remains.
# Now run the 196 time.
# 60510429 is not following now, 204 following remains.
# Now run the 197 time.
# 3521921 is not following now, 203 following remains.
# Now run the 198 time.
# 12338463 is not following now, 202 following remains.
# Now run the 199 time.
# 68399485 is not following now, 201 following remains.
# Now run the 200 time.
# 11455961 is not following now, 200 following remains.
# Now run the 201 time.
# 66128315 is not following now, 199 following remains.
# Now run the 202 time.
# 18830136 is not following now, 198 following remains.
# Now run the 203 time.
# 44753816 is not following now, 197 following remains.
# Now run the 204 time.
# 67687469 is not following now, 196 following remains.
# Now run the 205 time.
# 1785758 is not following now, 195 following remains.
# Now run the 206 time.
# 54064439 is not following now, 194 following remains.
# Now run the 207 time.
# 63484758 is not following now, 193 following remains.
# Now run the 208 time.
# 34542572 is not following now, 192 following remains.
# Now run the 209 time.
# 22296871 is not following now, 191 following remains.
# Now run the 210 time.
# 64561500 is not following now, 190 following remains.
# Now run the 211 time.
# 65688238 is not following now, 189 following remains.
# Now run the 212 time.
# 68233381 is not following now, 188 following remains.
# Now run the 213 time.
# 35012479 is not following now, 187 following remains.
# Now run the 214 time.
# 44838510 is not following now, 186 following remains.
# Now run the 215 time.
# 21305423 is not following now, 185 following remains.
# Now run the 216 time.
# 63004315 is not following now, 184 following remains.
# Now run the 217 time.
# 63001608 is not following now, 183 following remains.
# Now run the 218 time.
# 66347217 is not following now, 182 following remains.
# Now run the 219 time.
# 62480224 is not following now, 181 following remains.
# Now run the 220 time.
# 31307996 is not following now, 180 following remains.
# Now run the 221 time.
# 13661581 is not following now, 179 following remains.
# Now run the 222 time.
# 39130845 is not following now, 178 following remains.
# Now run the 223 time.
# 52409852 is not following now, 177 following remains.
# Now run the 224 time.
# 16918102 is not following now, 176 following remains.
# Now run the 225 time.
# 51066060 is not following now, 175 following remains.
# Now run the 226 time.
# 66837004 is not following now, 174 following remains.
# Now run the 227 time.
# 68363236 is not following now, 173 following remains.
# Now run the 228 time.
# 18478813 is not following now, 172 following remains.
# Now run the 229 time.
# 33173792 is not following now, 171 following remains.
# Now run the 230 time.
# 3772955 is not following now, 170 following remains.
# Now run the 231 time.
# 31506890 is not following now, 169 following remains.
# Now run the 232 time.
# 68401065 is not following now, 168 following remains.
# Now run the 233 time.
# 49636437 is not following now, 167 following remains.
# Now run the 234 time.
# 14287655 is not following now, 166 following remains.
# Now run the 235 time.
# 8862088 is not following now, 165 following remains.
# Now run the 236 time.
# 65666181 is not following now, 164 following remains.
# Now run the 237 time.
# 6438750 is not following now, 163 following remains.
# Now run the 238 time.
# 25062533 is not following now, 162 following remains.
# Now run the 239 time.
# 55996535 is not following now, 161 following remains.
# Now run the 240 time.
# 68267748 is not following now, 160 following remains.
# Now run the 241 time.
# 31343308 is not following now, 159 following remains.
# Now run the 242 time.
# 38381479 is not following now, 158 following remains.
# Now run the 243 time.
# 40854258 is not following now, 157 following remains.
# Now run the 244 time.
# 65743120 is not following now, 156 following remains.
# Now run the 245 time.
# 26083650 is not following now, 155 following remains.
# Now run the 246 time.
# 42993927 is not following now, 154 following remains.
# Now run the 247 time.
# 50704328 is not following now, 153 following remains.
# Now run the 248 time.
# 68403000 is not following now, 152 following remains.
# Now run the 249 time.
# 37721914 is not following now, 151 following remains.
# Now run the 250 time.
# 59996003 is not following now, 150 following remains.
# Now run the 251 time.
# 67974463 is not following now, 149 following remains.
# Now run the 252 time.
# 64901284 is not following now, 148 following remains.
# Now run the 253 time.
# 65432308 is not following now, 147 following remains.
# Now run the 254 time.
# 21036879 is not following now, 146 following remains.
# Now run the 255 time.
# 53420646 is not following now, 145 following remains.
# Now run the 256 time.
# 55061377 is not following now, 144 following remains.
# Now run the 257 time.
# 63864348 is not following now, 143 following remains.
# Now run the 258 time.
# 50479355 is not following now, 142 following remains.
# Now run the 259 time.
# 49734674 is not following now, 141 following remains.
# Now run the 260 time.
# 16624488 is not following now, 140 following remains.
# Now run the 261 time.
# 65298762 is not following now, 139 following remains.
# Now run the 262 time.
# 67596294 is not following now, 138 following remains.
# Now run the 263 time.
# 9047752 is not following now, 137 following remains.
# Now run the 264 time.
# 52296550 is not following now, 136 following remains.
# Now run the 265 time.
# 17681803 is not following now, 135 following remains.
# Now run the 266 time.
# 4914019 is not following now, 134 following remains.
# Now run the 267 time.
# 53940781 is not following now, 133 following remains.
# Now run the 268 time.
# 12405242 is not following now, 132 following remains.
# Now run the 269 time.
# 34045370 is not following now, 131 following remains.
# Now run the 270 time.
# 48846598 is not following now, 130 following remains.
# Now run the 271 time.
# 328576 is not following now, 129 following remains.
# Now run the 272 time.
# 26617029 is not following now, 128 following remains.
# Now run the 273 time.
# 66953940 is not following now, 127 following remains.
# Now run the 274 time.
# 44199617 is not following now, 126 following remains.
# Now run the 275 time.
# 50048293 is not following now, 125 following remains.
# Now run the 276 time.
# 37273979 is not following now, 124 following remains.
# Now run the 277 time.
# 28870164 is not following now, 123 following remains.
# Now run the 278 time.
# 25522333 is not following now, 122 following remains.
# Now run the 279 time.
# 55228007 is not following now, 121 following remains.
# Now run the 280 time.
# 10847026 is not following now, 120 following remains.
# Now run the 281 time.
# 6842665 is not following now, 119 following remains.
# Now run the 282 time.
# 18971654 is not following now, 118 following remains.
# Now run the 283 time.
# 66939750 is not following now, 117 following remains.
# Now run the 284 time.
# 54707959 is not following now, 116 following remains.
# Now run the 285 time.
# 16181682 is not following now, 115 following remains.
# Now run the 286 time.
# 56993864 is not following now, 114 following remains.
# Now run the 287 time.
# 56414698 is not following now, 113 following remains.
# Now run the 288 time.
# 67273260 is not following now, 112 following remains.
# Now run the 289 time.
# 6511343 is not following now, 111 following remains.
# Now run the 290 time.
# 14227630 is not following now, 110 following remains.
# Now run the 291 time.
# 49521026 is not following now, 109 following remains.
# Now run the 292 time.
# 45371600 is not following now, 108 following remains.
# Now run the 293 time.
# 16245067 is not following now, 107 following remains.
# Now run the 294 time.
# 66333235 is not following now, 106 following remains.
# Now run the 295 time.
# 68260048 is not following now, 105 following remains.
# Now run the 296 time.
# 66740931 is not following now, 104 following remains.
# Now run the 297 time.
# 45611296 is not following now, 103 following remains.
# Now run the 298 time.
# 33444203 is not following now, 102 following remains.
# Now run the 299 time.
# 66377909 is not following now, 101 following remains.
# Now run the 300 time.
# 30233818 is not following now, 100 following remains.
# Now run the 301 time.
# 56901917 is not following now, 99 following remains.
# Now run the 302 time.
# 16524781 is not following now, 98 following remains.
# Now run the 303 time.
# 28259188 is not following now, 97 following remains.
# Now run the 304 time.
# 40927544 is not following now, 96 following remains.
# Now run the 305 time.
# 66758402 is not following now, 95 following remains.
# Now run the 306 time.
# 34609311 is not following now, 94 following remains.
# Now run the 307 time.
# 3753514 is not following now, 93 following remains.
# Now run the 308 time.
# 35680945 is not following now, 92 following remains.
# Now run the 309 time.
# 11039947 is not following now, 91 following remains.
# Now run the 310 time.
# 49315682 is not following now, 90 following remains.
# Now run the 311 time.
# 67684224 is not following now, 89 following remains.
# Now run the 312 time.
# 45382250 is not following now, 88 following remains.
# Now run the 313 time.
# 36726753 is not following now, 87 following remains.
# Now run the 314 time.
# 63109425 is not following now, 86 following remains.
# Now run the 315 time.
# 61360662 is not following now, 85 following remains.
# Now run the 316 time.
# 62159908 is not following now, 84 following remains.
# Now run the 317 time.
# 68111074 is not following now, 83 following remains.
# Now run the 318 time.
# 53711707 is not following now, 82 following remains.
# Now run the 319 time.
# 67916642 is not following now, 81 following remains.
# Now run the 320 time.
# 66213707 is not following now, 80 following remains.
# Now run the 321 time.
# 21649132 is not following now, 79 following remains.
# Now run the 322 time.
# 67391379 is not following now, 78 following remains.
# Now run the 323 time.
# 61922102 is not following now, 77 following remains.
# Now run the 324 time.
# 24234615 is not following now, 76 following remains.
# Now run the 325 time.
# 64618082 is not following now, 75 following remains.
# Now run the 326 time.
# 30026172 is not following now, 74 following remains.
# Now run the 327 time.
# 15340132 is not following now, 73 following remains.
# Now run the 328 time.
# 68309740 is not following now, 72 following remains.
# Now run the 329 time.
# 40832407 is not following now, 71 following remains.
# Now run the 330 time.
# 39875730 is not following now, 70 following remains.
# Now run the 331 time.
# 58943820 is not following now, 69 following remains.
# Now run the 332 time.
# 1695054 is not following now, 68 following remains.
# Now run the 333 time.
# 62662668 is not following now, 67 following remains.
# Now run the 334 time.
# 52663600 is not following now, 66 following remains.
# Now run the 335 time.
# 50929616 is not following now, 65 following remains.
# Now run the 336 time.
# 30402612 is not following now, 64 following remains.
# Now run the 337 time.
# 6560695 is not following now, 63 following remains.
# Now run the 338 time.
# 11903869 is not following now, 62 following remains.
# Now run the 339 time.
# 5947340 is not following now, 61 following remains.
# Now run the 340 time.
# 25880744 is not following now, 60 following remains.
# Now run the 341 time.
# 41719143 is not following now, 59 following remains.
# Now run the 342 time.
# 65062586 is not following now, 58 following remains.
# Now run the 343 time.
# 66652705 is not following now, 57 following remains.
# Now run the 344 time.
# 23094466 is not following now, 56 following remains.
# Now run the 345 time.
# 28829276 is not following now, 55 following remains.
# Now run the 346 time.
# 15703549 is not following now, 54 following remains.
# Now run the 347 time.
# 68002801 is not following now, 53 following remains.
# Now run the 348 time.
# 43607012 is not following now, 52 following remains.
# Now run the 349 time.
# 24887248 is not following now, 51 following remains.
# Now run the 350 time.
# 46340617 is not following now, 50 following remains.
# Now run the 351 time.
# 7300427 is not following now, 49 following remains.
# Now run the 352 time.
# 58087904 is not following now, 48 following remains.
# Now run the 353 time.
# 21648501 is not following now, 47 following remains.
# Now run the 354 time.
# 53774000 is not following now, 46 following remains.
# Now run the 355 time.
# 43691192 is not following now, 45 following remains.
# Now run the 356 time.
# 51232801 is not following now, 44 following remains.
# Now run the 357 time.
# 33925937 is not following now, 43 following remains.
# Now run the 358 time.
# 17642780 is not following now, 42 following remains.
# Now run the 359 time.
# 15593142 is not following now, 41 following remains.
# Now run the 360 time.
# 15191608 is not following now, 40 following remains.
# Now run the 361 time.
# 68416574 is not following now, 39 following remains.
# Now run the 362 time.
# 20032294 is not following now, 38 following remains.
# Now run the 363 time.
# 11928542 is not following now, 37 following remains.
# Now run the 364 time.
# 15661343 is not following now, 36 following remains.
# Now run the 365 time.
# 59381450 is not following now, 35 following remains.
# Now run the 366 time.
# 37738758 is not following now, 34 following remains.
# Now run the 367 time.
# 26029278 is not following now, 33 following remains.
# Now run the 368 time.
# 68117936 is not following now, 32 following remains.
# Now run the 369 time.
# 3902627 is not following now, 31 following remains.
# Now run the 370 time.
# 17741457 is not following now, 30 following remains.
# Now run the 371 time.
# 11257737 is not following now, 29 following remains.
# Now run the 372 time.
# 19183255 is not following now, 28 following remains.
# Now run the 373 time.
# 40038823 is not following now, 27 following remains.
# Now run the 374 time.
# 30423501 is not following now, 26 following remains.
# Now run the 375 time.
# 11555597 is not following now, 25 following remains.
# Now run the 376 time.
# 48002734 is not following now, 24 following remains.
# Now run the 377 time.
# 29081089 is not following now, 23 following remains.
# Now run the 378 time.
# 5772545 is not following now, 22 following remains.
# Now run the 379 time.
# 33637676 is not following now, 21 following remains.
# Now run the 380 time.
# 58352188 is not following now, 20 following remains.
# Now run the 381 time.
# 25561570 is not following now, 19 following remains.
# Now run the 382 time.
# 59901288 is not following now, 18 following remains.
# Now run the 383 time.
# 6363587 is not following now, 17 following remains.
# Now run the 384 time.
# 58058325 is not following now, 16 following remains.
# Now run the 385 time.
# 53876179 is not following now, 15 following remains.
# Now run the 386 time.
# 53454060 is not following now, 14 following remains.
# Now run the 387 time.
# 34501593 is not following now, 13 following remains.
# Now run the 388 time.
# 3813401 is not following now, 12 following remains.
# Now run the 389 time.
# 19327418 is not following now, 11 following remains.
# Now run the 390 time.
# 54907902 is not following now, 10 following remains.
# Now run the 391 time.
# 44334134 is not following now, 9 following remains.
# Now run the 392 time.
# 16713463 is not following now, 8 following remains.
# Now run the 393 time.
# 13256968 is not following now, 7 following remains.
# Now run the 394 time.
# 24044517 is not following now, 6 following remains.
# Now run the 395 time.
# 15447627 is not following now, 5 following remains.
# Now run the 396 time.
# 12749986 is not following now, 4 following remains.
# Now run the 397 time.
# 10266747 is not following now, 3 following remains.
# Now run the 398 time.
# 41414422 is not following now, 2 following remains.
# Now run the 399 time.
# 41471219 is not following now, 1 following remains.
# Now run the 400 time.
# 11049828 is not following now, 0 following remains.

# %%
# add fans from Top Seller's shop
top_shop_url = 'https://shopee.co.id/shop/13484023/followers/?__classic__=1'
browser.get(top_shop_url)

# %%
# add certain number of fans
to_add_num_of_following = 400
num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))

# %%
# page down until we get at least 400 fans to cancel
while num_of_following_display <= 1000:
    body = browser.find_element_by_css_selector('body')
    # body.send_keys(Keys.PAGE_DOWN)
    body.send_keys(Keys.END)
    time.sleep(5)
    num_of_following_display = len(browser.find_elements_by_css_selector('.clickable_area.middle-centered-div'))
    
num_of_following_display
# Out:
# 1016

# %%
following_buttons = browser.find_elements_by_css_selector('.btn-follow.follow.L14')
len(following_buttons)
# Out:
# 1016

# %%
i = 0
total_add_num_of_following = to_add_num_of_following

scroll_to_the_top = browser.find_element_by_css_selector('body').send_keys(Keys.CONTROL + Keys.HOME)

while i <= total_add_num_of_following - 1:  
    while to_add_num_of_following > 0:
        print('Now run the ' + str(i + 1) + ' time.')
        if following_buttons[i].text == '+ 关注':
            # print(following_buttons[i].text)
            shopid = following_buttons[i].get_attribute('shopid')
            following_buttons[i].click()
            time.sleep(5)
            to_add_num_of_following -= 1
            print(str(shopid) + ' is following now, ' + str(to_add_num_of_following) + ' following remains.')
        else:
            print('Skip this one. It\'s following already.')
        i += 1
# Out:
# Now run the 1 time.
# Skip this one. It's following already.
# Now run the 2 time.
# Skip this one. It's following already.
# Now run the 3 time.
# Skip this one. It's following already.
# Now run the 4 time.
# Skip this one. It's following already.
# Now run the 5 time.
# Skip this one. It's following already.
# Now run the 6 time.
# Skip this one. It's following already.
# Now run the 7 time.
# Skip this one. It's following already.
# Now run the 8 time.
# Skip this one. It's following already.
# Now run the 9 time.
# Skip this one. It's following already.
# Now run the 10 time.
# Skip this one. It's following already.
# Now run the 11 time.
# Skip this one. It's following already.
# Now run the 12 time.
# Skip this one. It's following already.
# Now run the 13 time.
# Skip this one. It's following already.
# Now run the 14 time.
# Skip this one. It's following already.
# Now run the 15 time.
# Skip this one. It's following already.
# Now run the 16 time.
# Skip this one. It's following already.
# Now run the 17 time.
# Skip this one. It's following already.
# Now run the 18 time.
# Skip this one. It's following already.
# Now run the 19 time.
# Skip this one. It's following already.
# Now run the 20 time.
# Skip this one. It's following already.
# Now run the 21 time.
# Skip this one. It's following already.
# Now run the 22 time.
# Skip this one. It's following already.
# Now run the 23 time.
# Skip this one. It's following already.
# Now run the 24 time.
# Skip this one. It's following already.
# Now run the 25 time.
# Skip this one. It's following already.
# Now run the 26 time.
# Skip this one. It's following already.
# Now run the 27 time.
# Skip this one. It's following already.
# Now run the 28 time.
# Skip this one. It's following already.
# Now run the 29 time.
# Skip this one. It's following already.
# Now run the 30 time.
# Skip this one. It's following already.
# Now run the 31 time.
# Skip this one. It's following already.
# Now run the 32 time.
# Skip this one. It's following already.
# Now run the 33 time.
# Skip this one. It's following already.
# Now run the 34 time.
# Skip this one. It's following already.
# Now run the 35 time.
# Skip this one. It's following already.
# Now run the 36 time.
# Skip this one. It's following already.
# Now run the 37 time.
# Skip this one. It's following already.
# Now run the 38 time.
# Skip this one. It's following already.
# Now run the 39 time.
# Skip this one. It's following already.
# Now run the 40 time.
# Skip this one. It's following already.
# Now run the 41 time.
# Skip this one. It's following already.
# Now run the 42 time.
# Skip this one. It's following already.
# Now run the 43 time.
# Skip this one. It's following already.
# Now run the 44 time.
# Skip this one. It's following already.
# Now run the 45 time.
# Skip this one. It's following already.
# Now run the 46 time.
# Skip this one. It's following already.
# Now run the 47 time.
# Skip this one. It's following already.
# Now run the 48 time.
# Skip this one. It's following already.
# Now run the 49 time.
# Skip this one. It's following already.
# Now run the 50 time.
# Skip this one. It's following already.
# Now run the 51 time.
# Skip this one. It's following already.
# Now run the 52 time.
# Skip this one. It's following already.
# Now run the 53 time.
# Skip this one. It's following already.
# Now run the 54 time.
# Skip this one. It's following already.
# Now run the 55 time.
# Skip this one. It's following already.
# Now run the 56 time.
# Skip this one. It's following already.
# Now run the 57 time.
# Skip this one. It's following already.
# Now run the 58 time.
# Skip this one. It's following already.
# Now run the 59 time.
# Skip this one. It's following already.
# Now run the 60 time.
# Skip this one. It's following already.
# Now run the 61 time.
# Skip this one. It's following already.
# Now run the 62 time.
# Skip this one. It's following already.
# Now run the 63 time.
# Skip this one. It's following already.
# Now run the 64 time.
# Skip this one. It's following already.
# Now run the 65 time.
# Skip this one. It's following already.
# Now run the 66 time.
# Skip this one. It's following already.
# Now run the 67 time.
# Skip this one. It's following already.
# Now run the 68 time.
# Skip this one. It's following already.
# Now run the 69 time.
# Skip this one. It's following already.
# Now run the 70 time.
# Skip this one. It's following already.
# Now run the 71 time.
# Skip this one. It's following already.
# Now run the 72 time.
# Skip this one. It's following already.
# Now run the 73 time.
# Skip this one. It's following already.
# Now run the 74 time.
# Skip this one. It's following already.
# Now run the 75 time.
# Skip this one. It's following already.
# Now run the 76 time.
# Skip this one. It's following already.
# Now run the 77 time.
# Skip this one. It's following already.
# Now run the 78 time.
# Skip this one. It's following already.
# Now run the 79 time.
# Skip this one. It's following already.
# Now run the 80 time.
# Skip this one. It's following already.
# Now run the 81 time.
# Skip this one. It's following already.
# Now run the 82 time.
# Skip this one. It's following already.
# Now run the 83 time.
# Skip this one. It's following already.
# Now run the 84 time.
# Skip this one. It's following already.
# Now run the 85 time.
# Skip this one. It's following already.
# Now run the 86 time.
# Skip this one. It's following already.
# Now run the 87 time.
# Skip this one. It's following already.
# Now run the 88 time.
# Skip this one. It's following already.
# Now run the 89 time.
# Skip this one. It's following already.
# Now run the 90 time.
# Skip this one. It's following already.
# Now run the 91 time.
# Skip this one. It's following already.
# Now run the 92 time.
# Skip this one. It's following already.
# Now run the 93 time.
# Skip this one. It's following already.
# Now run the 94 time.
# Skip this one. It's following already.
# Now run the 95 time.
# Skip this one. It's following already.
# Now run the 96 time.
# Skip this one. It's following already.
# Now run the 97 time.
# Skip this one. It's following already.
# Now run the 98 time.
# Skip this one. It's following already.
# Now run the 99 time.
# Skip this one. It's following already.
# Now run the 100 time.
# Skip this one. It's following already.
# Now run the 101 time.
# Skip this one. It's following already.
# Now run the 102 time.
# Skip this one. It's following already.
# Now run the 103 time.
# Skip this one. It's following already.
# Now run the 104 time.
# Skip this one. It's following already.
# Now run the 105 time.
# Skip this one. It's following already.
# Now run the 106 time.
# Skip this one. It's following already.
# Now run the 107 time.
# Skip this one. It's following already.
# Now run the 108 time.
# Skip this one. It's following already.
# Now run the 109 time.
# Skip this one. It's following already.
# Now run the 110 time.
# Skip this one. It's following already.
# Now run the 111 time.
# Skip this one. It's following already.
# Now run the 112 time.
# Skip this one. It's following already.
# Now run the 113 time.
# Skip this one. It's following already.
# Now run the 114 time.
# Skip this one. It's following already.
# Now run the 115 time.
# Skip this one. It's following already.
# Now run the 116 time.
# Skip this one. It's following already.
# Now run the 117 time.
# Skip this one. It's following already.
# Now run the 118 time.
# Skip this one. It's following already.
# Now run the 119 time.
# Skip this one. It's following already.
# Now run the 120 time.
# Skip this one. It's following already.
# Now run the 121 time.
# Skip this one. It's following already.
# Now run the 122 time.
# Skip this one. It's following already.
# Now run the 123 time.
# Skip this one. It's following already.
# Now run the 124 time.
# Skip this one. It's following already.
# Now run the 125 time.
# Skip this one. It's following already.
# Now run the 126 time.
# Skip this one. It's following already.
# Now run the 127 time.
# Skip this one. It's following already.
# Now run the 128 time.
# Skip this one. It's following already.
# Now run the 129 time.
# Skip this one. It's following already.
# Now run the 130 time.
# Skip this one. It's following already.
# Now run the 131 time.
# Skip this one. It's following already.
# Now run the 132 time.
# Skip this one. It's following already.
# Now run the 133 time.
# Skip this one. It's following already.
# Now run the 134 time.
# Skip this one. It's following already.
# Now run the 135 time.
# Skip this one. It's following already.
# Now run the 136 time.
# Skip this one. It's following already.
# Now run the 137 time.
# Skip this one. It's following already.
# Now run the 138 time.
# Skip this one. It's following already.
# Now run the 139 time.
# Skip this one. It's following already.
# Now run the 140 time.
# Skip this one. It's following already.
# Now run the 141 time.
# Skip this one. It's following already.
# Now run the 142 time.
# Skip this one. It's following already.
# Now run the 143 time.
# Skip this one. It's following already.
# Now run the 144 time.
# Skip this one. It's following already.
# Now run the 145 time.
# Skip this one. It's following already.
# Now run the 146 time.
# Skip this one. It's following already.
# Now run the 147 time.
# Skip this one. It's following already.
# Now run the 148 time.
# Skip this one. It's following already.
# Now run the 149 time.
# Skip this one. It's following already.
# Now run the 150 time.
# Skip this one. It's following already.
# Now run the 151 time.
# Skip this one. It's following already.
# Now run the 152 time.
# Skip this one. It's following already.
# Now run the 153 time.
# Skip this one. It's following already.
# Now run the 154 time.
# Skip this one. It's following already.
# Now run the 155 time.
# Skip this one. It's following already.
# Now run the 156 time.
# Skip this one. It's following already.
# Now run the 157 time.
# Skip this one. It's following already.
# Now run the 158 time.
# Skip this one. It's following already.
# Now run the 159 time.
# Skip this one. It's following already.
# Now run the 160 time.
# Skip this one. It's following already.
# Now run the 161 time.
# Skip this one. It's following already.
# Now run the 162 time.
# Skip this one. It's following already.
# Now run the 163 time.
# Skip this one. It's following already.
# Now run the 164 time.
# Skip this one. It's following already.
# Now run the 165 time.
# Skip this one. It's following already.
# Now run the 166 time.
# Skip this one. It's following already.
# Now run the 167 time.
# Skip this one. It's following already.
# Now run the 168 time.
# Skip this one. It's following already.
# Now run the 169 time.
# Skip this one. It's following already.
# Now run the 170 time.
# Skip this one. It's following already.
# Now run the 171 time.
# Skip this one. It's following already.
# Now run the 172 time.
# Skip this one. It's following already.
# Now run the 173 time.
# Skip this one. It's following already.
# Now run the 174 time.
# Skip this one. It's following already.
# Now run the 175 time.
# Skip this one. It's following already.
# Now run the 176 time.
# Skip this one. It's following already.
# Now run the 177 time.
# Skip this one. It's following already.
# Now run the 178 time.
# Skip this one. It's following already.
# Now run the 179 time.
# Skip this one. It's following already.
# Now run the 180 time.
# Skip this one. It's following already.
# Now run the 181 time.
# Skip this one. It's following already.
# Now run the 182 time.
# Skip this one. It's following already.
# Now run the 183 time.
# Skip this one. It's following already.
# Now run the 184 time.
# Skip this one. It's following already.
# Now run the 185 time.
# Skip this one. It's following already.
# Now run the 186 time.
# Skip this one. It's following already.
# Now run the 187 time.
# Skip this one. It's following already.
# Now run the 188 time.
# Skip this one. It's following already.
# Now run the 189 time.
# Skip this one. It's following already.
# Now run the 190 time.
# Skip this one. It's following already.
# Now run the 191 time.
# Skip this one. It's following already.
# Now run the 192 time.
# Skip this one. It's following already.
# Now run the 193 time.
# Skip this one. It's following already.
# Now run the 194 time.
# Skip this one. It's following already.
# Now run the 195 time.
# Skip this one. It's following already.
# Now run the 196 time.
# Skip this one. It's following already.
# Now run the 197 time.
# Skip this one. It's following already.
# Now run the 198 time.
# Skip this one. It's following already.
# Now run the 199 time.
# Skip this one. It's following already.
# Now run the 200 time.
# Skip this one. It's following already.
# Now run the 201 time.
# Skip this one. It's following already.
# Now run the 202 time.
# Skip this one. It's following already.
# Now run the 203 time.
# Skip this one. It's following already.
# Now run the 204 time.
# Skip this one. It's following already.
# Now run the 205 time.
# Skip this one. It's following already.
# Now run the 206 time.
# Skip this one. It's following already.
# Now run the 207 time.
# Skip this one. It's following already.
# Now run the 208 time.
# Skip this one. It's following already.
# Now run the 209 time.
# Skip this one. It's following already.
# Now run the 210 time.
# Skip this one. It's following already.
# Now run the 211 time.
# Skip this one. It's following already.
# Now run the 212 time.
# Skip this one. It's following already.
# Now run the 213 time.
# Skip this one. It's following already.
# Now run the 214 time.
# Skip this one. It's following already.
# Now run the 215 time.
# Skip this one. It's following already.
# Now run the 216 time.
# Skip this one. It's following already.
# Now run the 217 time.
# Skip this one. It's following already.
# Now run the 218 time.
# Skip this one. It's following already.
# Now run the 219 time.
# Skip this one. It's following already.
# Now run the 220 time.
# Skip this one. It's following already.
# Now run the 221 time.
# Skip this one. It's following already.
# Now run the 222 time.
# Skip this one. It's following already.
# Now run the 223 time.
# Skip this one. It's following already.
# Now run the 224 time.
# Skip this one. It's following already.
# Now run the 225 time.
# Skip this one. It's following already.
# Now run the 226 time.
# Skip this one. It's following already.
# Now run the 227 time.
# Skip this one. It's following already.
# Now run the 228 time.
# Skip this one. It's following already.
# Now run the 229 time.
# Skip this one. It's following already.
# Now run the 230 time.
# Skip this one. It's following already.
# Now run the 231 time.
# Skip this one. It's following already.
# Now run the 232 time.
# Skip this one. It's following already.
# Now run the 233 time.
# Skip this one. It's following already.
# Now run the 234 time.
# Skip this one. It's following already.
# Now run the 235 time.
# Skip this one. It's following already.
# Now run the 236 time.
# Skip this one. It's following already.
# Now run the 237 time.
# Skip this one. It's following already.
# Now run the 238 time.
# Skip this one. It's following already.
# Now run the 239 time.
# Skip this one. It's following already.
# Now run the 240 time.
# Skip this one. It's following already.
# Now run the 241 time.
# Skip this one. It's following already.
# Now run the 242 time.
# Skip this one. It's following already.
# Now run the 243 time.
# Skip this one. It's following already.
# Now run the 244 time.
# Skip this one. It's following already.
# Now run the 245 time.
# Skip this one. It's following already.
# Now run the 246 time.
# Skip this one. It's following already.
# Now run the 247 time.
# Skip this one. It's following already.
# Now run the 248 time.
# Skip this one. It's following already.
# Now run the 249 time.
# Skip this one. It's following already.
# Now run the 250 time.
# Skip this one. It's following already.
# Now run the 251 time.
# Skip this one. It's following already.
# Now run the 252 time.
# Skip this one. It's following already.
# Now run the 253 time.
# Skip this one. It's following already.
# Now run the 254 time.
# Skip this one. It's following already.
# Now run the 255 time.
# Skip this one. It's following already.
# Now run the 256 time.
# Skip this one. It's following already.
# Now run the 257 time.
# Skip this one. It's following already.
# Now run the 258 time.
# Skip this one. It's following already.
# Now run the 259 time.
# Skip this one. It's following already.
# Now run the 260 time.
# Skip this one. It's following already.
# Now run the 261 time.
# Skip this one. It's following already.
# Now run the 262 time.
# Skip this one. It's following already.
# Now run the 263 time.
# Skip this one. It's following already.
# Now run the 264 time.
# Skip this one. It's following already.
# Now run the 265 time.
# Skip this one. It's following already.
# Now run the 266 time.
# Skip this one. It's following already.
# Now run the 267 time.
# Skip this one. It's following already.
# Now run the 268 time.
# Skip this one. It's following already.
# Now run the 269 time.
# Skip this one. It's following already.
# Now run the 270 time.
# Skip this one. It's following already.
# Now run the 271 time.
# Skip this one. It's following already.
# Now run the 272 time.
# Skip this one. It's following already.
# Now run the 273 time.
# Skip this one. It's following already.
# Now run the 274 time.
# Skip this one. It's following already.
# Now run the 275 time.
# Skip this one. It's following already.
# Now run the 276 time.
# Skip this one. It's following already.
# Now run the 277 time.
# Skip this one. It's following already.
# Now run the 278 time.
# Skip this one. It's following already.
# Now run the 279 time.
# Skip this one. It's following already.
# Now run the 280 time.
# Skip this one. It's following already.
# Now run the 281 time.
# Skip this one. It's following already.
# Now run the 282 time.
# Skip this one. It's following already.
# Now run the 283 time.
# Skip this one. It's following already.
# Now run the 284 time.
# Skip this one. It's following already.
# Now run the 285 time.
# Skip this one. It's following already.
# Now run the 286 time.
# Skip this one. It's following already.
# Now run the 287 time.
# Skip this one. It's following already.
# Now run the 288 time.
# Skip this one. It's following already.
# Now run the 289 time.
# Skip this one. It's following already.
# Now run the 290 time.
# Skip this one. It's following already.
# Now run the 291 time.
# Skip this one. It's following already.
# Now run the 292 time.
# Skip this one. It's following already.
# Now run the 293 time.
# Skip this one. It's following already.
# Now run the 294 time.
# Skip this one. It's following already.
# Now run the 295 time.
# Skip this one. It's following already.
# Now run the 296 time.
# Skip this one. It's following already.
# Now run the 297 time.
# Skip this one. It's following already.
# Now run the 298 time.
# Skip this one. It's following already.
# Now run the 299 time.
# Skip this one. It's following already.
# Now run the 300 time.
# Skip this one. It's following already.
# Now run the 301 time.
# Skip this one. It's following already.
# Now run the 302 time.
# Skip this one. It's following already.
# Now run the 303 time.
# Skip this one. It's following already.
# Now run the 304 time.
# Skip this one. It's following already.
# Now run the 305 time.
# Skip this one. It's following already.
# Now run the 306 time.
# Skip this one. It's following already.
# Now run the 307 time.
# Skip this one. It's following already.
# Now run the 308 time.
# Skip this one. It's following already.
# Now run the 309 time.
# Skip this one. It's following already.
# Now run the 310 time.
# Skip this one. It's following already.
# Now run the 311 time.
# Skip this one. It's following already.
# Now run the 312 time.
# Skip this one. It's following already.
# Now run the 313 time.
# Skip this one. It's following already.
# Now run the 314 time.
# Skip this one. It's following already.
# Now run the 315 time.
# Skip this one. It's following already.
# Now run the 316 time.
# Skip this one. It's following already.
# Now run the 317 time.
# Skip this one. It's following already.
# Now run the 318 time.
# Skip this one. It's following already.
# Now run the 319 time.
# Skip this one. It's following already.
# Now run the 320 time.
# Skip this one. It's following already.
# Now run the 321 time.
# Skip this one. It's following already.
# Now run the 322 time.
# Skip this one. It's following already.
# Now run the 323 time.
# Skip this one. It's following already.
# Now run the 324 time.
# Skip this one. It's following already.
# Now run the 325 time.
# Skip this one. It's following already.
# Now run the 326 time.
# Skip this one. It's following already.
# Now run the 327 time.
# Skip this one. It's following already.
# Now run the 328 time.
# Skip this one. It's following already.
# Now run the 329 time.
# Skip this one. It's following already.
# Now run the 330 time.
# Skip this one. It's following already.
# Now run the 331 time.
# Skip this one. It's following already.
# Now run the 332 time.
# Skip this one. It's following already.
# Now run the 333 time.
# Skip this one. It's following already.
# Now run the 334 time.
# Skip this one. It's following already.
# Now run the 335 time.
# Skip this one. It's following already.
# Now run the 336 time.
# Skip this one. It's following already.
# Now run the 337 time.
# Skip this one. It's following already.
# Now run the 338 time.
# Skip this one. It's following already.
# Now run the 339 time.
# Skip this one. It's following already.
# Now run the 340 time.
# Skip this one. It's following already.
# Now run the 341 time.
# Skip this one. It's following already.
# Now run the 342 time.
# Skip this one. It's following already.
# Now run the 343 time.
# Skip this one. It's following already.
# Now run the 344 time.
# Skip this one. It's following already.
# Now run the 345 time.
# Skip this one. It's following already.
# Now run the 346 time.
# Skip this one. It's following already.
# Now run the 347 time.
# Skip this one. It's following already.
# Now run the 348 time.
# Skip this one. It's following already.
# Now run the 349 time.
# Skip this one. It's following already.
# Now run the 350 time.
# Skip this one. It's following already.
# Now run the 351 time.
# Skip this one. It's following already.
# Now run the 352 time.
# Skip this one. It's following already.
# Now run the 353 time.
# Skip this one. It's following already.
# Now run the 354 time.
# Skip this one. It's following already.
# Now run the 355 time.
# Skip this one. It's following already.
# Now run the 356 time.
# Skip this one. It's following already.
# Now run the 357 time.
# Skip this one. It's following already.
# Now run the 358 time.
# Skip this one. It's following already.
# Now run the 359 time.
# Skip this one. It's following already.
# Now run the 360 time.
# Skip this one. It's following already.
# Now run the 361 time.
# Skip this one. It's following already.
# Now run the 362 time.
# Skip this one. It's following already.
# Now run the 363 time.
# Skip this one. It's following already.
# Now run the 364 time.
# Skip this one. It's following already.
# Now run the 365 time.
# Skip this one. It's following already.
# Now run the 366 time.
# Skip this one. It's following already.
# Now run the 367 time.
# Skip this one. It's following already.
# Now run the 368 time.
# Skip this one. It's following already.
# Now run the 369 time.
# Skip this one. It's following already.
# Now run the 370 time.
# Skip this one. It's following already.
# Now run the 371 time.
# Skip this one. It's following already.
# Now run the 372 time.
# Skip this one. It's following already.
# Now run the 373 time.
# Skip this one. It's following already.
# Now run the 374 time.
# Skip this one. It's following already.
# Now run the 375 time.
# Skip this one. It's following already.
# Now run the 376 time.
# Skip this one. It's following already.
# Now run the 377 time.
# Skip this one. It's following already.
# Now run the 378 time.
# Skip this one. It's following already.
# Now run the 379 time.
# Skip this one. It's following already.
# Now run the 380 time.
# Skip this one. It's following already.
# Now run the 381 time.
# Skip this one. It's following already.
# Now run the 382 time.
# Skip this one. It's following already.
# Now run the 383 time.
# Skip this one. It's following already.
# Now run the 384 time.
# Skip this one. It's following already.
# Now run the 385 time.
# Skip this one. It's following already.
# Now run the 386 time.
# Skip this one. It's following already.
# Now run the 387 time.
# Skip this one. It's following already.
# Now run the 388 time.
# Skip this one. It's following already.
# Now run the 389 time.
# Skip this one. It's following already.
# Now run the 390 time.
# Skip this one. It's following already.
# Now run the 391 time.
# Skip this one. It's following already.
# Now run the 392 time.
# Skip this one. It's following already.
# Now run the 393 time.
# Skip this one. It's following already.
# Now run the 394 time.
# Skip this one. It's following already.
# Now run the 395 time.
# Skip this one. It's following already.
# Now run the 396 time.
# Skip this one. It's following already.
# Now run the 397 time.
# Skip this one. It's following already.
# Now run the 398 time.
# Skip this one. It's following already.
# Now run the 399 time.
# Skip this one. It's following already.
# Now run the 400 time.
# Skip this one. It's following already.
# Now run the 401 time.
# 21610016 is following now, 272 following remains.
# Now run the 402 time.
# 55542163 is following now, 271 following remains.
# Now run the 403 time.
# 23586041 is following now, 270 following remains.
# Now run the 404 time.
# 56418514 is following now, 269 following remains.
# Now run the 405 time.
# 61424788 is following now, 268 following remains.
# Now run the 406 time.
# 67935892 is following now, 267 following remains.
# Now run the 407 time.
# 37483588 is following now, 266 following remains.
# Now run the 408 time.
# 43984183 is following now, 265 following remains.
# Now run the 409 time.
# 42387030 is following now, 264 following remains.
# Now run the 410 time.
# 9660699 is following now, 263 following remains.
# Now run the 411 time.
# 23907848 is following now, 262 following remains.
# Now run the 412 time.
# 53466160 is following now, 261 following remains.
# Now run the 413 time.
# 9436374 is following now, 260 following remains.
# Now run the 414 time.
# 11389245 is following now, 259 following remains.
# Now run the 415 time.
# 67158443 is following now, 258 following remains.
# Now run the 416 time.
# 11649472 is following now, 257 following remains.
# Now run the 417 time.
# 27391551 is following now, 256 following remains.
# Now run the 418 time.
# 68520064 is following now, 255 following remains.
# Now run the 419 time.
# 68426655 is following now, 254 following remains.
# Now run the 420 time.
# 28037120 is following now, 253 following remains.
# Now run the 421 time.
# 67893999 is following now, 252 following remains.
# Now run the 422 time.
# 46677574 is following now, 251 following remains.
# Now run the 423 time.
# 51641297 is following now, 250 following remains.
# Now run the 424 time.
# 37233481 is following now, 249 following remains.
# Now run the 425 time.
# 7765428 is following now, 248 following remains.
# Now run the 426 time.
# 2974572 is following now, 247 following remains.
# Now run the 427 time.
# 65303887 is following now, 246 following remains.
# Now run the 428 time.
# 67718871 is following now, 245 following remains.
# Now run the 429 time.
# 65959335 is following now, 244 following remains.
# Now run the 430 time.
# 44452097 is following now, 243 following remains.
# Now run the 431 time.
# 53034395 is following now, 242 following remains.
# Now run the 432 time.
# 42072134 is following now, 241 following remains.
# Now run the 433 time.
# 35828634 is following now, 240 following remains.
# Now run the 434 time.
# 7829755 is following now, 239 following remains.
# Now run the 435 time.
# 40485502 is following now, 238 following remains.
# Now run the 436 time.
# 68008708 is following now, 237 following remains.
# Now run the 437 time.
# 21402894 is following now, 236 following remains.
# Now run the 438 time.
# 7967351 is following now, 235 following remains.
# Now run the 439 time.
# 46940181 is following now, 234 following remains.
# Now run the 440 time.
# 57328221 is following now, 233 following remains.
# Now run the 441 time.
# 9693079 is following now, 232 following remains.
# Now run the 442 time.
# 60538032 is following now, 231 following remains.
# Now run the 443 time.
# 18482507 is following now, 230 following remains.
# Now run the 444 time.
# 59591209 is following now, 229 following remains.
# Now run the 445 time.
# 64765912 is following now, 228 following remains.
# Now run the 446 time.
# 61523554 is following now, 227 following remains.
# Now run the 447 time.
# 44245157 is following now, 226 following remains.
# Now run the 448 time.
# 54908632 is following now, 225 following remains.
# Now run the 449 time.
# 52146165 is following now, 224 following remains.
# Now run the 450 time.
# 67853786 is following now, 223 following remains.
# Now run the 451 time.
# 68490488 is following now, 222 following remains.
# Now run the 452 time.
# 57113989 is following now, 221 following remains.
# Now run the 453 time.
# 23642752 is following now, 220 following remains.
# Now run the 454 time.
# 61828536 is following now, 219 following remains.
# Now run the 455 time.
# 60388401 is following now, 218 following remains.
# Now run the 456 time.
# 60877114 is following now, 217 following remains.
# Now run the 457 time.
# 54629845 is following now, 216 following remains.
# Now run the 458 time.
# 58729656 is following now, 215 following remains.
# Now run the 459 time.
# 44540857 is following now, 214 following remains.
# Now run the 460 time.
# 35461932 is following now, 213 following remains.
# Now run the 461 time.
# 52347259 is following now, 212 following remains.
# Now run the 462 time.
# 57002227 is following now, 211 following remains.
# Now run the 463 time.
# 63283031 is following now, 210 following remains.
# Now run the 464 time.
# 35951375 is following now, 209 following remains.
# Now run the 465 time.
# 68086009 is following now, 208 following remains.
# Now run the 466 time.
# 50027989 is following now, 207 following remains.
# Now run the 467 time.
# 62376969 is following now, 206 following remains.
# Now run the 468 time.
# 14556385 is following now, 205 following remains.
# Now run the 469 time.
# 22112194 is following now, 204 following remains.
# Now run the 470 time.
# 6820513 is following now, 203 following remains.
# Now run the 471 time.
# 20145080 is following now, 202 following remains.
# Now run the 472 time.
# 44676885 is following now, 201 following remains.
# Now run the 473 time.
# 36714459 is following now, 200 following remains.
# Now run the 474 time.
# 4546339 is following now, 199 following remains.
# Now run the 475 time.
# 7328251 is following now, 198 following remains.
# Now run the 476 time.
# 43562803 is following now, 197 following remains.
# Now run the 477 time.
# 19877899 is following now, 196 following remains.
# Now run the 478 time.
# 68362065 is following now, 195 following remains.
# Now run the 479 time.
# 27231361 is following now, 194 following remains.
# Now run the 480 time.
# 26079978 is following now, 193 following remains.
# Now run the 481 time.
# 59634014 is following now, 192 following remains.
# Now run the 482 time.
# 24383224 is following now, 191 following remains.
# Now run the 483 time.
# 23344051 is following now, 190 following remains.
# Now run the 484 time.
# 18045989 is following now, 189 following remains.
# Now run the 485 time.
# 18017009 is following now, 188 following remains.
# Now run the 486 time.
# 15010539 is following now, 187 following remains.
# Now run the 487 time.
# 68337641 is following now, 186 following remains.
# Now run the 488 time.
# 19856137 is following now, 185 following remains.
# Now run the 489 time.
# 52568379 is following now, 184 following remains.
# Now run the 490 time.
# 67210938 is following now, 183 following remains.
# Now run the 491 time.
# 26124692 is following now, 182 following remains.
# Now run the 492 time.
# 58995790 is following now, 181 following remains.
# Now run the 493 time.
# 7837459 is following now, 180 following remains.
# Now run the 494 time.
# 67191759 is following now, 179 following remains.
# Now run the 495 time.
# 64956544 is following now, 178 following remains.
# Now run the 496 time.
# 53942028 is following now, 177 following remains.
# Now run the 497 time.
# 38018219 is following now, 176 following remains.
# Now run the 498 time.
# 58980921 is following now, 175 following remains.
# Now run the 499 time.
# 68021943 is following now, 174 following remains.
# Now run the 500 time.
# 1576796 is following now, 173 following remains.
# Now run the 501 time.
# 5651417 is following now, 172 following remains.
# Now run the 502 time.
# 62403962 is following now, 171 following remains.
# Now run the 503 time.
# 36903843 is following now, 170 following remains.
# Now run the 504 time.
# 4761836 is following now, 169 following remains.
# Now run the 505 time.
# 3554105 is following now, 168 following remains.
# Now run the 506 time.
# 22251565 is following now, 167 following remains.
# Now run the 507 time.
# 34652356 is following now, 166 following remains.
# Now run the 508 time.
# 64450730 is following now, 165 following remains.
# Now run the 509 time.
# 18363445 is following now, 164 following remains.
# Now run the 510 time.
# 9174285 is following now, 163 following remains.
# Now run the 511 time.
# 68512268 is following now, 162 following remains.
# Now run the 512 time.
# 62367954 is following now, 161 following remains.
# Now run the 513 time.
# 28433919 is following now, 160 following remains.
# Now run the 514 time.
# 23224969 is following now, 159 following remains.
# Now run the 515 time.
# 37128906 is following now, 158 following remains.
# Now run the 516 time.
# 67698038 is following now, 157 following remains.
# Now run the 517 time.
# 27403988 is following now, 156 following remains.
# Now run the 518 time.
# 469252 is following now, 155 following remains.
# Now run the 519 time.
# 46855461 is following now, 154 following remains.
# Now run the 520 time.
# 40264874 is following now, 153 following remains.
# Now run the 521 time.
# 64615788 is following now, 152 following remains.
# Now run the 522 time.
# 20550466 is following now, 151 following remains.
# Now run the 523 time.
# 66772319 is following now, 150 following remains.
# Now run the 524 time.
# 23934999 is following now, 149 following remains.
# Now run the 525 time.
# 29083591 is following now, 148 following remains.
# Now run the 526 time.
# 68510350 is following now, 147 following remains.
# Now run the 527 time.
# 19717552 is following now, 146 following remains.
# Now run the 528 time.
# 68494828 is following now, 145 following remains.
# Now run the 529 time.
# 14253878 is following now, 144 following remains.
# Now run the 530 time.
# 33707190 is following now, 143 following remains.
# Now run the 531 time.
# 20011680 is following now, 142 following remains.
# Now run the 532 time.
# 66371043 is following now, 141 following remains.
# Now run the 533 time.
# 5309588 is following now, 140 following remains.
# Now run the 534 time.
# 21196102 is following now, 139 following remains.
# Now run the 535 time.
# 56537103 is following now, 138 following remains.
# Now run the 536 time.
# 53039326 is following now, 137 following remains.
# Now run the 537 time.
# 55218314 is following now, 136 following remains.
# Now run the 538 time.
# 3585133 is following now, 135 following remains.
# Now run the 539 time.
# 54191462 is following now, 134 following remains.
# Now run the 540 time.
# 21840024 is following now, 133 following remains.
# Now run the 541 time.
# 52380436 is following now, 132 following remains.
# Now run the 542 time.
# 9979096 is following now, 131 following remains.
# Now run the 543 time.
# 59189330 is following now, 130 following remains.
# Now run the 544 time.
# 44418856 is following now, 129 following remains.
# Now run the 545 time.
# 5071339 is following now, 128 following remains.
# Now run the 546 time.
# 58181815 is following now, 127 following remains.
# Now run the 547 time.
# 24853269 is following now, 126 following remains.
# Now run the 548 time.
# 66886182 is following now, 125 following remains.
# Now run the 549 time.
# 55401555 is following now, 124 following remains.
# Now run the 550 time.
# 6530908 is following now, 123 following remains.
# Now run the 551 time.
# 53180480 is following now, 122 following remains.
# Now run the 552 time.
# 9645471 is following now, 121 following remains.
# Now run the 553 time.
# 67896480 is following now, 120 following remains.
# Now run the 554 time.
# 24732327 is following now, 119 following remains.
# Now run the 555 time.
# 38610725 is following now, 118 following remains.
# Now run the 556 time.
# 24528970 is following now, 117 following remains.
# Now run the 557 time.
# 19369244 is following now, 116 following remains.
# Now run the 558 time.
# 11859260 is following now, 115 following remains.
# Now run the 559 time.
# 37901724 is following now, 114 following remains.
# Now run the 560 time.
# 61729914 is following now, 113 following remains.
# Now run the 561 time.
# 61815948 is following now, 112 following remains.
# Now run the 562 time.
# 17135409 is following now, 111 following remains.
# Now run the 563 time.
# 30814248 is following now, 110 following remains.
# Now run the 564 time.
# 52507310 is following now, 109 following remains.
# Now run the 565 time.
# 13094054 is following now, 108 following remains.
# Now run the 566 time.
# 8216636 is following now, 107 following remains.
# Now run the 567 time.
# 65874078 is following now, 106 following remains.
# Now run the 568 time.
# 61875880 is following now, 105 following remains.
# Now run the 569 time.
# 60583209 is following now, 104 following remains.
# Now run the 570 time.
# 68475713 is following now, 103 following remains.
# Now run the 571 time.
# 15779009 is following now, 102 following remains.
# Now run the 572 time.
# 60012372 is following now, 101 following remains.
# Now run the 573 time.
# 25056226 is following now, 100 following remains.
# Now run the 574 time.
# 56501381 is following now, 99 following remains.
# Now run the 575 time.
# 34767376 is following now, 98 following remains.
# Now run the 576 time.
# 66835429 is following now, 97 following remains.
# Now run the 577 time.
# 60605957 is following now, 96 following remains.
# Now run the 578 time.
# 14643581 is following now, 95 following remains.
# Now run the 579 time.
# 51230991 is following now, 94 following remains.
# Now run the 580 time.
# 12424057 is following now, 93 following remains.
# Now run the 581 time.
# 43302526 is following now, 92 following remains.
# Now run the 582 time.
# 22857746 is following now, 91 following remains.
# Now run the 583 time.
# 14006996 is following now, 90 following remains.
# Now run the 584 time.
# 51771576 is following now, 89 following remains.
# Now run the 585 time.
# 62901906 is following now, 88 following remains.
# Now run the 586 time.
# 6692313 is following now, 87 following remains.
# Now run the 587 time.
# 44987769 is following now, 86 following remains.
# Now run the 588 time.
# 68283878 is following now, 85 following remains.
# Now run the 589 time.
# 64050285 is following now, 84 following remains.
# Now run the 590 time.
# 9142816 is following now, 83 following remains.
# Now run the 591 time.
# 29172877 is following now, 82 following remains.
# Now run the 592 time.
# 63266356 is following now, 81 following remains.
# Now run the 593 time.
# 68495585 is following now, 80 following remains.
# Now run the 594 time.
# 14195793 is following now, 79 following remains.
# Now run the 595 time.
# 66384673 is following now, 78 following remains.
# Now run the 596 time.
# 5264755 is following now, 77 following remains.
# Now run the 597 time.
# 45346162 is following now, 76 following remains.
# Now run the 598 time.
# 47532913 is following now, 75 following remains.
# Now run the 599 time.
# 57476843 is following now, 74 following remains.
# Now run the 600 time.
# 44998694 is following now, 73 following remains.
# Now run the 601 time.
# 27009301 is following now, 72 following remains.
# Now run the 602 time.
# 4778573 is following now, 71 following remains.
# Now run the 603 time.
# 63829043 is following now, 70 following remains.
# Now run the 604 time.
# 68425879 is following now, 69 following remains.
# Now run the 605 time.
# 21969252 is following now, 68 following remains.
# Now run the 606 time.
# 24099630 is following now, 67 following remains.
# Now run the 607 time.
# 34891965 is following now, 66 following remains.
# Now run the 608 time.
# 52605043 is following now, 65 following remains.
# Now run the 609 time.
# 8063506 is following now, 64 following remains.
# Now run the 610 time.
# 37196063 is following now, 63 following remains.
# Now run the 611 time.
# 53796494 is following now, 62 following remains.
# Now run the 612 time.
# 31117889 is following now, 61 following remains.
# Now run the 613 time.
# 9298947 is following now, 60 following remains.
# Now run the 614 time.
# 43743747 is following now, 59 following remains.
# Now run the 615 time.
# 33478257 is following now, 58 following remains.
# Now run the 616 time.
# 17593660 is following now, 57 following remains.
# Now run the 617 time.
# 55083304 is following now, 56 following remains.
# Now run the 618 time.
# 20694920 is following now, 55 following remains.
# Now run the 619 time.
# 10045074 is following now, 54 following remains.
# Now run the 620 time.
# 56843643 is following now, 53 following remains.
# Now run the 621 time.
# 58355110 is following now, 52 following remains.
# Now run the 622 time.
# 44886931 is following now, 51 following remains.
# Now run the 623 time.
# 21254968 is following now, 50 following remains.
# Now run the 624 time.
# 66347971 is following now, 49 following remains.
# Now run the 625 time.
# 25879195 is following now, 48 following remains.
# Now run the 626 time.
# 43577007 is following now, 47 following remains.
# Now run the 627 time.
# 43916223 is following now, 46 following remains.
# Now run the 628 time.
# 60021179 is following now, 45 following remains.
# Now run the 629 time.
# 44109305 is following now, 44 following remains.
# Now run the 630 time.
# 11879286 is following now, 43 following remains.
# Now run the 631 time.
# 54763335 is following now, 42 following remains.
# Now run the 632 time.
# 12799857 is following now, 41 following remains.
# Now run the 633 time.
# 64072316 is following now, 40 following remains.
# Now run the 634 time.
# 24398845 is following now, 39 following remains.
# Now run the 635 time.
# 41125432 is following now, 38 following remains.
# Now run the 636 time.
# 22734661 is following now, 37 following remains.
# Now run the 637 time.
# 19825193 is following now, 36 following remains.
# Now run the 638 time.
# 22065569 is following now, 35 following remains.
# Now run the 639 time.
# 68394916 is following now, 34 following remains.
# Now run the 640 time.
# 42669455 is following now, 33 following remains.
# Now run the 641 time.
# 64157615 is following now, 32 following remains.
# Now run the 642 time.
# 68121955 is following now, 31 following remains.
# Now run the 643 time.
# 68493597 is following now, 30 following remains.
# Now run the 644 time.
# 4153745 is following now, 29 following remains.
# Now run the 645 time.
# 3024015 is following now, 28 following remains.
# Now run the 646 time.
# 29850209 is following now, 27 following remains.
# Now run the 647 time.
# 58592772 is following now, 26 following remains.
# Now run the 648 time.
# 12582483 is following now, 25 following remains.
# Now run the 649 time.
# 20200704 is following now, 24 following remains.
# Now run the 650 time.
# 18645880 is following now, 23 following remains.
# Now run the 651 time.
# 52293583 is following now, 22 following remains.
# Now run the 652 time.
# 44364441 is following now, 21 following remains.
# Now run the 653 time.
# 9685097 is following now, 20 following remains.
# Now run the 654 time.
# 49930673 is following now, 19 following remains.
# Now run the 655 time.
# 63144507 is following now, 18 following remains.
# Now run the 656 time.
# 20764095 is following now, 17 following remains.
# Now run the 657 time.
# 22100498 is following now, 16 following remains.
# Now run the 658 time.
# 57066925 is following now, 15 following remains.
# Now run the 659 time.
# 64153270 is following now, 14 following remains.
# Now run the 660 time.
# 58615130 is following now, 13 following remains.
# Now run the 661 time.
# 50133583 is following now, 12 following remains.
# Now run the 662 time.
# 45635553 is following now, 11 following remains.
# Now run the 663 time.
# 61849051 is following now, 10 following remains.
# Now run the 664 time.
# 63866807 is following now, 9 following remains.
# Now run the 665 time.
# 17702698 is following now, 8 following remains.
# Now run the 666 time.
# 48163131 is following now, 7 following remains.
# Now run the 667 time.
# 66103059 is following now, 6 following remains.
# Now run the 668 time.
# 67854828 is following now, 5 following remains.
# Now run the 669 time.
# 18089254 is following now, 4 following remains.
# Now run the 670 time.
# 38633916 is following now, 3 following remains.
# Now run the 671 time.
# 12624669 is following now, 2 following remains.
# Now run the 672 time.
# 68490734 is following now, 1 following remains.
# Now run the 673 time.
# 11679287 is following now, 0 following remains.

# %%
# 关闭
browser.quit()
